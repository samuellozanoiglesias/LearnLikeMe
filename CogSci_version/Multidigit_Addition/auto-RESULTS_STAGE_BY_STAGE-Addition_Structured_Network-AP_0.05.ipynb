# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset


def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None


def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None


# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(jnp.dot(vec, T) + jnp.dot(z, v7))
    return z
    
def neural_network_2(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss


# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)

    correct_predictions_count = 0
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
def perfect_model():
    # R vectors of dimension (14,1)
    R2_perfect = np.zeros((14))
    R3_perfect = np.zeros((14))
    R4_perfect = np.zeros((14))
    R5_perfect = np.zeros((14))
    R6_perfect = np.zeros((14))
    R7_perfect = np.zeros((14))
    R8_perfect = np.zeros((14))
    
    for i in range(2):
        R2_perfect[7*i + 6] = 1
        R3_perfect[7*i + 5] = 1
        R4_perfect[7*i + 4] = 1
        R5_perfect[7*i + 3] = 1
        R6_perfect[7*i + 2] = 1
        R7_perfect[7*i + 1] = 1
        R8_perfect[7*i + 0] = 1
    
    # Scalar parameters v
    v2_perfect = 1/2
    v3_perfect = 1/2
    v4_perfect = 1/2
    v5_perfect = 1/2
    v6_perfect = 1/2
    v7_perfect = 1/2
    
    # Matrix T of dimension (28,7)
    T_perfect = np.zeros((14,8))
    for i in range(7):
        for j in range(2):
            T_perfect[7*j + i, i + 1] = 1
    
    # Parameter v
    v_perfect = 1/2
    
    original_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    trainable_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    return trainable_model, original_model

def generate_model_random(mean=0.5, std=1):
    R2 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the second bit
    R3 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R4 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R6 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R7 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R8 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    v2 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    T = initialize_random_weights(mean, std, (14, 8))  # 196 neurons that allow performing the sum
    v = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    trainable_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    return trainable_model, original_model
    
def generate_model_AP(epsilon_non_zeros = 0.01, epsilon_zeros = 0.01):   
    R2_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R3_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R8_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)

    for i in range(4):
        R2_almost_perfect[7*i + 6] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R8_almost_perfect[7*i + 0] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v2_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)

    T_almost_perfect = np.zeros((14,8)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(2):
            T_almost_perfect[7*j + i, i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    trainable_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stage_by_stage/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
model = 'trainable_model_stage'
training_type = 'AP_0.05_0.05'

folder = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
folder_path = f'{folder}/Parameters/{training_type}'
date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"{folder_path}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    training_stages = 3
    trainings_needed = np.zeros(training_stages)    
    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    N = 500

    for stage in range(1,3):
        if stage == 1:
            trainable_model_stage_1 = [trainable_model[0],
                                       trainable_model[1],
                                       trainable_model[2],
                                       trainable_model[3],
                                       trainable_model[4],
                                       trainable_model[5],
                                       trainable_model[6],
                                       trainable_model[7],
                                       trainable_model[8],
                                       trainable_model[9],
                                       trainable_model[10],
                                       trainable_model[11],
                                       trainable_model[12]]
        elif stage == 2:
            trainable_model_stage_2 = [trainable_model_stage_1[0], 
                                       trainable_model_stage_1[1], 
                                       trainable_model_stage_1[2], 
                                       trainable_model_stage_1[3], 
                                       trainable_model_stage_1[4], 
                                       trainable_model_stage_1[5], 
                                       trainable_model_stage_1[6], 
                                       trainable_model_stage_1[7], 
                                       trainable_model_stage_1[8], 
                                       trainable_model_stage_1[9], 
                                       trainable_model_stage_1[10],
                                       trainable_model_stage_1[11],
                                       trainable_model_stage_1[12],
                                       trainable_model[13], 
                                       trainable_model[14]]
        
        save_dir = f"{folder}/Trained_models/Stage_by_stage/{training_type}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.005
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_trained_count == train_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        train_size = correct_predictions_trained_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_12_04_18_57_30.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0031159017235040665.
# Objective completed
# Stage 1 completed in 10.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_1\trainable_model_stage_1-2024_12_04_18_57_30.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_1\Stage_1_results_2024_12_04_18_57_30.txt
# STAGE 2: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0030201186891645193.
# Objective completed
# Stage 2 completed in 10.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_2\trainable_model_stage_2-2024_12_04_18_57_30.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_2\Stage_2_results_2024_12_04_18_57_30.txt
# Loaded trainable_model_stage_2024_12_04_18_57_32.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.003368781879544258.
# Objective completed
# Stage 1 completed in 10.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_1\trainable_model_stage_1-2024_12_04_18_57_32.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_1\Stage_1_results_2024_12_04_18_57_32.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_2\trainable_model_stage_2-2024_12_04_18_57_32.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_2\Stage_2_results_2024_12_04_18_57_32.txt
# Loaded trainable_model_stage_2024_12_04_18_57_34.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.006632950156927109.
# Objective completed
# Stage 1 completed in 10.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_1\trainable_model_stage_1-2024_12_04_18_57_34.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_1\Stage_1_results_2024_12_04_18_57_34.txt
# STAGE 2: Out of 8000, 1585 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 440 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.1550164520740509.
# STAGE 2: Out of 8000, 3117 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 767 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.10315743833780289.
# STAGE 2: Out of 8000, 4261 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0680052861571312.
# STAGE 2: Out of 8000, 4546 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1106 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0615534707903862.
# STAGE 2: Out of 8000, 4529 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1101 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059926148504018784.
# STAGE 2: Out of 8000, 4537 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1116 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06386084854602814.
# STAGE 2: Out of 8000, 4434 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1088 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060209326446056366.
# STAGE 2: Out of 8000, 4442 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1109 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0549880713224411.
# STAGE 2: Out of 8000, 4350 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1080 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05658853054046631.
# STAGE 2: Out of 8000, 4583 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1147 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05966370180249214.
# STAGE 2: Out of 8000, 4612 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1139 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05824026092886925.
# STAGE 2: Out of 8000, 4657 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1171 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057865723967552185.
# STAGE 2: Out of 8000, 4398 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1102 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0570966936647892.
# STAGE 2: Out of 8000, 4700 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1177 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057378560304641724.
# STAGE 2: Out of 8000, 4364 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1096 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06220828369259834.
# STAGE 2: Out of 8000, 4631 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1149 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05957917124032974.
# STAGE 2: Out of 8000, 4730 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1175 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04998175427317619.
# STAGE 2: Out of 8000, 4371 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1104 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0555705800652504.
# STAGE 2: Out of 8000, 4608 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1153 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058490145951509476.
# STAGE 2: Out of 8000, 4658 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1164 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0526229627430439.
# STAGE 2: Out of 8000, 4704 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1166 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054346729069948196.
# STAGE 2: Out of 8000, 4631 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1152 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05741926282644272.
# STAGE 2: Out of 8000, 4700 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1181 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05897442251443863.
# STAGE 2: Out of 8000, 4545 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1140 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05728699266910553.
# STAGE 2: Out of 8000, 4741 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1190 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05131686106324196.
# STAGE 2: Out of 8000, 4672 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1166 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05939234420657158.
# STAGE 2: Out of 8000, 4536 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1132 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05863816291093826.
# STAGE 2: Out of 8000, 4467 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1126 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06087753176689148.
# STAGE 2: Out of 8000, 4781 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1194 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052908506244421005.
# STAGE 2: Out of 8000, 4535 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1139 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061103805899620056.
# STAGE 2: Out of 8000, 4580 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1150 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056006066501140594.
# STAGE 2: Out of 8000, 4765 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1188 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05628257617354393.
# STAGE 2: Out of 8000, 4474 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1119 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06083522364497185.
# STAGE 2: Out of 8000, 4715 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1175 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05796811729669571.
# STAGE 2: Out of 8000, 4712 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1177 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05665147304534912.
# STAGE 2: Out of 8000, 4616 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1148 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05705428868532181.
# STAGE 2: Out of 8000, 4546 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1142 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05541827157139778.
# STAGE 2: Out of 8000, 4801 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1192 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052315302193164825.
# STAGE 2: Out of 8000, 4284 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1079 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059239961206912994.
# STAGE 2: Out of 8000, 4460 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1107 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05698242783546448.
# STAGE 2: Out of 8000, 4711 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1180 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05571197345852852.
# STAGE 2: Out of 8000, 4692 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1193 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05308081954717636.
# STAGE 2: Out of 8000, 4351 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1094 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054535072296857834.
# STAGE 2: Out of 8000, 4661 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1175 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05124618858098984.
# STAGE 2: Out of 8000, 4157 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1048 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05925477668642998.
# STAGE 2: Out of 8000, 4747 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1196 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054462358355522156.
# STAGE 2: Out of 8000, 4783 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1187 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056721966713666916.
# STAGE 2: Out of 8000, 4737 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1176 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053213007748126984.
# STAGE 2: Out of 8000, 4697 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1171 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05566297471523285.
# STAGE 2: Out of 8000, 4613 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1148 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05681123211979866.
# STAGE 2: Out of 8000, 4792 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1182 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05410661920905113.
# STAGE 2: Out of 8000, 4681 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1175 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05446207895874977.
# STAGE 2: Out of 8000, 4599 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1139 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053346164524555206.
# STAGE 2: Out of 8000, 4698 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1173 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054429665207862854.
# STAGE 2: Out of 8000, 4607 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1147 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05222853273153305.
# STAGE 2: Out of 8000, 4739 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1186 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053654711693525314.
# STAGE 2: Out of 8000, 4516 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1142 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059811871498823166.
# STAGE 2: Out of 8000, 4624 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1142 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05418356508016586.
# STAGE 2: Out of 8000, 4495 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1122 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05530045926570892.
# STAGE 2: Out of 8000, 4693 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1166 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055106427520513535.
# STAGE 2: Out of 8000, 4500 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1128 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06279027462005615.
# STAGE 2: Out of 8000, 4638 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1165 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052270472049713135.
# STAGE 2: Out of 8000, 4505 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1120 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05726584419608116.
# STAGE 2: Out of 8000, 4484 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1121 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05433076247572899.
# STAGE 2: Out of 8000, 4636 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1154 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05514087527990341.
# STAGE 2: Out of 8000, 4576 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1143 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05343813821673393.
# STAGE 2: Out of 8000, 4704 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1180 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053608909249305725.
# STAGE 2: Out of 8000, 4590 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1147 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05513359233736992.
# STAGE 2: Out of 8000, 4539 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1129 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060013771057128906.
# STAGE 2: Out of 8000, 4622 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1141 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05751169100403786.
# STAGE 2: Out of 8000, 4564 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1143 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05724695324897766.
# STAGE 2: Out of 8000, 4467 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1110 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05214230343699455.
# STAGE 2: Out of 8000, 4570 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1139 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055518344044685364.
# STAGE 2: Out of 8000, 4671 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1171 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05308346450328827.
# STAGE 2: Out of 8000, 4618 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1154 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06003180891275406.
# STAGE 2: Out of 8000, 4723 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1177 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053561076521873474.
# STAGE 2: Out of 8000, 4509 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1139 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05562811717391014.
# STAGE 2: Out of 8000, 4669 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1158 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05116855725646019.
# STAGE 2: Out of 8000, 4684 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1169 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0591331422328949.
# STAGE 2: Out of 8000, 4708 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1171 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05747874453663826.
# STAGE 2: Out of 8000, 4648 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1162 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05315152555704117.
# STAGE 2: Out of 8000, 4794 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1193 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05219659581780434.
# STAGE 2: Out of 8000, 4853 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1205 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05331053212285042.
# STAGE 2: Out of 8000, 4759 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1205 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05258279666304588.
# STAGE 2: Out of 8000, 4782 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1184 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0552084781229496.
# STAGE 2: Out of 8000, 4790 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1196 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05679039657115936.
# STAGE 2: Out of 8000, 4543 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1129 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05484209209680557.
# STAGE 2: Out of 8000, 4763 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1181 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05408012866973877.
# STAGE 2: Out of 8000, 4494 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1117 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06116800382733345.
# STAGE 2: Out of 8000, 4679 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1184 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06055177375674248.
# STAGE 2: Out of 8000, 4803 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1197 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05105077847838402.
# STAGE 2: Out of 8000, 4699 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1185 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055965401232242584.
# STAGE 2: Out of 8000, 4679 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1168 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05417269095778465.
# STAGE 2: Out of 8000, 4663 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1169 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05888928845524788.
# STAGE 2: Out of 8000, 4561 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1139 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05360230430960655.
# STAGE 2: Out of 8000, 4482 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1130 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056345533579587936.
# STAGE 2: Out of 8000, 4654 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1160 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053277190774679184.
# STAGE 2: Out of 8000, 4377 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1105 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05706382915377617.
# STAGE 2: Out of 8000, 4674 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1175 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05160399526357651.
# STAGE 2: Out of 8000, 4665 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1166 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05683200806379318.
# STAGE 2: Out of 8000, 4609 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1147 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055148664861917496.
# STAGE 2: Out of 8000, 4797 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1191 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057056233286857605.
# STAGE 2: Out of 8000, 4771 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1199 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05616268888115883.
# STAGE 2: Out of 8000, 4672 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1166 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05367233231663704.
# STAGE 2: Out of 8000, 4821 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1201 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053961098194122314.
# STAGE 2: Out of 8000, 4694 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1162 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05247249826788902.
# STAGE 2: Out of 8000, 4505 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1124 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055846791714429855.
# STAGE 2: Out of 8000, 4545 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1129 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05787789449095726.
# STAGE 2: Out of 8000, 4351 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1086 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05960816517472267.
# STAGE 2: Out of 8000, 4583 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1147 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05580149218440056.
# STAGE 2: Out of 8000, 4483 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1117 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05317375808954239.
# STAGE 2: Out of 8000, 4694 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1166 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05689715966582298.
# STAGE 2: Out of 8000, 4396 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1094 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058082617819309235.
# STAGE 2: Out of 8000, 4552 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1142 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05518708378076553.
# STAGE 2: Out of 8000, 4386 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1092 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056272637099027634.
# STAGE 2: Out of 8000, 4823 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1208 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05432675778865814.
# STAGE 2: Out of 8000, 4492 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1138 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05764978751540184.
# STAGE 2: Out of 8000, 4674 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1166 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052209317684173584.
# STAGE 2: Out of 8000, 4738 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1182 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05281272158026695.
# STAGE 2: Out of 8000, 4699 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1182 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053860608488321304.
# STAGE 2: Out of 8000, 4455 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1126 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05712150037288666.
# STAGE 2: Out of 8000, 4516 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1130 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05682133138179779.
# STAGE 2: Out of 8000, 4438 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1110 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05281348153948784.
# STAGE 2: Out of 8000, 4692 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1174 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05507359281182289.
# STAGE 2: Out of 8000, 4560 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1161 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05869091674685478.
# STAGE 2: Out of 8000, 4730 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1182 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05240432918071747.
# STAGE 2: Out of 8000, 4725 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1193 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055457305163145065.
# STAGE 2: Out of 8000, 4445 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1124 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05957551673054695.
# STAGE 2: Out of 8000, 4466 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1144 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05572564899921417.
# STAGE 2: Out of 8000, 4579 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1174 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05395149067044258.
# STAGE 2: Out of 8000, 4654 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1183 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.051690638065338135.
# STAGE 2: Out of 8000, 4653 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1174 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05337364971637726.
# STAGE 2: Out of 8000, 4555 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1165 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05419843643903732.
# STAGE 2: Out of 8000, 4628 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1169 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05605074390769005.
# STAGE 2: Out of 8000, 4574 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1158 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05585408955812454.
# STAGE 2: Out of 8000, 4425 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1126 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06373309344053268.
# STAGE 2: Out of 8000, 4602 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1170 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05405265465378761.
# STAGE 2: Out of 8000, 4631 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1178 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05461402237415314.
# STAGE 2: Out of 8000, 4594 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1157 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05864088982343674.
# STAGE 2: Out of 8000, 4651 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1193 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052696071565151215.
# STAGE 2: Out of 8000, 4586 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1165 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05501510202884674.
# STAGE 2: Out of 8000, 4590 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1154 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05780831724405289.
# STAGE 2: Out of 8000, 4627 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1170 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05373984947800636.
# STAGE 2: Out of 8000, 4703 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1180 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05240093916654587.
# STAGE 2: Out of 8000, 4648 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1151 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052985403686761856.
# STAGE 2: Out of 8000, 4603 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1124 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055541764944791794.
# STAGE 2: Out of 8000, 4629 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1154 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05779380351305008.
# STAGE 2: Out of 8000, 4761 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1172 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05803084000945091.
# STAGE 2: Out of 8000, 4711 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1172 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05948873236775398.
# STAGE 2: Out of 8000, 4735 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1173 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05387858673930168.
# STAGE 2: Out of 8000, 4900 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1208 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05566713213920593.
# STAGE 2: Out of 8000, 4751 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1183 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05196661129593849.
# STAGE 2: Out of 8000, 4494 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1131 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06042572110891342.
# STAGE 2: Out of 8000, 4971 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1213 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0545528307557106.
# STAGE 2: Out of 8000, 5043 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1249 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05040329322218895.
# STAGE 2: Out of 8000, 5113 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1282 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055682223290205.
# STAGE 2: Out of 8000, 5119 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1269 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05209118127822876.
# STAGE 2: Out of 8000, 5089 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1277 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.051930077373981476.
# STAGE 2: Out of 8000, 5280 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1300 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04766473546624184.
# STAGE 2: Out of 8000, 5050 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1255 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05398402735590935.
# STAGE 2: Out of 8000, 5147 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1293 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05064224451780319.
# STAGE 2: Out of 8000, 5163 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1293 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04751167446374893.
# STAGE 2: Out of 8000, 5189 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1288 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04997948184609413.
# STAGE 2: Out of 8000, 5291 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1300 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05055081099271774.
# STAGE 2: Out of 8000, 5111 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1283 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05057666078209877.
# STAGE 2: Out of 8000, 5149 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1283 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.044631365686655045.
# STAGE 2: Out of 8000, 5215 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1307 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0492095910012722.
# STAGE 2: Out of 8000, 5179 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1288 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054989803582429886.
# STAGE 2: Out of 8000, 5167 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1294 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05057034268975258.
# STAGE 2: Out of 8000, 5064 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1259 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04745906591415405.
# STAGE 2: Out of 8000, 5050 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1262 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05080290511250496.
# STAGE 2: Out of 8000, 5091 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1264 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05141080170869827.
# STAGE 2: Out of 8000, 5194 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1279 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05037728324532509.
# STAGE 2: Out of 8000, 5008 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1246 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05708666890859604.
# STAGE 2: Out of 8000, 5219 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1285 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04425201192498207.
# STAGE 2: Out of 8000, 5204 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1285 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05048147961497307.
# STAGE 2: Out of 8000, 5273 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1300 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.050810229033231735.
# STAGE 2: Out of 8000, 5238 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1281 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04927132651209831.
# STAGE 2: Out of 8000, 5167 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1283 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0515289381146431.
# STAGE 2: Out of 8000, 5128 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1283 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05096472054719925.
# STAGE 2: Out of 8000, 5295 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1305 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052219539880752563.
# STAGE 2: Out of 8000, 5158 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1273 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.047265663743019104.
# STAGE 2: Out of 8000, 5214 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1292 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05278704687952995.
# STAGE 2: Out of 8000, 5152 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1273 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05263105034828186.
# STAGE 2: Out of 8000, 5133 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1273 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05662139132618904.
# STAGE 2: Out of 8000, 5198 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1282 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05151158571243286.
# STAGE 2: Out of 8000, 5067 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1265 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04988054558634758.
# STAGE 2: Out of 8000, 5191 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1292 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04958692193031311.
# STAGE 2: Out of 8000, 4966 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1258 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056649349629879.
# STAGE 2: Out of 8000, 5081 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1274 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05421755462884903.
# STAGE 2: Out of 8000, 5053 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1252 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05627402663230896.
# STAGE 2: Out of 8000, 5117 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1270 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05030493438243866.
# STAGE 2: Out of 8000, 5215 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1292 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.045592185109853745.
# STAGE 2: Out of 8000, 5190 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1287 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0512578971683979.
# STAGE 2: Out of 8000, 5116 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1271 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05288897454738617.
# STAGE 2: Out of 8000, 5061 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1265 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05563465133309364.
# STAGE 2: Out of 8000, 5082 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1249 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052517425268888474.
# STAGE 2: Out of 8000, 5130 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1287 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05094360560178757.
# STAGE 2: Out of 8000, 5235 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1296 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04975273087620735.
# STAGE 2: Out of 8000, 5092 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1278 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05079726129770279.
# STAGE 2: Out of 8000, 5168 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1268 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.042521730065345764.
# STAGE 2: Out of 8000, 5179 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1282 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05094801262021065.
# STAGE 2: Out of 8000, 5244 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1300 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.047213491052389145.
# STAGE 2: Out of 8000, 5128 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1279 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04597245529294014.
# STAGE 2: Out of 8000, 5059 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1268 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05212957039475441.
# STAGE 2: Out of 8000, 5036 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1258 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04836736246943474.
# STAGE 2: Out of 8000, 5146 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1283 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04632477089762688.
# STAGE 2: Out of 8000, 5090 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1272 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.050655342638492584.
# STAGE 2: Out of 8000, 5019 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1257 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.049135737121105194.
# STAGE 2: Out of 8000, 5044 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1251 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04694968834519386.
# STAGE 2: Out of 8000, 5005 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1245 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05311150476336479.
# STAGE 2: Out of 8000, 5169 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1291 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05294227972626686.
# STAGE 2: Out of 8000, 5154 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1272 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05435343086719513.
# STAGE 2: Out of 8000, 5032 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1259 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05350648611783981.
# STAGE 2: Out of 8000, 5119 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1266 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0522470660507679.
# STAGE 2: Out of 8000, 5052 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1252 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04592578485608101.
# STAGE 2: Out of 8000, 5111 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1274 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05063027888536453.
# STAGE 2: Out of 8000, 5119 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1268 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04985812306404114.
# STAGE 2: Out of 8000, 5191 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1286 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05161887779831886.
# STAGE 2: Out of 8000, 5162 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1286 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05171188339591026.
# STAGE 2: Out of 8000, 5140 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1282 tested were predicted correctly in the current model.
# ...
# STAGE 2: Out of 2000, 1559 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02663760632276535.
# STAGE 2: Out of 8000, 6330 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022705838084220886.
# STAGE 2: Out of 8000, 6325 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.019591687247157097.
# STAGE 2: Out of 8000, 6374 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1573 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02289193868637085.
# STAGE 2: Out of 8000, 6348 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.020689602941274643.
# STAGE 2: Out of 8000, 6323 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.020943690091371536.
# STAGE 2: Out of 8000, 6329 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02506309561431408.
# STAGE 2: Out of 8000, 6367 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1576 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.020840642973780632.
# STAGE 2: Out of 8000, 6338 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02432057447731495.
# STAGE 2: Out of 8000, 6323 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1559 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022167226299643517.
# STAGE 2: Out of 8000, 6343 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1565 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02307002618908882.
# STAGE 2: Out of 8000, 6319 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1559 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02194175310432911.
# STAGE 2: Out of 8000, 6328 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.01877834089100361.
# STAGE 2: Out of 8000, 6328 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023745249956846237.
# STAGE 2: Out of 8000, 6330 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1560 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023683816194534302.
# STAGE 2: Out of 8000, 6317 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1561 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.024595502763986588.
# STAGE 2: Out of 8000, 6330 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1557 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023240333423018456.
# STAGE 2: Out of 8000, 6314 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1561 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02289215661585331.
# STAGE 2: Out of 8000, 6324 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1558 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021979326382279396.
# STAGE 2: Out of 8000, 6314 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1559 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022837726399302483.
# STAGE 2: Out of 8000, 6325 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1561 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023471908643841743.
# STAGE 2: Out of 8000, 6341 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1565 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02253439836204052.
# STAGE 2: Out of 8000, 6327 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1556 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02398831956088543.
# STAGE 2: Out of 8000, 6327 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1561 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021940195932984352.
# STAGE 2: Out of 8000, 6341 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.025777198374271393.
# STAGE 2: Out of 8000, 6315 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1560 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.020221693441271782.
# STAGE 2: Out of 8000, 6341 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1572 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022247403860092163.
# STAGE 2: Out of 8000, 6327 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.025725478306412697.
# STAGE 2: Out of 8000, 6318 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1560 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021156322211027145.
# STAGE 2: Out of 8000, 6291 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.024803319945931435.
# STAGE 2: Out of 8000, 6331 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023016998544335365.
# STAGE 2: Out of 8000, 6320 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023471243679523468.
# STAGE 2: Out of 8000, 6315 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1560 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02384803257882595.
# STAGE 2: Out of 8000, 6315 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02489885501563549.
# STAGE 2: Out of 8000, 6330 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1561 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02411615289747715.
# STAGE 2: Out of 8000, 6335 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.026811104267835617.
# STAGE 2: Out of 8000, 6322 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1554 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022318854928016663.
# STAGE 2: Out of 8000, 6346 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1559 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.025030288845300674.
# STAGE 2: Out of 8000, 6335 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02243213728070259.
# STAGE 2: Out of 8000, 6353 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1566 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02145635150372982.
# STAGE 2: Out of 8000, 6328 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1565 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02281436324119568.
# STAGE 2: Out of 8000, 6336 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023228170350193977.
# STAGE 2: Out of 8000, 6326 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1560 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02411263808608055.
# STAGE 2: Out of 8000, 6317 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022094564512372017.
# STAGE 2: Out of 8000, 6331 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.025538235902786255.
# STAGE 2: Out of 8000, 6335 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022408971562981606.
# STAGE 2: Out of 8000, 6334 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1561 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023960115388035774.
# STAGE 2: Out of 8000, 6337 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.025410844013094902.
# STAGE 2: Out of 8000, 6336 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1565 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02175459824502468.
# STAGE 2: Out of 8000, 6324 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1558 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.024218138307332993.
# STAGE 2: Out of 8000, 6316 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1556 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022342700511217117.
# STAGE 2: Out of 8000, 6325 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1556 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021793151274323463.
# STAGE 2: Out of 8000, 6328 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.020337725058197975.
# STAGE 2: Out of 8000, 6337 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1562 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021406149491667747.
# STAGE 2: Out of 8000, 6328 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1558 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021943548694252968.
# STAGE 2: Out of 8000, 6338 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.025352995842695236.
# STAGE 2: Out of 8000, 6343 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1566 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.020144382491707802.
# STAGE 2: Out of 8000, 6341 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02440381608903408.
# STAGE 2: Out of 8000, 6358 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1571 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.024048343300819397.
# STAGE 2: Out of 8000, 6359 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1571 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02293398231267929.
# STAGE 2: Out of 8000, 6309 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1566 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02395309880375862.
# STAGE 2: Out of 8000, 6327 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023884063586592674.
# STAGE 2: Out of 8000, 6351 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1567 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.022006534039974213.
# STAGE 2: Out of 8000, 6354 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1566 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023866450414061546.
# STAGE 2: Out of 8000, 6336 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1559 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02093537338078022.
# STAGE 2: Out of 8000, 6329 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1568 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.019264252856373787.
# STAGE 2: Out of 8000, 6340 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1565 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023490235209465027.
# STAGE 2: Out of 8000, 6370 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1568 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02314773015677929.
# STAGE 2: Out of 8000, 6353 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1565 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02056184411048889.
# STAGE 2: Out of 8000, 6325 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1559 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023849066346883774.
# STAGE 2: Out of 8000, 6324 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1558 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021968260407447815.
# STAGE 2: Out of 8000, 6316 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1557 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.025406062602996826.
# STAGE 2: Out of 8000, 6348 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1567 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.021156178787350655.
# STAGE 2: Out of 8000, 6347 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1566 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.023489126935601234.
# STAGE 2: Out of 8000, 6330 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1558 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02344425953924656.
# STAGE 2: Out of 8000, 6340 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1560 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02207803912460804.
# STAGE 2: Out of 8000, 6307 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1551 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02481258660554886.
# Stage 2 completed in 2500.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_2\trainable_model_stage_2-2024_12_04_18_57_38.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stage_by_stage/AP_0.05_0.05/Stage_2\Stage_2_results_2024_12_04_18_57_38.txt
