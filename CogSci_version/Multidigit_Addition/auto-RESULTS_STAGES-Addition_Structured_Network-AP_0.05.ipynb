# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_carry_over_dataset = eval(file.read())
    
# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)

    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None


def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None


# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count, carry_over_size, correct_carry_over_predictions_tested_count = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {carry_over_size}, {correct_carry_over_predictions_tested_count} tested with carry-over were predicted correctly in the current model.")      

    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)

    correct_predictions_count = 0
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
def perfect_model():
    # R vectors of dimension (14,1)
    R2_perfect = np.zeros((14))
    R3_perfect = np.zeros((14))
    R4_perfect = np.zeros((14))
    R5_perfect = np.zeros((14))
    R6_perfect = np.zeros((14))
    R7_perfect = np.zeros((14))
    R8_perfect = np.zeros((14))
    
    for i in range(2):
        R2_perfect[7*i + 6] = 1
        R3_perfect[7*i + 5] = 1
        R4_perfect[7*i + 4] = 1
        R5_perfect[7*i + 3] = 1
        R6_perfect[7*i + 2] = 1
        R7_perfect[7*i + 1] = 1
        R8_perfect[7*i + 0] = 1
    
    # Scalar parameters v
    v2_perfect = 1/2
    v3_perfect = 1/2
    v4_perfect = 1/2
    v5_perfect = 1/2
    v6_perfect = 1/2
    v7_perfect = 1/2
    
    # Matrix T of dimension (28,7)
    T_perfect = np.zeros((14,8))
    for i in range(7):
        for j in range(2):
            T_perfect[7*j + i, i + 1] = 1
    
    # Parameter v
    v_perfect = 1/2
    
    original_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    trainable_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    return trainable_model, original_model

def generate_model_random(mean=0.5, std=1):
    R2 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the second bit
    R3 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R4 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R6 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R7 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R8 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    v2 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    T = initialize_random_weights(mean, std, (14, 8))  # 196 neurons that allow performing the sum
    v = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    trainable_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    return trainable_model, original_model
    
def generate_model_AP(epsilon_non_zeros = 0.01, epsilon_zeros = 0.01):   
    R2_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R3_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R8_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)

    for i in range(2):
        R2_almost_perfect[7*i + 6] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R8_almost_perfect[7*i + 0] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v2_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)

    T_almost_perfect = np.zeros((14,8)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(2):
            T_almost_perfect[7*j + i, i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    trainable_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
model = 'trainable_model_stage'
training_type = 'AP_0.05_0.05'

folder = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
folder_path = f'{folder}/Parameters/{training_type}'
date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"{folder_path}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    training_stages = 3
    trainings_needed = np.zeros(training_stages)    
    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    N = 500

    for stage in range(1,4):
        if stage == 1:
            trainable_model_stage_1 = [trainable_model[0],
                                       trainable_model[1],
                                       trainable_model[2],
                                       trainable_model[3],
                                       trainable_model[4],
                                       trainable_model[5],
                                       trainable_model[6],
                                       trainable_model[7],
                                       trainable_model[8],
                                       trainable_model[9],
                                       trainable_model[10],
                                       trainable_model[11],
                                       trainable_model[12]]
        elif stage == 2:
            trainable_model_stage_2 = [trainable_model[13], 
                                       trainable_model[14]]
        elif stage == 3:
            trainable_model_stage_3 = [trainable_model_stage_1[0], 
                                       trainable_model_stage_1[1], 
                                       trainable_model_stage_1[2], 
                                       trainable_model_stage_1[3], 
                                       trainable_model_stage_1[4], 
                                       trainable_model_stage_1[5], 
                                       trainable_model_stage_1[6], 
                                       trainable_model_stage_1[7], 
                                       trainable_model_stage_1[8], 
                                       trainable_model_stage_1[9], 
                                       trainable_model_stage_1[10],
                                       trainable_model_stage_1[11],
                                       trainable_model_stage_1[12],
                                       trainable_model_stage_2[0],
                                       trainable_model_stage_2[1]]
        
        save_dir = f"{folder}/Trained_models/Stages/{training_type}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.005
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_trained_count == train_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        train_size = correct_predictions_trained_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_12_04_18_57_30.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0031480712350457907.
# Objective completed
# Stage 1 completed in 10.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\trainable_model_stage_1-2024_12_04_18_57_30.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\Stage_1_results_2024_12_04_18_57_30.txt
# STAGE 2: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0030243468936532736.
# Objective completed
# Stage 2 completed in 10.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_2\trainable_model_stage_2-2024_12_04_18_57_30.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_2\Stage_2_results_2024_12_04_18_57_30.txt
# Objective completed
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\trainable_model_stage_3-2024_12_04_18_57_30.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\Stage_3_results_2024_12_04_18_57_30.txt
# Loaded trainable_model_stage_2024_12_04_18_57_32.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0035005828831344843.
# Objective completed
# Stage 1 completed in 10.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\trainable_model_stage_1-2024_12_04_18_57_32.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\Stage_1_results_2024_12_04_18_57_32.txt
# STAGE 2: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0015884455060586333.
# Objective completed
# Stage 2 completed in 10.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_2\trainable_model_stage_2-2024_12_04_18_57_32.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_2\Stage_2_results_2024_12_04_18_57_32.txt
# Objective completed
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\trainable_model_stage_3-2024_12_04_18_57_32.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\Stage_3_results_2024_12_04_18_57_32.txt
# Loaded trainable_model_stage_2024_12_04_18_57_34.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0066404687240719795.
# Objective completed
# Stage 1 completed in 10.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\trainable_model_stage_1-2024_12_04_18_57_34.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\Stage_1_results_2024_12_04_18_57_34.txt
# STAGE 2: Out of 8000, 2662 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 653 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.09157422930002213.
# STAGE 2: Out of 8000, 3824 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 947 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06044326350092888.
# STAGE 2: Out of 8000, 4091 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06812231242656708.
# STAGE 2: Out of 8000, 4399 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1066 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05901271477341652.
# STAGE 2: Out of 8000, 4192 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1036 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06153874471783638.
# STAGE 2: Out of 8000, 4134 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06475895643234253.
# STAGE 2: Out of 8000, 4223 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1029 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05615880712866783.
# STAGE 2: Out of 8000, 3345 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 844 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06496234983205795.
# STAGE 2: Out of 8000, 3579 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 895 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05948660522699356.
# STAGE 2: Out of 8000, 3447 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 852 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06386257708072662.
# STAGE 2: Out of 8000, 4026 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 990 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05676829069852829.
# STAGE 2: Out of 8000, 4282 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1033 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05862032622098923.
# STAGE 2: Out of 8000, 4040 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05963946506381035.
# STAGE 2: Out of 8000, 3682 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 920 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06336794793605804.
# STAGE 2: Out of 8000, 4216 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1033 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061354104429483414.
# STAGE 2: Out of 8000, 3972 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 977 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06294617801904678.
# STAGE 2: Out of 8000, 4472 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1080 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055661194026470184.
# STAGE 2: Out of 8000, 4180 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1049 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05244404822587967.
# STAGE 2: Out of 8000, 3690 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 912 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05376007407903671.
# STAGE 2: Out of 8000, 3987 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0606217086315155.
# STAGE 2: Out of 8000, 3822 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 953 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06094852462410927.
# STAGE 2: Out of 8000, 2331 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 584 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05689145252108574.
# STAGE 2: Out of 8000, 3963 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06155528128147125.
# STAGE 2: Out of 8000, 3841 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 953 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06035395339131355.
# STAGE 2: Out of 8000, 3671 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 938 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061235733330249786.
# STAGE 2: Out of 8000, 3712 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 920 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06299091130495071.
# STAGE 2: Out of 8000, 4242 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06528941541910172.
# STAGE 2: Out of 8000, 3503 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 879 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05982669070363045.
# STAGE 2: Out of 8000, 3933 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 985 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05719878897070885.
# STAGE 2: Out of 8000, 4022 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05437977984547615.
# STAGE 2: Out of 8000, 4241 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1048 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05401964113116264.
# STAGE 2: Out of 8000, 3742 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 942 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0638861209154129.
# STAGE 2: Out of 8000, 3418 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 871 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06731536239385605.
# STAGE 2: Out of 8000, 4119 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05905677378177643.
# STAGE 2: Out of 8000, 3942 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 969 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06277665495872498.
# STAGE 2: Out of 8000, 3246 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 812 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05987035483121872.
# STAGE 2: Out of 8000, 3952 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059298112988471985.
# STAGE 2: Out of 8000, 3896 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 973 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061588265001773834.
# STAGE 2: Out of 8000, 4027 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 985 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05941680818796158.
# STAGE 2: Out of 8000, 4022 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05536771938204765.
# STAGE 2: Out of 8000, 4148 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060055579990148544.
# STAGE 2: Out of 8000, 3798 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 951 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05775310844182968.
# STAGE 2: Out of 8000, 4009 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05608701705932617.
# STAGE 2: Out of 8000, 4271 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1047 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05637236684560776.
# STAGE 2: Out of 8000, 3396 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 847 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06157149747014046.
# STAGE 2: Out of 8000, 3902 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 969 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05333361774682999.
# STAGE 2: Out of 8000, 3978 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 981 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055279266089200974.
# STAGE 2: Out of 8000, 3865 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05892951041460037.
# STAGE 2: Out of 8000, 4079 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06354903429746628.
# STAGE 2: Out of 8000, 3873 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 974 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05808432772755623.
# STAGE 2: Out of 8000, 4059 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06387563794851303.
# STAGE 2: Out of 8000, 3871 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06239554286003113.
# STAGE 2: Out of 8000, 4006 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0645473524928093.
# STAGE 2: Out of 8000, 4189 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05713404342532158.
# STAGE 2: Out of 8000, 4007 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 999 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057555943727493286.
# STAGE 2: Out of 8000, 4043 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05944972112774849.
# STAGE 2: Out of 8000, 4243 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1045 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05872948840260506.
# STAGE 2: Out of 8000, 4021 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05439765006303787.
# STAGE 2: Out of 8000, 2471 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 623 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06875523179769516.
# STAGE 2: Out of 8000, 4269 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1040 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06418782472610474.
# STAGE 2: Out of 8000, 3921 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 988 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060606732964515686.
# STAGE 2: Out of 8000, 4081 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05741800740361214.
# STAGE 2: Out of 8000, 3940 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 981 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05980606749653816.
# STAGE 2: Out of 8000, 4086 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060575760900974274.
# STAGE 2: Out of 8000, 4295 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1042 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057362787425518036.
# STAGE 2: Out of 8000, 3555 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 896 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058072417974472046.
# STAGE 2: Out of 8000, 4247 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1054 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06395061314105988.
# STAGE 2: Out of 8000, 3818 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 973 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05957634747028351.
# STAGE 2: Out of 8000, 3872 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06409329921007156.
# STAGE 2: Out of 8000, 3898 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 967 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05619487538933754.
# STAGE 2: Out of 8000, 4117 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056419700384140015.
# STAGE 2: Out of 8000, 3130 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 788 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06222033128142357.
# STAGE 2: Out of 8000, 4109 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057339683175086975.
# STAGE 2: Out of 8000, 3623 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 921 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0661756619811058.
# STAGE 2: Out of 8000, 4067 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06017328426241875.
# STAGE 2: Out of 8000, 3884 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05607910826802254.
# STAGE 2: Out of 8000, 3843 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 974 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.062775619328022.
# STAGE 2: Out of 8000, 4331 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1053 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05658738687634468.
# STAGE 2: Out of 8000, 3710 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 931 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06521249562501907.
# STAGE 2: Out of 8000, 4309 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1045 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06104482337832451.
# STAGE 2: Out of 8000, 3853 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057648301124572754.
# STAGE 2: Out of 8000, 4161 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058502163738012314.
# STAGE 2: Out of 8000, 3689 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 925 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06420490890741348.
# STAGE 2: Out of 8000, 3486 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 867 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06602860987186432.
# STAGE 2: Out of 8000, 3943 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06382738053798676.
# STAGE 2: Out of 8000, 3766 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 957 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05993250012397766.
# STAGE 2: Out of 8000, 4244 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05372251197695732.
# STAGE 2: Out of 8000, 3553 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 899 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.062216099351644516.
# STAGE 2: Out of 8000, 3943 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05867714062333107.
# STAGE 2: Out of 8000, 4189 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05642813816666603.
# STAGE 2: Out of 8000, 3019 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 773 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06137695536017418.
# STAGE 2: Out of 8000, 4248 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1029 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05941082164645195.
# STAGE 2: Out of 8000, 2781 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 704 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06360677629709244.
# STAGE 2: Out of 8000, 4223 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1034 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05720359459519386.
# STAGE 2: Out of 8000, 3909 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06062505766749382.
# STAGE 2: Out of 8000, 3788 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 958 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06220948323607445.
# STAGE 2: Out of 8000, 3551 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 905 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07843184471130371.
# STAGE 2: Out of 8000, 4001 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06165195256471634.
# STAGE 2: Out of 8000, 3791 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 950 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05720333009958267.
# STAGE 2: Out of 8000, 3771 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 957 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058252040296792984.
# STAGE 2: Out of 8000, 3985 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055309221148490906.
# STAGE 2: Out of 8000, 4146 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1024 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05384686589241028.
# STAGE 2: Out of 8000, 4374 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1057 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06319157779216766.
# STAGE 2: Out of 8000, 3057 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 779 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05805316939949989.
# STAGE 2: Out of 8000, 3177 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 788 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057945579290390015.
# STAGE 2: Out of 8000, 3529 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 899 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057504359632730484.
# STAGE 2: Out of 8000, 3688 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 934 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06104467064142227.
# STAGE 2: Out of 8000, 3985 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06520956754684448.
# STAGE 2: Out of 8000, 4069 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05403248593211174.
# STAGE 2: Out of 8000, 3826 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 974 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05641428753733635.
# STAGE 2: Out of 8000, 4145 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06749345362186432.
# STAGE 2: Out of 8000, 3999 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1002 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05314205214381218.
# STAGE 2: Out of 8000, 3713 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 936 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058080535382032394.
# STAGE 2: Out of 8000, 4195 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05689574405550957.
# STAGE 2: Out of 8000, 4187 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06537779420614243.
# STAGE 2: Out of 8000, 3481 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 883 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06359734386205673.
# STAGE 2: Out of 8000, 3673 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 933 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056371692568063736.
# STAGE 2: Out of 8000, 4075 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057789720594882965.
# STAGE 2: Out of 8000, 3958 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05628060922026634.
# STAGE 2: Out of 8000, 3750 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 956 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06544516980648041.
# STAGE 2: Out of 8000, 4293 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1053 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06296058744192123.
# STAGE 2: Out of 8000, 3933 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 982 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057383645325899124.
# STAGE 2: Out of 8000, 4248 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1043 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06519240140914917.
# STAGE 2: Out of 8000, 3598 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 910 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05793085694313049.
# STAGE 2: Out of 8000, 3607 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 889 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06319912523031235.
# STAGE 2: Out of 8000, 4158 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05842158570885658.
# STAGE 2: Out of 8000, 3597 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 910 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06616673618555069.
# STAGE 2: Out of 8000, 3840 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 962 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06178395077586174.
# STAGE 2: Out of 8000, 3481 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 876 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06207193434238434.
# STAGE 2: Out of 8000, 3813 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 972 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05906548351049423.
# STAGE 2: Out of 8000, 4149 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0540882907807827.
# STAGE 2: Out of 8000, 3078 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 777 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05827309563755989.
# STAGE 2: Out of 8000, 3620 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 907 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061266589909791946.
# STAGE 2: Out of 8000, 4281 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1037 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05885525047779083.
# STAGE 2: Out of 8000, 4235 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1053 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05449943616986275.
# STAGE 2: Out of 8000, 3721 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 930 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06810717284679413.
# STAGE 2: Out of 8000, 3846 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 944 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06387372314929962.
# STAGE 2: Out of 8000, 4038 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 986 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059630703181028366.
# STAGE 2: Out of 8000, 3006 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 779 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06619128584861755.
# STAGE 2: Out of 8000, 4317 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1053 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061241116374731064.
# STAGE 2: Out of 8000, 2431 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 616 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0680844634771347.
# STAGE 2: Out of 8000, 4010 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05551149323582649.
# STAGE 2: Out of 8000, 4573 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1105 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06137005612254143.
# STAGE 2: Out of 8000, 4193 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1044 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06588532030582428.
# STAGE 2: Out of 8000, 3092 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 801 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06328165531158447.
# STAGE 2: Out of 8000, 3773 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 926 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0600222609937191.
# STAGE 2: Out of 8000, 4354 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1058 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05716036632657051.
# STAGE 2: Out of 8000, 3482 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 879 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06772588193416595.
# STAGE 2: Out of 8000, 4364 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1062 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06140332669019699.
# STAGE 2: Out of 8000, 3810 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 957 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06017886474728584.
# STAGE 2: Out of 8000, 3995 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06166502833366394.
# STAGE 2: Out of 8000, 4007 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059768155217170715.
# STAGE 2: Out of 8000, 4050 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 994 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06382589787244797.
# STAGE 2: Out of 8000, 4075 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.062217727303504944.
# STAGE 2: Out of 8000, 3758 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 956 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06365606933832169.
# STAGE 2: Out of 8000, 3686 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 920 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06418652087450027.
# STAGE 2: Out of 8000, 3098 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 800 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06208440661430359.
# STAGE 2: Out of 8000, 4550 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1094 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05117139592766762.
# STAGE 2: Out of 8000, 3288 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 811 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06565423309803009.
# STAGE 2: Out of 8000, 3451 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 869 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06421901285648346.
# STAGE 2: Out of 8000, 3628 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 917 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05591495335102081.
# STAGE 2: Out of 8000, 4067 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06620591878890991.
# STAGE 2: Out of 8000, 3942 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 982 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0537567138671875.
# STAGE 2: Out of 8000, 3194 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 804 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.065855473279953.
# STAGE 2: Out of 8000, 3847 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 968 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05714183673262596.
# STAGE 2: Out of 8000, 3990 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 983 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058333560824394226.
# STAGE 2: Out of 8000, 3940 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 994 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05771811306476593.
# STAGE 2: Out of 8000, 3994 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05779622122645378.
# STAGE 2: Out of 8000, 4236 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1037 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05803387239575386.
# STAGE 2: Out of 8000, 4000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05903743579983711.
# STAGE 2: Out of 8000, 3962 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05973063036799431.
# STAGE 2: Out of 8000, 4032 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05904783308506012.
# STAGE 2: Out of 8000, 3834 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 968 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05686457082629204.
# STAGE 2: Out of 8000, 4184 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1044 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059435147792100906.
# STAGE 2: Out of 8000, 4429 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1077 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0567263625562191.
# STAGE 2: Out of 8000, 4184 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06007290259003639.
# STAGE 2: Out of 8000, 3596 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 919 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05632441118359566.
# STAGE 2: Out of 8000, 4475 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1071 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05759982392191887.
# STAGE 2: Out of 8000, 4034 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05547872930765152.
# STAGE 2: Out of 8000, 4007 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05558390915393829.
# STAGE 2: Out of 8000, 3836 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 944 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058380186557769775.
# STAGE 2: Out of 8000, 3539 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 880 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060678694397211075.
# STAGE 2: Out of 8000, 4271 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1047 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06467057019472122.
# STAGE 2: Out of 8000, 3220 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 809 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061464183032512665.
# STAGE 2: Out of 8000, 3377 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 851 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06906523555517197.
# STAGE 2: Out of 8000, 3420 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 866 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05889743193984032.
# STAGE 2: Out of 8000, 4108 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1029 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059298355132341385.
# STAGE 2: Out of 8000, 4438 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1098 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054192788898944855.
# STAGE 2: Out of 8000, 2286 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 580 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06729361414909363.
# STAGE 2: Out of 8000, 4148 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05964658409357071.
# STAGE 2: Out of 8000, 3981 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 994 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06183316558599472.
# STAGE 2: Out of 8000, 4356 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1064 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05203365534543991.
# STAGE 2: Out of 8000, 4069 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06068676710128784.
# STAGE 2: Out of 8000, 3995 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 987 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06091797351837158.
# STAGE 2: Out of 8000, 3793 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 946 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.062047574669122696.
# STAGE 2: Out of 8000, 4535 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1096 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056093353778123856.
# STAGE 2: Out of 8000, 4027 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06159934401512146.
# STAGE 2: Out of 8000, 3961 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05533065274357796.
# STAGE 2: Out of 8000, 3788 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 949 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05969134718179703.
# STAGE 2: Out of 8000, 3549 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 890 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058246172964572906.
# STAGE 2: Out of 8000, 3952 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06076813489198685.
# STAGE 2: Out of 8000, 4363 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1059 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05971561744809151.
# STAGE 2: Out of 8000, 3951 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 981 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061389435082674026.
# STAGE 2: Out of 8000, 4181 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054844554513692856.
# STAGE 2: Out of 8000, 3926 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 972 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06108594313263893.
# STAGE 2: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05955903232097626.
# STAGE 2: Out of 8000, 4109 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 995 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06630392372608185.
# STAGE 2: Out of 8000, 3971 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 987 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05841635540127754.
# STAGE 2: Out of 8000, 3784 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 939 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06423614919185638.
# STAGE 2: Out of 8000, 4068 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 988 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06061485409736633.
# STAGE 2: Out of 8000, 3566 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 906 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061581116169691086.
# STAGE 2: Out of 8000, 3855 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 957 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06442970782518387.
# STAGE 2: Out of 8000, 3698 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 935 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05956177040934563.
# STAGE 2: Out of 8000, 4225 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07111094146966934.
# STAGE 2: Out of 8000, 3483 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 871 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0583869144320488.
# STAGE 2: Out of 8000, 4234 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1039 tested were predicted correctly in the current model.
# ...
# STAGE 3: Out of 2000, 1457 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02267625741660595.
# STAGE 3: Out of 8000, 5945 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1480 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02236809767782688.
# STAGE 3: Out of 8000, 6457 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1606 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02467559650540352.
# STAGE 3: Out of 8000, 6127 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1536 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.021945301443338394.
# STAGE 3: Out of 8000, 6541 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1609 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.026764292269945145.
# STAGE 3: Out of 8000, 6242 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1560 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025256682187318802.
# STAGE 3: Out of 8000, 6587 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1614 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024063600227236748.
# STAGE 3: Out of 8000, 6404 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1585 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02417070046067238.
# STAGE 3: Out of 8000, 6438 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1599 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023037083446979523.
# STAGE 3: Out of 8000, 6505 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1612 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020006636157631874.
# STAGE 3: Out of 8000, 6607 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1626 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023519499227404594.
# STAGE 3: Out of 8000, 6355 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1573 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.022577667608857155.
# STAGE 3: Out of 8000, 6573 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1620 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024656841531395912.
# STAGE 3: Out of 8000, 6494 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1604 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02222740463912487.
# STAGE 3: Out of 8000, 6364 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1574 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020782914012670517.
# STAGE 3: Out of 8000, 6426 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1592 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02252153307199478.
# STAGE 3: Out of 8000, 6546 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1610 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024462278932332993.
# STAGE 3: Out of 8000, 6388 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1580 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020363738760352135.
# STAGE 3: Out of 8000, 6692 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1641 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024908294901251793.
# STAGE 3: Out of 8000, 6600 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1641 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0251056719571352.
# STAGE 3: Out of 8000, 6445 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1594 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02401728369295597.
# STAGE 3: Out of 8000, 6501 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1622 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024824872612953186.
# STAGE 3: Out of 8000, 6188 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1538 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024574603885412216.
# STAGE 3: Out of 8000, 6285 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1563 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0222457442432642.
# STAGE 3: Out of 8000, 6653 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1650 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025021443143486977.
# STAGE 3: Out of 8000, 6486 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1607 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.021850664168596268.
# STAGE 3: Out of 8000, 6403 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1593 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02084343694150448.
# STAGE 3: Out of 8000, 6461 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1619 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02587774395942688.
# STAGE 3: Out of 8000, 6453 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1584 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024560289457440376.
# STAGE 3: Out of 8000, 6124 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1522 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.022685950621962547.
# STAGE 3: Out of 8000, 6548 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1632 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.026149379089474678.
# STAGE 3: Out of 8000, 6345 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1577 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02294347435235977.
# STAGE 3: Out of 8000, 6417 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1594 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0216583963483572.
# STAGE 3: Out of 8000, 6423 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1592 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025577398017048836.
# STAGE 3: Out of 8000, 6207 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1535 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020591096952557564.
# STAGE 3: Out of 8000, 6472 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1601 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020938465371727943.
# STAGE 3: Out of 8000, 6032 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1500 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023342883214354515.
# STAGE 3: Out of 8000, 6541 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1616 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02496936172246933.
# STAGE 3: Out of 8000, 6370 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1582 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02116158790886402.
# STAGE 3: Out of 8000, 6342 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1564 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024650156497955322.
# STAGE 3: Out of 8000, 6431 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1595 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02329992689192295.
# STAGE 3: Out of 8000, 6556 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1623 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02381301298737526.
# STAGE 3: Out of 8000, 6353 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1570 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.029214616864919662.
# STAGE 3: Out of 8000, 6493 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1613 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02480548992753029.
# STAGE 3: Out of 8000, 6622 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1659 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.022031929343938828.
# STAGE 3: Out of 8000, 6230 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1553 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.022094791755080223.
# STAGE 3: Out of 8000, 6297 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1572 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.027684953063726425.
# STAGE 3: Out of 8000, 6289 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1568 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025044746696949005.
# STAGE 3: Out of 8000, 6505 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1618 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023203261196613312.
# STAGE 3: Out of 8000, 5952 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1482 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025488046929240227.
# STAGE 3: Out of 8000, 6480 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1613 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024150053039193153.
# STAGE 3: Out of 8000, 6356 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1586 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023738978430628777.
# STAGE 3: Out of 8000, 6403 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1595 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02361302636563778.
# STAGE 3: Out of 8000, 6478 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1609 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024073734879493713.
# STAGE 3: Out of 8000, 6437 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1597 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.021663382649421692.
# STAGE 3: Out of 8000, 6489 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1601 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024024181067943573.
# STAGE 3: Out of 8000, 6633 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1620 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.027024663984775543.
# STAGE 3: Out of 8000, 6351 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1586 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02549748495221138.
# STAGE 3: Out of 8000, 6461 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1591 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02324635349214077.
# STAGE 3: Out of 8000, 6468 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1602 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023372406139969826.
# STAGE 3: Out of 8000, 6518 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1602 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02490682154893875.
# STAGE 3: Out of 8000, 6489 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1613 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.027027204632759094.
# STAGE 3: Out of 8000, 6393 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1578 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02397790364921093.
# STAGE 3: Out of 8000, 6495 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1610 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024570878595113754.
# STAGE 3: Out of 8000, 6364 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1568 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.024318421259522438.
# STAGE 3: Out of 8000, 6438 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1591 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023532552644610405.
# STAGE 3: Out of 8000, 6546 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1614 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023835038766264915.
# STAGE 3: Out of 8000, 6681 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1641 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.021915733814239502.
# STAGE 3: Out of 8000, 6648 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1653 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.022656206041574478.
# STAGE 3: Out of 8000, 6636 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1643 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02349000982940197.
# STAGE 3: Out of 8000, 5477 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1357 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02529357746243477.
# STAGE 3: Out of 8000, 6210 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1546 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025860510766506195.
# STAGE 3: Out of 8000, 6313 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1580 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.023852182552218437.
# STAGE 3: Out of 8000, 5424 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1343 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025795936584472656.
# STAGE 3: Out of 8000, 6478 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1603 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020203061401844025.
# STAGE 3: Out of 8000, 6462 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1603 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020998578518629074.
# STAGE 3: Out of 8000, 6399 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1601 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.025106176733970642.
# Stage 3 completed in 2500.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\trainable_model_stage_3-2024_12_04_18_57_38.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\Stage_3_results_2024_12_04_18_57_38.txt
