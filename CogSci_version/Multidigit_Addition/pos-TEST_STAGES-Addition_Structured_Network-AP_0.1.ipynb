# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_small_problem_size_binary.txt", 'r') as file:
    combinations_small_problem_size_binary = eval(file.read())

with open(f"{folder}/combinations_with_carry_over_decimal.txt", 'r') as file:
    combinations_with_carry_over_decimal = eval(file.read())

with open(f"{folder}/real_test_dataset_small_problem_size.txt", 'r') as file:
    real_test_dataset_small_problem_size = eval(file.read())

with open(f"{folder}/real_test_dataset_small_problem_size_binary.txt", 'r') as file:
    real_test_dataset_small_problem_size_binary = eval(file.read())

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_dataset_with_carry_over = eval(file.read())

with open(f"{folder}/real_test_dataset_with_carry_over_decimal.txt", 'r') as file:
    real_test_dataset_with_carry_over_decimal = eval(file.read())
    

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_carry_over_decimal = [pair for pair in train_couples if pair in combinations_with_carry_over_decimal]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)
    #column_1, column_2 = zip(*test_dataset)
    
    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None

# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_count, correct_predictions_test_count, train_count, correct_predictions_train_count, test_carry_over_count, correct_carry_over_predictions_test_count, train_carry_over_count, correct_carry_over_predictions_train_count, small_train_count, correct_predictions_small_train_count, small_test_count, correct_predictions_small_test_count, small_train_carry_count, correct_predictions_small_train_carry_count, small_test_carry_count, correct_predictions_small_test_carry_count, test_carry_over_decimal_count, correct_carry_over_decimal_predictions_test_count, train_carry_over_decimal_count, correct_carry_over_decimal_predictions_train_count, small_train_carry_decimal_count, correct_predictions_small_train_carry_decimal_count, small_test_carry_decimal_count, correct_predictions_small_test_carry_decimal_count, small_binary_train_count, correct_predictions_small_binary_train_count, small_binary_test_count, correct_predictions_small_binary_test_count, small_binary_train_carry_count, correct_predictions_small_binary_train_carry_count, small_binary_test_carry_count, correct_predictions_small_binary_test_carry_count, small_binary_train_carry_decimal_count, correct_predictions_small_binary_train_carry_decimal_count, small_binary_test_carry_decimal_count, correct_predictions_small_binary_test_carry_decimal_count, reaction_time_carry, reaction_time_carry_decimal, reaction_time_train,reaction_time_test, reaction_time_train_carry, reaction_time_train_carry_decimal, reaction_time_small_train, reaction_time_small_test, reaction_time_small_train_carry, reaction_time_small_test_carry, reaction_time_small_train_carry_decimal, reaction_time_small_test_carry_decimal, reaction_time_small_binary_train, reaction_time_small_binary_test, reaction_time_small_binary_train_carry, reaction_time_small_binary_test_carry, reaction_time_small_binary_train_carry_decimal, reaction_time_small_binary_test_carry_decimal = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_count}, {correct_predictions_train_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_count}, {correct_predictions_test_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_count}, {correct_carry_over_predictions_train_count} trained with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_count}, {correct_carry_over_predictions_test_count} tested with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_count}, {correct_predictions_small_train_count} trained with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_test_count}, {correct_predictions_small_test_count} tested with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_count}, {correct_predictions_small_train_carry_count} trained with small problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_count}, {correct_predictions_small_test_carry_count} tested with small problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_train_count} trained with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_test_count} tested with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_decimal_count}, {correct_predictions_small_train_carry_decimal_count} trained with small problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_decimal_count}, {correct_predictions_small_test_carry_decimal_count} tested with small problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_count}, {correct_predictions_small_binary_train_count} trained with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_test_count}, {correct_predictions_small_binary_test_count} tested with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_count}, {correct_predictions_small_binary_train_carry_count} trained with small binary problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_count}, {correct_predictions_small_binary_test_carry_count} tested with small binary problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_decimal_count}, {correct_predictions_small_binary_train_carry_decimal_count} trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_decimal_count}, {correct_predictions_small_binary_test_carry_decimal_count} tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: {reaction_time_carry} reaction time with carry over.")
        print(f"STAGE {stage}: {reaction_time_carry_decimal} reaction time with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_train} reaction time for train.")
        print(f"STAGE {stage}: {reaction_time_test} reaction time for test.")
        print(f"STAGE {stage}: {reaction_time_train_carry} reaction time for train with carry over .")
        print(f"STAGE {stage}: {reaction_time_train_carry_decimal} reaction time for train with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_small_train} reaction time for train small.")
        print(f"STAGE {stage}: {reaction_time_small_test} reaction time for test small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry} reaction time for train with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry} reaction time for test with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry_decimal} reaction time for train with carry over decimal and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry_decimal} reaction time for test with carry over decimal and small.") 
        print(f"STAGE {stage}: {reaction_time_small_binary_train} reaction time for train small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test} reaction time for test small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry} reaction time for train with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry} reaction time for test with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry_decimal} reaction time for train with carry over decimal and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry_decimal} reaction time for test with carry over decimal and small binary.") 
            
    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

def real_test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_real_test_dataset()    
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_test_count = 0
    correct_predictions_train_count = 0
    correct_carry_over_predictions_count = 0
    correct_carry_over_predictions_test_count = 0
    correct_carry_over_predictions_train_count = 0
    correct_predictions_small_train_count = 0
    correct_predictions_small_test_count = 0
    correct_predictions_small_train_carry_count = 0
    correct_predictions_small_test_carry_count = 0
    correct_carry_over_decimal_predictions_count = 0
    correct_carry_over_decimal_predictions_test_count = 0
    correct_carry_over_decimal_predictions_train_count = 0
    correct_predictions_small_train_carry_decimal_count = 0
    correct_predictions_small_test_carry_decimal_count = 0
    correct_predictions_small_binary_train_count = 0
    correct_predictions_small_binary_test_count = 0
    correct_predictions_small_binary_train_carry_count = 0
    correct_predictions_small_binary_test_carry_count = 0
    correct_predictions_small_binary_train_carry_decimal_count = 0
    correct_predictions_small_binary_test_carry_decimal_count = 0
    
    set_size = inputs_1.shape[0]
    train_count = len(train_couples)
    test_count = set_size - train_count
    carry_over_count = len(combinations_with_carry_over) 
    carry_over_decimal_count = len(combinations_with_carry_over_decimal) 
    train_carry_over_count = len(train_with_carry_over)
    test_carry_over_count = carry_over_count - train_carry_over_count
    small_count = len(combinations_small_problem_size)
    small_binary_count = len(combinations_small_problem_size_binary)
    train_carry_over_decimal_count = len(train_with_carry_over_decimal)
    test_carry_over_decimal_count = carry_over_decimal_count - train_carry_over_decimal_count

    # Contadores adicionales
    small_train_count = 0
    small_test_count = 0
    small_train_carry_count = 0
    small_test_carry_count = 0
    small_train_carry_decimal_count = 0
    small_test_carry_decimal_count = 0
    small_binary_train_count = 0
    small_binary_test_count = 0
    small_binary_train_carry_count = 0
    small_binary_test_carry_count = 0
    small_binary_train_carry_decimal_count = 0
    small_binary_test_carry_decimal_count = 0
    
    reaction_time_carry = 0
    reaction_time_carry_decimal = 0
    reaction_time_train = 0
    reaction_time_test = 0
    reaction_time_train_carry = 0
    reaction_time_train_carry_decimal = 0
    reaction_time_small_train = 0
    reaction_time_small_test = 0
    reaction_time_small_train_carry = 0
    reaction_time_small_test_carry = 0
    reaction_time_small_train_carry_decimal = 0
    reaction_time_small_test_carry_decimal = 0
    reaction_time_small_binary_train = 0
    reaction_time_small_binary_test = 0
    reaction_time_small_binary_train_carry = 0
    reaction_time_small_binary_test_carry = 0
    reaction_time_small_binary_train_carry_decimal = 0
    reaction_time_small_binary_test_carry_decimal = 0

    for i in range(set_size):
        pair = (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1])

        start_time = time.perf_counter_ns()
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        elapsed_time = time.perf_counter_ns() - start_time

        #is_small = pair in combinations_small_problem_size
        #is_small_binary = pair in combinations_small_problem_size_binary
        #is_train = pair in train_couples
        #is_carry = pair in combinations_with_carry_over
        #is_carry_decimal = pair in combinations_with_carry_over_decimal

        is_small = pair in real_test_dataset_small_problem_size
        is_small_binary = pair in real_test_dataset_small_problem_size_binary
        is_train = pair in train_couples
        is_carry = pair in real_test_dataset_with_carry_over
        is_carry_decimal = pair in real_test_dataset_with_carry_over_decimal

        # Actualizar tiempos de reacción y contadores totales
        if is_small:
            if is_train:
                small_train_count += 1
                reaction_time_small_train += elapsed_time
                if is_carry:
                    small_train_carry_count += 1
                    reaction_time_small_train_carry += elapsed_time
                if is_carry_decimal:
                    small_train_carry_decimal_count += 1
                    reaction_time_small_train_carry_decimal += elapsed_time
            else:
                small_test_count += 1
                reaction_time_small_test += elapsed_time
                if is_carry:
                    small_test_carry_count += 1
                    reaction_time_small_test_carry += elapsed_time
                if is_carry_decimal:
                    small_test_carry_decimal_count += 1
                    reaction_time_small_test_carry_decimal += elapsed_time

        # Actualizar tiempos de reacción y contadores totales
        if is_small_binary:
            if is_train:
                small_binary_train_count += 1
                reaction_time_small_binary_train += elapsed_time
                if is_carry:
                    small_binary_train_carry_count += 1
                    reaction_time_small_binary_train_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_train_carry_decimal_count += 1
                    reaction_time_small_binary_train_carry_decimal += elapsed_time
            else:
                small_binary_test_count += 1
                reaction_time_small_binary_test += elapsed_time
                if is_carry:
                    small_binary_test_carry_count += 1
                    reaction_time_small_binary_test_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_test_carry_decimal_count += 1
                    reaction_time_small_binary_test_carry_decimal += elapsed_time

        if is_carry:
            reaction_time_carry += elapsed_time
        if is_carry_decimal:
            reaction_time_carry_decimal += elapsed_time
        if is_train:
            reaction_time_train += elapsed_time
        else:
            reaction_time_test += elapsed_time
        if is_train and is_carry:
            reaction_time_train_carry += elapsed_time
        if is_train and is_carry_decimal:
            reaction_time_train_carry_decimal += elapsed_time

        # Contar predicciones correctas
        if jnp.all(prediction == outputs[i]):
            if is_small:
                if is_train:
                    correct_predictions_small_train_count += 1
                    if is_carry:
                        correct_predictions_small_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_test_count += 1
                    if is_carry:
                        correct_predictions_small_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_test_carry_decimal_count += 1

            if is_small_binary:
                if is_train:
                    correct_predictions_small_binary_train_count += 1
                    if is_carry:
                        correct_predictions_small_binary_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_binary_test_count += 1
                    if is_carry:
                        correct_predictions_small_binary_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_test_carry_decimal_count += 1

            # Actualizar contadores previos
            if is_carry:
                correct_carry_over_predictions_count += 1 
            if is_carry_decimal:
                correct_carry_over_decimal_predictions_count += 1 
            if is_train:
                correct_predictions_train_count += 1 
            else:
                correct_predictions_test_count += 1
            if is_train and is_carry:
                correct_carry_over_predictions_train_count += 1   
            if is_train and is_carry_decimal:
                correct_carry_over_decimal_predictions_train_count += 1 
                
        elif visualize_errors == 1:
            print(f'{pair[0]} plus {pair[1]} has failed.')

    correct_carry_over_predictions_test_count = correct_carry_over_predictions_count - correct_carry_over_predictions_train_count
    correct_carry_over_decimal_predictions_test_count = correct_carry_over_decimal_predictions_count - correct_carry_over_decimal_predictions_train_count
    
    return (
        test_count,
        correct_predictions_test_count,
        train_count,
        correct_predictions_train_count,
        test_carry_over_count,
        correct_carry_over_predictions_test_count,
        train_carry_over_count,
        correct_carry_over_predictions_train_count,
        small_train_count,
        correct_predictions_small_train_count,
        small_test_count,
        correct_predictions_small_test_count,
        small_train_carry_count,
        correct_predictions_small_train_carry_count,
        small_test_carry_count,
        correct_predictions_small_test_carry_count,
        test_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_test_count,
        train_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_train_count,
        small_train_carry_decimal_count,
        correct_predictions_small_train_carry_decimal_count,
        small_test_carry_decimal_count,
        correct_predictions_small_test_carry_decimal_count,
        small_binary_train_count,
        correct_predictions_small_binary_train_count,
        small_binary_test_count,
        correct_predictions_small_binary_test_count,
        small_binary_train_carry_count,
        correct_predictions_small_binary_train_carry_count,
        small_binary_test_carry_count,
        correct_predictions_small_binary_test_carry_count,
        small_binary_train_carry_decimal_count,
        correct_predictions_small_binary_train_carry_decimal_count,
        small_binary_test_carry_decimal_count,
        correct_predictions_small_binary_test_carry_decimal_count,
        reaction_time_carry,
        reaction_time_carry_decimal,
        reaction_time_train,
        reaction_time_test,
        reaction_time_train_carry,
        reaction_time_train_carry_decimal,
        reaction_time_small_train,
        reaction_time_small_test,
        reaction_time_small_train_carry,
        reaction_time_small_test_carry,
        reaction_time_small_train_carry_decimal,
        reaction_time_small_test_carry_decimal,
        reaction_time_small_binary_train,
        reaction_time_small_binary_test,
        reaction_time_small_binary_train_carry,
        reaction_time_small_binary_test_carry,
        reaction_time_small_binary_train_carry_decimal,
        reaction_time_small_binary_test_carry_decimal
    )

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
validation_performance = 'no'
easy_examples = 'no'
type_training = 'Stages'
file_name = 'AP_0.1_0.1'

if easy_examples == 'yes':
    if validation_performance == 'yes':
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_3'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_3'
    
else:
    if validation_performance == 'yes':    
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_3'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_3'

os.makedirs(os.path.dirname(output_file), exist_ok=True)

tee = Tee(output_file, 'w') 
sys.stdout = tee

try:
    visualize_errors = 0
    model = 'trainable_model_stage'
    
    date_pattern = r'trainable_model_stage_3-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
    files = sorted(
        (f for f in os.listdir(folder_path) if f.endswith('.pkl') and not f.startswith('.')),  # Filtrar archivos .pkl y ocultos
        key=lambda x: re.search(date_pattern, x).group(0) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
    
        for stage in range(1, 4):
            if easy_examples == 'yes':
                if validation_performance == 'yes':    
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                    
            else:
                if validation_performance == 'yes':   
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'

            with open(file_path, 'rb') as file:
                globals()[f"{model}_{stage}"] = pickle.load(file)
    
            print(f'Loaded {model}_{stage}-{current_time}.pkl')

            real_test = 1
            decide_test(params=globals()[f"{model}_{stage}"], stage=stage, real_test=real_test, visualize_errors=visualize_errors)
                
finally:
    sys.stdout = tee.console
    tee.close()
    
print(f'Finished, file {file_name} created')
# Out:
# Loaded trainable_model_stage_1-2024_11_19_13_21_53.pkl
# STAGE 1: Out of 8000, 3878 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 4026 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 2777 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 3464 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 747 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 459 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 286 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 172 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2788 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 2005 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 320 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 165 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3315 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 2500 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2214 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 1938 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2225 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 1154 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 14275116500 reaction time with carry over.
# STAGE 1: 10001016800 reaction time with carry over decimal.
# STAGE 1: 8086967400 reaction time for train.
# STAGE 1: 8475774400 reaction time for test.
# STAGE 1: 6523864700 reaction time for train with carry over .
# STAGE 1: 5571562700 reaction time for train with carry over decimal.
# STAGE 1: 1704858300 reaction time for train small.
# STAGE 1: 954089300 reaction time for test small.
# STAGE 1: 965646300 reaction time for train with carry over and small.
# STAGE 1: 567184000 reaction time for test with carry over and small.
# STAGE 1: 729625500 reaction time for train with carry over decimal and small.
# STAGE 1: 412998400 reaction time for test with carry over decimal and small.
# STAGE 1: 7084991100 reaction time for train small binary.
# STAGE 1: 5356814200 reaction time for test small binary.
# STAGE 1: 5521888400 reaction time for train with carry over and small binary.
# STAGE 1: 4632291600 reaction time for test with carry over and small binary.
# STAGE 1: 4569586400 reaction time for train with carry over decimal and small binary.
# STAGE 1: 2582284800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_13_21_53.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 18178126100 reaction time with carry over.
# STAGE 2: 12760127500 reaction time with carry over decimal.
# STAGE 2: 10296619500 reaction time for train.
# STAGE 2: 10747042900 reaction time for test.
# STAGE 2: 8334389200 reaction time for train with carry over .
# STAGE 2: 7140609400 reaction time for train with carry over decimal.
# STAGE 2: 2128453800 reaction time for train small.
# STAGE 2: 1228380600 reaction time for test small.
# STAGE 2: 1218247000 reaction time for train with carry over and small.
# STAGE 2: 747687600 reaction time for test with carry over and small.
# STAGE 2: 920090700 reaction time for train with carry over decimal and small.
# STAGE 2: 525657300 reaction time for test with carry over decimal and small.
# STAGE 2: 8976879200 reaction time for train small binary.
# STAGE 2: 6797310200 reaction time for test small binary.
# STAGE 2: 7014648900 reaction time for train with carry over and small binary.
# STAGE 2: 5894004200 reaction time for test with carry over and small binary.
# STAGE 2: 5820869100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3286262500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_19_13_21_53.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 17735833800 reaction time with carry over.
# STAGE 3: 12464524800 reaction time with carry over decimal.
# STAGE 3: 9941854700 reaction time for train.
# STAGE 3: 10512521900 reaction time for test.
# STAGE 3: 8109694500 reaction time for train with carry over .
# STAGE 3: 6945980300 reaction time for train with carry over decimal.
# STAGE 3: 1991084700 reaction time for train small.
# STAGE 3: 1181155000 reaction time for test small.
# STAGE 3: 1179693000 reaction time for train with carry over and small.
# STAGE 3: 705819000 reaction time for test with carry over and small.
# STAGE 3: 887727800 reaction time for train with carry over decimal and small.
# STAGE 3: 514285600 reaction time for test with carry over decimal and small.
# STAGE 3: 8692404000 reaction time for train small binary.
# STAGE 3: 6637641900 reaction time for test small binary.
# STAGE 3: 6860243800 reaction time for train with carry over and small binary.
# STAGE 3: 5751259300 reaction time for test with carry over and small binary.
# STAGE 3: 5696529600 reaction time for train with carry over decimal and small binary.
# STAGE 3: 3220371900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_18_48_37.pkl
# STAGE 1: Out of 8000, 3782 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 3560 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 3145 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 3293 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 907 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 466 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 555 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 296 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2522 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1945 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 382 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 209 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3343 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 2286 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2706 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 2019 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2083 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 1124 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16172611400 reaction time with carry over.
# STAGE 1: 11260273200 reaction time with carry over decimal.
# STAGE 1: 9175440100 reaction time for train.
# STAGE 1: 9589307700 reaction time for test.
# STAGE 1: 7423482300 reaction time for train with carry over .
# STAGE 1: 6312300900 reaction time for train with carry over decimal.
# STAGE 1: 1958144600 reaction time for train small.
# STAGE 1: 1154581300 reaction time for test small.
# STAGE 1: 1132522000 reaction time for train with carry over and small.
# STAGE 1: 690432600 reaction time for test with carry over and small.
# STAGE 1: 838842600 reaction time for train with carry over decimal and small.
# STAGE 1: 481409200 reaction time for test with carry over decimal and small.
# STAGE 1: 7993416400 reaction time for train small binary.
# STAGE 1: 6062619700 reaction time for test small binary.
# STAGE 1: 6241458600 reaction time for train with carry over and small binary.
# STAGE 1: 5222441100 reaction time for test with carry over and small binary.
# STAGE 1: 5130277200 reaction time for train with carry over decimal and small binary.
# STAGE 1: 2862710300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_18_48_37.pkl
# STAGE 2: Out of 8000, 4028 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 2987 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 3624 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 2577 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 184 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 545 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 173 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 356 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3174 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1529 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 114 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 253 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3697 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 2530 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3293 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 2120 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2843 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1310 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 19428694900 reaction time with carry over.
# STAGE 2: 13670398400 reaction time with carry over decimal.
# STAGE 2: 11013233000 reaction time for train.
# STAGE 2: 11465418100 reaction time for test.
# STAGE 2: 8936891600 reaction time for train with carry over .
# STAGE 2: 7686280300 reaction time for train with carry over decimal.
# STAGE 2: 2210637500 reaction time for train small.
# STAGE 2: 1276049100 reaction time for test small.
# STAGE 2: 1306101600 reaction time for train with carry over and small.
# STAGE 2: 762433100 reaction time for test with carry over and small.
# STAGE 2: 990530800 reaction time for train with carry over decimal and small.
# STAGE 2: 555866900 reaction time for test with carry over decimal and small.
# STAGE 2: 9628631800 reaction time for train small binary.
# STAGE 2: 7300529700 reaction time for test small binary.
# STAGE 2: 7552290400 reaction time for train with carry over and small binary.
# STAGE 2: 6326914900 reaction time for test with carry over and small binary.
# STAGE 2: 6301679100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3522675700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_19_18_48_37.pkl
# STAGE 3: Out of 8000, 5162 trained were predicted correctly in the current model.
# STAGE 3: Out of 8384, 3583 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 4449 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 3083 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1614, 484 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 946, 601 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 963, 362 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 568, 353 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 3878 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 1815 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 724, 269 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 412, 259 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 4492 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5302, 2739 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 3779 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4591, 2239 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 3208 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 2559, 1368 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 19509762700 reaction time with carry over.
# STAGE 3: 13743532500 reaction time with carry over decimal.
# STAGE 3: 10855243900 reaction time for train.
# STAGE 3: 11619874900 reaction time for test.
# STAGE 3: 8850161400 reaction time for train with carry over .
# STAGE 3: 7627892000 reaction time for train with carry over decimal.
# STAGE 3: 2163798600 reaction time for train small.
# STAGE 3: 1293254700 reaction time for test small.
# STAGE 3: 1278153400 reaction time for train with carry over and small.
# STAGE 3: 776953100 reaction time for test with carry over and small.
# STAGE 3: 973846700 reaction time for train with carry over decimal and small.
# STAGE 3: 567457400 reaction time for test with carry over decimal and small.
# STAGE 3: 9474720500 reaction time for train small binary.
# STAGE 3: 7300205100 reaction time for test small binary.
# STAGE 3: 7469638000 reaction time for train with carry over and small binary.
# STAGE 3: 6339931500 reaction time for test with carry over and small binary.
# STAGE 3: 6247368600 reaction time for train with carry over decimal and small binary.
# STAGE 3: 3562918400 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_02_27_59.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8357 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7646 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 942 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 564 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4368 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5291 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4580 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2555 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17032738700 reaction time with carry over.
# STAGE 1: 11943116300 reaction time with carry over decimal.
# STAGE 1: 9662619000 reaction time for train.
# STAGE 1: 10018508600 reaction time for test.
# STAGE 1: 7872264900 reaction time for train with carry over .
# STAGE 1: 6700114000 reaction time for train with carry over decimal.
# STAGE 1: 2010341600 reaction time for train small.
# STAGE 1: 1118724800 reaction time for test small.
# STAGE 1: 1198097800 reaction time for train with carry over and small.
# STAGE 1: 658218600 reaction time for test with carry over and small.
# STAGE 1: 898857500 reaction time for train with carry over decimal and small.
# STAGE 1: 482092200 reaction time for test with carry over decimal and small.
# STAGE 1: 8490362100 reaction time for train small binary.
# STAGE 1: 6337546300 reaction time for test small binary.
# STAGE 1: 6700008000 reaction time for train with carry over and small binary.
# STAGE 1: 5479511500 reaction time for test with carry over and small binary.
# STAGE 1: 5527857100 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3074867900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_02_27_59.pkl
# STAGE 2: Out of 8000, 74 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 54 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 20 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 32 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 53 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 17 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 10 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 6 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 74 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 54 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 53 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 17 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20887346200 reaction time with carry over.
# STAGE 2: 14555581000 reaction time with carry over decimal.
# STAGE 2: 11640635200 reaction time for train.
# STAGE 2: 12408109200 reaction time for test.
# STAGE 2: 9508852100 reaction time for train with carry over .
# STAGE 2: 8115327900 reaction time for train with carry over decimal.
# STAGE 2: 2352248900 reaction time for train small.
# STAGE 2: 1372268300 reaction time for test small.
# STAGE 2: 1401191600 reaction time for train with carry over and small.
# STAGE 2: 826019400 reaction time for test with carry over and small.
# STAGE 2: 1047602500 reaction time for train with carry over decimal and small.
# STAGE 2: 588767500 reaction time for test with carry over decimal and small.
# STAGE 2: 10120649100 reaction time for train small binary.
# STAGE 2: 7804801900 reaction time for test small binary.
# STAGE 2: 7988866000 reaction time for train with carry over and small binary.
# STAGE 2: 6775186800 reaction time for test with carry over and small binary.
# STAGE 2: 6595341800 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3706227700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_02_27_59.pkl
# STAGE 3: Out of 8000, 8 trained were predicted correctly in the current model.
# STAGE 3: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1614, 7 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 3 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 724, 2 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 8 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 3 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 20471744400 reaction time with carry over.
# STAGE 3: 14360619800 reaction time with carry over decimal.
# STAGE 3: 11510388300 reaction time for train.
# STAGE 3: 12100851200 reaction time for test.
# STAGE 3: 9382259300 reaction time for train with carry over .
# STAGE 3: 8036302600 reaction time for train with carry over decimal.
# STAGE 3: 2304852000 reaction time for train small.
# STAGE 3: 1324555000 reaction time for test small.
# STAGE 3: 1359058100 reaction time for train with carry over and small.
# STAGE 3: 784911300 reaction time for test with carry over and small.
# STAGE 3: 1019316900 reaction time for train with carry over decimal and small.
# STAGE 3: 569820800 reaction time for test with carry over decimal and small.
# STAGE 3: 10031709800 reaction time for train small binary.
# STAGE 3: 7600380500 reaction time for test small binary.
# STAGE 3: 7903580800 reaction time for train with carry over and small binary.
# STAGE 3: 6589014400 reaction time for test with carry over and small binary.
# STAGE 3: 6557624100 reaction time for train with carry over decimal and small binary.
# STAGE 3: 3655672800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_06_49_46.pkl
# STAGE 1: Out of 8000, 3833 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 3460 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 3166 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 3231 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1029 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 411 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 611 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 268 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2513 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1804 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 450 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 170 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3315 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 2184 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2648 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 1955 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 1995 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 963 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16808532400 reaction time with carry over.
# STAGE 1: 11749443200 reaction time with carry over decimal.
# STAGE 1: 9415650800 reaction time for train.
# STAGE 1: 10016465700 reaction time for test.
# STAGE 1: 7650830300 reaction time for train with carry over .
# STAGE 1: 6550946600 reaction time for train with carry over decimal.
# STAGE 1: 1916129800 reaction time for train small.
# STAGE 1: 1140186900 reaction time for test small.
# STAGE 1: 1135481100 reaction time for train with carry over and small.
# STAGE 1: 682688000 reaction time for test with carry over and small.
# STAGE 1: 862141500 reaction time for train with carry over decimal and small.
# STAGE 1: 502420700 reaction time for test with carry over decimal and small.
# STAGE 1: 8253482500 reaction time for train small binary.
# STAGE 1: 6387499000 reaction time for test small binary.
# STAGE 1: 6488662000 reaction time for train with carry over and small binary.
# STAGE 1: 5528735400 reaction time for test with carry over and small binary.
# STAGE 1: 5388778300 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3072000000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_06_49_46.pkl
# STAGE 2: Out of 8000, 443 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 313 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 87 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 139 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 330 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 141 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 44 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 46 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 443 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 313 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 330 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 141 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 21059521600 reaction time with carry over.
# STAGE 2: 14761308500 reaction time with carry over decimal.
# STAGE 2: 11920718600 reaction time for train.
# STAGE 2: 12367388300 reaction time for test.
# STAGE 2: 9737431500 reaction time for train with carry over .
# STAGE 2: 8281347900 reaction time for train with carry over decimal.
# STAGE 2: 2356183100 reaction time for train small.
# STAGE 2: 1376814700 reaction time for test small.
# STAGE 2: 1396773000 reaction time for train with carry over and small.
# STAGE 2: 833064700 reaction time for test with carry over and small.
# STAGE 2: 1041610200 reaction time for train with carry over decimal and small.
# STAGE 2: 606835700 reaction time for test with carry over decimal and small.
# STAGE 2: 10431962900 reaction time for train small binary.
# STAGE 2: 7887762000 reaction time for test small binary.
# STAGE 2: 8248675800 reaction time for train with carry over and small binary.
# STAGE 2: 6842463800 reaction time for test with carry over and small binary.
# STAGE 2: 6792592200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3816603500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_06_49_46.pkl
# STAGE 3: Out of 8000, 143 trained were predicted correctly in the current model.
# STAGE 3: Out of 8384, 31 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1614, 86 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 946, 13 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 43 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 11 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 724, 28 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 412, 7 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 143 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5302, 31 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 43 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 2559, 11 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 20655089100 reaction time with carry over.
# STAGE 3: 14458709800 reaction time with carry over decimal.
# STAGE 3: 11526647500 reaction time for train.
# STAGE 3: 12309611800 reaction time for test.
# STAGE 3: 9379242400 reaction time for train with carry over .
# STAGE 3: 8037963400 reaction time for train with carry over decimal.
# STAGE 3: 2328844100 reaction time for train small.
# STAGE 3: 1395296100 reaction time for test small.
# STAGE 3: 1371304500 reaction time for train with carry over and small.
# STAGE 3: 836600900 reaction time for test with carry over and small.
# STAGE 3: 1040125900 reaction time for train with carry over decimal and small.
# STAGE 3: 615047300 reaction time for test with carry over decimal and small.
# STAGE 3: 10085794700 reaction time for train small binary.
# STAGE 3: 7757308200 reaction time for test small binary.
# STAGE 3: 7938389600 reaction time for train with carry over and small binary.
# STAGE 3: 6723543100 reaction time for test with carry over and small binary.
# STAGE 3: 6597110600 reaction time for train with carry over decimal and small binary.
# STAGE 3: 3748882800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_02_35.pkl
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 6306 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 4506 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 5595 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1211 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 709 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 560 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 331 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 3999 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 3045 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 479 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 277 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 5225 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 3991 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 3749 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 3280 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 3242 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 1759 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16965636700 reaction time with carry over.
# STAGE 1: 11989211400 reaction time with carry over decimal.
# STAGE 1: 9679958100 reaction time for train.
# STAGE 1: 9938574500 reaction time for test.
# STAGE 1: 7879739400 reaction time for train with carry over .
# STAGE 1: 6766581400 reaction time for train with carry over decimal.
# STAGE 1: 1962975500 reaction time for train small.
# STAGE 1: 1123396300 reaction time for test small.
# STAGE 1: 1156976200 reaction time for train with carry over and small.
# STAGE 1: 668124500 reaction time for test with carry over and small.
# STAGE 1: 877527600 reaction time for train with carry over decimal and small.
# STAGE 1: 479014500 reaction time for test with carry over decimal and small.
# STAGE 1: 8471325500 reaction time for train small binary.
# STAGE 1: 6259606500 reaction time for test small binary.
# STAGE 1: 6671106800 reaction time for train with carry over and small binary.
# STAGE 1: 5406929300 reaction time for test with carry over and small binary.
# STAGE 1: 5557948800 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3041467100 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_02_35.pkl
# STAGE 2: Out of 8000, 1091 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 1254 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 866 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1056 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 68 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 111 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 27 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 33 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 843 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 605 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 40 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 48 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 863 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 819 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 638 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 621 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 615 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 372 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 21937114300 reaction time with carry over.
# STAGE 2: 15440858000 reaction time with carry over decimal.
# STAGE 2: 12440223600 reaction time for train.
# STAGE 2: 12881631700 reaction time for test.
# STAGE 2: 10148874500 reaction time for train with carry over .
# STAGE 2: 8695922700 reaction time for train with carry over decimal.
# STAGE 2: 2492146500 reaction time for train small.
# STAGE 2: 1469152500 reaction time for test small.
# STAGE 2: 1476116600 reaction time for train with carry over and small.
# STAGE 2: 883404700 reaction time for test with carry over and small.
# STAGE 2: 1103981600 reaction time for train with carry over decimal and small.
# STAGE 2: 637138600 reaction time for test with carry over decimal and small.
# STAGE 2: 10802674700 reaction time for train small binary.
# STAGE 2: 8050307700 reaction time for test small binary.
# STAGE 2: 8511325600 reaction time for train with carry over and small binary.
# STAGE 2: 6956915800 reaction time for test with carry over and small binary.
# STAGE 2: 7058373800 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3867130800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_11_02_35.pkl
# STAGE 3: Out of 8000, 1372 trained were predicted correctly in the current model.
# STAGE 3: Out of 8384, 939 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 993 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 759 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1614, 210 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 946, 115 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 963, 91 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 568, 38 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 961 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 507 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 724, 105 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 412, 45 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 1197 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5302, 713 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 818 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4591, 533 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 786 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 2559, 344 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 20702559500 reaction time with carry over.
# STAGE 3: 14468122700 reaction time with carry over decimal.
# STAGE 3: 11761199800 reaction time for train.
# ...
# STAGE 2: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 4381 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 18763496600 reaction time with carry over.
# STAGE 2: 13078139700 reaction time with carry over decimal.
# STAGE 2: 10453023200 reaction time for train.
# STAGE 2: 11179755000 reaction time for test.
# STAGE 2: 8520098300 reaction time for train with carry over .
# STAGE 2: 7254598200 reaction time for train with carry over decimal.
# STAGE 2: 2127056800 reaction time for train small.
# STAGE 2: 1256800500 reaction time for test small.
# STAGE 2: 1267331700 reaction time for train with carry over and small.
# STAGE 2: 749279100 reaction time for test with carry over and small.
# STAGE 2: 944859400 reaction time for train with carry over decimal and small.
# STAGE 2: 540732200 reaction time for test with carry over decimal and small.
# STAGE 2: 9151688500 reaction time for train small binary.
# STAGE 2: 7075846400 reaction time for test small binary.
# STAGE 2: 7218763600 reaction time for train with carry over and small binary.
# STAGE 2: 6139489700 reaction time for test with carry over and small binary.
# STAGE 2: 5953263500 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3372293400 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_11_28_48.pkl
# STAGE 3: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 3: Out of 8384, 8382 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 7671 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 4383 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 17816941700 reaction time with carry over.
# STAGE 3: 12504181600 reaction time with carry over decimal.
# STAGE 3: 10040799300 reaction time for train.
# STAGE 3: 10571711500 reaction time for test.
# STAGE 3: 8161201600 reaction time for train with carry over .
# STAGE 3: 6975034700 reaction time for train with carry over decimal.
# STAGE 3: 2060090500 reaction time for train small.
# STAGE 3: 1228286000 reaction time for test small.
# STAGE 3: 1218078300 reaction time for train with carry over and small.
# STAGE 3: 739121600 reaction time for test with carry over and small.
# STAGE 3: 926953900 reaction time for train with carry over decimal and small.
# STAGE 3: 542384700 reaction time for test with carry over decimal and small.
# STAGE 3: 8803601600 reaction time for train small binary.
# STAGE 3: 6717409800 reaction time for test small binary.
# STAGE 3: 6924003900 reaction time for train with carry over and small binary.
# STAGE 3: 5801438400 reaction time for test with carry over and small binary.
# STAGE 3: 5737837000 reaction time for train with carry over decimal and small binary.
# STAGE 3: 3242448600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_28_50.pkl
# STAGE 1: Out of 8000, 2267 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 1595 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 1696 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1353 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 689 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 258 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 302 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 104 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 1490 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 774 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 275 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 98 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 1787 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 1027 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 1216 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 785 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 1010 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 479 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 14827650700 reaction time with carry over.
# STAGE 1: 10424325200 reaction time with carry over decimal.
# STAGE 1: 8359258600 reaction time for train.
# STAGE 1: 8768683600 reaction time for test.
# STAGE 1: 6800759100 reaction time for train with carry over .
# STAGE 1: 5836284000 reaction time for train with carry over decimal.
# STAGE 1: 1687524100 reaction time for train small.
# STAGE 1: 976767900 reaction time for test small.
# STAGE 1: 996764000 reaction time for train with carry over and small.
# STAGE 1: 582551500 reaction time for test with carry over and small.
# STAGE 1: 744837800 reaction time for train with carry over decimal and small.
# STAGE 1: 428919000 reaction time for test with carry over decimal and small.
# STAGE 1: 7293979700 reaction time for train small binary.
# STAGE 1: 5538079200 reaction time for test small binary.
# STAGE 1: 5735480200 reaction time for train with carry over and small binary.
# STAGE 1: 4796287200 reaction time for test with carry over and small binary.
# STAGE 1: 4771005100 reaction time for train with carry over decimal and small binary.
# STAGE 1: 2674948600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_28_50.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 18661505800 reaction time with carry over.
# STAGE 2: 13098757100 reaction time with carry over decimal.
# STAGE 2: 10500325500 reaction time for train.
# STAGE 2: 11044543800 reaction time for test.
# STAGE 2: 8558909600 reaction time for train with carry over .
# STAGE 2: 7313506300 reaction time for train with carry over decimal.
# STAGE 2: 2091024900 reaction time for train small.
# STAGE 2: 1249142500 reaction time for test small.
# STAGE 2: 1243589400 reaction time for train with carry over and small.
# STAGE 2: 746063400 reaction time for test with carry over and small.
# STAGE 2: 934502600 reaction time for train with carry over decimal and small.
# STAGE 2: 539916100 reaction time for test with carry over decimal and small.
# STAGE 2: 9182261400 reaction time for train small binary.
# STAGE 2: 6964396900 reaction time for test small binary.
# STAGE 2: 7240845500 reaction time for train with carry over and small binary.
# STAGE 2: 6022449300 reaction time for test with carry over and small binary.
# STAGE 2: 5995442200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3348387700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_11_28_50.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 18207719100 reaction time with carry over.
# STAGE 3: 12731265800 reaction time with carry over decimal.
# STAGE 3: 10295233800 reaction time for train.
# STAGE 3: 10788834100 reaction time for test.
# STAGE 3: 8366639600 reaction time for train with carry over .
# STAGE 3: 7118494800 reaction time for train with carry over decimal.
# STAGE 3: 2145861700 reaction time for train small.
# STAGE 3: 1286887100 reaction time for test small.
# STAGE 3: 1264816500 reaction time for train with carry over and small.
# STAGE 3: 759578200 reaction time for test with carry over and small.
# STAGE 3: 929468500 reaction time for train with carry over decimal and small.
# STAGE 3: 556180800 reaction time for test with carry over decimal and small.
# STAGE 3: 9013531000 reaction time for train small binary.
# STAGE 3: 6894208600 reaction time for test small binary.
# STAGE 3: 7084936800 reaction time for train with carry over and small binary.
# STAGE 3: 5946454000 reaction time for test with carry over and small binary.
# STAGE 3: 5836792000 reaction time for train with carry over decimal and small binary.
# STAGE 3: 3309044800 reaction time for test with carry over decimal and small binary.
# Finished, file AP_0.1_0.1 created
