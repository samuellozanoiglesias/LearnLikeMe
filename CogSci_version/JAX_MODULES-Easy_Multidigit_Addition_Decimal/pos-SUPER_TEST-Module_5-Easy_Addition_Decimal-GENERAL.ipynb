# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Easy_Multidigit_Addition_Decimal/'
folder_specific = f'{folder}v1-Exponential_Decay/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model(f'{folder}Modules/unit_addition_module.keras')
unit_carry_model = load_model(f'{folder}Modules/unit_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        y_data.append([sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def construct_matrices(x):
    carry_unit_val = {}
    unit_val = {}

    for i in [0,1]:
       for j in [2,3]:
            units_inputs = jnp.array(x[:, [i, j]])
            units_input = units_inputs[:, None, :]
           
            unit_output = jnp.array(unit_addition_model(units_input))
            unit_carry_output = jnp.array(unit_carry_model(units_input))
           
            unit_val[f'{i}_{j}'] = jnp.argmax(unit_output, axis=-1)
            carry_unit_val[f'{i}_{j}'] = jnp.argmax(unit_carry_output, axis=-1)

    return carry_unit_val, unit_val


def model(params, x):
    carry_unit_val, unit_val = construct_matrices(x)
    
    salida_1 = sum(params[f'v_0_1_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_1_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i in [0,1] for j in [2,3]
        )

    # Salida 2
    salida_2 = sum(params[f'v_0_2_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_2_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i in [0,1] for j in [2,3]
        )

    return salida_1, salida_2

# %%
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
epsilons = [2.5,
            7.5,
            10
           ]

# %%
x_test, y_test = generate_test_dataset()
param_type = 'AP'

for epsilon in epsilons:
    print(f'Iniciado {epsilon}.')
    
    save_dir = f"{folder_specific}Super_Tests/"
    folder_path = f'{folder_specific}Super_Trained_models/{param_type}_{epsilon}'
    date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
    files = sorted(
        (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
        key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
    )
    
    os.makedirs(save_dir, exist_ok=True) 
    results_file = os.path.join(save_dir, f"Super_Tests_{param_type}_{epsilon}.txt") 
    tee = Tee(results_file, 'w') 
    sys.stdout = tee
    
    try:
        for filename in files:
            match = re.search(date_pattern, filename)
            if match:
                current_time = match.group(1)
            else:
                print('Error')
                break
            
            file_path = f"{folder_path}/super_trained_model_{current_time}.json"
            with open(file_path, 'rb') as file:
                trained_model = json.load(file)
        
            trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
            print(f'Loaded super_trained_model_{current_time}.json')
    
            predictions(trained_model_jnp, x_test, y_test)
        
    finally:
        sys.stdout = tee.console
        tee.close()
    
    print(f'Finalizado {epsilon}.')
# Out:
# Iniciado 2.5.
# Loaded super_trained_model_2025_01_20_12_12_21.json
# Out of 5050, 1719 predictions correct.
# Out of 4858, 1625 train predictions correct.
# Out of 2025, 656 carry-over predictions correct.
# Out of 1929, 605 carry-over train predictions correct.
# Out of 820, 431 small predictions correct.
# Out of 724, 367 small train predictions correct.
# Out of 270, 145 carry-over small predictions correct.
# Out of 222, 113 carry-over small train predictions correct.
# Out of 3159, 844 large predictions correct.
# Out of 3063, 814 large train predictions correct.
# Out of 1296, 336 carry-over large predictions correct.
# Out of 1248, 317 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_23.json
# Out of 5050, 1377 predictions correct.
# Out of 4858, 1309 train predictions correct.
# Out of 2025, 460 carry-over predictions correct.
# Out of 1929, 433 carry-over train predictions correct.
# Out of 820, 316 small predictions correct.
# Out of 724, 272 small train predictions correct.
# Out of 270, 89 carry-over small predictions correct.
# Out of 222, 72 carry-over small train predictions correct.
# Out of 3159, 718 large predictions correct.
# Out of 3063, 694 large train predictions correct.
# Out of 1296, 245 carry-over large predictions correct.
# Out of 1248, 235 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_25.json
# Out of 5050, 1167 predictions correct.
# Out of 4858, 1101 train predictions correct.
# Out of 2025, 385 carry-over predictions correct.
# Out of 1929, 357 carry-over train predictions correct.
# Out of 820, 340 small predictions correct.
# Out of 724, 289 small train predictions correct.
# Out of 270, 104 carry-over small predictions correct.
# Out of 222, 82 carry-over small train predictions correct.
# Out of 3159, 487 large predictions correct.
# Out of 3063, 472 large train predictions correct.
# Out of 1296, 157 carry-over large predictions correct.
# Out of 1248, 151 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_27.json
# Out of 5050, 970 predictions correct.
# Out of 4858, 915 train predictions correct.
# Out of 2025, 269 carry-over predictions correct.
# Out of 1929, 247 carry-over train predictions correct.
# Out of 820, 238 small predictions correct.
# Out of 724, 197 small train predictions correct.
# Out of 270, 76 carry-over small predictions correct.
# Out of 222, 57 carry-over small train predictions correct.
# Out of 3159, 494 large predictions correct.
# Out of 3063, 480 large train predictions correct.
# Out of 1296, 110 carry-over large predictions correct.
# Out of 1248, 107 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_29.json
# Out of 5050, 1519 predictions correct.
# Out of 4858, 1436 train predictions correct.
# Out of 2025, 568 carry-over predictions correct.
# Out of 1929, 530 carry-over train predictions correct.
# Out of 820, 433 small predictions correct.
# Out of 724, 369 small train predictions correct.
# Out of 270, 135 carry-over small predictions correct.
# Out of 222, 107 carry-over small train predictions correct.
# Out of 3159, 618 large predictions correct.
# Out of 3063, 599 large train predictions correct.
# Out of 1296, 239 carry-over large predictions correct.
# Out of 1248, 229 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_31.json
# Out of 5050, 1394 predictions correct.
# Out of 4858, 1333 train predictions correct.
# Out of 2025, 400 carry-over predictions correct.
# Out of 1929, 387 carry-over train predictions correct.
# Out of 820, 408 small predictions correct.
# Out of 724, 361 small train predictions correct.
# Out of 270, 68 carry-over small predictions correct.
# Out of 222, 60 carry-over small train predictions correct.
# Out of 3159, 490 large predictions correct.
# Out of 3063, 476 large train predictions correct.
# Out of 1296, 162 carry-over large predictions correct.
# Out of 1248, 157 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_33.json
# Out of 5050, 1342 predictions correct.
# Out of 4858, 1267 train predictions correct.
# Out of 2025, 484 carry-over predictions correct.
# Out of 1929, 449 carry-over train predictions correct.
# Out of 820, 329 small predictions correct.
# Out of 724, 276 small train predictions correct.
# Out of 270, 108 carry-over small predictions correct.
# Out of 222, 84 carry-over small train predictions correct.
# Out of 3159, 661 large predictions correct.
# Out of 3063, 639 large train predictions correct.
# Out of 1296, 238 carry-over large predictions correct.
# Out of 1248, 227 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_35.json
# Out of 5050, 736 predictions correct.
# Out of 4858, 699 train predictions correct.
# Out of 2025, 240 carry-over predictions correct.
# Out of 1929, 228 carry-over train predictions correct.
# Out of 820, 224 small predictions correct.
# Out of 724, 192 small train predictions correct.
# Out of 270, 49 carry-over small predictions correct.
# Out of 222, 39 carry-over small train predictions correct.
# Out of 3159, 264 large predictions correct.
# Out of 3063, 259 large train predictions correct.
# Out of 1296, 90 carry-over large predictions correct.
# Out of 1248, 88 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_37.json
# Out of 5050, 996 predictions correct.
# Out of 4858, 941 train predictions correct.
# Out of 2025, 306 carry-over predictions correct.
# Out of 1929, 283 carry-over train predictions correct.
# Out of 820, 231 small predictions correct.
# Out of 724, 194 small train predictions correct.
# Out of 270, 68 carry-over small predictions correct.
# Out of 222, 53 carry-over small train predictions correct.
# Out of 3159, 521 large predictions correct.
# Out of 3063, 503 large train predictions correct.
# Out of 1296, 157 carry-over large predictions correct.
# Out of 1248, 149 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_39.json
# Out of 5050, 1273 predictions correct.
# Out of 4858, 1205 train predictions correct.
# Out of 2025, 455 carry-over predictions correct.
# Out of 1929, 421 carry-over train predictions correct.
# Out of 820, 286 small predictions correct.
# Out of 724, 243 small train predictions correct.
# Out of 270, 98 carry-over small predictions correct.
# Out of 222, 77 carry-over small train predictions correct.
# Out of 3159, 684 large predictions correct.
# Out of 3063, 659 large train predictions correct.
# Out of 1296, 239 carry-over large predictions correct.
# Out of 1248, 226 carry-over large train predictions correct.
# Finalizado 2.5.
# Iniciado 7.5.
# Loaded super_trained_model_2025_01_20_12_12_41.json
# Out of 5050, 483 predictions correct.
# Out of 4858, 452 train predictions correct.
# Out of 2025, 230 carry-over predictions correct.
# Out of 1929, 220 carry-over train predictions correct.
# Out of 820, 226 small predictions correct.
# Out of 724, 201 small train predictions correct.
# Out of 270, 44 carry-over small predictions correct.
# Out of 222, 40 carry-over small train predictions correct.
# Out of 3159, 112 large predictions correct.
# Out of 3063, 106 large train predictions correct.
# Out of 1296, 112 carry-over large predictions correct.
# Out of 1248, 106 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_43.json
# Out of 5050, 456 predictions correct.
# Out of 4858, 436 train predictions correct.
# Out of 2025, 153 carry-over predictions correct.
# Out of 1929, 145 carry-over train predictions correct.
# Out of 820, 110 small predictions correct.
# Out of 724, 96 small train predictions correct.
# Out of 270, 35 carry-over small predictions correct.
# Out of 222, 30 carry-over small train predictions correct.
# Out of 3159, 230 large predictions correct.
# Out of 3063, 224 large train predictions correct.
# Out of 1296, 74 carry-over large predictions correct.
# Out of 1248, 71 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_45.json
# Out of 5050, 184 predictions correct.
# Out of 4858, 176 train predictions correct.
# Out of 2025, 29 carry-over predictions correct.
# Out of 1929, 29 carry-over train predictions correct.
# Out of 820, 51 small predictions correct.
# Out of 724, 43 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 61 large predictions correct.
# Out of 3063, 61 large train predictions correct.
# Out of 1296, 13 carry-over large predictions correct.
# Out of 1248, 13 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_47.json
# Out of 5050, 400 predictions correct.
# Out of 4858, 382 train predictions correct.
# Out of 2025, 91 carry-over predictions correct.
# Out of 1929, 89 carry-over train predictions correct.
# Out of 820, 93 small predictions correct.
# Out of 724, 81 small train predictions correct.
# Out of 270, 20 carry-over small predictions correct.
# Out of 222, 18 carry-over small train predictions correct.
# Out of 3159, 200 large predictions correct.
# Out of 3063, 194 large train predictions correct.
# Out of 1296, 34 carry-over large predictions correct.
# Out of 1248, 34 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_49.json
# Out of 5050, 265 predictions correct.
# Out of 4858, 245 train predictions correct.
# Out of 2025, 120 carry-over predictions correct.
# Out of 1929, 113 carry-over train predictions correct.
# Out of 820, 114 small predictions correct.
# Out of 724, 97 small train predictions correct.
# Out of 270, 18 carry-over small predictions correct.
# Out of 222, 13 carry-over small train predictions correct.
# Out of 3159, 62 large predictions correct.
# Out of 3063, 59 large train predictions correct.
# Out of 1296, 55 carry-over large predictions correct.
# Out of 1248, 53 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_51.json
# Out of 5050, 338 predictions correct.
# Out of 4858, 317 train predictions correct.
# Out of 2025, 95 carry-over predictions correct.
# Out of 1929, 93 carry-over train predictions correct.
# Out of 820, 137 small predictions correct.
# Out of 724, 119 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 100 large predictions correct.
# Out of 3063, 97 large train predictions correct.
# Out of 1296, 79 carry-over large predictions correct.
# Out of 1248, 77 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_53.json
# Out of 5050, 218 predictions correct.
# Out of 4858, 199 train predictions correct.
# Out of 2025, 73 carry-over predictions correct.
# Out of 1929, 71 carry-over train predictions correct.
# Out of 820, 124 small predictions correct.
# Out of 724, 107 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 62 large predictions correct.
# Out of 3063, 60 large train predictions correct.
# Out of 1296, 62 carry-over large predictions correct.
# Out of 1248, 60 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_55.json
# Out of 5050, 320 predictions correct.
# Out of 4858, 301 train predictions correct.
# Out of 2025, 109 carry-over predictions correct.
# Out of 1929, 102 carry-over train predictions correct.
# Out of 820, 94 small predictions correct.
# Out of 724, 79 small train predictions correct.
# Out of 270, 28 carry-over small predictions correct.
# Out of 222, 22 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 129 large train predictions correct.
# Out of 1296, 48 carry-over large predictions correct.
# Out of 1248, 47 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_57.json
# Out of 5050, 674 predictions correct.
# Out of 4858, 634 train predictions correct.
# Out of 2025, 238 carry-over predictions correct.
# Out of 1929, 222 carry-over train predictions correct.
# Out of 820, 213 small predictions correct.
# Out of 724, 182 small train predictions correct.
# Out of 270, 55 carry-over small predictions correct.
# Out of 222, 45 carry-over small train predictions correct.
# Out of 3159, 261 large predictions correct.
# Out of 3063, 252 large train predictions correct.
# Out of 1296, 101 carry-over large predictions correct.
# Out of 1248, 95 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_59.json
# Out of 5050, 402 predictions correct.
# Out of 4858, 382 train predictions correct.
# Out of 2025, 145 carry-over predictions correct.
# Out of 1929, 135 carry-over train predictions correct.
# Out of 820, 93 small predictions correct.
# Out of 724, 78 small train predictions correct.
# Out of 270, 29 carry-over small predictions correct.
# Out of 222, 20 carry-over small train predictions correct.
# Out of 3159, 210 large predictions correct.
# Out of 3063, 205 large train predictions correct.
# Out of 1296, 77 carry-over large predictions correct.
# Out of 1248, 76 carry-over large train predictions correct.
# Finalizado 7.5.
# Iniciado 10.
# Loaded super_trained_model_2025_01_20_12_13_01.json
# Out of 5050, 300 predictions correct.
# Out of 4858, 275 train predictions correct.
# Out of 2025, 145 carry-over predictions correct.
# Out of 1929, 137 carry-over train predictions correct.
# Out of 820, 134 small predictions correct.
# Out of 724, 111 small train predictions correct.
# Out of 270, 20 carry-over small predictions correct.
# Out of 222, 14 carry-over small train predictions correct.
# Out of 3159, 64 large predictions correct.
# Out of 3063, 62 large train predictions correct.
# Out of 1296, 64 carry-over large predictions correct.
# Out of 1248, 62 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_03.json
# Out of 5050, 122 predictions correct.
# Out of 4858, 113 train predictions correct.
# Out of 2025, 80 carry-over predictions correct.
# Out of 1929, 80 carry-over train predictions correct.
# Out of 820, 54 small predictions correct.
# Out of 724, 45 small train predictions correct.
# Out of 270, 12 carry-over small predictions correct.
# Out of 222, 12 carry-over small train predictions correct.
# Out of 3159, 25 large predictions correct.
# Out of 3063, 25 large train predictions correct.
# Out of 1296, 25 carry-over large predictions correct.
# Out of 1248, 25 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_05.json
# Out of 5050, 79 predictions correct.
# Out of 4858, 73 train predictions correct.
# Out of 2025, 24 carry-over predictions correct.
# Out of 1929, 22 carry-over train predictions correct.
# Out of 820, 39 small predictions correct.
# Out of 724, 35 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 24 large predictions correct.
# Out of 3063, 22 large train predictions correct.
# Out of 1296, 24 carry-over large predictions correct.
# Out of 1248, 22 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_07.json
# Out of 5050, 605 predictions correct.
# Out of 4858, 576 train predictions correct.
# Out of 2025, 172 carry-over predictions correct.
# Out of 1929, 161 carry-over train predictions correct.
# Out of 820, 142 small predictions correct.
# Out of 724, 122 small train predictions correct.
# Out of 270, 42 carry-over small predictions correct.
# Out of 222, 33 carry-over small train predictions correct.
# Out of 3159, 313 large predictions correct.
# Out of 3063, 304 large train predictions correct.
# Out of 1296, 77 carry-over large predictions correct.
# Out of 1248, 75 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_09.json
# Out of 5050, 46 predictions correct.
# Out of 4858, 41 train predictions correct.
# Out of 2025, 6 carry-over predictions correct.
# Out of 1929, 6 carry-over train predictions correct.
# Out of 820, 40 small predictions correct.
# Out of 724, 35 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_11.json
# Out of 5050, 168 predictions correct.
# Out of 4858, 159 train predictions correct.
# Out of 2025, 68 carry-over predictions correct.
# Out of 1929, 68 carry-over train predictions correct.
# Out of 820, 75 small predictions correct.
# Out of 724, 66 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 47 large predictions correct.
# Out of 3063, 47 large train predictions correct.
# Out of 1296, 47 carry-over large predictions correct.
# Out of 1248, 47 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_13.json
# Out of 5050, 70 predictions correct.
# Out of 4858, 64 train predictions correct.
# Out of 2025, 22 carry-over predictions correct.
# Out of 1929, 22 carry-over train predictions correct.
# Out of 820, 43 small predictions correct.
# Out of 724, 37 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 13 large predictions correct.
# Out of 3063, 13 large train predictions correct.
# Out of 1296, 13 carry-over large predictions correct.
# Out of 1248, 13 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_15.json
# Out of 5050, 414 predictions correct.
# Out of 4858, 383 train predictions correct.
# Out of 2025, 108 carry-over predictions correct.
# Out of 1929, 108 carry-over train predictions correct.
# Out of 820, 207 small predictions correct.
# Out of 724, 179 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 166 large predictions correct.
# Out of 3063, 163 large train predictions correct.
# Out of 1296, 86 carry-over large predictions correct.
# Out of 1248, 86 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_17.json
# Out of 5050, 428 predictions correct.
# Out of 4858, 407 train predictions correct.
# Out of 2025, 121 carry-over predictions correct.
# Out of 1929, 113 carry-over train predictions correct.
# Out of 820, 108 small predictions correct.
# Out of 724, 93 small train predictions correct.
# Out of 270, 32 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 3159, 214 large predictions correct.
# Out of 3063, 208 large train predictions correct.
# Out of 1296, 51 carry-over large predictions correct.
# Out of 1248, 48 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_19.json
# Out of 5050, 178 predictions correct.
# Out of 4858, 165 train predictions correct.
# Out of 2025, 54 carry-over predictions correct.
# Out of 1929, 52 carry-over train predictions correct.
# Out of 820, 74 small predictions correct.
# Out of 724, 61 small train predictions correct.
# Out of 270, 5 carry-over small predictions correct.
# Out of 222, 3 carry-over small train predictions correct.
# Out of 3159, 46 large predictions correct.
# Out of 3063, 46 large train predictions correct.
# Out of 1296, 28 carry-over large predictions correct.
# Out of 1248, 28 carry-over large train predictions correct.
# Finalizado 10.
