# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import pytz
import re
import os
import sys
import pickle
from datetime import datetime

# %%
# Define network parameters
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)
    
# We use a 2-degree polynomial function to approximate 0 and 1/2 to 0 and 1 stays in 1
def polynomial_function(x):
    return 2 * (x ** 2) - x

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return 0.5 * (1 - jnp.cos(jnp.pi * x))
    
# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size, n_max=10):
    # Generate two columns of random numbers between 0 and 9
    column_1 = np.random.randint(0, n_max, size)
    column_2 = np.random.randint(0, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_dataset_without_zeros(size, n_max=10):
    # Generate two columns of random numbers between 1 and 9
    column_1 = np.random.randint(1, n_max, size)
    column_2 = np.random.randint(1, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=10):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset


def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=4, bits_end=7):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        couples_not_included = [(3, 3), (5, 5), (6, 6), (7, 7), (9, 9), (3, 6), (3, 7), (6, 3), (7, 3), (5, 7), (7, 5), (6, 7), (7, 6)]
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(couples_not_included)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        column_1 = []
        column_2 = []
        pairs = [(5, 5), (9, 9)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 2:
        column_1 = []
        column_2 = []
        pairs = [(3, 3), (6, 6), (3, 6), (6, 3), (5, 7), (7, 5)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 3:
        column_1 = []
        column_2 = []
        pairs = [(3, 7), (6, 7), (7, 3), (7, 6)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 4:
        column_1 = [7] * size
        column_2 = [7] * size
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 5:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, inputs_1, inputs_2, outputs_prev):
    if stage == 1:
        return np.array([np.outer(vec2, vec1).flatten() for vec1, vec2 in zip(inputs_1, inputs_2)])

    elif stage == 2:
        outputs = []
        matrix_step_2 = np.zeros((16, 28))
        for i in range(4):
            for j in range(4):
                matrix_step_2[i*4 + j, i*8 + j] = 1
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            flatten_vector = jnp.dot(outer_product.flatten(), matrix_step_2)
            outputs.append(flatten_vector)
        return np.array(outputs)

    elif stage == 3:
        outputs = []
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            z3 = lower_even(outer_product[2,3] + outer_product[3,2])
            z4 = lower_even(outer_product[1,3] + outer_product[2,2] + outer_product[3,1] + z3 * 1/2)
            z5 = lower_even(outer_product[0,3] + outer_product[1,2] + outer_product[2,1] + outer_product[3,0] + z4 * 1/2)
            z6 = lower_even(outer_product[0,2] + outer_product[1,1] + outer_product[2,0] + z5 * 1/2)
            z7 = lower_even(outer_product[0,1] + outer_product[1,0] + z6 * 1/2)
            outputs.append([z7, z6, z5, z4, z3, 0, 0])
        return np.array(outputs)

    elif stage == 4:
        return outputs_prev

    elif stage == 5:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None
        
# Perfect parameters needed for the stages where a part of the NN performs perfectly

# Create the W1_perfect matrix of zeros with dimensions (8,16)
W1_perfect = np.zeros((8, 16))
# Introduce the correct numbers to multiply
for k in range(4):
    for i in range(4):
        W1_perfect[i, 12+i-k*4] = 1/2
        W1_perfect[4+i, 4*i:4*i+4] = 1/2

# Create the W2_perfect matrix of zeros with dimensions (16,28)
W2_perfect = np.zeros((16, 28))

# Correctly place the 7-bit vectors
for i in range(4):
    for j in range(4):
        W2_perfect[i*4 + j, i*8 + j] = 1

# R vectors of dimension (28,1)
R3_perfect = np.zeros((28))
R4_perfect = np.zeros((28))
R5_perfect = np.zeros((28))
R6_perfect = np.zeros((28))
R7_perfect = np.zeros((28))

for i in range(4):
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1

# Scalar parameters v
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((28,7))

for i in range(7):
    for j in range(4):
        T_perfect[7*j + i, i] = 1

# Parameter v7
v7_perfect = 1/2

# Neural network in every stage

def neural_network_1(params, x1, x2):
    W1, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    #vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return prev_vec

def neural_network_2(params, x1, x2):
    W2, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return vec

def neural_network_3(params, x1, x2):
    R3, R4, R5, R6, R7, v3, v4, v5, v6 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2_perfect) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return jnp.array([z7, z6, z5, z4, z3, 0, 0])

def neural_network_4(params, x1, x2):
    T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2_perfect) # vec is a (1,28) dimensional vector
    z3 = lower_even(relu(jnp.dot(vec, R3_perfect))) # z3 is a scalar with the second carry over
    z4 = lower_even(relu(jnp.dot(vec, R4_perfect) + jnp.dot(z3, v3_perfect))) # z4 is a scalar with the third carry over
    z5 = lower_even(relu(jnp.dot(vec, R5_perfect) + jnp.dot(z4, v4_perfect))) # z5 is a scalar with the fourth carry over
    z6 = lower_even(relu(jnp.dot(vec, R6_perfect) + jnp.dot(z5, v5_perfect))) # z6 is a scalar with the fifth carry over
    z7 = lower_even(relu(jnp.dot(vec, R7_perfect) + jnp.dot(z6, v6_perfect))) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return y

def neural_network_5(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(jnp.dot(vec, T) + jnp.dot(z, v7))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y, param_reg = 0):
    pred = neural_network_1(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_2(params, x1, x2, y, param_reg = 0):
    pred = neural_network_2(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_3(params, x1, x2, y, param_reg = 0):
    pred = neural_network_3(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_4(params, x1, x2, y, param_reg = 0):
    pred = neural_network_4(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_5(params, x1, x2, y, param_reg = 0):
    pred = neural_network_5(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization


# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_1)(params, x1, x2, y, param_reg)
    step_loss = loss_1(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_2)(params, x1, x2, y, param_reg)
    step_loss = loss_2(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_3(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_3)(params, x1, x2, y, param_reg)
    step_loss = loss_3(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_4(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_4)(params, x1, x2, y, param_reg)
    step_loss = loss_4(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_5(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_5)(params, x1, x2, y, param_reg)
    step_loss = loss_5(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss


def decide_training(params, x1, x2, y, lr, stage, param_reg = 0):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 4:
        params, step_loss = update_params_4(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 5:
        params, step_loss = update_params_5(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, param_reg = 0, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage, param_reg)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss


# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0, real_test=0):
    if real_test == 1:
        decimal_dataset = generate_test_dataset(n_max=12)
    else:
        decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    correct_predictions_count = 0
    test_size = inputs_1.shape[0]

    for i in range(test_size):
        prediction = predict(params, inputs_1[i], inputs_2[i], stage)
        #print(f'Se ha predicho {prediction} y era {outputs[i]}')
        if jnp.all(prediction == outputs[i]):  # Check if the prediction matches the expected output
            correct_predictions_count += 1  # Increment correct prediction count
        elif visualize_errors == 1:
            print(f'Ha fallado {decimal_dataset.iloc[i,0]} por {decimal_dataset.iloc[i,1]}.')
            #print(f'Se ha predicho {prediction} y era {outputs[i]}')
    return test_size, correct_predictions_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 4:
        binary_pred = neural_network_4(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 5:
        binary_pred = neural_network_5(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    else:
        print('Bad index for the training stage.')
        return None


# Check if two models are equal
def are_models_equal(model_1, model_2):
    # Check that both lists have the same length
    if len(model_1) != len(model_2):
        return False

    # Compare each element in both lists
    for elem1, elem2 in zip(model_1, model_2):
        if isinstance(elem1, jnp.ndarray) and isinstance(elem2, jnp.ndarray):
            # Compare two JAX arrays
            if not jnp.all(jnp.isclose(elem1, elem2, atol=1e-2)):
                return False
        else:
            return False

    return True

# %%
def generate_model(mean=0.5, std=1):
    W1 = initialize_random_weights(mean, std, (8, 16))  # 128 neurons in the hidden layer that include element-wise multiplication
    W2 = initialize_random_weights(mean, std, (16, 28))  # 448 neurons in the hidden layer that sort the bits
    R3 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the second bit
    R4 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fourth bit
    R6 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fifth bit
    R7 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the sixth bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the second bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fourth bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fifth bit
    T = initialize_random_weights(mean, std, (28, 7))  # 196 neurons that allow performing the sum
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    trainable_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

def load_trainable_model(model, stage, type_training, file_name, fecha):
    # Ruta dinámica basada en el stage y la fecha
    model_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{fecha}.pkl'
    
    # Cargar el archivo .pkl y asignarlo dinámicamente a trainable_model_stage_{stage}
    with open(model_path, 'rb') as f:
        globals()[f'trainable_model_stage_{stage}'] = pickle.load(f)
    
    # Confirmar la carga
    print(f'Model trainable_model_stage_{stage} loaded successfully.')
    return globals()[f'trainable_model_stage_{stage}']

# %%
model = 'trainable_model_stage'
date_pattern = r'trainable_model_stage_5-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'

csv_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/models_STAGES_to_test_validation_performance.csv'

df = pd.read_csv(csv_file, delimiter = ';')

for _, row in df.iterrows():
    current_time = row['current_time'] 
    type_training = row['type_training']
    file_name = row['file_name']

    for stage in range(5,6):
        load_trainable_model(model, stage, type_training, file_name, current_time)

    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    if type_training == 'No_stages':
        stage_changer = stage_changer*5
        
    N=500
    training_stages = 5
    trainings_needed = np.zeros(training_stages)
    
    for stage in range(5,6): 
        save_dir = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/{type_training}/{file_name}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, visualize_errors=0, real_test=1)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, visualize_errors=0, real_test=1)
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_count == test_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        test_size = correct_predictions_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Model trainable_model_stage_5 loaded successfully.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013118199072778225.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01776537112891674.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016208605840802193.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014707675203680992.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014449913054704666.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018455268815159798.
# STAGE 5: Out of 144, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016514228656888008.
# STAGE 5: Out of 144, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014182151295244694.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013679535128176212.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013808226212859154.
# STAGE 5: Out of 144, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01562329102307558.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016235023736953735.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013893457129597664.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014038331806659698.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014163264073431492.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013867251574993134.
# STAGE 5: Out of 144, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013926026411354542.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01487258542329073.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016541458666324615.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013899414800107479.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018646936863660812.
# STAGE 5: Out of 144, 46 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02343006618320942.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015777653083205223.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.026940809562802315.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016575675457715988.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015766875818371773.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01704578474164009.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014329967088997364.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01511547714471817.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014727521687746048.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013216735795140266.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015148084610700607.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014053361490368843.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012666458263993263.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013820208609104156.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013119940645992756.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013748450204730034.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014067288488149643.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012221502140164375.
# STAGE 5: Out of 144, 82 were predicted correctly in the current model.
# STAGE 5: Loss is 0.046652086079120636.
# STAGE 5: Out of 144, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027264991775155067.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017002278938889503.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015569482930004597.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014342590235173702.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013653166592121124.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014694390818476677.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015120991505682468.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014958466403186321.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014932737685739994.
# STAGE 5: Out of 144, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012416943907737732.
# STAGE 5: Out of 144, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.031203895807266235.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012735138647258282.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013750367797911167.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012337537482380867.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014020148664712906.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012313091196119785.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01776455156505108.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013312994502484798.
# STAGE 5: Out of 144, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01252883579581976.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014079177752137184.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015556863509118557.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012586472555994987.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012089632451534271.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012782818637788296.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012202533893287182.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011850436218082905.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011344248428940773.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012081452645361423.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012350054457783699.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011088309809565544.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011897671967744827.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010952934622764587.
# STAGE 5: Out of 144, 101 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010746259242296219.
# STAGE 5: Out of 144, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016683321446180344.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01619715802371502.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011157642118632793.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011089173145592213.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010420305654406548.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011177382431924343.
# STAGE 5: Out of 144, 101 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010922890156507492.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011271332390606403.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01113085076212883.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01099445577710867.
# STAGE 5: Out of 144, 101 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011893032118678093.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012043231166899204.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011909520253539085.
# STAGE 5: Out of 144, 101 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01166292279958725.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011251304298639297.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010618259198963642.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014779819175601006.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010850068181753159.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012641498818993568.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010563373565673828.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010323070921003819.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01489066332578659.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01596875675022602.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01004504319280386.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010675783269107342.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010397881269454956.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01020874921232462.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011730208061635494.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011933459900319576.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01108125876635313.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011160092428326607.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010077016428112984.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013239267282187939.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01116859633475542.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01094446238130331.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011227832175791264.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011733143590390682.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011030932888388634.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011195125058293343.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012605259194970131.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01050709281116724.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010184817016124725.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010047059506177902.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011403369717299938.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010178777389228344.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011159516870975494.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011575302109122276.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011938478797674179.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009954683482646942.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009848612360656261.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009991024620831013.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010309631936252117.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011313103139400482.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010280609130859375.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012000242248177528.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009949477389454842.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012562422081828117.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010757739655673504.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009954117238521576.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010556784458458424.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012921957299113274.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010365313850343227.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010180932469666004.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009783487766981125.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010447971522808075.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011271866038441658.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010427294299006462.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012966268695890903.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011565598659217358.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009860645048320293.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012004146352410316.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010119888931512833.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012469128705561161.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011061343364417553.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011371498927474022.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010812749154865742.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011414304375648499.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0110210832208395.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009763021022081375.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010159112513065338.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00971151702105999.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011577612720429897.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010713298805058002.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010090845637023449.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010205359198153019.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009714324958622456.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00933110248297453.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010737407021224499.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01738281361758709.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012440881691873074.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010333837941288948.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013237481005489826.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011712788604199886.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010764089412987232.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01051335223019123.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009933007881045341.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009485634043812752.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009597890079021454.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009807542897760868.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01079902146011591.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01045612059533596.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01023814082145691.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012022609822452068.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010683268308639526.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010744337923824787.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010553761385381222.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010869304649531841.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009728342294692993.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010376893915235996.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009897571988403797.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010905720293521881.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01606944017112255.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009393285028636456.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010249074548482895.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01050631795078516.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009453480131924152.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010265110060572624.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01065086666494608.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009651544503867626.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009991583414375782.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009778345935046673.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009704853408038616.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010303044691681862.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009256151504814625.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00952269695699215.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010176415555179119.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010312864556908607.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009546838700771332.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009840180166065693.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012794453650712967.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009225939400494099.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010617656633257866.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009472949430346489.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01017653476446867.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009792562574148178.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01062316820025444.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010525220073759556.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011066707782447338.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00959433801472187.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009708037599921227.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009591353125870228.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009939834475517273.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008153168484568596.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00989080872386694.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010814172215759754.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009893614798784256.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010610156692564487.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010918758809566498.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010507485829293728.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01242736540734768.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009956805035471916.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00938363652676344.
# STAGE 5: Out of 144, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011238506995141506.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009263196028769016.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009365057572722435.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010814479552209377.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009416015818715096.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010416962206363678.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009842827916145325.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009982971474528313.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010363980196416378.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008769085630774498.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010686278343200684.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012667895294725895.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012159906327724457.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009798839688301086.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011127321980893612.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009623292833566666.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009320007637143135.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009098141454160213.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00994125846773386.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00896180048584938.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011394854635000229.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009448830038309097.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013124357908964157.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009230225346982479.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009418005123734474.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011660388670861721.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009212730452418327.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009581676684319973.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009519495069980621.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009195422753691673.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009574932046234608.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009223266504704952.
# STAGE 5: Out of 144, 101 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009106941521167755.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009769399650394917.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01048534456640482.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008892393670976162.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009458189830183983.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012071676552295685.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011741988360881805.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00867263413965702.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011056564748287201.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010617420077323914.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009757878258824348.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009215442463755608.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009804926812648773.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011561552993953228.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009931164793670177.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009362882003188133.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008966131135821342.
# STAGE 5: Out of 144, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01263437606394291.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010871491394937038.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010311602614820004.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010928172618150711.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010406001470983028.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00864159781485796.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011467990465462208.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011011086404323578.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009996077977120876.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010623456910252571.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011183125898241997.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009544330649077892.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012643447145819664.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009411253966391087.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010569783858954906.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0097020473331213.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008979951031506062.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00878930650651455.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008919859305024147.
# STAGE 5: Out of 144, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01265605166554451.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008794518187642097.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009618975222110748.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01138661615550518.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009589084424078465.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009895293042063713.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012170366942882538.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011563952080905437.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009913625195622444.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00952909141778946.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009021003730595112.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011725249700248241.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011542254127562046.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01014939695596695.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010828221216797829.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009567866101861.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01077630277723074.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01261865720152855.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010169255547225475.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009725342504680157.
# STAGE 5: Out of 144, 65 were predicted correctly in the current model.
# STAGE 5: Loss is 0.050760529935359955.
# STAGE 5: Out of 144, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0314241386950016.
# STAGE 5: Out of 144, 72 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05965343490242958.
# STAGE 5: Out of 144, 70 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04853503033518791.
# STAGE 5: Out of 144, 79 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04194129630923271.
# STAGE 5: Out of 144, 82 were predicted correctly in the current model.
# STAGE 5: Loss is 0.043518584221601486.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02059231884777546.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016690872609615326.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016134819015860558.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014036789536476135.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012968073599040508.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012763682752847672.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013069776818156242.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012675954028964043.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020053330808877945.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014572943560779095.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0124063640832901.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01231976319104433.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01384787354618311.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012598720379173756.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017138060182332993.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018448781222105026.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014534479938447475.
# STAGE 5: Out of 144, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012767098844051361.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011968978680670261.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012911850586533546.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010376743040978909.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013930901885032654.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011672514490783215.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014844191260635853.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011506694369018078.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02749304659664631.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014165055938065052.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011355272494256496.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010460207238793373.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012571865692734718.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01220449898391962.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012281134724617004.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01505324151366949.
# STAGE 5: Out of 144, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018793465569615364.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011630751192569733.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01066130306571722.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011726528406143188.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010266375727951527.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02520618587732315.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013833345845341682.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010532520711421967.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011543065309524536.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010009968653321266.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011371972039341927.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015921777114272118.
# STAGE 5: Out of 144, 101 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012622864916920662.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012672863900661469.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011784126050770283.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011445865035057068.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010032426565885544.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01033869106322527.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015133813954889774.
# STAGE 5: Out of 144, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011388343758881092.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011376180686056614.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012021350674331188.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014667576178908348.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014101488515734673.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011833441443741322.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010414756834506989.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009922023862600327.
# STAGE 5: Out of 144, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017353763803839684.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010994183830916882.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010883179493248463.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01115513127297163.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010629171505570412.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012701237574219704.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01252233050763607.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013593788258731365.
# STAGE 5: Out of 144, 101 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010739893652498722.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010446685366332531.
# STAGE 5: Out of 144, 78 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01832418516278267.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011732461862266064.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01831907406449318.
# STAGE 5: Out of 144, 82 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0351761057972908.
# STAGE 5: Out of 144, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.026906194165349007.
# STAGE 5: Out of 144, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023455386981368065.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0162285678088665.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016518609598279.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013511715456843376.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013230685144662857.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0158210601657629.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011926500126719475.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01056957058608532.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012049360200762749.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012597913853824139.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013806060887873173.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011192897334694862.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014212070032954216.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01615113578736782.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01140637043863535.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011940845288336277.
# STAGE 5: Out of 144, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01278663519769907.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011324705556035042.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009247823618352413.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011088088154792786.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009796333499252796.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010600176639854908.
# STAGE 5: Out of 144, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01267524529248476.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011221406050026417.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011822451837360859.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011099214665591717.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011459169909358025.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009990633465349674.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00967374723404646.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009516919031739235.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01673087105154991.
# STAGE 5: Out of 144, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.026528608053922653.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010402568615972996.
# STAGE 5: Out of 144, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011873759329319.
# STAGE 5: Out of 144, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011019967496395111.
# STAGE 5: Out of 144, 70 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014219827018678188.
# STAGE 5: Out of 144, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011006733402609825.
# STAGE 5: Out of 144, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011759049259126186.
# STAGE 5: Out of 144, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009664304554462433.
# STAGE 5: Out of 144, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009286513552069664.
# STAGE 5: Out of 144, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01214908342808485.
# ...
# STAGE 5: Loss is 0.005846206098794937.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005976294633001089.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005883933510631323.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005275079049170017.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005172404460608959.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004961020778864622.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0059247612953186035.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.006095800548791885.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005867680534720421.
# STAGE 5: Out of 144, 103 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0051148622296750546.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0053834631107747555.
# STAGE 5: Out of 144, 102 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00487496005371213.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005748542957007885.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005388234276324511.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004635854158550501.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005108543671667576.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00506378011777997.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004889799281954765.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0055209617130458355.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004651521798223257.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005030510481446981.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004686043132096529.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0050880578346550465.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005780283361673355.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004780587274581194.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.006656100042164326.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004810842219740152.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004522554110735655.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00471652764827013.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005202456843107939.
# STAGE 5: Out of 144, 102 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005493848584592342.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0059363748878240585.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004935961216688156.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004618607461452484.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0054191346280276775.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004773381166160107.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004508269485086203.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005143584217876196.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005304757971316576.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00553933484479785.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0052986531518399715.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005142895970493555.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004653508309274912.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004738422576338053.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0048651560209691525.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004891781136393547.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004826840944588184.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004528491757810116.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004511894658207893.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004212319850921631.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004595660604536533.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0053530302830040455.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004394692834466696.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0048853871412575245.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00537930428981781.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004566939547657967.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005088699050247669.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004766357596963644.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005035394337028265.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004906094633042812.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004976416472345591.
# STAGE 5: Out of 144, 109 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004829934798181057.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004407244734466076.
# STAGE 5: Out of 144, 109 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004680786281824112.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005042067728936672.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004590705968439579.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0046543856151402.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004595925100147724.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005460626445710659.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004852116107940674.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0047336239367723465.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004286998882889748.
# STAGE 5: Out of 144, 110 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005245658569037914.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005181998945772648.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004633662756532431.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.006072441581636667.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004777323920279741.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004265701863914728.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004681005608290434.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004150827880948782.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005050403531640768.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004706200677901506.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004673248156905174.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004274036735296249.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004581336863338947.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004218313377350569.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0050436463207006454.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005242334213107824.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0042443289421498775.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00468044076114893.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0039004895370453596.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004803169518709183.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004281332716345787.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0044524953700602055.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.003847163636237383.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004902227316051722.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004229498561471701.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004877247381955385.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005140321329236031.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0047244965098798275.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004472990985959768.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004260290414094925.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004037810489535332.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0047619235701859.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004693415481597185.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004174977075308561.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004635322839021683.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00443662004545331.
# STAGE 5: Out of 144, 109 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004521481227129698.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0048719486221671104.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004141645971685648.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004961763042956591.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004172418266534805.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004439890384674072.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004647799767553806.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004594895057380199.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.003993503749370575.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00416775606572628.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00397654389962554.
# STAGE 5: Out of 144, 108 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0044980887323617935.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0036975976545363665.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004311493132263422.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0046000126749277115.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004859501030296087.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00449628010392189.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.005114360246807337.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004590805619955063.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0042906212620437145.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004152402747422457.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0042070322670042515.
# STAGE 5: Out of 144, 104 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004017458762973547.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004467669874429703.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004364168271422386.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004209538456052542.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.003739837557077408.
# STAGE 5: Out of 144, 107 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004710648208856583.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0038287194911390543.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004925257991999388.
# STAGE 5: Out of 144, 106 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004300431348383427.
# STAGE 5: Out of 144, 105 were predicted correctly in the current model.
# STAGE 5: Loss is 0.004208299331367016.
# Stage 5 completed in 2500.0 trainings.
# Model trainable_model_stage_5 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/Stages/Generated_model/Stage_5\trainable_model_stage_5-2024_11_08_02_49_22.pkl
# Results of Stage 5 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/Stages/Generated_model/Stage_5\Stage_5_results_2024_11_08_02_49_22.txt
