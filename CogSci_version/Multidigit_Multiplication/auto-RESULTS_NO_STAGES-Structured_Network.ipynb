# %%
import pandas as pd
import numpy as np
import math
import re
from glob import glob

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import pytz
import os
import sys
import pickle
from datetime import datetime

# %%
# Define network parameters
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)
    
# We use a 2-degree polynomial function to approximate 0 and 1/2 to 0 and 1 stays in 1
def polynomial_function(x):
    return 2 * (x ** 2) - x

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return 0.5 * (1 - jnp.cos(jnp.pi * x))
    
# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size, n_max=10):
    # Generate two columns of random numbers between 0 and 9
    column_1 = np.random.randint(0, n_max, size)
    column_2 = np.random.randint(0, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_dataset_without_zeros(size, n_max=10):
    # Generate two columns of random numbers between 1 and 9
    column_1 = np.random.randint(1, n_max, size)
    column_2 = np.random.randint(1, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=10):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset


def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=4, bits_end=7):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        couples_not_included = [(3, 3), (5, 5), (6, 6), (7, 7), (9, 9), (3, 6), (3, 7), (6, 3), (7, 3), (5, 7), (7, 5), (6, 7), (7, 6)]
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(couples_not_included)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        column_1 = []
        column_2 = []
        pairs = [(5, 5), (9, 9)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 2:
        column_1 = []
        column_2 = []
        pairs = [(3, 3), (6, 6), (3, 6), (6, 3), (5, 7), (7, 5)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 3:
        column_1 = []
        column_2 = []
        pairs = [(3, 7), (6, 7), (7, 3), (7, 6)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 4:
        column_1 = [7] * size
        column_2 = [7] * size
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 5:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, inputs_1, inputs_2, outputs_prev):
    if stage == 1:
        return np.array([np.outer(vec2, vec1).flatten() for vec1, vec2 in zip(inputs_1, inputs_2)])

    elif stage == 2:
        outputs = []
        matrix_step_2 = np.zeros((16, 28))
        for i in range(4):
            for j in range(4):
                matrix_step_2[i*4 + j, i*8 + j] = 1
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            flatten_vector = jnp.dot(outer_product.flatten(), matrix_step_2)
            outputs.append(flatten_vector)
        return np.array(outputs)

    elif stage == 3:
        outputs = []
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            z3 = lower_even(outer_product[2,3] + outer_product[3,2])
            z4 = lower_even(outer_product[1,3] + outer_product[2,2] + outer_product[3,1] + z3 * 1/2)
            z5 = lower_even(outer_product[0,3] + outer_product[1,2] + outer_product[2,1] + outer_product[3,0] + z4 * 1/2)
            z6 = lower_even(outer_product[0,2] + outer_product[1,1] + outer_product[2,0] + z5 * 1/2)
            z7 = lower_even(outer_product[0,1] + outer_product[1,0] + z6 * 1/2)
            outputs.append([z7, z6, z5, z4, z3, 0, 0])
        return np.array(outputs)

    elif stage == 4:
        return outputs_prev

    elif stage == 5:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None
        
# Perfect parameters needed for the stages where a part of the NN performs perfectly

# Create the W1_perfect matrix of zeros with dimensions (8,16)
W1_perfect = np.zeros((8, 16))
# Introduce the correct numbers to multiply
for k in range(4):
    for i in range(4):
        W1_perfect[i, 12+i-k*4] = 1/2
        W1_perfect[4+i, 4*i:4*i+4] = 1/2

# Create the W2_perfect matrix of zeros with dimensions (16,28)
W2_perfect = np.zeros((16, 28))

# Correctly place the 7-bit vectors
for i in range(4):
    for j in range(4):
        W2_perfect[i*4 + j, i*8 + j] = 1

# R vectors of dimension (28,1)
R3_perfect = np.zeros((28))
R4_perfect = np.zeros((28))
R5_perfect = np.zeros((28))
R6_perfect = np.zeros((28))
R7_perfect = np.zeros((28))

for i in range(4):
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1

# Scalar parameters v
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((28,7))

for i in range(7):
    for j in range(4):
        T_perfect[7*j + i, i] = 1

# Parameter v7
v7_perfect = 1/2

# Neural network in every stage

def neural_network_1(params, x1, x2):
    W1, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    #vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return prev_vec

def neural_network_2(params, x1, x2):
    W2, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return vec

def neural_network_3(params, x1, x2):
    R3, R4, R5, R6, R7, v3, v4, v5, v6 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2_perfect) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return jnp.array([z7, z6, z5, z4, z3, 0, 0])

def neural_network_4(params, x1, x2):
    T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2_perfect) # vec is a (1,28) dimensional vector
    z3 = lower_even(relu(jnp.dot(vec, R3_perfect))) # z3 is a scalar with the second carry over
    z4 = lower_even(relu(jnp.dot(vec, R4_perfect) + jnp.dot(z3, v3_perfect))) # z4 is a scalar with the third carry over
    z5 = lower_even(relu(jnp.dot(vec, R5_perfect) + jnp.dot(z4, v4_perfect))) # z5 is a scalar with the fourth carry over
    z6 = lower_even(relu(jnp.dot(vec, R6_perfect) + jnp.dot(z5, v5_perfect))) # z6 is a scalar with the fifth carry over
    z7 = lower_even(relu(jnp.dot(vec, R7_perfect) + jnp.dot(z6, v6_perfect))) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return y

def neural_network_5(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(jnp.dot(vec, T) + jnp.dot(z, v7))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_4(params, x1, x2, y):
    pred = neural_network_4(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_5(params, x1, x2, y, param_reg = 0):
    pred = neural_network_5(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization


# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_4(params, x1, x2, y, lr):
    gradients = grad(loss_4)(params, x1, x2, y)
    step_loss = loss_4(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_5(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_5)(params, x1, x2, y, param_reg)
    step_loss = loss_5(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss


def decide_training(params, x1, x2, y, lr, stage, param_reg = 0):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 4:
        params, step_loss = update_params_4(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 5:
        params, step_loss = update_params_5(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, param_reg = 0, lr=0.001, epochs=100, couples_included=[]):
    decimal_dataset = prepare_dataset(level, epochs, couples_included)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage, param_reg)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss


# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0, real_test=0):
    if real_test == 1:
        decimal_dataset = generate_test_dataset(n_max=12)
    else:
        decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    correct_predictions_count = 0
    test_size = inputs_1.shape[0]

    for i in range(test_size):
        prediction = predict(params, inputs_1[i], inputs_2[i], stage)
        #print(f'Se ha predicho {prediction} y era {outputs[i]}')
        if jnp.all(prediction == outputs[i]):  # Check if the prediction matches the expected output
            correct_predictions_count += 1  # Increment correct prediction count
        elif visualize_errors == 1:
            print(f'Ha fallado {decimal_dataset.iloc[i,0]} por {decimal_dataset.iloc[i,1]}.')
            #print(f'Se ha predicho {prediction} y era {outputs[i]}')
    return test_size, correct_predictions_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 4:
        binary_pred = neural_network_4(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 5:
        binary_pred = neural_network_5(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    else:
        print('Bad index for the training stage.')
        return None


# Check if two models are equal
def are_models_equal(model_1, model_2):
    # Check that both lists have the same length
    if len(model_1) != len(model_2):
        return False

    # Compare each element in both lists
    for elem1, elem2 in zip(model_1, model_2):
        if isinstance(elem1, jnp.ndarray) and isinstance(elem2, jnp.ndarray):
            # Compare two JAX arrays
            if not jnp.all(jnp.isclose(elem1, elem2, atol=1e-2)):
                return False
        else:
            return False

    return True

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

def load_trainable_model(model, stage, fecha):
    # Ruta dinámica basada en el stage y la fecha
    model_path = f'Parameters/{model}_{stage}-{fecha}.pkl'
    
    # Cargar el archivo .pkl y asignarlo dinámicamente a trainable_model_stage_{stage}
    with open(model_path, 'rb') as f:
        globals()[f'trainable_model_stage_{stage}'] = pickle.load(f)
    
    # Confirmar la carga
    print(f'Model trainable_model_stage_{stage} loaded successfully.')
    return globals()[f'trainable_model_stage_{stage}']

# %%
AP_name = 'AP_0.05_0.05'
folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Parameters/{AP_name}'
model = 'trainable_model_stage'

date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Parameters/{AP_name}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    h = 0.001 # Additional parameter needed for the two first stages
    trainable_model_stage_5 = trainable_model
    training_stages = 5
    trainings_needed = np.zeros(training_stages)

    visualizer = 10
    lr_changer = 250
    stage_changer = 2500*5
    N=500

    for stage in range(5,6): 
        save_dir = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/No_stages/{AP_name}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            level = -2
            lr = 0.001
            param_reg = 10
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, param_reg = param_reg, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break      
                if trainings_needed[stage-1] == visualizer:
                    param_reg = 0
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_count == test_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        test_size = correct_predictions_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_11_08_00_24_10.pkl
# STAGE 5: Out of 100, 8 were predicted correctly in the current model.
# STAGE 5: Loss is 2.31762957572937.
# STAGE 5: Out of 100, 10 were predicted correctly in the current model.
# STAGE 5: Loss is 0.22915737330913544.
# STAGE 5: Out of 100, 13 were predicted correctly in the current model.
# STAGE 5: Loss is 0.22015704214572906.
# STAGE 5: Out of 100, 19 were predicted correctly in the current model.
# STAGE 5: Loss is 0.18702325224876404.
# STAGE 5: Out of 100, 15 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1906588077545166.
# STAGE 5: Out of 100, 17 were predicted correctly in the current model.
# STAGE 5: Loss is 0.16890539228916168.
# STAGE 5: Out of 100, 22 were predicted correctly in the current model.
# STAGE 5: Loss is 0.17852655053138733.
# STAGE 5: Out of 100, 20 were predicted correctly in the current model.
# STAGE 5: Loss is 0.15764877200126648.
# STAGE 5: Out of 100, 20 were predicted correctly in the current model.
# STAGE 5: Loss is 0.132429838180542.
# STAGE 5: Out of 100, 27 were predicted correctly in the current model.
# STAGE 5: Loss is 0.14453966915607452.
# STAGE 5: Out of 100, 25 were predicted correctly in the current model.
# STAGE 5: Loss is 0.14907389879226685.
# STAGE 5: Out of 100, 14 were predicted correctly in the current model.
# STAGE 5: Loss is 0.19616419076919556.
# STAGE 5: Out of 100, 27 were predicted correctly in the current model.
# STAGE 5: Loss is 0.15437674522399902.
# STAGE 5: Out of 100, 19 were predicted correctly in the current model.
# STAGE 5: Loss is 0.18393151462078094.
# STAGE 5: Out of 100, 19 were predicted correctly in the current model.
# STAGE 5: Loss is 0.15644830465316772.
# STAGE 5: Out of 100, 39 were predicted correctly in the current model.
# STAGE 5: Loss is 0.11469396203756332.
# STAGE 5: Out of 100, 42 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10139483213424683.
# STAGE 5: Out of 100, 47 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10110786557197571.
# STAGE 5: Out of 100, 46 were predicted correctly in the current model.
# STAGE 5: Loss is 0.09004837274551392.
# STAGE 5: Out of 100, 26 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1343805342912674.
# STAGE 5: Out of 100, 28 were predicted correctly in the current model.
# STAGE 5: Loss is 0.13300734758377075.
# STAGE 5: Out of 100, 46 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10324258357286453.
# STAGE 5: Out of 100, 44 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10206343978643417.
# STAGE 5: Out of 100, 52 were predicted correctly in the current model.
# STAGE 5: Loss is 0.09014298766851425.
# STAGE 5: Out of 100, 61 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07816262543201447.
# STAGE 5: Out of 100, 43 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07475679367780685.
# STAGE 5: Out of 100, 44 were predicted correctly in the current model.
# STAGE 5: Loss is 0.08185520768165588.
# STAGE 5: Out of 100, 55 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10057850927114487.
# STAGE 5: Out of 100, 57 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0951954573392868.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.09706912934780121.
# STAGE 5: Out of 100, 29 were predicted correctly in the current model.
# STAGE 5: Loss is 0.11056554317474365.
# STAGE 5: Out of 100, 24 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10185882449150085.
# STAGE 5: Out of 100, 35 were predicted correctly in the current model.
# STAGE 5: Loss is 0.11318065226078033.
# STAGE 5: Out of 100, 37 were predicted correctly in the current model.
# STAGE 5: Loss is 0.13598781824111938.
# STAGE 5: Out of 100, 50 were predicted correctly in the current model.
# STAGE 5: Loss is 0.09468228369951248.
# STAGE 5: Out of 100, 47 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1016550064086914.
# STAGE 5: Out of 100, 41 were predicted correctly in the current model.
# STAGE 5: Loss is 0.12154943495988846.
# STAGE 5: Out of 100, 16 were predicted correctly in the current model.
# STAGE 5: Loss is 0.2237548977136612.
# STAGE 5: Out of 100, 15 were predicted correctly in the current model.
# STAGE 5: Loss is 0.21587465703487396.
# STAGE 5: Out of 100, 3 were predicted correctly in the current model.
# STAGE 5: Loss is 0.3709738850593567.
# STAGE 5: Out of 100, 9 were predicted correctly in the current model.
# STAGE 5: Loss is 0.25612497329711914.
# STAGE 5: Out of 100, 11 were predicted correctly in the current model.
# STAGE 5: Loss is 0.21853509545326233.
# STAGE 5: Out of 100, 11 were predicted correctly in the current model.
# STAGE 5: Loss is 0.19413094222545624.
# STAGE 5: Out of 100, 13 were predicted correctly in the current model.
# STAGE 5: Loss is 0.18440164625644684.
# STAGE 5: Out of 100, 16 were predicted correctly in the current model.
# STAGE 5: Loss is 0.17863400280475616.
# STAGE 5: Out of 100, 18 were predicted correctly in the current model.
# STAGE 5: Loss is 0.16109485924243927.
# STAGE 5: Out of 100, 20 were predicted correctly in the current model.
# STAGE 5: Loss is 0.18127529323101044.
# STAGE 5: Out of 100, 16 were predicted correctly in the current model.
# STAGE 5: Loss is 0.15847750008106232.
# STAGE 5: Out of 100, 26 were predicted correctly in the current model.
# STAGE 5: Loss is 0.15649031102657318.
# STAGE 5: Out of 100, 14 were predicted correctly in the current model.
# STAGE 5: Loss is 0.18707525730133057.
# STAGE 5: Out of 100, 27 were predicted correctly in the current model.
# STAGE 5: Loss is 0.15057626366615295.
# STAGE 5: Out of 100, 36 were predicted correctly in the current model.
# STAGE 5: Loss is 0.12176850438117981.
# STAGE 5: Out of 100, 38 were predicted correctly in the current model.
# STAGE 5: Loss is 0.11963345110416412.
# STAGE 5: Out of 100, 36 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1161113828420639.
# STAGE 5: Out of 100, 48 were predicted correctly in the current model.
# STAGE 5: Loss is 0.08542027324438095.
# STAGE 5: Out of 100, 52 were predicted correctly in the current model.
# STAGE 5: Loss is 0.08308844268321991.
# STAGE 5: Out of 100, 53 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07557588815689087.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07340120524168015.
# STAGE 5: Out of 100, 63 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07342049479484558.
# STAGE 5: Out of 100, 61 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07136613130569458.
# STAGE 5: Out of 100, 63 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07289707660675049.
# STAGE 5: Out of 100, 63 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07225875556468964.
# STAGE 5: Out of 100, 55 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06652557104825974.
# STAGE 5: Out of 100, 61 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06363093107938766.
# STAGE 5: Out of 100, 40 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06440787762403488.
# STAGE 5: Out of 100, 35 were predicted correctly in the current model.
# STAGE 5: Loss is 0.11860409379005432.
# STAGE 5: Out of 100, 63 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06424744427204132.
# STAGE 5: Out of 100, 45 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05881311744451523.
# STAGE 5: Out of 100, 69 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06408200412988663.
# STAGE 5: Out of 100, 61 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06640589982271194.
# STAGE 5: Out of 100, 51 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06509935110807419.
# STAGE 5: Out of 100, 65 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06347054243087769.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06114990636706352.
# STAGE 5: Out of 100, 55 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05937488004565239.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06503970175981522.
# STAGE 5: Out of 100, 70 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05424061045050621.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05396449938416481.
# STAGE 5: Out of 100, 49 were predicted correctly in the current model.
# STAGE 5: Loss is 0.08775539696216583.
# STAGE 5: Out of 100, 65 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05851143226027489.
# STAGE 5: Out of 100, 71 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05450967326760292.
# STAGE 5: Out of 100, 58 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06825190037488937.
# STAGE 5: Out of 100, 70 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04796621948480606.
# STAGE 5: Out of 100, 61 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06252125650644302.
# STAGE 5: Out of 100, 72 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05013136565685272.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0494307242333889.
# STAGE 5: Out of 100, 69 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05103692412376404.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.053221140056848526.
# STAGE 5: Out of 100, 75 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04870283976197243.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04870423674583435.
# STAGE 5: Out of 100, 60 were predicted correctly in the current model.
# STAGE 5: Loss is 0.09548574686050415.
# STAGE 5: Out of 100, 72 were predicted correctly in the current model.
# STAGE 5: Loss is 0.045765411108732224.
# STAGE 5: Out of 100, 58 were predicted correctly in the current model.
# STAGE 5: Loss is 0.048342958092689514.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04413792863488197.
# STAGE 5: Out of 100, 74 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04497038945555687.
# STAGE 5: Out of 100, 35 were predicted correctly in the current model.
# STAGE 5: Loss is 0.12566693127155304.
# STAGE 5: Out of 100, 35 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1223175898194313.
# STAGE 5: Out of 100, 34 were predicted correctly in the current model.
# STAGE 5: Loss is 0.11738467961549759.
# STAGE 5: Out of 100, 46 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10187091678380966.
# STAGE 5: Out of 100, 57 were predicted correctly in the current model.
# STAGE 5: Loss is 0.08082190901041031.
# STAGE 5: Out of 100, 40 were predicted correctly in the current model.
# STAGE 5: Loss is 0.08693554997444153.
# STAGE 5: Out of 100, 53 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06625910848379135.
# STAGE 5: Out of 100, 67 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06588596105575562.
# STAGE 5: Out of 100, 60 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0652134120464325.
# STAGE 5: Out of 100, 67 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06662286072969437.
# STAGE 5: Out of 100, 67 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06037469208240509.
# STAGE 5: Out of 100, 49 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07780487835407257.
# STAGE 5: Out of 100, 65 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07858794927597046.
# STAGE 5: Out of 100, 34 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1144169270992279.
# STAGE 5: Out of 100, 36 were predicted correctly in the current model.
# STAGE 5: Loss is 0.10451225191354752.
# STAGE 5: Out of 100, 54 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07668347656726837.
# STAGE 5: Out of 100, 51 were predicted correctly in the current model.
# STAGE 5: Loss is 0.07948004454374313.
# STAGE 5: Out of 100, 57 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0811457484960556.
# STAGE 5: Out of 100, 49 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06912118196487427.
# STAGE 5: Out of 100, 58 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06953809410333633.
# STAGE 5: Out of 100, 63 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06594293564558029.
# STAGE 5: Out of 100, 58 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05833464860916138.
# STAGE 5: Out of 100, 59 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06361418217420578.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05962493270635605.
# STAGE 5: Out of 100, 56 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05770062282681465.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06300904601812363.
# STAGE 5: Out of 100, 74 were predicted correctly in the current model.
# STAGE 5: Loss is 0.054055362939834595.
# STAGE 5: Out of 100, 73 were predicted correctly in the current model.
# STAGE 5: Loss is 0.053914036601781845.
# STAGE 5: Out of 100, 71 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05510412156581879.
# STAGE 5: Out of 100, 68 were predicted correctly in the current model.
# STAGE 5: Loss is 0.051188692450523376.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04857933148741722.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04412728175520897.
# STAGE 5: Out of 100, 70 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05269145965576172.
# STAGE 5: Out of 100, 70 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04655341058969498.
# STAGE 5: Out of 100, 77 were predicted correctly in the current model.
# STAGE 5: Loss is 0.042647670954465866.
# STAGE 5: Out of 100, 75 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04794938117265701.
# STAGE 5: Out of 100, 77 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04531809315085411.
# STAGE 5: Out of 100, 78 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0439266562461853.
# STAGE 5: Out of 100, 77 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04675047844648361.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03927727788686752.
# STAGE 5: Out of 100, 83 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04093991592526436.
# STAGE 5: Out of 100, 78 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03721217066049576.
# STAGE 5: Out of 100, 73 were predicted correctly in the current model.
# STAGE 5: Loss is 0.039076607674360275.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03539693355560303.
# STAGE 5: Out of 100, 81 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03870251029729843.
# STAGE 5: Out of 100, 76 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03995101526379585.
# STAGE 5: Out of 100, 81 were predicted correctly in the current model.
# STAGE 5: Loss is 0.035213589668273926.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.033931463956832886.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.037307266145944595.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04249922186136246.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03192954882979393.
# STAGE 5: Out of 100, 82 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03538549691438675.
# STAGE 5: Out of 100, 83 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03390905261039734.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.035393062978982925.
# STAGE 5: Out of 100, 82 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03354286402463913.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.034047920256853104.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0348246730864048.
# STAGE 5: Out of 100, 74 were predicted correctly in the current model.
# STAGE 5: Loss is 0.034185051918029785.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03118816576898098.
# STAGE 5: Out of 100, 78 were predicted correctly in the current model.
# STAGE 5: Loss is 0.036668602377176285.
# STAGE 5: Out of 100, 83 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03030528500676155.
# STAGE 5: Out of 100, 78 were predicted correctly in the current model.
# STAGE 5: Loss is 0.031506072729825974.
# STAGE 5: Out of 100, 69 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03441730886697769.
# STAGE 5: Out of 100, 81 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03163420036435127.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.030703017488121986.
# STAGE 5: Out of 100, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.032683126628398895.
# STAGE 5: Out of 100, 83 were predicted correctly in the current model.
# STAGE 5: Loss is 0.030355842784047127.
# STAGE 5: Out of 100, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03236111253499985.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03251111879944801.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029954589903354645.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03128313645720482.
# STAGE 5: Out of 100, 81 were predicted correctly in the current model.
# STAGE 5: Loss is 0.031979963183403015.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.028013668954372406.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.030384520068764687.
# STAGE 5: Out of 100, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.030688222497701645.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03024434484541416.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.028249340131878853.
# STAGE 5: Out of 100, 79 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029648324474692345.
# STAGE 5: Out of 100, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02825561724603176.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.028222618624567986.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029989175498485565.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02543659508228302.
# STAGE 5: Out of 100, 74 were predicted correctly in the current model.
# STAGE 5: Loss is 0.028842415660619736.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029684191569685936.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029537616297602654.
# STAGE 5: Out of 100, 83 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03217538818717003.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.028186453506350517.
# STAGE 5: Out of 100, 77 were predicted correctly in the current model.
# STAGE 5: Loss is 0.028609512373805046.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029574766755104065.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027579249814152718.
# STAGE 5: Out of 100, 83 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029515331611037254.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02889968454837799.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.029371321201324463.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02647560089826584.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02612335979938507.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027568019926548004.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027727313339710236.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024544840678572655.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027042705565690994.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025232573971152306.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02420971542596817.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02834010124206543.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02681819535791874.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027876868844032288.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024757249280810356.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025715673342347145.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027174152433872223.
# STAGE 5: Out of 100, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025585338473320007.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025891300290822983.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02683592587709427.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023074518889188766.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025319885462522507.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02424575947225094.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025775747373700142.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.026159681379795074.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024670923128724098.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02536838874220848.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023311328142881393.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02325139194726944.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02676982991397381.
# STAGE 5: Out of 100, 82 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02412317506968975.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0257402490824461.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.026023900136351585.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024021871387958527.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0253230519592762.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024860668927431107.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019996847957372665.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027769140899181366.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023636385798454285.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025401044636964798.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022853679955005646.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023927519097924232.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02331210859119892.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02378169447183609.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02299560233950615.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0208439864218235.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02339797466993332.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023793427273631096.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02253722958266735.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0226791612803936.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021491622552275658.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02472757361829281.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024508951231837273.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020482663065195084.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025388024747371674.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023445555940270424.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022345470264554024.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024771302938461304.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021333182230591774.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022981278598308563.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021584071218967438.
# STAGE 5: Out of 100, 83 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02424377016723156.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021893909201025963.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02171049453318119.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02183203026652336.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022388964891433716.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023109328001737595.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02225828915834427.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021691899746656418.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021478792652487755.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023534325882792473.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021349022164940834.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02453526481986046.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02180449292063713.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021061204373836517.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021239547058939934.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023982534185051918.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022198043763637543.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019269773736596107.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02272089198231697.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022357460111379623.
# STAGE 5: Out of 100, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019141728058457375.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021004358306527138.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019837310537695885.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020886551588773727.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022769177332520485.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019430261105298996.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0238181184977293.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019463922828435898.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019717298448085785.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02017567865550518.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0205833837389946.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019982092082500458.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018993062898516655.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02904939278960228.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018720978870987892.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022158183157444.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01808258518576622.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020055115222930908.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022503135725855827.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017735807225108147.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017359519377350807.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018918104469776154.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018535863608121872.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01918063871562481.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01945439912378788.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01853136718273163.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02084229327738285.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02022002451121807.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01773439534008503.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02367980405688286.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018874894827604294.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022083038464188576.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018799075856804848.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019811386242508888.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0168361347168684.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02226763404905796.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019930172711610794.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017692608758807182.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018376564607024193.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01752701960504055.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01790643110871315.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018287532031536102.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01804778352379799.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018519947305321693.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016963403671979904.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01757277175784111.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017228122800588608.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017571475356817245.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01878214068710804.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022521046921610832.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017748264595866203.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019722141325473785.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017058860510587692.
# STAGE 5: Out of 100, 81 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0188459362834692.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020604582503437996.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017582790926098824.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01806632988154888.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022232012823224068.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019393717870116234.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017843343317508698.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0175795815885067.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01634872518479824.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016228919848799706.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01712854765355587.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01725456677377224.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017404451966285706.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016415776684880257.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01617361605167389.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017307763919234276.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016534624621272087.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015760118141770363.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016038941219449043.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017966751009225845.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01735730469226837.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01654399186372757.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015834320336580276.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01733139157295227.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018541762605309486.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021062055602669716.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01928272284567356.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01728321984410286.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017198964953422546.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016877640038728714.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016921918839216232.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016698362305760384.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018391821533441544.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016425471752882004.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017399027943611145.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01747073605656624.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016829077154397964.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014792980626225471.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018618116155266762.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01576833613216877.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02382851205766201.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01581851951777935.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020101100206375122.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017277825623750687.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015652118250727654.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016830291599035263.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016103435307741165.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014677093364298344.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016828466206789017.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018684929236769676.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015109260566532612.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016233885660767555.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016282809898257256.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015237633138895035.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016681775450706482.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015492238104343414.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014707451686263084.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016425130888819695.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015674181282520294.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015835745260119438.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01490860152989626.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018176108598709106.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015160073526203632.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0174962617456913.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016554610803723335.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018723778426647186.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01691431924700737.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0159405916929245.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015786239877343178.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017290225252509117.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016162186861038208.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01590135134756565.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017144743353128433.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016242630779743195.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019512712955474854.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01636704057455063.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017636040225625038.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015094649977982044.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016844207420945168.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017290670424699783.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017737977206707.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0152843426913023.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01583586260676384.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016305478289723396.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015397095121443272.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018405748531222343.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017621206119656563.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015345374122262001.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017263974994421005.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015471652150154114.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019174253568053246.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014733841642737389.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015157640911638737.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018916193395853043.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017066415399312973.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017596261575818062.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018143462017178535.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016625186428427696.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014978541992604733.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015432835556566715.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016737619414925575.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0175082478672266.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01452004723250866.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018879489973187447.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01510920375585556.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014942131005227566.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01682160049676895.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015709038823843002.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016774453222751617.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014984801411628723.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02050646021962166.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016415830701589584.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017834186553955078.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014665134251117706.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014971517026424408.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021678738296031952.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.016464855521917343.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0165695957839489.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01524445042014122.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01709667220711708.
# ...
# STAGE 5: Loss is 0.044977445155382156.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03807992860674858.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.042044516652822495.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04077630490064621.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0365787073969841.
# STAGE 5: Out of 100, 82 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03807782009243965.
# STAGE 5: Out of 100, 80 were predicted correctly in the current model.
# STAGE 5: Loss is 0.045179497450590134.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05143483355641365.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.04471107944846153.
# STAGE 5: Out of 100, 48 were predicted correctly in the current model.
# STAGE 5: Loss is 0.11633086949586868.
# STAGE 5: Out of 100, 49 were predicted correctly in the current model.
# STAGE 5: Loss is 0.09030811488628387.
# STAGE 5: Out of 100, 53 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1023990586400032.
# STAGE 5: Out of 100, 53 were predicted correctly in the current model.
# STAGE 5: Loss is 0.1206573024392128.
# STAGE 5: Out of 100, 62 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06110657379031181.
# STAGE 5: Out of 100, 67 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06507092714309692.
# STAGE 5: Out of 100, 70 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06753553450107574.
# STAGE 5: Out of 100, 69 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06463176757097244.
# STAGE 5: Out of 100, 66 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06225729361176491.
# STAGE 5: Out of 100, 55 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06863231211900711.
# STAGE 5: Out of 100, 71 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0558483712375164.
# STAGE 5: Out of 100, 61 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06435133516788483.
# STAGE 5: Out of 100, 64 were predicted correctly in the current model.
# STAGE 5: Loss is 0.052129555493593216.
# STAGE 5: Out of 100, 78 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05522963032126427.
# Stage 5 completed in 12500.0 trainings.
# Model trainable_model_stage_5 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/No_stages/AP_0.05_0.05/Stage_5\trainable_model_stage_5-2024_11_08_00_41_59.pkl
# Results of Stage 5 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/No_stages/AP_0.05_0.05/Stage_5\Stage_5_results_2024_11_08_00_41_59.txt
# Loaded trainable_model_stage_2024_11_08_00_42_45.pkl
# STAGE 5: Out of 100, 30 were predicted correctly in the current model.
# STAGE 5: Loss is 2.4313204288482666.
# STAGE 5: Out of 100, 47 were predicted correctly in the current model.
# STAGE 5: Loss is 0.09475766867399216.
# STAGE 5: Out of 100, 65 were predicted correctly in the current model.
# STAGE 5: Loss is 0.06890807300806046.
# STAGE 5: Out of 100, 71 were predicted correctly in the current model.
# STAGE 5: Loss is 0.05138646066188812.
# STAGE 5: Out of 100, 75 were predicted correctly in the current model.
# STAGE 5: Loss is 0.047613561153411865.
# STAGE 5: Out of 100, 79 were predicted correctly in the current model.
# STAGE 5: Loss is 0.039681483060121536.
# STAGE 5: Out of 100, 74 were predicted correctly in the current model.
# STAGE 5: Loss is 0.03483179584145546.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.030951524153351784.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02895040065050125.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.031743861734867096.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.026193490251898766.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027930565178394318.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02863161452114582.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.027796898037195206.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025898009538650513.
# STAGE 5: Out of 100, 85 were predicted correctly in the current model.
# STAGE 5: Loss is 0.026606669649481773.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024911941960453987.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023848913609981537.
# STAGE 5: Out of 100, 86 were predicted correctly in the current model.
# STAGE 5: Loss is 0.025803761556744576.
# STAGE 5: Out of 100, 84 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02476421557366848.
# STAGE 5: Out of 100, 87 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024067005142569542.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023531997576355934.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02375936694443226.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02008223533630371.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023689020425081253.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.024570932611823082.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02114514634013176.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02208825945854187.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02053133025765419.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02129947580397129.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02116496115922928.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01991189457476139.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020971521735191345.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02267490141093731.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02236999198794365.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023213492706418037.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.02136104367673397.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021394113078713417.
# STAGE 5: Out of 100, 88 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022790174931287766.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021805910393595695.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01997274160385132.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020756782963871956.
# STAGE 5: Out of 100, 92 were predicted correctly in the current model.
# STAGE 5: Loss is 0.023143351078033447.
# STAGE 5: Out of 100, 90 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020164817571640015.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021420596167445183.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.022321416065096855.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01989196054637432.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.021148893982172012.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019220909103751183.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020411254838109016.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020087379962205887.
# STAGE 5: Out of 100, 89 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01989505998790264.
# STAGE 5: Out of 100, 91 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019493339583277702.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018743786960840225.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.020531009882688522.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01856221631169319.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01824897713959217.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01943386159837246.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01724076084792614.
# STAGE 5: Out of 100, 94 were predicted correctly in the current model.
# STAGE 5: Loss is 0.018244685605168343.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.019673682749271393.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0180957093834877.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.017444057390093803.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015905724838376045.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015288406983017921.
# STAGE 5: Out of 100, 93 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012841520830988884.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015255036763846874.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01418722327798605.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015733415260910988.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015276480466127396.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013901645317673683.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.015821481123566628.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014484571292996407.
# STAGE 5: Out of 100, 95 were predicted correctly in the current model.
# STAGE 5: Loss is 0.014690898358821869.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013550513423979282.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011834630742669106.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013617588207125664.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013225539587438107.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012811221182346344.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012233073823153973.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.013164481148123741.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.012881739996373653.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010820424184203148.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01097981445491314.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010974896140396595.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.01178665366023779.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.011778131127357483.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009972209110856056.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010977373458445072.
# STAGE 5: Out of 100, 96 were predicted correctly in the current model.
# STAGE 5: Loss is 0.0103588392958045.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009715105406939983.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00946357287466526.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009009753353893757.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009471286088228226.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009068134240806103.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.010637866333127022.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00999814085662365.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009471206925809383.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008864029310643673.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008100617676973343.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008892709389328957.
# STAGE 5: Out of 100, 97 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00834688264876604.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.00814195815473795.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008668949827551842.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008360114879906178.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008989807218313217.
# STAGE 5: Out of 100, 99 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008675391785800457.
# STAGE 5: Out of 100, 98 were predicted correctly in the current model.
# STAGE 5: Loss is 0.008206190541386604.
# STAGE 5: Out of 100, 100 were predicted correctly in the current model.
# STAGE 5: Loss is 0.009109674021601677.
# Objective completed
# Stage 5 completed in 1090.0 trainings.
# Model trainable_model_stage_5 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/No_stages/AP_0.05_0.05/Stage_5\trainable_model_stage_5-2024_11_08_00_42_45.pkl
# Results of Stage 5 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/No_stages/AP_0.05_0.05/Stage_5\Stage_5_results_2024_11_08_00_42_45.txt
# Loaded trainable_model_stage_2024_11_08_00_43_07.pkl
# STAGE 5: Out of 100, 1 were predicted correctly in the current model.
# STAGE 5: Loss is 7.315009593963623.
# Loss is NaN
# Stage 5 completed in 13.0 trainings.
# Model trainable_model_stage_5 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/No_stages/AP_0.05_0.05/Stage_5\trainable_model_stage_5-2024_11_08_00_43_07.pkl
# Results of Stage 5 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/No_stages/AP_0.05_0.05/Stage_5\Stage_5_results_2024_11_08_00_43_07.txt

# %%
visualize_errors = 1
real_test = 0
stage = 4

test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, visualize_errors=visualize_errors, real_test=real_test)
print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
# Out:
# Ha fallado 1 por 1.
# Ha fallado 3 por 1.
# Ha fallado 4 por 1.
# Ha fallado 5 por 1.
# Ha fallado 8 por 1.
# Ha fallado 9 por 1.
# Ha fallado 8 por 2.
# Ha fallado 3 por 3.
# Ha fallado 4 por 3.
# Ha fallado 5 por 3.
# Ha fallado 6 por 3.
# Ha fallado 8 por 3.
# Ha fallado 9 por 3.
# Ha fallado 2 por 5.
# Ha fallado 3 por 5.
# Ha fallado 8 por 5.
# Ha fallado 9 por 5.
# Ha fallado 3 por 6.
# Ha fallado 6 por 6.
# Ha fallado 7 por 6.
# Ha fallado 2 por 7.
# Ha fallado 5 por 7.
# Ha fallado 9 por 7.
# Ha fallado 2 por 8.
# Ha fallado 3 por 8.
# Ha fallado 6 por 8.
# Ha fallado 7 por 8.
# Ha fallado 8 por 8.
# Ha fallado 1 por 9.
# Ha fallado 2 por 9.
# Ha fallado 3 por 9.
# Ha fallado 4 por 9.
# Ha fallado 5 por 9.
# Ha fallado 6 por 9.
# Ha fallado 7 por 9.
# Ha fallado 8 por 9.
# Ha fallado 9 por 9.
# STAGE 4: Out of 100, 63 were predicted correctly in the current model.

# %%
stage = 5
trainable_model_stage_5 = [trainable_model_stage_1[0],
                           trainable_model_stage_2[0],
                           trainable_model_stage_3[0],
                           trainable_model_stage_3[1],
                           trainable_model_stage_3[2],
                           trainable_model_stage_3[3],
                           trainable_model_stage_3[4],
                           trainable_model_stage_3[5],
                           trainable_model_stage_3[6],
                           trainable_model_stage_3[7],
                           trainable_model_stage_3[8],
                           trainable_model_stage_4[0],
                           trainable_model_stage_4[1]
                           ]

# %%
visualizer = 10
lr_changer = 250
N=500
lr = 0.01
param_reg = 10
test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)

while correct_predictions_count != test_size:
    prev_model = globals()[f"{model}_{stage}"]
    globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=-1, param_reg = param_reg, lr=lr, epochs=N)
    trainings_needed[stage-1] += 1
    
    if math.isnan(final_loss):
        globals()[f"{model}_{stage}"] = prev_model
        print('Final loss in NaN')
        break
    else:
        test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
    
    if trainings_needed[stage-1] % visualizer == 0:
        print(f"STAGE {stage}: Loss is {final_loss}.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
        
    if trainings_needed[stage-1] % lr_changer == 0:
        new_lr = input(f"Change of leraning rate? (Current one is {lr}, press enter if not): ")
        if new_lr != "":
            lr = float(new_lr)
        new_param_reg = input(f"Change of regularization parameter? (Current one is {param_reg}, press enter if not): ")
        if new_param_reg != "":
            param_reg = float(new_param_reg)
                    
    if trainings_needed[stage-1] % stage_changer == 0:
        response = input("Skip to next stage? (yes/no): ")
        if response.lower() == "yes":
            break
            
print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')

# %%
model = 'trainable_model_stage'
stage = 3
test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, visualize_errors=1)
print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
# Out:
# Ha fallado 9 por 9.
# Se ha predicho [-0. -0.  0.  0.  0.  0.  0.] y era [0. 0. 2. 0. 0. 0. 0.]
# STAGE 3: Out of 100, 99 were predicted correctly in the current model.
