# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import pytz
import re
import os
import sys
import pickle
from datetime import datetime

# %%
# Define network parameters
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)
    
# We use a 2-degree polynomial function to approximate 0 and 1/2 to 0 and 1 stays in 1
def polynomial_function(x):
    return 2 * (x ** 2) - x

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return 0.5 * (1 - jnp.cos(jnp.pi * x))
    
# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size, n_max=10):
    # Generate two columns of random numbers between 0 and 9
    column_1 = np.random.randint(0, n_max, size)
    column_2 = np.random.randint(0, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_dataset_without_zeros(size, n_max=10):
    # Generate two columns of random numbers between 1 and 9
    column_1 = np.random.randint(1, n_max, size)
    column_2 = np.random.randint(1, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=10):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset


def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=4, bits_end=7):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        couples_not_included = [(3, 3), (5, 5), (6, 6), (7, 7), (9, 9), (3, 6), (3, 7), (6, 3), (7, 3), (5, 7), (7, 5), (6, 7), (7, 6)]
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(couples_not_included)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        column_1 = []
        column_2 = []
        pairs = [(5, 5), (9, 9)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 2:
        column_1 = []
        column_2 = []
        pairs = [(3, 3), (6, 6), (3, 6), (6, 3), (5, 7), (7, 5)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 3:
        column_1 = []
        column_2 = []
        pairs = [(3, 7), (6, 7), (7, 3), (7, 6)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 4:
        column_1 = [7] * size
        column_2 = [7] * size
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 5:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, inputs_1, inputs_2, outputs_prev):
    if stage == 1:
        return np.array([np.outer(vec2, vec1).flatten() for vec1, vec2 in zip(inputs_1, inputs_2)])

    elif stage == 2:
        outputs = []
        matrix_step_2 = np.zeros((16, 28))
        for i in range(4):
            for j in range(4):
                matrix_step_2[i*4 + j, i*8 + j] = 1
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            flatten_vector = jnp.dot(outer_product.flatten(), matrix_step_2)
            outputs.append(flatten_vector)
        return np.array(outputs)

    elif stage == 3:
        outputs = []
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            z3 = lower_even(outer_product[2,3] + outer_product[3,2])
            z4 = lower_even(outer_product[1,3] + outer_product[2,2] + outer_product[3,1] + z3 * 1/2)
            z5 = lower_even(outer_product[0,3] + outer_product[1,2] + outer_product[2,1] + outer_product[3,0] + z4 * 1/2)
            z6 = lower_even(outer_product[0,2] + outer_product[1,1] + outer_product[2,0] + z5 * 1/2)
            z7 = lower_even(outer_product[0,1] + outer_product[1,0] + z6 * 1/2)
            outputs.append([z7, z6, z5, z4, z3, 0, 0])
        return np.array(outputs)

    elif stage == 4:
        return outputs_prev

    elif stage == 5:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None
        
# Perfect parameters needed for the stages where a part of the NN performs perfectly

# Create the W1_perfect matrix of zeros with dimensions (8,16)
W1_perfect = np.zeros((8, 16))
# Introduce the correct numbers to multiply
for k in range(4):
    for i in range(4):
        W1_perfect[i, 12+i-k*4] = 1/2
        W1_perfect[4+i, 4*i:4*i+4] = 1/2

# Create the W2_perfect matrix of zeros with dimensions (16,28)
W2_perfect = np.zeros((16, 28))

# Correctly place the 7-bit vectors
for i in range(4):
    for j in range(4):
        W2_perfect[i*4 + j, i*8 + j] = 1

# R vectors of dimension (28,1)
R3_perfect = np.zeros((28))
R4_perfect = np.zeros((28))
R5_perfect = np.zeros((28))
R6_perfect = np.zeros((28))
R7_perfect = np.zeros((28))

for i in range(4):
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1

# Scalar parameters v
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((28,7))

for i in range(7):
    for j in range(4):
        T_perfect[7*j + i, i] = 1

# Parameter v7
v7_perfect = 1/2

# Neural network in every stage

def neural_network_1(params, x1, x2):
    W1, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    #vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return prev_vec

def neural_network_2(params, x1, x2):
    W1, W2 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return vec

def neural_network_3(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return jnp.array([z7, z6, z5, z4, z3, 0, 0])

def neural_network_4(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(jnp.dot(vec, T) + jnp.dot(z, v7))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y, param_reg = 0):
    pred = neural_network_1(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_2(params, x1, x2, y, param_reg = 0):
    pred = neural_network_2(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_3(params, x1, x2, y, param_reg = 0):
    pred = neural_network_3(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_4(params, x1, x2, y, param_reg = 0):
    pred = neural_network_4(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_5(params, x1, x2, y, param_reg = 0):
    pred = neural_network_5(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization


# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_1)(params, x1, x2, y, param_reg)
    step_loss = loss_1(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_2)(params, x1, x2, y, param_reg)
    step_loss = loss_2(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_3(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_3)(params, x1, x2, y, param_reg)
    step_loss = loss_3(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_4(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_4)(params, x1, x2, y, param_reg)
    step_loss = loss_4(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_5(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_5)(params, x1, x2, y, param_reg)
    step_loss = loss_5(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss


def decide_training(params, x1, x2, y, lr, stage, param_reg = 0):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 4:
        params, step_loss = update_params_4(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    elif stage == 5:
        params, step_loss = update_params_5(params, x1, x2, y, lr, param_reg)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, param_reg = 0, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage, param_reg)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss


# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0, real_test=0):
    if real_test == 1:
        decimal_dataset = generate_test_dataset(n_max=12)
    else:
        decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    correct_predictions_count = 0
    test_size = inputs_1.shape[0]

    for i in range(test_size):
        prediction = predict(params, inputs_1[i], inputs_2[i], stage)
        #print(f'Se ha predicho {prediction} y era {outputs[i]}')
        if jnp.all(prediction == outputs[i]):  # Check if the prediction matches the expected output
            correct_predictions_count += 1  # Increment correct prediction count
        elif visualize_errors == 1:
            print(f'Ha fallado {decimal_dataset.iloc[i,0]} por {decimal_dataset.iloc[i,1]}.')
            #print(f'Se ha predicho {prediction} y era {outputs[i]}')
    return test_size, correct_predictions_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 4:
        binary_pred = neural_network_4(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 5:
        binary_pred = neural_network_5(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    else:
        print('Bad index for the training stage.')
        return None


# Check if two models are equal
def are_models_equal(model_1, model_2):
    # Check that both lists have the same length
    if len(model_1) != len(model_2):
        return False

    # Compare each element in both lists
    for elem1, elem2 in zip(model_1, model_2):
        if isinstance(elem1, jnp.ndarray) and isinstance(elem2, jnp.ndarray):
            # Compare two JAX arrays
            if not jnp.all(jnp.isclose(elem1, elem2, atol=1e-2)):
                return False
        else:
            return False

    return True

# %%
def generate_model(mean=0.5, std=1):
    W1 = initialize_random_weights(mean, std, (8, 16))  # 128 neurons in the hidden layer that include element-wise multiplication
    W2 = initialize_random_weights(mean, std, (16, 28))  # 448 neurons in the hidden layer that sort the bits
    R3 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the second bit
    R4 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fourth bit
    R6 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fifth bit
    R7 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the sixth bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the second bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fourth bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fifth bit
    T = initialize_random_weights(mean, std, (28, 7))  # 196 neurons that allow performing the sum
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    trainable_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

def load_trainable_model(model, stage, type_training, file_name, fecha):
    # Ruta dinámica basada en el stage y la fecha
    model_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{fecha}.pkl'
    
    # Cargar el archivo .pkl y asignarlo dinámicamente a trainable_model_stage_{stage}
    with open(model_path, 'rb') as f:
        globals()[f'trainable_model_stage_{stage}'] = pickle.load(f)
    
    # Confirmar la carga
    print(f'Model trainable_model_stage_{stage} loaded successfully.')
    return globals()[f'trainable_model_stage_{stage}']

# %%
model = 'trainable_model_stage'
date_pattern = r'trainable_model_stage_4-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'

csv_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/models_STAGE_BY_STAGE_to_test_validation_performance.csv'

df = pd.read_csv(csv_file, delimiter = ';')

for _, row in df.iterrows():
    current_time = row['current_time'] 
    type_training = row['type_training']
    file_name = row['file_name']

    stage = 4
    load_trainable_model(model, stage, type_training, file_name, current_time)

    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    if type_training == 'No_stages':
        stage_changer = stage_changer*5
        
    N=500
    training_stages = 5
    trainings_needed = np.zeros(training_stages)
    
    for stage in range(4,5): 
        save_dir = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/{type_training}/{file_name}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, visualize_errors=0, real_test=1)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, visualize_errors=0, real_test=1)
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_count == test_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        test_size = correct_predictions_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Model trainable_model_stage_4 loaded successfully.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.010003852657973766.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.009125124663114548.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.009058920666575432.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.009095603600144386.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.009030141867697239.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.009480149485170841.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.009077920578420162.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008926931768655777.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008971848525106907.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.009105566889047623.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008522593416273594.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008869600482285023.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008853795938193798.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008623816072940826.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008482848294079304.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00836082361638546.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008422945626080036.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008180882781744003.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008031140081584454.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007915439084172249.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008634533733129501.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008209697902202606.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008296927437186241.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008020521141588688.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008201852440834045.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008411215618252754.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007777190767228603.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008288023993372917.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007952862419188023.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007726403418928385.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00821964256465435.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008312687277793884.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008451885543763638.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008401360362768173.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008239188231527805.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008025317452847958.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007641725242137909.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008134615607559681.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007667649537324905.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007978027686476707.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008010072633624077.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0075245751067996025.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007897374220192432.
# STAGE 4: Out of 144, 105 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007633521221578121.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00769310537725687.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007380819413810968.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007743402849882841.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.008191375061869621.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007689609657973051.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007646861951798201.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0078097921796143055.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0077597349882125854.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007718568202108145.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007253744173794985.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007679064758121967.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007564535364508629.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007792667020112276.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007389383390545845.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007330127060413361.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007810876704752445.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0075744991190731525.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007750567514449358.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00725372601300478.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007010030094534159.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0074681248515844345.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007306859828531742.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006854834500700235.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007270516827702522.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007351286709308624.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007068665698170662.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007497877348214388.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00719483382999897.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007251123897731304.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007475619204342365.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007026947569102049.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007025809492915869.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007214609999209642.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007061402313411236.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006892225705087185.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007210039999336004.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006677677854895592.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00725382287055254.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0068928455002605915.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006665628869086504.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007381425704807043.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006972888484597206.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007096536923199892.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006716944742947817.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006986596155911684.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006849802564829588.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0069213672541081905.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006783605087548494.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0067661227658391.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006471371743828058.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0066130030900239944.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006750722415745258.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00673679681494832.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006563221570104361.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006973458454012871.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006923644803464413.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006428439170122147.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006797391921281815.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006989284884184599.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006629545707255602.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006550032179802656.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006420930847525597.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006558694411069155.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006580347660928965.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006633969489485025.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006375881377607584.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006460814271122217.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006636143196374178.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006447087042033672.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006647339556366205.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006454693153500557.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00630832789465785.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006499689072370529.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00667601777240634.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006549503188580275.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006234799977391958.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006136901676654816.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006665610242635012.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006648450158536434.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006339760962873697.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006616855505853891.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006055548787117004.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006441332399845123.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006166505627334118.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006175232585519552.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006732423324137926.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006109751760959625.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006351101212203503.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006165666971355677.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006399135105311871.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0063862791284918785.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006213492248207331.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00653806421905756.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006018841173499823.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006498313043266535.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006458742078393698.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006527746096253395.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006511404179036617.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006142098922282457.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006323868874460459.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006097558420151472.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0062058595940470695.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00602705217897892.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006325868424028158.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006307978183031082.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006168965715914965.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006016949191689491.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006107315421104431.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005796391982585192.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006064858753234148.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006069516763091087.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006166356150060892.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006296999286860228.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0062279049307107925.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006253065075725317.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005964572541415691.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006137747783213854.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005929476115852594.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005878769792616367.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00605036411434412.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005968562792986631.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005940713919699192.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005954954773187637.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005768332164734602.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00581353809684515.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005869492422789335.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006105152424424887.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0060370005667209625.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005912770051509142.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00612297048792243.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0057531739585101604.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005993636325001717.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00592542439699173.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005925436038523912.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006018118932843208.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005614147055894136.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005821375176310539.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0060815089382231236.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005803912412375212.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005945512093603611.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00605523819103837.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0059770685620605946.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0059124017134308815.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005538179539144039.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005698945373296738.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005892571527510881.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00566628435626626.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006041273474693298.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005675805266946554.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005339931230992079.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005812367890030146.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005806203465908766.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005648331250995398.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005705360788851976.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005878607742488384.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005859845317900181.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005733474623411894.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005823724437505007.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005743119865655899.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005600183270871639.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005720715969800949.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005619672127068043.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005710642319172621.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005606591701507568.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005402856040745974.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005798616912215948.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005549416411668062.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005908760242164135.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005688570439815521.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005813113879412413.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00560787646099925.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0057617067359387875.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005622867960482836.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005201974418014288.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005669143982231617.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0053974417969584465.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0053930762223899364.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005220605060458183.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005396975204348564.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005406498908996582.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005288638174533844.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005612302105873823.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005578421056270599.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005414398852735758.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005498107522726059.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00549054192379117.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005166053306311369.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005280670244246721.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005201949737966061.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005327490624040365.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005312737543135881.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005421529524028301.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00513254851102829.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005163494497537613.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005011424887925386.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004928786773234606.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005171813070774078.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005425803828984499.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005161709152162075.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00536045478656888.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005213888827711344.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0052466560155153275.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005063333548605442.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005219455808401108.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0052644917741417885.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005295555107295513.
# Stage 4 completed in 2500.0 trainings.
# Model trainable_model_stage_4 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/Stage_by_stage/AP_0.05_0.05/Stage_4\trainable_model_stage_4-2024_11_08_00_24_10.pkl
# Results of Stage 4 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/Stage_by_stage/AP_0.05_0.05/Stage_4\Stage_4_results_2024_11_08_00_24_10.txt
# Model trainable_model_stage_4 loaded successfully.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004628267139196396.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005426995921880007.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0048357779160141945.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004451319109648466.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0040780482813715935.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0037230656016618013.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004030338954180479.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00396193191409111.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0039057787507772446.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003978395368903875.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0032514026388525963.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003346078097820282.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003593157511204481.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0030783996917307377.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003406396135687828.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0031222719699144363.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003174222307279706.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0028273595962673426.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0029907606076449156.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002851346740499139.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0035601272247731686.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0022123928647488356.
# STAGE 4: Out of 144, 104 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0027801545802503824.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002816694788634777.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002135735470801592.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0024374639615416527.
# STAGE 4: Out of 144, 103 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002687911270186305.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002109341789036989.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00281964591704309.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002208101097494364.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0025548518169671297.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0024447666946798563.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002125813625752926.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002105831867083907.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0020476055797189474.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0021644211374223232.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002087423810735345.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0024042322766035795.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0018767430447041988.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0018797274678945541.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0019794474355876446.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002363987732678652.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002113490365445614.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0018167346715927124.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001909769605845213.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0019070821581408381.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0016932736616581678.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0018595821456983685.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002033042488619685.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0019327241461724043.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0017934172647073865.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0016727057518437505.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001951173646375537.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0019173366017639637.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0017487474251538515.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0016096460167318583.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001719560706987977.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0018059751018881798.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0017000720836222172.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0016317488625645638.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0018129420932382345.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013727747136726975.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0014651239616796374.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0015808332245796919.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001646007178351283.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001539340359158814.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0015038989949971437.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0014790206914767623.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001553649315610528.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0014311788836494088.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0014571037609130144.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0014091006014496088.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012889389181509614.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0015595596050843596.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001312806154601276.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0015210213605314493.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013961275108158588.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013301969738677144.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0015420147683471441.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013295512180775404.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012955779675394297.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0014086331939324737.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012132249539718032.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013036370510235429.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012341156834736466.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013512296136468649.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012500790180638433.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012800527038052678.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0014274619752541184.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00106318190228194.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012568328529596329.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013534959871321917.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012725499691441655.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012577120214700699.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010931406868621707.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0013328276108950377.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012338610831648111.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012492245296016335.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001190334209240973.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012402561260387301.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011502611450850964.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011638307478278875.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0012934139231219888.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011640703305602074.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011679751332849264.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011269605020061135.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010886682430282235.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009862248552963138.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010336944833397865.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010973506141453981.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011268039233982563.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001150676398538053.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00123010971583426.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011060872348025441.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011475883657112718.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011388409184291959.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001182669191621244.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010812463006004691.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010943602537736297.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001051614060997963.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011658102739602327.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010736525291576982.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009317028452642262.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010775260161608458.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010610149474814534.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010533630847930908.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009136762819252908.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010040837805718184.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009896537521854043.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010606186697259545.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011378603521734476.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011619612341746688.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010476306779310107.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011162669397890568.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010903342626988888.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0011247200891375542.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009665979305282235.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009307641303166747.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010073476005345583.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001020667958073318.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009154238505288959.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0008487945306114852.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010229829931631684.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009694106411188841.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009642430813983083.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009930835803970695.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.000929752248339355.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009173429571092129.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009368131286464632.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010110191069543362.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.001003668992780149.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009936279384419322.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010857811430469155.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009991694241762161.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009391052881255746.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010184631682932377.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010053637670353055.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009225505054928362.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0010020555928349495.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009247909765690565.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009114889544434845.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009680947987362742.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0008566306787542999.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009207166149280965.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009729648008942604.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0008267903467640281.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009832748910412192.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.000909147784113884.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009455780382268131.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009005311294458807.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0008743090438656509.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009722328395582736.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009181793429888785.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0008262446499429643.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0009490154916420579.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# ...
# STAGE 4: Loss is 0.005539041478186846.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004753264598548412.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004813479725271463.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005081495735794306.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004761321935802698.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004798897076398134.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005178876221179962.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004736198112368584.
# STAGE 4: Out of 144, 93 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005413866136223078.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005014983005821705.
# STAGE 4: Out of 144, 98 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005474367644637823.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007243053521960974.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005913742817938328.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00487522641196847.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004610144533216953.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004368286579847336.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004736769944429398.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00473976181820035.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004889775067567825.
# STAGE 4: Out of 144, 102 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004521580878645182.
# STAGE 4: Out of 144, 95 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006591593846678734.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00479446304962039.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004477535840123892.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004216909874230623.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005700693465769291.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004514182917773724.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004022541921585798.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004424892831593752.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004237169399857521.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004382839426398277.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004266656935214996.
# STAGE 4: Out of 144, 94 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0065085203386843204.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004304500762373209.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004236331209540367.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003857768839225173.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006489038933068514.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004222269169986248.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004006562288850546.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004180055111646652.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004201168194413185.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004474290646612644.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004314344841986895.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004302452318370342.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003861852688714862.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0040225679986178875.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0038777415174990892.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003833169350400567.
# STAGE 4: Out of 144, 101 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004214189480990171.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004245815798640251.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003881501965224743.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004158225376158953.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00404908275231719.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0038733489345759153.
# STAGE 4: Out of 144, 98 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005028106737881899.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003940504044294357.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006259146146476269.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0038093016482889652.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004113964736461639.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004070115741342306.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0036030602641403675.
# STAGE 4: Out of 144, 97 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004351662937551737.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0038313374388962984.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003765868954360485.
# STAGE 4: Out of 144, 96 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0041341218166053295.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00390022830106318.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00576245691627264.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004025287460535765.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003846504259854555.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003592437133193016.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0036706840619444847.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003659735433757305.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0036545402836054564.
# STAGE 4: Out of 144, 98 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007447723299264908.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0037270132452249527.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0035119277890771627.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0036188436206430197.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0037532171700149775.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0034054527059197426.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003609219565987587.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0035353810526430607.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00365265179425478.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003452311735600233.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004857248160988092.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005627795122563839.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0036225998774170876.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0055309198796749115.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0034228316508233547.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0036021615378558636.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004500207956880331.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0034296701196581125.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0034580084029585123.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003454375546425581.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0034388364292681217.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004235087428241968.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0030627292580902576.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003526107408106327.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0035919041838496923.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0036122966557741165.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004867711570113897.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004470236133784056.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003352727275341749.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0034455067943781614.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0037231671158224344.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003360424190759659.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005949154496192932.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0032404784578830004.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.002993087749928236.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003481549210846424.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003332083811983466.
# STAGE 4: Out of 144, 99 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007010378409177065.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00575139420107007.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003133856225758791.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0031813785899430513.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003355475142598152.
# STAGE 4: Out of 144, 93 were predicted correctly in the current model.
# STAGE 4: Loss is 0.007488137576729059.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.005021607968956232.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003402732778340578.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0032962316181510687.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0031750276684761047.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0048465668223798275.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003309367224574089.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0033457446843385696.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0033742093946784735.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0030992894899100065.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006078767590224743.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0031295055523514748.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0032596758101135492.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0032654062379151583.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.00318842357955873.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0032776077277958393.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0031932180281728506.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003999008797109127.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0030870421323925257.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0031974785961210728.
# STAGE 4: Out of 144, 97 were predicted correctly in the current model.
# STAGE 4: Loss is 0.004436987917870283.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0034142013173550367.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.006231261882930994.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.003335208399221301.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0033752964809536934.
# STAGE 4: Out of 144, 100 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0032840061467140913.
# Stage 4 completed in 2500.0 trainings.
# Model trainable_model_stage_4 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/Stage_by_stage/AP_0.1_0.1/Stage_4\trainable_model_stage_4-2024_11_08_01_14_33.pkl
# Results of Stage 4 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Validation_Performance/Stage_by_stage/AP_0.1_0.1/Stage_4\Stage_4_results_2024_11_08_01_14_33.txt
