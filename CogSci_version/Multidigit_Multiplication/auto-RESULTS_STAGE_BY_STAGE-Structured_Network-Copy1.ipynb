# %%
import pandas as pd
import numpy as np
import math
import re
from glob import glob

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import pytz
import os
import sys
import pickle
from datetime import datetime

# %%
# Define network parameters
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)
    
# We use a 2-degree polynomial function to approximate 0 and 1/2 to 0 and 1 stays in 1
def polynomial_function(x):
    return 2 * (x ** 2) - x

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return 0.5 * (1 - jnp.cos(jnp.pi * x))
    
# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size, n_max=10):
    # Generate two columns of random numbers between 0 and 9
    column_1 = np.random.randint(0, n_max, size)
    column_2 = np.random.randint(0, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_dataset_without_zeros(size, n_max=10):
    # Generate two columns of random numbers between 1 and 9
    column_1 = np.random.randint(1, n_max, size)
    column_2 = np.random.randint(1, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=10):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset


def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=4, bits_end=7):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        couples_not_included = [(3, 3), (5, 5), (6, 6), (7, 7), (9, 9), (3, 6), (3, 7), (6, 3), (7, 3), (5, 7), (7, 5), (6, 7), (7, 6)]
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(couples_not_included)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        column_1 = []
        column_2 = []
        pairs = [(5, 5), (9, 9)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 2:
        column_1 = []
        column_2 = []
        pairs = [(3, 3), (6, 6), (3, 6), (6, 3), (5, 7), (7, 5)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 3:
        column_1 = []
        column_2 = []
        pairs = [(3, 7), (6, 7), (7, 3), (7, 6)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 4:
        column_1 = [7] * size
        column_2 = [7] * size
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 5:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, inputs_1, inputs_2, outputs_prev):
    if stage == 1:
        return np.array([np.outer(vec2, vec1).flatten() for vec1, vec2 in zip(inputs_1, inputs_2)])

    elif stage == 2:
        outputs = []
        matrix_step_2 = np.zeros((16, 28))
        for i in range(4):
            for j in range(4):
                matrix_step_2[i*4 + j, i*8 + j] = 1
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            flatten_vector = jnp.dot(outer_product.flatten(), matrix_step_2)
            outputs.append(flatten_vector)
        return np.array(outputs)

    elif stage == 3:
        outputs = []
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            z3 = lower_even(outer_product[2,3] + outer_product[3,2])
            z4 = lower_even(outer_product[1,3] + outer_product[2,2] + outer_product[3,1] + z3 * 1/2)
            z5 = lower_even(outer_product[0,3] + outer_product[1,2] + outer_product[2,1] + outer_product[3,0] + z4 * 1/2)
            z6 = lower_even(outer_product[0,2] + outer_product[1,1] + outer_product[2,0] + z5 * 1/2)
            z7 = lower_even(outer_product[0,1] + outer_product[1,0] + z6 * 1/2)
            outputs.append([z7, z6, z5, z4, z3, 0, 0])
        return np.array(outputs)

    elif stage == 4:
        return outputs_prev

    elif stage == 5:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None
        
# Perfect parameters needed for the stages where a part of the NN performs perfectly

# Create the W1_perfect matrix of zeros with dimensions (8,16)
W1_perfect = np.zeros((8, 16))
# Introduce the correct numbers to multiply
for k in range(4):
    for i in range(4):
        W1_perfect[i, 12+i-k*4] = 1/2
        W1_perfect[4+i, 4*i:4*i+4] = 1/2

# Create the W2_perfect matrix of zeros with dimensions (16,28)
W2_perfect = np.zeros((16, 28))

# Correctly place the 7-bit vectors
for i in range(4):
    for j in range(4):
        W2_perfect[i*4 + j, i*8 + j] = 1

# R vectors of dimension (28,1)
R3_perfect = np.zeros((28))
R4_perfect = np.zeros((28))
R5_perfect = np.zeros((28))
R6_perfect = np.zeros((28))
R7_perfect = np.zeros((28))

for i in range(4):
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1

# Scalar parameters v
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((28,7))

for i in range(7):
    for j in range(4):
        T_perfect[7*j + i, i] = 1

# Parameter v7
v7_perfect = 1/2

# Neural network in every stage

def neural_network_1(params, x1, x2):
    W1, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    #vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return prev_vec

def neural_network_2(params, x1, x2):
    W1, W2 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return vec

def neural_network_3(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return jnp.array([z7, z6, z5, z4, z3, 0, 0])

def neural_network_4(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(jnp.dot(vec, T) + jnp.dot(z, v7))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y, param_reg = 0):
    pred = neural_network_1(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_2(params, x1, x2, y, param_reg = 0):
    pred = neural_network_2(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_3(params, x1, x2, y, param_reg = 0):
    pred = neural_network_3(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_4(params, x1, x2, y, param_reg = 0):
    pred = neural_network_4(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization


# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_1)(params, x1, x2, y, param_reg)
    step_loss = loss_1(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_2)(params, x1, x2, y, param_reg)
    step_loss = loss_2(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_3(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_3)(params, x1, x2, y, param_reg)
    step_loss = loss_3(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_4(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_4)(params, x1, x2, y, param_reg)
    step_loss = loss_4(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss


def decide_training(params, x1, x2, y, lr, stage, param_reg = 0):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 4:
        params, step_loss = update_params_4(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, param_reg = 0, lr=0.001, epochs=100, couples_included=[]):
    decimal_dataset = prepare_dataset(level, epochs, couples_included)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage, param_reg)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss


# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0, real_test=0):
    if real_test == 1:
        decimal_dataset = generate_test_dataset(n_max=12)
    else:
        decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    correct_predictions_count = 0
    test_size = inputs_1.shape[0]

    for i in range(test_size):
        prediction = predict(params, inputs_1[i], inputs_2[i], stage)
        #print(f'Se ha predicho {prediction} y era {outputs[i]}')
        if jnp.all(prediction == outputs[i]):  # Check if the prediction matches the expected output
            correct_predictions_count += 1  # Increment correct prediction count
        elif visualize_errors == 1:
            print(f'Ha fallado {decimal_dataset.iloc[i,0]} por {decimal_dataset.iloc[i,1]}.')
            #print(f'Se ha predicho {prediction} y era {outputs[i]}')
    return test_size, correct_predictions_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 4:
        binary_pred = neural_network_4(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    else:
        print('Bad index for the training stage.')
        return None


# Check if two models are equal
def are_models_equal(model_1, model_2):
    # Check that both lists have the same length
    if len(model_1) != len(model_2):
        return False

    # Compare each element in both lists
    for elem1, elem2 in zip(model_1, model_2):
        if isinstance(elem1, jnp.ndarray) and isinstance(elem2, jnp.ndarray):
            # Compare two JAX arrays
            if not jnp.all(jnp.isclose(elem1, elem2, atol=1e-2)):
                return False
        else:
            return False

    return True

def generate_model(mean=0.5, std=1):
    W1 = initialize_random_weights(mean, std, (8, 16))  # 128 neurons in the hidden layer that include element-wise multiplication
    W2 = initialize_random_weights(mean, std, (16, 28))  # 448 neurons in the hidden layer that sort the bits
    R3 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the second bit
    R4 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fourth bit
    R6 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fifth bit
    R7 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the sixth bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the second bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fourth bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fifth bit
    T = initialize_random_weights(mean, std, (28, 7))  # 196 neurons that allow performing the sum
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    trainable_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

def load_trainable_model(model, stage, fecha):
    # Ruta dinámica basada en el stage y la fecha
    model_path = f'Parameters/{model}_{stage}-{fecha}.pkl'
    
    # Cargar el archivo .pkl y asignarlo dinámicamente a trainable_model_stage_{stage}
    with open(model_path, 'rb') as f:
        globals()[f'trainable_model_stage_{stage}'] = pickle.load(f)
    
    # Confirmar la carga
    print(f'Model trainable_model_stage_{stage} loaded successfully.')
    return globals()[f'trainable_model_stage_{stage}']

# %%
AP_name = 'Generated_model'
folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Parameters/{AP_name}'
model = 'trainable_model_stage'

date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Parameters/{AP_name}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    h = 0.001 # Additional parameter needed for the two first stages
    training_stages = 5
    trainings_needed = np.zeros(training_stages)

    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    N=500

    for stage in range(1,5): 
        if stage == 1:
            trainable_model_stage_1 = [trainable_model[0], h]
        elif stage == 2:
            trainable_model_stage_2 = [trainable_model_stage_1[0], trainable_model[1]]
        elif stage == 3:
            trainable_model_stage_3 = [trainable_model_stage_2[0], 
                           trainable_model_stage_2[1], 
                           trainable_model[2], 
                           trainable_model[3], 
                           trainable_model[4], 
                           trainable_model[5], 
                           trainable_model[6], 
                           trainable_model[7], 
                           trainable_model[8], 
                           trainable_model[9], 
                           trainable_model[10]]
        elif stage == 4:
            trainable_model_stage_4 = [trainable_model_stage_3[0], 
                           trainable_model_stage_3[1], 
                           trainable_model_stage_3[2], 
                           trainable_model_stage_3[3], 
                           trainable_model_stage_3[4], 
                           trainable_model_stage_3[5], 
                           trainable_model_stage_3[6], 
                           trainable_model_stage_3[7], 
                           trainable_model_stage_3[8], 
                           trainable_model_stage_3[9], 
                           trainable_model_stage_3[10],
                           trainable_model[11],
                           trainable_model[12]
                          ]
        
        save_dir = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/{AP_name}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stagae-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_count == test_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        test_size = correct_predictions_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_11_07_23_51_21.pkl
# STAGE 1: Out of 100, 2 were predicted correctly in the current model.
# STAGE 1: Loss is 0.33913862705230713.
# STAGE 1: Out of 100, 5 were predicted correctly in the current model.
# STAGE 1: Loss is 0.16570448875427246.
# STAGE 1: Out of 100, 11 were predicted correctly in the current model.
# STAGE 1: Loss is 0.13284268975257874.
# STAGE 1: Out of 100, 18 were predicted correctly in the current model.
# STAGE 1: Loss is 0.10241413861513138.
# STAGE 1: Out of 100, 24 were predicted correctly in the current model.
# STAGE 1: Loss is 0.10406432300806046.
# STAGE 1: Out of 100, 26 were predicted correctly in the current model.
# STAGE 1: Loss is 0.09320684522390366.
# STAGE 1: Out of 100, 29 were predicted correctly in the current model.
# STAGE 1: Loss is 0.08643539994955063.
# STAGE 1: Out of 100, 33 were predicted correctly in the current model.
# STAGE 1: Loss is 0.08097650110721588.
# STAGE 1: Out of 100, 38 were predicted correctly in the current model.
# STAGE 1: Loss is 0.08181565999984741.
# STAGE 1: Out of 100, 39 were predicted correctly in the current model.
# STAGE 1: Loss is 0.06961282342672348.
# STAGE 1: Out of 100, 41 were predicted correctly in the current model.
# STAGE 1: Loss is 0.07080234587192535.
# STAGE 1: Out of 100, 41 were predicted correctly in the current model.
# STAGE 1: Loss is 0.06594241410493851.
# STAGE 1: Out of 100, 42 were predicted correctly in the current model.
# STAGE 1: Loss is 0.06637752801179886.
# STAGE 1: Out of 100, 48 were predicted correctly in the current model.
# STAGE 1: Loss is 0.06066462770104408.
# STAGE 1: Out of 100, 50 were predicted correctly in the current model.
# STAGE 1: Loss is 0.059891533106565475.
# STAGE 1: Out of 100, 50 were predicted correctly in the current model.
# STAGE 1: Loss is 0.055640265345573425.
# STAGE 1: Out of 100, 53 were predicted correctly in the current model.
# STAGE 1: Loss is 0.05707972124218941.
# STAGE 1: Out of 100, 54 were predicted correctly in the current model.
# STAGE 1: Loss is 0.05559176206588745.
# STAGE 1: Out of 100, 56 were predicted correctly in the current model.
# STAGE 1: Loss is 0.050825074315071106.
# STAGE 1: Out of 100, 61 were predicted correctly in the current model.
# STAGE 1: Loss is 0.050495706498622894.
# STAGE 1: Out of 100, 65 were predicted correctly in the current model.
# STAGE 1: Loss is 0.04973539337515831.
# STAGE 1: Out of 100, 70 were predicted correctly in the current model.
# STAGE 1: Loss is 0.046392619609832764.
# STAGE 1: Out of 100, 70 were predicted correctly in the current model.
# STAGE 1: Loss is 0.04446055740118027.
# STAGE 1: Out of 100, 71 were predicted correctly in the current model.
# STAGE 1: Loss is 0.04470628499984741.
# STAGE 1: Out of 100, 72 were predicted correctly in the current model.
# STAGE 1: Loss is 0.04113968461751938.
# STAGE 1: Out of 100, 72 were predicted correctly in the current model.
# STAGE 1: Loss is 0.03598868474364281.
# STAGE 1: Out of 100, 77 were predicted correctly in the current model.
# STAGE 1: Loss is 0.03343771770596504.
# STAGE 1: Out of 100, 78 were predicted correctly in the current model.
# STAGE 1: Loss is 0.033753249794244766.
# STAGE 1: Out of 100, 78 were predicted correctly in the current model.
# STAGE 1: Loss is 0.03309904783964157.
# STAGE 1: Out of 100, 78 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02934865839779377.
# STAGE 1: Out of 100, 78 were predicted correctly in the current model.
# STAGE 1: Loss is 0.028005290776491165.
# STAGE 1: Out of 100, 78 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02807801216840744.
# STAGE 1: Out of 100, 78 were predicted correctly in the current model.
# STAGE 1: Loss is 0.026397230103611946.
# STAGE 1: Out of 100, 82 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02393336407840252.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.024823492392897606.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.022441839799284935.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.023613322526216507.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.024966230615973473.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02205733023583889.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02043992467224598.
# STAGE 1: Out of 100, 86 were predicted correctly in the current model.
# STAGE 1: Loss is 0.020972931757569313.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.019739534705877304.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.020719848573207855.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.021192900836467743.
# STAGE 1: Out of 100, 89 were predicted correctly in the current model.
# STAGE 1: Loss is 0.019268039613962173.
# STAGE 1: Out of 100, 90 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01813715510070324.
# STAGE 1: Out of 100, 90 were predicted correctly in the current model.
# STAGE 1: Loss is 0.019353250041604042.
# STAGE 1: Out of 100, 90 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017520133405923843.
# STAGE 1: Out of 100, 90 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015533446334302425.
# STAGE 1: Out of 100, 95 were predicted correctly in the current model.
# STAGE 1: Loss is 0.014089479111135006.
# STAGE 1: Out of 100, 99 were predicted correctly in the current model.
# STAGE 1: Loss is 0.013344477862119675.
# STAGE 1: Out of 100, 100 were predicted correctly in the current model.
# STAGE 1: Loss is 0.012685608118772507.
# Objective completed
# Stage 1 completed in 520.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_1\trainable_model_stage_1-2024_11_07_23_51_21.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_1\Stage_1_results_2024_11_07_23_51_21.txt
# STAGE 2: Out of 100, 3 were predicted correctly in the current model.
# STAGE 2: Loss is 0.15842166543006897.
# STAGE 2: Out of 100, 8 were predicted correctly in the current model.
# STAGE 2: Loss is 0.10702955722808838.
# STAGE 2: Out of 100, 14 were predicted correctly in the current model.
# STAGE 2: Loss is 0.07947774231433868.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06508778780698776.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.059081073850393295.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05922679230570793.
# STAGE 2: Out of 100, 20 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0579787977039814.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05334505811333656.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05269878730177879.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05255291238427162.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05253894254565239.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05474359914660454.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05416085571050644.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.053946707397699356.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0

# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.043310754001140594.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.041933752596378326.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0421280674636364.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.041978832334280014.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04201418161392212.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04142092540860176.
# STAGE 2: Out of 100, 25 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0426366813480854.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04261825606226921.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.041412390768527985.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04339796304702759.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.042130742222070694.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04123691841959953.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04302248731255531.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04256492480635643.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04194243997335434.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.041225504130125046.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.041913826018571854.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.040159888565540314.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04167647287249565.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04296397417783737.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04109276831150055.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04120473191142082.
# STAGE 2: Out of 100, 30 were predicted correctly in the current model.
# STAGE 2: Loss is 0.042369261384010315.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04065794125199318.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04149624705314636.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04095694050192833.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.042419180274009705.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04049765318632126.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04054100811481476.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04277092218399048.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.038735222071409225.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.040193744003772736.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04161451756954193.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03880811482667923.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04031922295689583.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.039708226919174194.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.041573863476514816.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03999562934041023.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03962342441082001.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04133591055870056.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04020439088344574.
# STAGE 2: Out of 100, 27 were predicted correctly in the current model.
# STAGE 2: Loss is 0.039391614496707916.
# Stage 2 completed in 2500.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_2\trainable_model_stage_2-2024_11_07_23_51_21.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_2\Stage_2_results_2024_11_07_23_51_21.txt
# Loss is NaN
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_3\trainable_model_stage_3-2024_11_07_23_51_21.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_3\Stage_3_results_2024_11_07_23_51_21.txt
# Loss is NaN
# Stage 4 completed in 1.0 trainings.
# Model trainable_model_stage_4 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_4\trainable_model_stage_4-2024_11_07_23_51_21.pkl
# Results of Stage 4 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_4\Stage_4_results_2024_11_07_23_51_21.txt
# Loaded trainable_model_stage_2024_11_08_00_05_18.pkl
# STAGE 1: Out of 100, 1 were predicted correctly in the current model.
# STAGE 1: Loss is 0.34031087160110474.
# STAGE 1: Out of 100, 2 were predicted correctly in the current model.
# STAGE 1: Loss is 0.1667267233133316.
# STAGE 1: Out of 100, 11 were predicted correctly in the current model.
# STAGE 1: Loss is 0.120717354118824.
# STAGE 1: Out of 100, 16 were predicted correctly in the current model.
# STAGE 1: Loss is 0.09371780604124069.
# STAGE 1: Out of 100, 25 were predicted correctly in the current model.
# STAGE 1: Loss is 0.07854027301073074.
# STAGE 1: Out of 100, 34 were predicted correctly in the current model.
# STAGE 1: Loss is 0.061439938843250275.
# STAGE 1: Out of 100, 37 were predicted correctly in the current model.
# STAGE 1: Loss is 0.05669397488236427.
# STAGE 1: Out of 100, 43 were predicted correctly in the current model.
# STAGE 1: Loss is 0.04525665566325188.
# STAGE 1: Out of 100, 51 were predicted correctly in the current model.
# STAGE 1: Loss is 0.04004291445016861.
# STAGE 1: Out of 100, 61 were predicted correctly in the current model.
# STAGE 1: Loss is 0.03303384780883789.
# STAGE 1: Out of 100, 68 were predicted correctly in the current model.
# STAGE 1: Loss is 0.03012019209563732.
# STAGE 1: Out of 100, 72 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02778531424701214.
# STAGE 1: Out of 100, 75 were predicted correctly in the current model.
# STAGE 1: Loss is 0.025670742616057396.
# STAGE 1: Out of 100, 78 were predicted correctly in the current model.
# STAGE 1: Loss is 0.024628648534417152.
# STAGE 1: Out of 100, 79 were predicted correctly in the current model.
# STAGE 1: Loss is 0.022463252767920494.
# STAGE 1: Out of 100, 80 were predicted correctly in the current model.
# STAGE 1: Loss is 0.023109573870897293.
# STAGE 1: Out of 100, 81 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02053116448223591.
# STAGE 1: Out of 100, 82 were predicted correctly in the current model.
# STAGE 1: Loss is 0.020755669102072716.
# STAGE 1: Out of 100, 82 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01978999190032482.
# STAGE 1: Out of 100, 82 were predicted correctly in the current model.
# STAGE 1: Loss is 0.019595740363001823.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.019273508340120316.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01868698187172413.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017460692673921585.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.018765226006507874.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01766914688050747.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01838681288063526.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017956387251615524.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017592037096619606.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01779339462518692.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017430681735277176.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016061032190918922.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016805576160550117.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01884847693145275.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017136095091700554.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01555789913982153.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01852971501648426.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016623370349407196.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016567694023251534.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.018122490495443344.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017610110342502594.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015503555536270142.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015428082086145878.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015541874803602695.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015819214284420013.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016118153929710388.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016351452097296715.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01549187209457159.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016742950305342674.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016424426808953285.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017584791406989098.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015512494370341301.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01598704606294632.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015637027099728584.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015969043597579002.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015866203233599663.
# STAGE 1: Out of 100, 84 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01676923781633377.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015039793215692043.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.014146397821605206.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01685209758579731.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01650353893637657.
# STAGE 1: Out of 100, 87 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016197049990296364.
# STAGE 1: Out of 100, 87 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01663425751030445.
# STAGE 1: Out of 100, 87 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015383771620690823.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015813829377293587.
# STAGE 1: Out of 100, 87 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01664336584508419.
# STAGE 1: Out of 100, 89 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015054977498948574.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01511344499886036.
# STAGE 1: Out of 100, 87 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016741925850510597.
# STAGE 1: Out of 100, 85 were predicted correctly in the current model.
# STAGE 1: Loss is 0.014408065937459469.
# STAGE 1: Out of 100, 87 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015962272882461548.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.018104827031493187.
# STAGE 1: Out of 100, 89 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015184403397142887.
# STAGE 1: Out of 100, 89 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01699737459421158.
# STAGE 1: Out of 100, 91 were predicted correctly in the current model.
# STAGE 1: Loss is 0.017203520983457565.
# STAGE 1: Out of 100, 91 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01700402796268463.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015724385157227516.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01586056314408779.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015649210661649704.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01578790508210659.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.014614582993090153.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.016013719141483307.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.014958214946091175.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.014864329248666763.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.014591362327337265.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.0161331407725811.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015158958733081818.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01277848333120346.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.013885180465877056.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.013050603680312634.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.011112022213637829.
# STAGE 1: Out of 100, 95 were predicted correctly in the current model.
# STAGE 1: Loss is 0.011440261267125607.
# STAGE 1: Out of 100, 99 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01062055490911007.
# STAGE 1: Out of 100, 100 were predicted correctly in the current model.
# STAGE 1: Loss is 0.010021871887147427.
# Objective completed
# Stage 1 completed in 930.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_1\trainable_model_stage_1-2024_11_08_00_05_18.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/Generated_model/Stage_1\Stage_1_results_2024_11_08_00_05_18.txt
# STAGE 2: Out of 100, 2 were predicted correctly in the current model.
# STAGE 2: Loss is 0.19319644570350647.
# STAGE 2: Out of 100, 7 were predicted correctly in the current model.
# STAGE 2: Loss is 0.11695720255374908.
# STAGE 2: Out of 100, 17 were predicted correctly in the current model.
# STAGE 2: Loss is 0.08175672590732574.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0708170160651207.
# STAGE 2: Out of 100, 20 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06495390087366104.
# STAGE 2: Out of 100, 21 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06609689444303513.
# STAGE 2: Out of 100, 20 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06451462209224701.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06295192986726761.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06086612120270729.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06056121364235878.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.062064316123723984.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.059820469468832016.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.058749157935380936.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05829868093132973.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0560256689786911.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.056376248598098755.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05946088209748268.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.056728847324848175.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0589284747838974.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.057587139308452606.
# STAGE 2: Out of 100, 19 were predicted correctly in the current model.
# STAGE 2: Loss is 0.055255088955163956.
# ...
# STAGE 2: Loss is 0.046863213181495667.
# STAGE 2: Out of 100, 22 were predicted correctly in the current model.
# STAGE 2: Loss is 0.046727631241083145.
# STAGE 2: Out of 100, 22 were predicted correctly in the current model.
# STAGE 2: Loss is 0.046667397022247314.
# STAGE 2: Out of 100, 22 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04937214404344559.
# STAGE 2: Out of 100, 22 were predicted correctly in the current model.
# STAGE 2: Loss is 0.