# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import pytz
import os
import sys
import pickle
from datetime import datetime

# %%
# Define network parameters
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)
    
# We use a 2-degree polynomial function to approximate 0 and 1/2 to 0 and 1 stays in 1
def polynomial_function(x):
    return 2 * (x ** 2) - x

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return 0.5 * (1 - jnp.cos(jnp.pi * x))
    
# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size, n_max=10):
    # Generate two columns of random numbers between 0 and 9
    column_1 = np.random.randint(0, n_max, size)
    column_2 = np.random.randint(0, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_dataset_without_zeros(size, n_max=10):
    # Generate two columns of random numbers between 1 and 9
    column_1 = np.random.randint(1, n_max, size)
    column_2 = np.random.randint(1, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=10):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset


def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=4, bits_end=7):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        couples_not_included = [(3, 3), (5, 5), (6, 6), (7, 7), (9, 9), (3, 6), (3, 7), (6, 3), (7, 3), (5, 7), (7, 5), (6, 7), (7, 6)]
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(couples_not_included)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        column_1 = []
        column_2 = []
        pairs = [(5, 5), (9, 9)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 2:
        column_1 = []
        column_2 = []
        pairs = [(3, 3), (6, 6), (3, 6), (6, 3), (5, 7), (7, 5)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 3:
        column_1 = []
        column_2 = []
        pairs = [(3, 7), (6, 7), (7, 3), (7, 6)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 4:
        column_1 = [7] * size
        column_2 = [7] * size
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 5:
        column_1 = []
        column_2 = []
        pairs = [(3, 3), (5, 5), (6, 6), (7, 7), (9, 9), (3, 6), (3, 7), (6, 3), (7, 3), (5, 7), (7, 5), (6, 7), (7, 6)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, inputs_1, inputs_2, outputs_prev):
    if stage == 1:
        return np.array([np.outer(vec2, vec1).flatten() for vec1, vec2 in zip(inputs_1, inputs_2)])

    elif stage == 2:
        outputs = []
        matrix_step_2 = np.zeros((16, 28))
        for i in range(4):
            for j in range(4):
                matrix_step_2[i*4 + j, i*8 + j] = 1
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            flatten_vector = jnp.dot(outer_product.flatten(), matrix_step_2)
            outputs.append(flatten_vector)
        return np.array(outputs)

    elif stage == 3:
        outputs = []
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            z3 = lower_even(outer_product[2,3] + outer_product[3,2])
            z4 = lower_even(outer_product[1,3] + outer_product[2,2] + outer_product[3,1] + z3 * 1/2)
            z5 = lower_even(outer_product[0,3] + outer_product[1,2] + outer_product[2,1] + outer_product[3,0] + z4 * 1/2)
            z6 = lower_even(outer_product[0,2] + outer_product[1,1] + outer_product[2,0] + z5 * 1/2)
            z7 = lower_even(outer_product[0,1] + outer_product[1,0] + z6 * 1/2)
            outputs.append([z7, z6, z5, z4, z3, 0, 0])
        return np.array(outputs)

    elif stage == 4:
        return outputs_prev

    elif stage == 5:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None
        
# Perfect parameters needed for the stages where a part of the NN performs perfectly

# Create the W1_perfect matrix of zeros with dimensions (8,16)
W1_perfect = np.zeros((8, 16))
# Introduce the correct numbers to multiply
for k in range(4):
    for i in range(4):
        W1_perfect[i, 12+i-k*4] = 1/2
        W1_perfect[4+i, 4*i:4*i+4] = 1/2

# Create the W2_perfect matrix of zeros with dimensions (16,28)
W2_perfect = np.zeros((16, 28))

# Correctly place the 7-bit vectors
for i in range(4):
    for j in range(4):
        W2_perfect[i*4 + j, i*8 + j] = 1

# R vectors of dimension (28,1)
R3_perfect = np.zeros((28))
R4_perfect = np.zeros((28))
R5_perfect = np.zeros((28))
R6_perfect = np.zeros((28))
R7_perfect = np.zeros((28))

for i in range(4):
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1

# Scalar parameters v
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((28,7))

for i in range(7):
    for j in range(4):
        T_perfect[7*j + i, i] = 1

# Parameter v7
v7_perfect = 1/2

# Neural network in every stage

def neural_network_1(params, x1, x2):
    W1, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    #vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return prev_vec

def neural_network_2(params, x1, x2):
    W2, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return vec

def neural_network_3(params, x1, x2):
    R3, R4, R5, R6, R7, v3, v4, v5, v6 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2_perfect) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return jnp.array([z7, z6, z5, z4, z3, 0, 0])

def neural_network_4(params, x1, x2):
    T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1_perfect)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2_perfect) # vec is a (1,28) dimensional vector
    z3 = lower_even(relu(jnp.dot(vec, R3_perfect))) # z3 is a scalar with the second carry over
    z4 = lower_even(relu(jnp.dot(vec, R4_perfect) + jnp.dot(z3, v3_perfect))) # z4 is a scalar with the third carry over
    z5 = lower_even(relu(jnp.dot(vec, R5_perfect) + jnp.dot(z4, v4_perfect))) # z5 is a scalar with the fourth carry over
    z6 = lower_even(relu(jnp.dot(vec, R6_perfect) + jnp.dot(z5, v5_perfect))) # z6 is a scalar with the fifth carry over
    z7 = lower_even(relu(jnp.dot(vec, R7_perfect) + jnp.dot(z6, v6_perfect))) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return y

def neural_network_5(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(jnp.dot(vec, T) + jnp.dot(z, v7))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_4(params, x1, x2, y):
    pred = neural_network_4(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_5(params, x1, x2, y):
    pred = neural_network_5(params, x1, x2)
    return jnp.mean((pred - y)**2)


# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_4(params, x1, x2, y, lr):
    gradients = grad(loss_4)(params, x1, x2, y)
    step_loss = loss_4(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_5(params, x1, x2, y, lr):
    gradients = grad(loss_5)(params, x1, x2, y)
    step_loss = loss_5(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss


def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 4:
        params, step_loss = update_params_4(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 5:
        params, step_loss = update_params_5(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss


# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0, real_test=0):
    if real_test == 1:
        decimal_dataset = generate_test_dataset(n_max=12)
    else:
        decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    correct_predictions_count = 0
    test_size = inputs_1.shape[0]

    for i in range(test_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        #print(f'Se ha predicho {prediction} y era {outputs[i]}')
        if jnp.all(prediction == outputs[i]):  # Check if the prediction matches the expected output
            correct_predictions_count += 1  # Increment correct prediction count
        elif visualize_errors == 1:
            print(f'Ha fallado {decimal_dataset.iloc[i,0]} por {decimal_dataset.iloc[i,1]}.')
    return test_size, correct_predictions_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
    elif stage == 4:
        binary_pred = neural_network_4(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
    elif stage == 5:
        binary_pred = neural_network_5(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
    else:
        print('Bad index for the training stage.')
        return None


# Check if two models are equal
def are_models_equal(model_1, model_2):
    # Check that both lists have the same length
    if len(model_1) != len(model_2):
        return False

    # Compare each element in both lists
    for elem1, elem2 in zip(model_1, model_2):
        if isinstance(elem1, jnp.ndarray) and isinstance(elem2, jnp.ndarray):
            # Compare two JAX arrays
            if not jnp.all(jnp.isclose(elem1, elem2, atol=1e-2)):
                return False
        else:
            return False

    return True

# %%
def generate_model(epsilon_non_zeros = 0.01, epsilon_zeros = 0):
    W1_almost_perfect = np.zeros((8, 16)) + epsilon_zeros * np.random.randint(-10, 10)
    for k in range(4):
        for i in range(4):
            W1_almost_perfect[i, 12+i-k*4] = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
            W1_almost_perfect[4+i, 4*i:4*i+4] = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    W2_almost_perfect = np.zeros((16, 28)) + epsilon_zeros * np.random.randint(-10, 10)
    for i in range(4):
        for j in range(4):
            W2_almost_perfect[i*4 + j, i*8 + j] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    R3_almost_perfect = np.zeros((28)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((28)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((28)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((28)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((28)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(4):
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    T_almost_perfect = np.zeros((28,7)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(4):
            T_almost_perfect[7*j + i, i] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [W1_almost_perfect, 
                      W2_almost_perfect, 
                      R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, 
                      v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect,
                      T_almost_perfect, v7_almost_perfect]
    trainable_model = [W1_almost_perfect, 
                       W2_almost_perfect, 
                       R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, 
                       v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect,
                       T_almost_perfect, v7_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

def load_trainable_model(model, stage, date, epsilon_zeros = 0, epsilon_non_zeros = 0):
    model_path = f'Structured_Network/Stages/Model_almost_perfect_zeros_{epsilon_zeros}_non-zeros_{epsilon_non_zeros}/Stage_{stage}/{model}_{stage}-{date}.pkl'
    with open(model_path, 'rb') as f:
        globals()[f'{model}_{stage}'] = pickle.load(f)
    print(f'Model {model}_{stage} loaded successfully.')
    return globals()[f'{model}_{stage}']

# %%
iters = 15
epsilon_non_zeros = 0.1
epsilon_zeros = 0.1
model = 'trainable_model_stage'

for iteration in range(iters):
    trainable_model, original_model = generate_model(epsilon_non_zeros = epsilon_non_zeros, epsilon_zeros = epsilon_zeros)
    h = 0.001 # Additional parameter needed for the two first stages
    trainable_model_stage_1 = [trainable_model[0], h]
    trainable_model_stage_2 = [trainable_model[1], h]
    trainable_model_stage_3 = [trainable_model[2], trainable_model[3], trainable_model[4], trainable_model[5], trainable_model[6], trainable_model[7], trainable_model[8], trainable_model[9], trainable_model[10]]
    trainable_model_stage_4 = [trainable_model[11], trainable_model[12]]
    training_stages = 5
    trainings_needed = np.zeros(training_stages)
    folder_path = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Parameters_AP/AP_{epsilon_zeros}_{epsilon_non_zeros}"
    os.makedirs(folder_path, exist_ok=True) 
    
    current_time = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    file_path = os.path.join(folder_path, f"{model}_{current_time}.pkl")
    
    with open(file_path, 'wb') as file:
        pickle.dump(original_model, file)
    
    print(f'Saved file: {model}_{current_time}.pkl')

    visualizer = 10
    lr_changer = 250
    stage_changer = 2000
    N = 500

    for stage in range(1,5): 
        save_dir = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_{epsilon_zeros}_{epsilon_non_zeros}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee       
    
        try:
            test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break    
                    
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr.lower() == "no":
                #        pass
                #    elif new_lr != "":
                #        lr = float(new_lr)
                        
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                        
                if correct_predictions_count == test_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        test_size = correct_predictions_count + 1

            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"{model}_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model {model}_{stage} saved at {save_path}")
               
        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Saved file: trainable_model_stage_2024_11_08_00_06_04.pkl
# STAGE 1: Out of 100, 19 were predicted correctly in the current model.
# STAGE 1: Loss is 0.11382551491260529.
# STAGE 1: Out of 100, 62 were predicted correctly in the current model.
# STAGE 1: Loss is 0.05718415230512619.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.03834055736660957.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.029891345649957657.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02205708995461464.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.019330579787492752.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.01614702306687832.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.013261009007692337.
# STAGE 1: Out of 100, 94 were predicted correctly in the current model.
# STAGE 1: Loss is 0.011702854186296463.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.009528957307338715.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.009111919440329075.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.007319243159145117.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.006815832573920488.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.005251470021903515.
# STAGE 1: Out of 100, 97 were predicted correctly in the current model.
# STAGE 1: Loss is 0.005508679896593094.
# STAGE 1: Out of 100, 97 were predicted correctly in the current model.
# STAGE 1: Loss is 0.005209997296333313.
# STAGE 1: Out of 100, 99 were predicted correctly in the current model.
# STAGE 1: Loss is 0.005010299384593964.
# STAGE 1: Out of 100, 100 were predicted correctly in the current model.
# STAGE 1: Loss is 0.0047439029440283775.
# Objective completed
# Stage 1 completed in 180.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_08_00_06_04.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_08_00_06_04.txt
# STAGE 2: Out of 100, 30 were predicted correctly in the current model.
# STAGE 2: Loss is 0.7798349857330322.
# STAGE 2: Out of 100, 31 were predicted correctly in the current model.
# STAGE 2: Loss is 0.5616744756698608.
# STAGE 2: Out of 100, 41 were predicted correctly in the current model.
# STAGE 2: Loss is 0.3309970498085022.
# STAGE 2: Out of 100, 45 were predicted correctly in the current model.
# STAGE 2: Loss is 0.212482288479805.
# STAGE 2: Out of 100, 49 were predicted correctly in the current model.
# STAGE 2: Loss is 0.16823016107082367.
# STAGE 2: Out of 100, 57 were predicted correctly in the current model.
# STAGE 2: Loss is 0.1329261064529419.
# STAGE 2: Out of 100, 64 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0854392945766449.
# STAGE 2: Out of 100, 67 were predicted correctly in the current model.
# STAGE 2: Loss is 0.07816182076931.
# STAGE 2: Out of 100, 73 were predicted correctly in the current model.
# STAGE 2: Loss is 0.06573815643787384.
# STAGE 2: Out of 100, 73 were predicted correctly in the current model.
# STAGE 2: Loss is 0.053643424063920975.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0417894572019577.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.040766552090644836.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.033120494335889816.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03008156642317772.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.030291253700852394.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.024284308776259422.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02567351423203945.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02137184329330921.
# STAGE 2: Out of 100, 93 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019869240000844002.
# STAGE 2: Out of 100, 96 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01994529366493225.
# STAGE 2: Out of 100, 97 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016826599836349487.
# STAGE 2: Out of 100, 97 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01727304793894291.
# STAGE 2: Out of 100, 97 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016586266458034515.
# STAGE 2: Out of 100, 97 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013815001584589481.
# STAGE 2: Out of 100, 97 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013360343873500824.
# STAGE 2: Out of 100, 97 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012100378051400185.
# STAGE 2: Out of 100, 98 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010947478003799915.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010797502472996712.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009636121802031994.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008772718720138073.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008833001367747784.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.007518589962273836.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008119085803627968.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.007597348187118769.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.005637036636471748.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.006241681519895792.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0052033402025699615.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0054942043498158455.
# STAGE 2: Out of 100, 99 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0049171848222613335.
# STAGE 2: Out of 100, 100 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0047901649959385395.
# Objective completed
# Stage 2 completed in 400.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_08_00_06_04.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_08_00_06_04.txt
# STAGE 3: Out of 100, 24 were predicted correctly in the current model.
# STAGE 3: Loss is 0.6237276196479797.
# STAGE 3: Out of 100, 50 were predicted correctly in the current model.
# STAGE 3: Loss is 0.24185748398303986.
# STAGE 3: Out of 100, 56 were predicted correctly in the current model.
# STAGE 3: Loss is 0.18232126533985138.
# STAGE 3: Out of 100, 60 were predicted correctly in the current model.
# STAGE 3: Loss is 0.16376763582229614.
# STAGE 3: Out of 100, 66 were predicted correctly in the current model.
# STAGE 3: Loss is 0.1490936428308487.
# STAGE 3: Out of 100, 67 were predicted correctly in the current model.
# STAGE 3: Loss is 0.10428750514984131.
# STAGE 3: Out of 100, 72 were predicted correctly in the current model.
# STAGE 3: Loss is 0.09301294386386871.
# STAGE 3: Out of 100, 76 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0756053477525711.
# STAGE 3: Out of 100, 83 were predicted correctly in the current model.
# STAGE 3: Loss is 0.057638224214315414.
# STAGE 3: Out of 100, 89 were predicted correctly in the current model.
# STAGE 3: Loss is 0.041811466217041016.
# STAGE 3: Out of 100, 90 were predicted correctly in the current model.
# STAGE 3: Loss is 0.045256152749061584.
# STAGE 3: Out of 100, 93 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03563695400953293.
# STAGE 3: Out of 100, 93 were predicted correctly in the current model.
# STAGE 3: Loss is 0.034955427050590515.
# STAGE 3: Out of 100, 93 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03936869278550148.
# STAGE 3: Out of 100, 93 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04635847359895706.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03353528305888176.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04007904976606369.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.024729080498218536.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03263505548238754.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.026517171412706375.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03435043618083.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03701949864625931.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.040959399193525314.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03578317537903786.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.027315653860569.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.030201034620404243.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03528350591659546.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03618916496634483.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04009108617901802.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03076995722949505.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0470593087375164.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02860276959836483.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.027404647320508957.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.030421849340200424.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.021202344447374344.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.023049909621477127.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02199152298271656.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.031137540936470032.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.032096706330776215.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.034093305468559265.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.028897233307361603.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03093704581260681.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03393014520406723.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03501813858747482.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0369371734559536.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0214733574539423.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02555297128856182.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02757101133465767.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.029546737670898438.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03675886243581772.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.039758097380399704.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.034651778638362885.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.026372749358415604.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03348951041698456.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.025270719081163406.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03446422144770622.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.036516521126031876.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03138101100921631.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03339717537164688.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.026216847822070122.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.021052885800600052.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.024085985496640205.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03227657079696655.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03226260840892792.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.024044813588261604.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03631726652383804.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03326142951846123.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03525466471910477.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03629476577043533.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03118489682674408.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03730011731386185.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02910000830888748.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02496143989264965.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03420936316251755.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03215322643518448.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02293134294450283.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03109978325664997.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03210941702127457.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.019784627482295036.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.028020218014717102.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.025963911786675453.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0351630263030529.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.031038137152791023.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03410448133945465.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.027967289090156555.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02383243478834629.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.023881806060671806.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03001035936176777.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03819718956947327.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.028984935954213142.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.035123810172080994.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.039198826998472214.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04024496302008629.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02589128166437149.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.029987018555402756.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.027953460812568665.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02483667992055416.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03304321691393852.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.027924275025725365.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04227382689714432.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0330272801220417.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.020751405507326126.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04122913256287575.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.025847556069493294.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03301265463232994.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.037130314856767654.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.025881174951791763.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.026893924921751022.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03198383003473282.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.023799872025847435.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.031004121527075768.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.029976094141602516.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.021713491529226303.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.036068130284547806.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.025859059765934944.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03405849635601044.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03300517797470093.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.041204895824193954.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.029921755194664.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04017568379640579.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03505273163318634.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.037095725536346436.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03711380064487457.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.024833204224705696.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03095264919102192.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03300308808684349.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.026870954781770706.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03504202514886856.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03712678700685501.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.028941933065652847.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0340091846883297.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03098309598863125.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0329756885766983.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02682350017130375.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03915431722998619.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03200360760092735.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.039136163890361786.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.030948728322982788.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03604721650481224.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03709134832024574.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.030948583036661148.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02584717608988285.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03402623534202576.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.01867644488811493.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.034009914845228195.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.024840405210852623.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02783701755106449.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02580442652106285.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.036065760999917984.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.030946005135774612.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.021702582016587257.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02684018202126026.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03194304183125496.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.035005196928977966.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.026845084503293037.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.036042436957359314.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.030938470736145973.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04116370901465416.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.030872004106640816.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.025817718356847763.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.036104150116443634.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.027871862053871155.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.028866365551948547.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03300035372376442.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03194957599043846.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03299693018198013.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03298753499984741.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02581586129963398.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.038128457963466644.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03706112504005432.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02067747712135315.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.031982313841581345.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02167472429573536.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02681284211575985.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.020646044984459877.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.031957365572452545.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.028880130499601364.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03299805149435997.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03295750916004181.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.042220089584589005.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03094964660704136.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.0319499671459198.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03500818833708763.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.028882218524813652.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02480405382812023.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.04119693860411644.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03297211974859238.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02990373969078064.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03194015473127365.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.029913412407040596.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.018646232783794403.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.024762488901615143.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.022682717069983482.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03196775168180466.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03603258356451988.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.024784371256828308.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.029887598007917404.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.03195196017622948.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.02272966131567955.
# STAGE 3: Out of 100, 94 were predicted correctly in the current model.
# STAGE 3: Loss is 0.025816181674599648.
# Stage 3 completed in 2000.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_08_00_06_04.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_08_00_06_04.txt
# STAGE 4: Out of 100, 36 were predicted correctly in the current model.
# STAGE 4: Loss is 0.20383447408676147.
# STAGE 4: Out of 100, 36 were predicted correctly in the current model.
# STAGE 4: Loss is 0.21405039727687836.
# STAGE 4: Out of 100, 37 were predicted correctly in the current model.
# STAGE 4: Loss is 0.2069065421819687.
# STAGE 4: Out of 100, 38 were predicted correctly in the current model.
# STAGE 4: Loss is 0.17474032938480377.
# STAGE 4: Out of 100, 41 were predicted correctly in the current model.
# STAGE 4: Loss is 0.18897013366222382.
# STAGE 4: Out of 100, 43 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16104918718338013.
# STAGE 4: Out of 100, 43 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1664855182170868.
# STAGE 4: Out of 100, 44 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1740562617778778.
# STAGE 4: Out of 100, 48 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15221457183361053.
# STAGE 4: Out of 100, 49 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1437864750623703.
# STAGE 4: Out of 100, 49 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1620180755853653.
# STAGE 4: Out of 100, 49 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15470708906650543.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16153503954410553.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1734277755022049.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14095625281333923.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15991075336933136.
# STAGE 4: Out of 100, 48 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1529717743396759.
# STAGE 4: Out of 100, 49 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14039099216461182.
# STAGE 4: Out of 100, 49 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14015886187553406.
# STAGE 4: Out of 100, 49 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1477353274822235.
# STAGE 4: Out of 100, 49 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14026926457881927.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14062078297138214.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.151304692029953.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13816320896148682.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14920400083065033.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14535003900527954.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1394108533859253.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15670722723007202.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13478083908557892.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13109032809734344.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13499715924263.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13253255188465118.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13360567390918732.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12092795968055725.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12293246388435364.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12536147236824036.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11661295592784882.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11797609180212021.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1102074608206749.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09695981442928314.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10447253286838531.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10577181726694107.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10718464851379395.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10980386286973953.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09604145586490631.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09362923353910446.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09382685273885727.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11931899935007095.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09149986505508423.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09373484551906586.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08640630543231964.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09743008762598038.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09140601009130478.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09233657270669937.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09937135875225067.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08624126762151718.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09483176469802856.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07242544740438461.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08111099898815155.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08284477889537811.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08674921840429306.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07989499717950821.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06995940953493118.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07879549264907837.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07631011307239532.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07524577528238297.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07409998774528503.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07922782003879547.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08087795227766037.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07823684066534042.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08551498502492905.
# STAGE 4: Out of 100, 62 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07294150441884995.
# STAGE 4: Out of 100, 62 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07390230149030685.
# STAGE 4: Out of 100, 62 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07646183669567108.
# STAGE 4: Out of 100, 63 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06721028685569763.
# STAGE 4: Out of 100, 63 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07659891992807388.
# STAGE 4: Out of 100, 63 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06585551798343658.
# STAGE 4: Out of 100, 63 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06926825642585754.
# STAGE 4: Out of 100, 63 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07382546365261078.
# STAGE 4: Out of 100, 64 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06711699813604355.
# STAGE 4: Out of 100, 64 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07728233188390732.
# STAGE 4: Out of 100, 64 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07277507334947586.
# STAGE 4: Out of 100, 64 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06761484593153.
# STAGE 4: Out of 100, 64 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06740709394216537.
# STAGE 4: Out of 100, 65 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07033900916576385.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05559029057621956.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06427671760320663.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0630192756652832.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05506862699985504.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06089523434638977.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05898476764559746.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04755708947777748.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.059031836688518524.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.058087509125471115.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05265691503882408.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.047927774488925934.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05409841239452362.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05073181912302971.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.053312186151742935.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05386625975370407.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04566842317581177.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04804610088467598.
# STAGE 4: Out of 100, 69 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0542261004447937.
# STAGE 4: Out of 100, 70 were predicted correctly in the current model.
# STAGE 4: Loss is 0.044842809438705444.
# STAGE 4: Out of 100, 70 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04582276567816734.
# STAGE 4: Out of 100, 70 were predicted correctly in the current model.
# STAGE 4: Loss is 0.055519212037324905.
# STAGE 4: Out of 100, 72 were predicted correctly in the current model.
# STAGE 4: Loss is 0.035358015447854996.
# STAGE 4: Out of 100, 73 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05093783512711525.
# STAGE 4: Out of 100, 75 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03532479330897331.
# STAGE 4: Out of 100, 76 were predicted correctly in the current model.
# STAGE 4: Loss is 0.038684744387865067.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.043483078479766846.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.032889775931835175.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03731824457645416.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03569433093070984.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03335428237915039.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.034673720598220825.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03729688376188278.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0339018739759922.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03671197220683098.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.033225540071725845.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03750963136553764.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.041641149669885635.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03735010698437691.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.035926852375268936.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03332475945353508.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03781742602586746.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04464748874306679.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03266597166657448.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03835331276059151.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03379105404019356.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.032571133226156235.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04374207928776741.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.036553096026182175.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03427105024456978.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029090607538819313.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03884514421224594.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.041296619921922684.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0319737009704113.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03392735496163368.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029818115755915642.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03908433020114899.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.036708977073431015.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.035283152014017105.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0329703763127327.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03580687940120697.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03759513795375824.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.034950993955135345.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.037207283079624176.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03071153350174427.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03664721921086311.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0357886403799057.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03917105868458748.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03633894398808479.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03780177980661392.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0371343158185482.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03948940336704254.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04002418741583824.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03141281381249428.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.038574326783418655.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03741295263171196.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029165251180529594.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03632795438170433.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03314540162682533.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03854697570204735.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02972421795129776.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03999391198158264.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04223015159368515.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03824213519692421.
# ...
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16043619811534882.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16008801758289337.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16036631166934967.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.18388091027736664.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.17310850322246552.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16448743641376495.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.17601832747459412.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16954927146434784.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16263408958911896.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.18155859410762787.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15673688054084778.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16712872684001923.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16178688406944275.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.18217401206493378.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1699720323085785.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.17703822255134583.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.17316126823425293.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.17087377607822418.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16724815964698792.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16449859738349915.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1733647882938385.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.18160922825336456.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.17075179517269135.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16647666692733765.
# STAGE 4: Out of 100, 54 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16355901956558228.
# STAGE 4: Out of 100, 54 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16104979813098907.
# STAGE 4: Out of 100, 54 were predicted correctly in the current model.
# STAGE 4: Loss is 0.162950336933136.
# STAGE 4: Out of 100, 54 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1622312366962433.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15935198962688446.
# STAGE 4: Out of 100, 54 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16968576610088348.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1470228135585785.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.16075372695922852.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1524563431739807.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15534061193466187.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15055008232593536.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14139412343502045.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15348203480243683.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14587090909481049.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14743848145008087.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14052659273147583.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15204156935214996.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15744765102863312.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1441262811422348.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13492053747177124.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1380135715007782.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13635936379432678.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13970226049423218.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.15449760854244232.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1490134745836258.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14585435390472412.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14475290477275848.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1413213312625885.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13087198138237.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1375213861465454.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1486556977033615.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14290504157543182.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13270971179008484.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12690411508083344.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13121123611927032.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1344655454158783.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12849390506744385.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1385628581047058.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1371448040008545.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.125846728682518.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12836557626724243.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.14018604159355164.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1355879008769989.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13653069734573364.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12261714786291122.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11899934709072113.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13556735217571259.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13384774327278137.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12061372399330139.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1338283121585846.
# STAGE 4: Out of 100, 54 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13797536492347717.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13440057635307312.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12557728588581085.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13205775618553162.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1262158453464508.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1259455680847168.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13443468511104584.
# STAGE 4: Out of 100, 51 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12245287746191025.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12570740282535553.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13537631928920746.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11958557367324829.
# STAGE 4: Out of 100, 53 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13024556636810303.
# STAGE 4: Out of 100, 54 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1284395158290863.
# STAGE 4: Out of 100, 55 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1164180189371109.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10849028080701828.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10514567047357559.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11737224459648132.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11677791178226471.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10124637931585312.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10514067113399506.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09598442167043686.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.1009901911020279.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09991350769996643.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10715630650520325.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10306527465581894.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10165145248174667.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10743413865566254.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.098769910633564.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09925328195095062.
# STAGE 4: Out of 100, 56 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10564953088760376.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10481546819210052.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10676859319210052.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09837523847818375.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11041630059480667.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11381284892559052.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09993042796850204.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10885961353778839.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09322027117013931.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.11266680806875229.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09510117024183273.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10599933564662933.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09083280712366104.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10062896460294724.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09653245657682419.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10227690637111664.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10058905929327011.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10857727378606796.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09087223559617996.
# STAGE 4: Out of 100, 58 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08984871953725815.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08796750754117966.
# STAGE 4: Out of 100, 57 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09352607280015945.
# STAGE 4: Out of 100, 59 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08883509039878845.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08487490564584732.
# STAGE 4: Out of 100, 62 were predicted correctly in the current model.
# STAGE 4: Loss is 0.09168896079063416.
# STAGE 4: Out of 100, 61 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08459295332431793.
# STAGE 4: Out of 100, 63 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0856948122382164.
# STAGE 4: Out of 100, 62 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0797487124800682.
# STAGE 4: Out of 100, 65 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07240986078977585.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08459734171628952.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.08242367953062057.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07487772405147552.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07176026701927185.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0739877000451088.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05768853425979614.
# STAGE 4: Out of 100, 69 were predicted correctly in the current model.
# STAGE 4: Loss is 0.061922408640384674.
# STAGE 4: Out of 100, 71 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07240165024995804.
# STAGE 4: Out of 100, 72 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05555025860667229.
# STAGE 4: Out of 100, 72 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06028921157121658.
# STAGE 4: Out of 100, 74 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06317982822656631.
# Stage 4 completed in 2000.0 trainings.
# Model trainable_model_stage_4 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_4\trainable_model_stage_4-2024_11_08_01_34_46.pkl
# Results of Stage 4 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stages/AP_0.1_0.1/Stage_4\Stage_4_results_2024_11_08_01_34_46.txt

# %%
visualize_errors = 0
real_test = 1
stage = 5

test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, visualize_errors=visualize_errors, real_test=real_test)
print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
# Out:
# STAGE 5: Out of 144, 82 were predicted correctly in the current model.
