# %%
import pandas as pd
import numpy as np
import math
import re
from glob import glob

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import pytz
import os
import sys
import pickle
from datetime import datetime

# %%
# Define network parameters
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)
    
# We use a 2-degree polynomial function to approximate 0 and 1/2 to 0 and 1 stays in 1
def polynomial_function(x):
    return 2 * (x ** 2) - x

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return 0.5 * (1 - jnp.cos(jnp.pi * x))
    
# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size, n_max=10):
    # Generate two columns of random numbers between 0 and 9
    column_1 = np.random.randint(0, n_max, size)
    column_2 = np.random.randint(0, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_dataset_without_zeros(size, n_max=10):
    # Generate two columns of random numbers between 1 and 9
    column_1 = np.random.randint(1, n_max, size)
    column_2 = np.random.randint(1, n_max, size)

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=10):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']

    return dataset


def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=4, bits_end=7):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        couples_not_included = [(3, 3), (5, 5), (6, 6), (7, 7), (9, 9), (3, 6), (3, 7), (6, 3), (7, 3), (5, 7), (7, 5), (6, 7), (7, 6)]
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(couples_not_included)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        column_1 = []
        column_2 = []
        pairs = [(5, 5), (9, 9)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 2:
        column_1 = []
        column_2 = []
        pairs = [(3, 3), (6, 6), (3, 6), (6, 3), (5, 7), (7, 5)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 3:
        column_1 = []
        column_2 = []
        pairs = [(3, 7), (6, 7), (7, 3), (7, 6)]
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 4:
        column_1 = [7] * size
        column_2 = [7] * size
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 5:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, inputs_1, inputs_2, outputs_prev):
    if stage == 1:
        return np.array([np.outer(vec2, vec1).flatten() for vec1, vec2 in zip(inputs_1, inputs_2)])

    elif stage == 2:
        outputs = []
        matrix_step_2 = np.zeros((16, 28))
        for i in range(4):
            for j in range(4):
                matrix_step_2[i*4 + j, i*8 + j] = 1
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            flatten_vector = jnp.dot(outer_product.flatten(), matrix_step_2)
            outputs.append(flatten_vector)
        return np.array(outputs)

    elif stage == 3:
        outputs = []
        for vec1, vec2 in zip(inputs_1, inputs_2):
            outer_product = np.outer(vec2, vec1)
            z3 = lower_even(outer_product[2,3] + outer_product[3,2])
            z4 = lower_even(outer_product[1,3] + outer_product[2,2] + outer_product[3,1] + z3 * 1/2)
            z5 = lower_even(outer_product[0,3] + outer_product[1,2] + outer_product[2,1] + outer_product[3,0] + z4 * 1/2)
            z6 = lower_even(outer_product[0,2] + outer_product[1,1] + outer_product[2,0] + z5 * 1/2)
            z7 = lower_even(outer_product[0,1] + outer_product[1,0] + z6 * 1/2)
            outputs.append([z7, z6, z5, z4, z3, 0, 0])
        return np.array(outputs)

    elif stage == 4:
        return outputs_prev

    elif stage == 5:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None
        
# Perfect parameters needed for the stages where a part of the NN performs perfectly

# Create the W1_perfect matrix of zeros with dimensions (8,16)
W1_perfect = np.zeros((8, 16))
# Introduce the correct numbers to multiply
for k in range(4):
    for i in range(4):
        W1_perfect[i, 12+i-k*4] = 1/2
        W1_perfect[4+i, 4*i:4*i+4] = 1/2

# Create the W2_perfect matrix of zeros with dimensions (16,28)
W2_perfect = np.zeros((16, 28))

# Correctly place the 7-bit vectors
for i in range(4):
    for j in range(4):
        W2_perfect[i*4 + j, i*8 + j] = 1

# R vectors of dimension (28,1)
R3_perfect = np.zeros((28))
R4_perfect = np.zeros((28))
R5_perfect = np.zeros((28))
R6_perfect = np.zeros((28))
R7_perfect = np.zeros((28))

for i in range(4):
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1

# Scalar parameters v
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((28,7))

for i in range(7):
    for j in range(4):
        T_perfect[7*j + i, i] = 1

# Parameter v7
v7_perfect = 1/2

# Neural network in every stage

def neural_network_1(params, x1, x2):
    W1, h = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    #vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return prev_vec

def neural_network_2(params, x1, x2):
    W1, W2 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    #z3 = lower_even(relu(jnp.dot(vec, R3))) # z3 is a scalar with the second carry over
    #z4 = lower_even(relu(jnp.dot(vec, R4) + jnp.dot(z3, v3))) # z4 is a scalar with the third carry over
    #z5 = lower_even(relu(jnp.dot(vec, R5) + jnp.dot(z4, v4))) # z5 is a scalar with the fourth carry over
    #z6 = lower_even(relu(jnp.dot(vec, R6) + jnp.dot(z5, v5))) # z6 is a scalar with the fifth carry over
    #z7 = lower_even(relu(jnp.dot(vec, R7) + jnp.dot(z6, v6))) # z7 is a scalar with the seventh carry over
    #z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return vec

def neural_network_3(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return jnp.array([z7, z6, z5, z4, z3, 0, 0])

def neural_network_4(params, x1, x2):
    W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    prev_vec = polynomial_function(jnp.dot(x, W1)) # Multiplies values, prev_vec is a (1,8) matrix
    vec = jnp.dot(prev_vec, W2) # vec is a (1,28) dimensional vector
    z3 = lower_even(jnp.dot(vec, R3)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(vec, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(vec, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(vec, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(vec, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z7, z6, z5, z4, z3, 0, 0])
    y = differentiable_even_or_odd(jnp.dot(vec, T) + jnp.dot(z, v7))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y, param_reg = 0):
    pred = neural_network_1(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_2(params, x1, x2, y, param_reg = 0):
    pred = neural_network_2(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_3(params, x1, x2, y, param_reg = 0):
    pred = neural_network_3(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization

def loss_4(params, x1, x2, y, param_reg = 0):
    pred = neural_network_4(params, x1, x2)
    mse_loss = jnp.mean((pred - y)**2)
    regularization = jnp.sum(jnp.array([jnp.mean(jnp.square(param)) for param in params]))
    return mse_loss + param_reg * regularization


# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_1)(params, x1, x2, y, param_reg)
    step_loss = loss_1(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_2)(params, x1, x2, y, param_reg)
    step_loss = loss_2(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_3(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_3)(params, x1, x2, y, param_reg)
    step_loss = loss_3(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_4(params, x1, x2, y, lr, param_reg = 0):
    gradients = grad(loss_4)(params, x1, x2, y, param_reg)
    step_loss = loss_4(params, x1, x2, y, param_reg)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss


def decide_training(params, x1, x2, y, lr, stage, param_reg = 0):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 4:
        params, step_loss = update_params_4(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, param_reg = 0, lr=0.001, epochs=100, couples_included=[]):
    decimal_dataset = prepare_dataset(level, epochs, couples_included)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage, param_reg)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss


# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0, real_test=0):
    if real_test == 1:
        decimal_dataset = generate_test_dataset(n_max=12)
    else:
        decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    correct_predictions_count = 0
    test_size = inputs_1.shape[0]

    for i in range(test_size):
        prediction = predict(params, inputs_1[i], inputs_2[i], stage)
        #print(f'Se ha predicho {prediction} y era {outputs[i]}')
        if jnp.all(prediction == outputs[i]):  # Check if the prediction matches the expected output
            correct_predictions_count += 1  # Increment correct prediction count
        elif visualize_errors == 1:
            print(f'Ha fallado {decimal_dataset.iloc[i,0]} por {decimal_dataset.iloc[i,1]}.')
            #print(f'Se ha predicho {prediction} y era {outputs[i]}')
    return test_size, correct_predictions_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    elif stage == 4:
        binary_pred = neural_network_4(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred
    else:
        print('Bad index for the training stage.')
        return None


# Check if two models are equal
def are_models_equal(model_1, model_2):
    # Check that both lists have the same length
    if len(model_1) != len(model_2):
        return False

    # Compare each element in both lists
    for elem1, elem2 in zip(model_1, model_2):
        if isinstance(elem1, jnp.ndarray) and isinstance(elem2, jnp.ndarray):
            # Compare two JAX arrays
            if not jnp.all(jnp.isclose(elem1, elem2, atol=1e-2)):
                return False
        else:
            return False

    return True

def generate_model(mean=0.5, std=1):
    W1 = initialize_random_weights(mean, std, (8, 16))  # 128 neurons in the hidden layer that include element-wise multiplication
    W2 = initialize_random_weights(mean, std, (16, 28))  # 448 neurons in the hidden layer that sort the bits
    R3 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the second bit
    R4 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fourth bit
    R6 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the fifth bit
    R7 = initialize_random_weights(mean, std, (28))  # 28 neurons that correctly calculate the carry for the sixth bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the second bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fourth bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the fifth bit
    T = initialize_random_weights(mean, std, (28, 7))  # 196 neurons that allow performing the sum
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    trainable_model = [W1, W2, R3, R4, R5, R6, R7, v3, v4, v5, v6, T, v7]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

def load_trainable_model(model, stage, fecha):
    # Ruta dinámica basada en el stage y la fecha
    model_path = f'Parameters/{model}_{stage}-{fecha}.pkl'
    
    # Cargar el archivo .pkl y asignarlo dinámicamente a trainable_model_stage_{stage}
    with open(model_path, 'rb') as f:
        globals()[f'trainable_model_stage_{stage}'] = pickle.load(f)
    
    # Confirmar la carga
    print(f'Model trainable_model_stage_{stage} loaded successfully.')
    return globals()[f'trainable_model_stage_{stage}']

# %%
AP_name = 'AP_0.1_0.1'
folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Parameters/{AP_name}'
model = 'trainable_model_stage'

date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Parameters/{AP_name}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    h = 0.001 # Additional parameter needed for the two first stages
    training_stages = 5
    trainings_needed = np.zeros(training_stages)

    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    N=500

    for stage in range(1,5): 
        if stage == 1:
            trainable_model_stage_1 = [trainable_model[0], h]
        elif stage == 2:
            trainable_model_stage_2 = [trainable_model_stage_1[0], trainable_model[1]]
        elif stage == 3:
            trainable_model_stage_3 = [trainable_model_stage_2[0], 
                           trainable_model_stage_2[1], 
                           trainable_model[2], 
                           trainable_model[3], 
                           trainable_model[4], 
                           trainable_model[5], 
                           trainable_model[6], 
                           trainable_model[7], 
                           trainable_model[8], 
                           trainable_model[9], 
                           trainable_model[10]]
        elif stage == 4:
            trainable_model_stage_4 = [trainable_model_stage_3[0], 
                           trainable_model_stage_3[1], 
                           trainable_model_stage_3[2], 
                           trainable_model_stage_3[3], 
                           trainable_model_stage_3[4], 
                           trainable_model_stage_3[5], 
                           trainable_model_stage_3[6], 
                           trainable_model_stage_3[7], 
                           trainable_model_stage_3[8], 
                           trainable_model_stage_3[9], 
                           trainable_model_stage_3[10],
                           trainable_model[11],
                           trainable_model[12]
                          ]
        
        save_dir = f"D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/{AP_name}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_count} were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_count == test_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        test_size = correct_predictions_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_11_08_00_06_04.pkl
# STAGE 1: Out of 100, 19 were predicted correctly in the current model.
# STAGE 1: Loss is 0.11623084545135498.
# STAGE 1: Out of 100, 68 were predicted correctly in the current model.
# STAGE 1: Loss is 0.05080265551805496.
# STAGE 1: Out of 100, 83 were predicted correctly in the current model.
# STAGE 1: Loss is 0.03840753808617592.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02774602174758911.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02084185741841793.
# STAGE 1: Out of 100, 88 were predicted correctly in the current model.
# STAGE 1: Loss is 0.02083546668291092.
# STAGE 1: Out of 100, 89 were predicted correctly in the current model.
# STAGE 1: Loss is 0.015809547156095505.
# STAGE 1: Out of 100, 92 were predicted correctly in the current model.
# STAGE 1: Loss is 0.013724400661885738.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.010929333977401257.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.009593920782208443.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.008109699934720993.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.007729217875748873.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.006710229907184839.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.006259745452553034.
# STAGE 1: Out of 100, 96 were predicted correctly in the current model.
# STAGE 1: Loss is 0.005270014982670546.
# STAGE 1: Out of 100, 97 were predicted correctly in the current model.
# STAGE 1: Loss is 0.005142464302480221.
# STAGE 1: Out of 100, 99 were predicted correctly in the current model.
# STAGE 1: Loss is 0.004921314772218466.
# STAGE 1: Out of 100, 99 were predicted correctly in the current model.
# STAGE 1: Loss is 0.004878531210124493.
# STAGE 1: Out of 100, 100 were predicted correctly in the current model.
# STAGE 1: Loss is 0.00416136160492897.
# Objective completed
# Stage 1 completed in 190.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_08_00_06_04.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_08_00_06_04.txt
# STAGE 2: Out of 100, 23 were predicted correctly in the current model.
# STAGE 2: Loss is 0.05518126115202904.
# STAGE 2: Out of 100, 25 were predicted correctly in the current model.
# STAGE 2: Loss is 0.048323579132556915.
# STAGE 2: Out of 100, 25 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04781651869416237.
# STAGE 2: Out of 100, 25 were predicted correctly in the current model.
# STAGE 2: Loss is 0.044569119811058044.
# STAGE 2: Out of 100, 25 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04529077932238579.
# STAGE 2: Out of 100, 25 were predicted correctly in the current model.
# STAGE 2: Loss is 0.041687943041324615.
# STAGE 2: Out of 100, 25 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04343399778008461.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03723584860563278.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.04129139333963394.
# STAGE 2: Out of 100, 26 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03822587803006172.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03793647512793541.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.036162395030260086.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03556453064084053.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03483176976442337.
# STAGE 2: Out of 100, 28 were predicted correctly in the current model.
# STAGE 2: Loss is 0.031167959794402122.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03369487449526787.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.032700859010219574.
# STAGE 2: Out of 100, 29 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03114364854991436.
# STAGE 2: Out of 100, 31 were predicted correctly in the current model.
# STAGE 2: Loss is 0.03018873929977417.
# STAGE 2: Out of 100, 30 were predicted correctly in the current model.
# STAGE 2: Loss is 0.030556999146938324.
# STAGE 2: Out of 100, 31 were predicted correctly in the current model.
# STAGE 2: Loss is 0.030165717005729675.
# STAGE 2: Out of 100, 32 were predicted correctly in the current model.
# STAGE 2: Loss is 0.029230954125523567.
# STAGE 2: Out of 100, 34 were predicted correctly in the current model.
# STAGE 2: Loss is 0.028297536075115204.
# STAGE 2: Out of 100, 36 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02876528725028038.
# STAGE 2: Out of 100, 39 were predicted correctly in the current model.
# STAGE 2: Loss is 0.029037872329354286.
# STAGE 2: Out of 100, 39 were predicted correctly in the current model.
# STAGE 2: Loss is 0.027267297729849815.
# STAGE 2: Out of 100, 40 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02697088196873665.
# STAGE 2: Out of 100, 41 were predicted correctly in the current model.
# STAGE 2: Loss is 0.027246231213212013.
# STAGE 2: Out of 100, 45 were predicted correctly in the current model.
# STAGE 2: Loss is 0.026563603430986404.
# STAGE 2: Out of 100, 46 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02605520933866501.
# STAGE 2: Out of 100, 50 were predicted correctly in the current model.
# STAGE 2: Loss is 0.027162203565239906.
# STAGE 2: Out of 100, 50 were predicted correctly in the current model.
# STAGE 2: Loss is 0.024672674015164375.
# STAGE 2: Out of 100, 51 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02510169893503189.
# STAGE 2: Out of 100, 52 were predicted correctly in the current model.
# STAGE 2: Loss is 0.025262532755732536.
# STAGE 2: Out of 100, 53 were predicted correctly in the current model.
# STAGE 2: Loss is 0.024895604699850082.
# STAGE 2: Out of 100, 53 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02364945039153099.
# STAGE 2: Out of 100, 53 were predicted correctly in the current model.
# STAGE 2: Loss is 0.025138065218925476.
# STAGE 2: Out of 100, 55 were predicted correctly in the current model.
# STAGE 2: Loss is 0.024350252002477646.
# STAGE 2: Out of 100, 58 were predicted correctly in the current model.
# STAGE 2: Loss is 0.023755792528390884.
# STAGE 2: Out of 100, 58 were predicted correctly in the current model.
# STAGE 2: Loss is 0.021987631916999817.
# STAGE 2: Out of 100, 58 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0241998378187418.
# STAGE 2: Out of 100, 59 were predicted correctly in the current model.
# STAGE 2: Loss is 0.022848468273878098.
# STAGE 2: Out of 100, 60 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02143261395394802.
# STAGE 2: Out of 100, 60 were predicted correctly in the current model.
# STAGE 2: Loss is 0.022332211956381798.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02130141295492649.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.022178977727890015.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02221008390188217.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02108970656991005.
# STAGE 2: Out of 100, 62 were predicted correctly in the current model.
# STAGE 2: Loss is 0.020480137318372726.
# STAGE 2: Out of 100, 62 were predicted correctly in the current model.
# STAGE 2: Loss is 0.021577138453722.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02124905213713646.
# STAGE 2: Out of 100, 62 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02067776955664158.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02015550062060356.
# STAGE 2: Out of 100, 62 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02083413302898407.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.021384065970778465.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019843092188239098.
# STAGE 2: Out of 100, 61 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019564390182495117.
# STAGE 2: Out of 100, 62 were predicted correctly in the current model.
# STAGE 2: Loss is 0.020251329988241196.
# STAGE 2: Out of 100, 63 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019285723567008972.
# STAGE 2: Out of 100, 63 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019719751551747322.
# STAGE 2: Out of 100, 64 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01960843801498413.
# STAGE 2: Out of 100, 63 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01860210858285427.
# STAGE 2: Out of 100, 64 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018498659133911133.
# STAGE 2: Out of 100, 64 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019506223499774933.
# STAGE 2: Out of 100, 64 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0184642244130373.
# STAGE 2: Out of 100, 65 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01895342953503132.
# STAGE 2: Out of 100, 66 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018594294786453247.
# STAGE 2: Out of 100, 66 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017219824716448784.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017566939815878868.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017791178077459335.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017688829451799393.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017731791362166405.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017958924174308777.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01736762560904026.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017319869250059128.
# STAGE 2: Out of 100, 67 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016896046698093414.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0175457913428545.
# STAGE 2: Out of 100, 69 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01696527749300003.
# STAGE 2: Out of 100, 66 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01706700585782528.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01675478182733059.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017557434737682343.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016554955393075943.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016757013276219368.
# STAGE 2: Out of 100, 67 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01607569307088852.
# STAGE 2: Out of 100, 69 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016313064843416214.
# STAGE 2: Out of 100, 69 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01603422500193119.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016025502234697342.
# STAGE 2: Out of 100, 69 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015331453643739223.
# STAGE 2: Out of 100, 69 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016872268170118332.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016138901934027672.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014850129373371601.
# STAGE 2: Out of 100, 68 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015471738763153553.
# STAGE 2: Out of 100, 69 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016337310895323753.
# STAGE 2: Out of 100, 70 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0157120693475008.
# STAGE 2: Out of 100, 71 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015371530316770077.
# STAGE 2: Out of 100, 71 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014873230829834938.
# STAGE 2: Out of 100, 70 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015576771460473537.
# STAGE 2: Out of 100, 70 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01474965363740921.
# STAGE 2: Out of 100, 71 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0148551557213068.
# STAGE 2: Out of 100, 72 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015672845765948296.
# STAGE 2: Out of 100, 72 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013980112038552761.
# STAGE 2: Out of 100, 73 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014409049414098263.
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014475817792117596.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013782273046672344.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01454183179885149.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014466962777078152.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01520086731761694.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014426185749471188.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014390443451702595.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014597459696233273.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01330365426838398.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013738267123699188.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013921769335865974.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013307850807905197.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013521901331841946.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013296747580170631.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.014525421895086765.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013703321106731892.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013500586152076721.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013184959068894386.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013207308016717434.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012798642739653587.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012805236503481865.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01237485185265541.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012661376968026161.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01218658871948719.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013455837965011597.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012799722142517567.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013100916519761086.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012327725067734718.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012323174625635147.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.013169611804187298.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012526002712547779.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012661268934607506.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012385829351842403.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012174221687018871.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012509819120168686.
# STAGE 2: Out of 100, 86 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012735513970255852.
# STAGE 2: Out of 100, 86 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01176987774670124.
# STAGE 2: Out of 100, 86 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011974798515439034.
# STAGE 2: Out of 100, 87 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012021784670650959.
# STAGE 2: Out of 100, 87 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012158679775893688.
# STAGE 2: Out of 100, 87 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01193144079297781.
# STAGE 2: Out of 100, 88 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012949971482157707.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012156032957136631.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01234437245875597.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012085873633623123.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.012346596457064152.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011933756060898304.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011797601357102394.
# STAGE 2: Out of 100, 88 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011159144341945648.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011171631515026093.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011738468892872334.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011221633292734623.
# STAGE 2: Out of 100, 89 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011025059036910534.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01132858358323574.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011458403430879116.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01111065037548542.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011303244158625603.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01143585704267025.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010726585052907467.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010806692764163017.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011092421598732471.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010604136623442173.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011808649636805058.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010615535080432892.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01074391882866621.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011015093885362148.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01110679842531681.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011292770504951477.
# STAGE 2: Out of 100, 90 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011492246761918068.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010714809410274029.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011303646489977837.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010985162109136581.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011261273175477982.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010685079731047153.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01102075818926096.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010988353751599789.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010926839895546436.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010793125256896019.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01042698509991169.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010468470863997936.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010129808448255062.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01082882285118103.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010246144607663155.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010294876992702484.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010257551446557045.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010590006597340107.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01034263800829649.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.011304523795843124.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010103217326104641.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010515209287405014.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010376904159784317.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010339190252125263.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010751831345260143.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010549618862569332.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010807943530380726.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01034857239574194.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009682987816631794.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010777375660836697.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010477282106876373.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010166540741920471.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01021855603903532.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010339902713894844.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009899388067424297.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009709563106298447.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.00991235114634037.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009378868155181408.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009895272552967072.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009589697234332561.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010212034918367863.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009880033321678638.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009383389726281166.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009723170660436153.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009766713716089725.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010306666605174541.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009606419131159782.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009923809207975864.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.00993664562702179.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010279407724738121.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.010214823298156261.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.00983017310500145.
# STAGE 2: Out of 100, 91 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009250798262655735.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009650537744164467.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.00991459283977747.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009473001584410667.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009387077763676643.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009555279277265072.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009642495773732662.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0095907561480999.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009398735128343105.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009373093955218792.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009322142228484154.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009270453825592995.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009509164839982986.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009707619436085224.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009524570778012276.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.00974234938621521.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009145667776465416.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009203565306961536.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009640608914196491.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008986514993011951.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009390517137944698.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008894546888768673.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008797289803624153.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008974170312285423.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008570377714931965.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008987625129520893.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.009054861031472683.
# STAGE 2: Out of 100, 92 were predicted correctly in the current model.
# STAGE 2: Loss is 0.008589664474129677.
# Stage 2 completed in 2500.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_08_00_06_04.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_08_00_06_04.txt
# Loss is NaN
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_08_00_06_04.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_08_00_06_04.txt
# STAGE 4: Out of 100, 4 were predicted correctly in the current model.
# STAGE 4: Loss is 0.3447861671447754.
# STAGE 4: Out of 100, 7 were predicted correctly in the current model.
# STAGE 4: Loss is 0.33887070417404175.
# STAGE 4: Out of 100, 11 were predicted correctly in the current model.
# STAGE 4: Loss is 0.2785252630710602.
# STAGE 4: Out of 100, 35 were predicted correctly in the current model.
# STAGE 4: Loss is 0.13657507300376892.
# STAGE 4: Out of 100, 48 were predicted correctly in the current model.
# STAGE 4: Loss is 0.10908540338277817.
# STAGE 4: Out of 100, 37 were predicted correctly in the current model.
# STAGE 4: Loss is 0.12441147863864899.
# STAGE 4: Out of 100, 52 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07807699590921402.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07388465106487274.
# STAGE 4: Out of 100, 60 were predicted correctly in the current model.
# STAGE 4: Loss is 0.060376860201358795.
# STAGE 4: Out of 100, 65 were predicted correctly in the current model.
# STAGE 4: Loss is 0.058952461928129196.
# STAGE 4: Out of 100, 65 were predicted correctly in the current model.
# STAGE 4: Loss is 0.060148194432258606.
# STAGE 4: Out of 100, 71 were predicted correctly in the current model.
# STAGE 4: Loss is 0.060171082615852356.
# STAGE 4: Out of 100, 71 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06505724787712097.
# STAGE 4: Out of 100, 64 were predicted correctly in the current model.
# STAGE 4: Loss is 0.054297883063554764.
# STAGE 4: Out of 100, 73 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05580576881766319.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0645979568362236.
# STAGE 4: Out of 100, 69 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05754802003502846.
# STAGE 4: Out of 100, 71 were predicted correctly in the current model.
# STAGE 4: Loss is 0.06415284425020218.
# STAGE 4: Out of 100, 75 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05646238476037979.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04519926384091377.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04501762613654137.
# STAGE 4: Out of 100, 72 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05255090072751045.
# STAGE 4: Out of 100, 75 were predicted correctly in the current model.
# STAGE 4: Loss is 0.053777508437633514.
# STAGE 4: Out of 100, 69 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05464146286249161.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.057319462299346924.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05637741461396217.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.051003631204366684.
# STAGE 4: Out of 100, 72 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03985615819692612.
# STAGE 4: Out of 100, 69 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05299370363354683.
# STAGE 4: Out of 100, 70 were predicted correctly in the current model.
# STAGE 4: Loss is 0.045578598976135254.
# STAGE 4: Out of 100, 74 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04538258910179138.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0511777363717556.
# STAGE 4: Out of 100, 64 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05006980523467064.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.047128334641456604.
# STAGE 4: Out of 100, 76 were predicted correctly in the current model.
# STAGE 4: Loss is 0.048852380365133286.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.040112484246492386.
# STAGE 4: Out of 100, 71 were predicted correctly in the current model.
# STAGE 4: Loss is 0.05562182515859604.
# STAGE 4: Out of 100, 75 were predicted correctly in the current model.
# STAGE 4: Loss is 0.052402570843696594.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04109738767147064.
# STAGE 4: Out of 100, 84 were predicted correctly in the current model.
# STAGE 4: Loss is 0.036428194493055344.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04549620673060417.
# STAGE 4: Out of 100, 69 were predicted correctly in the current model.
# STAGE 4: Loss is 0.07758759707212448.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04515943303704262.
# STAGE 4: Out of 100, 66 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04699203744530678.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04094270244240761.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04036818817257881.
# STAGE 4: Out of 100, 77 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04003934934735298.
# STAGE 4: Out of 100, 77 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04032456874847412.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04030000418424606.
# STAGE 4: Out of 100, 73 were predicted correctly in the current model.
# STAGE 4: Loss is 0.046117622405290604.
# STAGE 4: Out of 100, 75 were predicted correctly in the current model.
# STAGE 4: Loss is 0.042368125170469284.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04053191468119621.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03471594676375389.
# STAGE 4: Out of 100, 74 were predicted correctly in the current model.
# STAGE 4: Loss is 0.039751727133989334.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.036197230219841.
# STAGE 4: Out of 100, 75 were predicted correctly in the current model.
# STAGE 4: Loss is 0.038157109171152115.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03546068072319031.
# STAGE 4: Out of 100, 76 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03710794821381569.
# STAGE 4: Out of 100, 67 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03967536613345146.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.036907728761434555.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04495306685566902.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04320238158106804.
# STAGE 4: Out of 100, 73 were predicted correctly in the current model.
# STAGE 4: Loss is 0.042196474969387054.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03812270238995552.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03422044590115547.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03714939206838608.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04115733504295349.
# STAGE 4: Out of 100, 88 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03802214190363884.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.034546516835689545.
# STAGE 4: Out of 100, 68 were predicted correctly in the current model.
# STAGE 4: Loss is 0.042747460305690765.
# STAGE 4: Out of 100, 77 were predicted correctly in the current model.
# STAGE 4: Loss is 0.037046171724796295.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03402600437402725.
# STAGE 4: Out of 100, 77 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03393791615962982.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0317576639354229.
# STAGE 4: Out of 100, 86 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0305064357817173.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03554648160934448.
# STAGE 4: Out of 100, 77 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04383164644241333.
# STAGE 4: Out of 100, 74 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03520689904689789.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.04003371670842171.
# STAGE 4: Out of 100, 86 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0338423028588295.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03288764879107475.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03597509488463402.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03776656091213226.
# STAGE 4: Out of 100, 62 were predicted correctly in the current model.
# STAGE 4: Loss is 0.037062179297208786.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0333208367228508.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029650313779711723.
# STAGE 4: Out of 100, 72 were predicted correctly in the current model.
# STAGE 4: Loss is 0.028340540826320648.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.039081502705812454.
# STAGE 4: Out of 100, 73 were predicted correctly in the current model.
# STAGE 4: Loss is 0.030056152492761612.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029548557475209236.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0319272056221962.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03102019429206848.
# STAGE 4: Out of 100, 89 were predicted correctly in the current model.
# STAGE 4: Loss is 0.031767670065164566.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03699231892824173.
# STAGE 4: Out of 100, 84 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03727371618151665.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.024967949837446213.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.038958579301834106.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.027309728786349297.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.025803932920098305.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.030016068369150162.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03624682128429413.
# STAGE 4: Out of 100, 89 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03104034624993801.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03155981004238129.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.030352110043168068.
# STAGE 4: Out of 100, 78 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03453893959522247.
# STAGE 4: Out of 100, 88 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03331694006919861.
# STAGE 4: Out of 100, 88 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029742073267698288.
# STAGE 4: Out of 100, 71 were predicted correctly in the current model.
# STAGE 4: Loss is 0.026776323094964027.
# STAGE 4: Out of 100, 86 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029207950457930565.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.026233067736029625.
# STAGE 4: Out of 100, 86 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03350343555212021.
# STAGE 4: Out of 100, 84 were predicted correctly in the current model.
# STAGE 4: Loss is 0.032089896500110626.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.025086302310228348.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0333094485104084.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.028482208028435707.
# STAGE 4: Out of 100, 92 were predicted correctly in the current model.
# STAGE 4: Loss is 0.028414035215973854.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.039023030549287796.
# STAGE 4: Out of 100, 84 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02669973112642765.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.027019169181585312.
# STAGE 4: Out of 100, 84 were predicted correctly in the current model.
# STAGE 4: Loss is 0.025934170931577682.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03154804930090904.
# STAGE 4: Out of 100, 90 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02296198531985283.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.038649171590805054.
# STAGE 4: Out of 100, 89 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029725942760705948.
# STAGE 4: Out of 100, 91 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02771058864891529.
# STAGE 4: Out of 100, 74 were predicted correctly in the current model.
# STAGE 4: Loss is 0.028959782794117928.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03086957521736622.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03708917275071144.
# STAGE 4: Out of 100, 86 were predicted correctly in the current model.
# STAGE 4: Loss is 0.033938851207494736.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02846280299127102.
# STAGE 4: Out of 100, 88 were predicted correctly in the current model.
# STAGE 4: Loss is 0.029109323397278786.
# STAGE 4: Out of 100, 84 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03138761967420578.
# STAGE 4: Out of 100, 77 were predicted correctly in the current model.
# STAGE 4: Loss is 0.028995513916015625.
# STAGE 4: Out of 100, 74 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02212357148528099.
# STAGE 4: Out of 100, 79 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02757249027490616.
# STAGE 4: Out of 100, 91 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02194494754076004.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0290568545460701.
# STAGE 4: Out of 100, 88 were predicted correctly in the current model.
# STAGE 4: Loss is 0.0309143103659153.
# STAGE 4: Out of 100, 75 were predicted correctly in the current model.
# STAGE 4: Loss is 0.025475235655903816.
# STAGE 4: Out of 100, 90 were predicted correctly in the current model.
# STAGE 4: Loss is 0.026044562458992004.
# STAGE 4: Out of 100, 81 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03143952414393425.
# STAGE 4: Out of 100, 91 were predicted correctly in the current model.
# STAGE 4: Loss is 0.021508578211069107.
# STAGE 4: Out of 100, 91 were predicted correctly in the current model.
# STAGE 4: Loss is 0.028454221785068512.
# STAGE 4: Out of 100, 83 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03131113946437836.
# STAGE 4: Out of 100, 88 were predicted correctly in the current model.
# STAGE 4: Loss is 0.027171272784471512.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.025476565584540367.
# STAGE 4: Out of 100, 87 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03285191208124161.
# STAGE 4: Out of 100, 90 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02713244967162609.
# STAGE 4: Out of 100, 88 were predicted correctly in the current model.
# STAGE 4: Loss is 0.02498377300798893.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.026231635361909866.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.023942183703184128.
# STAGE 4: Out of 100, 85 were predicted correctly in the current model.
# STAGE 4: Loss is 0.023894567042589188.
# STAGE 4: Out of 100, 93 were predicted correctly in the current model.
# STAGE 4: Loss is 0.023970870301127434.
# STAGE 4: Out of 100, 80 were predicted correctly in the current model.
# STAGE 4: Loss is 0.026937322691082954.
# STAGE 4: Out of 100, 82 were predicted correctly in the current model.
# STAGE 4: Loss is 0.03218991681933403.
# STAGE 4: Out of 100, 91 were predicted correctly in the current model.
# ...
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01998087577521801.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.020438389852643013.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.02042875811457634.
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.020401861518621445.
# STAGE 2: Out of 100, 73 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019633516669273376.
# STAGE 2: Out of 100, 73 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018825791776180267.
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018688790500164032.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.020000364631414413.
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018687069416046143.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019862568005919456.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01936640590429306.
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01971876248717308.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018893243744969368.
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01866450160741806.
# STAGE 2: Out of 100, 73 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019017722457647324.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018983708694577217.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018464399501681328.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019135715439915657.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019324764609336853.
# STAGE 2: Out of 100, 75 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019014297053217888.
# STAGE 2: Out of 100, 74 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018565716221928596.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018819237127900124.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01900322549045086.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01966099999845028.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018820160999894142.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01963568665087223.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01909857802093029.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017911700531840324.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019223803654313087.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018883921205997467.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018060432747006416.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018763596192002296.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018332399427890778.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01787995919585228.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019397206604480743.
# STAGE 2: Out of 100, 77 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018530752509832382.
# STAGE 2: Out of 100, 76 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018686478957533836.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01844291016459465.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017757656052708626.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018547581508755684.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.019137423485517502.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01845376566052437.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018050815910100937.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0188135989010334.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017934365198016167.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01815040223300457.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018321862444281578.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017485199496150017.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01810525357723236.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018445812165737152.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01827687956392765.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01762775331735611.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018051257357001305.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017884643748402596.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017003992572426796.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017366807907819748.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01815836690366268.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.018100624904036522.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017484841868281364.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017620500177145004.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01685357838869095.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017304884269833565.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0179526899009943.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01713264361023903.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01679818704724312.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017736466601490974.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017663877457380295.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017110494896769524.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016766991466283798.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01692371815443039.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017746521160006523.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01805322803556919.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017873194068670273.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016706662252545357.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017240474000573158.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016488777473568916.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01663084141910076.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01686861924827099.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016597000882029533.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016819387674331665.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01689653843641281.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01713288575410843.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016532961279153824.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01684003882110119.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01735122688114643.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017026443034410477.
# STAGE 2: Out of 100, 78 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017871839925646782.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01673579029738903.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016828296706080437.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017166700214147568.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01688310317695141.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01677100360393524.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017388707026839256.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016773181036114693.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016067063435912132.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016589121893048286.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016590962186455727.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01678432896733284.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01706351712346077.
# STAGE 2: Out of 100, 79 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01616622880101204.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017344022169709206.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01701732724905014.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016521181911230087.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016520684584975243.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01657920889556408.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015913212671875954.
# STAGE 2: Out of 100, 80 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015175807289779186.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.017024004831910133.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016107741743326187.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01605241186916828.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016678931191563606.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016079174354672432.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016283538192510605.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01659441366791725.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016386764124035835.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01619783230125904.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01628687232732773.
# STAGE 2: Out of 100, 82 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016073131933808327.
# STAGE 2: Out of 100, 81 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016554035246372223.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015954764559864998.
# STAGE 2: Out of 100, 85 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01623896323144436.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016888614743947983.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016095289960503578.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016015760600566864.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015867216512560844.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.0173023771494627.
# STAGE 2: Out of 100, 85 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016184329986572266.
# STAGE 2: Out of 100, 85 were predicted correctly in the current model.
# STAGE 2: Loss is 0.016383172944188118.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015627378597855568.
# STAGE 2: Out of 100, 83 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01592930406332016.
# STAGE 2: Out of 100, 85 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015590721741318703.
# STAGE 2: Out of 100, 84 were predicted correctly in the current model.
# STAGE 2: Loss is 0.01646888442337513.
# STAGE 2: Out of 100, 85 were predicted correctly in the current model.
# STAGE 2: Loss is 0.015666773542761803.
# Stage 2 completed in 2500.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_08_01_34_46.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_08_01_34_46.txt
# Loss is NaN
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_08_01_34_46.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_08_01_34_46.txt
# Loss is NaN
# Stage 4 completed in 2.0 trainings.
# Model trainable_model_stage_4 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_4\trainable_model_stage_4-2024_11_08_01_34_46.pkl
# Results of Stage 4 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Trained_models/Stage_by_stage/AP_0.1_0.1/Stage_4\Stage_4_results_2024_11_08_01_34_46.txt
