# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Super_Easy_Multidigit_Addition_Decimal/'
folder_specific = f'{folder}v1-Balanced_Frequencies/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model(f'{folder}Modules/unit_addition_module.keras')
unit_carry_model = load_model(f'{folder}Modules/unit_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        y_data.append([sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    carry_unit_val = {}
    unit_val = {}

    for i, j in [(0, 2), (1, 3)]:
        units_inputs = jnp.array(x[:, [i, j]])
        units_input = units_inputs[:, None, :]
    
        unit_output = jnp.array(unit_addition_model(units_input))
        unit_carry_output = jnp.array(unit_carry_model(units_input))
    
        unit_val[f'{i}_{j}'] = jnp.argmax(unit_output, axis=-1)
        carry_unit_val[f'{i}_{j}'] = jnp.argmax(unit_carry_output, axis=-1)
    
    salida_1 = sum(
        params[f'v_0_1_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_1_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i, j in [(0, 2), (1, 3)]
    )
    
    salida_2 = sum(
        params[f'v_0_2_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_2_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i, j in [(0, 2), (1, 3)]
    )

    return salida_1, salida_2

# %%
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
epsilons = [0.1, 0.2, 0.3, 0.5, 0.7,
            1, 1.5,
            2, 2.5,
            3, 
            5, 7.5,
            10
           ]

# %%
x_test, y_test = generate_test_dataset()
param_type = 'AP'

for epsilon in epsilons:
    print(f'Iniciado {epsilon}.')
    
    save_dir = f"{folder_specific}Tests/"
    folder_path = f'{folder_specific}Trained_models/{param_type}_{epsilon}'
    date_pattern = r'trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
    files = sorted(
        (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
        key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
    )
    
    os.makedirs(save_dir, exist_ok=True) 
    results_file = os.path.join(save_dir, f"Tests_{param_type}_{epsilon}.txt") 
    tee = Tee(results_file, 'w') 
    sys.stdout = tee
    
    try:
        for filename in files:
            match = re.search(date_pattern, filename)
            if match:
                current_time = match.group(1)
            else:
                print('Error')
                break
            
            file_path = f"{folder_path}/trained_model_{current_time}.json"
            with open(file_path, 'rb') as file:
                trained_model = json.load(file)
        
            trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
            print(f'Loaded trained_model_{current_time}.json')
    
            predictions(trained_model_jnp, x_test, y_test)
        
    finally:
        sys.stdout = tee.console
        tee.close()

    print(f'Finalizado {epsilon}.')
# Out:
# Iniciado 0.1.
# Loaded trained_model_2025_01_21_01_12_17.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_19.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_21.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_23.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_25.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_27.json
# Out of 5050, 4876 predictions correct.
# Out of 4858, 4728 train predictions correct.
# Out of 2025, 1851 carry-over predictions correct.
# Out of 1929, 1799 carry-over train predictions correct.
# Out of 820, 658 small predictions correct.
# Out of 724, 606 small train predictions correct.
# Out of 270, 108 carry-over small predictions correct.
# Out of 222, 104 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_29.json
# Out of 5050, 4999 predictions correct.
# Out of 4858, 4827 train predictions correct.
# Out of 2025, 1974 carry-over predictions correct.
# Out of 1929, 1898 carry-over train predictions correct.
# Out of 820, 769 small predictions correct.
# Out of 724, 693 small train predictions correct.
# Out of 270, 219 carry-over small predictions correct.
# Out of 222, 191 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_31.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_33.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_35.json
# Out of 5050, 4915 predictions correct.
# Out of 4858, 4757 train predictions correct.
# Out of 2025, 1890 carry-over predictions correct.
# Out of 1929, 1828 carry-over train predictions correct.
# Out of 820, 689 small predictions correct.
# Out of 724, 627 small train predictions correct.
# Out of 270, 139 carry-over small predictions correct.
# Out of 222, 125 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.1.
# Iniciado 0.2.
# Loaded trained_model_2025_01_21_01_12_37.json
# Out of 5050, 4447 predictions correct.
# Out of 4858, 4307 train predictions correct.
# Out of 2025, 1482 carry-over predictions correct.
# Out of 1929, 1438 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 3081 large predictions correct.
# Out of 3063, 2989 large train predictions correct.
# Out of 1296, 1278 carry-over large predictions correct.
# Out of 1248, 1234 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_39.json
# Out of 5050, 3301 predictions correct.
# Out of 4858, 3185 train predictions correct.
# Out of 2025, 795 carry-over predictions correct.
# Out of 1929, 763 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2139 large predictions correct.
# Out of 3063, 2071 large train predictions correct.
# Out of 1296, 795 carry-over large predictions correct.
# Out of 1248, 763 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_41.json
# Out of 5050, 2424 predictions correct.
# Out of 4858, 2330 train predictions correct.
# Out of 2025, 543 carry-over predictions correct.
# Out of 1929, 523 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1269 large predictions correct.
# Out of 3063, 1223 large train predictions correct.
# Out of 1296, 543 carry-over large predictions correct.
# Out of 1248, 523 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_43.json
# Out of 5050, 2817 predictions correct.
# Out of 4858, 2711 train predictions correct.
# Out of 2025, 681 carry-over predictions correct.
# Out of 1929, 653 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1662 large predictions correct.
# Out of 3063, 1604 large train predictions correct.
# Out of 1296, 681 carry-over large predictions correct.
# Out of 1248, 653 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_45.json
# Out of 5050, 4027 predictions correct.
# Out of 4858, 3897 train predictions correct.
# Out of 2025, 1239 carry-over predictions correct.
# Out of 1929, 1199 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2811 large predictions correct.
# Out of 3063, 2729 large train predictions correct.
# Out of 1296, 1185 carry-over large predictions correct.
# Out of 1248, 1145 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_47.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_49.json
# Out of 5050, 2331 predictions correct.
# Out of 4858, 2245 train predictions correct.
# Out of 2025, 342 carry-over predictions correct.
# Out of 1929, 330 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1176 large predictions correct.
# Out of 3063, 1138 large train predictions correct.
# Out of 1296, 342 carry-over large predictions correct.
# Out of 1248, 330 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_51.json
# Out of 5050, 3520 predictions correct.
# Out of 4858, 3400 train predictions correct.
# Out of 2025, 1104 carry-over predictions correct.
# Out of 1929, 1068 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2304 large predictions correct.
# Out of 3063, 2232 large train predictions correct.
# Out of 1296, 1050 carry-over large predictions correct.
# Out of 1248, 1014 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_53.json
# Out of 5050, 2032 predictions correct.
# Out of 4858, 1948 train predictions correct.
# Out of 2025, 451 carry-over predictions correct.
# Out of 1929, 433 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 883 large predictions correct.
# Out of 3063, 847 large train predictions correct.
# Out of 1296, 451 carry-over large predictions correct.
# Out of 1248, 433 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_55.json
# Out of 5050, 3943 predictions correct.
# Out of 4858, 3815 train predictions correct.
# Out of 2025, 1182 carry-over predictions correct.
# Out of 1929, 1144 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2727 large predictions correct.
# Out of 3063, 2647 large train predictions correct.
# Out of 1296, 1128 carry-over large predictions correct.
# Out of 1248, 1090 carry-over large train predictions correct.
# Finalizado 0.2.
# Iniciado 0.3.
# Loaded trained_model_2025_01_21_01_12_57.json
# Out of 5050, 1360 predictions correct.
# Out of 4858, 1304 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 270 large predictions correct.
# Out of 3063, 262 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_59.json
# Out of 5050, 1432 predictions correct.
# Out of 4858, 1372 train predictions correct.
# Out of 2025, 153 carry-over predictions correct.
# Out of 1929, 149 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 342 large predictions correct.
# Out of 3063, 330 large train predictions correct.
# Out of 1296, 153 carry-over large predictions correct.
# Out of 1248, 149 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_01.json
# Out of 5050, 2020 predictions correct.
# Out of 4858, 1936 train predictions correct.
# Out of 2025, 451 carry-over predictions correct.
# Out of 1929, 433 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 883 large predictions correct.
# Out of 3063, 847 large train predictions correct.
# Out of 1296, 451 carry-over large predictions correct.
# Out of 1248, 433 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_03.json
# Out of 5050, 1346 predictions correct.
# Out of 4858, 1288 train predictions correct.
# Out of 2025, 153 carry-over predictions correct.
# Out of 1929, 149 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 286 large predictions correct.
# Out of 3063, 276 large train predictions correct.
# Out of 1296, 153 carry-over large predictions correct.
# Out of 1248, 149 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_05.json
# Out of 5050, 3012 predictions correct.
# Out of 4858, 2900 train predictions correct.
# Out of 2025, 681 carry-over predictions correct.
# Out of 1929, 653 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1857 large predictions correct.
# Out of 3063, 1793 large train predictions correct.
# Out of 1296, 681 carry-over large predictions correct.
# Out of 1248, 653 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_07.json
# Out of 5050, 3394 predictions correct.
# Out of 4858, 3274 train predictions correct.
# Out of 2025, 1056 carry-over predictions correct.
# Out of 1929, 1020 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2178 large predictions correct.
# Out of 3063, 2106 large train predictions correct.
# Out of 1296, 1002 carry-over large predictions correct.
# Out of 1248, 966 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_09.json
# Out of 5050, 1264 predictions correct.
# Out of 4858, 1210 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 214 large predictions correct.
# Out of 3063, 208 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_11.json
# Out of 5050, 1168 predictions correct.
# Out of 4858, 1114 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_13.json
# Out of 5050, 2311 predictions correct.
# Out of 4858, 2219 train predictions correct.
# Out of 2025, 451 carry-over predictions correct.
# Out of 1929, 433 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1156 large predictions correct.
# Out of 3063, 1112 large train predictions correct.
# Out of 1296, 451 carry-over large predictions correct.
# Out of 1248, 433 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_15.json
# Out of 5050, 1350 predictions correct.
# Out of 4858, 1294 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 270 large predictions correct.
# Out of 3063, 262 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Finalizado 0.3.
# Iniciado 0.5.
# Loaded trained_model_2025_01_21_01_13_17.json
# Out of 5050, 833 predictions correct.
# Out of 4858, 789 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 519 small predictions correct.
# Out of 724, 475 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_19.json
# Out of 5050, 788 predictions correct.
# Out of 4858, 742 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 528 small predictions correct.
# Out of 724, 482 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_21.json
# Out of 5050, 4399 predictions correct.
# Out of 4858, 4259 train predictions correct.
# Out of 2025, 1434 carry-over predictions correct.
# Out of 1929, 1390 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 3063 large predictions correct.
# Out of 3063, 2971 large train predictions correct.
# Out of 1296, 1260 carry-over large predictions correct.
# Out of 1248, 1216 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_23.json
# Out of 5050, 786 predictions correct.
# Out of 4858, 756 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 472 small predictions correct.
# Out of 724, 442 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_25.json
# Out of 5050, 2817 predictions correct.
# Out of 4858, 2711 train predictions correct.
# Out of 2025, 681 carry-over predictions correct.
# Out of 1929, 653 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1662 large predictions correct.
# Out of 3063, 1604 large train predictions correct.
# Out of 1296, 681 carry-over large predictions correct.
# Out of 1248, 653 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_27.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_29.json
# Out of 5050, 923 predictions correct.
# Out of 4858, 877 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 536 small predictions correct.
# Out of 724, 490 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_31.json
# Out of 5050, 833 predictions correct.
# Out of 4858, 789 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 519 small predictions correct.
# Out of 724, 475 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_33.json
# Out of 5050, 1183 predictions correct.
# Out of 4858, 1129 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_35.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.5.
# Iniciado 0.7.
# Loaded trained_model_2025_01_21_01_13_37.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_39.json
# Out of 5050, 833 predictions correct.
# Out of 4858, 789 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 519 small predictions correct.
# Out of 724, 475 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_41.json
# Out of 5050, 564 predictions correct.
# Out of 4858, 538 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 429 small predictions correct.
# Out of 724, 403 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_43.json
# Out of 5050, 729 predictions correct.
# Out of 4858, 687 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 499 small predictions correct.
# Out of 724, 457 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_45.json
# Out of 5050, 471 predictions correct.
# Out of 4858, 441 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 421 small predictions correct.
# Out of 724, 391 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_47.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_49.json
# Out of 5050, 538 predictions correct.
# Out of 4858, 512 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 403 small predictions correct.
# Out of 724, 377 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_51.json
# Out of 5050, 833 predictions correct.
# Out of 4858, 789 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 519 small predictions correct.
# Out of 724, 475 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_53.json
# Out of 5050, 702 predictions correct.
# Out of 4858, 672 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 472 small predictions correct.
# Out of 724, 442 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_55.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 0.7.
# Iniciado 1.
# Loaded trained_model_2025_01_21_01_13_57.json
# Out of 5050, 399 predictions correct.
# Out of 4858, 379 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 349 small predictions correct.
# Out of 724, 329 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_59.json
# Out of 5050, 3511 predictions correct.
# Out of 4858, 3391 train predictions correct.
# Out of 2025, 1005 carry-over predictions correct.
# Out of 1929, 969 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2295 large predictions correct.
# Out of 3063, 2223 large train predictions correct.
# Out of 1296, 951 carry-over large predictions correct.
# Out of 1248, 915 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_01.json
# Out of 5050, 786 predictions correct.
# Out of 4858, 756 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 472 small predictions correct.
# Out of 724, 442 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_03.json
# Out of 5050, 825 predictions correct.
# Out of 4858, 783 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 469 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_05.json
# Out of 5050, 400 predictions correct.
# Out of 4858, 386 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 305 small predictions correct.
# Out of 724, 291 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_07.json
# Out of 5050, 399 predictions correct.
# Out of 4858, 379 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 349 small predictions correct.
# Out of 724, 329 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_09.json
# Out of 5050, 399 predictions correct.
# Out of 4858, 379 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 349 small predictions correct.
# Out of 724, 329 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_11.json
# Out of 5050, 369 predictions correct.
# Out of 4858, 355 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 319 small predictions correct.
# Out of 724, 305 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_13.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_15.json
# Out of 5050, 477 predictions correct.
# Out of 4858, 457 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 382 small predictions correct.
# Out of 724, 362 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 1.
# Iniciado 1.5.
# Loaded trained_model_2025_01_21_01_14_17.json
# Out of 5050, 220 predictions correct.
# Out of 4858, 212 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 220 small predictions correct.
# Out of 724, 212 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_19.json
# Out of 5050, 295 predictions correct.
# Out of 4858, 287 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 245 small predictions correct.
# Out of 724, 237 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_21.json
# Out of 5050, 399 predictions correct.
# Out of 4858, 379 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 349 small predictions correct.
# Out of 724, 329 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_23.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_25.json
# Out of 5050, 257 predictions correct.
# Out of 4858, 237 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 257 small predictions correct.
# Out of 724, 237 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_27.json
# Out of 5050, 259 predictions correct.
# Out of 4858, 245 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 259 small predictions correct.
# Out of 724, 245 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_29.json
# Out of 5050, 309 predictions correct.
# Out of 4858, 295 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 259 small predictions correct.
# Out of 724, 245 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_31.json
# Out of 5050, 227 predictions correct.
# Out of 4858, 213 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 227 small predictions correct.
# Out of 724, 213 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_33.json
# Out of 5050, 516 predictions correct.
# Out of 4858, 486 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 421 small predictions correct.
# Out of 724, 391 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_35.json
# Out of 5050, 643 predictions correct.
# Out of 4858, 623 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 413 small predictions correct.
# Out of 724, 393 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 1.5.
# Iniciado 2.
# Loaded trained_model_2025_01_21_01_14_37.json
# Out of 5050, 166 predictions correct.
# Out of 4858, 158 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 166 small predictions correct.
# Out of 724, 158 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_39.json
# Out of 5050, 166 predictions correct.
# Out of 4858, 158 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 166 small predictions correct.
# Out of 724, 158 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_41.json
# Out of 5050, 295 predictions correct.
# Out of 4858, 287 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 245 small predictions correct.
# Out of 724, 237 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_43.json
# Out of 5050, 349 predictions correct.
# Out of 4858, 329 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 349 small predictions correct.
# Out of 724, 329 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_45.json
# Out of 5050, 259 predictions correct.
# Out of 4858, 245 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 259 small predictions correct.
# Out of 724, 245 small train predictions correct.
# ...
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_47.json
# Out of 5050, 112 predictions correct.
# Out of 4858, 106 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 112 small predictions correct.
# Out of 724, 106 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_49.json
# Out of 5050, 70 predictions correct.
# Out of 4858, 68 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_51.json
# Out of 5050, 130 predictions correct.
# Out of 4858, 126 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 130 small predictions correct.
# Out of 724, 126 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_53.json
# Out of 5050, 54 predictions correct.
# Out of 4858, 48 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 54 small predictions correct.
# Out of 724, 48 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_55.json
# Out of 5050, 90 predictions correct.
# Out of 4858, 86 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 90 small predictions correct.
# Out of 724, 86 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 5.
# Iniciado 7.5.
# Loaded trained_model_2025_01_21_01_15_57.json
# Out of 5050, 66 predictions correct.
# Out of 4858, 60 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 66 small predictions correct.
# Out of 724, 60 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_59.json
# Out of 5050, 132 predictions correct.
# Out of 4858, 128 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 132 small predictions correct.
# Out of 724, 128 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_01.json
# Out of 5050, 106 predictions correct.
# Out of 4858, 100 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 106 small predictions correct.
# Out of 724, 100 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_03.json
# Out of 5050, 70 predictions correct.
# Out of 4858, 68 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_05.json
# Out of 5050, 106 predictions correct.
# Out of 4858, 104 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 106 small predictions correct.
# Out of 724, 104 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_07.json
# Out of 5050, 1168 predictions correct.
# Out of 4858, 1114 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_09.json
# Out of 5050, 166 predictions correct.
# Out of 4858, 158 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 166 small predictions correct.
# Out of 724, 158 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_11.json
# Out of 5050, 130 predictions correct.
# Out of 4858, 126 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 130 small predictions correct.
# Out of 724, 126 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_13.json
# Out of 5050, 45 predictions correct.
# Out of 4858, 45 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 45 small predictions correct.
# Out of 724, 45 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_15.json
# Out of 5050, 166 predictions correct.
# Out of 4858, 158 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 166 small predictions correct.
# Out of 724, 158 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 7.5.
# Iniciado 10.
# Loaded trained_model_2025_01_21_01_16_17.json
# Out of 5050, 70 predictions correct.
# Out of 4858, 68 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_19.json
# Out of 5050, 9 predictions correct.
# Out of 4858, 9 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 9 small predictions correct.
# Out of 724, 9 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_21.json
# Out of 5050, 70 predictions correct.
# Out of 4858, 68 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_23.json
# Out of 5050, 30 predictions correct.
# Out of 4858, 28 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 30 small predictions correct.
# Out of 724, 28 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_25.json
# Out of 5050, 70 predictions correct.
# Out of 4858, 68 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_27.json
# Out of 5050, 9 predictions correct.
# Out of 4858, 9 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 9 small predictions correct.
# Out of 724, 9 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_29.json
# Out of 5050, 55 predictions correct.
# Out of 4858, 53 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 55 small predictions correct.
# Out of 724, 53 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_31.json
# Out of 5050, 45 predictions correct.
# Out of 4858, 45 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 45 small predictions correct.
# Out of 724, 45 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_33.json
# Out of 5050, 66 predictions correct.
# Out of 4858, 64 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 66 small predictions correct.
# Out of 724, 64 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_35.json
# Out of 5050, 37 predictions correct.
# Out of 4858, 37 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 37 small predictions correct.
# Out of 724, 37 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 10.
