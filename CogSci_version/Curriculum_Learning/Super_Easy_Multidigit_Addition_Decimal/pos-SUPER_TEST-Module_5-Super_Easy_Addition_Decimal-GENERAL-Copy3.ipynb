# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Super_Easy_Multidigit_Addition_Decimal/'
folder_specific = f'{folder}v1-Balanced_Frequencies/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model(f'{folder}Modules/unit_addition_module.keras')
unit_carry_model = load_model(f'{folder}Modules/unit_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        y_data.append([sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    carry_unit_val = {}
    unit_val = {}

    for i, j in [(0, 2), (1, 3)]:
        units_inputs = jnp.array(x[:, [i, j]])
        units_input = units_inputs[:, None, :]
    
        unit_output = jnp.array(unit_addition_model(units_input))
        unit_carry_output = jnp.array(unit_carry_model(units_input))
    
        unit_val[f'{i}_{j}'] = jnp.argmax(unit_output, axis=-1)
        carry_unit_val[f'{i}_{j}'] = jnp.argmax(unit_carry_output, axis=-1)
    
    salida_1 = sum(
        params[f'v_0_1_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_1_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i, j in [(0, 2), (1, 3)]
    )
    
    salida_2 = sum(
        params[f'v_0_2_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_2_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i, j in [(0, 2), (1, 3)]
    )

    return salida_1, salida_2

# %%
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
epsilons = [0.1, 0.2, 0.3, 0.5, 0.7,
            1, 1.5,
            2, 2.5,
            3, 
            5, 7.5,
            10
           ]

# %%
x_test, y_test = generate_test_dataset()
param_type = 'AP'

for epsilon in epsilons:
    print(f'Iniciado {epsilon}.')
    
    save_dir = f"{folder_specific}Super_Tests/"
    folder_path = f'{folder_specific}Super_Trained_models/{param_type}_{epsilon}'
    date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
    files = sorted(
        (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
        key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
    )
    
    os.makedirs(save_dir, exist_ok=True) 
    results_file = os.path.join(save_dir, f"Super_Tests_{param_type}_{epsilon}.txt") 
    tee = Tee(results_file, 'w') 
    sys.stdout = tee
    
    try:
        for filename in files:
            match = re.search(date_pattern, filename)
            if match:
                current_time = match.group(1)
            else:
                print('Error')
                break
            
            file_path = f"{folder_path}/super_trained_model_{current_time}.json"
            with open(file_path, 'rb') as file:
                trained_model = json.load(file)
        
            trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
            print(f'Loaded super_trained_model_{current_time}.json')
    
            predictions(trained_model_jnp, x_test, y_test)
        
    finally:
        sys.stdout = tee.console
        tee.close()
    
    print(f'Finalizado {epsilon}.')
# Out:
# Iniciado 0.1.
# Loaded super_trained_model_2025_01_21_01_12_17.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_19.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_21.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_23.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_25.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_27.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_29.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_31.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_33.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_35.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.1.
# Iniciado 0.2.
# Loaded super_trained_model_2025_01_21_01_12_37.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_39.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_41.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_43.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_45.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_47.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_49.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_51.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_53.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_55.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.2.
# Iniciado 0.3.
# Loaded super_trained_model_2025_01_21_01_12_57.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_12_59.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_01.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_03.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_05.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_07.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_09.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_11.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_13.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_15.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.3.
# Iniciado 0.5.
# Loaded super_trained_model_2025_01_21_01_13_17.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_19.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_21.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_23.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_25.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_27.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_29.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_31.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_33.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_35.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.5.
# Iniciado 0.7.
# Loaded super_trained_model_2025_01_21_01_13_37.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_39.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_41.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_43.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_45.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_47.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_49.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_51.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_53.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_55.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.7.
# Iniciado 1.
# Loaded super_trained_model_2025_01_21_01_13_57.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_13_59.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_01.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_03.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_05.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_07.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_09.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_11.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_13.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_15.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 1.
# Iniciado 1.5.
# Loaded super_trained_model_2025_01_21_01_14_17.json
# Out of 5050, 4876 predictions correct.
# Out of 4858, 4728 train predictions correct.
# Out of 2025, 1851 carry-over predictions correct.
# Out of 1929, 1799 carry-over train predictions correct.
# Out of 820, 658 small predictions correct.
# Out of 724, 606 small train predictions correct.
# Out of 270, 108 carry-over small predictions correct.
# Out of 222, 104 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_19.json
# Out of 5050, 4945 predictions correct.
# Out of 4858, 4787 train predictions correct.
# Out of 2025, 1920 carry-over predictions correct.
# Out of 1929, 1858 carry-over train predictions correct.
# Out of 820, 715 small predictions correct.
# Out of 724, 653 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_21.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_23.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_25.json
# Out of 5050, 4999 predictions correct.
# Out of 4858, 4827 train predictions correct.
# Out of 2025, 1974 carry-over predictions correct.
# Out of 1929, 1898 carry-over train predictions correct.
# Out of 820, 769 small predictions correct.
# Out of 724, 693 small train predictions correct.
# Out of 270, 219 carry-over small predictions correct.
# Out of 222, 191 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_27.json
# Out of 5050, 4941 predictions correct.
# Out of 4858, 4783 train predictions correct.
# Out of 2025, 1916 carry-over predictions correct.
# Out of 1929, 1854 carry-over train predictions correct.
# Out of 820, 715 small predictions correct.
# Out of 724, 653 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_29.json
# Out of 5050, 5038 predictions correct.
# Out of 4858, 4852 train predictions correct.
# Out of 2025, 2013 carry-over predictions correct.
# Out of 1929, 1923 carry-over train predictions correct.
# Out of 820, 808 small predictions correct.
# Out of 724, 718 small train predictions correct.
# Out of 270, 258 carry-over small predictions correct.
# Out of 222, 216 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_31.json
# Out of 5050, 4983 predictions correct.
# Out of 4858, 4815 train predictions correct.
# Out of 2025, 1958 carry-over predictions correct.
# Out of 1929, 1886 carry-over train predictions correct.
# Out of 820, 753 small predictions correct.
# Out of 724, 681 small train predictions correct.
# Out of 270, 203 carry-over small predictions correct.
# Out of 222, 179 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_33.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_35.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 1.5.
# Iniciado 2.
# Loaded super_trained_model_2025_01_21_01_14_37.json
# Out of 5050, 4602 predictions correct.
# Out of 4858, 4458 train predictions correct.
# Out of 2025, 1587 carry-over predictions correct.
# Out of 1929, 1539 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 3143 large predictions correct.
# Out of 3063, 3047 large train predictions correct.
# Out of 1296, 1290 carry-over large predictions correct.
# Out of 1248, 1242 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_39.json
# Out of 5050, 4399 predictions correct.
# Out of 4858, 4259 train predictions correct.
# Out of 2025, 1434 carry-over predictions correct.
# Out of 1929, 1390 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 3063 large predictions correct.
# Out of 3063, 2971 large train predictions correct.
# Out of 1296, 1260 carry-over large predictions correct.
# Out of 1248, 1216 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_14_41.json
# Out of 5050, 4876 predictions correct.
# ...
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1129 large predictions correct.
# Out of 3063, 1089 large train predictions correct.
# Out of 1296, 570 carry-over large predictions correct.
# Out of 1248, 548 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_15_49.json
# Out of 5050, 1183 predictions correct.
# Out of 4858, 1129 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_15_51.json
# Out of 5050, 2103 predictions correct.
# Out of 4858, 2019 train predictions correct.
# Out of 2025, 487 carry-over predictions correct.
# Out of 1929, 469 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 954 large predictions correct.
# Out of 3063, 918 large train predictions correct.
# Out of 1296, 487 carry-over large predictions correct.
# Out of 1248, 469 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_15_53.json
# Out of 5050, 957 predictions correct.
# Out of 4858, 909 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_15_55.json
# Out of 5050, 1744 predictions correct.
# Out of 4858, 1676 train predictions correct.
# Out of 2025, 387 carry-over predictions correct.
# Out of 1929, 375 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 625 large predictions correct.
# Out of 3063, 605 large train predictions correct.
# Out of 1296, 387 carry-over large predictions correct.
# Out of 1248, 375 carry-over large train predictions correct.
# Finalizado 5.
# Iniciado 7.5.
# Loaded super_trained_model_2025_01_21_01_15_57.json
# Out of 5050, 2067 predictions correct.
# Out of 4858, 1989 train predictions correct.
# Out of 2025, 387 carry-over predictions correct.
# Out of 1929, 375 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 918 large predictions correct.
# Out of 3063, 888 large train predictions correct.
# Out of 1296, 387 carry-over large predictions correct.
# Out of 1248, 375 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_15_59.json
# Out of 5050, 2403 predictions correct.
# Out of 4858, 2309 train predictions correct.
# Out of 2025, 543 carry-over predictions correct.
# Out of 1929, 523 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1248 large predictions correct.
# Out of 3063, 1202 large train predictions correct.
# Out of 1296, 543 carry-over large predictions correct.
# Out of 1248, 523 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_01.json
# Out of 5050, 2403 predictions correct.
# Out of 4858, 2309 train predictions correct.
# Out of 2025, 543 carry-over predictions correct.
# Out of 1929, 523 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1248 large predictions correct.
# Out of 3063, 1202 large train predictions correct.
# Out of 1296, 543 carry-over large predictions correct.
# Out of 1248, 523 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_03.json
# Out of 5050, 618 predictions correct.
# Out of 4858, 576 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 483 small predictions correct.
# Out of 724, 441 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_05.json
# Out of 5050, 1704 predictions correct.
# Out of 4858, 1634 train predictions correct.
# Out of 2025, 153 carry-over predictions correct.
# Out of 1929, 149 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 585 large predictions correct.
# Out of 3063, 563 large train predictions correct.
# Out of 1296, 153 carry-over large predictions correct.
# Out of 1248, 149 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_07.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_09.json
# Out of 5050, 3598 predictions correct.
# Out of 4858, 3476 train predictions correct.
# Out of 2025, 1182 carry-over predictions correct.
# Out of 1929, 1144 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2382 large predictions correct.
# Out of 3063, 2308 large train predictions correct.
# Out of 1296, 1128 carry-over large predictions correct.
# Out of 1248, 1090 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_11.json
# Out of 5050, 2131 predictions correct.
# Out of 4858, 2047 train predictions correct.
# Out of 2025, 451 carry-over predictions correct.
# Out of 1929, 433 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 982 large predictions correct.
# Out of 3063, 946 large train predictions correct.
# Out of 1296, 451 carry-over large predictions correct.
# Out of 1248, 433 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_13.json
# Out of 5050, 833 predictions correct.
# Out of 4858, 789 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 519 small predictions correct.
# Out of 724, 475 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_15.json
# Out of 5050, 4399 predictions correct.
# Out of 4858, 4259 train predictions correct.
# Out of 2025, 1434 carry-over predictions correct.
# Out of 1929, 1390 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 3063 large predictions correct.
# Out of 3063, 2971 large train predictions correct.
# Out of 1296, 1260 carry-over large predictions correct.
# Out of 1248, 1216 carry-over large train predictions correct.
# Finalizado 7.5.
# Iniciado 10.
# Loaded super_trained_model_2025_01_21_01_16_17.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_19.json
# Out of 5050, 564 predictions correct.
# Out of 4858, 538 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 429 small predictions correct.
# Out of 724, 403 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_21.json
# Out of 5050, 1264 predictions correct.
# Out of 4858, 1210 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 214 large predictions correct.
# Out of 3063, 208 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_23.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_25.json
# Out of 5050, 833 predictions correct.
# Out of 4858, 789 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 519 small predictions correct.
# Out of 724, 475 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_27.json
# Out of 5050, 498 predictions correct.
# Out of 4858, 472 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 403 small predictions correct.
# Out of 724, 377 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_29.json
# Out of 5050, 588 predictions correct.
# Out of 4858, 558 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 453 small predictions correct.
# Out of 724, 423 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_31.json
# Out of 5050, 729 predictions correct.
# Out of 4858, 687 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 499 small predictions correct.
# Out of 724, 457 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_33.json
# Out of 5050, 833 predictions correct.
# Out of 4858, 789 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 519 small predictions correct.
# Out of 724, 475 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_21_01_16_35.json
# Out of 5050, 538 predictions correct.
# Out of 4858, 512 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 403 small predictions correct.
# Out of 724, 377 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 10.
