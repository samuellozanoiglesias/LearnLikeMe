# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Easy_Multidigit_Addition_Decimal/'
folder_specific = f'{folder}v1-Balanced_Frequencies/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model(f'{folder}Modules/unit_addition_module.keras')
unit_carry_model = load_model(f'{folder}Modules/unit_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        y_data.append([sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def construct_matrices(x):
    carry_unit_val = {}
    unit_val = {}

    for i in [0,1]:
       for j in [2,3]:
            units_inputs = jnp.array(x[:, [i, j]])
            units_input = units_inputs[:, None, :]
           
            unit_output = jnp.array(unit_addition_model(units_input))
            unit_carry_output = jnp.array(unit_carry_model(units_input))
           
            unit_val[f'{i}_{j}'] = jnp.argmax(unit_output, axis=-1)
            carry_unit_val[f'{i}_{j}'] = jnp.argmax(unit_carry_output, axis=-1)

    return carry_unit_val, unit_val


def model(params, x):
    carry_unit_val, unit_val = construct_matrices(x)
    
    salida_1 = sum(params[f'v_0_1_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_1_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i in [0,1] for j in [2,3]
        )

    # Salida 2
    salida_2 = sum(params[f'v_0_2_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_2_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i in [0,1] for j in [2,3]
        )

    return salida_1, salida_2

# %%
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
epsilons = [0.1, 0.2, 0.3, 0.5, 0.7,
            1, 1.5,
            2, 2.5,
            3, 
            5,
            7.5,
            10
           ]

# %%
x_test, y_test = generate_test_dataset()
param_type = 'AP'

for epsilon in epsilons:
    print(f'Iniciado {epsilon}.')
    
    save_dir = f"{folder_specific}Super_Tests/"
    folder_path = f'{folder_specific}Super_Trained_models/{param_type}_{epsilon}'
    date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
    files = sorted(
        (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
        key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
    )
    
    os.makedirs(save_dir, exist_ok=True) 
    results_file = os.path.join(save_dir, f"Super_Tests_{param_type}_{epsilon}.txt") 
    tee = Tee(results_file, 'w') 
    sys.stdout = tee
    
    try:
        for filename in files:
            match = re.search(date_pattern, filename)
            if match:
                current_time = match.group(1)
            else:
                print('Error')
                break
            
            file_path = f"{folder_path}/super_trained_model_{current_time}.json"
            with open(file_path, 'rb') as file:
                trained_model = json.load(file)
        
            trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
            print(f'Loaded super_trained_model_{current_time}.json')
    
            predictions(trained_model_jnp, x_test, y_test)
        
    finally:
        sys.stdout = tee.console
        tee.close()
    
    print(f'Finalizado {epsilon}.')
# Out:
# Iniciado 0.1.
# Loaded super_trained_model_2025_01_15_14_52_53.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_52_55.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_52_57.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_52_59.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_01.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_03.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_05.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_07.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_09.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_11.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.1.
# Iniciado 0.2.
# Loaded super_trained_model_2025_01_15_14_53_13.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_15.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_17.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_19.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_21.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_23.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_25.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_27.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_29.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_31.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.2.
# Iniciado 0.3.
# Loaded super_trained_model_2025_01_15_14_53_33.json
# Out of 5050, 5012 predictions correct.
# Out of 4858, 4820 train predictions correct.
# Out of 2025, 2019 carry-over predictions correct.
# Out of 1929, 1923 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3121 large predictions correct.
# Out of 3063, 3025 large train predictions correct.
# Out of 1296, 1290 carry-over large predictions correct.
# Out of 1248, 1242 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_35.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_37.json
# Out of 5050, 5047 predictions correct.
# Out of 4858, 4855 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3156 large predictions correct.
# Out of 3063, 3060 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_39.json
# Out of 5050, 5042 predictions correct.
# Out of 4858, 4850 train predictions correct.
# Out of 2025, 2022 carry-over predictions correct.
# Out of 1929, 1926 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3151 large predictions correct.
# Out of 3063, 3055 large train predictions correct.
# Out of 1296, 1293 carry-over large predictions correct.
# Out of 1248, 1245 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_41.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_43.json
# Out of 5050, 4374 predictions correct.
# Out of 4858, 4186 train predictions correct.
# Out of 2025, 1801 carry-over predictions correct.
# Out of 1929, 1707 carry-over train predictions correct.
# Out of 820, 789 small predictions correct.
# Out of 724, 693 small train predictions correct.
# Out of 270, 262 carry-over small predictions correct.
# Out of 222, 214 carry-over small train predictions correct.
# Out of 3159, 2606 large predictions correct.
# Out of 3063, 2514 large train predictions correct.
# Out of 1296, 1118 carry-over large predictions correct.
# Out of 1248, 1072 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_45.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_47.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_49.json
# Out of 5050, 4922 predictions correct.
# Out of 4858, 4730 train predictions correct.
# Out of 2025, 1993 carry-over predictions correct.
# Out of 1929, 1897 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3039 large predictions correct.
# Out of 3063, 2943 large train predictions correct.
# Out of 1296, 1267 carry-over large predictions correct.
# Out of 1248, 1219 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_51.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.3.
# Iniciado 0.5.
# Loaded super_trained_model_2025_01_15_14_53_53.json
# Out of 5050, 4986 predictions correct.
# Out of 4858, 4794 train predictions correct.
# Out of 2025, 2006 carry-over predictions correct.
# Out of 1929, 1910 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3099 large predictions correct.
# Out of 3063, 3003 large train predictions correct.
# Out of 1296, 1279 carry-over large predictions correct.
# Out of 1248, 1231 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_55.json
# Out of 5050, 5022 predictions correct.
# Out of 4858, 4830 train predictions correct.
# Out of 2025, 2020 carry-over predictions correct.
# Out of 1929, 1924 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3131 large predictions correct.
# Out of 3063, 3035 large train predictions correct.
# Out of 1296, 1291 carry-over large predictions correct.
# Out of 1248, 1243 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_57.json
# Out of 5050, 5040 predictions correct.
# Out of 4858, 4848 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3149 large predictions correct.
# Out of 3063, 3053 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_53_59.json
# Out of 5050, 5042 predictions correct.
# Out of 4858, 4850 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3151 large predictions correct.
# Out of 3063, 3055 large train predictions correct.
# Out of 1296, 1295 carry-over large predictions correct.
# Out of 1248, 1247 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_01.json
# Out of 5050, 5045 predictions correct.
# Out of 4858, 4853 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3154 large predictions correct.
# Out of 3063, 3058 large train predictions correct.
# Out of 1296, 1295 carry-over large predictions correct.
# Out of 1248, 1247 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_03.json
# Out of 5050, 3721 predictions correct.
# Out of 4858, 3549 train predictions correct.
# Out of 2025, 1461 carry-over predictions correct.
# Out of 1929, 1374 carry-over train predictions correct.
# Out of 820, 764 small predictions correct.
# Out of 724, 669 small train predictions correct.
# Out of 270, 244 carry-over small predictions correct.
# Out of 222, 197 carry-over small train predictions correct.
# Out of 3159, 2100 large predictions correct.
# Out of 3063, 2023 large train predictions correct.
# Out of 1296, 867 carry-over large predictions correct.
# Out of 1248, 827 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_05.json
# Out of 5050, 4053 predictions correct.
# Out of 4858, 3872 train predictions correct.
# Out of 2025, 1626 carry-over predictions correct.
# Out of 1929, 1535 carry-over train predictions correct.
# Out of 820, 776 small predictions correct.
# Out of 724, 680 small train predictions correct.
# Out of 270, 256 carry-over small predictions correct.
# Out of 222, 208 carry-over small train predictions correct.
# Out of 3159, 2357 large predictions correct.
# Out of 3063, 2272 large train predictions correct.
# Out of 1296, 974 carry-over large predictions correct.
# Out of 1248, 931 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_07.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_09.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_11.json
# Out of 5050, 4075 predictions correct.
# Out of 4858, 3895 train predictions correct.
# Out of 2025, 1646 carry-over predictions correct.
# Out of 1929, 1556 carry-over train predictions correct.
# Out of 820, 766 small predictions correct.
# Out of 724, 672 small train predictions correct.
# Out of 270, 246 carry-over small predictions correct.
# Out of 222, 200 carry-over small train predictions correct.
# Out of 3159, 2400 large predictions correct.
# Out of 3063, 2314 large train predictions correct.
# Out of 1296, 1019 carry-over large predictions correct.
# Out of 1248, 975 carry-over large train predictions correct.
# Finalizado 0.5.
# Iniciado 0.7.
# Loaded super_trained_model_2025_01_15_14_54_13.json
# Out of 5050, 4953 predictions correct.
# Out of 4858, 4761 train predictions correct.
# Out of 2025, 2002 carry-over predictions correct.
# Out of 1929, 1906 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3065 large predictions correct.
# Out of 3063, 2969 large train predictions correct.
# Out of 1296, 1274 carry-over large predictions correct.
# Out of 1248, 1226 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_15.json
# Out of 5050, 3511 predictions correct.
# Out of 4858, 3345 train predictions correct.
# Out of 2025, 1356 carry-over predictions correct.
# Out of 1929, 1273 carry-over train predictions correct.
# Out of 820, 758 small predictions correct.
# Out of 724, 664 small train predictions correct.
# Out of 270, 240 carry-over small predictions correct.
# Out of 222, 194 carry-over small train predictions correct.
# Out of 3159, 1929 large predictions correct.
# Out of 3063, 1857 large train predictions correct.
# Out of 1296, 786 carry-over large predictions correct.
# Out of 1248, 749 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_17.json
# Out of 5050, 4422 predictions correct.
# Out of 4858, 4236 train predictions correct.
# Out of 2025, 1811 carry-over predictions correct.
# Out of 1929, 1718 carry-over train predictions correct.
# Out of 820, 790 small predictions correct.
# Out of 724, 695 small train predictions correct.
# Out of 270, 258 carry-over small predictions correct.
# Out of 222, 211 carry-over small train predictions correct.
# Out of 3159, 2651 large predictions correct.
# Out of 3063, 2560 large train predictions correct.
# Out of 1296, 1132 carry-over large predictions correct.
# Out of 1248, 1086 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_19.json
# Out of 5050, 3185 predictions correct.
# Out of 4858, 3034 train predictions correct.
# Out of 2025, 1132 carry-over predictions correct.
# Out of 1929, 1056 carry-over train predictions correct.
# Out of 820, 735 small predictions correct.
# Out of 724, 642 small train predictions correct.
# Out of 270, 227 carry-over small predictions correct.
# Out of 222, 182 carry-over small train predictions correct.
# Out of 3159, 1675 large predictions correct.
# Out of 3063, 1617 large train predictions correct.
# Out of 1296, 623 carry-over large predictions correct.
# Out of 1248, 592 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_21.json
# Out of 5050, 4741 predictions correct.
# Out of 4858, 4550 train predictions correct.
# Out of 2025, 1910 carry-over predictions correct.
# Out of 1929, 1815 carry-over train predictions correct.
# Out of 820, 805 small predictions correct.
# Out of 724, 709 small train predictions correct.
# Out of 270, 263 carry-over small predictions correct.
# Out of 222, 215 carry-over small train predictions correct.
# Out of 3159, 2906 large predictions correct.
# Out of 3063, 2811 large train predictions correct.
# Out of 1296, 1207 carry-over large predictions correct.
# Out of 1248, 1160 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_23.json
# Out of 5050, 3086 predictions correct.
# Out of 4858, 2937 train predictions correct.
# Out of 2025, 1057 carry-over predictions correct.
# Out of 1929, 983 carry-over train predictions correct.
# Out of 820, 716 small predictions correct.
# Out of 724, 624 small train predictions correct.
# Out of 270, 222 carry-over small predictions correct.
# Out of 222, 178 carry-over small train predictions correct.
# Out of 3159, 1613 large predictions correct.
# Out of 3063, 1556 large train predictions correct.
# Out of 1296, 570 carry-over large predictions correct.
# Out of 1248, 540 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_25.json
# Out of 5050, 3565 predictions correct.
# Out of 4858, 3397 train predictions correct.
# Out of 2025, 1349 carry-over predictions correct.
# Out of 1929, 1265 carry-over train predictions correct.
# Out of 820, 750 small predictions correct.
# Out of 724, 656 small train predictions correct.
# Out of 270, 230 carry-over small predictions correct.
# Out of 222, 184 carry-over small train predictions correct.
# Out of 3159, 1998 large predictions correct.
# Out of 3063, 1924 large train predictions correct.
# Out of 1296, 804 carry-over large predictions correct.
# Out of 1248, 766 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_27.json
# Out of 5050, 3781 predictions correct.
# Out of 4858, 3608 train predictions correct.
# Out of 2025, 1504 carry-over predictions correct.
# Out of 1929, 1417 carry-over train predictions correct.
# Out of 820, 764 small predictions correct.
# Out of 724, 670 small train predictions correct.
# Out of 270, 245 carry-over small predictions correct.
# Out of 222, 199 carry-over small train predictions correct.
# Out of 3159, 2148 large predictions correct.
# Out of 3063, 2069 large train predictions correct.
# Out of 1296, 900 carry-over large predictions correct.
# Out of 1248, 859 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_29.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_31.json
# Out of 5050, 2773 predictions correct.
# Out of 4858, 2639 train predictions correct.
# Out of 2025, 934 carry-over predictions correct.
# Out of 1929, 872 carry-over train predictions correct.
# Out of 820, 649 small predictions correct.
# Out of 724, 562 small train predictions correct.
# Out of 270, 200 carry-over small predictions correct.
# Out of 222, 160 carry-over small train predictions correct.
# Out of 3159, 1415 large predictions correct.
# Out of 3063, 1368 large train predictions correct.
# Out of 1296, 480 carry-over large predictions correct.
# Out of 1248, 458 carry-over large train predictions correct.
# Finalizado 0.7.
# Iniciado 1.
# Loaded super_trained_model_2025_01_15_14_54_33.json
# Out of 5050, 4070 predictions correct.
# Out of 4858, 3889 train predictions correct.
# Out of 2025, 1610 carry-over predictions correct.
# Out of 1929, 1520 carry-over train predictions correct.
# Out of 820, 765 small predictions correct.
# Out of 724, 671 small train predictions correct.
# Out of 270, 242 carry-over small predictions correct.
# Out of 222, 196 carry-over small train predictions correct.
# Out of 3159, 2407 large predictions correct.
# Out of 3063, 2320 large train predictions correct.
# Out of 1296, 1000 carry-over large predictions correct.
# Out of 1248, 956 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_35.json
# Out of 5050, 2787 predictions correct.
# Out of 4858, 2647 train predictions correct.
# Out of 2025, 893 carry-over predictions correct.
# Out of 1929, 827 carry-over train predictions correct.
# Out of 820, 663 small predictions correct.
# Out of 724, 572 small train predictions correct.
# Out of 270, 205 carry-over small predictions correct.
# Out of 222, 162 carry-over small train predictions correct.
# Out of 3159, 1438 large predictions correct.
# Out of 3063, 1389 large train predictions correct.
# Out of 1296, 464 carry-over large predictions correct.
# Out of 1248, 441 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_37.json
# Out of 5050, 2279 predictions correct.
# Out of 4858, 2161 train predictions correct.
# Out of 2025, 720 carry-over predictions correct.
# Out of 1929, 664 carry-over train predictions correct.
# Out of 820, 537 small predictions correct.
# Out of 724, 460 small train predictions correct.
# Out of 270, 169 carry-over small predictions correct.
# Out of 222, 132 carry-over small train predictions correct.
# Out of 3159, 1152 large predictions correct.
# Out of 3063, 1111 large train predictions correct.
# Out of 1296, 339 carry-over large predictions correct.
# Out of 1248, 320 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_39.json
# Out of 5050, 2672 predictions correct.
# Out of 4858, 2540 train predictions correct.
# Out of 2025, 891 carry-over predictions correct.
# Out of 1929, 830 carry-over train predictions correct.
# Out of 820, 633 small predictions correct.
# Out of 724, 547 small train predictions correct.
# Out of 270, 197 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 3159, 1348 large predictions correct.
# Out of 3063, 1302 large train predictions correct.
# Out of 1296, 444 carry-over large predictions correct.
# Out of 1248, 422 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_41.json
# Out of 5050, 3839 predictions correct.
# Out of 4858, 3664 train predictions correct.
# Out of 2025, 1514 carry-over predictions correct.
# Out of 1929, 1426 carry-over train predictions correct.
# Out of 820, 764 small predictions correct.
# Out of 724, 669 small train predictions correct.
# Out of 270, 244 carry-over small predictions correct.
# Out of 222, 197 carry-over small train predictions correct.
# Out of 3159, 2201 large predictions correct.
# Out of 3063, 2121 large train predictions correct.
# Out of 1296, 911 carry-over large predictions correct.
# Out of 1248, 870 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_43.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_45.json
# Out of 5050, 3404 predictions correct.
# Out of 4858, 3243 train predictions correct.
# Out of 2025, 1270 carry-over predictions correct.
# Out of 1929, 1190 carry-over train predictions correct.
# Out of 820, 748 small predictions correct.
# Out of 724, 655 small train predictions correct.
# Out of 270, 232 carry-over small predictions correct.
# Out of 222, 187 carry-over small train predictions correct.
# Out of 3159, 1845 large predictions correct.
# Out of 3063, 1777 large train predictions correct.
# Out of 1296, 724 carry-over large predictions correct.
# Out of 1248, 689 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_47.json
# Out of 5050, 3412 predictions correct.
# Out of 4858, 3251 train predictions correct.
# Out of 2025, 1238 carry-over predictions correct.
# Out of 1929, 1159 carry-over train predictions correct.
# Out of 820, 746 small predictions correct.
# Out of 724, 653 small train predictions correct.
# Out of 270, 230 carry-over small predictions correct.
# Out of 222, 185 carry-over small train predictions correct.
# Out of 3159, 1856 large predictions correct.
# Out of 3063, 1788 large train predictions correct.
# Out of 1296, 700 carry-over large predictions correct.
# Out of 1248, 666 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_49.json
# Out of 5050, 2130 predictions correct.
# Out of 4858, 2018 train predictions correct.
# Out of 2025, 650 carry-over predictions correct.
# Out of 1929, 601 carry-over train predictions correct.
# Out of 820, 522 small predictions correct.
# Out of 724, 446 small train predictions correct.
# Out of 270, 157 carry-over small predictions correct.
# Out of 222, 123 carry-over small train predictions correct.
# Out of 3159, 1059 large predictions correct.
# Out of 3063, 1023 large train predictions correct.
# Out of 1296, 303 carry-over large predictions correct.
# Out of 1248, 288 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_51.json
# Out of 5050, 4008 predictions correct.
# Out of 4858, 3829 train predictions correct.
# Out of 2025, 1622 carry-over predictions correct.
# Out of 1929, 1531 carry-over train predictions correct.
# Out of 820, 775 small predictions correct.
# Out of 724, 679 small train predictions correct.
# Out of 270, 255 carry-over small predictions correct.
# Out of 222, 207 carry-over small train predictions correct.
# Out of 3159, 2323 large predictions correct.
# Out of 3063, 2240 large train predictions correct.
# Out of 1296, 977 carry-over large predictions correct.
# Out of 1248, 934 carry-over large train predictions correct.
# Finalizado 1.
# Iniciado 1.5.
# Loaded super_trained_model_2025_01_15_14_54_53.json
# Out of 5050, 2344 predictions correct.
# Out of 4858, 2232 train predictions correct.
# Out of 2025, 789 carry-over predictions correct.
# Out of 1929, 743 carry-over train predictions correct.
# Out of 820, 561 small predictions correct.
# Out of 724, 484 small train predictions correct.
# Out of 270, 167 carry-over small predictions correct.
# Out of 222, 135 carry-over small train predictions correct.
# Out of 3159, 1154 large predictions correct.
# Out of 3063, 1119 large train predictions correct.
# Out of 1296, 384 carry-over large predictions correct.
# Out of 1248, 370 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_55.json
# Out of 5050, 3037 predictions correct.
# Out of 4858, 2889 train predictions correct.
# Out of 2025, 1042 carry-over predictions correct.
# Out of 1929, 968 carry-over train predictions correct.
# Out of 820, 713 small predictions correct.
# Out of 724, 621 small train predictions correct.
# Out of 270, 219 carry-over small predictions correct.
# Out of 222, 175 carry-over small train predictions correct.
# Out of 3159, 1576 large predictions correct.
# Out of 3063, 1520 large train predictions correct.
# Out of 1296, 560 carry-over large predictions correct.
# Out of 1248, 530 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_57.json
# Out of 5050, 1582 predictions correct.
# Out of 4858, 1495 train predictions correct.
# Out of 2025, 534 carry-over predictions correct.
# Out of 1929, 493 carry-over train predictions correct.
# Out of 820, 393 small predictions correct.
# Out of 724, 332 small train predictions correct.
# Out of 270, 127 carry-over small predictions correct.
# Out of 222, 98 carry-over small train predictions correct.
# Out of 3159, 778 large predictions correct.
# Out of 3063, 752 large train predictions correct.
# Out of 1296, 246 carry-over large predictions correct.
# Out of 1248, 234 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_54_59.json
# Out of 5050, 4024 predictions correct.
# Out of 4858, 3846 train predictions correct.
# Out of 2025, 1528 carry-over predictions correct.
# Out of 1929, 1442 carry-over train predictions correct.
# Out of 820, 769 small predictions correct.
# Out of 724, 676 small train predictions correct.
# Out of 270, 236 carry-over small predictions correct.
# Out of 222, 191 carry-over small train predictions correct.
# Out of 3159, 2373 large predictions correct.
# Out of 3063, 2288 large train predictions correct.
# Out of 1296, 952 carry-over large predictions correct.
# Out of 1248, 911 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_01.json
# Out of 5050, 2106 predictions correct.
# Out of 4858, 1998 train predictions correct.
# Out of 2025, 519 carry-over predictions correct.
# Out of 1929, 475 carry-over train predictions correct.
# Out of 820, 551 small predictions correct.
# Out of 724, 474 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 129 carry-over small train predictions correct.
# Out of 3159, 981 large predictions correct.
# Out of 3063, 950 large train predictions correct.
# Out of 1296, 164 carry-over large predictions correct.
# Out of 1248, 156 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_03.json
# Out of 5050, 1754 predictions correct.
# Out of 4858, 1660 train predictions correct.
# Out of 2025, 492 carry-over predictions correct.
# Out of 1929, 452 carry-over train predictions correct.
# Out of 820, 482 small predictions correct.
# Out of 724, 408 small train predictions correct.
# Out of 270, 155 carry-over small predictions correct.
# Out of 222, 121 carry-over small train predictions correct.
# Out of 3159, 761 large predictions correct.
# Out of 3063, 741 large train predictions correct.
# Out of 1296, 152 carry-over large predictions correct.
# Out of 1248, 146 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_05.json
# Out of 5050, 2068 predictions correct.
# Out of 4858, 1956 train predictions correct.
# Out of 2025, 621 carry-over predictions correct.
# Out of 1929, 572 carry-over train predictions correct.
# Out of 820, 522 small predictions correct.
# Out of 724, 444 small train predictions correct.
# Out of 270, 158 carry-over small predictions correct.
# Out of 222, 122 carry-over small train predictions correct.
# Out of 3159, 1008 large predictions correct.
# Out of 3063, 974 large train predictions correct.
# Out of 1296, 275 carry-over large predictions correct.
# Out of 1248, 262 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_07.json
# Out of 5050, 3089 predictions correct.
# Out of 4858, 2946 train predictions correct.
# Out of 2025, 1107 carry-over predictions correct.
# Out of 1929, 1041 carry-over train predictions correct.
# Out of 820, 716 small predictions correct.
# Out of 724, 626 small train predictions correct.
# Out of 270, 218 carry-over small predictions correct.
# Out of 222, 176 carry-over small train predictions correct.
# Out of 3159, 1588 large predictions correct.
# Out of 3063, 1535 large train predictions correct.
# Out of 1296, 589 carry-over large predictions correct.
# Out of 1248, 565 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_09.json
# Out of 5050, 1850 predictions correct.
# Out of 4858, 1751 train predictions correct.
# Out of 2025, 591 carry-over predictions correct.
# Out of 1929, 544 carry-over train predictions correct.
# Out of 820, 451 small predictions correct.
# Out of 724, 384 small train predictions correct.
# Out of 270, 136 carry-over small predictions correct.
# Out of 222, 104 carry-over small train predictions correct.
# Out of 3159, 942 large predictions correct.
# Out of 3063, 910 large train predictions correct.
# Out of 1296, 284 carry-over large predictions correct.
# Out of 1248, 269 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_11.json
# Out of 5050, 2727 predictions correct.
# Out of 4858, 2585 train predictions correct.
# Out of 2025, 962 carry-over predictions correct.
# Out of 1929, 891 carry-over train predictions correct.
# Out of 820, 676 small predictions correct.
# Out of 724, 584 small train predictions correct.
# Out of 270, 214 carry-over small predictions correct.
# Out of 222, 170 carry-over small train predictions correct.
# Out of 3159, 1363 large predictions correct.
# Out of 3063, 1313 large train predictions correct.
# Out of 1296, 491 carry-over large predictions correct.
# Out of 1248, 464 carry-over large train predictions correct.
# Finalizado 1.5.
# Iniciado 2.
# Loaded super_trained_model_2025_01_15_14_55_13.json
# Out of 5050, 2664 predictions correct.
# Out of 4858, 2534 train predictions correct.
# Out of 2025, 896 carry-over predictions correct.
# Out of 1929, 836 carry-over train predictions correct.
# Out of 820, 611 small predictions correct.
# Out of 724, 527 small train predictions correct.
# Out of 270, 186 carry-over small predictions correct.
# Out of 222, 147 carry-over small train predictions correct.
# Out of 3159, 1386 large predictions correct.
# Out of 3063, 1340 large train predictions correct.
# Out of 1296, 467 carry-over large predictions correct.
# Out of 1248, 446 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_15.json
# Out of 5050, 2618 predictions correct.
# Out of 4858, 2480 train predictions correct.
# Out of 2025, 824 carry-over predictions correct.
# Out of 1929, 758 carry-over train predictions correct.
# Out of 820, 631 small predictions correct.
# Out of 724, 542 small train predictions correct.
# Out of 270, 196 carry-over small predictions correct.
# Out of 222, 154 carry-over small train predictions correct.
# Out of 3159, 1323 large predictions correct.
# Out of 3063, 1274 large train predictions correct.
# Out of 1296, 405 carry-over large predictions correct.
# Out of 1248, 381 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_55_17.json
# Out of 5050, 4173 predictions correct.
# Out of 4858, 4012 train predictions correct.
# Out of 2025, 1415 carry-over predictions correct.
# ...
# Out of 820, 98 small predictions correct.
# Out of 724, 83 small train predictions correct.
# Out of 270, 21 carry-over small predictions correct.
# Out of 222, 17 carry-over small train predictions correct.
# Out of 3159, 226 large predictions correct.
# Out of 3063, 219 large train predictions correct.
# Out of 1296, 79 carry-over large predictions correct.
# Out of 1248, 76 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_56_05.json
# Out of 5050, 430 predictions correct.
# Out of 4858, 408 train predictions correct.
# Out of 2025, 187 carry-over predictions correct.
# Out of 1929, 178 carry-over train predictions correct.
# Out of 820, 147 small predictions correct.
# Out of 724, 128 small train predictions correct.
# Out of 270, 41 carry-over small predictions correct.
# Out of 222, 34 carry-over small train predictions correct.
# Out of 3159, 137 large predictions correct.
# Out of 3063, 134 large train predictions correct.
# Out of 1296, 85 carry-over large predictions correct.
# Out of 1248, 83 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_56_07.json
# Out of 5050, 713 predictions correct.
# Out of 4858, 672 train predictions correct.
# Out of 2025, 249 carry-over predictions correct.
# Out of 1929, 229 carry-over train predictions correct.
# Out of 820, 161 small predictions correct.
# Out of 724, 134 small train predictions correct.
# Out of 270, 52 carry-over small predictions correct.
# Out of 222, 39 carry-over small train predictions correct.
# Out of 3159, 384 large predictions correct.
# Out of 3063, 370 large train predictions correct.
# Out of 1296, 135 carry-over large predictions correct.
# Out of 1248, 128 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_56_09.json
# Out of 5050, 435 predictions correct.
# Out of 4858, 408 train predictions correct.
# Out of 2025, 175 carry-over predictions correct.
# Out of 1929, 165 carry-over train predictions correct.
# Out of 820, 155 small predictions correct.
# Out of 724, 132 small train predictions correct.
# Out of 270, 37 carry-over small predictions correct.
# Out of 222, 29 carry-over small train predictions correct.
# Out of 3159, 134 large predictions correct.
# Out of 3063, 130 large train predictions correct.
# Out of 1296, 77 carry-over large predictions correct.
# Out of 1248, 75 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_15_14_56_11.json
# Out of 5050, 555 predictions correct.
# Out of 4858, 527 train predictions correct.
# Out of 2025, 191 carry-over predictions correct.
# Out of 1929, 178 carry-over train predictions correct.
# Out of 820, 126 small predictions correct.
# Out of 724, 108 small train predictions correct.
# Out of 270, 38 carry-over small predictions correct.
# Out of 222, 31 carry-over small train predictions correct.
# Out of 3159, 288 large predictions correct.
# Out of 3063, 278 large train predictions correct.
# Out of 1296, 98 carry-over large predictions correct.
# Out of 1248, 92 carry-over large train predictions correct.
# Finalizado 5.
# Iniciado 7.5.
# Loaded super_trained_model_2025_01_20_12_12_41.json
# Out of 5050, 439 predictions correct.
# Out of 4858, 416 train predictions correct.
# Out of 2025, 179 carry-over predictions correct.
# Out of 1929, 177 carry-over train predictions correct.
# Out of 820, 176 small predictions correct.
# Out of 724, 155 small train predictions correct.
# Out of 270, 9 carry-over small predictions correct.
# Out of 222, 9 carry-over small train predictions correct.
# Out of 3159, 92 large predictions correct.
# Out of 3063, 90 large train predictions correct.
# Out of 1296, 92 carry-over large predictions correct.
# Out of 1248, 90 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_43.json
# Out of 5050, 388 predictions correct.
# Out of 4858, 369 train predictions correct.
# Out of 2025, 112 carry-over predictions correct.
# Out of 1929, 105 carry-over train predictions correct.
# Out of 820, 97 small predictions correct.
# Out of 724, 84 small train predictions correct.
# Out of 270, 30 carry-over small predictions correct.
# Out of 222, 25 carry-over small train predictions correct.
# Out of 3159, 192 large predictions correct.
# Out of 3063, 186 large train predictions correct.
# Out of 1296, 50 carry-over large predictions correct.
# Out of 1248, 48 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_45.json
# Out of 5050, 103 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 63 carry-over predictions correct.
# Out of 1929, 61 carry-over train predictions correct.
# Out of 820, 40 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 43 large predictions correct.
# Out of 3063, 41 large train predictions correct.
# Out of 1296, 43 carry-over large predictions correct.
# Out of 1248, 41 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_47.json
# Out of 5050, 252 predictions correct.
# Out of 4858, 234 train predictions correct.
# Out of 2025, 108 carry-over predictions correct.
# Out of 1929, 101 carry-over train predictions correct.
# Out of 820, 99 small predictions correct.
# Out of 724, 81 small train predictions correct.
# Out of 270, 32 carry-over small predictions correct.
# Out of 222, 25 carry-over small train predictions correct.
# Out of 3159, 40 large predictions correct.
# Out of 3063, 40 large train predictions correct.
# Out of 1296, 33 carry-over large predictions correct.
# Out of 1248, 33 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_49.json
# Out of 5050, 285 predictions correct.
# Out of 4858, 270 train predictions correct.
# Out of 2025, 128 carry-over predictions correct.
# Out of 1929, 125 carry-over train predictions correct.
# Out of 820, 106 small predictions correct.
# Out of 724, 94 small train predictions correct.
# Out of 270, 17 carry-over small predictions correct.
# Out of 222, 16 carry-over small train predictions correct.
# Out of 3159, 90 large predictions correct.
# Out of 3063, 87 large train predictions correct.
# Out of 1296, 64 carry-over large predictions correct.
# Out of 1248, 62 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_51.json
# Out of 5050, 219 predictions correct.
# Out of 4858, 201 train predictions correct.
# Out of 2025, 113 carry-over predictions correct.
# Out of 1929, 111 carry-over train predictions correct.
# Out of 820, 106 small predictions correct.
# Out of 724, 90 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 68 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 68 carry-over large predictions correct.
# Out of 1248, 66 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_53.json
# Out of 5050, 143 predictions correct.
# Out of 4858, 127 train predictions correct.
# Out of 2025, 71 carry-over predictions correct.
# Out of 1929, 71 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 56 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 45 large predictions correct.
# Out of 3063, 45 large train predictions correct.
# Out of 1296, 45 carry-over large predictions correct.
# Out of 1248, 45 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_55.json
# Out of 5050, 375 predictions correct.
# Out of 4858, 358 train predictions correct.
# Out of 2025, 93 carry-over predictions correct.
# Out of 1929, 87 carry-over train predictions correct.
# Out of 820, 90 small predictions correct.
# Out of 724, 76 small train predictions correct.
# Out of 270, 22 carry-over small predictions correct.
# Out of 222, 16 carry-over small train predictions correct.
# Out of 3159, 191 large predictions correct.
# Out of 3063, 188 large train predictions correct.
# Out of 1296, 38 carry-over large predictions correct.
# Out of 1248, 38 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_57.json
# Out of 5050, 587 predictions correct.
# Out of 4858, 554 train predictions correct.
# Out of 2025, 234 carry-over predictions correct.
# Out of 1929, 222 carry-over train predictions correct.
# Out of 820, 181 small predictions correct.
# Out of 724, 154 small train predictions correct.
# Out of 270, 46 carry-over small predictions correct.
# Out of 222, 36 carry-over small train predictions correct.
# Out of 3159, 196 large predictions correct.
# Out of 3063, 190 large train predictions correct.
# Out of 1296, 91 carry-over large predictions correct.
# Out of 1248, 89 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_12_59.json
# Out of 5050, 345 predictions correct.
# Out of 4858, 328 train predictions correct.
# Out of 2025, 121 carry-over predictions correct.
# Out of 1929, 112 carry-over train predictions correct.
# Out of 820, 85 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 32 carry-over small predictions correct.
# Out of 222, 25 carry-over small train predictions correct.
# Out of 3159, 167 large predictions correct.
# Out of 3063, 165 large train predictions correct.
# Out of 1296, 60 carry-over large predictions correct.
# Out of 1248, 58 carry-over large train predictions correct.
# Finalizado 7.5.
# Iniciado 10.
# Loaded super_trained_model_2025_01_20_12_13_01.json
# Out of 5050, 239 predictions correct.
# Out of 4858, 224 train predictions correct.
# Out of 2025, 140 carry-over predictions correct.
# Out of 1929, 138 carry-over train predictions correct.
# Out of 820, 90 small predictions correct.
# Out of 724, 77 small train predictions correct.
# Out of 270, 12 carry-over small predictions correct.
# Out of 222, 12 carry-over small train predictions correct.
# Out of 3159, 61 large predictions correct.
# Out of 3063, 59 large train predictions correct.
# Out of 1296, 61 carry-over large predictions correct.
# Out of 1248, 59 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_03.json
# Out of 5050, 81 predictions correct.
# Out of 4858, 71 train predictions correct.
# Out of 2025, 46 carry-over predictions correct.
# Out of 1929, 46 carry-over train predictions correct.
# Out of 820, 35 small predictions correct.
# Out of 724, 25 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 13 large predictions correct.
# Out of 3063, 13 large train predictions correct.
# Out of 1296, 13 carry-over large predictions correct.
# Out of 1248, 13 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_05.json
# Out of 5050, 36 predictions correct.
# Out of 4858, 27 train predictions correct.
# Out of 2025, 13 carry-over predictions correct.
# Out of 1929, 13 carry-over train predictions correct.
# Out of 820, 23 small predictions correct.
# Out of 724, 14 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 13 large predictions correct.
# Out of 3063, 13 large train predictions correct.
# Out of 1296, 13 carry-over large predictions correct.
# Out of 1248, 13 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_07.json
# Out of 5050, 508 predictions correct.
# Out of 4858, 482 train predictions correct.
# Out of 2025, 151 carry-over predictions correct.
# Out of 1929, 140 carry-over train predictions correct.
# Out of 820, 127 small predictions correct.
# Out of 724, 107 small train predictions correct.
# Out of 270, 40 carry-over small predictions correct.
# Out of 222, 31 carry-over small train predictions correct.
# Out of 3159, 248 large predictions correct.
# Out of 3063, 242 large train predictions correct.
# Out of 1296, 64 carry-over large predictions correct.
# Out of 1248, 62 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_09.json
# Out of 5050, 53 predictions correct.
# Out of 4858, 51 train predictions correct.
# Out of 2025, 34 carry-over predictions correct.
# Out of 1929, 34 carry-over train predictions correct.
# Out of 820, 19 small predictions correct.
# Out of 724, 17 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 13 large predictions correct.
# Out of 3063, 13 large train predictions correct.
# Out of 1296, 13 carry-over large predictions correct.
# Out of 1248, 13 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_11.json
# Out of 5050, 136 predictions correct.
# Out of 4858, 125 train predictions correct.
# Out of 2025, 77 carry-over predictions correct.
# Out of 1929, 75 carry-over train predictions correct.
# Out of 820, 59 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 49 large predictions correct.
# Out of 3063, 47 large train predictions correct.
# Out of 1296, 49 carry-over large predictions correct.
# Out of 1248, 47 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_13.json
# Out of 5050, 43 predictions correct.
# Out of 4858, 39 train predictions correct.
# Out of 2025, 24 carry-over predictions correct.
# Out of 1929, 24 carry-over train predictions correct.
# Out of 820, 22 small predictions correct.
# Out of 724, 18 small train predictions correct.
# Out of 270, 3 carry-over small predictions correct.
# Out of 222, 3 carry-over small train predictions correct.
# Out of 3159, 6 large predictions correct.
# Out of 3063, 6 large train predictions correct.
# Out of 1296, 6 carry-over large predictions correct.
# Out of 1248, 6 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_15.json
# Out of 5050, 229 predictions correct.
# Out of 4858, 202 train predictions correct.
# Out of 2025, 118 carry-over predictions correct.
# Out of 1929, 118 carry-over train predictions correct.
# Out of 820, 111 small predictions correct.
# Out of 724, 84 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 64 large predictions correct.
# Out of 3063, 64 large train predictions correct.
# Out of 1296, 64 carry-over large predictions correct.
# Out of 1248, 64 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_17.json
# Out of 5050, 512 predictions correct.
# Out of 4858, 487 train predictions correct.
# Out of 2025, 171 carry-over predictions correct.
# Out of 1929, 159 carry-over train predictions correct.
# Out of 820, 92 small predictions correct.
# Out of 724, 76 small train predictions correct.
# Out of 270, 46 carry-over small predictions correct.
# Out of 222, 36 carry-over small train predictions correct.
# Out of 3159, 285 large predictions correct.
# Out of 3063, 276 large train predictions correct.
# Out of 1296, 76 carry-over large predictions correct.
# Out of 1248, 74 carry-over large train predictions correct.
# Loaded super_trained_model_2025_01_20_12_13_19.json
# Out of 5050, 134 predictions correct.
# Out of 4858, 125 train predictions correct.
# Out of 2025, 98 carry-over predictions correct.
# Out of 1929, 95 carry-over train predictions correct.
# Out of 820, 51 small predictions correct.
# Out of 724, 44 small train predictions correct.
# Out of 270, 15 carry-over small predictions correct.
# Out of 222, 14 carry-over small train predictions correct.
# Out of 3159, 40 large predictions correct.
# Out of 3063, 38 large train predictions correct.
# Out of 1296, 40 carry-over large predictions correct.
# Out of 1248, 38 carry-over large train predictions correct.
# Finalizado 10.
