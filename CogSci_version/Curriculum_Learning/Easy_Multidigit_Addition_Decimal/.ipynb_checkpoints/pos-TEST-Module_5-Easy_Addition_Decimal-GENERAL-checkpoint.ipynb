# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Easy_Multidigit_Addition_Decimal/'
folder_specific = f'{folder}v1-Balanced_Frequencies/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model(f'{folder}Modules/unit_addition_module.keras')
unit_carry_model = load_model(f'{folder}Modules/unit_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        y_data.append([sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def construct_matrices(x):
    carry_unit_val = {}
    unit_val = {}

    for i in [0,1]:
       for j in [2,3]:
            units_inputs = jnp.array(x[:, [i, j]])
            units_input = units_inputs[:, None, :]
           
            unit_output = jnp.array(unit_addition_model(units_input))
            unit_carry_output = jnp.array(unit_carry_model(units_input))
           
            unit_val[f'{i}_{j}'] = jnp.argmax(unit_output, axis=-1)
            carry_unit_val[f'{i}_{j}'] = jnp.argmax(unit_carry_output, axis=-1)

    return carry_unit_val, unit_val


def model(params, x):
    carry_unit_val, unit_val = construct_matrices(x)
    
    salida_1 = sum(params[f'v_0_1_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_1_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i in [0,1] for j in [2,3]
        )

    # Salida 2
    salida_2 = sum(params[f'v_0_2_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_2_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i in [0,1] for j in [2,3]
        )

    return salida_1, salida_2

# %%
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
epsilons = [0.1, 0.2, 0.3, 0.5, 0.7,
            1, 1.5,
            2, 2.5,
            3, 
            5,
            7.5,
            10
           ]

# %%
x_test, y_test = generate_test_dataset()
param_type = 'AP'

for epsilon in epsilons:
    print(f'Iniciado {epsilon}.')
    
    save_dir = f"{folder_specific}Tests/"
    folder_path = f'{folder_specific}Trained_models/{param_type}_{epsilon}'
    date_pattern = r'trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
    files = sorted(
        (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
        key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
    )
    
    os.makedirs(save_dir, exist_ok=True) 
    results_file = os.path.join(save_dir, f"Tests_{param_type}_{epsilon}.txt") 
    tee = Tee(results_file, 'w') 
    sys.stdout = tee
    
    try:
        for filename in files:
            match = re.search(date_pattern, filename)
            if match:
                current_time = match.group(1)
            else:
                print('Error')
                break
            
            file_path = f"{folder_path}/trained_model_{current_time}.json"
            with open(file_path, 'rb') as file:
                trained_model = json.load(file)
        
            trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
            print(f'Loaded trained_model_{current_time}.json')
    
            predictions(trained_model_jnp, x_test, y_test)
        
    finally:
        sys.stdout = tee.console
        tee.close()

    print(f'Finalizado {epsilon}.')
# Out:
# Iniciado 0.1.
# Loaded trained_model_2025_01_15_14_52_53.json
# Out of 5050, 3486 predictions correct.
# Out of 4858, 3339 train predictions correct.
# Out of 2025, 1287 carry-over predictions correct.
# Out of 1929, 1218 carry-over train predictions correct.
# Out of 820, 746 small predictions correct.
# Out of 724, 657 small train predictions correct.
# Out of 270, 199 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 3159, 1952 large predictions correct.
# Out of 3063, 1894 large train predictions correct.
# Out of 1296, 905 carry-over large predictions correct.
# Out of 1248, 877 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_52_55.json
# Out of 5050, 3575 predictions correct.
# Out of 4858, 3420 train predictions correct.
# Out of 2025, 1200 carry-over predictions correct.
# Out of 1929, 1134 carry-over train predictions correct.
# Out of 820, 763 small predictions correct.
# Out of 724, 671 small train predictions correct.
# Out of 270, 228 carry-over small predictions correct.
# Out of 222, 184 carry-over small train predictions correct.
# Out of 3159, 1953 large predictions correct.
# Out of 3063, 1890 large train predictions correct.
# Out of 1296, 658 carry-over large predictions correct.
# Out of 1248, 636 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_52_57.json
# Out of 5050, 3909 predictions correct.
# Out of 4858, 3751 train predictions correct.
# Out of 2025, 1407 carry-over predictions correct.
# Out of 1929, 1334 carry-over train predictions correct.
# Out of 820, 746 small predictions correct.
# Out of 724, 656 small train predictions correct.
# Out of 270, 201 carry-over small predictions correct.
# Out of 222, 159 carry-over small train predictions correct.
# Out of 3159, 2306 large predictions correct.
# Out of 3063, 2238 large train predictions correct.
# Out of 1296, 960 carry-over large predictions correct.
# Out of 1248, 929 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_52_59.json
# Out of 5050, 3833 predictions correct.
# Out of 4858, 3671 train predictions correct.
# Out of 2025, 1172 carry-over predictions correct.
# Out of 1929, 1101 carry-over train predictions correct.
# Out of 820, 731 small predictions correct.
# Out of 724, 641 small train predictions correct.
# Out of 270, 201 carry-over small predictions correct.
# Out of 222, 159 carry-over small train predictions correct.
# Out of 3159, 2313 large predictions correct.
# Out of 3063, 2241 large train predictions correct.
# Out of 1296, 788 carry-over large predictions correct.
# Out of 1248, 759 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_01.json
# Out of 5050, 5005 predictions correct.
# Out of 4858, 4813 train predictions correct.
# Out of 2025, 1986 carry-over predictions correct.
# Out of 1929, 1890 carry-over train predictions correct.
# Out of 820, 811 small predictions correct.
# Out of 724, 715 small train predictions correct.
# Out of 270, 261 carry-over small predictions correct.
# Out of 222, 213 carry-over small train predictions correct.
# Out of 3159, 3145 large predictions correct.
# Out of 3063, 3049 large train predictions correct.
# Out of 1296, 1288 carry-over large predictions correct.
# Out of 1248, 1240 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_03.json
# Out of 5050, 3542 predictions correct.
# Out of 4858, 3378 train predictions correct.
# Out of 2025, 1359 carry-over predictions correct.
# Out of 1929, 1279 carry-over train predictions correct.
# Out of 820, 757 small predictions correct.
# Out of 724, 663 small train predictions correct.
# Out of 270, 239 carry-over small predictions correct.
# Out of 222, 193 carry-over small train predictions correct.
# Out of 3159, 1968 large predictions correct.
# Out of 3063, 1898 large train predictions correct.
# Out of 1296, 797 carry-over large predictions correct.
# Out of 1248, 763 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_05.json
# Out of 5050, 3914 predictions correct.
# Out of 4858, 3740 train predictions correct.
# Out of 2025, 1449 carry-over predictions correct.
# Out of 1929, 1367 carry-over train predictions correct.
# Out of 820, 768 small predictions correct.
# Out of 724, 675 small train predictions correct.
# Out of 270, 234 carry-over small predictions correct.
# Out of 222, 189 carry-over small train predictions correct.
# Out of 3159, 2281 large predictions correct.
# Out of 3063, 2200 large train predictions correct.
# Out of 1296, 894 carry-over large predictions correct.
# Out of 1248, 857 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_07.json
# Out of 5050, 3834 predictions correct.
# Out of 4858, 3668 train predictions correct.
# Out of 2025, 1379 carry-over predictions correct.
# Out of 1929, 1304 carry-over train predictions correct.
# Out of 820, 769 small predictions correct.
# Out of 724, 676 small train predictions correct.
# Out of 270, 234 carry-over small predictions correct.
# Out of 222, 189 carry-over small train predictions correct.
# Out of 3159, 2205 large predictions correct.
# Out of 3063, 2132 large train predictions correct.
# Out of 1296, 831 carry-over large predictions correct.
# Out of 1248, 801 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_09.json
# Out of 5050, 4762 predictions correct.
# Out of 4858, 4570 train predictions correct.
# Out of 2025, 1944 carry-over predictions correct.
# Out of 1929, 1848 carry-over train predictions correct.
# Out of 820, 814 small predictions correct.
# Out of 724, 718 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 2905 large predictions correct.
# Out of 3063, 2809 large train predictions correct.
# Out of 1296, 1224 carry-over large predictions correct.
# Out of 1248, 1176 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_11.json
# Out of 5050, 4841 predictions correct.
# Out of 4858, 4649 train predictions correct.
# Out of 2025, 1933 carry-over predictions correct.
# Out of 1929, 1837 carry-over train predictions correct.
# Out of 820, 804 small predictions correct.
# Out of 724, 708 small train predictions correct.
# Out of 270, 259 carry-over small predictions correct.
# Out of 222, 211 carry-over small train predictions correct.
# Out of 3159, 2999 large predictions correct.
# Out of 3063, 2903 large train predictions correct.
# Out of 1296, 1237 carry-over large predictions correct.
# Out of 1248, 1189 carry-over large train predictions correct.
# Finalizado 0.1.
# Iniciado 0.2.
# Loaded trained_model_2025_01_15_14_53_13.json
# Out of 5050, 2127 predictions correct.
# Out of 4858, 2024 train predictions correct.
# Out of 2025, 989 carry-over predictions correct.
# Out of 1929, 942 carry-over train predictions correct.
# Out of 820, 645 small predictions correct.
# Out of 724, 565 small train predictions correct.
# Out of 270, 189 carry-over small predictions correct.
# Out of 222, 157 carry-over small train predictions correct.
# Out of 3159, 850 large predictions correct.
# Out of 3063, 827 large train predictions correct.
# Out of 1296, 490 carry-over large predictions correct.
# Out of 1248, 475 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_15.json
# Out of 5050, 3391 predictions correct.
# Out of 4858, 3230 train predictions correct.
# Out of 2025, 1259 carry-over predictions correct.
# Out of 1929, 1179 carry-over train predictions correct.
# Out of 820, 749 small predictions correct.
# Out of 724, 655 small train predictions correct.
# Out of 270, 234 carry-over small predictions correct.
# Out of 222, 188 carry-over small train predictions correct.
# Out of 3159, 1839 large predictions correct.
# Out of 3063, 1772 large train predictions correct.
# Out of 1296, 719 carry-over large predictions correct.
# Out of 1248, 685 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_17.json
# Out of 5050, 2716 predictions correct.
# Out of 4858, 2587 train predictions correct.
# Out of 2025, 863 carry-over predictions correct.
# Out of 1929, 808 carry-over train predictions correct.
# Out of 820, 696 small predictions correct.
# Out of 724, 606 small train predictions correct.
# Out of 270, 206 carry-over small predictions correct.
# Out of 222, 164 carry-over small train predictions correct.
# Out of 3159, 1275 large predictions correct.
# Out of 3063, 1236 large train predictions correct.
# Out of 1296, 391 carry-over large predictions correct.
# Out of 1248, 378 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_19.json
# Out of 5050, 1857 predictions correct.
# Out of 4858, 1758 train predictions correct.
# Out of 2025, 734 carry-over predictions correct.
# Out of 1929, 699 carry-over train predictions correct.
# Out of 820, 639 small predictions correct.
# Out of 724, 571 small train predictions correct.
# Out of 270, 145 carry-over small predictions correct.
# Out of 222, 125 carry-over small train predictions correct.
# Out of 3159, 862 large predictions correct.
# Out of 3063, 831 large train predictions correct.
# Out of 1296, 406 carry-over large predictions correct.
# Out of 1248, 391 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_21.json
# Out of 5050, 1286 predictions correct.
# Out of 4858, 1216 train predictions correct.
# Out of 2025, 423 carry-over predictions correct.
# Out of 1929, 405 carry-over train predictions correct.
# Out of 820, 589 small predictions correct.
# Out of 724, 527 small train predictions correct.
# Out of 270, 106 carry-over small predictions correct.
# Out of 222, 92 carry-over small train predictions correct.
# Out of 3159, 219 large predictions correct.
# Out of 3063, 211 large train predictions correct.
# Out of 1296, 134 carry-over large predictions correct.
# Out of 1248, 130 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_23.json
# Out of 5050, 2748 predictions correct.
# Out of 4858, 2605 train predictions correct.
# Out of 2025, 962 carry-over predictions correct.
# Out of 1929, 891 carry-over train predictions correct.
# Out of 820, 678 small predictions correct.
# Out of 724, 587 small train predictions correct.
# Out of 270, 215 carry-over small predictions correct.
# Out of 222, 171 carry-over small train predictions correct.
# Out of 3159, 1383 large predictions correct.
# Out of 3063, 1331 large train predictions correct.
# Out of 1296, 493 carry-over large predictions correct.
# Out of 1248, 466 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_25.json
# Out of 5050, 3478 predictions correct.
# Out of 4858, 3323 train predictions correct.
# Out of 2025, 1197 carry-over predictions correct.
# Out of 1929, 1128 carry-over train predictions correct.
# Out of 820, 735 small predictions correct.
# Out of 724, 645 small train predictions correct.
# Out of 270, 200 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 3159, 1960 large predictions correct.
# Out of 3063, 1895 large train predictions correct.
# Out of 1296, 799 carry-over large predictions correct.
# Out of 1248, 772 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_27.json
# Out of 5050, 888 predictions correct.
# Out of 4858, 827 train predictions correct.
# Out of 2025, 388 carry-over predictions correct.
# Out of 1929, 372 carry-over train predictions correct.
# Out of 820, 467 small predictions correct.
# Out of 724, 408 small train predictions correct.
# Out of 270, 98 carry-over small predictions correct.
# Out of 222, 84 carry-over small train predictions correct.
# Out of 3159, 111 large predictions correct.
# Out of 3063, 109 large train predictions correct.
# Out of 1296, 111 carry-over large predictions correct.
# Out of 1248, 109 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_29.json
# Out of 5050, 2215 predictions correct.
# Out of 4858, 2121 train predictions correct.
# Out of 2025, 987 carry-over predictions correct.
# Out of 1929, 954 carry-over train predictions correct.
# Out of 820, 615 small predictions correct.
# Out of 724, 552 small train predictions correct.
# Out of 270, 119 carry-over small predictions correct.
# Out of 222, 104 carry-over small train predictions correct.
# Out of 3159, 957 large predictions correct.
# Out of 3063, 926 large train predictions correct.
# Out of 1296, 584 carry-over large predictions correct.
# Out of 1248, 566 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_31.json
# Out of 5050, 2522 predictions correct.
# Out of 4858, 2395 train predictions correct.
# Out of 2025, 840 carry-over predictions correct.
# Out of 1929, 781 carry-over train predictions correct.
# Out of 820, 613 small predictions correct.
# Out of 724, 527 small train predictions correct.
# Out of 270, 191 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 3159, 1243 large predictions correct.
# Out of 3063, 1202 large train predictions correct.
# Out of 1296, 405 carry-over large predictions correct.
# Out of 1248, 386 carry-over large train predictions correct.
# Finalizado 0.2.
# Iniciado 0.3.
# Loaded trained_model_2025_01_15_14_53_33.json
# Out of 5050, 901 predictions correct.
# Out of 4858, 850 train predictions correct.
# Out of 2025, 283 carry-over predictions correct.
# Out of 1929, 278 carry-over train predictions correct.
# Out of 820, 372 small predictions correct.
# Out of 724, 327 small train predictions correct.
# Out of 270, 32 carry-over small predictions correct.
# Out of 222, 30 carry-over small train predictions correct.
# Out of 3159, 190 large predictions correct.
# Out of 3063, 184 large train predictions correct.
# Out of 1296, 118 carry-over large predictions correct.
# Out of 1248, 115 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_35.json
# Out of 5050, 2490 predictions correct.
# Out of 4858, 2402 train predictions correct.
# Out of 2025, 642 carry-over predictions correct.
# Out of 1929, 626 carry-over train predictions correct.
# Out of 820, 621 small predictions correct.
# Out of 724, 568 small train predictions correct.
# Out of 270, 91 carry-over small predictions correct.
# Out of 222, 86 carry-over small train predictions correct.
# Out of 3159, 1218 large predictions correct.
# Out of 3063, 1183 large train predictions correct.
# Out of 1296, 368 carry-over large predictions correct.
# Out of 1248, 357 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_37.json
# Out of 5050, 636 predictions correct.
# Out of 4858, 589 train predictions correct.
# Out of 2025, 260 carry-over predictions correct.
# Out of 1929, 258 carry-over train predictions correct.
# Out of 820, 330 small predictions correct.
# Out of 724, 287 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 148 large predictions correct.
# Out of 3063, 144 large train predictions correct.
# Out of 1296, 102 carry-over large predictions correct.
# Out of 1248, 100 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_39.json
# Out of 5050, 1037 predictions correct.
# Out of 4858, 979 train predictions correct.
# Out of 2025, 447 carry-over predictions correct.
# Out of 1929, 434 carry-over train predictions correct.
# Out of 820, 430 small predictions correct.
# Out of 724, 380 small train predictions correct.
# Out of 270, 68 carry-over small predictions correct.
# Out of 222, 61 carry-over small train predictions correct.
# Out of 3159, 247 large predictions correct.
# Out of 3063, 239 large train predictions correct.
# Out of 1296, 216 carry-over large predictions correct.
# Out of 1248, 210 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_41.json
# Out of 5050, 1128 predictions correct.
# Out of 4858, 1063 train predictions correct.
# Out of 2025, 391 carry-over predictions correct.
# Out of 1929, 381 carry-over train predictions correct.
# Out of 820, 431 small predictions correct.
# Out of 724, 381 small train predictions correct.
# Out of 270, 24 carry-over small predictions correct.
# Out of 222, 21 carry-over small train predictions correct.
# Out of 3159, 411 large predictions correct.
# Out of 3063, 396 large train predictions correct.
# Out of 1296, 224 carry-over large predictions correct.
# Out of 1248, 217 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_43.json
# Out of 5050, 437 predictions correct.
# Out of 4858, 402 train predictions correct.
# Out of 2025, 230 carry-over predictions correct.
# Out of 1929, 228 carry-over train predictions correct.
# Out of 820, 207 small predictions correct.
# Out of 724, 174 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 102 large predictions correct.
# Out of 3063, 100 large train predictions correct.
# Out of 1296, 102 carry-over large predictions correct.
# Out of 1248, 100 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_45.json
# Out of 5050, 3104 predictions correct.
# Out of 4858, 2978 train predictions correct.
# Out of 2025, 1072 carry-over predictions correct.
# Out of 1929, 1025 carry-over train predictions correct.
# Out of 820, 691 small predictions correct.
# Out of 724, 614 small train predictions correct.
# Out of 270, 163 carry-over small predictions correct.
# Out of 222, 134 carry-over small train predictions correct.
# Out of 3159, 1584 large predictions correct.
# Out of 3063, 1535 large train predictions correct.
# Out of 1296, 598 carry-over large predictions correct.
# Out of 1248, 580 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_47.json
# Out of 5050, 1211 predictions correct.
# Out of 4858, 1143 train predictions correct.
# Out of 2025, 428 carry-over predictions correct.
# Out of 1929, 419 carry-over train predictions correct.
# Out of 820, 350 small predictions correct.
# Out of 724, 303 small train predictions correct.
# Out of 270, 9 carry-over small predictions correct.
# Out of 222, 8 carry-over small train predictions correct.
# Out of 3159, 642 large predictions correct.
# Out of 3063, 621 large train predictions correct.
# Out of 1296, 256 carry-over large predictions correct.
# Out of 1248, 248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_49.json
# Out of 5050, 1536 predictions correct.
# Out of 4858, 1470 train predictions correct.
# Out of 2025, 721 carry-over predictions correct.
# Out of 1929, 701 carry-over train predictions correct.
# Out of 820, 393 small predictions correct.
# Out of 724, 348 small train predictions correct.
# Out of 270, 63 carry-over small predictions correct.
# Out of 222, 58 carry-over small train predictions correct.
# Out of 3159, 683 large predictions correct.
# Out of 3063, 662 large train predictions correct.
# Out of 1296, 458 carry-over large predictions correct.
# Out of 1248, 443 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_51.json
# Out of 5050, 1874 predictions correct.
# Out of 4858, 1786 train predictions correct.
# Out of 2025, 703 carry-over predictions correct.
# Out of 1929, 684 carry-over train predictions correct.
# Out of 820, 551 small predictions correct.
# Out of 724, 498 small train predictions correct.
# Out of 270, 92 carry-over small predictions correct.
# Out of 222, 87 carry-over small train predictions correct.
# Out of 3159, 1041 large predictions correct.
# Out of 3063, 1006 large train predictions correct.
# Out of 1296, 428 carry-over large predictions correct.
# Out of 1248, 414 carry-over large train predictions correct.
# Finalizado 0.3.
# Iniciado 0.5.
# Loaded trained_model_2025_01_15_14_53_53.json
# Out of 5050, 602 predictions correct.
# Out of 4858, 554 train predictions correct.
# Out of 2025, 334 carry-over predictions correct.
# Out of 1929, 319 carry-over train predictions correct.
# Out of 820, 320 small predictions correct.
# Out of 724, 272 small train predictions correct.
# Out of 270, 84 carry-over small predictions correct.
# Out of 222, 69 carry-over small train predictions correct.
# Out of 3159, 79 large predictions correct.
# Out of 3063, 79 large train predictions correct.
# Out of 1296, 79 carry-over large predictions correct.
# Out of 1248, 79 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_55.json
# Out of 5050, 1303 predictions correct.
# Out of 4858, 1246 train predictions correct.
# Out of 2025, 437 carry-over predictions correct.
# Out of 1929, 426 carry-over train predictions correct.
# Out of 820, 441 small predictions correct.
# Out of 724, 394 small train predictions correct.
# Out of 270, 64 carry-over small predictions correct.
# Out of 222, 59 carry-over small train predictions correct.
# Out of 3159, 367 large predictions correct.
# Out of 3063, 357 large train predictions correct.
# Out of 1296, 224 carry-over large predictions correct.
# Out of 1248, 218 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_57.json
# Out of 5050, 415 predictions correct.
# Out of 4858, 372 train predictions correct.
# Out of 2025, 207 carry-over predictions correct.
# Out of 1929, 205 carry-over train predictions correct.
# Out of 820, 208 small predictions correct.
# Out of 724, 167 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 94 large predictions correct.
# Out of 3063, 92 large train predictions correct.
# Out of 1296, 94 carry-over large predictions correct.
# Out of 1248, 92 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_53_59.json
# Out of 5050, 2278 predictions correct.
# Out of 4858, 2184 train predictions correct.
# Out of 2025, 820 carry-over predictions correct.
# Out of 1929, 785 carry-over train predictions correct.
# Out of 820, 529 small predictions correct.
# Out of 724, 466 small train predictions correct.
# Out of 270, 133 carry-over small predictions correct.
# Out of 222, 112 carry-over small train predictions correct.
# Out of 3159, 1103 large predictions correct.
# Out of 3063, 1072 large train predictions correct.
# Out of 1296, 428 carry-over large predictions correct.
# Out of 1248, 414 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_01.json
# Out of 5050, 1394 predictions correct.
# Out of 4858, 1320 train predictions correct.
# Out of 2025, 474 carry-over predictions correct.
# Out of 1929, 451 carry-over train predictions correct.
# Out of 820, 457 small predictions correct.
# Out of 724, 398 small train predictions correct.
# Out of 270, 89 carry-over small predictions correct.
# Out of 222, 75 carry-over small train predictions correct.
# Out of 3159, 479 large predictions correct.
# Out of 3063, 464 large train predictions correct.
# Out of 1296, 201 carry-over large predictions correct.
# Out of 1248, 192 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_03.json
# Out of 5050, 587 predictions correct.
# Out of 4858, 559 train predictions correct.
# Out of 2025, 253 carry-over predictions correct.
# Out of 1929, 250 carry-over train predictions correct.
# Out of 820, 230 small predictions correct.
# Out of 724, 205 small train predictions correct.
# Out of 270, 32 carry-over small predictions correct.
# Out of 222, 31 carry-over small train predictions correct.
# Out of 3159, 100 large predictions correct.
# Out of 3063, 97 large train predictions correct.
# Out of 1296, 87 carry-over large predictions correct.
# Out of 1248, 85 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_05.json
# Out of 5050, 1421 predictions correct.
# Out of 4858, 1346 train predictions correct.
# Out of 2025, 442 carry-over predictions correct.
# Out of 1929, 412 carry-over train predictions correct.
# Out of 820, 366 small predictions correct.
# Out of 724, 312 small train predictions correct.
# Out of 270, 117 carry-over small predictions correct.
# Out of 222, 94 carry-over small train predictions correct.
# Out of 3159, 662 large predictions correct.
# Out of 3063, 641 large train predictions correct.
# Out of 1296, 172 carry-over large predictions correct.
# Out of 1248, 165 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_07.json
# Out of 5050, 1001 predictions correct.
# Out of 4858, 953 train predictions correct.
# Out of 2025, 428 carry-over predictions correct.
# Out of 1929, 420 carry-over train predictions correct.
# Out of 820, 205 small predictions correct.
# Out of 724, 174 small train predictions correct.
# Out of 270, 12 carry-over small predictions correct.
# Out of 222, 11 carry-over small train predictions correct.
# Out of 3159, 576 large predictions correct.
# Out of 3063, 559 large train predictions correct.
# Out of 1296, 249 carry-over large predictions correct.
# Out of 1248, 242 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_09.json
# Out of 5050, 1092 predictions correct.
# Out of 4858, 1028 train predictions correct.
# Out of 2025, 292 carry-over predictions correct.
# Out of 1929, 286 carry-over train predictions correct.
# Out of 820, 394 small predictions correct.
# Out of 724, 347 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 513 large predictions correct.
# Out of 3063, 496 large train predictions correct.
# Out of 1296, 206 carry-over large predictions correct.
# Out of 1248, 200 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_11.json
# Out of 5050, 255 predictions correct.
# Out of 4858, 230 train predictions correct.
# Out of 2025, 102 carry-over predictions correct.
# Out of 1929, 100 carry-over train predictions correct.
# Out of 820, 148 small predictions correct.
# Out of 724, 125 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 90 large predictions correct.
# Out of 3063, 88 large train predictions correct.
# Out of 1296, 90 carry-over large predictions correct.
# Out of 1248, 88 carry-over large train predictions correct.
# Finalizado 0.5.
# Iniciado 0.7.
# Loaded trained_model_2025_01_15_14_54_13.json
# Out of 5050, 823 predictions correct.
# Out of 4858, 774 train predictions correct.
# Out of 2025, 322 carry-over predictions correct.
# Out of 1929, 315 carry-over train predictions correct.
# Out of 820, 377 small predictions correct.
# Out of 724, 331 small train predictions correct.
# Out of 270, 57 carry-over small predictions correct.
# Out of 222, 52 carry-over small train predictions correct.
# Out of 3159, 131 large predictions correct.
# Out of 3063, 128 large train predictions correct.
# Out of 1296, 111 carry-over large predictions correct.
# Out of 1248, 109 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_15.json
# Out of 5050, 230 predictions correct.
# Out of 4858, 204 train predictions correct.
# Out of 2025, 118 carry-over predictions correct.
# Out of 1929, 118 carry-over train predictions correct.
# Out of 820, 112 small predictions correct.
# Out of 724, 86 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 65 large predictions correct.
# Out of 3063, 65 large train predictions correct.
# Out of 1296, 65 carry-over large predictions correct.
# Out of 1248, 65 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_17.json
# Out of 5050, 974 predictions correct.
# Out of 4858, 931 train predictions correct.
# Out of 2025, 593 carry-over predictions correct.
# Out of 1929, 580 carry-over train predictions correct.
# Out of 820, 286 small predictions correct.
# Out of 724, 252 small train predictions correct.
# Out of 270, 52 carry-over small predictions correct.
# Out of 222, 47 carry-over small train predictions correct.
# Out of 3159, 387 large predictions correct.
# Out of 3063, 378 large train predictions correct.
# Out of 1296, 353 carry-over large predictions correct.
# Out of 1248, 345 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_19.json
# Out of 5050, 209 predictions correct.
# Out of 4858, 187 train predictions correct.
# Out of 2025, 115 carry-over predictions correct.
# Out of 1929, 115 carry-over train predictions correct.
# Out of 820, 94 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 59 large predictions correct.
# Out of 3063, 59 large train predictions correct.
# Out of 1296, 59 carry-over large predictions correct.
# Out of 1248, 59 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_21.json
# Out of 5050, 565 predictions correct.
# Out of 4858, 526 train predictions correct.
# Out of 2025, 201 carry-over predictions correct.
# Out of 1929, 199 carry-over train predictions correct.
# Out of 820, 290 small predictions correct.
# Out of 724, 253 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 111 large predictions correct.
# Out of 3063, 109 large train predictions correct.
# Out of 1296, 111 carry-over large predictions correct.
# Out of 1248, 109 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_23.json
# Out of 5050, 200 predictions correct.
# Out of 4858, 178 train predictions correct.
# Out of 2025, 92 carry-over predictions correct.
# Out of 1929, 90 carry-over train predictions correct.
# Out of 820, 108 small predictions correct.
# Out of 724, 88 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 75 large predictions correct.
# Out of 3063, 73 large train predictions correct.
# Out of 1296, 75 carry-over large predictions correct.
# Out of 1248, 73 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_25.json
# Out of 5050, 255 predictions correct.
# Out of 4858, 231 train predictions correct.
# Out of 2025, 143 carry-over predictions correct.
# Out of 1929, 141 carry-over train predictions correct.
# Out of 820, 112 small predictions correct.
# Out of 724, 90 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 80 large predictions correct.
# Out of 3063, 78 large train predictions correct.
# Out of 1296, 80 carry-over large predictions correct.
# Out of 1248, 78 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_27.json
# Out of 5050, 320 predictions correct.
# Out of 4858, 291 train predictions correct.
# Out of 2025, 168 carry-over predictions correct.
# Out of 1929, 166 carry-over train predictions correct.
# Out of 820, 152 small predictions correct.
# Out of 724, 125 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 87 large predictions correct.
# Out of 3063, 85 large train predictions correct.
# Out of 1296, 87 carry-over large predictions correct.
# Out of 1248, 85 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_29.json
# Out of 5050, 687 predictions correct.
# Out of 4858, 635 train predictions correct.
# Out of 2025, 257 carry-over predictions correct.
# Out of 1929, 255 carry-over train predictions correct.
# Out of 820, 341 small predictions correct.
# Out of 724, 294 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 175 large predictions correct.
# Out of 3063, 170 large train predictions correct.
# Out of 1296, 102 carry-over large predictions correct.
# Out of 1248, 100 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_31.json
# Out of 5050, 269 predictions correct.
# Out of 4858, 249 train predictions correct.
# Out of 2025, 110 carry-over predictions correct.
# Out of 1929, 108 carry-over train predictions correct.
# Out of 820, 136 small predictions correct.
# Out of 724, 118 small train predictions correct.
# Out of 270, 6 carry-over small predictions correct.
# Out of 222, 6 carry-over small train predictions correct.
# Out of 3159, 62 large predictions correct.
# Out of 3063, 60 large train predictions correct.
# Out of 1296, 62 carry-over large predictions correct.
# Out of 1248, 60 carry-over large train predictions correct.
# Finalizado 0.7.
# Iniciado 1.
# Loaded trained_model_2025_01_15_14_54_33.json
# Out of 5050, 245 predictions correct.
# Out of 4858, 220 train predictions correct.
# Out of 2025, 132 carry-over predictions correct.
# Out of 1929, 132 carry-over train predictions correct.
# Out of 820, 113 small predictions correct.
# Out of 724, 88 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 79 large predictions correct.
# Out of 3063, 79 large train predictions correct.
# Out of 1296, 79 carry-over large predictions correct.
# Out of 1248, 79 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_35.json
# Out of 5050, 84 predictions correct.
# Out of 4858, 70 train predictions correct.
# Out of 2025, 41 carry-over predictions correct.
# Out of 1929, 41 carry-over train predictions correct.
# Out of 820, 43 small predictions correct.
# Out of 724, 29 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 24 large predictions correct.
# Out of 3063, 24 large train predictions correct.
# Out of 1296, 24 carry-over large predictions correct.
# Out of 1248, 24 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_37.json
# Out of 5050, 273 predictions correct.
# Out of 4858, 256 train predictions correct.
# Out of 2025, 123 carry-over predictions correct.
# Out of 1929, 120 carry-over train predictions correct.
# Out of 820, 121 small predictions correct.
# Out of 724, 106 small train predictions correct.
# Out of 270, 15 carry-over small predictions correct.
# Out of 222, 14 carry-over small train predictions correct.
# Out of 3159, 66 large predictions correct.
# Out of 3063, 64 large train predictions correct.
# Out of 1296, 66 carry-over large predictions correct.
# Out of 1248, 64 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_39.json
# Out of 5050, 220 predictions correct.
# Out of 4858, 203 train predictions correct.
# Out of 2025, 96 carry-over predictions correct.
# Out of 1929, 96 carry-over train predictions correct.
# Out of 820, 119 small predictions correct.
# Out of 724, 102 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 60 large predictions correct.
# Out of 3063, 60 large train predictions correct.
# Out of 1296, 60 carry-over large predictions correct.
# Out of 1248, 60 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_41.json
# Out of 5050, 182 predictions correct.
# Out of 4858, 160 train predictions correct.
# Out of 2025, 83 carry-over predictions correct.
# Out of 1929, 83 carry-over train predictions correct.
# Out of 820, 99 small predictions correct.
# Out of 724, 77 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 65 large predictions correct.
# Out of 3063, 65 large train predictions correct.
# Out of 1296, 65 carry-over large predictions correct.
# Out of 1248, 65 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_43.json
# Out of 5050, 1336 predictions correct.
# Out of 4858, 1275 train predictions correct.
# Out of 2025, 294 carry-over predictions correct.
# Out of 1929, 289 carry-over train predictions correct.
# Out of 820, 484 small predictions correct.
# Out of 724, 436 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 25 carry-over small train predictions correct.
# Out of 3159, 388 large predictions correct.
# Out of 3063, 375 large train predictions correct.
# Out of 1296, 147 carry-over large predictions correct.
# Out of 1248, 144 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_45.json
# Out of 5050, 453 predictions correct.
# Out of 4858, 426 train predictions correct.
# Out of 2025, 212 carry-over predictions correct.
# Out of 1929, 207 carry-over train predictions correct.
# Out of 820, 176 small predictions correct.
# Out of 724, 152 small train predictions correct.
# Out of 270, 14 carry-over small predictions correct.
# Out of 222, 12 carry-over small train predictions correct.
# Out of 3159, 145 large predictions correct.
# Out of 3063, 142 large train predictions correct.
# Out of 1296, 141 carry-over large predictions correct.
# Out of 1248, 138 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_47.json
# Out of 5050, 135 predictions correct.
# Out of 4858, 116 train predictions correct.
# Out of 2025, 59 carry-over predictions correct.
# Out of 1929, 59 carry-over train predictions correct.
# Out of 820, 76 small predictions correct.
# Out of 724, 57 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 47 large predictions correct.
# Out of 3063, 47 large train predictions correct.
# Out of 1296, 47 carry-over large predictions correct.
# Out of 1248, 47 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_49.json
# Out of 5050, 125 predictions correct.
# Out of 4858, 115 train predictions correct.
# Out of 2025, 74 carry-over predictions correct.
# Out of 1929, 74 carry-over train predictions correct.
# Out of 820, 51 small predictions correct.
# Out of 724, 41 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 47 large predictions correct.
# Out of 3063, 47 large train predictions correct.
# Out of 1296, 47 carry-over large predictions correct.
# Out of 1248, 47 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_51.json
# Out of 5050, 305 predictions correct.
# Out of 4858, 277 train predictions correct.
# Out of 2025, 173 carry-over predictions correct.
# Out of 1929, 173 carry-over train predictions correct.
# Out of 820, 132 small predictions correct.
# Out of 724, 104 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 78 large predictions correct.
# Out of 3063, 78 large train predictions correct.
# Out of 1296, 78 carry-over large predictions correct.
# Out of 1248, 78 carry-over large train predictions correct.
# Finalizado 1.
# Iniciado 1.5.
# Loaded trained_model_2025_01_15_14_54_53.json
# Out of 5050, 279 predictions correct.
# Out of 4858, 263 train predictions correct.
# Out of 2025, 147 carry-over predictions correct.
# Out of 1929, 144 carry-over train predictions correct.
# Out of 820, 96 small predictions correct.
# Out of 724, 83 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 124 large predictions correct.
# Out of 3063, 121 large train predictions correct.
# Out of 1296, 124 carry-over large predictions correct.
# Out of 1248, 121 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_55.json
# Out of 5050, 773 predictions correct.
# Out of 4858, 733 train predictions correct.
# Out of 2025, 325 carry-over predictions correct.
# Out of 1929, 308 carry-over train predictions correct.
# Out of 820, 233 small predictions correct.
# Out of 724, 202 small train predictions correct.
# Out of 270, 72 carry-over small predictions correct.
# Out of 222, 61 carry-over small train predictions correct.
# Out of 3159, 273 large predictions correct.
# Out of 3063, 264 large train predictions correct.
# Out of 1296, 125 carry-over large predictions correct.
# Out of 1248, 119 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_57.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 85 train predictions correct.
# Out of 2025, 57 carry-over predictions correct.
# Out of 1929, 57 carry-over train predictions correct.
# Out of 820, 38 small predictions correct.
# Out of 724, 28 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 47 large predictions correct.
# Out of 3063, 47 large train predictions correct.
# Out of 1296, 47 carry-over large predictions correct.
# Out of 1248, 47 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_54_59.json
# Out of 5050, 519 predictions correct.
# Out of 4858, 486 train predictions correct.
# Out of 2025, 252 carry-over predictions correct.
# Out of 1929, 247 carry-over train predictions correct.
# Out of 820, 162 small predictions correct.
# Out of 724, 137 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 280 large predictions correct.
# Out of 3063, 272 large train predictions correct.
# Out of 1296, 191 carry-over large predictions correct.
# Out of 1248, 186 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_01.json
# Out of 5050, 48 predictions correct.
# Out of 4858, 40 train predictions correct.
# Out of 2025, 24 carry-over predictions correct.
# Out of 1929, 24 carry-over train predictions correct.
# Out of 820, 24 small predictions correct.
# Out of 724, 16 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 12 large predictions correct.
# Out of 3063, 12 large train predictions correct.
# Out of 1296, 12 carry-over large predictions correct.
# Out of 1248, 12 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_03.json
# Out of 5050, 36 predictions correct.
# Out of 4858, 28 train predictions correct.
# Out of 2025, 18 carry-over predictions correct.
# Out of 1929, 18 carry-over train predictions correct.
# Out of 820, 18 small predictions correct.
# Out of 724, 10 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 12 large predictions correct.
# Out of 3063, 12 large train predictions correct.
# Out of 1296, 12 carry-over large predictions correct.
# Out of 1248, 12 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_05.json
# Out of 5050, 131 predictions correct.
# Out of 4858, 121 train predictions correct.
# Out of 2025, 78 carry-over predictions correct.
# Out of 1929, 78 carry-over train predictions correct.
# Out of 820, 53 small predictions correct.
# Out of 724, 43 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 47 large predictions correct.
# Out of 3063, 47 large train predictions correct.
# Out of 1296, 47 carry-over large predictions correct.
# Out of 1248, 47 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_07.json
# Out of 5050, 242 predictions correct.
# Out of 4858, 221 train predictions correct.
# Out of 2025, 91 carry-over predictions correct.
# Out of 1929, 91 carry-over train predictions correct.
# Out of 820, 133 small predictions correct.
# Out of 724, 112 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 60 large predictions correct.
# Out of 3063, 60 large train predictions correct.
# Out of 1296, 60 carry-over large predictions correct.
# Out of 1248, 60 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_09.json
# Out of 5050, 413 predictions correct.
# Out of 4858, 392 train predictions correct.
# Out of 2025, 129 carry-over predictions correct.
# Out of 1929, 121 carry-over train predictions correct.
# Out of 820, 120 small predictions correct.
# Out of 724, 102 small train predictions correct.
# Out of 270, 37 carry-over small predictions correct.
# Out of 222, 29 carry-over small train predictions correct.
# Out of 3159, 163 large predictions correct.
# Out of 3063, 160 large train predictions correct.
# Out of 1296, 41 carry-over large predictions correct.
# Out of 1248, 41 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_11.json
# Out of 5050, 145 predictions correct.
# Out of 4858, 130 train predictions correct.
# Out of 2025, 79 carry-over predictions correct.
# Out of 1929, 79 carry-over train predictions correct.
# Out of 820, 66 small predictions correct.
# Out of 724, 51 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 52 large predictions correct.
# Out of 3063, 52 large train predictions correct.
# Out of 1296, 52 carry-over large predictions correct.
# Out of 1248, 52 carry-over large train predictions correct.
# Finalizado 1.5.
# Iniciado 2.
# Loaded trained_model_2025_01_15_14_55_13.json
# Out of 5050, 203 predictions correct.
# Out of 4858, 184 train predictions correct.
# Out of 2025, 66 carry-over predictions correct.
# Out of 1929, 64 carry-over train predictions correct.
# Out of 820, 127 small predictions correct.
# Out of 724, 110 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 45 large predictions correct.
# Out of 3063, 43 large train predictions correct.
# Out of 1296, 45 carry-over large predictions correct.
# Out of 1248, 43 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_15.json
# Out of 5050, 135 predictions correct.
# Out of 4858, 122 train predictions correct.
# Out of 2025, 77 carry-over predictions correct.
# Out of 1929, 77 carry-over train predictions correct.
# Out of 820, 58 small predictions correct.
# Out of 724, 45 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 45 large predictions correct.
# Out of 3063, 45 large train predictions correct.
# Out of 1296, 45 carry-over large predictions correct.
# Out of 1248, 45 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_17.json
# Out of 5050, 249 predictions correct.
# Out of 4858, 230 train predictions correct.
# Out of 2025, 35 carry-over predictions correct.
# Out of 1929, 35 carry-over train predictions correct.
# Out of 820, 101 small predictions correct.
# Out of 724, 85 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 148 large predictions correct.
# Out of 3063, 145 large train predictions correct.
# Out of 1296, 35 carry-over large predictions correct.
# Out of 1248, 35 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_55_19.json
# Out of 5050, 558 predictions correct.
# Out of 4858, 526 train predictions correct.
# Out of 2025, 196 carry-over predictions correct.
# Out of 1929, 178 carry-over train predictions correct.
# Out of 820, 136 small predictions correct.
# Out of 724, 112 small train predictions correct.
# Out of 270, 45 carry-over small predictions correct.
# Out of 222, 32 carry-over small train predictions correct.
# Out of 3159, 263 large predictions correct.
# Out of 3063, 255 large train predictions correct.
# Out of 1296, 86 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# ...
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_56_03.json
# Out of 5050, 9 predictions correct.
# Out of 4858, 9 train predictions correct.
# Out of 2025, 6 carry-over predictions correct.
# Out of 1929, 6 carry-over train predictions correct.
# Out of 820, 3 small predictions correct.
# Out of 724, 3 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 6 large predictions correct.
# Out of 3063, 6 large train predictions correct.
# Out of 1296, 6 carry-over large predictions correct.
# Out of 1248, 6 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_56_05.json
# Out of 5050, 3 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 3 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_56_07.json
# Out of 5050, 28 predictions correct.
# Out of 4858, 22 train predictions correct.
# Out of 2025, 19 carry-over predictions correct.
# Out of 1929, 19 carry-over train predictions correct.
# Out of 820, 9 small predictions correct.
# Out of 724, 3 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 19 large predictions correct.
# Out of 3063, 19 large train predictions correct.
# Out of 1296, 19 carry-over large predictions correct.
# Out of 1248, 19 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_56_09.json
# Out of 5050, 18 predictions correct.
# Out of 4858, 16 train predictions correct.
# Out of 2025, 14 carry-over predictions correct.
# Out of 1929, 14 carry-over train predictions correct.
# Out of 820, 4 small predictions correct.
# Out of 724, 2 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 14 large predictions correct.
# Out of 3063, 14 large train predictions correct.
# Out of 1296, 14 carry-over large predictions correct.
# Out of 1248, 14 carry-over large train predictions correct.
# Loaded trained_model_2025_01_15_14_56_11.json
# Out of 5050, 37 predictions correct.
# Out of 4858, 33 train predictions correct.
# Out of 2025, 19 carry-over predictions correct.
# Out of 1929, 19 carry-over train predictions correct.
# Out of 820, 18 small predictions correct.
# Out of 724, 14 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 15 large predictions correct.
# Out of 3063, 15 large train predictions correct.
# Out of 1296, 15 carry-over large predictions correct.
# Out of 1248, 15 carry-over large train predictions correct.
# Finalizado 5.
# Iniciado 7.5.
# Loaded trained_model_2025_01_20_12_12_41.json
# Out of 5050, 3 predictions correct.
# Out of 4858, 2 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 3 small predictions correct.
# Out of 724, 2 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_43.json
# Out of 5050, 11 predictions correct.
# Out of 4858, 11 train predictions correct.
# Out of 2025, 6 carry-over predictions correct.
# Out of 1929, 6 carry-over train predictions correct.
# Out of 820, 5 small predictions correct.
# Out of 724, 5 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 6 large predictions correct.
# Out of 3063, 6 large train predictions correct.
# Out of 1296, 6 carry-over large predictions correct.
# Out of 1248, 6 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_45.json
# Out of 5050, 1 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_47.json
# Out of 5050, 3 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 3 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_49.json
# Out of 5050, 3 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 3 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_51.json
# Out of 5050, 1 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_53.json
# Out of 5050, 9 predictions correct.
# Out of 4858, 8 train predictions correct.
# Out of 2025, 6 carry-over predictions correct.
# Out of 1929, 6 carry-over train predictions correct.
# Out of 820, 3 small predictions correct.
# Out of 724, 2 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_55.json
# Out of 5050, 59 predictions correct.
# Out of 4858, 58 train predictions correct.
# Out of 2025, 37 carry-over predictions correct.
# Out of 1929, 37 carry-over train predictions correct.
# Out of 820, 18 small predictions correct.
# Out of 724, 17 small train predictions correct.
# Out of 270, 6 carry-over small predictions correct.
# Out of 222, 6 carry-over small train predictions correct.
# Out of 3159, 23 large predictions correct.
# Out of 3063, 23 large train predictions correct.
# Out of 1296, 20 carry-over large predictions correct.
# Out of 1248, 20 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_57.json
# Out of 5050, 9 predictions correct.
# Out of 4858, 7 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 9 small predictions correct.
# Out of 724, 7 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_12_59.json
# Out of 5050, 13 predictions correct.
# Out of 4858, 13 train predictions correct.
# Out of 2025, 7 carry-over predictions correct.
# Out of 1929, 7 carry-over train predictions correct.
# Out of 820, 6 small predictions correct.
# Out of 724, 6 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 7 large predictions correct.
# Out of 3063, 7 large train predictions correct.
# Out of 1296, 7 carry-over large predictions correct.
# Out of 1248, 7 carry-over large train predictions correct.
# Finalizado 7.5.
# Iniciado 10.
# Loaded trained_model_2025_01_20_12_13_01.json
# Out of 5050, 3 predictions correct.
# Out of 4858, 3 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 3 small predictions correct.
# Out of 724, 3 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_03.json
# Out of 5050, 7 predictions correct.
# Out of 4858, 7 train predictions correct.
# Out of 2025, 5 carry-over predictions correct.
# Out of 1929, 5 carry-over train predictions correct.
# Out of 820, 2 small predictions correct.
# Out of 724, 2 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_05.json
# Out of 5050, 1 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_07.json
# Out of 5050, 4 predictions correct.
# Out of 4858, 4 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 4 small predictions correct.
# Out of 724, 4 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_09.json
# Out of 5050, 1 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_11.json
# Out of 5050, 1 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_13.json
# Out of 5050, 1 predictions correct.
# Out of 4858, 1 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_15.json
# Out of 5050, 4 predictions correct.
# Out of 4858, 3 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 4 small predictions correct.
# Out of 724, 3 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_17.json
# Out of 5050, 14 predictions correct.
# Out of 4858, 14 train predictions correct.
# Out of 2025, 12 carry-over predictions correct.
# Out of 1929, 12 carry-over train predictions correct.
# Out of 820, 2 small predictions correct.
# Out of 724, 2 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 6 large predictions correct.
# Out of 3063, 6 large train predictions correct.
# Out of 1296, 6 carry-over large predictions correct.
# Out of 1248, 6 carry-over large train predictions correct.
# Loaded trained_model_2025_01_20_12_13_19.json
# Out of 5050, 8 predictions correct.
# Out of 4858, 8 train predictions correct.
# Out of 2025, 7 carry-over predictions correct.
# Out of 1929, 7 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 7 large predictions correct.
# Out of 3063, 7 large train predictions correct.
# Out of 1296, 7 carry-over large predictions correct.
# Out of 1248, 7 carry-over large train predictions correct.
# Finalizado 10.
