# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_small_problem_size_binary.txt", 'r') as file:
    combinations_small_problem_size_binary = eval(file.read())

with open(f"{folder}/combinations_with_carry_over_decimal.txt", 'r') as file:
    combinations_with_carry_over_decimal = eval(file.read())

with open(f"{folder}/real_test_dataset_small_problem_size.txt", 'r') as file:
    real_test_dataset_small_problem_size = eval(file.read())

with open(f"{folder}/real_test_dataset_small_problem_size_binary.txt", 'r') as file:
    real_test_dataset_small_problem_size_binary = eval(file.read())

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_dataset_with_carry_over = eval(file.read())

with open(f"{folder}/real_test_dataset_with_carry_over_decimal.txt", 'r') as file:
    real_test_dataset_with_carry_over_decimal = eval(file.read())
    

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_carry_over_decimal = [pair for pair in train_couples if pair in combinations_with_carry_over_decimal]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)
    #column_1, column_2 = zip(*test_dataset)
    
    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None

# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z
    
def neural_network_2(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)
    
# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_count, correct_predictions_test_count, train_count, correct_predictions_train_count, test_carry_over_count, correct_carry_over_predictions_test_count, train_carry_over_count, correct_carry_over_predictions_train_count, small_train_count, correct_predictions_small_train_count, small_test_count, correct_predictions_small_test_count, small_train_carry_count, correct_predictions_small_train_carry_count, small_test_carry_count, correct_predictions_small_test_carry_count, test_carry_over_decimal_count, correct_carry_over_decimal_predictions_test_count, train_carry_over_decimal_count, correct_carry_over_decimal_predictions_train_count, small_train_carry_decimal_count, correct_predictions_small_train_carry_decimal_count, small_test_carry_decimal_count, correct_predictions_small_test_carry_decimal_count, small_binary_train_count, correct_predictions_small_binary_train_count, small_binary_test_count, correct_predictions_small_binary_test_count, small_binary_train_carry_count, correct_predictions_small_binary_train_carry_count, small_binary_test_carry_count, correct_predictions_small_binary_test_carry_count, small_binary_train_carry_decimal_count, correct_predictions_small_binary_train_carry_decimal_count, small_binary_test_carry_decimal_count, correct_predictions_small_binary_test_carry_decimal_count, reaction_time_carry, reaction_time_carry_decimal, reaction_time_train,reaction_time_test, reaction_time_train_carry, reaction_time_train_carry_decimal, reaction_time_small_train, reaction_time_small_test, reaction_time_small_train_carry, reaction_time_small_test_carry, reaction_time_small_train_carry_decimal, reaction_time_small_test_carry_decimal, reaction_time_small_binary_train, reaction_time_small_binary_test, reaction_time_small_binary_train_carry, reaction_time_small_binary_test_carry, reaction_time_small_binary_train_carry_decimal, reaction_time_small_binary_test_carry_decimal = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_count}, {correct_predictions_train_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_count}, {correct_predictions_test_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_count}, {correct_carry_over_predictions_train_count} trained with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_count}, {correct_carry_over_predictions_test_count} tested with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_count}, {correct_predictions_small_train_count} trained with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_test_count}, {correct_predictions_small_test_count} tested with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_count}, {correct_predictions_small_train_carry_count} trained with small problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_count}, {correct_predictions_small_test_carry_count} tested with small problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_train_count} trained with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_test_count} tested with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_decimal_count}, {correct_predictions_small_train_carry_decimal_count} trained with small problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_decimal_count}, {correct_predictions_small_test_carry_decimal_count} tested with small problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_count}, {correct_predictions_small_binary_train_count} trained with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_test_count}, {correct_predictions_small_binary_test_count} tested with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_count}, {correct_predictions_small_binary_train_carry_count} trained with small binary problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_count}, {correct_predictions_small_binary_test_carry_count} tested with small binary problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_decimal_count}, {correct_predictions_small_binary_train_carry_decimal_count} trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_decimal_count}, {correct_predictions_small_binary_test_carry_decimal_count} tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: {reaction_time_carry} reaction time with carry over.")
        print(f"STAGE {stage}: {reaction_time_carry_decimal} reaction time with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_train} reaction time for train.")
        print(f"STAGE {stage}: {reaction_time_test} reaction time for test.")
        print(f"STAGE {stage}: {reaction_time_train_carry} reaction time for train with carry over .")
        print(f"STAGE {stage}: {reaction_time_train_carry_decimal} reaction time for train with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_small_train} reaction time for train small.")
        print(f"STAGE {stage}: {reaction_time_small_test} reaction time for test small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry} reaction time for train with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry} reaction time for test with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry_decimal} reaction time for train with carry over decimal and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry_decimal} reaction time for test with carry over decimal and small.") 
        print(f"STAGE {stage}: {reaction_time_small_binary_train} reaction time for train small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test} reaction time for test small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry} reaction time for train with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry} reaction time for test with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry_decimal} reaction time for train with carry over decimal and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry_decimal} reaction time for test with carry over decimal and small binary.") 
            
    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

def real_test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_real_test_dataset()    
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_test_count = 0
    correct_predictions_train_count = 0
    correct_carry_over_predictions_count = 0
    correct_carry_over_predictions_test_count = 0
    correct_carry_over_predictions_train_count = 0
    correct_predictions_small_train_count = 0
    correct_predictions_small_test_count = 0
    correct_predictions_small_train_carry_count = 0
    correct_predictions_small_test_carry_count = 0
    correct_carry_over_decimal_predictions_count = 0
    correct_carry_over_decimal_predictions_test_count = 0
    correct_carry_over_decimal_predictions_train_count = 0
    correct_predictions_small_train_carry_decimal_count = 0
    correct_predictions_small_test_carry_decimal_count = 0
    correct_predictions_small_binary_train_count = 0
    correct_predictions_small_binary_test_count = 0
    correct_predictions_small_binary_train_carry_count = 0
    correct_predictions_small_binary_test_carry_count = 0
    correct_predictions_small_binary_train_carry_decimal_count = 0
    correct_predictions_small_binary_test_carry_decimal_count = 0
    
    set_size = inputs_1.shape[0]
    train_count = len(train_couples)
    test_count = set_size - train_count
    carry_over_count = len(combinations_with_carry_over) 
    carry_over_decimal_count = len(combinations_with_carry_over_decimal) 
    train_carry_over_count = len(train_with_carry_over)
    test_carry_over_count = carry_over_count - train_carry_over_count
    small_count = len(combinations_small_problem_size)
    small_binary_count = len(combinations_small_problem_size_binary)
    train_carry_over_decimal_count = len(train_with_carry_over_decimal)
    test_carry_over_decimal_count = carry_over_decimal_count - train_carry_over_decimal_count

    # Contadores adicionales
    small_train_count = 0
    small_test_count = 0
    small_train_carry_count = 0
    small_test_carry_count = 0
    small_train_carry_decimal_count = 0
    small_test_carry_decimal_count = 0
    small_binary_train_count = 0
    small_binary_test_count = 0
    small_binary_train_carry_count = 0
    small_binary_test_carry_count = 0
    small_binary_train_carry_decimal_count = 0
    small_binary_test_carry_decimal_count = 0
    
    reaction_time_carry = 0
    reaction_time_carry_decimal = 0
    reaction_time_train = 0
    reaction_time_test = 0
    reaction_time_train_carry = 0
    reaction_time_train_carry_decimal = 0
    reaction_time_small_train = 0
    reaction_time_small_test = 0
    reaction_time_small_train_carry = 0
    reaction_time_small_test_carry = 0
    reaction_time_small_train_carry_decimal = 0
    reaction_time_small_test_carry_decimal = 0
    reaction_time_small_binary_train = 0
    reaction_time_small_binary_test = 0
    reaction_time_small_binary_train_carry = 0
    reaction_time_small_binary_test_carry = 0
    reaction_time_small_binary_train_carry_decimal = 0
    reaction_time_small_binary_test_carry_decimal = 0

    for i in range(set_size):
        pair = (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1])

        start_time = time.perf_counter_ns()
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        elapsed_time = time.perf_counter_ns() - start_time

        #is_small = pair in combinations_small_problem_size
        #is_small_binary = pair in combinations_small_problem_size_binary
        #is_train = pair in train_couples
        #is_carry = pair in combinations_with_carry_over
        #is_carry_decimal = pair in combinations_with_carry_over_decimal

        is_small = pair in real_test_dataset_small_problem_size
        is_small_binary = pair in real_test_dataset_small_problem_size_binary
        is_train = pair in train_couples
        is_carry = pair in real_test_dataset_with_carry_over
        is_carry_decimal = pair in real_test_dataset_with_carry_over_decimal

        # Actualizar tiempos de reacción y contadores totales
        if is_small:
            if is_train:
                small_train_count += 1
                reaction_time_small_train += elapsed_time
                if is_carry:
                    small_train_carry_count += 1
                    reaction_time_small_train_carry += elapsed_time
                if is_carry_decimal:
                    small_train_carry_decimal_count += 1
                    reaction_time_small_train_carry_decimal += elapsed_time
            else:
                small_test_count += 1
                reaction_time_small_test += elapsed_time
                if is_carry:
                    small_test_carry_count += 1
                    reaction_time_small_test_carry += elapsed_time
                if is_carry_decimal:
                    small_test_carry_decimal_count += 1
                    reaction_time_small_test_carry_decimal += elapsed_time

        # Actualizar tiempos de reacción y contadores totales
        if is_small_binary:
            if is_train:
                small_binary_train_count += 1
                reaction_time_small_binary_train += elapsed_time
                if is_carry:
                    small_binary_train_carry_count += 1
                    reaction_time_small_binary_train_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_train_carry_decimal_count += 1
                    reaction_time_small_binary_train_carry_decimal += elapsed_time
            else:
                small_binary_test_count += 1
                reaction_time_small_binary_test += elapsed_time
                if is_carry:
                    small_binary_test_carry_count += 1
                    reaction_time_small_binary_test_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_test_carry_decimal_count += 1
                    reaction_time_small_binary_test_carry_decimal += elapsed_time

        if is_carry:
            reaction_time_carry += elapsed_time
        if is_carry_decimal:
            reaction_time_carry_decimal += elapsed_time
        if is_train:
            reaction_time_train += elapsed_time
        else:
            reaction_time_test += elapsed_time
        if is_train and is_carry:
            reaction_time_train_carry += elapsed_time
        if is_train and is_carry_decimal:
            reaction_time_train_carry_decimal += elapsed_time

        # Contar predicciones correctas
        if jnp.all(prediction == outputs[i]):
            if is_small:
                if is_train:
                    correct_predictions_small_train_count += 1
                    if is_carry:
                        correct_predictions_small_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_test_count += 1
                    if is_carry:
                        correct_predictions_small_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_test_carry_decimal_count += 1

            if is_small_binary:
                if is_train:
                    correct_predictions_small_binary_train_count += 1
                    if is_carry:
                        correct_predictions_small_binary_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_binary_test_count += 1
                    if is_carry:
                        correct_predictions_small_binary_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_test_carry_decimal_count += 1

            # Actualizar contadores previos
            if is_carry:
                correct_carry_over_predictions_count += 1 
            if is_carry_decimal:
                correct_carry_over_decimal_predictions_count += 1 
            if is_train:
                correct_predictions_train_count += 1 
            else:
                correct_predictions_test_count += 1
            if is_train and is_carry:
                correct_carry_over_predictions_train_count += 1   
            if is_train and is_carry_decimal:
                correct_carry_over_decimal_predictions_train_count += 1 
                
        elif visualize_errors == 1:
            print(f'{pair[0]} plus {pair[1]} has failed.')

    correct_carry_over_predictions_test_count = correct_carry_over_predictions_count - correct_carry_over_predictions_train_count
    correct_carry_over_decimal_predictions_test_count = correct_carry_over_decimal_predictions_count - correct_carry_over_decimal_predictions_train_count
    
    return (
        test_count,
        correct_predictions_test_count,
        train_count,
        correct_predictions_train_count,
        test_carry_over_count,
        correct_carry_over_predictions_test_count,
        train_carry_over_count,
        correct_carry_over_predictions_train_count,
        small_train_count,
        correct_predictions_small_train_count,
        small_test_count,
        correct_predictions_small_test_count,
        small_train_carry_count,
        correct_predictions_small_train_carry_count,
        small_test_carry_count,
        correct_predictions_small_test_carry_count,
        test_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_test_count,
        train_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_train_count,
        small_train_carry_decimal_count,
        correct_predictions_small_train_carry_decimal_count,
        small_test_carry_decimal_count,
        correct_predictions_small_test_carry_decimal_count,
        small_binary_train_count,
        correct_predictions_small_binary_train_count,
        small_binary_test_count,
        correct_predictions_small_binary_test_count,
        small_binary_train_carry_count,
        correct_predictions_small_binary_train_carry_count,
        small_binary_test_carry_count,
        correct_predictions_small_binary_test_carry_count,
        small_binary_train_carry_decimal_count,
        correct_predictions_small_binary_train_carry_decimal_count,
        small_binary_test_carry_decimal_count,
        correct_predictions_small_binary_test_carry_decimal_count,
        reaction_time_carry,
        reaction_time_carry_decimal,
        reaction_time_train,
        reaction_time_test,
        reaction_time_train_carry,
        reaction_time_train_carry_decimal,
        reaction_time_small_train,
        reaction_time_small_test,
        reaction_time_small_train_carry,
        reaction_time_small_test_carry,
        reaction_time_small_train_carry_decimal,
        reaction_time_small_test_carry_decimal,
        reaction_time_small_binary_train,
        reaction_time_small_binary_test,
        reaction_time_small_binary_train_carry,
        reaction_time_small_binary_test_carry,
        reaction_time_small_binary_train_carry_decimal,
        reaction_time_small_binary_test_carry_decimal
    )

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stage_by_stage/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
validation_performance = 'no'
easy_examples = 'no'
type_training = 'Stage_by_stage'
file_name = 'AP_0.1_0.1'

if easy_examples == 'yes':
    if validation_performance == 'yes':
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_2'
    
else:
    if validation_performance == 'yes':    
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_2'

os.makedirs(os.path.dirname(output_file), exist_ok=True)

tee = Tee(output_file, 'w') 
sys.stdout = tee

try:
    visualize_errors = 0
    model = 'trainable_model_stage'
    
    date_pattern = r'trainable_model_stage_2-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
    files = sorted(
        (f for f in os.listdir(folder_path) if f.endswith('.pkl') and not f.startswith('.')),  # Filtrar archivos .pkl y ocultos
        key=lambda x: re.search(date_pattern, x).group(0) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
    
        for stage in range(1, 3):
            if easy_examples == 'yes':
                if validation_performance == 'yes':    
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                    
            else:
                if validation_performance == 'yes':   
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'

            with open(file_path, 'rb') as file:
                globals()[f"{model}_{stage}"] = pickle.load(file)
    
            print(f'Loaded {model}_{stage}-{current_time}.pkl')

            real_test = 1
            decide_test(params=globals()[f"{model}_{stage}"], stage=stage, real_test=real_test, visualize_errors=visualize_errors)
                
finally:
    sys.stdout = tee.console
    tee.close()
    
print(f'Finished, file {file_name} created')
# Out:
# Loaded trainable_model_stage_1-2024_11_19_13_21_53.pkl
# STAGE 1: Out of 8000, 3580 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 3905 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 2567 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 3389 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 705 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 437 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 268 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 159 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2572 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1924 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 288 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 153 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3041 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 2392 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2028 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 1876 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2033 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 1092 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16264088300 reaction time with carry over.
# STAGE 1: 11426377300 reaction time with carry over decimal.
# STAGE 1: 9205357900 reaction time for train.
# STAGE 1: 9745585800 reaction time for test.
# STAGE 1: 7428812700 reaction time for train with carry over .
# STAGE 1: 6376598300 reaction time for train with carry over decimal.
# STAGE 1: 1923800200 reaction time for train small.
# STAGE 1: 1181533500 reaction time for test small.
# STAGE 1: 1074063100 reaction time for train with carry over and small.
# STAGE 1: 648091700 reaction time for test with carry over and small.
# STAGE 1: 813101300 reaction time for train with carry over decimal and small.
# STAGE 1: 466051100 reaction time for test with carry over decimal and small.
# STAGE 1: 8036539600 reaction time for train small binary.
# STAGE 1: 6142947300 reaction time for test small binary.
# STAGE 1: 6259994400 reaction time for train with carry over and small binary.
# STAGE 1: 5232637100 reaction time for test with carry over and small binary.
# STAGE 1: 5207780000 reaction time for train with carry over decimal and small binary.
# STAGE 1: 2934109600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_13_21_53.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 19021768300 reaction time with carry over.
# STAGE 2: 13272864600 reaction time with carry over decimal.
# STAGE 2: 10855025300 reaction time for train.
# STAGE 2: 11211686000 reaction time for test.
# STAGE 2: 8769427200 reaction time for train with carry over .
# STAGE 2: 7458792300 reaction time for train with carry over decimal.
# STAGE 2: 2279581400 reaction time for train small.
# STAGE 2: 1257683200 reaction time for test small.
# STAGE 2: 1303814700 reaction time for train with carry over and small.
# STAGE 2: 750405700 reaction time for test with carry over and small.
# STAGE 2: 975686900 reaction time for train with carry over decimal and small.
# STAGE 2: 536390000 reaction time for test with carry over decimal and small.
# STAGE 2: 9533805500 reaction time for train small binary.
# STAGE 2: 7135209200 reaction time for test small binary.
# STAGE 2: 7448207400 reaction time for train with carry over and small binary.
# STAGE 2: 6175864300 reaction time for test with carry over and small binary.
# STAGE 2: 6137572500 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3398308200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_18_48_37.pkl
# STAGE 1: Out of 8000, 4700 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 4262 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 3977 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 3942 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 999 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 557 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 627 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 358 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 3205 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 2279 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 429 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 241 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 4126 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 2839 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 3403 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 2519 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2631 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 1382 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16870679400 reaction time with carry over.
# STAGE 1: 11846891500 reaction time with carry over decimal.
# STAGE 1: 9420551700 reaction time for train.
# STAGE 1: 10041039000 reaction time for test.
# STAGE 1: 7657932600 reaction time for train with carry over .
# STAGE 1: 6584257000 reaction time for train with carry over decimal.
# STAGE 1: 1873798500 reaction time for train small.
# STAGE 1: 1071109800 reaction time for test small.
# STAGE 1: 1098657600 reaction time for train with carry over and small.
# STAGE 1: 636613900 reaction time for test with carry over and small.
# STAGE 1: 833102300 reaction time for train with carry over decimal and small.
# STAGE 1: 469279200 reaction time for test with carry over decimal and small.
# STAGE 1: 8163551900 reaction time for train small binary.
# STAGE 1: 6200327400 reaction time for test small binary.
# STAGE 1: 6400932800 reaction time for train with carry over and small binary.
# STAGE 1: 5372035200 reaction time for test with carry over and small binary.
# STAGE 1: 5327257200 reaction time for train with carry over decimal and small binary.
# STAGE 1: 2989741100 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_18_48_37.pkl
# STAGE 2: Out of 8000, 4959 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 3908 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4265 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 3508 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 571 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 505 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 388 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 351 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3584 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1964 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 272 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 247 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4474 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 3279 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3780 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 2879 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3099 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1648 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20319805700 reaction time with carry over.
# STAGE 2: 14250258400 reaction time with carry over decimal.
# STAGE 2: 11600589500 reaction time for train.
# STAGE 2: 11892098300 reaction time for test.
# STAGE 2: 9456849100 reaction time for train with carry over .
# STAGE 2: 8057603700 reaction time for train with carry over decimal.
# STAGE 2: 2347211200 reaction time for train small.
# STAGE 2: 1386229600 reaction time for test small.
# STAGE 2: 1391753500 reaction time for train with carry over and small.
# STAGE 2: 822829200 reaction time for test with carry over and small.
# STAGE 2: 1037721000 reaction time for train with carry over decimal and small.
# STAGE 2: 590264600 reaction time for test with carry over decimal and small.
# STAGE 2: 10133520300 reaction time for train small binary.
# STAGE 2: 7601476400 reaction time for test small binary.
# STAGE 2: 7989779900 reaction time for train with carry over and small binary.
# STAGE 2: 6572334700 reaction time for test with carry over and small binary.
# STAGE 2: 6590534500 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3640596700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_02_27_59.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8377 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7666 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4381 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16759141900 reaction time with carry over.
# STAGE 1: 11759245100 reaction time with carry over decimal.
# STAGE 1: 9463095600 reaction time for train.
# STAGE 1: 9960762700 reaction time for test.
# STAGE 1: 7667706100 reaction time for train with carry over .
# STAGE 1: 6537462100 reaction time for train with carry over decimal.
# STAGE 1: 1957258100 reaction time for train small.
# STAGE 1: 1172663900 reaction time for test small.
# STAGE 1: 1145430900 reaction time for train with carry over and small.
# STAGE 1: 695441400 reaction time for test with carry over and small.
# STAGE 1: 847563400 reaction time for train with carry over decimal and small.
# STAGE 1: 503881700 reaction time for test with carry over decimal and small.
# STAGE 1: 8295494800 reaction time for train small binary.
# STAGE 1: 6288741900 reaction time for test small binary.
# STAGE 1: 6500105300 reaction time for train with carry over and small binary.
# STAGE 1: 5419415000 reaction time for test with carry over and small binary.
# STAGE 1: 5369861300 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3047660600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_02_27_59.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20729830300 reaction time with carry over.
# STAGE 2: 14601090100 reaction time with carry over decimal.
# STAGE 2: 11792458700 reaction time for train.
# STAGE 2: 12177884500 reaction time for test.
# STAGE 2: 9619969200 reaction time for train with carry over .
# STAGE 2: 8270591500 reaction time for train with carry over decimal.
# STAGE 2: 2396325700 reaction time for train small.
# STAGE 2: 1449451600 reaction time for test small.
# STAGE 2: 1416858200 reaction time for train with carry over and small.
# STAGE 2: 866406100 reaction time for test with carry over and small.
# STAGE 2: 1064244000 reaction time for train with carry over decimal and small.
# STAGE 2: 617737200 reaction time for test with carry over decimal and small.
# STAGE 2: 10250546600 reaction time for train small binary.
# STAGE 2: 7686978200 reaction time for test small binary.
# STAGE 2: 8078057100 reaction time for train with carry over and small binary.
# STAGE 2: 6618954800 reaction time for test with carry over and small binary.
# STAGE 2: 6728679400 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3681922600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_06_49_46.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8162 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7451 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4276 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5293 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4582 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2555 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17027511800 reaction time with carry over.
# STAGE 1: 11940435200 reaction time with carry over decimal.
# STAGE 1: 9634625900 reaction time for train.
# STAGE 1: 10043777000 reaction time for test.
# STAGE 1: 7826374000 reaction time for train with carry over .
# STAGE 1: 6679017100 reaction time for train with carry over decimal.
# STAGE 1: 1953176700 reaction time for train small.
# STAGE 1: 1105483100 reaction time for test small.
# STAGE 1: 1149083100 reaction time for train with carry over and small.
# STAGE 1: 655152800 reaction time for test with carry over and small.
# STAGE 1: 855101400 reaction time for train with carry over decimal and small.
# STAGE 1: 481873600 reaction time for test with carry over decimal and small.
# STAGE 1: 8425822600 reaction time for train small binary.
# STAGE 1: 6292311100 reaction time for test small binary.
# STAGE 1: 6617570700 reaction time for train with carry over and small binary.
# STAGE 1: 5449671900 reaction time for test with carry over and small binary.
# STAGE 1: 5470213800 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3033050500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_06_49_46.pkl
# STAGE 2: Out of 8000, 3 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 2 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 3 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 1 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 1 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 1 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 2 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 1 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20652403100 reaction time with carry over.
# STAGE 2: 14465472800 reaction time with carry over decimal.
# STAGE 2: 11637643000 reaction time for train.
# STAGE 2: 12259474600 reaction time for test.
# STAGE 2: 9447279100 reaction time for train with carry over .
# STAGE 2: 8068020700 reaction time for train with carry over decimal.
# STAGE 2: 2431444800 reaction time for train small.
# STAGE 2: 1414793700 reaction time for test small.
# STAGE 2: 1432786700 reaction time for train with carry over and small.
# STAGE 2: 836807200 reaction time for test with carry over and small.
# STAGE 2: 1043612100 reaction time for train with carry over decimal and small.
# STAGE 2: 606728900 reaction time for test with carry over decimal and small.
# STAGE 2: 10120110100 reaction time for train small binary.
# STAGE 2: 7766605700 reaction time for test small binary.
# STAGE 2: 7929746200 reaction time for train with carry over and small binary.
# STAGE 2: 6712255100 reaction time for test with carry over and small binary.
# STAGE 2: 6550487800 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3704931200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_02_35.pkl
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 6306 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 4506 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 5595 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1211 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 709 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 560 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 331 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 3999 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 3045 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 479 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 277 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 5225 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 3991 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 3749 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 3280 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 3242 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 1759 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17321839600 reaction time with carry over.
# STAGE 1: 12121320000 reaction time with carry over decimal.
# STAGE 1: 9657723300 reaction time for train.
# STAGE 1: 10376963200 reaction time for test.
# STAGE 1: 7830094300 reaction time for train with carry over .
# STAGE 1: 6688867500 reaction time for train with carry over decimal.
# STAGE 1: 1960746800 reaction time for train small.
# STAGE 1: 1155153400 reaction time for test small.
# STAGE 1: 1132878600 reaction time for train with carry over and small.
# STAGE 1: 684523800 reaction time for test with carry over and small.
# STAGE 1: 850773600 reaction time for train with carry over decimal and small.
# STAGE 1: 496963400 reaction time for test with carry over decimal and small.
# STAGE 1: 8429823900 reaction time for train small binary.
# STAGE 1: 6472644800 reaction time for test small binary.
# STAGE 1: 6602194900 reaction time for train with carry over and small binary.
# STAGE 1: 5587426900 reaction time for test with carry over and small binary.
# STAGE 1: 5460968100 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3110885000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_02_35.pkl
# STAGE 2: Out of 8000, 3 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20405820500 reaction time with carry over.
# STAGE 2: 14352073600 reaction time with carry over decimal.
# STAGE 2: 11649150300 reaction time for train.
# STAGE 2: 11931586700 reaction time for test.
# STAGE 2: 9493827400 reaction time for train with carry over .
# STAGE 2: 8111378300 reaction time for train with carry over decimal.
# STAGE 2: 2343579200 reaction time for train small.
# STAGE 2: 1367800000 reaction time for test small.
# STAGE 2: 1400766600 reaction time for train with carry over and small.
# STAGE 2: 822958500 reaction time for test with carry over and small.
# STAGE 2: 1043808500 reaction time for train with carry over decimal and small.
# STAGE 2: 589571900 reaction time for test with carry over decimal and small.
# STAGE 2: 10153078400 reaction time for train small binary.
# STAGE 2: 7598559200 reaction time for test small binary.
# STAGE 2: 7997755500 reaction time for train with carry over and small binary.
# STAGE 2: 6578965600 reaction time for test with carry over and small binary.
# STAGE 2: 6615306400 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3675931300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_24_06.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8384 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7673 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17581040000 reaction time with carry over.
# STAGE 1: 12313914300 reaction time with carry over decimal.
# STAGE 1: 9975518400 reaction time for train.
# STAGE 1: 10356998400 reaction time for test.
# STAGE 1: 8108893100 reaction time for train with carry over .
# STAGE 1: 6942338300 reaction time for train with carry over decimal.
# STAGE 1: 2037306900 reaction time for train small.
# STAGE 1: 1158656000 reaction time for test small.
# STAGE 1: 1205206000 reaction time for train with carry over and small.
# STAGE 1: 699663800 reaction time for test with carry over and small.
# STAGE 1: 903808300 reaction time for train with carry over decimal and small.
# STAGE 1: 503830800 reaction time for test with carry over decimal and small.
# STAGE 1: 8755557900 reaction time for train small binary.
# STAGE 1: 6606116500 reaction time for test small binary.
# STAGE 1: 6888932600 reaction time for train with carry over and small binary.
# STAGE 1: 5721265000 reaction time for test with carry over and small binary.
# STAGE 1: 5722377800 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3170391000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_24_06.pkl
# STAGE 2: Out of 8000, 4 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 1 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 4 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 1 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 1 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 1 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20797915700 reaction time with carry over.
# STAGE 2: 14634770700 reaction time with carry over decimal.
# STAGE 2: 11773118300 reaction time for train.
# STAGE 2: 12321702700 reaction time for test.
# STAGE 2: 9540314100 reaction time for train with carry over .
# STAGE 2: 8206496800 reaction time for train with carry over decimal.
# STAGE 2: 2374571100 reaction time for train small.
# STAGE 2: 1369391700 reaction time for test small.
# STAGE 2: 1386448400 reaction time for train with carry over and small.
# STAGE 2: 814580500 reaction time for test with carry over and small.
# STAGE 2: 1049504800 reaction time for train with carry over decimal and small.
# STAGE 2: 590390400 reaction time for test with carry over decimal and small.
# STAGE 2: 10283104300 reaction time for train small binary.
# STAGE 2: 7853242900 reaction time for test small binary.
# STAGE 2: 8050300100 reaction time for train with carry over and small binary.
# STAGE 2: 6789141800 reaction time for test with carry over and small binary.
# STAGE 2: 6716482800 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3752790200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_24_08.pkl
# STAGE 1: Out of 8000, 3396 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 3628 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 2390 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 3106 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 754 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 524 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 304 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 223 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2409 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1856 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 271 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 173 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 2884 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 2209 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 1878 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 1687 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 1897 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 1006 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17016469900 reaction time with carry over.
# STAGE 1: 11856984100 reaction time with carry over decimal.
# STAGE 1: 9534519100 reaction time for train.
# STAGE 1: 10086981000 reaction time for test.
# STAGE 1: 7778473000 reaction time for train with carry over .
# STAGE 1: 6603717000 reaction time for train with carry over decimal.
# STAGE 1: 1925870800 reaction time for train small.
# STAGE 1: 1148571200 reaction time for test small.
# STAGE 1: 1143156400 reaction time for train with carry over and small.
# STAGE 1: 690149300 reaction time for test with carry over and small.
# STAGE 1: 843123400 reaction time for train with carry over decimal and small.
# STAGE 1: 501836300 reaction time for test with carry over decimal and small.
# STAGE 1: 8349596900 reaction time for train small binary.
# STAGE 1: 6391419800 reaction time for test small binary.
# STAGE 1: 6593550800 reaction time for train with carry over and small binary.
# STAGE 1: 5542435700 reaction time for test with carry over and small binary.
# STAGE 1: 5418794800 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3074792800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_24_08.pkl
# STAGE 2: Out of 8000, 3168 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 2133 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 2772 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1842 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 309 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 374 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 245 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 248 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 2269 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1026 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 171 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 170 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 2959 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 1854 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 2563 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 1563 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2060 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 878 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20443935900 reaction time with carry over.
# STAGE 2: 14278094000 reaction time with carry over decimal.
# STAGE 2: 11505541300 reaction time for train.
# STAGE 2: 12066357000 reaction time for test.
# STAGE 2: 9382511200 reaction time for train with carry over .
# STAGE 2: 7991866700 reaction time for train with carry over decimal.
# STAGE 2: 2354800900 reaction time for train small.
# STAGE 2: 1353592400 reaction time for test small.
# STAGE 2: 1398255300 reaction time for train with carry over and small.
# STAGE 2: 812666500 reaction time for test with carry over and small.
# STAGE 2: 1063229800 reaction time for train with carry over decimal and small.
# STAGE 2: 587914800 reaction time for test with carry over decimal and small.
# STAGE 2: 10008256700 reaction time for train small binary.
# STAGE 2: 7627853600 reaction time for test small binary.
# STAGE 2: 7885226600 reaction time for train with carry over and small binary.
# STAGE 2: 6622921300 reaction time for test with carry over and small binary.
# STAGE 2: 6494582100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3663127600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_24_10.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8158 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7449 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 900 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 524 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4268 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 384 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5081 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4372 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2448 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16895652400 reaction time with carry over.
# STAGE 1: 11835384500 reaction time with carry over decimal.
# ...
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20715507400 reaction time with carry over.
# STAGE 2: 14505030700 reaction time with carry over decimal.
# STAGE 2: 11722187500 reaction time for train.
# STAGE 2: 12220407600 reaction time for test.
# STAGE 2: 9537001400 reaction time for train with carry over .
# STAGE 2: 8133558200 reaction time for train with carry over decimal.
# STAGE 2: 2314287200 reaction time for train small.
# STAGE 2: 1343792200 reaction time for test small.
# STAGE 2: 1343863200 reaction time for train with carry over and small.
# STAGE 2: 786721800 reaction time for test with carry over and small.
# STAGE 2: 999458300 reaction time for train with carry over decimal and small.
# STAGE 2: 567774400 reaction time for test with carry over decimal and small.
# STAGE 2: 10261573700 reaction time for train small binary.
# STAGE 2: 7807488800 reaction time for test small binary.
# STAGE 2: 8076387600 reaction time for train with carry over and small binary.
# STAGE 2: 6765587200 reaction time for test with carry over and small binary.
# STAGE 2: 6672944400 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3766706800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_28_48.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8384 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7673 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16922736700 reaction time with carry over.
# STAGE 1: 11811052900 reaction time with carry over decimal.
# STAGE 1: 9546821600 reaction time for train.
# STAGE 1: 10001063300 reaction time for test.
# STAGE 1: 7763043100 reaction time for train with carry over .
# STAGE 1: 6608794700 reaction time for train with carry over decimal.
# STAGE 1: 1922246800 reaction time for train small.
# STAGE 1: 1125929100 reaction time for test small.
# STAGE 1: 1131098500 reaction time for train with carry over and small.
# STAGE 1: 676925200 reaction time for test with carry over and small.
# STAGE 1: 856451200 reaction time for train with carry over decimal and small.
# STAGE 1: 484096100 reaction time for test with carry over decimal and small.
# STAGE 1: 8376937800 reaction time for train small binary.
# STAGE 1: 6328418900 reaction time for test small binary.
# STAGE 1: 6593159300 reaction time for train with carry over and small binary.
# STAGE 1: 5487049200 reaction time for test with carry over and small binary.
# STAGE 1: 5438910900 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3037967300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_28_48.pkl
# STAGE 2: Out of 8000, 6098 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 4571 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 5156 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 4014 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 907 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 712 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 658 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 448 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 4354 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 2249 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 452 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 308 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 5256 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 3587 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4314 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 3030 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3512 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1727 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20612785400 reaction time with carry over.
# STAGE 2: 14430792400 reaction time with carry over decimal.
# STAGE 2: 11640696700 reaction time for train.
# STAGE 2: 12135309800 reaction time for test.
# STAGE 2: 9502506100 reaction time for train with carry over .
# STAGE 2: 8100763100 reaction time for train with carry over decimal.
# STAGE 2: 2315620600 reaction time for train small.
# STAGE 2: 1351432200 reaction time for test small.
# STAGE 2: 1367338600 reaction time for train with carry over and small.
# STAGE 2: 812198000 reaction time for test with carry over and small.
# STAGE 2: 1037536300 reaction time for train with carry over decimal and small.
# STAGE 2: 600758800 reaction time for test with carry over decimal and small.
# STAGE 2: 10180625800 reaction time for train small binary.
# STAGE 2: 7718420500 reaction time for test small binary.
# STAGE 2: 8042435200 reaction time for train with carry over and small binary.
# STAGE 2: 6693390000 reaction time for test with carry over and small binary.
# STAGE 2: 6640692200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3728746800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_28_50.pkl
# STAGE 1: Out of 8000, 2072 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 1493 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 1566 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1268 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 605 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 233 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 256 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 87 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 1374 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 694 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 242 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 86 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 1637 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 1004 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 1131 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 779 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 939 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 457 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16780009600 reaction time with carry over.
# STAGE 1: 11798143500 reaction time with carry over decimal.
# STAGE 1: 9475851500 reaction time for train.
# STAGE 1: 9939158000 reaction time for test.
# STAGE 1: 7693476400 reaction time for train with carry over .
# STAGE 1: 6595262100 reaction time for train with carry over decimal.
# STAGE 1: 1936185400 reaction time for train small.
# STAGE 1: 1130443800 reaction time for test small.
# STAGE 1: 1127362200 reaction time for train with carry over and small.
# STAGE 1: 679112300 reaction time for test with carry over and small.
# STAGE 1: 841762200 reaction time for train with carry over decimal and small.
# STAGE 1: 491483300 reaction time for test with carry over decimal and small.
# STAGE 1: 8311085600 reaction time for train small binary.
# STAGE 1: 6358097900 reaction time for test small binary.
# STAGE 1: 6528710500 reaction time for train with carry over and small binary.
# STAGE 1: 5505473100 reaction time for test with carry over and small binary.
# STAGE 1: 5430496200 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3086522000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_28_50.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20584845500 reaction time with carry over.
# STAGE 2: 14433044700 reaction time with carry over decimal.
# STAGE 2: 11607658300 reaction time for train.
# STAGE 2: 12131151900 reaction time for test.
# STAGE 2: 9470434000 reaction time for train with carry over .
# STAGE 2: 8131112600 reaction time for train with carry over decimal.
# STAGE 2: 2307424700 reaction time for train small.
# STAGE 2: 1333559100 reaction time for test small.
# STAGE 2: 1361843100 reaction time for train with carry over and small.
# STAGE 2: 797115200 reaction time for test with carry over and small.
# STAGE 2: 1039200500 reaction time for train with carry over decimal and small.
# STAGE 2: 580737700 reaction time for test with carry over decimal and small.
# STAGE 2: 10145356500 reaction time for train small binary.
# STAGE 2: 7693900500 reaction time for test small binary.
# STAGE 2: 8008132200 reaction time for train with carry over and small binary.
# STAGE 2: 6677160100 reaction time for test with carry over and small binary.
# STAGE 2: 6668810800 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3679993300 reaction time for test with carry over decimal and small binary.
# Finished, file AP_0.1_0.1 created
