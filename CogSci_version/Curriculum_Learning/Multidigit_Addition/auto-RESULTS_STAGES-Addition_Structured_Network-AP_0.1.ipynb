# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_carry_over_dataset = eval(file.read())
    
# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)

    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None


def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None


# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count, carry_over_size, correct_carry_over_predictions_tested_count = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {carry_over_size}, {correct_carry_over_predictions_tested_count} tested with carry-over were predicted correctly in the current model.")      

    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)

    correct_predictions_count = 0
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
def perfect_model():
    # R vectors of dimension (14,1)
    R2_perfect = np.zeros((14))
    R3_perfect = np.zeros((14))
    R4_perfect = np.zeros((14))
    R5_perfect = np.zeros((14))
    R6_perfect = np.zeros((14))
    R7_perfect = np.zeros((14))
    R8_perfect = np.zeros((14))
    
    for i in range(2):
        R2_perfect[7*i + 6] = 1
        R3_perfect[7*i + 5] = 1
        R4_perfect[7*i + 4] = 1
        R5_perfect[7*i + 3] = 1
        R6_perfect[7*i + 2] = 1
        R7_perfect[7*i + 1] = 1
        R8_perfect[7*i + 0] = 1
    
    # Scalar parameters v
    v2_perfect = 1/2
    v3_perfect = 1/2
    v4_perfect = 1/2
    v5_perfect = 1/2
    v6_perfect = 1/2
    v7_perfect = 1/2
    
    # Matrix T of dimension (28,7)
    T_perfect = np.zeros((14,8))
    for i in range(7):
        for j in range(2):
            T_perfect[7*j + i, i + 1] = 1
    
    # Parameter v
    v_perfect = 1/2
    
    original_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    trainable_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    return trainable_model, original_model

def generate_model_random(mean=0.5, std=1):
    R2 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the second bit
    R3 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R4 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R6 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R7 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R8 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    v2 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    T = initialize_random_weights(mean, std, (14, 8))  # 196 neurons that allow performing the sum
    v = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    trainable_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    return trainable_model, original_model
    
def generate_model_AP(epsilon_non_zeros = 0.01, epsilon_zeros = 0.01):   
    R2_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R3_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R8_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)

    for i in range(2):
        R2_almost_perfect[7*i + 6] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R8_almost_perfect[7*i + 0] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v2_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)

    T_almost_perfect = np.zeros((14,8)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(2):
            T_almost_perfect[7*j + i, i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    trainable_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
# Parámetros
epsilon_zeros = 0.1
epsilon_non_zeros = 0.1

# Ruta base
base_path = r"D:\OneDrive - Universidad Complutense de Madrid (UCM)\Doctorado\Curriculum_Learning\Multidigit_Addition\Parameters"
folder_name = f"AP_{epsilon_zeros}_{epsilon_non_zeros}"
output_path = os.path.join(base_path, folder_name)

# Crear la carpeta si no existe
os.makedirs(output_path, exist_ok=True)

# Generar y guardar cinco modelos
for _ in range(5):
    trainable_model, original_model = generate_model_AP(epsilon_non_zeros, epsilon_zeros)
    current_time = datetime.now().strftime("%Y_%m_%d_%H_%M_%S")
    file_name = f"trainable_model_stage_{current_time}.pkl"
    file_path = os.path.join(output_path, file_name)
    with open(file_path, "wb") as file:
        pickle.dump(trainable_model, file)
    print(f"Modelo guardado como {file_path}")
    time.sleep(2)
# Out:
# Modelo guardado como D:\OneDrive - Universidad Complutense de Madrid (UCM)\Doctorado\Curriculum_Learning\Multidigit_Addition\Parameters\AP_0.1_0.1\trainable_model_stage_2024_12_04_12_42_00.pkl
# Modelo guardado como D:\OneDrive - Universidad Complutense de Madrid (UCM)\Doctorado\Curriculum_Learning\Multidigit_Addition\Parameters\AP_0.1_0.1\trainable_model_stage_2024_12_04_12_42_02.pkl
# Modelo guardado como D:\OneDrive - Universidad Complutense de Madrid (UCM)\Doctorado\Curriculum_Learning\Multidigit_Addition\Parameters\AP_0.1_0.1\trainable_model_stage_2024_12_04_12_42_04.pkl
# Modelo guardado como D:\OneDrive - Universidad Complutense de Madrid (UCM)\Doctorado\Curriculum_Learning\Multidigit_Addition\Parameters\AP_0.1_0.1\trainable_model_stage_2024_12_04_12_42_06.pkl
# Modelo guardado como D:\OneDrive - Universidad Complutense de Madrid (UCM)\Doctorado\Curriculum_Learning\Multidigit_Addition\Parameters\AP_0.1_0.1\trainable_model_stage_2024_12_04_12_42_08.pkl

# %%
model = 'trainable_model_stage'
training_type = 'AP_0.1_0.1'

folder = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
folder_path = f'{folder}/Parameters/{training_type}'
date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"{folder_path}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    training_stages = 3
    trainings_needed = np.zeros(training_stages)    
    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    N = 500

    for stage in range(1,4):
        if stage == 1:
            trainable_model_stage_1 = [trainable_model[0],
                                       trainable_model[1],
                                       trainable_model[2],
                                       trainable_model[3],
                                       trainable_model[4],
                                       trainable_model[5],
                                       trainable_model[6],
                                       trainable_model[7],
                                       trainable_model[8],
                                       trainable_model[9],
                                       trainable_model[10],
                                       trainable_model[11],
                                       trainable_model[12]]
        elif stage == 2:
            trainable_model_stage_2 = [trainable_model[13], 
                                       trainable_model[14]]
        elif stage == 3:
            trainable_model_stage_3 = [trainable_model_stage_1[0], 
                                       trainable_model_stage_1[1], 
                                       trainable_model_stage_1[2], 
                                       trainable_model_stage_1[3], 
                                       trainable_model_stage_1[4], 
                                       trainable_model_stage_1[5], 
                                       trainable_model_stage_1[6], 
                                       trainable_model_stage_1[7], 
                                       trainable_model_stage_1[8], 
                                       trainable_model_stage_1[9], 
                                       trainable_model_stage_1[10],
                                       trainable_model_stage_1[11],
                                       trainable_model_stage_1[12],
                                       trainable_model_stage_2[0],
                                       trainable_model_stage_2[1]]
        
        save_dir = f"{folder}/Trained_models/Stages/{training_type}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.005
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_trained_count == train_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        train_size = correct_predictions_trained_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_12_04_12_42_00.pkl
# STAGE 1: Out of 8000, 5506 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1366 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.05013854801654816.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.005366088822484016.
# Objective completed
# Stage 1 completed in 20.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_12_04_12_42_00.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_12_04_12_42_00.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_12_04_12_42_00.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_12_04_12_42_00.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_12_04_12_42_00.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_12_04_12_42_00.txt
# Loaded trainable_model_stage_2024_12_04_12_42_02.pkl
# STAGE 1: Out of 8000, 4789 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1195 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.07975983619689941.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.005714065860956907.
# Objective completed
# Stage 1 completed in 20.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_12_04_12_42_02.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_12_04_12_42_02.txt
# STAGE 2: Out of 8000, 1453 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 354 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.13604840636253357.
# STAGE 2: Out of 8000, 4084 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07141578942537308.
# STAGE 2: Out of 8000, 3946 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 969 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057254403829574585.
# STAGE 2: Out of 8000, 3450 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 840 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06643788516521454.
# STAGE 2: Out of 8000, 3928 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05650283396244049.
# STAGE 2: Out of 8000, 3932 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 974 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05815650895237923.
# STAGE 2: Out of 8000, 3615 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 899 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05892578512430191.
# STAGE 2: Out of 8000, 3924 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 981 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058672599494457245.
# STAGE 2: Out of 8000, 2048 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 521 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06682543456554413.
# STAGE 2: Out of 8000, 4156 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05784769728779793.
# STAGE 2: Out of 8000, 3943 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061033811420202255.
# STAGE 2: Out of 8000, 3798 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 954 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06513319164514542.
# STAGE 2: Out of 8000, 4181 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05483833700418472.
# STAGE 2: Out of 8000, 3598 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 915 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0649920254945755.
# STAGE 2: Out of 8000, 3466 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 882 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060808222740888596.
# STAGE 2: Out of 8000, 4316 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1057 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05823345482349396.
# STAGE 2: Out of 8000, 4139 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059454724192619324.
# STAGE 2: Out of 8000, 3334 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 821 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06303960829973221.
# STAGE 2: Out of 8000, 3713 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 917 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059118255972862244.
# STAGE 2: Out of 8000, 4437 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1070 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055026136338710785.
# STAGE 2: Out of 8000, 4115 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059319738298654556.
# STAGE 2: Out of 8000, 3897 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 977 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05924665182828903.
# STAGE 2: Out of 8000, 4148 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1024 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06376960873603821.
# STAGE 2: Out of 8000, 4291 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1047 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061777450144290924.
# STAGE 2: Out of 8000, 4024 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061080340296030045.
# STAGE 2: Out of 8000, 4230 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1033 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0593843087553978.
# STAGE 2: Out of 8000, 4369 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1063 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05601926147937775.
# STAGE 2: Out of 8000, 4071 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05823065713047981.
# STAGE 2: Out of 8000, 4482 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1108 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05398780107498169.
# STAGE 2: Out of 8000, 4087 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1003 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058084867894649506.
# STAGE 2: Out of 8000, 1830 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 458 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06986440718173981.
# STAGE 2: Out of 8000, 3870 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05902980640530586.
# STAGE 2: Out of 8000, 3906 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 972 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06344969570636749.
# STAGE 2: Out of 8000, 4108 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05825657397508621.
# STAGE 2: Out of 8000, 4234 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1039 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05865203216671944.
# STAGE 2: Out of 8000, 4218 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1037 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06097733601927757.
# STAGE 2: Out of 8000, 3860 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 982 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06138741597533226.
# STAGE 2: Out of 8000, 4165 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06270922720432281.
# STAGE 2: Out of 8000, 4038 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1002 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0568222776055336.
# STAGE 2: Out of 8000, 4228 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.046354759484529495.
# STAGE 2: Out of 8000, 4127 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1029 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06412049382925034.
# STAGE 2: Out of 8000, 3805 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 953 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06315816193819046.
# STAGE 2: Out of 8000, 4096 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 999 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05858315899968147.
# STAGE 2: Out of 8000, 3820 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 958 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0566251203417778.
# STAGE 2: Out of 8000, 3670 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 933 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05836497247219086.
# STAGE 2: Out of 8000, 3866 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 962 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057730261236429214.
# STAGE 2: Out of 8000, 3187 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 811 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06603533029556274.
# STAGE 2: Out of 8000, 3591 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 918 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06602383404970169.
# STAGE 2: Out of 8000, 3993 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060868602246046066.
# STAGE 2: Out of 8000, 3719 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 931 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060807086527347565.
# STAGE 2: Out of 8000, 3971 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057749781757593155.
# STAGE 2: Out of 8000, 3974 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06468403339385986.
# STAGE 2: Out of 8000, 4410 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1086 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0557270348072052.
# STAGE 2: Out of 8000, 3767 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 944 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057577844709157944.
# STAGE 2: Out of 8000, 4191 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1036 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05376119539141655.
# STAGE 2: Out of 8000, 3314 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 845 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06026192754507065.
# STAGE 2: Out of 8000, 4306 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1062 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056742820888757706.
# STAGE 2: Out of 8000, 4440 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1082 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05372285470366478.
# STAGE 2: Out of 8000, 3861 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 963 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05858348682522774.
# STAGE 2: Out of 8000, 2499 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 625 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06662832945585251.
# STAGE 2: Out of 8000, 2969 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 759 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06390178948640823.
# STAGE 2: Out of 8000, 4342 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1064 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0601414255797863.
# STAGE 2: Out of 8000, 3034 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 761 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05783696845173836.
# STAGE 2: Out of 8000, 4276 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1050 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06303971260786057.
# STAGE 2: Out of 8000, 3152 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 812 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059433791786432266.
# STAGE 2: Out of 8000, 4361 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1062 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06013412028551102.
# STAGE 2: Out of 8000, 3472 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 864 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0564967505633831.
# STAGE 2: Out of 8000, 3299 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 828 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07030988484621048.
# STAGE 2: Out of 8000, 3786 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 951 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06315908581018448.
# STAGE 2: Out of 8000, 3941 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 985 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06457019597291946.
# STAGE 2: Out of 8000, 4359 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1050 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05875999480485916.
# STAGE 2: Out of 8000, 4040 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 985 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06272348761558533.
# STAGE 2: Out of 8000, 3399 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 864 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05963395908474922.
# STAGE 2: Out of 8000, 3101 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 789 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06226430460810661.
# STAGE 2: Out of 8000, 3884 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 957 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060343287885189056.
# STAGE 2: Out of 8000, 2114 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 554 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06827151775360107.
# STAGE 2: Out of 8000, 4051 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 986 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06330781430006027.
# STAGE 2: Out of 8000, 4340 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1054 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061815664172172546.
# STAGE 2: Out of 8000, 4301 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1049 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0552213080227375.
# STAGE 2: Out of 8000, 4075 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06367047131061554.
# STAGE 2: Out of 8000, 3949 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06136337295174599.
# STAGE 2: Out of 8000, 4295 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1063 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06462890654802322.
# STAGE 2: Out of 8000, 3665 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 917 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0649544894695282.
# STAGE 2: Out of 8000, 4224 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1036 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06113147735595703.
# STAGE 2: Out of 8000, 3437 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 861 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06319233775138855.
# STAGE 2: Out of 8000, 3604 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 922 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06208672374486923.
# STAGE 2: Out of 8000, 4025 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1004 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05802411958575249.
# STAGE 2: Out of 8000, 4254 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1034 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05841262638568878.
# STAGE 2: Out of 8000, 4094 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06568571925163269.
# STAGE 2: Out of 8000, 3796 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 940 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05839770287275314.
# STAGE 2: Out of 8000, 3881 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 969 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0644623413681984.
# STAGE 2: Out of 8000, 4390 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1068 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0526406392455101.
# STAGE 2: Out of 8000, 4056 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1002 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0660180076956749.
# STAGE 2: Out of 8000, 3575 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 896 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06032577157020569.
# STAGE 2: Out of 8000, 3732 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 945 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060080111026763916.
# STAGE 2: Out of 8000, 4012 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 995 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05410856753587723.
# STAGE 2: Out of 8000, 3644 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 903 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05921658128499985.
# STAGE 2: Out of 8000, 3762 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 942 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0720985159277916.
# STAGE 2: Out of 8000, 4174 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055417563766241074.
# STAGE 2: Out of 8000, 3994 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 983 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06074272841215134.
# STAGE 2: Out of 8000, 4014 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 987 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060125961899757385.
# STAGE 2: Out of 8000, 3961 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06250690668821335.
# STAGE 2: Out of 8000, 4372 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1069 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057057783007621765.
# STAGE 2: Out of 8000, 4092 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0570063441991806.
# STAGE 2: Out of 8000, 2556 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 646 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055220529437065125.
# STAGE 2: Out of 8000, 4322 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06030299514532089.
# STAGE 2: Out of 8000, 4397 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1063 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058857228606939316.
# STAGE 2: Out of 8000, 3696 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 925 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06526611000299454.
# STAGE 2: Out of 8000, 4117 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05555611848831177.
# STAGE 2: Out of 8000, 4372 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1063 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0570085309445858.
# STAGE 2: Out of 8000, 3746 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 944 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06342805176973343.
# STAGE 2: Out of 8000, 3442 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 863 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06757510453462601.
# STAGE 2: Out of 8000, 3683 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 900 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056871455162763596.
# STAGE 2: Out of 8000, 3415 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 859 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06060696020722389.
# STAGE 2: Out of 8000, 3890 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 969 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059346720576286316.
# STAGE 2: Out of 8000, 3375 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 849 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05927855148911476.
# STAGE 2: Out of 8000, 3816 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 950 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06728895753622055.
# STAGE 2: Out of 8000, 3764 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 950 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06033219024538994.
# STAGE 2: Out of 8000, 3819 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 973 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05809134989976883.
# STAGE 2: Out of 8000, 3909 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 977 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05908108502626419.
# STAGE 2: Out of 8000, 4054 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06114993989467621.
# STAGE 2: Out of 8000, 3983 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05822364240884781.
# STAGE 2: Out of 8000, 3629 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 897 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055794648826122284.
# STAGE 2: Out of 8000, 3566 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 864 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06103574112057686.
# STAGE 2: Out of 8000, 4393 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1085 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05725739896297455.
# STAGE 2: Out of 8000, 4136 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1027 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06024105101823807.
# STAGE 2: Out of 8000, 3969 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 991 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05901913344860077.
# STAGE 2: Out of 8000, 3776 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 949 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07147713750600815.
# STAGE 2: Out of 8000, 3697 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 906 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054470986127853394.
# STAGE 2: Out of 8000, 4300 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1055 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05648742616176605.
# STAGE 2: Out of 8000, 4567 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1106 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05540402606129646.
# STAGE 2: Out of 8000, 4270 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1056 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05552321672439575.
# STAGE 2: Out of 8000, 3950 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 976 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060467708855867386.
# STAGE 2: Out of 8000, 3884 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 968 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05577362701296806.
# STAGE 2: Out of 8000, 3720 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 941 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05545502156019211.
# STAGE 2: Out of 8000, 4352 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1074 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.050408001989126205.
# STAGE 2: Out of 8000, 4032 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05719497427344322.
# STAGE 2: Out of 8000, 4146 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1031 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061521705240011215.
# STAGE 2: Out of 8000, 3898 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 971 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059813324362039566.
# STAGE 2: Out of 8000, 4179 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1036 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055997367948293686.
# STAGE 2: Out of 8000, 3899 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06818167865276337.
# STAGE 2: Out of 8000, 3828 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 960 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06593231856822968.
# STAGE 2: Out of 8000, 4599 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1116 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05140792205929756.
# STAGE 2: Out of 8000, 4202 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05175119265913963.
# STAGE 2: Out of 8000, 4210 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05596185475587845.
# STAGE 2: Out of 8000, 4272 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1040 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055461958050727844.
# STAGE 2: Out of 8000, 3724 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 926 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05602568760514259.
# STAGE 2: Out of 8000, 3825 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 954 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056411683559417725.
# STAGE 2: Out of 8000, 3923 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05632928013801575.
# STAGE 2: Out of 8000, 3738 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 942 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06628385931253433.
# STAGE 2: Out of 8000, 4105 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058560214936733246.
# STAGE 2: Out of 8000, 3641 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 910 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06278550624847412.
# STAGE 2: Out of 8000, 3774 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 953 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06127409636974335.
# STAGE 2: Out of 8000, 4130 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06050589308142662.
# STAGE 2: Out of 8000, 4108 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05707260221242905.
# STAGE 2: Out of 8000, 3587 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 882 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06913109123706818.
# STAGE 2: Out of 8000, 4282 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1059 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05561947450041771.
# STAGE 2: Out of 8000, 3150 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 780 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06535783410072327.
# STAGE 2: Out of 8000, 4448 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1083 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06757421791553497.
# STAGE 2: Out of 8000, 4083 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06320418417453766.
# STAGE 2: Out of 8000, 3900 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 974 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05882314220070839.
# STAGE 2: Out of 8000, 4056 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05906936153769493.
# STAGE 2: Out of 8000, 3912 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06512097269296646.
# STAGE 2: Out of 8000, 4277 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1065 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0502585805952549.
# STAGE 2: Out of 8000, 3948 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 990 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05826307088136673.
# STAGE 2: Out of 8000, 2670 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 684 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06428131461143494.
# STAGE 2: Out of 8000, 4192 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1036 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055430538952350616.
# STAGE 2: Out of 8000, 4377 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1074 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05490325018763542.
# STAGE 2: Out of 8000, 3853 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 965 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06036777421832085.
# STAGE 2: Out of 8000, 4152 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06241752952337265.
# STAGE 2: Out of 8000, 3953 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 983 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05392403155565262.
# STAGE 2: Out of 8000, 4336 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1065 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0608455166220665.
# STAGE 2: Out of 8000, 3757 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 956 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05532730370759964.
# STAGE 2: Out of 8000, 3664 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 932 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05858251079916954.
# STAGE 2: Out of 8000, 4090 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05357551947236061.
# STAGE 2: Out of 8000, 4050 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06197332218289375.
# STAGE 2: Out of 8000, 3930 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05879037827253342.
# STAGE 2: Out of 8000, 4550 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1106 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05331879109144211.
# STAGE 2: Out of 8000, 4150 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1034 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05840045213699341.
# STAGE 2: Out of 8000, 4017 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055207543075084686.
# STAGE 2: Out of 8000, 3522 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 884 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05597330629825592.
# STAGE 2: Out of 8000, 4094 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05835358053445816.
# STAGE 2: Out of 8000, 3409 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 858 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06225220859050751.
# STAGE 2: Out of 8000, 3923 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 963 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06247902661561966.
# STAGE 2: Out of 8000, 4083 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 988 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05348111689090729.
# STAGE 2: Out of 8000, 4135 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05771785229444504.
# STAGE 2: Out of 8000, 4344 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1037 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05867835134267807.
# STAGE 2: Out of 8000, 3590 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 911 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06608272343873978.
# STAGE 2: Out of 8000, 3305 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 839 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06834154576063156.
# STAGE 2: Out of 8000, 3689 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 927 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0542021170258522.
# STAGE 2: Out of 8000, 3891 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 982 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05576949939131737.
# STAGE 2: Out of 8000, 3540 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 891 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06113148108124733.
# STAGE 2: Out of 8000, 4266 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1049 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06316579133272171.
# STAGE 2: Out of 8000, 4038 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06069669499993324.
# STAGE 2: Out of 8000, 3665 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 928 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07110195606946945.
# STAGE 2: Out of 8000, 3895 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 967 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059550248086452484.
# STAGE 2: Out of 8000, 4066 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06413854658603668.
# STAGE 2: Out of 8000, 4253 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1039 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05399615317583084.
# STAGE 2: Out of 8000, 4204 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05168881639838219.
# STAGE 2: Out of 8000, 4176 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1040 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05535868555307388.
# STAGE 2: Out of 8000, 4039 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 994 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05853652581572533.
# STAGE 2: Out of 8000, 4313 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1057 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060358572751283646.
# STAGE 2: Out of 8000, 3929 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05377606675028801.
# STAGE 2: Out of 8000, 2976 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 757 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05938773602247238.
# STAGE 2: Out of 8000, 3914 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06368254870176315.
# STAGE 2: Out of 8000, 4254 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1042 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05869624391198158.
# STAGE 2: Out of 8000, 3934 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0612543486058712.
# STAGE 2: Out of 8000, 3996 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057402320206165314.
# STAGE 2: Out of 8000, 4267 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1038 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05386872962117195.
# STAGE 2: Out of 8000, 4368 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1067 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05330049246549606.
# STAGE 2: Out of 8000, 4042 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05784465745091438.
# STAGE 2: Out of 8000, 3589 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 903 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05857868120074272.
# STAGE 2: Out of 8000, 3971 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05292007699608803.
# STAGE 2: Out of 8000, 3814 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 933 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05972883105278015.
# STAGE 2: Out of 8000, 4055 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06020011752843857.
# STAGE 2: Out of 8000, 4059 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 999 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06718500703573227.
# STAGE 2: Out of 8000, 4170 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05780494585633278.
# STAGE 2: Out of 8000, 4073 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057739779353141785.
# STAGE 2: Out of 8000, 3734 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 940 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.062454842031002045.
# STAGE 2: Out of 8000, 3261 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 810 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06452368944883347.
# STAGE 2: Out of 8000, 4221 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058089729398489.
# STAGE 2: Out of 8000, 3651 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 904 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06320623308420181.
# STAGE 2: Out of 8000, 4302 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1066 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06141585484147072.
# STAGE 2: Out of 8000, 3673 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 926 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060151077806949615.
# STAGE 2: Out of 8000, 4120 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1021 tested were predicted correctly in the current model.
# ...
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.02522243559360504.
# STAGE 3: Out of 8000, 6380 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1588 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.022513050585985184.
# STAGE 3: Out of 8000, 6635 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1648 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.021389758214354515.
# STAGE 3: Out of 8000, 6827 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1687 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01945396512746811.
# STAGE 3: Out of 8000, 6787 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1684 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.018295185640454292.
# STAGE 3: Out of 8000, 6551 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1619 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.019140446558594704.
# STAGE 3: Out of 8000, 6741 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1680 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.019442696124315262.
# STAGE 3: Out of 8000, 6903 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1708 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01691836677491665.
# STAGE 3: Out of 8000, 6757 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1674 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017582714557647705.
# STAGE 3: Out of 8000, 6843 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1688 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01746314764022827.
# STAGE 3: Out of 8000, 6711 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1663 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.019429469481110573.
# STAGE 3: Out of 8000, 6876 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1706 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01766842044889927.
# STAGE 3: Out of 8000, 6917 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1716 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.018053563311696053.
# STAGE 3: Out of 8000, 6912 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1709 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.016271835193037987.
# STAGE 3: Out of 8000, 6750 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1683 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017510026693344116.
# STAGE 3: Out of 8000, 6822 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1693 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.015587711706757545.
# STAGE 3: Out of 8000, 6904 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1719 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.018493657931685448.
# STAGE 3: Out of 8000, 6924 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1719 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01668638363480568.
# STAGE 3: Out of 8000, 6847 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1682 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017848936840891838.
# STAGE 3: Out of 8000, 6925 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1732 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.016453994438052177.
# STAGE 3: Out of 8000, 6780 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1676 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01615179516375065.
# STAGE 3: Out of 8000, 6818 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1684 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.016092387959361076.
# STAGE 3: Out of 8000, 6799 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1672 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01767299510538578.
# STAGE 3: Out of 8000, 6880 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1693 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017400847747921944.
# STAGE 3: Out of 8000, 6739 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1670 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.018962040543556213.
# STAGE 3: Out of 8000, 6844 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1695 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.016604451462626457.
# STAGE 3: Out of 8000, 6679 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1661 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017204325646162033.
# STAGE 3: Out of 8000, 6844 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1682 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.019145529717206955.
# STAGE 3: Out of 8000, 6868 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1695 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017650440335273743.
# STAGE 3: Out of 8000, 6783 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1687 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.018640901893377304.
# STAGE 3: Out of 8000, 6687 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1668 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01924785226583481.
# STAGE 3: Out of 8000, 6834 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1701 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01805718243122101.
# STAGE 3: Out of 8000, 6658 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1642 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.020008951425552368.
# STAGE 3: Out of 8000, 6754 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1678 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.018399590626358986.
# STAGE 3: Out of 8000, 6732 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1672 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017745573073625565.
# STAGE 3: Out of 8000, 6794 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1681 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01669127680361271.
# STAGE 3: Out of 8000, 6788 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1681 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.015850195661187172.
# STAGE 3: Out of 8000, 6687 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1652 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.019319621846079826.
# STAGE 3: Out of 8000, 6771 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1688 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017219234257936478.
# STAGE 3: Out of 8000, 6693 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1667 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01865795999765396.
# STAGE 3: Out of 8000, 6684 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1657 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01587861031293869.
# STAGE 3: Out of 8000, 6851 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1681 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017288411036133766.
# STAGE 3: Out of 8000, 6692 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1662 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.018311500549316406.
# STAGE 3: Out of 8000, 6765 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1689 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.019428500905632973.
# STAGE 3: Out of 8000, 6744 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1694 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.01808161288499832.
# STAGE 3: Out of 8000, 6795 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1699 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.017246518284082413.
# Stage 3 completed in 2500.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_12_04_12_42_02.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_12_04_12_42_02.txt
# Loaded trainable_model_stage_2024_12_04_12_42_04.pkl
# STAGE 1: Out of 8000, 3324 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 862 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2102823704481125.
# STAGE 1: Out of 8000, 7868 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1958 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0088267233222723.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0011585252359509468.
# Objective completed
# Stage 1 completed in 30.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_12_04_12_42_04.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_12_04_12_42_04.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_12_04_12_42_04.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_12_04_12_42_04.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_12_04_12_42_04.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_12_04_12_42_04.txt
# Loaded trainable_model_stage_2024_12_04_12_42_06.pkl
# STAGE 1: Out of 8000, 7690 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1931 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.02074691466987133.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0042867595329880714.
# Objective completed
# Stage 1 completed in 20.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_12_04_12_42_06.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_12_04_12_42_06.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_12_04_12_42_06.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_12_04_12_42_06.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_12_04_12_42_06.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_12_04_12_42_06.txt
# Loaded trainable_model_stage_2024_12_04_12_42_08.pkl
# STAGE 1: Out of 8000, 4336 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1043 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.08516562730073929.
# STAGE 1: Out of 8000, 7941 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1982 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.008398879319429398.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.002400449477136135.
# Objective completed
# Stage 1 completed in 30.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_12_04_12_42_08.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_12_04_12_42_08.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_12_04_12_42_08.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_12_04_12_42_08.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_12_04_12_42_08.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_12_04_12_42_08.txt
