# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_carry_over_dataset = eval(file.read())
    
# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)

    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None


def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None


# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count, carry_over_size, correct_carry_over_predictions_tested_count = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {carry_over_size}, {correct_carry_over_predictions_tested_count} tested with carry-over were predicted correctly in the current model.")      

    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)

    correct_predictions_count = 0
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
def perfect_model():
    # R vectors of dimension (14,1)
    R2_perfect = np.zeros((14))
    R3_perfect = np.zeros((14))
    R4_perfect = np.zeros((14))
    R5_perfect = np.zeros((14))
    R6_perfect = np.zeros((14))
    R7_perfect = np.zeros((14))
    R8_perfect = np.zeros((14))
    
    for i in range(2):
        R2_perfect[7*i + 6] = 1
        R3_perfect[7*i + 5] = 1
        R4_perfect[7*i + 4] = 1
        R5_perfect[7*i + 3] = 1
        R6_perfect[7*i + 2] = 1
        R7_perfect[7*i + 1] = 1
        R8_perfect[7*i + 0] = 1
    
    # Scalar parameters v
    v2_perfect = 1/2
    v3_perfect = 1/2
    v4_perfect = 1/2
    v5_perfect = 1/2
    v6_perfect = 1/2
    v7_perfect = 1/2
    
    # Matrix T of dimension (28,7)
    T_perfect = np.zeros((14,8))
    for i in range(7):
        for j in range(2):
            T_perfect[7*j + i, i + 1] = 1
    
    # Parameter v
    v_perfect = 1/2
    
    original_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    trainable_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    return trainable_model, original_model

def generate_model_random(mean=0.5, std=1):
    R2 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the second bit
    R3 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R4 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R6 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R7 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R8 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    v2 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    T = initialize_random_weights(mean, std, (14, 8))  # 196 neurons that allow performing the sum
    v = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    trainable_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    return trainable_model, original_model
    
def generate_model_AP(epsilon_non_zeros = 0.01, epsilon_zeros = 0.01):   
    R2_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R3_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R8_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)

    for i in range(2):
        R2_almost_perfect[7*i + 6] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R8_almost_perfect[7*i + 0] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v2_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)

    T_almost_perfect = np.zeros((14,8)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(2):
            T_almost_perfect[7*j + i, i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    trainable_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
model = 'trainable_model_stage'
training_type = 'Generated_model'

folder = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
folder_path = f'{folder}/Parameters/{training_type}'
date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"{folder_path}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    training_stages = 3
    trainings_needed = np.zeros(training_stages)    
    visualizer = 10
    lr_changer = 250
    stage_changer = 2500
    N = 500

    for stage in range(1,4):
        if stage == 1:
            trainable_model_stage_1 = [trainable_model[0],
                                       trainable_model[1],
                                       trainable_model[2],
                                       trainable_model[3],
                                       trainable_model[4],
                                       trainable_model[5],
                                       trainable_model[6],
                                       trainable_model[7],
                                       trainable_model[8],
                                       trainable_model[9],
                                       trainable_model[10],
                                       trainable_model[11],
                                       trainable_model[12]]
        elif stage == 2:
            trainable_model_stage_2 = [trainable_model[13], 
                                       trainable_model[14]]
        elif stage == 3:
            trainable_model_stage_3 = [trainable_model_stage_1[0], 
                                       trainable_model_stage_1[1], 
                                       trainable_model_stage_1[2], 
                                       trainable_model_stage_1[3], 
                                       trainable_model_stage_1[4], 
                                       trainable_model_stage_1[5], 
                                       trainable_model_stage_1[6], 
                                       trainable_model_stage_1[7], 
                                       trainable_model_stage_1[8], 
                                       trainable_model_stage_1[9], 
                                       trainable_model_stage_1[10],
                                       trainable_model_stage_1[11],
                                       trainable_model_stage_1[12],
                                       trainable_model_stage_2[0],
                                       trainable_model_stage_2[1]]
        
        save_dir = f"{folder}/Trained_models/Stages/{training_type}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_trained_count == train_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        train_size = correct_predictions_trained_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_11_20_11_30_19.pkl
# STAGE 1: Out of 8000, 25 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 10 tested were predicted correctly in the current model.
# STAGE 1: Loss is 2.0055062770843506.
# STAGE 1: Out of 8000, 109 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 36 tested were predicted correctly in the current model.
# STAGE 1: Loss is 1.2247213125228882.
# STAGE 1: Out of 8000, 208 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 82 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.9069748520851135.
# STAGE 1: Out of 8000, 357 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 106 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.7071625590324402.
# STAGE 1: Out of 8000, 530 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 144 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.5515646934509277.
# STAGE 1: Out of 8000, 796 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 192 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.40678346157073975.
# STAGE 1: Out of 8000, 1144 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 268 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3185116648674011.
# STAGE 1: Out of 8000, 1753 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 420 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.24102352559566498.
# STAGE 1: Out of 8000, 2290 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 534 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.17812024056911469.
# STAGE 1: Out of 8000, 2773 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 665 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.13138793408870697.
# STAGE 1: Out of 8000, 3510 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 844 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1004834845662117.
# STAGE 1: Out of 8000, 4464 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1085 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.08073259890079498.
# STAGE 1: Out of 8000, 5485 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1366 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.05158008635044098.
# STAGE 1: Out of 8000, 6471 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1618 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.030062541365623474.
# STAGE 1: Out of 8000, 7522 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1879 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.019820794463157654.
# STAGE 1: Out of 8000, 7906 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1967 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.01023149024695158.
# STAGE 1: Out of 8000, 7978 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1993 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.00656871497631073.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.004821841139346361.
# Objective completed
# Stage 1 completed in 180.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\trainable_model_stage_1-2024_11_20_11_30_19.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\Stage_1_results_2024_11_20_11_30_19.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\trainable_model_stage_2-2024_11_20_11_30_19.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\Stage_2_results_2024_11_20_11_30_19.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\trainable_model_stage_3-2024_11_20_11_30_19.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\Stage_3_results_2024_11_20_11_30_19.txt
# Loaded trainable_model_stage_2024_11_20_11_30_21.pkl
# STAGE 1: Out of 8000, 18 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 5 tested were predicted correctly in the current model.
# STAGE 1: Loss is 2.2468838691711426.
# STAGE 1: Out of 8000, 62 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 12 tested were predicted correctly in the current model.
# STAGE 1: Loss is 1.3034710884094238.
# STAGE 1: Out of 8000, 137 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 31 tested were predicted correctly in the current model.
# STAGE 1: Loss is 1.0657129287719727.
# STAGE 1: Out of 8000, 208 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 49 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.792123019695282.
# STAGE 1: Out of 8000, 393 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 89 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.6095367074012756.
# STAGE 1: Out of 8000, 627 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 153 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.4931205213069916.
# STAGE 1: Out of 8000, 891 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 214 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.4395395517349243.
# STAGE 1: Out of 8000, 1200 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 293 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3420981168746948.
# STAGE 1: Out of 8000, 1639 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 409 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.33834677934646606.
# STAGE 1: Out of 8000, 2035 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 525 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29347237944602966.
# STAGE 1: Out of 8000, 2439 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 628 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.23211000859737396.
# STAGE 1: Out of 8000, 2863 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 727 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.240308478474617.
# STAGE 1: Out of 8000, 3412 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 893 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.18914012610912323.
# STAGE 1: Out of 8000, 3846 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1008 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.18844406306743622.
# STAGE 1: Out of 8000, 4138 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1065 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.15547062456607819.
# STAGE 1: Out of 8000, 4379 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1125 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12283284962177277.
# STAGE 1: Out of 8000, 4455 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1151 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12855130434036255.
# STAGE 1: Out of 8000, 4666 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1186 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12781104445457458.
# STAGE 1: Out of 8000, 4777 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1225 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10927046835422516.
# STAGE 1: Out of 8000, 4726 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1204 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11526097357273102.
# STAGE 1: Out of 8000, 4746 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1194 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.13280244171619415.
# STAGE 1: Out of 8000, 4642 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1174 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10872111469507217.
# STAGE 1: Out of 8000, 4591 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1163 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11963465064764023.
# STAGE 1: Out of 8000, 4597 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1159 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11101603507995605.
# STAGE 1: Out of 8000, 4425 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1123 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12300363928079605.
# STAGE 1: Out of 8000, 4536 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1154 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11060573905706406.
# STAGE 1: Out of 8000, 4616 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1170 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10955047607421875.
# STAGE 1: Out of 8000, 4617 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1177 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09610690921545029.
# STAGE 1: Out of 8000, 4542 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1157 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09950987994670868.
# STAGE 1: Out of 8000, 4545 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1163 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11943844705820084.
# STAGE 1: Out of 8000, 4579 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1158 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.13170398771762848.
# STAGE 1: Out of 8000, 4516 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1137 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10550566762685776.
# STAGE 1: Out of 8000, 4491 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1137 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.13346077501773834.
# STAGE 1: Out of 8000, 4628 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1174 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10361779481172562.
# STAGE 1: Out of 8000, 4458 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1125 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1162962019443512.
# STAGE 1: Out of 8000, 4554 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1154 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10404356569051743.
# STAGE 1: Out of 8000, 4552 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1148 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12205967307090759.
# STAGE 1: Out of 8000, 4622 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1176 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0995820164680481.
# STAGE 1: Out of 8000, 4456 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1131 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10962893068790436.
# STAGE 1: Out of 8000, 4488 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1130 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11269793659448624.
# STAGE 1: Out of 8000, 4519 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1132 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11001713573932648.
# STAGE 1: Out of 8000, 4417 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1119 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10493014007806778.
# STAGE 1: Out of 8000, 4535 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1130 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10927870124578476.
# STAGE 1: Out of 8000, 4460 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1110 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10240752249956131.
# STAGE 1: Out of 8000, 4411 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1124 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10510050505399704.
# STAGE 1: Out of 8000, 4441 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1130 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11667416989803314.
# STAGE 1: Out of 8000, 4392 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1107 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10311055183410645.
# STAGE 1: Out of 8000, 4335 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1104 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12301898747682571.
# STAGE 1: Out of 8000, 4326 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1101 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11633383482694626.
# STAGE 1: Out of 8000, 4307 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1085 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10442906618118286.
# STAGE 1: Out of 8000, 4338 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1096 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09714630246162415.
# STAGE 1: Out of 8000, 4285 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1082 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10443557798862457.
# STAGE 1: Out of 8000, 4302 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1090 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11192598938941956.
# STAGE 1: Out of 8000, 4259 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1060 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11787313967943192.
# STAGE 1: Out of 8000, 4245 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1067 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11392923444509506.
# STAGE 1: Out of 8000, 4182 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1045 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10431300848722458.
# STAGE 1: Out of 8000, 4242 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1076 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0916103646159172.
# STAGE 1: Out of 8000, 4208 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1047 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.101204052567482.
# STAGE 1: Out of 8000, 4197 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1068 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10933507233858109.
# STAGE 1: Out of 8000, 4208 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1062 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10620182007551193.
# STAGE 1: Out of 8000, 4234 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1059 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11107376217842102.
# STAGE 1: Out of 8000, 4140 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1046 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1088981032371521.
# STAGE 1: Out of 8000, 4198 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1069 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09533902257680893.
# STAGE 1: Out of 8000, 4163 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1042 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10637093335390091.
# STAGE 1: Out of 8000, 4118 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1045 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09909976273775101.
# STAGE 1: Out of 8000, 4089 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1044 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09623023867607117.
# STAGE 1: Out of 8000, 4140 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1049 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10350281000137329.
# STAGE 1: Out of 8000, 4110 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1031 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1065983921289444.
# STAGE 1: Out of 8000, 4069 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1050 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10604637116193771.
# STAGE 1: Out of 8000, 4071 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1045 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09797979891300201.
# STAGE 1: Out of 8000, 4104 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1044 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1064770296216011.
# STAGE 1: Out of 8000, 4102 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1033 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10237745195627213.
# STAGE 1: Out of 8000, 4072 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1037 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10416410118341446.
# STAGE 1: Out of 8000, 4064 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09865278005599976.
# STAGE 1: Out of 8000, 4107 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1040 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10838073492050171.
# STAGE 1: Out of 8000, 4135 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1045 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10468947142362595.
# STAGE 1: Out of 8000, 4097 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1040 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09595736861228943.
# STAGE 1: Out of 8000, 4046 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11492425948381424.
# STAGE 1: Out of 8000, 4051 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1027 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10664787143468857.
# STAGE 1: Out of 8000, 4074 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09675606340169907.
# STAGE 1: Out of 8000, 4065 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1039 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09854578971862793.
# STAGE 1: Out of 8000, 4046 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09528783708810806.
# STAGE 1: Out of 8000, 4065 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11630458384752274.
# STAGE 1: Out of 8000, 4044 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1019 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11034861207008362.
# STAGE 1: Out of 8000, 4129 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1038 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11554499715566635.
# STAGE 1: Out of 8000, 4066 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1034 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09856575727462769.
# STAGE 1: Out of 8000, 4043 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10079997032880783.
# STAGE 1: Out of 8000, 4048 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10870061069726944.
# STAGE 1: Out of 8000, 4037 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09927716106176376.
# STAGE 1: Out of 8000, 4048 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10603273659944534.
# STAGE 1: Out of 8000, 4024 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1031 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10310248285531998.
# STAGE 1: Out of 8000, 4102 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09737233817577362.
# STAGE 1: Out of 8000, 4078 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1091022789478302.
# STAGE 1: Out of 8000, 4045 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10227417945861816.
# STAGE 1: Out of 8000, 4023 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09979107230901718.
# STAGE 1: Out of 8000, 4098 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10390190035104752.
# STAGE 1: Out of 8000, 4052 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1038 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11579284816980362.
# STAGE 1: Out of 8000, 4001 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10534930974245071.
# STAGE 1: Out of 8000, 4010 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1049283966422081.
# STAGE 1: Out of 8000, 4021 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1008 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10144203901290894.
# STAGE 1: Out of 8000, 4059 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10447218269109726.
# STAGE 1: Out of 8000, 4058 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11961712688207626.
# STAGE 1: Out of 8000, 4045 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11583106219768524.
# STAGE 1: Out of 8000, 4021 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11235464364290237.
# STAGE 1: Out of 8000, 4135 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1052 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1071406900882721.
# STAGE 1: Out of 8000, 4070 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10198773443698883.
# STAGE 1: Out of 8000, 3981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10476214438676834.
# STAGE 1: Out of 8000, 4101 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10569537431001663.
# STAGE 1: Out of 8000, 4064 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.094227135181427.
# STAGE 1: Out of 8000, 4046 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1029 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10600388050079346.
# STAGE 1: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10607574135065079.
# STAGE 1: Out of 8000, 4079 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10319523513317108.
# STAGE 1: Out of 8000, 4042 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1031 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10967147350311279.
# STAGE 1: Out of 8000, 4054 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1024 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10788128525018692.
# STAGE 1: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09883555769920349.
# STAGE 1: Out of 8000, 4042 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1081850454211235.
# STAGE 1: Out of 8000, 3966 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10760439932346344.
# STAGE 1: Out of 8000, 4066 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09060432016849518.
# STAGE 1: Out of 8000, 3991 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10828909277915955.
# STAGE 1: Out of 8000, 4029 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10077451914548874.
# STAGE 1: Out of 8000, 4035 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1024 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09938045591115952.
# STAGE 1: Out of 8000, 4009 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10168763995170593.
# STAGE 1: Out of 8000, 4024 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10592766851186752.
# STAGE 1: Out of 8000, 4009 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10691902041435242.
# STAGE 1: Out of 8000, 3998 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09977767616510391.
# STAGE 1: Out of 8000, 4013 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10508189350366592.
# STAGE 1: Out of 8000, 3993 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10386756807565689.
# STAGE 1: Out of 8000, 4057 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1024 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10389921814203262.
# STAGE 1: Out of 8000, 4064 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11600490659475327.
# STAGE 1: Out of 8000, 4007 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1045854240655899.
# STAGE 1: Out of 8000, 4112 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1033 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10654566437005997.
# STAGE 1: Out of 8000, 3996 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09592394530773163.
# STAGE 1: Out of 8000, 3976 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09912857413291931.
# STAGE 1: Out of 8000, 3984 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11383586376905441.
# STAGE 1: Out of 8000, 4004 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10459880530834198.
# STAGE 1: Out of 8000, 4036 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10053282976150513.
# STAGE 1: Out of 8000, 4037 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09945537149906158.
# STAGE 1: Out of 8000, 4066 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09963560849428177.
# STAGE 1: Out of 8000, 4004 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1024 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11193816363811493.
# STAGE 1: Out of 8000, 3951 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1027781292796135.
# STAGE 1: Out of 8000, 4069 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09191490709781647.
# STAGE 1: Out of 8000, 4017 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10907704383134842.
# STAGE 1: Out of 8000, 3979 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10948055982589722.
# STAGE 1: Out of 8000, 4047 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10946789383888245.
# STAGE 1: Out of 8000, 4006 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1042143702507019.
# STAGE 1: Out of 8000, 4078 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10873226821422577.
# STAGE 1: Out of 8000, 3948 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 994 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11132849752902985.
# STAGE 1: Out of 8000, 4059 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10287702083587646.
# STAGE 1: Out of 8000, 4014 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11087160557508469.
# STAGE 1: Out of 8000, 4055 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11010444909334183.
# STAGE 1: Out of 8000, 4043 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09008277952671051.
# STAGE 1: Out of 8000, 4062 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.113868847489357.
# STAGE 1: Out of 8000, 4095 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09011669456958771.
# STAGE 1: Out of 8000, 3958 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10410773009061813.
# STAGE 1: Out of 8000, 4064 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1030 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10479294508695602.
# STAGE 1: Out of 8000, 4022 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09759356081485748.
# STAGE 1: Out of 8000, 4026 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0988563522696495.
# STAGE 1: Out of 8000, 3974 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1003 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11495473235845566.
# STAGE 1: Out of 8000, 4084 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10435089468955994.
# STAGE 1: Out of 8000, 3951 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09796259552240372.
# STAGE 1: Out of 8000, 4054 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11344730108976364.
# STAGE 1: Out of 8000, 4100 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1042 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10072740167379379.
# STAGE 1: Out of 8000, 3978 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11847405880689621.
# STAGE 1: Out of 8000, 4026 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09695795923471451.
# STAGE 1: Out of 8000, 4071 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1033 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09811613708734512.
# STAGE 1: Out of 8000, 4118 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1049 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10714197903871536.
# STAGE 1: Out of 8000, 4096 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10467512160539627.
# STAGE 1: Out of 8000, 4053 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1033 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10371419787406921.
# STAGE 1: Out of 8000, 4021 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1039 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10801052302122116.
# STAGE 1: Out of 8000, 3991 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10937168449163437.
# STAGE 1: Out of 8000, 3923 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1003 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09900622814893723.
# STAGE 1: Out of 8000, 4027 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1027 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09487952291965485.
# STAGE 1: Out of 8000, 4044 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10342127829790115.
# STAGE 1: Out of 8000, 4114 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0957975760102272.
# STAGE 1: Out of 8000, 4049 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10302519798278809.
# STAGE 1: Out of 8000, 4031 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09528429061174393.
# STAGE 1: Out of 8000, 4015 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10160978138446808.
# STAGE 1: Out of 8000, 4007 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09368781745433807.
# STAGE 1: Out of 8000, 4057 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1031 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1047782227396965.
# STAGE 1: Out of 8000, 4104 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1038 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10538968443870544.
# STAGE 1: Out of 8000, 4016 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10223846137523651.
# STAGE 1: Out of 8000, 4037 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09741572290658951.
# STAGE 1: Out of 8000, 4047 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10188914090394974.
# STAGE 1: Out of 8000, 4039 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11834288388490677.
# STAGE 1: Out of 8000, 4085 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10040529817342758.
# STAGE 1: Out of 8000, 4009 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10312771052122116.
# STAGE 1: Out of 8000, 3968 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11368929594755173.
# STAGE 1: Out of 8000, 4064 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09164708852767944.
# STAGE 1: Out of 8000, 3954 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10913199931383133.
# STAGE 1: Out of 8000, 4014 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10718593746423721.
# STAGE 1: Out of 8000, 4001 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10366092622280121.
# STAGE 1: Out of 8000, 3979 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10668905824422836.
# STAGE 1: Out of 8000, 3936 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 999 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10472434759140015.
# STAGE 1: Out of 8000, 3961 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1008 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10946905612945557.
# STAGE 1: Out of 8000, 4062 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09358774125576019.
# STAGE 1: Out of 8000, 3978 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10375769436359406.
# STAGE 1: Out of 8000, 4045 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11318276822566986.
# STAGE 1: Out of 8000, 4053 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1019 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11531694233417511.
# STAGE 1: Out of 8000, 4034 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10141924023628235.
# STAGE 1: Out of 8000, 4006 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1025 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11659152060747147.
# STAGE 1: Out of 8000, 4022 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1030421182513237.
# STAGE 1: Out of 8000, 4009 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11049681156873703.
# STAGE 1: Out of 8000, 4022 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09779007732868195.
# STAGE 1: Out of 8000, 4071 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10959696024656296.
# STAGE 1: Out of 8000, 4055 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1032 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11727455258369446.
# STAGE 1: Out of 8000, 4095 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10161172598600388.
# STAGE 1: Out of 8000, 3989 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10751959681510925.
# STAGE 1: Out of 8000, 4039 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10879281163215637.
# STAGE 1: Out of 8000, 4017 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11468213051557541.
# STAGE 1: Out of 8000, 4018 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09814251214265823.
# STAGE 1: Out of 8000, 3970 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10805322229862213.
# STAGE 1: Out of 8000, 4121 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1037 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09995397925376892.
# STAGE 1: Out of 8000, 3997 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11178074032068253.
# ...
# STAGE 1: Out of 2000, 176 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.43685105443000793.
# STAGE 1: Out of 8000, 1091 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 270 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.30606427788734436.
# STAGE 1: Out of 8000, 1865 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 446 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.20836272835731506.
# STAGE 1: Out of 8000, 2902 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 721 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1475420743227005.
# STAGE 1: Out of 8000, 3937 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.09133826196193695.
# STAGE 1: Out of 8000, 5197 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1283 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.06197486072778702.
# STAGE 1: Out of 8000, 6505 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1638 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.03096606209874153.
# STAGE 1: Out of 8000, 7459 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1852 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.017804231494665146.
# STAGE 1: Out of 8000, 7899 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1970 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.011909098364412785.
# STAGE 1: Out of 8000, 7985 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1997 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.007813968695700169.
# STAGE 1: Out of 8000, 7998 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.005575456656515598.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.004216385539621115.
# Objective completed
# Stage 1 completed in 170.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\trainable_model_stage_1-2024_11_20_11_30_33.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\Stage_1_results_2024_11_20_11_30_33.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\trainable_model_stage_2-2024_11_20_11_30_33.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\Stage_2_results_2024_11_20_11_30_33.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\trainable_model_stage_3-2024_11_20_11_30_33.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\Stage_3_results_2024_11_20_11_30_33.txt
# Loaded trainable_model_stage_2024_11_20_11_30_35.pkl
# STAGE 1: Out of 8000, 64 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 10 tested were predicted correctly in the current model.
# STAGE 1: Loss is 1.4418915510177612.
# STAGE 1: Out of 8000, 191 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 37 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.9070693850517273.
# STAGE 1: Out of 8000, 452 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 99 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.6407989859580994.
# STAGE 1: Out of 8000, 1000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 232 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.38085150718688965.
# STAGE 1: Out of 8000, 1865 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 450 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29267507791519165.
# STAGE 1: Out of 8000, 2478 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 596 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.26183706521987915.
# STAGE 1: Out of 8000, 2895 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 691 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.22181586921215057.
# STAGE 1: Out of 8000, 3185 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 794 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.17743070423603058.
# STAGE 1: Out of 8000, 3471 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 865 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.15140412747859955.
# STAGE 1: Out of 8000, 3671 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 923 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11344471573829651.
# STAGE 1: Out of 8000, 3912 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11440032720565796.
# STAGE 1: Out of 8000, 4275 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1087 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0859808474779129.
# STAGE 1: Out of 8000, 4738 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1193 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.07343322783708572.
# STAGE 1: Out of 8000, 5061 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1253 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0720227062702179.
# STAGE 1: Out of 8000, 5647 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1407 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.04127722233533859.
# STAGE 1: Out of 8000, 6292 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1585 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.02537410333752632.
# STAGE 1: Out of 8000, 7131 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1783 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.016690809279680252.
# STAGE 1: Out of 8000, 7748 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1937 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.008151696994900703.
# STAGE 1: Out of 8000, 7987 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1997 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0056677646934986115.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.003501048544421792.
# Objective completed
# Stage 1 completed in 200.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\trainable_model_stage_1-2024_11_20_11_30_35.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\Stage_1_results_2024_11_20_11_30_35.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\trainable_model_stage_2-2024_11_20_11_30_35.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\Stage_2_results_2024_11_20_11_30_35.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\trainable_model_stage_3-2024_11_20_11_30_35.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\Stage_3_results_2024_11_20_11_30_35.txt
# Loaded trainable_model_stage_2024_11_20_11_30_37.pkl
# STAGE 1: Out of 8000, 11 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2 tested were predicted correctly in the current model.
# STAGE 1: Loss is 2.5533387660980225.
# STAGE 1: Out of 8000, 37 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 9 tested were predicted correctly in the current model.
# STAGE 1: Loss is 1.5755637884140015.
# STAGE 1: Out of 8000, 101 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 22 tested were predicted correctly in the current model.
# STAGE 1: Loss is 1.2011744976043701.
# STAGE 1: Out of 8000, 194 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 51 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.9036311507225037.
# STAGE 1: Out of 8000, 373 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 88 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.6925473809242249.
# STAGE 1: Out of 8000, 574 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 150 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.5798236727714539.
# STAGE 1: Out of 8000, 817 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 224 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.4226217269897461.
# STAGE 1: Out of 8000, 1174 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 320 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.32735586166381836.
# STAGE 1: Out of 8000, 1753 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 452 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2654777765274048.
# STAGE 1: Out of 8000, 2441 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 584 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.19243955612182617.
# STAGE 1: Out of 8000, 3195 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 792 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1510448008775711.
# STAGE 1: Out of 8000, 4099 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1017 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11441851407289505.
# STAGE 1: Out of 8000, 4890 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1221 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0788729190826416.
# STAGE 1: Out of 8000, 5439 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1372 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.05520084872841835.
# STAGE 1: Out of 8000, 6217 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1552 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.03349100053310394.
# STAGE 1: Out of 8000, 6780 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1719 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.022840263321995735.
# STAGE 1: Out of 8000, 7148 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1809 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0174787025898695.
# STAGE 1: Out of 8000, 7426 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1876 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.013854452408850193.
# STAGE 1: Out of 8000, 7694 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1935 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.010766401886940002.
# STAGE 1: Out of 8000, 7842 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1973 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.009024432860314846.
# STAGE 1: Out of 8000, 7919 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1984 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.006731735542416573.
# STAGE 1: Out of 8000, 7956 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1992 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.005721019580960274.
# STAGE 1: Out of 8000, 7988 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1997 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.004711114801466465.
# STAGE 1: Out of 8000, 7998 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0036634483840316534.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0031061479821801186.
# Objective completed
# Stage 1 completed in 250.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\trainable_model_stage_1-2024_11_20_11_30_37.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_1\Stage_1_results_2024_11_20_11_30_37.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\trainable_model_stage_2-2024_11_20_11_30_37.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_2\Stage_2_results_2024_11_20_11_30_37.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\trainable_model_stage_3-2024_11_20_11_30_37.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/Generated_model/Stage_3\Stage_3_results_2024_11_20_11_30_37.txt
