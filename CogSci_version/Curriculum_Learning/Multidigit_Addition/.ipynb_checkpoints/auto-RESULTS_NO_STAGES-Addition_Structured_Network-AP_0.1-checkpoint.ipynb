# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_carry_over_dataset = eval(file.read())
    
# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)

    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None


def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None


# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count, carry_over_size, correct_carry_over_predictions_tested_count = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {carry_over_size}, {correct_carry_over_predictions_tested_count} tested with carry-over were predicted correctly in the current model.")      

    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)

    correct_predictions_count = 0
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
def perfect_model():
    # R vectors of dimension (14,1)
    R2_perfect = np.zeros((14))
    R3_perfect = np.zeros((14))
    R4_perfect = np.zeros((14))
    R5_perfect = np.zeros((14))
    R6_perfect = np.zeros((14))
    R7_perfect = np.zeros((14))
    R8_perfect = np.zeros((14))
    
    for i in range(2):
        R2_perfect[7*i + 6] = 1
        R3_perfect[7*i + 5] = 1
        R4_perfect[7*i + 4] = 1
        R5_perfect[7*i + 3] = 1
        R6_perfect[7*i + 2] = 1
        R7_perfect[7*i + 1] = 1
        R8_perfect[7*i + 0] = 1
    
    # Scalar parameters v
    v2_perfect = 1/2
    v3_perfect = 1/2
    v4_perfect = 1/2
    v5_perfect = 1/2
    v6_perfect = 1/2
    v7_perfect = 1/2
    
    # Matrix T of dimension (28,7)
    T_perfect = np.zeros((14,8))
    for i in range(7):
        for j in range(2):
            T_perfect[7*j + i, i + 1] = 1
    
    # Parameter v
    v_perfect = 1/2
    
    original_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    trainable_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    return trainable_model, original_model

def generate_model_random(mean=0.5, std=1):
    R2 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the second bit
    R3 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R4 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R6 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R7 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R8 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    v2 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    T = initialize_random_weights(mean, std, (14, 8))  # 196 neurons that allow performing the sum
    v = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    trainable_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    return trainable_model, original_model
    
def generate_model_AP(epsilon_non_zeros = 0.01, epsilon_zeros = 0.01):   
    R2_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R3_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R8_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)

    for i in range(2):
        R2_almost_perfect[7*i + 6] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R8_almost_perfect[7*i + 0] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v2_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)

    T_almost_perfect = np.zeros((14,8)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(2):
            T_almost_perfect[7*j + i, i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    trainable_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
model = 'trainable_model_stage'
training_type = 'AP_0.1_0.1'

folder = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
folder_path = f'{folder}/Parameters/{training_type}'
date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"{folder_path}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    training_stages = 3
    trainings_needed = np.zeros(training_stages)    
    visualizer = 10
    lr_changer = 250
    stage_changer = 2500*3
    N = 500

    for stage in range(3,4):
        if stage == 3:
            trainable_model_stage_3 = [trainable_model[0], 
                                       trainable_model[1], 
                                       trainable_model[2], 
                                       trainable_model[3], 
                                       trainable_model[4], 
                                       trainable_model[5], 
                                       trainable_model[6], 
                                       trainable_model[7], 
                                       trainable_model[8], 
                                       trainable_model[9], 
                                       trainable_model[10],
                                       trainable_model[11],
                                       trainable_model[12],
                                       trainable_model[13],
                                       trainable_model[14]]
        
        save_dir = f"{folder}/Trained_models/No_stages/{training_type}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_trained_count == train_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        train_size = correct_predictions_trained_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_11_20_11_28_32.pkl
# STAGE 1: Out of 8000, 304 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 88 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.5720585584640503.
# STAGE 1: Out of 8000, 1599 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 402 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.19648414850234985.
# STAGE 1: Out of 8000, 3619 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 945 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1041264757514.
# STAGE 1: Out of 8000, 5706 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1425 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.047716330736875534.
# STAGE 1: Out of 8000, 7330 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1824 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.020808661356568336.
# STAGE 1: Out of 8000, 7984 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1996 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.012677798978984356.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.008918769657611847.
# Objective completed
# Stage 1 completed in 70.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_20_11_28_32.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_20_11_28_32.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_20_11_28_32.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_20_11_28_32.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_20_11_28_32.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_20_11_28_32.txt
# Loaded trainable_model_stage_2024_11_20_11_28_34.pkl
# STAGE 1: Out of 8000, 609 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 134 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.7271324992179871.
# STAGE 1: Out of 8000, 2018 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 471 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2282797247171402.
# STAGE 1: Out of 8000, 4445 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1080 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.06559523940086365.
# STAGE 1: Out of 8000, 6895 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1706 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.026893680915236473.
# STAGE 1: Out of 8000, 7819 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1950 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.015237357467412949.
# STAGE 1: Out of 8000, 7974 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1991 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.010670340619981289.
# STAGE 1: Out of 8000, 7999 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.007592464797198772.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.005744569469243288.
# Objective completed
# Stage 1 completed in 80.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_20_11_28_34.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_20_11_28_34.txt
# STAGE 2: Out of 8000, 537 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 127 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.19799001514911652.
# STAGE 2: Out of 8000, 1001 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 233 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.15666015446186066.
# STAGE 2: Out of 8000, 1657 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 416 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.13790878653526306.
# STAGE 2: Out of 8000, 1860 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 455 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.11707370728254318.
# STAGE 2: Out of 8000, 2035 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 493 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.11350095272064209.
# STAGE 2: Out of 8000, 2369 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 580 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0974968895316124.
# STAGE 2: Out of 8000, 2821 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 700 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.08740678429603577.
# STAGE 2: Out of 8000, 3053 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 754 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07779505848884583.
# STAGE 2: Out of 8000, 3403 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 844 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06847028434276581.
# STAGE 2: Out of 8000, 3440 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 853 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06340005993843079.
# STAGE 2: Out of 8000, 3480 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 871 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06771065294742584.
# STAGE 2: Out of 8000, 3448 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 868 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06268900632858276.
# STAGE 2: Out of 8000, 3556 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 887 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059367191046476364.
# STAGE 2: Out of 8000, 3535 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 875 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06297870725393295.
# STAGE 2: Out of 8000, 3459 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 866 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06179516389966011.
# STAGE 2: Out of 8000, 3547 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 877 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06657005846500397.
# STAGE 2: Out of 8000, 3461 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 867 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05727473273873329.
# STAGE 2: Out of 8000, 3494 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 868 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06018862873315811.
# STAGE 2: Out of 8000, 3531 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 879 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.062382712960243225.
# STAGE 2: Out of 8000, 3568 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 883 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06546802073717117.
# STAGE 2: Out of 8000, 3529 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 873 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06640784442424774.
# STAGE 2: Out of 8000, 3548 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 883 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0657811313867569.
# STAGE 2: Out of 8000, 3520 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 873 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06530984491109848.
# STAGE 2: Out of 8000, 3526 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 876 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06504601985216141.
# STAGE 2: Out of 8000, 3488 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 858 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06362849473953247.
# STAGE 2: Out of 8000, 3480 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 856 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06372395157814026.
# STAGE 2: Out of 8000, 3544 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 865 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06421969830989838.
# STAGE 2: Out of 8000, 3547 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 875 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0632309764623642.
# STAGE 2: Out of 8000, 3533 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 869 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06304102391004562.
# STAGE 2: Out of 8000, 3508 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 855 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059816084802150726.
# STAGE 2: Out of 8000, 3544 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 868 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05998169258236885.
# STAGE 2: Out of 8000, 3526 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 860 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0654691681265831.
# STAGE 2: Out of 8000, 3535 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 869 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0578182116150856.
# STAGE 2: Out of 8000, 3527 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 865 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06354819238185883.
# STAGE 2: Out of 8000, 3570 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 881 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05417193844914436.
# STAGE 2: Out of 8000, 3599 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 915 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05128069967031479.
# STAGE 2: Out of 8000, 3603 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 913 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0544314980506897.
# STAGE 2: Out of 8000, 3711 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 918 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05067845806479454.
# STAGE 2: Out of 8000, 3866 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 966 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0561579167842865.
# STAGE 2: Out of 8000, 4120 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04864180088043213.
# STAGE 2: Out of 8000, 4424 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1085 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04660019278526306.
# STAGE 2: Out of 8000, 4678 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1136 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04986439272761345.
# STAGE 2: Out of 8000, 5051 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1217 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.04792385548353195.
# STAGE 2: Out of 8000, 5436 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1318 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.041181743144989014.
# STAGE 2: Out of 8000, 5864 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1432 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.03186472877860069.
# STAGE 2: Out of 8000, 7849 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1951 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.005378599278628826.
# STAGE 2: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.00028518124599941075.
# Objective completed
# Stage 2 completed in 470.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_20_11_28_34.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_20_11_28_34.txt
# STAGE 3: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0017586846370249987.
# Objective completed
# Stage 3 completed in 10.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_20_11_28_34.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_20_11_28_34.txt
# Loaded trainable_model_stage_2024_11_20_11_28_36.pkl
# STAGE 1: Out of 8000, 24 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 8 tested were predicted correctly in the current model.
# STAGE 1: Loss is 1.0192255973815918.
# STAGE 1: Out of 8000, 420 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 104 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.45592740178108215.
# STAGE 1: Out of 8000, 1154 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 279 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3033701777458191.
# STAGE 1: Out of 8000, 1837 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 471 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.21885721385478973.
# STAGE 1: Out of 8000, 2566 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 638 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.15211229026317596.
# STAGE 1: Out of 8000, 3381 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 864 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11778869479894638.
# STAGE 1: Out of 8000, 3893 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 963 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0859517976641655.
# STAGE 1: Out of 8000, 4989 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1213 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0697895735502243.
# STAGE 1: Out of 8000, 5941 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1443 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.041900113224983215.
# STAGE 1: Out of 8000, 7137 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1794 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.023595064878463745.
# STAGE 1: Out of 8000, 7796 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1942 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.011944793164730072.
# STAGE 1: Out of 8000, 7988 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1997 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.00949414074420929.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.006705829873681068.
# Objective completed
# Stage 1 completed in 130.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_20_11_28_36.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_20_11_28_36.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_20_11_28_36.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_20_11_28_36.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_20_11_28_36.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_20_11_28_36.txt
# Loaded trainable_model_stage_2024_11_20_11_28_38.pkl
# STAGE 1: Out of 8000, 1219 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 304 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3527867794036865.
# STAGE 1: Out of 8000, 2673 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 620 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.148866668343544.
# STAGE 1: Out of 8000, 6038 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1501 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.04098951816558838.
# STAGE 1: Out of 8000, 7552 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1900 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.018607061356306076.
# STAGE 1: Out of 8000, 7968 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1989 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.009855798445641994.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.006396849639713764.
# Objective completed
# Stage 1 completed in 60.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_20_11_28_38.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_20_11_28_38.txt
# STAGE 2: Out of 8000, 5835 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1423 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053425490856170654.
# STAGE 2: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.02015492506325245.
# Objective completed
# Stage 2 completed in 20.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_20_11_28_38.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_20_11_28_38.txt
# STAGE 3: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.012261235155165195.
# Objective completed
# Stage 3 completed in 10.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_20_11_28_38.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_20_11_28_38.txt
# Loaded trainable_model_stage_2024_11_20_11_28_40.pkl
# STAGE 1: Out of 8000, 590 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 151 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.48935526609420776.
# STAGE 1: Out of 8000, 2415 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 603 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1226736456155777.
# STAGE 1: Out of 8000, 6419 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1623 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.03376738354563713.
# STAGE 1: Out of 8000, 7759 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1932 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.016541950404644012.
# STAGE 1: Out of 8000, 7985 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1999 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.009823008440434933.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.006358373444527388.
# Objective completed
# Stage 1 completed in 60.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_20_11_28_40.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_20_11_28_40.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_20_11_28_40.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_20_11_28_40.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_20_11_28_40.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_20_11_28_40.txt
# Loaded trainable_model_stage_2024_11_20_11_28_42.pkl
# STAGE 1: Out of 8000, 841 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 228 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.37803661823272705.
# STAGE 1: Out of 8000, 1840 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 459 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2558481991291046.
# STAGE 1: Out of 8000, 3635 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 936 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.16741321980953217.
# STAGE 1: Out of 8000, 5365 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1382 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.14559808373451233.
# STAGE 1: Out of 8000, 5832 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1478 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12995849549770355.
# STAGE 1: Out of 8000, 5886 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1498 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1301572620868683.
# STAGE 1: Out of 8000, 5905 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1503 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12799938023090363.
# STAGE 1: Out of 8000, 5935 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1513 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12329976260662079.
# STAGE 1: Out of 8000, 5952 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1514 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12313373386859894.
# STAGE 1: Out of 8000, 5959 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1515 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11685023456811905.
# STAGE 1: Out of 8000, 5962 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1515 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.13174845278263092.
# STAGE 1: Out of 8000, 5962 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1515 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12217798084020615.
# STAGE 1: Out of 8000, 5962 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1515 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12438972294330597.
# STAGE 1: Out of 8000, 5964 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1515 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10531188547611237.
# STAGE 1: Out of 8000, 5966 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1516 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10859469324350357.
# STAGE 1: Out of 8000, 5969 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1516 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12802189588546753.
# STAGE 1: Out of 8000, 5970 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1516 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1216454729437828.
# STAGE 1: Out of 8000, 5975 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1516 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11465702950954437.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12528398633003235.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12291023135185242.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.13050545752048492.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.14198647439479828.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11429379135370255.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11151790618896484.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12218718975782394.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12153008580207825.
# STAGE 1: Out of 8000, 5981 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11036038398742676.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1517 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11428336054086685.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12615662813186646.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11152686923742294.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11804467439651489.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11593285202980042.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12462057173252106.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.13347260653972626.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12013330310583115.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11898716539144516.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12022387981414795.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.14049820601940155.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11194638907909393.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10532556474208832.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11633992195129395.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11959208548069.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1136634349822998.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10794305056333542.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12949179112911224.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.117047019302845.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1345611959695816.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1141381487250328.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11524911969900131.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12560564279556274.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12479158490896225.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10951777547597885.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11668173968791962.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10237830877304077.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11122386157512665.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1343105584383011.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12370043247938156.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11325156688690186.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11739195883274078.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11721520870923996.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11559955775737762.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1173379048705101.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.106696717441082.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11631526798009872.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11305517703294754.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11188779771327972.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12448891997337341.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12157846242189407.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1457243263721466.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12064483761787415.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10734967887401581.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1313050240278244.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1249464675784111.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12071140855550766.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12065395712852478.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1179068461060524.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10966943949460983.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11772044003009796.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.0982283502817154.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12864726781845093.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10709759593009949.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12147415429353714.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12115104496479034.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10175298899412155.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11234263330698013.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12045735865831375.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11496032029390335.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1194506362080574.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11330392211675644.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11487860232591629.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11083150655031204.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10793290287256241.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10776393115520477.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12468883395195007.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12122482806444168.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11037719994783401.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12553587555885315.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12582458555698395.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12027562409639359.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11843658238649368.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.1085832491517067.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10232831537723541.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12460464239120483.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.10589484870433807.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11741634458303452.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12114085257053375.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.11475576460361481.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12191253900527954.
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.12110093235969543.
# ...
# STAGE 1: Out of 2000, 572 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2722446918487549.
# STAGE 1: Out of 8000, 2208 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 561 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29035094380378723.
# STAGE 1: Out of 8000, 2278 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 583 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27855348587036133.
# STAGE 1: Out of 8000, 2291 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 579 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27717360854148865.
# STAGE 1: Out of 8000, 2242 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 562 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29073798656463623.
# STAGE 1: Out of 8000, 2304 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 584 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2972191870212555.
# STAGE 1: Out of 8000, 2222 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 569 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2806599736213684.
# STAGE 1: Out of 8000, 2307 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 576 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2802827060222626.
# STAGE 1: Out of 8000, 2296 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 602 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2838289141654968.
# STAGE 1: Out of 8000, 2364 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 613 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29628095030784607.
# STAGE 1: Out of 8000, 2282 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 581 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2900134027004242.
# STAGE 1: Out of 8000, 2273 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 579 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27266475558280945.
# STAGE 1: Out of 8000, 2290 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 579 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29376280307769775.
# STAGE 1: Out of 8000, 2288 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 590 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3050042986869812.
# STAGE 1: Out of 8000, 2212 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 576 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2851475775241852.
# STAGE 1: Out of 8000, 2319 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 590 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.282740980386734.
# STAGE 1: Out of 8000, 2290 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 593 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2920607924461365.
# STAGE 1: Out of 8000, 2286 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 589 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.28218719363212585.
# STAGE 1: Out of 8000, 2135 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 531 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.31804803013801575.
# STAGE 1: Out of 8000, 2105 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 544 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.30050837993621826.
# STAGE 1: Out of 8000, 2169 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 556 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29522696137428284.
# STAGE 1: Out of 8000, 2243 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 581 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2939719259738922.
# STAGE 1: Out of 8000, 2291 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 590 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2779388725757599.
# STAGE 1: Out of 8000, 2309 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 595 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2862238883972168.
# STAGE 1: Out of 8000, 2401 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 610 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.26941612362861633.
# STAGE 1: Out of 8000, 2220 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 569 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3039260506629944.
# STAGE 1: Out of 8000, 2209 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 565 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2780768573284149.
# STAGE 1: Out of 8000, 2248 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 571 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2909506857395172.
# STAGE 1: Out of 8000, 2247 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 565 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2755347192287445.
# STAGE 1: Out of 8000, 2163 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 549 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.30028507113456726.
# STAGE 1: Out of 8000, 2273 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 581 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.294475793838501.
# STAGE 1: Out of 8000, 2302 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 603 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27343517541885376.
# STAGE 1: Out of 8000, 2267 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 574 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29575857520103455.
# STAGE 1: Out of 8000, 2291 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 589 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2907063364982605.
# STAGE 1: Out of 8000, 2372 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 613 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29989326000213623.
# STAGE 1: Out of 8000, 2264 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 568 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2765594720840454.
# STAGE 1: Out of 8000, 2289 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 583 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29332345724105835.
# STAGE 1: Out of 8000, 2329 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 595 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29174092411994934.
# STAGE 1: Out of 8000, 2241 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 582 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3150246739387512.
# STAGE 1: Out of 8000, 2191 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 549 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2965098023414612.
# STAGE 1: Out of 8000, 2388 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 614 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27823588252067566.
# STAGE 1: Out of 8000, 2344 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 588 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2733630836009979.
# STAGE 1: Out of 8000, 2230 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 567 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2723364531993866.
# STAGE 1: Out of 8000, 2195 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 566 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27915117144584656.
# STAGE 1: Out of 8000, 2309 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 582 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2942292094230652.
# STAGE 1: Out of 8000, 2247 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 568 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2851327061653137.
# STAGE 1: Out of 8000, 2043 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 515 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2847650647163391.
# STAGE 1: Out of 8000, 2284 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 582 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27396053075790405.
# STAGE 1: Out of 8000, 2232 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 570 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.28669506311416626.
# STAGE 1: Out of 8000, 1953 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 495 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2759052515029907.
# STAGE 1: Out of 8000, 2281 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 585 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3113859295845032.
# STAGE 1: Out of 8000, 2316 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 590 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2788250744342804.
# STAGE 1: Out of 8000, 2296 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 591 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3082156777381897.
# STAGE 1: Out of 8000, 2215 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 565 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.26956284046173096.
# STAGE 1: Out of 8000, 2229 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 564 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29647117853164673.
# STAGE 1: Out of 8000, 2260 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 577 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3001168370246887.
# STAGE 1: Out of 8000, 2196 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 563 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2999034821987152.
# STAGE 1: Out of 8000, 2316 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 592 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.28623196482658386.
# STAGE 1: Out of 8000, 2362 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 593 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3019132614135742.
# STAGE 1: Out of 8000, 2362 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 594 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2867185175418854.
# STAGE 1: Out of 8000, 2290 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 582 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.28106340765953064.
# STAGE 1: Out of 8000, 2296 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 576 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2836912274360657.
# STAGE 1: Out of 8000, 2327 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 590 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.28569403290748596.
# STAGE 1: Out of 8000, 2338 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 598 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2671733498573303.
# STAGE 1: Out of 8000, 2170 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 551 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2999008297920227.
# STAGE 1: Out of 8000, 2120 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 538 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.3087933659553528.
# STAGE 1: Out of 8000, 2189 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 556 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29198580980300903.
# STAGE 1: Out of 8000, 2296 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 583 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27785205841064453.
# STAGE 1: Out of 8000, 2296 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 585 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2865372598171234.
# STAGE 1: Out of 8000, 2338 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 597 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.2982935607433319.
# STAGE 1: Out of 8000, 2261 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 589 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.27124178409576416.
# STAGE 1: Out of 8000, 2330 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 592 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.26734164357185364.
# STAGE 1: Out of 8000, 2267 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 589 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.29356849193573.
# Stage 1 completed in 2500.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\trainable_model_stage_1-2024_11_20_11_28_50.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_1\Stage_1_results_2024_11_20_11_28_50.txt
# Loss is NaN.
# Stage 2 completed in 1.0 trainings.
# Model trainable_model_stage_2 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\trainable_model_stage_2-2024_11_20_11_28_50.pkl
# Results of Stage 2 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_2\Stage_2_results_2024_11_20_11_28_50.txt
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\trainable_model_stage_3-2024_11_20_11_28_50.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.1_0.1/Stage_3\Stage_3_results_2024_11_20_11_28_50.txt
