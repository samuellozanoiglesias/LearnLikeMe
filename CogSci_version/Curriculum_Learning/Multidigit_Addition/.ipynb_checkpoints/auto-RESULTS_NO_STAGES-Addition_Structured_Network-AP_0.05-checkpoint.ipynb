# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_carry_over_dataset = eval(file.read())
    
# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)

    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None


def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None


# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count, carry_over_size, correct_carry_over_predictions_tested_count = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {carry_over_size}, {correct_carry_over_predictions_tested_count} tested with carry-over were predicted correctly in the current model.")      

    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)

    correct_predictions_count = 0
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
def perfect_model():
    # R vectors of dimension (14,1)
    R2_perfect = np.zeros((14))
    R3_perfect = np.zeros((14))
    R4_perfect = np.zeros((14))
    R5_perfect = np.zeros((14))
    R6_perfect = np.zeros((14))
    R7_perfect = np.zeros((14))
    R8_perfect = np.zeros((14))
    
    for i in range(2):
        R2_perfect[7*i + 6] = 1
        R3_perfect[7*i + 5] = 1
        R4_perfect[7*i + 4] = 1
        R5_perfect[7*i + 3] = 1
        R6_perfect[7*i + 2] = 1
        R7_perfect[7*i + 1] = 1
        R8_perfect[7*i + 0] = 1
    
    # Scalar parameters v
    v2_perfect = 1/2
    v3_perfect = 1/2
    v4_perfect = 1/2
    v5_perfect = 1/2
    v6_perfect = 1/2
    v7_perfect = 1/2
    
    # Matrix T of dimension (28,7)
    T_perfect = np.zeros((14,8))
    for i in range(7):
        for j in range(2):
            T_perfect[7*j + i, i + 1] = 1
    
    # Parameter v
    v_perfect = 1/2
    
    original_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    trainable_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    return trainable_model, original_model

def generate_model_random(mean=0.5, std=1):
    R2 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the second bit
    R3 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R4 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R6 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R7 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R8 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    v2 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    T = initialize_random_weights(mean, std, (14, 8))  # 196 neurons that allow performing the sum
    v = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    trainable_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    return trainable_model, original_model
    
def generate_model_AP(epsilon_non_zeros = 0.01, epsilon_zeros = 0.01):   
    R2_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R3_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R8_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)

    for i in range(2):
        R2_almost_perfect[7*i + 6] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R8_almost_perfect[7*i + 0] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v2_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)

    T_almost_perfect = np.zeros((14,8)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(2):
            T_almost_perfect[7*j + i, i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    trainable_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
model = 'trainable_model_stage'
training_type = 'AP_0.05_0.05'

folder = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
folder_path = f'{folder}/Parameters/{training_type}'
date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"{folder_path}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    training_stages = 3
    trainings_needed = np.zeros(training_stages)    
    visualizer = 10
    lr_changer = 250
    stage_changer = 2500*3
    N = 500

    for stage in range(3,4):
        if stage == 3:
            trainable_model_stage_3 = [trainable_model[0], 
                                       trainable_model[1], 
                                       trainable_model[2], 
                                       trainable_model[3], 
                                       trainable_model[4], 
                                       trainable_model[5], 
                                       trainable_model[6], 
                                       trainable_model[7], 
                                       trainable_model[8], 
                                       trainable_model[9], 
                                       trainable_model[10],
                                       trainable_model[11],
                                       trainable_model[12],
                                       trainable_model[13],
                                       trainable_model[14]]
        
        save_dir = f"{folder}/Trained_models/No_stages/{training_type}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_trained_count == train_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        train_size = correct_predictions_trained_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_11_20_11_29_20.pkl
# STAGE 1: Out of 8000, 1997 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 498 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.24362002313137054.
# STAGE 1: Out of 8000, 6574 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1634 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.034251514822244644.
# STAGE 1: Out of 8000, 7801 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1942 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.014513279311358929.
# STAGE 1: Out of 8000, 7987 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1998 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.008948134258389473.
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Loss is 0.006172615103423595.
# Objective completed
# Stage 1 completed in 50.0 trainings.
# Model trainable_model_stage_1 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\trainable_model_stage_1-2024_11_20_11_29_20.pkl
# Results of Stage 1 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_1\Stage_1_results_2024_11_20_11_29_20.txt
# STAGE 2: Out of 8000, 883 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 222 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.23461735248565674.
# STAGE 2: Out of 8000, 2607 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 649 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.11122451722621918.
# STAGE 2: Out of 8000, 2974 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 721 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.08069144934415817.
# STAGE 2: Out of 8000, 3624 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 899 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0711624026298523.
# STAGE 2: Out of 8000, 3711 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 916 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.07183369249105453.
# STAGE 2: Out of 8000, 3733 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 922 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06816352158784866.
# STAGE 2: Out of 8000, 3732 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 918 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0661388412117958.
# STAGE 2: Out of 8000, 3432 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 874 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06670518219470978.
# STAGE 2: Out of 8000, 3724 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 936 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0563141293823719.
# STAGE 2: Out of 8000, 3722 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 941 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060664102435112.
# STAGE 2: Out of 8000, 3647 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 926 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06492744386196136.
# STAGE 2: Out of 8000, 3936 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 990 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05144864320755005.
# STAGE 2: Out of 8000, 3729 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 942 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06519736349582672.
# STAGE 2: Out of 8000, 4060 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.049844060093164444.
# STAGE 2: Out of 8000, 4043 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.048424895852804184.
# STAGE 2: Out of 8000, 3941 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055537767708301544.
# STAGE 2: Out of 8000, 3824 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 954 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057542312890291214.
# STAGE 2: Out of 8000, 3940 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 976 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05814320221543312.
# STAGE 2: Out of 8000, 3980 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 991 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05957998335361481.
# STAGE 2: Out of 8000, 4075 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055372484028339386.
# STAGE 2: Out of 8000, 4089 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055360205471515656.
# STAGE 2: Out of 8000, 3825 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 960 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06047198548913002.
# STAGE 2: Out of 8000, 4054 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054383303970098495.
# STAGE 2: Out of 8000, 3714 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 929 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05906766653060913.
# STAGE 2: Out of 8000, 4120 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05289474129676819.
# STAGE 2: Out of 8000, 3707 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 944 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06366375088691711.
# STAGE 2: Out of 8000, 4128 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05742111802101135.
# STAGE 2: Out of 8000, 4031 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060167331248521805.
# STAGE 2: Out of 8000, 3948 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 982 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05548906698822975.
# STAGE 2: Out of 8000, 3914 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06307482719421387.
# STAGE 2: Out of 8000, 3896 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 972 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06509188562631607.
# STAGE 2: Out of 8000, 4039 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05606868118047714.
# STAGE 2: Out of 8000, 3896 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055630095303058624.
# STAGE 2: Out of 8000, 4061 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05388789623975754.
# STAGE 2: Out of 8000, 3974 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 981 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056268367916345596.
# STAGE 2: Out of 8000, 4018 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05263523384928703.
# STAGE 2: Out of 8000, 4051 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05584593862295151.
# STAGE 2: Out of 8000, 3843 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 970 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05753086134791374.
# STAGE 2: Out of 8000, 4147 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05457239970564842.
# STAGE 2: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05785166844725609.
# STAGE 2: Out of 8000, 4177 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05654092878103256.
# STAGE 2: Out of 8000, 3929 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 973 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059605903923511505.
# STAGE 2: Out of 8000, 3877 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 960 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06753648072481155.
# STAGE 2: Out of 8000, 4054 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 995 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05255669355392456.
# STAGE 2: Out of 8000, 3998 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 987 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06306225061416626.
# STAGE 2: Out of 8000, 4120 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05744565650820732.
# STAGE 2: Out of 8000, 4057 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05653825402259827.
# STAGE 2: Out of 8000, 4152 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0542355552315712.
# STAGE 2: Out of 8000, 3989 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 987 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06364563852548599.
# STAGE 2: Out of 8000, 3949 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 991 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05647929012775421.
# STAGE 2: Out of 8000, 4006 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056458570063114166.
# STAGE 2: Out of 8000, 4032 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05646931380033493.
# STAGE 2: Out of 8000, 3613 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 920 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06532440334558487.
# STAGE 2: Out of 8000, 4059 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05776761472225189.
# STAGE 2: Out of 8000, 4137 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05436325445771217.
# STAGE 2: Out of 8000, 4079 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05454973876476288.
# STAGE 2: Out of 8000, 4086 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05281565710902214.
# STAGE 2: Out of 8000, 4155 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05657270923256874.
# STAGE 2: Out of 8000, 3893 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05977896600961685.
# STAGE 2: Out of 8000, 3992 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 991 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056478433310985565.
# STAGE 2: Out of 8000, 3846 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 959 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057747893035411835.
# STAGE 2: Out of 8000, 4152 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055209930986166.
# STAGE 2: Out of 8000, 4128 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0537293441593647.
# STAGE 2: Out of 8000, 3903 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05995132401585579.
# STAGE 2: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1008 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06241929158568382.
# STAGE 2: Out of 8000, 3918 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 985 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059453047811985016.
# STAGE 2: Out of 8000, 4053 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056581225246191025.
# STAGE 2: Out of 8000, 4072 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057858988642692566.
# STAGE 2: Out of 8000, 3755 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 945 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060119401663541794.
# STAGE 2: Out of 8000, 3927 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 990 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05674668401479721.
# STAGE 2: Out of 8000, 3960 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 985 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05831312760710716.
# STAGE 2: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1008 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05745607241988182.
# STAGE 2: Out of 8000, 3890 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059243474155664444.
# STAGE 2: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054703693836927414.
# STAGE 2: Out of 8000, 3954 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05149204283952713.
# STAGE 2: Out of 8000, 4043 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0523407869040966.
# STAGE 2: Out of 8000, 3962 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05911458283662796.
# STAGE 2: Out of 8000, 3931 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 988 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05814991518855095.
# STAGE 2: Out of 8000, 3978 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1004 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05591656267642975.
# STAGE 2: Out of 8000, 3952 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 999 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058404695242643356.
# STAGE 2: Out of 8000, 4073 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05317480117082596.
# STAGE 2: Out of 8000, 3939 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 982 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06390000134706497.
# STAGE 2: Out of 8000, 3920 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06523971259593964.
# STAGE 2: Out of 8000, 4056 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1003 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058206938207149506.
# STAGE 2: Out of 8000, 3862 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 983 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059256892651319504.
# STAGE 2: Out of 8000, 4191 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054300688207149506.
# STAGE 2: Out of 8000, 4120 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05567622929811478.
# STAGE 2: Out of 8000, 4169 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05605045333504677.
# STAGE 2: Out of 8000, 4140 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05609242618083954.
# STAGE 2: Out of 8000, 4001 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 990 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05822214484214783.
# STAGE 2: Out of 8000, 4107 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05563093349337578.
# STAGE 2: Out of 8000, 3969 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05566409230232239.
# STAGE 2: Out of 8000, 4055 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05260700359940529.
# STAGE 2: Out of 8000, 3933 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05602749437093735.
# STAGE 2: Out of 8000, 4058 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056928105652332306.
# STAGE 2: Out of 8000, 3922 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 977 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057087916880846024.
# STAGE 2: Out of 8000, 3839 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 972 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059169888496398926.
# STAGE 2: Out of 8000, 4177 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1027 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05341627448797226.
# STAGE 2: Out of 8000, 4119 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1015 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054804712533950806.
# STAGE 2: Out of 8000, 3954 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 988 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05913710966706276.
# STAGE 2: Out of 8000, 4063 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.050589945167303085.
# STAGE 2: Out of 8000, 3973 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 988 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05906081572175026.
# STAGE 2: Out of 8000, 3996 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056513696908950806.
# STAGE 2: Out of 8000, 3937 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 981 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05791403353214264.
# STAGE 2: Out of 8000, 4124 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1020 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056103773415088654.
# STAGE 2: Out of 8000, 3991 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 992 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05645693093538284.
# STAGE 2: Out of 8000, 4007 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05928407236933708.
# STAGE 2: Out of 8000, 4078 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05714708939194679.
# STAGE 2: Out of 8000, 3934 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 983 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05482570827007294.
# STAGE 2: Out of 8000, 4027 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056947458535432816.
# STAGE 2: Out of 8000, 3855 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 971 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06077469885349274.
# STAGE 2: Out of 8000, 3943 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 973 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05261692777276039.
# STAGE 2: Out of 8000, 4052 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05617804825305939.
# STAGE 2: Out of 8000, 4040 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 995 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055978041142225266.
# STAGE 2: Out of 8000, 4024 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0530281700193882.
# STAGE 2: Out of 8000, 4261 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1051 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05313246324658394.
# STAGE 2: Out of 8000, 3961 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05995805561542511.
# STAGE 2: Out of 8000, 3917 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 972 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05925453081727028.
# STAGE 2: Out of 8000, 4000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05172734335064888.
# STAGE 2: Out of 8000, 4084 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056263964623212814.
# STAGE 2: Out of 8000, 4199 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1029 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055930245667696.
# STAGE 2: Out of 8000, 3845 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 967 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05937052518129349.
# STAGE 2: Out of 8000, 3940 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05449800193309784.
# STAGE 2: Out of 8000, 3787 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 952 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05819132551550865.
# STAGE 2: Out of 8000, 3920 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 966 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05436139926314354.
# STAGE 2: Out of 8000, 3898 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 969 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05803577974438667.
# STAGE 2: Out of 8000, 3887 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05614619702100754.
# STAGE 2: Out of 8000, 3831 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 967 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05692664533853531.
# STAGE 2: Out of 8000, 4050 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1004 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05372394621372223.
# STAGE 2: Out of 8000, 3975 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05667983740568161.
# STAGE 2: Out of 8000, 3930 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 979 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05263080075383186.
# STAGE 2: Out of 8000, 3866 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05575302243232727.
# STAGE 2: Out of 8000, 3780 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 951 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05950675904750824.
# STAGE 2: Out of 8000, 4066 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054578982293605804.
# STAGE 2: Out of 8000, 4105 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1013 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06097729131579399.
# STAGE 2: Out of 8000, 3816 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 967 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05741705372929573.
# STAGE 2: Out of 8000, 4047 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061921119689941406.
# STAGE 2: Out of 8000, 3960 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056025560945272446.
# STAGE 2: Out of 8000, 3740 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 948 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06022322177886963.
# STAGE 2: Out of 8000, 4154 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1029 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054952509701251984.
# STAGE 2: Out of 8000, 4006 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06087939813733101.
# STAGE 2: Out of 8000, 4071 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1007 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05572664737701416.
# STAGE 2: Out of 8000, 4057 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 993 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05915776640176773.
# STAGE 2: Out of 8000, 3761 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 944 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05974805727601051.
# STAGE 2: Out of 8000, 4045 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1004 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054315030574798584.
# STAGE 2: Out of 8000, 4126 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.049930885434150696.
# STAGE 2: Out of 8000, 4091 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1016 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058036576956510544.
# STAGE 2: Out of 8000, 4092 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05308470502495766.
# STAGE 2: Out of 8000, 3825 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 967 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05549178645014763.
# STAGE 2: Out of 8000, 3920 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05732499063014984.
# STAGE 2: Out of 8000, 4117 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058987390249967575.
# STAGE 2: Out of 8000, 4134 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056352753192186356.
# STAGE 2: Out of 8000, 4010 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054296594113111496.
# STAGE 2: Out of 8000, 4033 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1004 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05980117246508598.
# STAGE 2: Out of 8000, 3899 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0517767071723938.
# STAGE 2: Out of 8000, 4297 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1056 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05341057479381561.
# STAGE 2: Out of 8000, 4181 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1034 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0511278472840786.
# STAGE 2: Out of 8000, 3898 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 984 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060018207877874374.
# STAGE 2: Out of 8000, 4071 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1008 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05550016090273857.
# STAGE 2: Out of 8000, 3765 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 955 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056798070669174194.
# STAGE 2: Out of 8000, 4031 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.056045420467853546.
# STAGE 2: Out of 8000, 3920 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 987 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05393945053219795.
# STAGE 2: Out of 8000, 4059 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.055363550782203674.
# STAGE 2: Out of 8000, 3966 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 995 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05949631705880165.
# STAGE 2: Out of 8000, 3928 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060683950781822205.
# STAGE 2: Out of 8000, 4050 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.059548426419496536.
# STAGE 2: Out of 8000, 3699 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 940 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06575208157300949.
# STAGE 2: Out of 8000, 4139 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1019 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054837681353092194.
# STAGE 2: Out of 8000, 4092 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052760157734155655.
# STAGE 2: Out of 8000, 3976 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1001 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05643372982740402.
# STAGE 2: Out of 8000, 4068 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05582229048013687.
# STAGE 2: Out of 8000, 4105 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05819622799754143.
# STAGE 2: Out of 8000, 4116 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05600094050168991.
# STAGE 2: Out of 8000, 4098 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05570875480771065.
# STAGE 2: Out of 8000, 4183 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1034 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05449794977903366.
# STAGE 2: Out of 8000, 3939 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 980 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05828431248664856.
# STAGE 2: Out of 8000, 3799 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 951 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06370389461517334.
# STAGE 2: Out of 8000, 3695 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 931 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06292900443077087.
# STAGE 2: Out of 8000, 4070 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1003 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05523405596613884.
# STAGE 2: Out of 8000, 3981 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.060302916914224625.
# STAGE 2: Out of 8000, 3654 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 923 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06202734261751175.
# STAGE 2: Out of 8000, 4029 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06131642311811447.
# STAGE 2: Out of 8000, 4012 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05741646885871887.
# STAGE 2: Out of 8000, 3647 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 924 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06626986712217331.
# STAGE 2: Out of 8000, 3911 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 975 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05609472841024399.
# STAGE 2: Out of 8000, 4218 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1036 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05359145998954773.
# STAGE 2: Out of 8000, 3986 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 982 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052827443927526474.
# STAGE 2: Out of 8000, 3768 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 947 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058747027069330215.
# STAGE 2: Out of 8000, 4181 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1021 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058009665459394455.
# STAGE 2: Out of 8000, 3816 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 956 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05989371985197067.
# STAGE 2: Out of 8000, 4126 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05051927641034126.
# STAGE 2: Out of 8000, 4084 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0549807995557785.
# STAGE 2: Out of 8000, 3992 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 989 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06240827217698097.
# STAGE 2: Out of 8000, 4063 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1002 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05596182867884636.
# STAGE 2: Out of 8000, 3873 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 960 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05943268910050392.
# STAGE 2: Out of 8000, 3953 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06148376315832138.
# STAGE 2: Out of 8000, 3863 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 971 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05994012579321861.
# STAGE 2: Out of 8000, 4039 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 998 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05885586142539978.
# STAGE 2: Out of 8000, 3891 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 964 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05819768086075783.
# STAGE 2: Out of 8000, 3839 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 969 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.061793092638254166.
# STAGE 2: Out of 8000, 4152 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05787890404462814.
# STAGE 2: Out of 8000, 4157 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1026 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05401363968849182.
# STAGE 2: Out of 8000, 4084 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.057671673595905304.
# STAGE 2: Out of 8000, 4030 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05691630765795708.
# STAGE 2: Out of 8000, 4063 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 994 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06008465588092804.
# STAGE 2: Out of 8000, 4056 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054237090051174164.
# STAGE 2: Out of 8000, 4038 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1002 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05849646404385567.
# STAGE 2: Out of 8000, 4058 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1003 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05465695634484291.
# STAGE 2: Out of 8000, 4055 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06003990396857262.
# STAGE 2: Out of 8000, 4019 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1000 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054652340710163116.
# STAGE 2: Out of 8000, 4139 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1011 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05332055315375328.
# STAGE 2: Out of 8000, 4016 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1002 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05914032831788063.
# STAGE 2: Out of 8000, 4039 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1006 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05697251856327057.
# STAGE 2: Out of 8000, 3914 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 976 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05679617077112198.
# STAGE 2: Out of 8000, 4159 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1023 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05523984506726265.
# STAGE 2: Out of 8000, 3889 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 972 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058853428810834885.
# STAGE 2: Out of 8000, 3799 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 958 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0610693022608757.
# STAGE 2: Out of 8000, 4145 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.054797399789094925.
# STAGE 2: Out of 8000, 4124 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1005 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05657336115837097.
# STAGE 2: Out of 8000, 3911 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 978 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.06143270805478096.
# STAGE 2: Out of 8000, 4056 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1010 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05231443792581558.
# STAGE 2: Out of 8000, 3970 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 996 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.058330655097961426.
# STAGE 2: Out of 8000, 4030 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 997 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05768844112753868.
# STAGE 2: Out of 8000, 4103 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1018 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0535641685128212.
# STAGE 2: Out of 8000, 4059 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1014 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05657101050019264.
# STAGE 2: Out of 8000, 3896 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 976 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.053703662008047104.
# STAGE 2: Out of 8000, 3833 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 955 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.052342966198921204.
# STAGE 2: Out of 8000, 4148 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1012 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05480104684829712.
# STAGE 2: Out of 8000, 4023 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 991 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05686866492033005.
# STAGE 2: Out of 8000, 4077 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1008 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.05357115715742111.
# STAGE 2: Out of 8000, 4179 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1035 tested were predicted correctly in the current model.
# STAGE 2: Loss is 0.0529915951192379.
# STAGE 2: Out of 8000, 3802 trained were predicted correctly in the current model.
# ...
# STAGE 3: Out of 8000, 5155 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1259 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0376991406083107.
# STAGE 3: Out of 8000, 5355 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1317 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.030490702018141747.
# STAGE 3: Out of 8000, 5092 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1253 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03890286386013031.
# STAGE 3: Out of 8000, 5006 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1232 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04514904320240021.
# STAGE 3: Out of 8000, 5269 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1280 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.036499712616205215.
# STAGE 3: Out of 8000, 5125 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1253 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04267685115337372.
# STAGE 3: Out of 8000, 5290 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1300 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03499845415353775.
# STAGE 3: Out of 8000, 5142 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1261 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04441140592098236.
# STAGE 3: Out of 8000, 5221 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1277 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0338677354156971.
# STAGE 3: Out of 8000, 5110 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1256 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03992857038974762.
# STAGE 3: Out of 8000, 5175 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1280 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.035292282700538635.
# STAGE 3: Out of 8000, 5264 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1285 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03221650421619415.
# STAGE 3: Out of 8000, 5354 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1309 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.034749653190374374.
# STAGE 3: Out of 8000, 5356 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1305 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03531071916222572.
# STAGE 3: Out of 8000, 5114 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1258 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04343730956315994.
# STAGE 3: Out of 8000, 5247 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1283 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.032406747341156006.
# STAGE 3: Out of 8000, 5092 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1256 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.037088941782712936.
# STAGE 3: Out of 8000, 5111 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1260 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03886854648590088.
# STAGE 3: Out of 8000, 5080 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1250 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.040676116943359375.
# STAGE 3: Out of 8000, 5018 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1231 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04162874072790146.
# STAGE 3: Out of 8000, 5123 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1258 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04233132302761078.
# STAGE 3: Out of 8000, 5308 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1291 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03639260679483414.
# STAGE 3: Out of 8000, 5325 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1311 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03170665726065636.
# STAGE 3: Out of 8000, 5314 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1311 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.032117005437612534.
# STAGE 3: Out of 8000, 5370 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1315 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.038598641753196716.
# STAGE 3: Out of 8000, 5261 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1273 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04308197274804115.
# STAGE 3: Out of 8000, 5263 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1279 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03808334842324257.
# STAGE 3: Out of 8000, 5156 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1266 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03773875534534454.
# STAGE 3: Out of 8000, 4981 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1220 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04539203271269798.
# STAGE 3: Out of 8000, 5320 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1306 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03914607688784599.
# STAGE 3: Out of 8000, 5223 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1278 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.040123749524354935.
# STAGE 3: Out of 8000, 5116 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1268 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.041182566434144974.
# STAGE 3: Out of 8000, 5168 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1269 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03545128554105759.
# STAGE 3: Out of 8000, 5263 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1298 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04035736247897148.
# STAGE 3: Out of 8000, 5298 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1292 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03783215954899788.
# STAGE 3: Out of 8000, 5331 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1301 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03892527520656586.
# STAGE 3: Out of 8000, 5269 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1294 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.038495492190122604.
# STAGE 3: Out of 8000, 5169 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1278 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03792271018028259.
# STAGE 3: Out of 8000, 5247 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1287 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0398055836558342.
# STAGE 3: Out of 8000, 5231 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1285 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04036789759993553.
# STAGE 3: Out of 8000, 5403 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1321 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03534791246056557.
# STAGE 3: Out of 8000, 5371 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1307 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03460172936320305.
# STAGE 3: Out of 8000, 5087 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1270 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.037765514105558395.
# STAGE 3: Out of 8000, 5211 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1275 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.034118425101041794.
# STAGE 3: Out of 8000, 5356 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1310 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03767574205994606.
# STAGE 3: Out of 8000, 5287 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1293 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03213171660900116.
# STAGE 3: Out of 8000, 5350 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1309 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03604215756058693.
# STAGE 3: Out of 8000, 5111 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1256 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0364270880818367.
# STAGE 3: Out of 8000, 5251 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1269 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.039325613528490067.
# STAGE 3: Out of 8000, 5271 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1290 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03409514203667641.
# STAGE 3: Out of 8000, 5246 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1294 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.036949530243873596.
# STAGE 3: Out of 8000, 5304 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1295 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03813460096716881.
# STAGE 3: Out of 8000, 5264 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1287 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03538692370057106.
# STAGE 3: Out of 8000, 5293 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1297 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04165934398770332.
# STAGE 3: Out of 8000, 5139 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1259 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.043092820793390274.
# STAGE 3: Out of 8000, 5303 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1286 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03661977872252464.
# STAGE 3: Out of 8000, 5152 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1279 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.038227684795856476.
# STAGE 3: Out of 8000, 5054 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1248 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.040467631071805954.
# STAGE 3: Out of 8000, 5163 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1265 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04228556528687477.
# STAGE 3: Out of 8000, 5398 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1327 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03578151762485504.
# STAGE 3: Out of 8000, 5405 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1334 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03193049877882004.
# STAGE 3: Out of 8000, 5090 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1259 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.037846848368644714.
# STAGE 3: Out of 8000, 4973 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1231 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04188787564635277.
# STAGE 3: Out of 8000, 5390 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1326 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03163470700383186.
# STAGE 3: Out of 8000, 5378 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1314 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.032892122864723206.
# STAGE 3: Out of 8000, 5020 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1240 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04453974962234497.
# STAGE 3: Out of 8000, 5261 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1295 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03892482444643974.
# STAGE 3: Out of 8000, 5293 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1284 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.042206987738609314.
# STAGE 3: Out of 8000, 5361 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1305 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03917407616972923.
# STAGE 3: Out of 8000, 5093 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1251 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03725256398320198.
# STAGE 3: Out of 8000, 5047 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1227 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.036548204720020294.
# STAGE 3: Out of 8000, 5270 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1277 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0374348983168602.
# STAGE 3: Out of 8000, 5226 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1292 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03351554274559021.
# STAGE 3: Out of 8000, 5132 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1269 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.036836083978414536.
# STAGE 3: Out of 8000, 5427 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1329 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.035032305866479874.
# STAGE 3: Out of 8000, 5424 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1341 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.03517388924956322.
# STAGE 3: Out of 8000, 5167 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1280 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.04090268164873123.
# Stage 3 completed in 2500.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\trainable_model_stage_3-2024_11_20_11_29_38.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Stages/AP_0.05_0.05/Stage_3\Stage_3_results_2024_11_20_11_29_38.txt
