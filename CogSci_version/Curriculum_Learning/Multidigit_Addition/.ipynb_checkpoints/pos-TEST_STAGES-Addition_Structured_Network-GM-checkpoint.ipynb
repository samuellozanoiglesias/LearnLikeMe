# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_dataset_with_carry_over = eval(file.read())

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_with_carry_over_decimal.txt", 'r') as file:
    combinations_with_carry_over_decimal = eval(file.read())
    

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_carry_over_decimal = [pair for pair in train_couples if pair in combinations_with_carry_over_decimal]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    #column_1, column_2 = zip(*real_test_dataset)
    column_1, column_2 = zip(*test_dataset)
    
    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None

# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_count, correct_predictions_test_count, train_count, correct_predictions_train_count, test_carry_over_count, correct_carry_over_predictions_test_count, train_carry_over_count, correct_carry_over_predictions_train_count, small_train_count, correct_predictions_small_train_count, small_test_count, correct_predictions_small_test_count, small_train_carry_count, correct_predictions_small_train_carry_count, small_test_carry_count, correct_predictions_small_test_carry_count, test_carry_over_decimal_count, correct_carry_over_decimal_predictions_test_count, train_carry_over_decimal_count, correct_carry_over_decimal_predictions_train_count, small_train_carry_decimal_count, correct_predictions_small_train_carry_decimal_count, small_test_carry_decimal_count, correct_predictions_small_test_carry_decimal_count, reaction_time_carry, reaction_time_carry_decimal, reaction_time_train,reaction_time_test, reaction_time_train_carry, reaction_time_train_carry_decimal, reaction_time_small_train, reaction_time_small_test, reaction_time_small_train_carry, reaction_time_small_test_carry, reaction_time_small_train_carry_decimal, reaction_time_small_test_carry_decimal= real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_count}, {correct_predictions_train_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_count}, {correct_predictions_test_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_count}, {correct_carry_over_predictions_train_count} trained with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_count}, {correct_carry_over_predictions_test_count} tested with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_count}, {correct_predictions_small_train_count} trained with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_test_count}, {correct_predictions_small_test_count} tested with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_count}, {correct_predictions_small_train_carry_count} trained with small problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_count}, {correct_predictions_small_test_carry_count} tested with small problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_train_count} trained with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_test_count} tested with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_decimal_count}, {correct_predictions_small_train_carry_decimal_count} trained with small problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_decimal_count}, {correct_predictions_small_test_carry_decimal_count} tested with small problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: {reaction_time_carry} reaction time with carry over.")
        print(f"STAGE {stage}: {reaction_time_carry_decimal} reaction time with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_train} reaction time for train.")
        print(f"STAGE {stage}: {reaction_time_test} reaction time for test.")
        print(f"STAGE {stage}: {reaction_time_train_carry} reaction time for train with carry over .")
        print(f"STAGE {stage}: {reaction_time_train_carry_decimal} reaction time for train with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_small_train} reaction time for train small.")
        print(f"STAGE {stage}: {reaction_time_small_test} reaction time for test small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry} reaction time for train with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry} reaction time for test with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry_decimal} reaction time for train with carry over decimal and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry_decimal} reaction time for test with carry over decimal and small.") 
            
    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

def real_test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_real_test_dataset()    
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_test_count = 0
    correct_predictions_train_count = 0
    correct_carry_over_predictions_count = 0
    correct_carry_over_predictions_test_count = 0
    correct_carry_over_predictions_train_count = 0
    correct_predictions_small_train_count = 0
    correct_predictions_small_test_count = 0
    correct_predictions_small_train_carry_count = 0
    correct_predictions_small_test_carry_count = 0
    correct_carry_over_decimal_predictions_count = 0
    correct_carry_over_decimal_predictions_test_count = 0
    correct_carry_over_decimal_predictions_train_count = 0
    correct_predictions_small_train_carry_decimal_count = 0
    correct_predictions_small_test_carry_decimal_count = 0

    set_size = inputs_1.shape[0]
    train_count = len(train_couples)
    test_count = set_size - train_count
    carry_over_count = len(combinations_with_carry_over) 
    carry_over_decimal_count = len(combinations_with_carry_over_decimal) 
    train_carry_over_count = len(train_with_carry_over)
    test_carry_over_count = carry_over_count - train_carry_over_count
    small_count = len(combinations_small_problem_size)
    train_carry_over_decimal_count = len(train_with_carry_over_decimal)
    test_carry_over_decimal_count = carry_over_decimal_count - train_carry_over_decimal_count

    # Contadores adicionales
    small_train_count = 0
    small_test_count = 0
    small_train_carry_count = 0
    small_test_carry_count = 0
    small_train_carry_decimal_count = 0
    small_test_carry_decimal_count = 0
    
    reaction_time_carry = 0
    reaction_time_carry_decimal = 0
    reaction_time_train = 0
    reaction_time_test = 0
    reaction_time_train_carry = 0
    reaction_time_train_carry_decimal = 0
    reaction_time_small_train = 0
    reaction_time_small_test = 0
    reaction_time_small_train_carry = 0
    reaction_time_small_test_carry = 0
    reaction_time_small_train_carry_decimal = 0
    reaction_time_small_test_carry_decimal = 0

    for i in range(set_size):
        pair = (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1])

        start_time = time.perf_counter_ns()
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        elapsed_time = time.perf_counter_ns() - start_time

        is_small = pair in combinations_small_problem_size
        is_train = pair in train_couples
        is_carry = pair in real_test_dataset_with_carry_over
        is_carry_decimal = pair in combinations_with_carry_over_decimal

        # Actualizar tiempos de reacción y contadores totales
        if is_small:
            if is_train:
                small_train_count += 1
                reaction_time_small_train += elapsed_time
                if is_carry:
                    small_train_carry_count += 1
                    reaction_time_small_train_carry += elapsed_time
                if is_carry_decimal:
                    small_train_carry_decimal_count += 1
                    reaction_time_small_train_carry_decimal += elapsed_time
            else:
                small_test_count += 1
                reaction_time_small_test += elapsed_time
                if is_carry:
                    small_test_carry_count += 1
                    reaction_time_small_test_carry += elapsed_time
                if is_carry_decimal:
                    small_test_carry_decimal_count += 1
                    reaction_time_small_test_carry_decimal += elapsed_time

        if is_carry:
            reaction_time_carry += elapsed_time
        if is_carry_decimal:
            reaction_time_carry_decimal += elapsed_time
        if is_train:
            reaction_time_train += elapsed_time
        else:
            reaction_time_test += elapsed_time
        if is_train and is_carry:
            reaction_time_train_carry += elapsed_time
        if is_train and is_carry_decimal:
            reaction_time_train_carry_decimal += elapsed_time

        # Contar predicciones correctas
        if jnp.all(prediction == outputs[i]):
            if is_small:
                if is_train:
                    correct_predictions_small_train_count += 1
                    if is_carry:
                        correct_predictions_small_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_test_count += 1
                    if is_carry:
                        correct_predictions_small_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_test_carry_decimal_count += 1

            # Actualizar contadores previos
            if is_carry:
                correct_carry_over_predictions_count += 1 
            if is_carry_decimal:
                correct_carry_over_decimal_predictions_count += 1 
            if is_train:
                correct_predictions_train_count += 1 
            else:
                correct_predictions_test_count += 1
            if is_train and is_carry:
                correct_carry_over_predictions_train_count += 1   
            if is_train and is_carry_decimal:
                correct_carry_over_decimal_predictions_train_count += 1 
                
        elif visualize_errors == 1:
            print(f'{pair[0]} plus {pair[1]} has failed.')

    correct_carry_over_predictions_test_count = correct_carry_over_predictions_count - correct_carry_over_predictions_train_count
    correct_carry_over_decimal_predictions_test_count = correct_carry_over_decimal_predictions_count - correct_carry_over_decimal_predictions_train_count
    
    return (
        test_count,
        correct_predictions_test_count,
        train_count,
        correct_predictions_train_count,
        test_carry_over_count,
        correct_carry_over_predictions_test_count,
        train_carry_over_count,
        correct_carry_over_predictions_train_count,
        small_train_count,
        correct_predictions_small_train_count,
        small_test_count,
        correct_predictions_small_test_count,
        small_train_carry_count,
        correct_predictions_small_train_carry_count,
        small_test_carry_count,
        correct_predictions_small_test_carry_count,
        test_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_test_count,
        train_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_train_count,
        small_train_carry_decimal_count,
        correct_predictions_small_train_carry_decimal_count,
        small_test_carry_decimal_count,
        correct_predictions_small_test_carry_decimal_count,
        reaction_time_carry,
        reaction_time_carry_decimal,
        reaction_time_train,
        reaction_time_test,
        reaction_time_train_carry,
        reaction_time_train_carry_decimal,
        reaction_time_small_train,
        reaction_time_small_test,
        reaction_time_small_train_carry,
        reaction_time_small_test_carry,
        reaction_time_small_train_carry_decimal,
        reaction_time_small_test_carry_decimal
    )

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
validation_performance = 'no'
easy_examples = 'no'
type_training = 'Stages'
file_name = 'Generated_model'

if easy_examples == 'yes':
    if validation_performance == 'yes':
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_3'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_3'
    
else:
    if validation_performance == 'yes':    
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_3'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_3'

os.makedirs(os.path.dirname(output_file), exist_ok=True)

tee = Tee(output_file, 'w') 
sys.stdout = tee

try:
    visualize_errors = 0
    model = 'trainable_model_stage'
    
    date_pattern = r'trainable_model_stage_3-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
    files = sorted(
        (f for f in os.listdir(folder_path) if f.endswith('.pkl') and not f.startswith('.')),  # Filtrar archivos .pkl y ocultos
        key=lambda x: re.search(date_pattern, x).group(0) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
    
        for stage in range(1, 4):
            if easy_examples == 'yes':
                if validation_performance == 'yes':    
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                    
            else:
                if validation_performance == 'yes':   
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'

            with open(file_path, 'rb') as file:
                globals()[f"{model}_{stage}"] = pickle.load(file)
    
            print(f'Loaded {model}_{stage}-{current_time}.pkl')

            real_test = 1
            decide_test(params=globals()[f"{model}_{stage}"], stage=stage, real_test=real_test, visualize_errors=visualize_errors)
                
finally:
    sys.stdout = tee.console
    tee.close()
    
print(f'Finished, file {file_name} created')
# Out:
# Loaded trainable_model_stage_1-2024_11_19_13_22_02.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 8528308100 reaction time with carry over.
# STAGE 1: 7352328200 reaction time with carry over decimal.
# STAGE 1: 8379853000 reaction time for train.
# STAGE 1: 2088863700 reaction time for test.
# STAGE 1: 6831019300 reaction time for train with carry over .
# STAGE 1: 5881249100 reaction time for train with carry over decimal.
# STAGE 1: 1589367800 reaction time for train small.
# STAGE 1: 383113300 reaction time for test small.
# STAGE 1: 916943700 reaction time for train with carry over and small.
# STAGE 1: 212578500 reaction time for test with carry over and small.
# STAGE 1: 696343900 reaction time for train with carry over decimal and small.
# STAGE 1: 174632600 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_19_13_22_02.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10292188900 reaction time with carry over.
# STAGE 2: 8789353800 reaction time with carry over decimal.
# STAGE 2: 10132899100 reaction time for train.
# STAGE 2: 2534689400 reaction time for test.
# STAGE 2: 8232121000 reaction time for train with carry over .
# STAGE 2: 7025437300 reaction time for train with carry over decimal.
# STAGE 2: 1999909700 reaction time for train small.
# STAGE 2: 474749300 reaction time for test small.
# STAGE 2: 1165565700 reaction time for train with carry over and small.
# STAGE 2: 266738400 reaction time for test with carry over and small.
# STAGE 2: 874366400 reaction time for train with carry over decimal and small.
# STAGE 2: 214272500 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_19_13_22_02.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 10108170000 reaction time with carry over.
# STAGE 3: 8671905100 reaction time with carry over decimal.
# STAGE 3: 9911930000 reaction time for train.
# STAGE 3: 2475820000 reaction time for test.
# STAGE 3: 8084545800 reaction time for train with carry over .
# STAGE 3: 6933108200 reaction time for train with carry over decimal.
# STAGE 3: 1901186300 reaction time for train small.
# STAGE 3: 448196700 reaction time for test small.
# STAGE 3: 1116994000 reaction time for train with carry over and small.
# STAGE 3: 256906300 reaction time for test with carry over and small.
# STAGE 3: 862125900 reaction time for train with carry over decimal and small.
# STAGE 3: 209250900 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_19_16_35_43.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 8519272900 reaction time with carry over.
# STAGE 1: 7300010400 reaction time with carry over decimal.
# STAGE 1: 8382065900 reaction time for train.
# STAGE 1: 2091429800 reaction time for test.
# STAGE 1: 6820528600 reaction time for train with carry over .
# STAGE 1: 5839697200 reaction time for train with carry over decimal.
# STAGE 1: 1622607400 reaction time for train small.
# STAGE 1: 383164000 reaction time for test small.
# STAGE 1: 947157500 reaction time for train with carry over and small.
# STAGE 1: 213041500 reaction time for test with carry over and small.
# STAGE 1: 720775900 reaction time for train with carry over decimal and small.
# STAGE 1: 175884400 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_19_16_35_43.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11292136600 reaction time with carry over.
# STAGE 2: 9654751600 reaction time with carry over decimal.
# STAGE 2: 11115441200 reaction time for train.
# STAGE 2: 2747051800 reaction time for test.
# STAGE 2: 9055893600 reaction time for train with carry over .
# STAGE 2: 7724495700 reaction time for train with carry over decimal.
# STAGE 2: 2123659700 reaction time for train small.
# STAGE 2: 501952100 reaction time for test small.
# STAGE 2: 1253263700 reaction time for train with carry over and small.
# STAGE 2: 284468400 reaction time for test with carry over and small.
# STAGE 2: 967673400 reaction time for train with carry over decimal and small.
# STAGE 2: 235354600 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_19_16_35_43.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11747491600 reaction time with carry over.
# STAGE 3: 10031660000 reaction time with carry over decimal.
# STAGE 3: 11579106500 reaction time for train.
# STAGE 3: 2879520800 reaction time for test.
# STAGE 3: 9406328300 reaction time for train with carry over .
# STAGE 3: 8024140900 reaction time for train with carry over decimal.
# STAGE 3: 2293710400 reaction time for train small.
# STAGE 3: 553898800 reaction time for test small.
# STAGE 3: 1361967400 reaction time for train with carry over and small.
# STAGE 3: 322298700 reaction time for test with carry over and small.
# STAGE 3: 1032735300 reaction time for train with carry over decimal and small.
# STAGE 3: 257242600 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_19_17_28_01.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9640042800 reaction time with carry over.
# STAGE 1: 8074679600 reaction time with carry over decimal.
# STAGE 1: 9450548400 reaction time for train.
# STAGE 1: 2320932200 reaction time for test.
# STAGE 1: 7742050100 reaction time for train with carry over .
# STAGE 1: 6460629900 reaction time for train with carry over decimal.
# STAGE 1: 1734710500 reaction time for train small.
# STAGE 1: 405416100 reaction time for test small.
# STAGE 1: 1023276500 reaction time for train with carry over and small.
# STAGE 1: 226912900 reaction time for test with carry over and small.
# STAGE 1: 771724700 reaction time for train with carry over decimal and small.
# STAGE 1: 186805100 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_19_17_28_01.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11479907400 reaction time with carry over.
# STAGE 2: 9841339900 reaction time with carry over decimal.
# STAGE 2: 11306490200 reaction time for train.
# STAGE 2: 2845530400 reaction time for test.
# STAGE 2: 9174245400 reaction time for train with carry over .
# STAGE 2: 7862174600 reaction time for train with carry over decimal.
# STAGE 2: 2231754200 reaction time for train small.
# STAGE 2: 529550000 reaction time for test small.
# STAGE 2: 1290978700 reaction time for train with carry over and small.
# STAGE 2: 289233600 reaction time for test with carry over and small.
# STAGE 2: 984580200 reaction time for train with carry over decimal and small.
# STAGE 2: 239344600 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_19_17_28_01.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11333871500 reaction time with carry over.
# STAGE 3: 9657717800 reaction time with carry over decimal.
# STAGE 3: 11113170000 reaction time for train.
# STAGE 3: 2789249800 reaction time for test.
# STAGE 3: 9059414100 reaction time for train with carry over .
# STAGE 3: 7713624200 reaction time for train with carry over decimal.
# STAGE 3: 2097498000 reaction time for train small.
# STAGE 3: 503681300 reaction time for test small.
# STAGE 3: 1237531700 reaction time for train with carry over and small.
# STAGE 3: 292605200 reaction time for test with carry over and small.
# STAGE 3: 944126400 reaction time for train with carry over decimal and small.
# STAGE 3: 232606300 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_19_17_39_57.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9433261200 reaction time with carry over.
# STAGE 1: 7970197700 reaction time with carry over decimal.
# STAGE 1: 9273070500 reaction time for train.
# STAGE 1: 2309163000 reaction time for test.
# STAGE 1: 7555398800 reaction time for train with carry over .
# STAGE 1: 6366481300 reaction time for train with carry over decimal.
# STAGE 1: 1929710300 reaction time for train small.
# STAGE 1: 442313100 reaction time for test small.
# STAGE 1: 1162502800 reaction time for train with carry over and small.
# STAGE 1: 251053100 reaction time for test with carry over and small.
# STAGE 1: 827071900 reaction time for train with carry over decimal and small.
# STAGE 1: 204699900 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_19_17_39_57.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 12012502500 reaction time with carry over.
# STAGE 2: 10230488500 reaction time with carry over decimal.
# STAGE 2: 11794915000 reaction time for train.
# STAGE 2: 2920135700 reaction time for test.
# STAGE 2: 9625015700 reaction time for train with carry over .
# STAGE 2: 8195152100 reaction time for train with carry over decimal.
# STAGE 2: 2209062400 reaction time for train small.
# STAGE 2: 521313300 reaction time for test small.
# STAGE 2: 1284603100 reaction time for train with carry over and small.
# STAGE 2: 295680300 reaction time for test with carry over and small.
# STAGE 2: 969408500 reaction time for train with carry over decimal and small.
# STAGE 2: 237049400 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_19_17_39_57.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 12534287300 reaction time with carry over.
# STAGE 3: 10813349400 reaction time with carry over decimal.
# STAGE 3: 12212604600 reaction time for train.
# STAGE 3: 3027938400 reaction time for test.
# STAGE 3: 10036886300 reaction time for train with carry over .
# STAGE 3: 8653082400 reaction time for train with carry over decimal.
# STAGE 3: 2283131200 reaction time for train small.
# STAGE 3: 542456100 reaction time for test small.
# STAGE 3: 1349704900 reaction time for train with carry over and small.
# STAGE 3: 316853300 reaction time for test with carry over and small.
# STAGE 3: 1037135500 reaction time for train with carry over decimal and small.
# STAGE 3: 259547300 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_19_21_05_14.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 10292341900 reaction time with carry over.
# STAGE 1: 8765055000 reaction time with carry over decimal.
# STAGE 1: 10134950000 reaction time for train.
# STAGE 1: 2521174200 reaction time for test.
# STAGE 1: 8239411100 reaction time for train with carry over .
# STAGE 1: 7014046400 reaction time for train with carry over decimal.
# STAGE 1: 2006349200 reaction time for train small.
# STAGE 1: 464123900 reaction time for test small.
# STAGE 1: 1176245700 reaction time for train with carry over and small.
# STAGE 1: 263993100 reaction time for test with carry over and small.
# STAGE 1: 897457600 reaction time for train with carry over decimal and small.
# STAGE 1: 212376300 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_19_21_05_14.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11592531800 reaction time with carry over.
# STAGE 2: 9874427500 reaction time with carry over decimal.
# STAGE 2: 11358446000 reaction time for train.
# STAGE 2: 2839866000 reaction time for test.
# STAGE 2: 9273098600 reaction time for train with carry over .
# STAGE 2: 7893279800 reaction time for train with carry over decimal.
# STAGE 2: 2184233000 reaction time for train small.
# STAGE 2: 509999800 reaction time for test small.
# STAGE 2: 1295594300 reaction time for train with carry over and small.
# STAGE 2: 289932100 reaction time for test with carry over and small.
# STAGE 2: 997012200 reaction time for train with carry over decimal and small.
# STAGE 2: 234081500 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_19_21_05_14.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11018926500 reaction time with carry over.
# STAGE 3: 9419551100 reaction time with carry over decimal.
# STAGE 3: 10794001100 reaction time for train.
# STAGE 3: 2693734000 reaction time for test.
# STAGE 3: 8819335300 reaction time for train with carry over .
# STAGE 3: 7534755100 reaction time for train with carry over decimal.
# STAGE 3: 2039001800 reaction time for train small.
# STAGE 3: 480310700 reaction time for test small.
# STAGE 3: 1194893300 reaction time for train with carry over and small.
# STAGE 3: 269968100 reaction time for test with carry over and small.
# STAGE 3: 896377700 reaction time for train with carry over decimal and small.
# STAGE 3: 220561000 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_20_01_35_23.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9106591500 reaction time with carry over.
# STAGE 1: 7796738600 reaction time with carry over decimal.
# STAGE 1: 8952721500 reaction time for train.
# STAGE 1: 2214083700 reaction time for test.
# STAGE 1: 7302120800 reaction time for train with carry over .
# STAGE 1: 6241180400 reaction time for train with carry over decimal.
# STAGE 1: 1724721500 reaction time for train small.
# STAGE 1: 403490900 reaction time for test small.
# STAGE 1: 1006673700 reaction time for train with carry over and small.
# STAGE 1: 230314600 reaction time for test with carry over and small.
# STAGE 1: 776749800 reaction time for train with carry over decimal and small.
# STAGE 1: 190471300 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_20_01_35_23.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11092229200 reaction time with carry over.
# STAGE 2: 9494300200 reaction time with carry over decimal.
# STAGE 2: 10875979200 reaction time for train.
# STAGE 2: 2735923600 reaction time for test.
# STAGE 2: 8858585200 reaction time for train with carry over .
# STAGE 2: 7585692600 reaction time for train with carry over decimal.
# STAGE 2: 2080881600 reaction time for train small.
# STAGE 2: 499912800 reaction time for test small.
# STAGE 2: 1219244000 reaction time for train with carry over and small.
# STAGE 2: 282170400 reaction time for test with carry over and small.
# STAGE 2: 914463800 reaction time for train with carry over decimal and small.
# STAGE 2: 227197600 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_20_01_35_23.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11559454100 reaction time with carry over.
# STAGE 3: 9884440600 reaction time with carry over decimal.
# STAGE 3: 11335108000 reaction time for train.
# STAGE 3: 2838260200 reaction time for test.
# STAGE 3: 9227410200 reaction time for train with carry over .
# STAGE 3: 7893344500 reaction time for train with carry over decimal.
# STAGE 3: 2158333000 reaction time for train small.
# STAGE 3: 505673500 reaction time for test small.
# STAGE 3: 1271309900 reaction time for train with carry over and small.
# STAGE 3: 295794900 reaction time for test with carry over and small.
# STAGE 3: 957190000 reaction time for train with carry over decimal and small.
# STAGE 3: 234192800 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_20_06_05_47.pkl
# STAGE 1: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9617844500 reaction time with carry over.
# STAGE 1: 8261592300 reaction time with carry over decimal.
# STAGE 1: 9430971200 reaction time for train.
# STAGE 1: 2371312300 reaction time for test.
# STAGE 1: 7690012500 reaction time for train with carry over .
# STAGE 1: 6599280000 reaction time for train with carry over decimal.
# STAGE 1: 1835449100 reaction time for train small.
# STAGE 1: 433572000 reaction time for test small.
# STAGE 1: 1085039400 reaction time for train with carry over and small.
# STAGE 1: 242878500 reaction time for test with carry over and small.
# STAGE 1: 838383000 reaction time for train with carry over decimal and small.
# STAGE 1: 203004800 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_20_06_05_47.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11407914200 reaction time with carry over.
# STAGE 2: 9735293500 reaction time with carry over decimal.
# STAGE 2: 11215835200 reaction time for train.
# STAGE 2: 2796593500 reaction time for test.
# STAGE 2: 9136860300 reaction time for train with carry over .
# STAGE 2: 7786447100 reaction time for train with carry over decimal.
# STAGE 2: 2156574000 reaction time for train small.
# STAGE 2: 510161800 reaction time for test small.
# STAGE 2: 1267185100 reaction time for train with carry over and small.
# STAGE 2: 285108700 reaction time for test with carry over and small.
# STAGE 2: 951840800 reaction time for train with carry over decimal and small.
# STAGE 2: 232234300 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_20_06_05_47.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11071433200 reaction time with carry over.
# STAGE 3: 9474970900 reaction time with carry over decimal.
# STAGE 3: 10837213500 reaction time for train.
# STAGE 3: 2756007300 reaction time for test.
# STAGE 3: 8827697100 reaction time for train with carry over .
# STAGE 3: 7555124600 reaction time for train with carry over decimal.
# STAGE 3: 2096190300 reaction time for train small.
# STAGE 3: 505430700 reaction time for test small.
# STAGE 3: 1225924700 reaction time for train with carry over and small.
# STAGE 3: 282690300 reaction time for test with carry over and small.
# STAGE 3: 930469100 reaction time for train with carry over decimal and small.
# STAGE 3: 231754400 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_20_10_30_52.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9688855700 reaction time with carry over.
# STAGE 1: 8351687400 reaction time with carry over decimal.
# STAGE 1: 9591105000 reaction time for train.
# STAGE 1: 2383944700 reaction time for test.
# STAGE 1: 7760132500 reaction time for train with carry over .
# STAGE 1: 6690326200 reaction time for train with carry over decimal.
# STAGE 1: 1914029500 reaction time for train small.
# STAGE 1: 459044800 reaction time for test small.
# STAGE 1: 1119831200 reaction time for train with carry over and small.
# STAGE 1: 256826400 reaction time for test with carry over and small.
# STAGE 1: 868826000 reaction time for train with carry over decimal and small.
# STAGE 1: 211460300 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_20_10_30_52.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 12563383800 reaction time with carry over.
# STAGE 2: 10858884400 reaction time with carry over decimal.
# STAGE 2: 12403598000 reaction time for train.
# STAGE 2: 3050605600 reaction time for test.
# STAGE 2: 10074891500 reaction time for train with carry over .
# STAGE 2: 8707637800 reaction time for train with carry over decimal.
# STAGE 2: 2392432000 reaction time for train small.
# STAGE 2: 561618600 reaction time for test small.
# STAGE 2: 1392504800 reaction time for train with carry over and small.
# STAGE 2: 317957600 reaction time for test with carry over and small.
# STAGE 2: 1057121800 reaction time for train with carry over decimal and small.
# STAGE 2: 259852200 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_20_10_30_52.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# ...
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10303703200 reaction time with carry over.
# STAGE 2: 8816469600 reaction time with carry over decimal.
# STAGE 2: 10115854500 reaction time for train.
# STAGE 2: 2526842100 reaction time for test.
# STAGE 2: 8243295600 reaction time for train with carry over .
# STAGE 2: 7049912400 reaction time for train with carry over decimal.
# STAGE 2: 1944664300 reaction time for train small.
# STAGE 2: 459109000 reaction time for test small.
# STAGE 2: 1143190400 reaction time for train with carry over and small.
# STAGE 2: 260907400 reaction time for test with carry over and small.
# STAGE 2: 867411900 reaction time for train with carry over decimal and small.
# STAGE 2: 211838100 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_20_11_30_33.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 10040221900 reaction time with carry over.
# STAGE 3: 8581099600 reaction time with carry over decimal.
# STAGE 3: 9837544800 reaction time for train.
# STAGE 3: 2459579000 reaction time for test.
# STAGE 3: 8032385800 reaction time for train with carry over .
# STAGE 3: 6858945800 reaction time for train with carry over decimal.
# STAGE 3: 1878304600 reaction time for train small.
# STAGE 3: 444018100 reaction time for test small.
# STAGE 3: 1103699900 reaction time for train with carry over and small.
# STAGE 3: 251915300 reaction time for test with carry over and small.
# STAGE 3: 838731300 reaction time for train with carry over decimal and small.
# STAGE 3: 204348700 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_20_11_30_35.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 8223502600 reaction time with carry over.
# STAGE 1: 7029208400 reaction time with carry over decimal.
# STAGE 1: 8069538100 reaction time for train.
# STAGE 1: 2013870100 reaction time for test.
# STAGE 1: 6580604400 reaction time for train with carry over .
# STAGE 1: 5618746100 reaction time for train with carry over decimal.
# STAGE 1: 1553227100 reaction time for train small.
# STAGE 1: 366328900 reaction time for test small.
# STAGE 1: 912004300 reaction time for train with carry over and small.
# STAGE 1: 208261700 reaction time for test with carry over and small.
# STAGE 1: 693295300 reaction time for train with carry over decimal and small.
# STAGE 1: 169472200 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_20_11_30_35.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10328245600 reaction time with carry over.
# STAGE 2: 8836258600 reaction time with carry over decimal.
# STAGE 2: 10130316400 reaction time for train.
# STAGE 2: 2536789800 reaction time for test.
# STAGE 2: 8257149900 reaction time for train with carry over .
# STAGE 2: 7059821300 reaction time for train with carry over decimal.
# STAGE 2: 1951522400 reaction time for train small.
# STAGE 2: 461228300 reaction time for test small.
# STAGE 2: 1149316200 reaction time for train with carry over and small.
# STAGE 2: 262604900 reaction time for test with carry over and small.
# STAGE 2: 875462700 reaction time for train with carry over decimal and small.
# STAGE 2: 213107400 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_20_11_30_35.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 9885615700 reaction time with carry over.
# STAGE 3: 8453290500 reaction time with carry over decimal.
# STAGE 3: 9697376800 reaction time for train.
# STAGE 3: 2423548500 reaction time for test.
# STAGE 3: 7908817700 reaction time for train with carry over .
# STAGE 3: 6757369300 reaction time for train with carry over decimal.
# STAGE 3: 1860998100 reaction time for train small.
# STAGE 3: 440793700 reaction time for test small.
# STAGE 3: 1094013700 reaction time for train with carry over and small.
# STAGE 3: 250610200 reaction time for test with carry over and small.
# STAGE 3: 830732800 reaction time for train with carry over decimal and small.
# STAGE 3: 203341000 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_1-2024_11_20_11_30_37.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 8159492200 reaction time with carry over.
# STAGE 1: 6952804800 reaction time with carry over decimal.
# STAGE 1: 8007861500 reaction time for train.
# STAGE 1: 1995320100 reaction time for test.
# STAGE 1: 6531255700 reaction time for train with carry over .
# STAGE 1: 5556905900 reaction time for train with carry over decimal.
# STAGE 1: 1531203700 reaction time for train small.
# STAGE 1: 361656500 reaction time for test small.
# STAGE 1: 898113700 reaction time for train with carry over and small.
# STAGE 1: 205308300 reaction time for test with carry over and small.
# STAGE 1: 681850100 reaction time for train with carry over decimal and small.
# STAGE 1: 166604600 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_2-2024_11_20_11_30_37.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10240378400 reaction time with carry over.
# STAGE 2: 8761139700 reaction time with carry over decimal.
# STAGE 2: 10047289300 reaction time for train.
# STAGE 2: 2511733000 reaction time for test.
# STAGE 2: 8192295000 reaction time for train with carry over .
# STAGE 2: 7003980200 reaction time for train with carry over decimal.
# STAGE 2: 1928736600 reaction time for train small.
# STAGE 2: 456979300 reaction time for test small.
# STAGE 2: 1134754900 reaction time for train with carry over and small.
# STAGE 2: 259762500 reaction time for test with carry over and small.
# STAGE 2: 862309700 reaction time for train with carry over decimal and small.
# STAGE 2: 210791500 reaction time for test with carry over decimal and small.
# Loaded trainable_model_stage_3-2024_11_20_11_30_37.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 9940172600 reaction time with carry over.
# STAGE 3: 8498805100 reaction time with carry over decimal.
# STAGE 3: 9753729500 reaction time for train.
# STAGE 3: 2435813400 reaction time for test.
# STAGE 3: 7953929600 reaction time for train with carry over .
# STAGE 3: 6794583900 reaction time for train with carry over decimal.
# STAGE 3: 1878011500 reaction time for train small.
# STAGE 3: 443623200 reaction time for test small.
# STAGE 3: 1104518300 reaction time for train with carry over and small.
# STAGE 3: 251818100 reaction time for test with carry over and small.
# STAGE 3: 839952900 reaction time for train with carry over decimal and small.
# STAGE 3: 204976300 reaction time for test with carry over decimal and small.
# Finished, file Generated_model created
