# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_dataset_with_carry_over = eval(file.read())

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_small_problem_size_binary.txt", 'r') as file:
    combinations_small_problem_size_binary = eval(file.read())
    
with open(f"{folder}/combinations_with_carry_over_decimal.txt", 'r') as file:
    combinations_with_carry_over_decimal = eval(file.read())
    

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_carry_over_decimal = [pair for pair in train_couples if pair in combinations_with_carry_over_decimal]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    #column_1, column_2 = zip(*real_test_dataset)
    column_1, column_2 = zip(*test_dataset)
    
    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None

# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z
    
def neural_network_2(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)
    
# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_count, correct_predictions_test_count, train_count, correct_predictions_train_count, test_carry_over_count, correct_carry_over_predictions_test_count, train_carry_over_count, correct_carry_over_predictions_train_count, small_train_count, correct_predictions_small_train_count, small_test_count, correct_predictions_small_test_count, small_train_carry_count, correct_predictions_small_train_carry_count, small_test_carry_count, correct_predictions_small_test_carry_count, test_carry_over_decimal_count, correct_carry_over_decimal_predictions_test_count, train_carry_over_decimal_count, correct_carry_over_decimal_predictions_train_count, small_train_carry_decimal_count, correct_predictions_small_train_carry_decimal_count, small_test_carry_decimal_count, correct_predictions_small_test_carry_decimal_count, small_binary_train_count, correct_predictions_small_binary_train_count, small_binary_test_count, correct_predictions_small_binary_test_count, small_binary_train_carry_count, correct_predictions_small_binary_train_carry_count, small_binary_test_carry_count, correct_predictions_small_binary_test_carry_count, small_binary_train_carry_decimal_count, correct_predictions_small_binary_train_carry_decimal_count, small_binary_test_carry_decimal_count, correct_predictions_small_binary_test_carry_decimal_count, reaction_time_carry, reaction_time_carry_decimal, reaction_time_train,reaction_time_test, reaction_time_train_carry, reaction_time_train_carry_decimal, reaction_time_small_train, reaction_time_small_test, reaction_time_small_train_carry, reaction_time_small_test_carry, reaction_time_small_train_carry_decimal, reaction_time_small_test_carry_decimal, reaction_time_small_binary_train, reaction_time_small_binary_test, reaction_time_small_binary_train_carry, reaction_time_small_binary_test_carry, reaction_time_small_binary_train_carry_decimal, reaction_time_small_binary_test_carry_decimal = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_count}, {correct_predictions_train_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_count}, {correct_predictions_test_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_count}, {correct_carry_over_predictions_train_count} trained with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_count}, {correct_carry_over_predictions_test_count} tested with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_count}, {correct_predictions_small_train_count} trained with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_test_count}, {correct_predictions_small_test_count} tested with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_count}, {correct_predictions_small_train_carry_count} trained with small problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_count}, {correct_predictions_small_test_carry_count} tested with small problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_train_count} trained with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_test_count} tested with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_decimal_count}, {correct_predictions_small_train_carry_decimal_count} trained with small problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_decimal_count}, {correct_predictions_small_test_carry_decimal_count} tested with small problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_count}, {correct_predictions_small_binary_train_count} trained with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_test_count}, {correct_predictions_small_binary_test_count} tested with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_count}, {correct_predictions_small_binary_train_carry_count} trained with small binary problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_count}, {correct_predictions_small_binary_test_carry_count} tested with small binary problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_decimal_count}, {correct_predictions_small_binary_train_carry_decimal_count} trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_decimal_count}, {correct_predictions_small_binary_test_carry_decimal_count} tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: {reaction_time_carry} reaction time with carry over.")
        print(f"STAGE {stage}: {reaction_time_carry_decimal} reaction time with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_train} reaction time for train.")
        print(f"STAGE {stage}: {reaction_time_test} reaction time for test.")
        print(f"STAGE {stage}: {reaction_time_train_carry} reaction time for train with carry over .")
        print(f"STAGE {stage}: {reaction_time_train_carry_decimal} reaction time for train with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_small_train} reaction time for train small.")
        print(f"STAGE {stage}: {reaction_time_small_test} reaction time for test small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry} reaction time for train with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry} reaction time for test with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry_decimal} reaction time for train with carry over decimal and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry_decimal} reaction time for test with carry over decimal and small.") 
        print(f"STAGE {stage}: {reaction_time_small_binary_train} reaction time for train small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test} reaction time for test small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry} reaction time for train with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry} reaction time for test with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry_decimal} reaction time for train with carry over decimal and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry_decimal} reaction time for test with carry over decimal and small binary.") 
            
    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

def real_test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_real_test_dataset()    
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_test_count = 0
    correct_predictions_train_count = 0
    correct_carry_over_predictions_count = 0
    correct_carry_over_predictions_test_count = 0
    correct_carry_over_predictions_train_count = 0
    correct_predictions_small_train_count = 0
    correct_predictions_small_test_count = 0
    correct_predictions_small_train_carry_count = 0
    correct_predictions_small_test_carry_count = 0
    correct_carry_over_decimal_predictions_count = 0
    correct_carry_over_decimal_predictions_test_count = 0
    correct_carry_over_decimal_predictions_train_count = 0
    correct_predictions_small_train_carry_decimal_count = 0
    correct_predictions_small_test_carry_decimal_count = 0
    correct_predictions_small_binary_train_count = 0
    correct_predictions_small_binary_test_count = 0
    correct_predictions_small_binary_train_carry_count = 0
    correct_predictions_small_binary_test_carry_count = 0
    correct_predictions_small_binary_train_carry_decimal_count = 0
    correct_predictions_small_binary_test_carry_decimal_count = 0
    
    set_size = inputs_1.shape[0]
    train_count = len(train_couples)
    test_count = set_size - train_count
    carry_over_count = len(combinations_with_carry_over) 
    carry_over_decimal_count = len(combinations_with_carry_over_decimal) 
    train_carry_over_count = len(train_with_carry_over)
    test_carry_over_count = carry_over_count - train_carry_over_count
    small_count = len(combinations_small_problem_size)
    small_binary_count = len(combinations_small_problem_size_binary)
    train_carry_over_decimal_count = len(train_with_carry_over_decimal)
    test_carry_over_decimal_count = carry_over_decimal_count - train_carry_over_decimal_count

    # Contadores adicionales
    small_train_count = 0
    small_test_count = 0
    small_train_carry_count = 0
    small_test_carry_count = 0
    small_train_carry_decimal_count = 0
    small_test_carry_decimal_count = 0
    small_binary_train_count = 0
    small_binary_test_count = 0
    small_binary_train_carry_count = 0
    small_binary_test_carry_count = 0
    small_binary_train_carry_decimal_count = 0
    small_binary_test_carry_decimal_count = 0
    
    reaction_time_carry = 0
    reaction_time_carry_decimal = 0
    reaction_time_train = 0
    reaction_time_test = 0
    reaction_time_train_carry = 0
    reaction_time_train_carry_decimal = 0
    reaction_time_small_train = 0
    reaction_time_small_test = 0
    reaction_time_small_train_carry = 0
    reaction_time_small_test_carry = 0
    reaction_time_small_train_carry_decimal = 0
    reaction_time_small_test_carry_decimal = 0
    reaction_time_small_binary_train = 0
    reaction_time_small_binary_test = 0
    reaction_time_small_binary_train_carry = 0
    reaction_time_small_binary_test_carry = 0
    reaction_time_small_binary_train_carry_decimal = 0
    reaction_time_small_binary_test_carry_decimal = 0

    for i in range(set_size):
        pair = (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1])

        start_time = time.perf_counter_ns()
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        elapsed_time = time.perf_counter_ns() - start_time

        is_small = pair in combinations_small_problem_size
        is_small_binary = pair in combinations_small_problem_size_binary
        is_train = pair in train_couples
        is_carry = pair in combinations_with_carry_over
        is_carry_decimal = pair in combinations_with_carry_over_decimal

        # Actualizar tiempos de reacción y contadores totales
        if is_small:
            if is_train:
                small_train_count += 1
                reaction_time_small_train += elapsed_time
                if is_carry:
                    small_train_carry_count += 1
                    reaction_time_small_train_carry += elapsed_time
                if is_carry_decimal:
                    small_train_carry_decimal_count += 1
                    reaction_time_small_train_carry_decimal += elapsed_time
            else:
                small_test_count += 1
                reaction_time_small_test += elapsed_time
                if is_carry:
                    small_test_carry_count += 1
                    reaction_time_small_test_carry += elapsed_time
                if is_carry_decimal:
                    small_test_carry_decimal_count += 1
                    reaction_time_small_test_carry_decimal += elapsed_time

        # Actualizar tiempos de reacción y contadores totales
        if is_small_binary:
            if is_train:
                small_binary_train_count += 1
                reaction_time_small_binary_train += elapsed_time
                if is_carry:
                    small_binary_train_carry_count += 1
                    reaction_time_small_binary_train_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_train_carry_decimal_count += 1
                    reaction_time_small_binary_train_carry_decimal += elapsed_time
            else:
                small_binary_test_count += 1
                reaction_time_small_binary_test += elapsed_time
                if is_carry:
                    small_binary_test_carry_count += 1
                    reaction_time_small_binary_test_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_test_carry_decimal_count += 1
                    reaction_time_small_binary_test_carry_decimal += elapsed_time

        if is_carry:
            reaction_time_carry += elapsed_time
        if is_carry_decimal:
            reaction_time_carry_decimal += elapsed_time
        if is_train:
            reaction_time_train += elapsed_time
        else:
            reaction_time_test += elapsed_time
        if is_train and is_carry:
            reaction_time_train_carry += elapsed_time
        if is_train and is_carry_decimal:
            reaction_time_train_carry_decimal += elapsed_time

        # Contar predicciones correctas
        if jnp.all(prediction == outputs[i]):
            if is_small:
                if is_train:
                    correct_predictions_small_train_count += 1
                    if is_carry:
                        correct_predictions_small_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_test_count += 1
                    if is_carry:
                        correct_predictions_small_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_test_carry_decimal_count += 1

            if is_small_binary:
                if is_train:
                    correct_predictions_small_binary_train_count += 1
                    if is_carry:
                        correct_predictions_small_binary_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_binary_test_count += 1
                    if is_carry:
                        correct_predictions_small_binary_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_test_carry_decimal_count += 1

            # Actualizar contadores previos
            if is_carry:
                correct_carry_over_predictions_count += 1 
            if is_carry_decimal:
                correct_carry_over_decimal_predictions_count += 1 
            if is_train:
                correct_predictions_train_count += 1 
            else:
                correct_predictions_test_count += 1
            if is_train and is_carry:
                correct_carry_over_predictions_train_count += 1   
            if is_train and is_carry_decimal:
                correct_carry_over_decimal_predictions_train_count += 1 
                
        elif visualize_errors == 1:
            print(f'{pair[0]} plus {pair[1]} has failed.')

    correct_carry_over_predictions_test_count = correct_carry_over_predictions_count - correct_carry_over_predictions_train_count
    correct_carry_over_decimal_predictions_test_count = correct_carry_over_decimal_predictions_count - correct_carry_over_decimal_predictions_train_count
    
    return (
        test_count,
        correct_predictions_test_count,
        train_count,
        correct_predictions_train_count,
        test_carry_over_count,
        correct_carry_over_predictions_test_count,
        train_carry_over_count,
        correct_carry_over_predictions_train_count,
        small_train_count,
        correct_predictions_small_train_count,
        small_test_count,
        correct_predictions_small_test_count,
        small_train_carry_count,
        correct_predictions_small_train_carry_count,
        small_test_carry_count,
        correct_predictions_small_test_carry_count,
        test_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_test_count,
        train_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_train_count,
        small_train_carry_decimal_count,
        correct_predictions_small_train_carry_decimal_count,
        small_test_carry_decimal_count,
        correct_predictions_small_test_carry_decimal_count,
        small_binary_train_count,
        correct_predictions_small_binary_train_count,
        small_binary_test_count,
        correct_predictions_small_binary_test_count,
        small_binary_train_carry_count,
        correct_predictions_small_binary_train_carry_count,
        small_binary_test_carry_count,
        correct_predictions_small_binary_test_carry_count,
        small_binary_train_carry_decimal_count,
        correct_predictions_small_binary_train_carry_decimal_count,
        small_binary_test_carry_decimal_count,
        correct_predictions_small_binary_test_carry_decimal_count,
        reaction_time_carry,
        reaction_time_carry_decimal,
        reaction_time_train,
        reaction_time_test,
        reaction_time_train_carry,
        reaction_time_train_carry_decimal,
        reaction_time_small_train,
        reaction_time_small_test,
        reaction_time_small_train_carry,
        reaction_time_small_test_carry,
        reaction_time_small_train_carry_decimal,
        reaction_time_small_test_carry_decimal,
        reaction_time_small_binary_train,
        reaction_time_small_binary_test,
        reaction_time_small_binary_train_carry,
        reaction_time_small_binary_test_carry,
        reaction_time_small_binary_train_carry_decimal,
        reaction_time_small_binary_test_carry_decimal
    )

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stage_by_stage/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
validation_performance = 'no'
easy_examples = 'no'
type_training = 'Stage_by_stage'
file_name = 'AP_0.05_0.05'

if easy_examples == 'yes':
    if validation_performance == 'yes':
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_2'
    
else:
    if validation_performance == 'yes':    
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_2'

os.makedirs(os.path.dirname(output_file), exist_ok=True)

tee = Tee(output_file, 'w') 
sys.stdout = tee

try:
    visualize_errors = 0
    model = 'trainable_model_stage'
    
    date_pattern = r'trainable_model_stage_2-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
    files = sorted(
        (f for f in os.listdir(folder_path) if f.endswith('.pkl') and not f.startswith('.')),  # Filtrar archivos .pkl y ocultos
        key=lambda x: re.search(date_pattern, x).group(0) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
    
        for stage in range(1, 3):
            if easy_examples == 'yes':
                if validation_performance == 'yes':    
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                    
            else:
                if validation_performance == 'yes':   
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'

            with open(file_path, 'rb') as file:
                globals()[f"{model}_{stage}"] = pickle.load(file)
    
            print(f'Loaded {model}_{stage}-{current_time}.pkl')

            real_test = 1
            decide_test(params=globals()[f"{model}_{stage}"], stage=stage, real_test=real_test, visualize_errors=visualize_errors)
                
finally:
    sys.stdout = tee.console
    tee.close()
    
print(f'Finished, file {file_name} created')
# Out:
# Loaded trainable_model_stage_1-2024_11_18_18_05_05.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9143024900 reaction time with carry over.
# STAGE 1: 7801624500 reaction time with carry over decimal.
# STAGE 1: 8970214100 reaction time for train.
# STAGE 1: 2255458100 reaction time for test.
# STAGE 1: 7306048700 reaction time for train with carry over .
# STAGE 1: 6227754800 reaction time for train with carry over decimal.
# STAGE 1: 1733690500 reaction time for train small.
# STAGE 1: 420494500 reaction time for test small.
# STAGE 1: 1005840500 reaction time for train with carry over and small.
# STAGE 1: 237790300 reaction time for test with carry over and small.
# STAGE 1: 782059200 reaction time for train with carry over decimal and small.
# STAGE 1: 197117200 reaction time for test with carry over decimal and small.
# STAGE 1: 7848551200 reaction time for train small binary.
# STAGE 1: 1938449100 reaction time for test small binary.
# STAGE 1: 6184385800 reaction time for train with carry over and small binary.
# STAGE 1: 1519967200 reaction time for test with carry over and small binary.
# STAGE 1: 5106091900 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1256860700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_18_18_05_05.pkl
# STAGE 2: Out of 8000, 5662 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1395 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4700 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1159 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1083 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 260 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 645 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 154 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3974 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 996 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 464 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 127 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4937 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1194 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3975 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 958 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3249 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 795 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11559437900 reaction time with carry over.
# STAGE 2: 9919165200 reaction time with carry over decimal.
# STAGE 2: 11323656900 reaction time for train.
# STAGE 2: 2833600400 reaction time for test.
# STAGE 2: 9249416300 reaction time for train with carry over .
# STAGE 2: 7924281100 reaction time for train with carry over decimal.
# STAGE 2: 2102215500 reaction time for train small.
# STAGE 2: 499061100 reaction time for test small.
# STAGE 2: 1248214500 reaction time for train with carry over and small.
# STAGE 2: 286371000 reaction time for test with carry over and small.
# STAGE 2: 946448500 reaction time for train with carry over decimal and small.
# STAGE 2: 229765600 reaction time for test with carry over decimal and small.
# STAGE 2: 9861796800 reaction time for train small binary.
# STAGE 2: 2427137000 reaction time for test small binary.
# STAGE 2: 7787556200 reaction time for train with carry over and small binary.
# STAGE 2: 1903558200 reaction time for test with carry over and small binary.
# STAGE 2: 6462421000 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1588420700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_13_21_44.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9442769300 reaction time with carry over.
# STAGE 1: 8147656100 reaction time with carry over decimal.
# STAGE 1: 9247785800 reaction time for train.
# STAGE 1: 2306839000 reaction time for test.
# STAGE 1: 7557198000 reaction time for train with carry over .
# STAGE 1: 6512792700 reaction time for train with carry over decimal.
# STAGE 1: 1754340900 reaction time for train small.
# STAGE 1: 410948100 reaction time for test small.
# STAGE 1: 1037692100 reaction time for train with carry over and small.
# STAGE 1: 236126300 reaction time for test with carry over and small.
# STAGE 1: 793165300 reaction time for train with carry over decimal and small.
# STAGE 1: 193161500 reaction time for test with carry over decimal and small.
# STAGE 1: 8042322600 reaction time for train small binary.
# STAGE 1: 1961028600 reaction time for test small binary.
# STAGE 1: 6351734800 reaction time for train with carry over and small binary.
# STAGE 1: 1539760900 reaction time for test with carry over and small binary.
# STAGE 1: 5307329500 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1289053000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_13_21_44.pkl
# STAGE 2: Out of 8000, 5470 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1317 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4671 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1121 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 566 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 133 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 416 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 92 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 4103 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 981 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 311 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 75 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4947 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1191 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4148 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 995 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3580 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 855 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11381297800 reaction time with carry over.
# STAGE 2: 9720384300 reaction time with carry over decimal.
# STAGE 2: 11242260800 reaction time for train.
# STAGE 2: 2789531400 reaction time for test.
# STAGE 2: 9105669300 reaction time for train with carry over .
# STAGE 2: 7784664500 reaction time for train with carry over decimal.
# STAGE 2: 2207053400 reaction time for train small.
# STAGE 2: 529177300 reaction time for test small.
# STAGE 2: 1286546000 reaction time for train with carry over and small.
# STAGE 2: 307453900 reaction time for test with carry over and small.
# STAGE 2: 970663600 reaction time for train with carry over decimal and small.
# STAGE 2: 235074700 reaction time for test with carry over decimal and small.
# STAGE 2: 9864891600 reaction time for train small binary.
# STAGE 2: 2408739600 reaction time for test small binary.
# STAGE 2: 7728300100 reaction time for train with carry over and small binary.
# STAGE 2: 1894836700 reaction time for test with carry over and small binary.
# STAGE 2: 6407295300 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1554928000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_16_34_42.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9466535500 reaction time with carry over.
# STAGE 1: 8140819400 reaction time with carry over decimal.
# STAGE 1: 9285967900 reaction time for train.
# STAGE 1: 2325080900 reaction time for test.
# STAGE 1: 7569096200 reaction time for train with carry over .
# STAGE 1: 6507059100 reaction time for train with carry over decimal.
# STAGE 1: 1742215700 reaction time for train small.
# STAGE 1: 413474500 reaction time for test small.
# STAGE 1: 1016563900 reaction time for train with carry over and small.
# STAGE 1: 233121500 reaction time for test with carry over and small.
# STAGE 1: 771844600 reaction time for train with carry over decimal and small.
# STAGE 1: 187290100 reaction time for test with carry over decimal and small.
# STAGE 1: 8116613600 reaction time for train small binary.
# STAGE 1: 2000545100 reaction time for test small binary.
# STAGE 1: 6399741900 reaction time for train with carry over and small binary.
# STAGE 1: 1572903500 reaction time for test with carry over and small binary.
# STAGE 1: 5337704800 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1309224500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_16_34_42.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11150310800 reaction time with carry over.
# STAGE 2: 9446650500 reaction time with carry over decimal.
# STAGE 2: 10907649400 reaction time for train.
# STAGE 2: 2749642300 reaction time for test.
# STAGE 2: 8899149100 reaction time for train with carry over .
# STAGE 2: 7524236400 reaction time for train with carry over decimal.
# STAGE 2: 2073643000 reaction time for train small.
# STAGE 2: 490466400 reaction time for test small.
# STAGE 2: 1232306000 reaction time for train with carry over and small.
# STAGE 2: 284664300 reaction time for test with carry over and small.
# STAGE 2: 944309700 reaction time for train with carry over decimal and small.
# STAGE 2: 233350600 reaction time for test with carry over decimal and small.
# STAGE 2: 9568435600 reaction time for train small binary.
# STAGE 2: 2377363900 reaction time for test small binary.
# STAGE 2: 7559935300 reaction time for train with carry over and small binary.
# STAGE 2: 1878883300 reaction time for test with carry over and small binary.
# STAGE 2: 6185022600 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1550135700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_17_43_33.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1999 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1630 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 363 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 206 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1717 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1348 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9642561300 reaction time with carry over.
# STAGE 1: 8253592100 reaction time with carry over decimal.
# STAGE 1: 9398728500 reaction time for train.
# STAGE 1: 2391291600 reaction time for test.
# STAGE 1: 7685674300 reaction time for train with carry over .
# STAGE 1: 6563479900 reaction time for train with carry over decimal.
# STAGE 1: 1773296000 reaction time for train small.
# STAGE 1: 420612300 reaction time for test small.
# STAGE 1: 1042238900 reaction time for train with carry over and small.
# STAGE 1: 237491200 reaction time for test with carry over and small.
# STAGE 1: 788436100 reaction time for train with carry over decimal and small.
# STAGE 1: 193166200 reaction time for test with carry over decimal and small.
# STAGE 1: 8176882800 reaction time for train small binary.
# STAGE 1: 2052125200 reaction time for test small binary.
# STAGE 1: 6463828600 reaction time for train with carry over and small binary.
# STAGE 1: 1617720600 reaction time for test with carry over and small binary.
# STAGE 1: 5341634200 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1350945800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_17_43_33.pkl
# STAGE 2: Out of 8000, 3881 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 943 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 3531 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 855 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 461 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 111 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 438 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 99 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 2720 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 649 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 255 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 62 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3552 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 859 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3202 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 771 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2391 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 565 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10901549700 reaction time with carry over.
# STAGE 2: 9329887500 reaction time with carry over decimal.
# STAGE 2: 10710475000 reaction time for train.
# STAGE 2: 2669557100 reaction time for test.
# STAGE 2: 8724101200 reaction time for train with carry over .
# STAGE 2: 7462270100 reaction time for train with carry over decimal.
# STAGE 2: 2067545900 reaction time for train small.
# STAGE 2: 481226600 reaction time for test small.
# STAGE 2: 1225087400 reaction time for train with carry over and small.
# STAGE 2: 274590500 reaction time for test with carry over and small.
# STAGE 2: 925790500 reaction time for train with carry over decimal and small.
# STAGE 2: 221523500 reaction time for test with carry over decimal and small.
# STAGE 2: 9365944100 reaction time for train small binary.
# STAGE 2: 2297509200 reaction time for test small binary.
# STAGE 2: 7379570300 reaction time for train with carry over and small binary.
# STAGE 2: 1805400600 reaction time for test with carry over and small binary.
# STAGE 2: 6117739200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1495569500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_20_42_21.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9218876500 reaction time with carry over.
# STAGE 1: 7877709800 reaction time with carry over decimal.
# STAGE 1: 9064484000 reaction time for train.
# STAGE 1: 2303624100 reaction time for test.
# STAGE 1: 7347739200 reaction time for train with carry over .
# STAGE 1: 6283129500 reaction time for train with carry over decimal.
# STAGE 1: 1825336400 reaction time for train small.
# STAGE 1: 452967600 reaction time for test small.
# STAGE 1: 1060494000 reaction time for train with carry over and small.
# STAGE 1: 260038100 reaction time for test with carry over and small.
# STAGE 1: 819557600 reaction time for train with carry over decimal and small.
# STAGE 1: 204219300 reaction time for test with carry over decimal and small.
# STAGE 1: 7923221500 reaction time for train small binary.
# STAGE 1: 1980983000 reaction time for test small binary.
# STAGE 1: 6206476700 reaction time for train with carry over and small binary.
# STAGE 1: 1548496200 reaction time for test with carry over and small binary.
# STAGE 1: 5141867000 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1271939200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_20_42_21.pkl
# STAGE 2: Out of 8000, 7174 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1792 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 5837 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1464 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1326 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 304 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 771 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 170 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 5066 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1276 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 598 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 146 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 6246 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1530 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4909 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 1202 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 4138 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 1014 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11168677400 reaction time with carry over.
# STAGE 2: 9540715000 reaction time with carry over decimal.
# STAGE 2: 10955748800 reaction time for train.
# STAGE 2: 2736766400 reaction time for test.
# STAGE 2: 8934576500 reaction time for train with carry over .
# STAGE 2: 7619382000 reaction time for train with carry over decimal.
# STAGE 2: 2090057900 reaction time for train small.
# STAGE 2: 500603200 reaction time for test small.
# STAGE 2: 1231056100 reaction time for train with carry over and small.
# STAGE 2: 285851400 reaction time for test with carry over and small.
# STAGE 2: 938468900 reaction time for train with carry over decimal and small.
# STAGE 2: 235911700 reaction time for test with carry over decimal and small.
# STAGE 2: 9570769800 reaction time for train small binary.
# STAGE 2: 2357296000 reaction time for test small binary.
# STAGE 2: 7549597500 reaction time for train with carry over and small binary.
# STAGE 2: 1854630500 reaction time for test with carry over and small binary.
# STAGE 2: 6234403000 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1541862600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_20_48_56.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9142025400 reaction time with carry over.
# STAGE 1: 7817175300 reaction time with carry over decimal.
# STAGE 1: 8961583300 reaction time for train.
# STAGE 1: 2228436900 reaction time for test.
# STAGE 1: 7318509600 reaction time for train with carry over .
# STAGE 1: 6256383500 reaction time for train with carry over decimal.
# STAGE 1: 1687905100 reaction time for train small.
# STAGE 1: 396402400 reaction time for test small.
# STAGE 1: 997518900 reaction time for train with carry over and small.
# STAGE 1: 226710500 reaction time for test with carry over and small.
# STAGE 1: 759186900 reaction time for train with carry over decimal and small.
# STAGE 1: 181188600 reaction time for test with carry over decimal and small.
# STAGE 1: 7820161400 reaction time for train small binary.
# STAGE 1: 1907569300 reaction time for test small binary.
# STAGE 1: 6177087700 reaction time for train with carry over and small binary.
# STAGE 1: 1502648200 reaction time for test with carry over and small binary.
# STAGE 1: 5114961600 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1239924200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_20_48_56.pkl
# STAGE 2: Out of 8000, 2969 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 733 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 2936 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 724 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 360 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 79 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 348 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 77 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 1993 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 500 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 196 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 46 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 2466 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 591 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 2433 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 582 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 1490 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 358 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11243802500 reaction time with carry over.
# STAGE 2: 9619641700 reaction time with carry over decimal.
# STAGE 2: 10950050600 reaction time for train.
# STAGE 2: 2766893700 reaction time for test.
# STAGE 2: 8967867400 reaction time for train with carry over .
# STAGE 2: 7665841900 reaction time for train with carry over decimal.
# STAGE 2: 2056585400 reaction time for train small.
# STAGE 2: 478279400 reaction time for test small.
# STAGE 2: 1203857000 reaction time for train with carry over and small.
# STAGE 2: 272797500 reaction time for test with carry over and small.
# STAGE 2: 926176100 reaction time for train with carry over decimal and small.
# STAGE 2: 223080900 reaction time for test with carry over decimal and small.
# STAGE 2: 9552088300 reaction time for train small binary.
# STAGE 2: 2363568300 reaction time for test small binary.
# STAGE 2: 7569905100 reaction time for train with carry over and small binary.
# STAGE 2: 1872609700 reaction time for test with carry over and small binary.
# STAGE 2: 6267879600 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1550474400 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_01_16_24.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9257330000 reaction time with carry over.
# STAGE 1: 7885936200 reaction time with carry over decimal.
# STAGE 1: 9068861700 reaction time for train.
# STAGE 1: 2248473100 reaction time for test.
# STAGE 1: 7417336300 reaction time for train with carry over .
# STAGE 1: 6309420400 reaction time for train with carry over decimal.
# STAGE 1: 1691115300 reaction time for train small.
# STAGE 1: 400098100 reaction time for test small.
# STAGE 1: 999187500 reaction time for train with carry over and small.
# STAGE 1: 231210200 reaction time for test with carry over and small.
# STAGE 1: 746618000 reaction time for train with carry over decimal and small.
# STAGE 1: 182767800 reaction time for test with carry over decimal and small.
# STAGE 1: 7951099400 reaction time for train small binary.
# STAGE 1: 1932737600 reaction time for test small binary.
# STAGE 1: 6299574000 reaction time for train with carry over and small binary.
# STAGE 1: 1524258200 reaction time for test with carry over and small binary.
# STAGE 1: 5191658100 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1260780300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_01_16_24.pkl
# STAGE 2: Out of 8000, 5010 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1228 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4427 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1084 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 359 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 86 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 292 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 69 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3861 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 935 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 219 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 53 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4645 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1131 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4062 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 987 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3496 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 838 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11363060500 reaction time with carry over.
# STAGE 2: 9697729000 reaction time with carry over decimal.
# STAGE 2: 11180103700 reaction time for train.
# STAGE 2: 2768690900 reaction time for test.
# STAGE 2: 9121240700 reaction time for train with carry over .
# STAGE 2: 7773816700 reaction time for train with carry over decimal.
# STAGE 2: 2106937600 reaction time for train small.
# STAGE 2: 495991300 reaction time for test small.
# STAGE 2: 1234530600 reaction time for train with carry over and small.
# STAGE 2: 279068200 reaction time for test with carry over and small.
# STAGE 2: 936040400 reaction time for train with carry over decimal and small.
# STAGE 2: 228280100 reaction time for test with carry over decimal and small.
# STAGE 2: 9779543400 reaction time for train small binary.
# STAGE 2: 2393209400 reaction time for test small binary.
# STAGE 2: 7720680400 reaction time for train with carry over and small binary.
# STAGE 2: 1866338300 reaction time for test with carry over and small binary.
# STAGE 2: 6373256400 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1548430800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_05_46_23.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# ...
# STAGE 2: Out of 364, 81 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 245 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 66 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3979 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 959 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 161 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 46 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4503 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1106 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4004 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 982 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3439 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 831 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10953171700 reaction time with carry over.
# STAGE 2: 9330424100 reaction time with carry over decimal.
# STAGE 2: 10737970500 reaction time for train.
# STAGE 2: 2672141500 reaction time for test.
# STAGE 2: 8776102800 reaction time for train with carry over .
# STAGE 2: 7470966800 reaction time for train with carry over decimal.
# STAGE 2: 2047280500 reaction time for train small.
# STAGE 2: 481100600 reaction time for test small.
# STAGE 2: 1205156900 reaction time for train with carry over and small.
# STAGE 2: 272669100 reaction time for test with carry over and small.
# STAGE 2: 903580300 reaction time for train with carry over decimal and small.
# STAGE 2: 218311900 reaction time for test with carry over decimal and small.
# STAGE 2: 9405956900 reaction time for train small binary.
# STAGE 2: 2297259100 reaction time for test small binary.
# STAGE 2: 7444089200 reaction time for train with carry over and small binary.
# STAGE 2: 1802186500 reaction time for test with carry over and small binary.
# STAGE 2: 6138953200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1484574900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_29_36.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9317646700 reaction time with carry over.
# STAGE 1: 7910160200 reaction time with carry over decimal.
# STAGE 1: 9115715200 reaction time for train.
# STAGE 1: 2272655300 reaction time for test.
# STAGE 1: 7455851500 reaction time for train with carry over .
# STAGE 1: 6314957200 reaction time for train with carry over decimal.
# STAGE 1: 1757939400 reaction time for train small.
# STAGE 1: 413294000 reaction time for test small.
# STAGE 1: 1025275300 reaction time for train with carry over and small.
# STAGE 1: 232206000 reaction time for test with carry over and small.
# STAGE 1: 790771400 reaction time for train with carry over decimal and small.
# STAGE 1: 192006100 reaction time for test with carry over decimal and small.
# STAGE 1: 7972723500 reaction time for train small binary.
# STAGE 1: 1958983600 reaction time for test small binary.
# STAGE 1: 6312859800 reaction time for train with carry over and small binary.
# STAGE 1: 1548123500 reaction time for test with carry over and small binary.
# STAGE 1: 5171965500 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1281531300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_29_36.pkl
# STAGE 2: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10937243900 reaction time with carry over.
# STAGE 2: 9364385500 reaction time with carry over decimal.
# STAGE 2: 10723212600 reaction time for train.
# STAGE 2: 2710747300 reaction time for test.
# STAGE 2: 8726822700 reaction time for train with carry over .
# STAGE 2: 7468729500 reaction time for train with carry over decimal.
# STAGE 2: 2048173700 reaction time for train small.
# STAGE 2: 482502200 reaction time for test small.
# STAGE 2: 1209534000 reaction time for train with carry over and small.
# STAGE 2: 275860000 reaction time for test with carry over and small.
# STAGE 2: 917166800 reaction time for train with carry over decimal and small.
# STAGE 2: 219848000 reaction time for test with carry over decimal and small.
# STAGE 2: 9409633300 reaction time for train small binary.
# STAGE 2: 2327937200 reaction time for test small binary.
# STAGE 2: 7413243400 reaction time for train with carry over and small binary.
# STAGE 2: 1827611100 reaction time for test with carry over and small binary.
# STAGE 2: 6155150200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1512845900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_29_38.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 8843106400 reaction time with carry over.
# STAGE 1: 7512145800 reaction time with carry over decimal.
# STAGE 1: 8698814200 reaction time for train.
# STAGE 1: 2168381500 reaction time for test.
# STAGE 1: 7088014900 reaction time for train with carry over .
# STAGE 1: 6013489000 reaction time for train with carry over decimal.
# STAGE 1: 1711803600 reaction time for train small.
# STAGE 1: 410283400 reaction time for test small.
# STAGE 1: 1006184600 reaction time for train with carry over and small.
# STAGE 1: 222963900 reaction time for test with carry over and small.
# STAGE 1: 758881700 reaction time for train with carry over decimal and small.
# STAGE 1: 182936500 reaction time for test with carry over decimal and small.
# STAGE 1: 7612012600 reaction time for train small binary.
# STAGE 1: 1867415600 reaction time for test small binary.
# STAGE 1: 6001213300 reaction time for train with carry over and small binary.
# STAGE 1: 1454125600 reaction time for test with carry over and small binary.
# STAGE 1: 4926687400 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1197690900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_29_38.pkl
# STAGE 2: Out of 8000, 4436 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1144 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 3583 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 922 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 751 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 183 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 407 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 95 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3178 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 813 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 319 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 79 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3851 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 977 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 2998 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 755 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2593 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 646 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10619810200 reaction time with carry over.
# STAGE 2: 9080585500 reaction time with carry over decimal.
# STAGE 2: 10435704200 reaction time for train.
# STAGE 2: 2586848300 reaction time for test.
# STAGE 2: 8509930600 reaction time for train with carry over .
# STAGE 2: 7277729400 reaction time for train with carry over decimal.
# STAGE 2: 1962246000 reaction time for train small.
# STAGE 2: 468317000 reaction time for test small.
# STAGE 2: 1149023400 reaction time for train with carry over and small.
# STAGE 2: 262899000 reaction time for test with carry over and small.
# STAGE 2: 888231100 reaction time for train with carry over decimal and small.
# STAGE 2: 217646500 reaction time for test with carry over decimal and small.
# STAGE 2: 9182213100 reaction time for train small binary.
# STAGE 2: 2233668800 reaction time for test small binary.
# STAGE 2: 7256439500 reaction time for train with carry over and small binary.
# STAGE 2: 1756700100 reaction time for test with carry over and small binary.
# STAGE 2: 6024238300 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1449676600 reaction time for test with carry over decimal and small binary.
# Finished, file AP_0.05_0.05 created
