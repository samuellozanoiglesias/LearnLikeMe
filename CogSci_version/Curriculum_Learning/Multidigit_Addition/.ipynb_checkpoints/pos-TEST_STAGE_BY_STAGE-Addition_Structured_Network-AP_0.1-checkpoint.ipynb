# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_dataset_with_carry_over = eval(file.read())

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_small_problem_size_binary.txt", 'r') as file:
    combinations_small_problem_size_binary = eval(file.read())
    
with open(f"{folder}/combinations_with_carry_over_decimal.txt", 'r') as file:
    combinations_with_carry_over_decimal = eval(file.read())
    

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_carry_over_decimal = [pair for pair in train_couples if pair in combinations_with_carry_over_decimal]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    #column_1, column_2 = zip(*real_test_dataset)
    column_1, column_2 = zip(*test_dataset)
    
    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None

# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z
    
def neural_network_2(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)
    
# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_count, correct_predictions_test_count, train_count, correct_predictions_train_count, test_carry_over_count, correct_carry_over_predictions_test_count, train_carry_over_count, correct_carry_over_predictions_train_count, small_train_count, correct_predictions_small_train_count, small_test_count, correct_predictions_small_test_count, small_train_carry_count, correct_predictions_small_train_carry_count, small_test_carry_count, correct_predictions_small_test_carry_count, test_carry_over_decimal_count, correct_carry_over_decimal_predictions_test_count, train_carry_over_decimal_count, correct_carry_over_decimal_predictions_train_count, small_train_carry_decimal_count, correct_predictions_small_train_carry_decimal_count, small_test_carry_decimal_count, correct_predictions_small_test_carry_decimal_count, small_binary_train_count, correct_predictions_small_binary_train_count, small_binary_test_count, correct_predictions_small_binary_test_count, small_binary_train_carry_count, correct_predictions_small_binary_train_carry_count, small_binary_test_carry_count, correct_predictions_small_binary_test_carry_count, small_binary_train_carry_decimal_count, correct_predictions_small_binary_train_carry_decimal_count, small_binary_test_carry_decimal_count, correct_predictions_small_binary_test_carry_decimal_count, reaction_time_carry, reaction_time_carry_decimal, reaction_time_train,reaction_time_test, reaction_time_train_carry, reaction_time_train_carry_decimal, reaction_time_small_train, reaction_time_small_test, reaction_time_small_train_carry, reaction_time_small_test_carry, reaction_time_small_train_carry_decimal, reaction_time_small_test_carry_decimal, reaction_time_small_binary_train, reaction_time_small_binary_test, reaction_time_small_binary_train_carry, reaction_time_small_binary_test_carry, reaction_time_small_binary_train_carry_decimal, reaction_time_small_binary_test_carry_decimal = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_count}, {correct_predictions_train_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_count}, {correct_predictions_test_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_count}, {correct_carry_over_predictions_train_count} trained with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_count}, {correct_carry_over_predictions_test_count} tested with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_count}, {correct_predictions_small_train_count} trained with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_test_count}, {correct_predictions_small_test_count} tested with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_count}, {correct_predictions_small_train_carry_count} trained with small problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_count}, {correct_predictions_small_test_carry_count} tested with small problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_train_count} trained with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_test_count} tested with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_decimal_count}, {correct_predictions_small_train_carry_decimal_count} trained with small problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_decimal_count}, {correct_predictions_small_test_carry_decimal_count} tested with small problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_count}, {correct_predictions_small_binary_train_count} trained with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_test_count}, {correct_predictions_small_binary_test_count} tested with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_count}, {correct_predictions_small_binary_train_carry_count} trained with small binary problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_count}, {correct_predictions_small_binary_test_carry_count} tested with small binary problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_decimal_count}, {correct_predictions_small_binary_train_carry_decimal_count} trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_decimal_count}, {correct_predictions_small_binary_test_carry_decimal_count} tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: {reaction_time_carry} reaction time with carry over.")
        print(f"STAGE {stage}: {reaction_time_carry_decimal} reaction time with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_train} reaction time for train.")
        print(f"STAGE {stage}: {reaction_time_test} reaction time for test.")
        print(f"STAGE {stage}: {reaction_time_train_carry} reaction time for train with carry over .")
        print(f"STAGE {stage}: {reaction_time_train_carry_decimal} reaction time for train with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_small_train} reaction time for train small.")
        print(f"STAGE {stage}: {reaction_time_small_test} reaction time for test small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry} reaction time for train with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry} reaction time for test with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry_decimal} reaction time for train with carry over decimal and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry_decimal} reaction time for test with carry over decimal and small.") 
        print(f"STAGE {stage}: {reaction_time_small_binary_train} reaction time for train small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test} reaction time for test small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry} reaction time for train with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry} reaction time for test with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry_decimal} reaction time for train with carry over decimal and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry_decimal} reaction time for test with carry over decimal and small binary.") 
            
    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

def real_test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_real_test_dataset()    
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_test_count = 0
    correct_predictions_train_count = 0
    correct_carry_over_predictions_count = 0
    correct_carry_over_predictions_test_count = 0
    correct_carry_over_predictions_train_count = 0
    correct_predictions_small_train_count = 0
    correct_predictions_small_test_count = 0
    correct_predictions_small_train_carry_count = 0
    correct_predictions_small_test_carry_count = 0
    correct_carry_over_decimal_predictions_count = 0
    correct_carry_over_decimal_predictions_test_count = 0
    correct_carry_over_decimal_predictions_train_count = 0
    correct_predictions_small_train_carry_decimal_count = 0
    correct_predictions_small_test_carry_decimal_count = 0
    correct_predictions_small_binary_train_count = 0
    correct_predictions_small_binary_test_count = 0
    correct_predictions_small_binary_train_carry_count = 0
    correct_predictions_small_binary_test_carry_count = 0
    correct_predictions_small_binary_train_carry_decimal_count = 0
    correct_predictions_small_binary_test_carry_decimal_count = 0
    
    set_size = inputs_1.shape[0]
    train_count = len(train_couples)
    test_count = set_size - train_count
    carry_over_count = len(combinations_with_carry_over) 
    carry_over_decimal_count = len(combinations_with_carry_over_decimal) 
    train_carry_over_count = len(train_with_carry_over)
    test_carry_over_count = carry_over_count - train_carry_over_count
    small_count = len(combinations_small_problem_size)
    small_binary_count = len(combinations_small_problem_size_binary)
    train_carry_over_decimal_count = len(train_with_carry_over_decimal)
    test_carry_over_decimal_count = carry_over_decimal_count - train_carry_over_decimal_count

    # Contadores adicionales
    small_train_count = 0
    small_test_count = 0
    small_train_carry_count = 0
    small_test_carry_count = 0
    small_train_carry_decimal_count = 0
    small_test_carry_decimal_count = 0
    small_binary_train_count = 0
    small_binary_test_count = 0
    small_binary_train_carry_count = 0
    small_binary_test_carry_count = 0
    small_binary_train_carry_decimal_count = 0
    small_binary_test_carry_decimal_count = 0
    
    reaction_time_carry = 0
    reaction_time_carry_decimal = 0
    reaction_time_train = 0
    reaction_time_test = 0
    reaction_time_train_carry = 0
    reaction_time_train_carry_decimal = 0
    reaction_time_small_train = 0
    reaction_time_small_test = 0
    reaction_time_small_train_carry = 0
    reaction_time_small_test_carry = 0
    reaction_time_small_train_carry_decimal = 0
    reaction_time_small_test_carry_decimal = 0
    reaction_time_small_binary_train = 0
    reaction_time_small_binary_test = 0
    reaction_time_small_binary_train_carry = 0
    reaction_time_small_binary_test_carry = 0
    reaction_time_small_binary_train_carry_decimal = 0
    reaction_time_small_binary_test_carry_decimal = 0

    for i in range(set_size):
        pair = (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1])

        start_time = time.perf_counter_ns()
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        elapsed_time = time.perf_counter_ns() - start_time

        is_small = pair in combinations_small_problem_size
        is_small_binary = pair in combinations_small_problem_size_binary
        is_train = pair in train_couples
        is_carry = pair in combinations_with_carry_over
        is_carry_decimal = pair in combinations_with_carry_over_decimal

        # Actualizar tiempos de reacción y contadores totales
        if is_small:
            if is_train:
                small_train_count += 1
                reaction_time_small_train += elapsed_time
                if is_carry:
                    small_train_carry_count += 1
                    reaction_time_small_train_carry += elapsed_time
                if is_carry_decimal:
                    small_train_carry_decimal_count += 1
                    reaction_time_small_train_carry_decimal += elapsed_time
            else:
                small_test_count += 1
                reaction_time_small_test += elapsed_time
                if is_carry:
                    small_test_carry_count += 1
                    reaction_time_small_test_carry += elapsed_time
                if is_carry_decimal:
                    small_test_carry_decimal_count += 1
                    reaction_time_small_test_carry_decimal += elapsed_time

        # Actualizar tiempos de reacción y contadores totales
        if is_small_binary:
            if is_train:
                small_binary_train_count += 1
                reaction_time_small_binary_train += elapsed_time
                if is_carry:
                    small_binary_train_carry_count += 1
                    reaction_time_small_binary_train_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_train_carry_decimal_count += 1
                    reaction_time_small_binary_train_carry_decimal += elapsed_time
            else:
                small_binary_test_count += 1
                reaction_time_small_binary_test += elapsed_time
                if is_carry:
                    small_binary_test_carry_count += 1
                    reaction_time_small_binary_test_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_test_carry_decimal_count += 1
                    reaction_time_small_binary_test_carry_decimal += elapsed_time

        if is_carry:
            reaction_time_carry += elapsed_time
        if is_carry_decimal:
            reaction_time_carry_decimal += elapsed_time
        if is_train:
            reaction_time_train += elapsed_time
        else:
            reaction_time_test += elapsed_time
        if is_train and is_carry:
            reaction_time_train_carry += elapsed_time
        if is_train and is_carry_decimal:
            reaction_time_train_carry_decimal += elapsed_time

        # Contar predicciones correctas
        if jnp.all(prediction == outputs[i]):
            if is_small:
                if is_train:
                    correct_predictions_small_train_count += 1
                    if is_carry:
                        correct_predictions_small_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_test_count += 1
                    if is_carry:
                        correct_predictions_small_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_test_carry_decimal_count += 1

            if is_small_binary:
                if is_train:
                    correct_predictions_small_binary_train_count += 1
                    if is_carry:
                        correct_predictions_small_binary_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_binary_test_count += 1
                    if is_carry:
                        correct_predictions_small_binary_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_test_carry_decimal_count += 1

            # Actualizar contadores previos
            if is_carry:
                correct_carry_over_predictions_count += 1 
            if is_carry_decimal:
                correct_carry_over_decimal_predictions_count += 1 
            if is_train:
                correct_predictions_train_count += 1 
            else:
                correct_predictions_test_count += 1
            if is_train and is_carry:
                correct_carry_over_predictions_train_count += 1   
            if is_train and is_carry_decimal:
                correct_carry_over_decimal_predictions_train_count += 1 
                
        elif visualize_errors == 1:
            print(f'{pair[0]} plus {pair[1]} has failed.')

    correct_carry_over_predictions_test_count = correct_carry_over_predictions_count - correct_carry_over_predictions_train_count
    correct_carry_over_decimal_predictions_test_count = correct_carry_over_decimal_predictions_count - correct_carry_over_decimal_predictions_train_count
    
    return (
        test_count,
        correct_predictions_test_count,
        train_count,
        correct_predictions_train_count,
        test_carry_over_count,
        correct_carry_over_predictions_test_count,
        train_carry_over_count,
        correct_carry_over_predictions_train_count,
        small_train_count,
        correct_predictions_small_train_count,
        small_test_count,
        correct_predictions_small_test_count,
        small_train_carry_count,
        correct_predictions_small_train_carry_count,
        small_test_carry_count,
        correct_predictions_small_test_carry_count,
        test_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_test_count,
        train_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_train_count,
        small_train_carry_decimal_count,
        correct_predictions_small_train_carry_decimal_count,
        small_test_carry_decimal_count,
        correct_predictions_small_test_carry_decimal_count,
        small_binary_train_count,
        correct_predictions_small_binary_train_count,
        small_binary_test_count,
        correct_predictions_small_binary_test_count,
        small_binary_train_carry_count,
        correct_predictions_small_binary_train_carry_count,
        small_binary_test_carry_count,
        correct_predictions_small_binary_test_carry_count,
        small_binary_train_carry_decimal_count,
        correct_predictions_small_binary_train_carry_decimal_count,
        small_binary_test_carry_decimal_count,
        correct_predictions_small_binary_test_carry_decimal_count,
        reaction_time_carry,
        reaction_time_carry_decimal,
        reaction_time_train,
        reaction_time_test,
        reaction_time_train_carry,
        reaction_time_train_carry_decimal,
        reaction_time_small_train,
        reaction_time_small_test,
        reaction_time_small_train_carry,
        reaction_time_small_test_carry,
        reaction_time_small_train_carry_decimal,
        reaction_time_small_test_carry_decimal,
        reaction_time_small_binary_train,
        reaction_time_small_binary_test,
        reaction_time_small_binary_train_carry,
        reaction_time_small_binary_test_carry,
        reaction_time_small_binary_train_carry_decimal,
        reaction_time_small_binary_test_carry_decimal
    )

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stage_by_stage/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
validation_performance = 'no'
easy_examples = 'no'
type_training = 'Stage_by_stage'
file_name = 'AP_0.1_0.1'

if easy_examples == 'yes':
    if validation_performance == 'yes':
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_2'
    
else:
    if validation_performance == 'yes':    
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_2'

os.makedirs(os.path.dirname(output_file), exist_ok=True)

tee = Tee(output_file, 'w') 
sys.stdout = tee

try:
    visualize_errors = 0
    model = 'trainable_model_stage'
    
    date_pattern = r'trainable_model_stage_2-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
    files = sorted(
        (f for f in os.listdir(folder_path) if f.endswith('.pkl') and not f.startswith('.')),  # Filtrar archivos .pkl y ocultos
        key=lambda x: re.search(date_pattern, x).group(0) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
    
        for stage in range(1, 3):
            if easy_examples == 'yes':
                if validation_performance == 'yes':    
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                    
            else:
                if validation_performance == 'yes':   
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'

            with open(file_path, 'rb') as file:
                globals()[f"{model}_{stage}"] = pickle.load(file)
    
            print(f'Loaded {model}_{stage}-{current_time}.pkl')

            real_test = 1
            decide_test(params=globals()[f"{model}_{stage}"], stage=stage, real_test=real_test, visualize_errors=visualize_errors)
                
finally:
    sys.stdout = tee.console
    tee.close()
    
print(f'Finished, file {file_name} created')
# Out:
# Loaded trainable_model_stage_1-2024_11_19_13_21_53.pkl
# STAGE 1: Out of 8000, 3580 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 909 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 2567 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 661 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 682 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 166 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 250 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 60 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2572 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 658 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 276 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 74 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3041 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 760 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2028 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 512 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2033 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 509 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9059911200 reaction time with carry over.
# STAGE 1: 7791542700 reaction time with carry over decimal.
# STAGE 1: 8870153100 reaction time for train.
# STAGE 1: 2210293400 reaction time for test.
# STAGE 1: 7258808700 reaction time for train with carry over .
# STAGE 1: 6231407800 reaction time for train with carry over decimal.
# STAGE 1: 1691565300 reaction time for train small.
# STAGE 1: 402361400 reaction time for test small.
# STAGE 1: 1004375900 reaction time for train with carry over and small.
# STAGE 1: 226831400 reaction time for test with carry over and small.
# STAGE 1: 757409100 reaction time for train with carry over decimal and small.
# STAGE 1: 183887800 reaction time for test with carry over decimal and small.
# STAGE 1: 7684336100 reaction time for train small binary.
# STAGE 1: 1885117500 reaction time for test small binary.
# STAGE 1: 6072991700 reaction time for train with carry over and small binary.
# STAGE 1: 1475926600 reaction time for test with carry over and small binary.
# STAGE 1: 5045590800 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1234959000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_13_21_53.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10990607500 reaction time with carry over.
# STAGE 2: 9386005700 reaction time with carry over decimal.
# STAGE 2: 10747800500 reaction time for train.
# STAGE 2: 2700470400 reaction time for test.
# STAGE 2: 8787262100 reaction time for train with carry over .
# STAGE 2: 7496662900 reaction time for train with carry over decimal.
# STAGE 2: 2050902400 reaction time for train small.
# STAGE 2: 481424100 reaction time for test small.
# STAGE 2: 1217502500 reaction time for train with carry over and small.
# STAGE 2: 271783300 reaction time for test with carry over and small.
# STAGE 2: 912197100 reaction time for train with carry over decimal and small.
# STAGE 2: 224043000 reaction time for test with carry over decimal and small.
# STAGE 2: 9375658500 reaction time for train small binary.
# STAGE 2: 2316105000 reaction time for test small binary.
# STAGE 2: 7415120100 reaction time for train with carry over and small binary.
# STAGE 2: 1818980000 reaction time for test with carry over and small binary.
# STAGE 2: 6124520900 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1504977400 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_18_48_37.pkl
# STAGE 1: Out of 8000, 4700 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1197 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 3977 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1021 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 972 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 225 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 600 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 138 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 3205 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 822 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 411 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 105 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 4126 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1027 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 3403 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 851 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2631 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 652 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9683312900 reaction time with carry over.
# STAGE 1: 8307774400 reaction time with carry over decimal.
# STAGE 1: 9529020000 reaction time for train.
# STAGE 1: 2369990500 reaction time for test.
# STAGE 1: 7753318100 reaction time for train with carry over .
# STAGE 1: 6644782500 reaction time for train with carry over decimal.
# STAGE 1: 1784584000 reaction time for train small.
# STAGE 1: 417261700 reaction time for test small.
# STAGE 1: 1038810900 reaction time for train with carry over and small.
# STAGE 1: 237181700 reaction time for test with carry over and small.
# STAGE 1: 798581800 reaction time for train with carry over decimal and small.
# STAGE 1: 193064000 reaction time for test with carry over decimal and small.
# STAGE 1: 8308583600 reaction time for train small binary.
# STAGE 1: 2034983400 reaction time for test small binary.
# STAGE 1: 6532881700 reaction time for train with carry over and small binary.
# STAGE 1: 1594987700 reaction time for test with carry over and small binary.
# STAGE 1: 5424346100 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1327984800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_18_48_37.pkl
# STAGE 2: Out of 8000, 4959 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1221 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4265 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1051 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 571 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 134 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 388 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 96 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3584 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 873 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 272 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 64 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4474 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1102 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3780 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 932 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3099 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 754 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11414649600 reaction time with carry over.
# STAGE 2: 9890173500 reaction time with carry over decimal.
# STAGE 2: 11192429200 reaction time for train.
# STAGE 2: 2794676400 reaction time for test.
# STAGE 2: 9130135000 reaction time for train with carry over .
# STAGE 2: 7910138800 reaction time for train with carry over decimal.
# STAGE 2: 2112411500 reaction time for train small.
# STAGE 2: 510762100 reaction time for test small.
# STAGE 2: 1234932600 reaction time for train with carry over and small.
# STAGE 2: 300882800 reaction time for test with carry over and small.
# STAGE 2: 948758500 reaction time for train with carry over decimal and small.
# STAGE 2: 231329200 reaction time for test with carry over decimal and small.
# STAGE 2: 9692757300 reaction time for train small binary.
# STAGE 2: 2368863500 reaction time for test small binary.
# STAGE 2: 7630463100 reaction time for train with carry over and small binary.
# STAGE 2: 1858701700 reaction time for test with carry over and small binary.
# STAGE 2: 6410466900 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1554221800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_02_27_59.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9439904400 reaction time with carry over.
# STAGE 1: 8065541100 reaction time with carry over decimal.
# STAGE 1: 9247139300 reaction time for train.
# STAGE 1: 2305261200 reaction time for test.
# STAGE 1: 7552263200 reaction time for train with carry over .
# STAGE 1: 6455320800 reaction time for train with carry over decimal.
# STAGE 1: 1752484900 reaction time for train small.
# STAGE 1: 415452500 reaction time for test small.
# STAGE 1: 1032352400 reaction time for train with carry over and small.
# STAGE 1: 236817000 reaction time for test with carry over and small.
# STAGE 1: 774000500 reaction time for train with carry over decimal and small.
# STAGE 1: 188250300 reaction time for test with carry over decimal and small.
# STAGE 1: 8063998800 reaction time for train small binary.
# STAGE 1: 1971847100 reaction time for test small binary.
# STAGE 1: 6369122700 reaction time for train with carry over and small binary.
# STAGE 1: 1554227100 reaction time for test with carry over and small binary.
# STAGE 1: 5272180300 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1276806200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_02_27_59.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11533916300 reaction time with carry over.
# STAGE 2: 9869519200 reaction time with carry over decimal.
# STAGE 2: 11298272700 reaction time for train.
# STAGE 2: 2826483300 reaction time for test.
# STAGE 2: 9234696700 reaction time for train with carry over .
# STAGE 2: 7880623700 reaction time for train with carry over decimal.
# STAGE 2: 2146305900 reaction time for train small.
# STAGE 2: 509498600 reaction time for test small.
# STAGE 2: 1258589900 reaction time for train with carry over and small.
# STAGE 2: 287051800 reaction time for test with carry over and small.
# STAGE 2: 974998200 reaction time for train with carry over decimal and small.
# STAGE 2: 238244700 reaction time for test with carry over decimal and small.
# STAGE 2: 9904503000 reaction time for train small binary.
# STAGE 2: 2441634000 reaction time for test small binary.
# STAGE 2: 7840927000 reaction time for train with carry over and small binary.
# STAGE 2: 1914370300 reaction time for test with carry over and small binary.
# STAGE 2: 6486854000 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1604046200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_06_49_46.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9273743300 reaction time with carry over.
# STAGE 1: 7949536400 reaction time with carry over decimal.
# STAGE 1: 9053121300 reaction time for train.
# STAGE 1: 2287081400 reaction time for test.
# STAGE 1: 7406153700 reaction time for train with carry over .
# STAGE 1: 6341700700 reaction time for train with carry over decimal.
# STAGE 1: 1764123500 reaction time for train small.
# STAGE 1: 419717800 reaction time for test small.
# STAGE 1: 1049843200 reaction time for train with carry over and small.
# STAGE 1: 238315200 reaction time for test with carry over and small.
# STAGE 1: 797931100 reaction time for train with carry over decimal and small.
# STAGE 1: 194162000 reaction time for test with carry over decimal and small.
# STAGE 1: 7894894900 reaction time for train small binary.
# STAGE 1: 1957774600 reaction time for test small binary.
# STAGE 1: 6247927300 reaction time for train with carry over and small binary.
# STAGE 1: 1538282800 reaction time for test with carry over and small binary.
# STAGE 1: 5183474300 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1278528900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_06_49_46.pkl
# STAGE 2: Out of 8000, 3 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 2 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 3 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 1 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 1 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 1 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 2 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 1 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 1 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11680315300 reaction time with carry over.
# STAGE 2: 9912864000 reaction time with carry over decimal.
# STAGE 2: 11479316900 reaction time for train.
# STAGE 2: 2846141800 reaction time for test.
# STAGE 2: 9354902300 reaction time for train with carry over .
# STAGE 2: 7939336500 reaction time for train with carry over decimal.
# STAGE 2: 2231983400 reaction time for train small.
# STAGE 2: 523634600 reaction time for test small.
# STAGE 2: 1308190400 reaction time for train with carry over and small.
# STAGE 2: 295052500 reaction time for test with carry over and small.
# STAGE 2: 989912500 reaction time for train with carry over decimal and small.
# STAGE 2: 233995800 reaction time for test with carry over decimal and small.
# STAGE 2: 10049090000 reaction time for train small binary.
# STAGE 2: 2441915900 reaction time for test small binary.
# STAGE 2: 7924675400 reaction time for train with carry over and small binary.
# STAGE 2: 1921187100 reaction time for test with carry over and small binary.
# STAGE 2: 6509109600 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1569301600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_02_35.pkl
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 4506 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1149 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1152 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 273 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 520 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 116 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 3999 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1026 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 454 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 116 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 5225 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1303 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 3749 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 934 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 3242 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 811 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9573076200 reaction time with carry over.
# STAGE 1: 8232608100 reaction time with carry over decimal.
# STAGE 1: 9386692100 reaction time for train.
# STAGE 1: 2330328700 reaction time for test.
# STAGE 1: 7671637100 reaction time for train with carry over .
# STAGE 1: 6593617300 reaction time for train with carry over decimal.
# STAGE 1: 1761231500 reaction time for train small.
# STAGE 1: 411902000 reaction time for test small.
# STAGE 1: 1023222000 reaction time for train with carry over and small.
# STAGE 1: 228553000 reaction time for test with carry over and small.
# STAGE 1: 790519500 reaction time for train with carry over decimal and small.
# STAGE 1: 186311400 reaction time for test with carry over decimal and small.
# STAGE 1: 8103534800 reaction time for train small binary.
# STAGE 1: 1974786500 reaction time for test small binary.
# STAGE 1: 6388479800 reaction time for train with carry over and small binary.
# STAGE 1: 1545896900 reaction time for test with carry over and small binary.
# STAGE 1: 5310460000 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1283448600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_02_35.pkl
# STAGE 2: Out of 8000, 3 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11339972500 reaction time with carry over.
# STAGE 2: 9723858700 reaction time with carry over decimal.
# STAGE 2: 11074961700 reaction time for train.
# STAGE 2: 2794087500 reaction time for test.
# STAGE 2: 9048914200 reaction time for train with carry over .
# STAGE 2: 7763064400 reaction time for train with carry over decimal.
# STAGE 2: 2115410500 reaction time for train small.
# STAGE 2: 518355700 reaction time for test small.
# STAGE 2: 1243182700 reaction time for train with carry over and small.
# STAGE 2: 300001600 reaction time for test with carry over and small.
# STAGE 2: 954209300 reaction time for train with carry over decimal and small.
# STAGE 2: 239824100 reaction time for test with carry over decimal and small.
# STAGE 2: 9631014000 reaction time for train small binary.
# STAGE 2: 2389269900 reaction time for test small binary.
# STAGE 2: 7604966500 reaction time for train with carry over and small binary.
# STAGE 2: 1886240700 reaction time for test with carry over and small binary.
# STAGE 2: 6319116700 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1555976700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_24_06.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9211805500 reaction time with carry over.
# STAGE 1: 7844861900 reaction time with carry over decimal.
# STAGE 1: 9065041100 reaction time for train.
# STAGE 1: 2258263500 reaction time for test.
# STAGE 1: 7374211000 reaction time for train with carry over .
# STAGE 1: 6282296100 reaction time for train with carry over decimal.
# STAGE 1: 1792537100 reaction time for train small.
# STAGE 1: 424071400 reaction time for test small.
# STAGE 1: 1049769800 reaction time for train with carry over and small.
# STAGE 1: 243292800 reaction time for test with carry over and small.
# STAGE 1: 788719300 reaction time for train with carry over decimal and small.
# STAGE 1: 189089800 reaction time for test with carry over decimal and small.
# STAGE 1: 7898789100 reaction time for train small binary.
# STAGE 1: 1938940600 reaction time for test small binary.
# STAGE 1: 6207959000 reaction time for train with carry over and small binary.
# STAGE 1: 1518271600 reaction time for test with carry over and small binary.
# STAGE 1: 5116044100 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1243242900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_24_06.pkl
# STAGE 2: Out of 8000, 4 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 4 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 1 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 1 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 1 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11098646400 reaction time with carry over.
# STAGE 2: 9528903800 reaction time with carry over decimal.
# STAGE 2: 10882726500 reaction time for train.
# STAGE 2: 2714446600 reaction time for test.
# STAGE 2: 8883010500 reaction time for train with carry over .
# STAGE 2: 7628711500 reaction time for train with carry over decimal.
# STAGE 2: 2093215700 reaction time for train small.
# STAGE 2: 501023400 reaction time for test small.
# STAGE 2: 1230331200 reaction time for train with carry over and small.
# STAGE 2: 287235100 reaction time for test with carry over and small.
# STAGE 2: 939977800 reaction time for train with carry over decimal and small.
# STAGE 2: 231120400 reaction time for test with carry over decimal and small.
# STAGE 2: 9497425300 reaction time for train small binary.
# STAGE 2: 2324199600 reaction time for test small binary.
# STAGE 2: 7497709300 reaction time for train with carry over and small binary.
# STAGE 2: 1825388900 reaction time for test with carry over and small binary.
# STAGE 2: 6243410300 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1509945300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_24_08.pkl
# STAGE 1: Out of 8000, 3396 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 878 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 2390 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 633 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 742 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 182 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 292 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 68 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2409 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 628 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 259 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 68 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 2884 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 726 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 1878 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 481 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 1897 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 476 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9413651600 reaction time with carry over.
# STAGE 1: 8023068200 reaction time with carry over decimal.
# STAGE 1: 9324992200 reaction time for train.
# STAGE 1: 2310869800 reaction time for test.
# STAGE 1: 7540162600 reaction time for train with carry over .
# STAGE 1: 6419682600 reaction time for train with carry over decimal.
# STAGE 1: 1878980900 reaction time for train small.
# STAGE 1: 438724200 reaction time for test small.
# STAGE 1: 1080491000 reaction time for train with carry over and small.
# STAGE 1: 249243200 reaction time for test with carry over and small.
# STAGE 1: 810565700 reaction time for train with carry over decimal and small.
# STAGE 1: 202404400 reaction time for test with carry over decimal and small.
# STAGE 1: 8190293200 reaction time for train small binary.
# STAGE 1: 1998049400 reaction time for test small binary.
# STAGE 1: 6405463600 reaction time for train with carry over and small binary.
# STAGE 1: 1560668600 reaction time for test with carry over and small binary.
# STAGE 1: 5284983600 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1290565200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_24_08.pkl
# STAGE 2: Out of 8000, 3168 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 765 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 2772 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 679 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 309 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 76 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 245 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 60 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 2269 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 544 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 171 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 43 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 2959 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 706 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 2563 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 620 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2060 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 485 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11080150100 reaction time with carry over.
# STAGE 2: 9505963800 reaction time with carry over decimal.
# STAGE 2: 10883880300 reaction time for train.
# STAGE 2: 2721216700 reaction time for test.
# STAGE 2: 8861664100 reaction time for train with carry over .
# STAGE 2: 7593360300 reaction time for train with carry over decimal.
# STAGE 2: 2121657200 reaction time for train small.
# STAGE 2: 502909700 reaction time for test small.
# STAGE 2: 1242279200 reaction time for train with carry over and small.
# STAGE 2: 287558000 reaction time for test with carry over and small.
# STAGE 2: 935548000 reaction time for train with carry over decimal and small.
# STAGE 2: 239351200 reaction time for test with carry over decimal and small.
# STAGE 2: 9506761100 reaction time for train small binary.
# STAGE 2: 2337885400 reaction time for test small binary.
# STAGE 2: 7484544900 reaction time for train with carry over and small binary.
# STAGE 2: 1835154700 reaction time for test with carry over and small binary.
# STAGE 2: 6216241100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1529272200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_24_10.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9357796100 reaction time with carry over.
# STAGE 1: 7938597100 reaction time with carry over decimal.
# STAGE 1: 9183622300 reaction time for train.
# STAGE 1: 2293295300 reaction time for test.
# ...
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11267069000 reaction time with carry over.
# STAGE 2: 9634919300 reaction time with carry over decimal.
# STAGE 2: 11072098000 reaction time for train.
# STAGE 2: 2753216900 reaction time for test.
# STAGE 2: 9019406200 reaction time for train with carry over .
# STAGE 2: 7711600200 reaction time for train with carry over decimal.
# STAGE 2: 2123570400 reaction time for train small.
# STAGE 2: 499712500 reaction time for test small.
# STAGE 2: 1240220600 reaction time for train with carry over and small.
# STAGE 2: 283815900 reaction time for test with carry over and small.
# STAGE 2: 941253400 reaction time for train with carry over decimal and small.
# STAGE 2: 225423900 reaction time for test with carry over decimal and small.
# STAGE 2: 9676011100 reaction time for train small binary.
# STAGE 2: 2366148100 reaction time for test small binary.
# STAGE 2: 7623319300 reaction time for train with carry over and small binary.
# STAGE 2: 1860594000 reaction time for test with carry over and small binary.
# STAGE 2: 6315513300 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1536250300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_28_48.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9275730200 reaction time with carry over.
# STAGE 1: 7979289700 reaction time with carry over decimal.
# STAGE 1: 9066572500 reaction time for train.
# STAGE 1: 2255538600 reaction time for test.
# STAGE 1: 7425287800 reaction time for train with carry over .
# STAGE 1: 6389538900 reaction time for train with carry over decimal.
# STAGE 1: 1711936500 reaction time for train small.
# STAGE 1: 404023400 reaction time for test small.
# STAGE 1: 1004704200 reaction time for train with carry over and small.
# STAGE 1: 230608200 reaction time for test with carry over and small.
# STAGE 1: 779490400 reaction time for train with carry over decimal and small.
# STAGE 1: 188133900 reaction time for test with carry over decimal and small.
# STAGE 1: 7897416700 reaction time for train small binary.
# STAGE 1: 1929375700 reaction time for test small binary.
# STAGE 1: 6256132000 reaction time for train with carry over and small binary.
# STAGE 1: 1524279500 reaction time for test with carry over and small binary.
# STAGE 1: 5220383100 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1263587900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_28_48.pkl
# STAGE 2: Out of 8000, 6098 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 1505 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 5156 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1273 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 876 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 194 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 629 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 132 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 4354 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1071 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 440 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 100 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 5256 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1284 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4314 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 1052 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3512 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 850 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11009728900 reaction time with carry over.
# STAGE 2: 9347649600 reaction time with carry over decimal.
# STAGE 2: 10797744600 reaction time for train.
# STAGE 2: 2708989700 reaction time for test.
# STAGE 2: 8801250800 reaction time for train with carry over .
# STAGE 2: 7473529700 reaction time for train with carry over decimal.
# STAGE 2: 2108338700 reaction time for train small.
# STAGE 2: 507858200 reaction time for test small.
# STAGE 2: 1241652300 reaction time for train with carry over and small.
# STAGE 2: 289930200 reaction time for test with carry over and small.
# STAGE 2: 945560300 reaction time for train with carry over decimal and small.
# STAGE 2: 231985900 reaction time for test with carry over decimal and small.
# STAGE 2: 9436797100 reaction time for train small binary.
# STAGE 2: 2335439800 reaction time for test small binary.
# STAGE 2: 7440303300 reaction time for train with carry over and small binary.
# STAGE 2: 1834928200 reaction time for test with carry over and small binary.
# STAGE 2: 6112582200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1500570000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_28_50.pkl
# STAGE 1: Out of 8000, 2072 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 522 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 1566 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 393 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 576 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 137 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 234 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 53 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 1374 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 358 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 230 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 65 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 1637 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 396 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 1131 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 267 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 939 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 232 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 8813304700 reaction time with carry over.
# STAGE 1: 7521029800 reaction time with carry over decimal.
# STAGE 1: 8647691100 reaction time for train.
# STAGE 1: 2160474100 reaction time for test.
# STAGE 1: 7045599500 reaction time for train with carry over .
# STAGE 1: 6010849900 reaction time for train with carry over decimal.
# STAGE 1: 1661549500 reaction time for train small.
# STAGE 1: 391642300 reaction time for test small.
# STAGE 1: 974206600 reaction time for train with carry over and small.
# STAGE 1: 223432100 reaction time for test with carry over and small.
# STAGE 1: 734702000 reaction time for train with carry over decimal and small.
# STAGE 1: 182615200 reaction time for test with carry over decimal and small.
# STAGE 1: 7545976900 reaction time for train small binary.
# STAGE 1: 1855266100 reaction time for test small binary.
# STAGE 1: 5943885300 reaction time for train with carry over and small binary.
# STAGE 1: 1462497200 reaction time for test with carry over and small binary.
# STAGE 1: 4909135700 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1204971900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_28_50.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 10796052200 reaction time with carry over.
# STAGE 2: 9269045000 reaction time with carry over decimal.
# STAGE 2: 10580665500 reaction time for train.
# STAGE 2: 2637661800 reaction time for test.
# STAGE 2: 8643052200 reaction time for train with carry over .
# STAGE 2: 7409453300 reaction time for train with carry over decimal.
# STAGE 2: 2038135500 reaction time for train small.
# STAGE 2: 477721100 reaction time for test small.
# STAGE 2: 1201656600 reaction time for train with carry over and small.
# STAGE 2: 274028300 reaction time for test with carry over and small.
# STAGE 2: 918614600 reaction time for train with carry over decimal and small.
# STAGE 2: 224011100 reaction time for test with carry over decimal and small.
# STAGE 2: 9189523300 reaction time for train small binary.
# STAGE 2: 2247921800 reaction time for test small binary.
# STAGE 2: 7251910000 reaction time for train with carry over and small binary.
# STAGE 2: 1763260000 reaction time for test with carry over and small binary.
# STAGE 2: 6018311100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1469851700 reaction time for test with carry over decimal and small binary.
# Finished, file AP_0.1_0.1 created
