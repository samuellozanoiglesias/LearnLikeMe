# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_dataset_with_carry_over = eval(file.read())

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_small_problem_size_binary.txt", 'r') as file:
    combinations_small_problem_size_binary = eval(file.read())
    
with open(f"{folder}/combinations_with_carry_over_decimal.txt", 'r') as file:
    combinations_with_carry_over_decimal = eval(file.read())
    

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_carry_over_decimal = [pair for pair in train_couples if pair in combinations_with_carry_over_decimal]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    #column_1, column_2 = zip(*real_test_dataset)
    column_1, column_2 = zip(*test_dataset)
    
    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None

# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_count, correct_predictions_test_count, train_count, correct_predictions_train_count, test_carry_over_count, correct_carry_over_predictions_test_count, train_carry_over_count, correct_carry_over_predictions_train_count, small_train_count, correct_predictions_small_train_count, small_test_count, correct_predictions_small_test_count, small_train_carry_count, correct_predictions_small_train_carry_count, small_test_carry_count, correct_predictions_small_test_carry_count, test_carry_over_decimal_count, correct_carry_over_decimal_predictions_test_count, train_carry_over_decimal_count, correct_carry_over_decimal_predictions_train_count, small_train_carry_decimal_count, correct_predictions_small_train_carry_decimal_count, small_test_carry_decimal_count, correct_predictions_small_test_carry_decimal_count, small_binary_train_count, correct_predictions_small_binary_train_count, small_binary_test_count, correct_predictions_small_binary_test_count, small_binary_train_carry_count, correct_predictions_small_binary_train_carry_count, small_binary_test_carry_count, correct_predictions_small_binary_test_carry_count, small_binary_train_carry_decimal_count, correct_predictions_small_binary_train_carry_decimal_count, small_binary_test_carry_decimal_count, correct_predictions_small_binary_test_carry_decimal_count, reaction_time_carry, reaction_time_carry_decimal, reaction_time_train,reaction_time_test, reaction_time_train_carry, reaction_time_train_carry_decimal, reaction_time_small_train, reaction_time_small_test, reaction_time_small_train_carry, reaction_time_small_test_carry, reaction_time_small_train_carry_decimal, reaction_time_small_test_carry_decimal, reaction_time_small_binary_train, reaction_time_small_binary_test, reaction_time_small_binary_train_carry, reaction_time_small_binary_test_carry, reaction_time_small_binary_train_carry_decimal, reaction_time_small_binary_test_carry_decimal = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_count}, {correct_predictions_train_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_count}, {correct_predictions_test_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_count}, {correct_carry_over_predictions_train_count} trained with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_count}, {correct_carry_over_predictions_test_count} tested with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_count}, {correct_predictions_small_train_count} trained with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_test_count}, {correct_predictions_small_test_count} tested with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_count}, {correct_predictions_small_train_carry_count} trained with small problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_count}, {correct_predictions_small_test_carry_count} tested with small problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_train_count} trained with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_test_count} tested with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_decimal_count}, {correct_predictions_small_train_carry_decimal_count} trained with small problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_decimal_count}, {correct_predictions_small_test_carry_decimal_count} tested with small problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_count}, {correct_predictions_small_binary_train_count} trained with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_test_count}, {correct_predictions_small_binary_test_count} tested with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_count}, {correct_predictions_small_binary_train_carry_count} trained with small binary problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_count}, {correct_predictions_small_binary_test_carry_count} tested with small binary problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_decimal_count}, {correct_predictions_small_binary_train_carry_decimal_count} trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_decimal_count}, {correct_predictions_small_binary_test_carry_decimal_count} tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: {reaction_time_carry} reaction time with carry over.")
        print(f"STAGE {stage}: {reaction_time_carry_decimal} reaction time with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_train} reaction time for train.")
        print(f"STAGE {stage}: {reaction_time_test} reaction time for test.")
        print(f"STAGE {stage}: {reaction_time_train_carry} reaction time for train with carry over .")
        print(f"STAGE {stage}: {reaction_time_train_carry_decimal} reaction time for train with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_small_train} reaction time for train small.")
        print(f"STAGE {stage}: {reaction_time_small_test} reaction time for test small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry} reaction time for train with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry} reaction time for test with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry_decimal} reaction time for train with carry over decimal and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry_decimal} reaction time for test with carry over decimal and small.") 
        print(f"STAGE {stage}: {reaction_time_small_binary_train} reaction time for train small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test} reaction time for test small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry} reaction time for train with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry} reaction time for test with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry_decimal} reaction time for train with carry over decimal and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry_decimal} reaction time for test with carry over decimal and small binary.") 
            
    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

def real_test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_real_test_dataset()    
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_test_count = 0
    correct_predictions_train_count = 0
    correct_carry_over_predictions_count = 0
    correct_carry_over_predictions_test_count = 0
    correct_carry_over_predictions_train_count = 0
    correct_predictions_small_train_count = 0
    correct_predictions_small_test_count = 0
    correct_predictions_small_train_carry_count = 0
    correct_predictions_small_test_carry_count = 0
    correct_carry_over_decimal_predictions_count = 0
    correct_carry_over_decimal_predictions_test_count = 0
    correct_carry_over_decimal_predictions_train_count = 0
    correct_predictions_small_train_carry_decimal_count = 0
    correct_predictions_small_test_carry_decimal_count = 0
    correct_predictions_small_binary_train_count = 0
    correct_predictions_small_binary_test_count = 0
    correct_predictions_small_binary_train_carry_count = 0
    correct_predictions_small_binary_test_carry_count = 0
    correct_predictions_small_binary_train_carry_decimal_count = 0
    correct_predictions_small_binary_test_carry_decimal_count = 0
    
    set_size = inputs_1.shape[0]
    train_count = len(train_couples)
    test_count = set_size - train_count
    carry_over_count = len(combinations_with_carry_over) 
    carry_over_decimal_count = len(combinations_with_carry_over_decimal) 
    train_carry_over_count = len(train_with_carry_over)
    test_carry_over_count = carry_over_count - train_carry_over_count
    small_count = len(combinations_small_problem_size)
    small_binary_count = len(combinations_small_problem_size_binary)
    train_carry_over_decimal_count = len(train_with_carry_over_decimal)
    test_carry_over_decimal_count = carry_over_decimal_count - train_carry_over_decimal_count

    # Contadores adicionales
    small_train_count = 0
    small_test_count = 0
    small_train_carry_count = 0
    small_test_carry_count = 0
    small_train_carry_decimal_count = 0
    small_test_carry_decimal_count = 0
    small_binary_train_count = 0
    small_binary_test_count = 0
    small_binary_train_carry_count = 0
    small_binary_test_carry_count = 0
    small_binary_train_carry_decimal_count = 0
    small_binary_test_carry_decimal_count = 0
    
    reaction_time_carry = 0
    reaction_time_carry_decimal = 0
    reaction_time_train = 0
    reaction_time_test = 0
    reaction_time_train_carry = 0
    reaction_time_train_carry_decimal = 0
    reaction_time_small_train = 0
    reaction_time_small_test = 0
    reaction_time_small_train_carry = 0
    reaction_time_small_test_carry = 0
    reaction_time_small_train_carry_decimal = 0
    reaction_time_small_test_carry_decimal = 0
    reaction_time_small_binary_train = 0
    reaction_time_small_binary_test = 0
    reaction_time_small_binary_train_carry = 0
    reaction_time_small_binary_test_carry = 0
    reaction_time_small_binary_train_carry_decimal = 0
    reaction_time_small_binary_test_carry_decimal = 0

    for i in range(set_size):
        pair = (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1])

        start_time = time.perf_counter_ns()
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        elapsed_time = time.perf_counter_ns() - start_time

        is_small = pair in combinations_small_problem_size
        is_small_binary = pair in combinations_small_problem_size_binary
        is_train = pair in train_couples
        is_carry = pair in combinations_with_carry_over
        is_carry_decimal = pair in combinations_with_carry_over_decimal

        # Actualizar tiempos de reacción y contadores totales
        if is_small:
            if is_train:
                small_train_count += 1
                reaction_time_small_train += elapsed_time
                if is_carry:
                    small_train_carry_count += 1
                    reaction_time_small_train_carry += elapsed_time
                if is_carry_decimal:
                    small_train_carry_decimal_count += 1
                    reaction_time_small_train_carry_decimal += elapsed_time
            else:
                small_test_count += 1
                reaction_time_small_test += elapsed_time
                if is_carry:
                    small_test_carry_count += 1
                    reaction_time_small_test_carry += elapsed_time
                if is_carry_decimal:
                    small_test_carry_decimal_count += 1
                    reaction_time_small_test_carry_decimal += elapsed_time

        # Actualizar tiempos de reacción y contadores totales
        if is_small_binary:
            if is_train:
                small_binary_train_count += 1
                reaction_time_small_binary_train += elapsed_time
                if is_carry:
                    small_binary_train_carry_count += 1
                    reaction_time_small_binary_train_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_train_carry_decimal_count += 1
                    reaction_time_small_binary_train_carry_decimal += elapsed_time
            else:
                small_binary_test_count += 1
                reaction_time_small_binary_test += elapsed_time
                if is_carry:
                    small_binary_test_carry_count += 1
                    reaction_time_small_binary_test_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_test_carry_decimal_count += 1
                    reaction_time_small_binary_test_carry_decimal += elapsed_time

        if is_carry:
            reaction_time_carry += elapsed_time
        if is_carry_decimal:
            reaction_time_carry_decimal += elapsed_time
        if is_train:
            reaction_time_train += elapsed_time
        else:
            reaction_time_test += elapsed_time
        if is_train and is_carry:
            reaction_time_train_carry += elapsed_time
        if is_train and is_carry_decimal:
            reaction_time_train_carry_decimal += elapsed_time

        # Contar predicciones correctas
        if jnp.all(prediction == outputs[i]):
            if is_small:
                if is_train:
                    correct_predictions_small_train_count += 1
                    if is_carry:
                        correct_predictions_small_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_test_count += 1
                    if is_carry:
                        correct_predictions_small_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_test_carry_decimal_count += 1

            if is_small_binary:
                if is_train:
                    correct_predictions_small_binary_train_count += 1
                    if is_carry:
                        correct_predictions_small_binary_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_binary_test_count += 1
                    if is_carry:
                        correct_predictions_small_binary_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_test_carry_decimal_count += 1

            # Actualizar contadores previos
            if is_carry:
                correct_carry_over_predictions_count += 1 
            if is_carry_decimal:
                correct_carry_over_decimal_predictions_count += 1 
            if is_train:
                correct_predictions_train_count += 1 
            else:
                correct_predictions_test_count += 1
            if is_train and is_carry:
                correct_carry_over_predictions_train_count += 1   
            if is_train and is_carry_decimal:
                correct_carry_over_decimal_predictions_train_count += 1 
                
        elif visualize_errors == 1:
            print(f'{pair[0]} plus {pair[1]} has failed.')

    correct_carry_over_predictions_test_count = correct_carry_over_predictions_count - correct_carry_over_predictions_train_count
    correct_carry_over_decimal_predictions_test_count = correct_carry_over_decimal_predictions_count - correct_carry_over_decimal_predictions_train_count
    
    return (
        test_count,
        correct_predictions_test_count,
        train_count,
        correct_predictions_train_count,
        test_carry_over_count,
        correct_carry_over_predictions_test_count,
        train_carry_over_count,
        correct_carry_over_predictions_train_count,
        small_train_count,
        correct_predictions_small_train_count,
        small_test_count,
        correct_predictions_small_test_count,
        small_train_carry_count,
        correct_predictions_small_train_carry_count,
        small_test_carry_count,
        correct_predictions_small_test_carry_count,
        test_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_test_count,
        train_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_train_count,
        small_train_carry_decimal_count,
        correct_predictions_small_train_carry_decimal_count,
        small_test_carry_decimal_count,
        correct_predictions_small_test_carry_decimal_count,
        small_binary_train_count,
        correct_predictions_small_binary_train_count,
        small_binary_test_count,
        correct_predictions_small_binary_test_count,
        small_binary_train_carry_count,
        correct_predictions_small_binary_train_carry_count,
        small_binary_test_carry_count,
        correct_predictions_small_binary_test_carry_count,
        small_binary_train_carry_decimal_count,
        correct_predictions_small_binary_train_carry_decimal_count,
        small_binary_test_carry_decimal_count,
        correct_predictions_small_binary_test_carry_decimal_count,
        reaction_time_carry,
        reaction_time_carry_decimal,
        reaction_time_train,
        reaction_time_test,
        reaction_time_train_carry,
        reaction_time_train_carry_decimal,
        reaction_time_small_train,
        reaction_time_small_test,
        reaction_time_small_train_carry,
        reaction_time_small_test_carry,
        reaction_time_small_train_carry_decimal,
        reaction_time_small_test_carry_decimal,
        reaction_time_small_binary_train,
        reaction_time_small_binary_test,
        reaction_time_small_binary_train_carry,
        reaction_time_small_binary_test_carry,
        reaction_time_small_binary_train_carry_decimal,
        reaction_time_small_binary_test_carry_decimal
    )

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
validation_performance = 'no'
easy_examples = 'no'
type_training = 'Stages'
file_name = 'AP_0.1_0.1'

if easy_examples == 'yes':
    if validation_performance == 'yes':
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_3'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_3'
    
else:
    if validation_performance == 'yes':    
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_3'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_3'

os.makedirs(os.path.dirname(output_file), exist_ok=True)

tee = Tee(output_file, 'w') 
sys.stdout = tee

try:
    visualize_errors = 0
    model = 'trainable_model_stage'
    
    date_pattern = r'trainable_model_stage_3-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
    files = sorted(
        (f for f in os.listdir(folder_path) if f.endswith('.pkl') and not f.startswith('.')),  # Filtrar archivos .pkl y ocultos
        key=lambda x: re.search(date_pattern, x).group(0) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
    
        for stage in range(1, 4):
            if easy_examples == 'yes':
                if validation_performance == 'yes':    
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                    
            else:
                if validation_performance == 'yes':   
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'

            with open(file_path, 'rb') as file:
                globals()[f"{model}_{stage}"] = pickle.load(file)
    
            print(f'Loaded {model}_{stage}-{current_time}.pkl')

            real_test = 1
            decide_test(params=globals()[f"{model}_{stage}"], stage=stage, real_test=real_test, visualize_errors=visualize_errors)
                
finally:
    sys.stdout = tee.console
    tee.close()
    
print(f'Finished, file {file_name} created')
# Out:
# Loaded trainable_model_stage_1-2024_11_19_13_21_53.pkl
# STAGE 1: Out of 8000, 3878 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 984 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 2777 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 706 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 723 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 176 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 268 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 61 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2788 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 716 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 307 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 80 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3315 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 823 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2214 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 545 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2225 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 555 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 8855558600 reaction time with carry over.
# STAGE 1: 7570501400 reaction time with carry over decimal.
# STAGE 1: 8602161300 reaction time for train.
# STAGE 1: 2220348900 reaction time for test.
# STAGE 1: 7023705700 reaction time for train with carry over .
# STAGE 1: 5981143100 reaction time for train with carry over decimal.
# STAGE 1: 1702152100 reaction time for train small.
# STAGE 1: 393923300 reaction time for test small.
# STAGE 1: 1021629200 reaction time for train with carry over and small.
# STAGE 1: 224206700 reaction time for test with carry over and small.
# STAGE 1: 728431800 reaction time for train with carry over decimal and small.
# STAGE 1: 181119100 reaction time for test with carry over decimal and small.
# STAGE 1: 7480733000 reaction time for train small binary.
# STAGE 1: 1897261800 reaction time for test small binary.
# STAGE 1: 5902277400 reaction time for train with carry over and small binary.
# STAGE 1: 1508765800 reaction time for test with carry over and small binary.
# STAGE 1: 4859714800 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1266271200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_13_21_53.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11018408900 reaction time with carry over.
# STAGE 2: 9474313200 reaction time with carry over decimal.
# STAGE 2: 10819139700 reaction time for train.
# STAGE 2: 2698814600 reaction time for test.
# STAGE 2: 8815460900 reaction time for train with carry over .
# STAGE 2: 7576880900 reaction time for train with carry over decimal.
# STAGE 2: 2049505500 reaction time for train small.
# STAGE 2: 488910900 reaction time for test small.
# STAGE 2: 1214297500 reaction time for train with carry over and small.
# STAGE 2: 277277200 reaction time for test with carry over and small.
# STAGE 2: 904588600 reaction time for train with carry over decimal and small.
# STAGE 2: 224522500 reaction time for test with carry over decimal and small.
# STAGE 2: 9392060100 reaction time for train small binary.
# STAGE 2: 2306345100 reaction time for test small binary.
# STAGE 2: 7388381300 reaction time for train with carry over and small binary.
# STAGE 2: 1810478500 reaction time for test with carry over and small binary.
# STAGE 2: 6149801300 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1504962800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_19_13_21_53.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 10966621600 reaction time with carry over.
# STAGE 3: 9338489100 reaction time with carry over decimal.
# STAGE 3: 10733697900 reaction time for train.
# STAGE 3: 2685785700 reaction time for test.
# STAGE 3: 8777730500 reaction time for train with carry over .
# STAGE 3: 7473515700 reaction time for train with carry over decimal.
# STAGE 3: 2022883700 reaction time for train small.
# STAGE 3: 483564800 reaction time for test small.
# STAGE 3: 1194214800 reaction time for train with carry over and small.
# STAGE 3: 275408600 reaction time for test with carry over and small.
# STAGE 3: 898262800 reaction time for train with carry over decimal and small.
# STAGE 3: 223867500 reaction time for test with carry over decimal and small.
# STAGE 3: 9368684000 reaction time for train small binary.
# STAGE 3: 2308350400 reaction time for test small binary.
# STAGE 3: 7412716600 reaction time for train with carry over and small binary.
# STAGE 3: 1811455800 reaction time for test with carry over and small binary.
# STAGE 3: 6108501800 reaction time for train with carry over decimal and small binary.
# STAGE 3: 1487538100 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_18_48_37.pkl
# STAGE 1: Out of 8000, 3782 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 954 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 3145 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 797 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 884 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 202 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 532 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 120 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2522 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 652 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 364 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 94 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3343 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 824 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2706 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 667 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 2083 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 522 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9681650200 reaction time with carry over.
# STAGE 1: 8270053000 reaction time with carry over decimal.
# STAGE 1: 9453916800 reaction time for train.
# STAGE 1: 2371728300 reaction time for test.
# STAGE 1: 7732301200 reaction time for train with carry over .
# STAGE 1: 6603166400 reaction time for train with carry over decimal.
# STAGE 1: 1719270600 reaction time for train small.
# STAGE 1: 403693300 reaction time for test small.
# STAGE 1: 1011310400 reaction time for train with carry over and small.
# STAGE 1: 232291000 reaction time for test with carry over and small.
# STAGE 1: 773203100 reaction time for train with carry over decimal and small.
# STAGE 1: 186283800 reaction time for test with carry over decimal and small.
# STAGE 1: 8259168400 reaction time for train small binary.
# STAGE 1: 2043839100 reaction time for test small binary.
# STAGE 1: 6537552800 reaction time for train with carry over and small binary.
# STAGE 1: 1621459800 reaction time for test with carry over and small binary.
# STAGE 1: 5408418000 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1338997400 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_18_48_37.pkl
# STAGE 2: Out of 8000, 4028 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 987 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 3624 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 886 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 184 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 57 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 173 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 51 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3174 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 764 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 114 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 38 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3697 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 906 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3293 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 805 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2843 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 683 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11825428700 reaction time with carry over.
# STAGE 2: 10153645300 reaction time with carry over decimal.
# STAGE 2: 11555391600 reaction time for train.
# STAGE 2: 2877188400 reaction time for test.
# STAGE 2: 9470101900 reaction time for train with carry over .
# STAGE 2: 8122466300 reaction time for train with carry over decimal.
# STAGE 2: 2186820600 reaction time for train small.
# STAGE 2: 514233600 reaction time for test small.
# STAGE 2: 1296847900 reaction time for train with carry over and small.
# STAGE 2: 291772200 reaction time for test with carry over and small.
# STAGE 2: 969564500 reaction time for train with carry over decimal and small.
# STAGE 2: 233465700 reaction time for test with carry over decimal and small.
# STAGE 2: 9995924400 reaction time for train small binary.
# STAGE 2: 2455253700 reaction time for test small binary.
# STAGE 2: 7910634700 reaction time for train with carry over and small binary.
# STAGE 2: 1933392100 reaction time for test with carry over and small binary.
# STAGE 2: 6562999100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1609244300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_19_18_48_37.pkl
# STAGE 3: Out of 8000, 5162 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1268 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 4449 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 1110 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 484 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 116 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 362 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 84 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 3878 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 941 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 269 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 66 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 4492 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 1718, 1096 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 3779 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1349, 938 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 3208 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1117, 769 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11170655900 reaction time with carry over.
# STAGE 3: 9574676800 reaction time with carry over decimal.
# STAGE 3: 10966423000 reaction time for train.
# STAGE 3: 2721216100 reaction time for test.
# STAGE 3: 8947664400 reaction time for train with carry over .
# STAGE 3: 7668378500 reaction time for train with carry over decimal.
# STAGE 3: 2064945400 reaction time for train small.
# STAGE 3: 492121400 reaction time for test small.
# STAGE 3: 1209492400 reaction time for train with carry over and small.
# STAGE 3: 283998400 reaction time for test with carry over and small.
# STAGE 3: 921008100 reaction time for train with carry over decimal and small.
# STAGE 3: 227585200 reaction time for test with carry over decimal and small.
# STAGE 3: 9594317500 reaction time for train small binary.
# STAGE 3: 2338683300 reaction time for test small binary.
# STAGE 3: 7575558900 reaction time for train with carry over and small binary.
# STAGE 3: 1840458700 reaction time for test with carry over and small binary.
# STAGE 3: 6296273000 reaction time for train with carry over decimal and small binary.
# STAGE 3: 1523765500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_02_27_59.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9515433500 reaction time with carry over.
# STAGE 1: 8128548200 reaction time with carry over decimal.
# STAGE 1: 9326414300 reaction time for train.
# STAGE 1: 2328678200 reaction time for test.
# STAGE 1: 7614957900 reaction time for train with carry over .
# STAGE 1: 6513267000 reaction time for train with carry over decimal.
# STAGE 1: 1792968200 reaction time for train small.
# STAGE 1: 418071500 reaction time for test small.
# STAGE 1: 1054870800 reaction time for train with carry over and small.
# STAGE 1: 237275400 reaction time for test with carry over and small.
# STAGE 1: 785132600 reaction time for train with carry over decimal and small.
# STAGE 1: 191616000 reaction time for test with carry over decimal and small.
# STAGE 1: 8093539800 reaction time for train small binary.
# STAGE 1: 1990080300 reaction time for test small binary.
# STAGE 1: 6382083400 reaction time for train with carry over and small binary.
# STAGE 1: 1561877700 reaction time for test with carry over and small binary.
# STAGE 1: 5280392500 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1276683300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_02_27_59.pkl
# STAGE 2: Out of 8000, 74 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 23 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 20 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 9 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 53 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 14 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 10 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 5 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 74 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 23 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 53 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 14 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11225231900 reaction time with carry over.
# STAGE 2: 9620439400 reaction time with carry over decimal.
# STAGE 2: 11024638000 reaction time for train.
# STAGE 2: 2746676600 reaction time for test.
# STAGE 2: 8977472800 reaction time for train with carry over .
# STAGE 2: 7694612600 reaction time for train with carry over decimal.
# STAGE 2: 2105878800 reaction time for train small.
# STAGE 2: 500946300 reaction time for test small.
# STAGE 2: 1230796600 reaction time for train with carry over and small.
# STAGE 2: 285481600 reaction time for test with carry over and small.
# STAGE 2: 934347700 reaction time for train with carry over decimal and small.
# STAGE 2: 232230300 reaction time for test with carry over decimal and small.
# STAGE 2: 9618368000 reaction time for train small binary.
# STAGE 2: 2358063700 reaction time for test small binary.
# STAGE 2: 7571202800 reaction time for train with carry over and small binary.
# STAGE 2: 1859146200 reaction time for test with carry over and small binary.
# STAGE 2: 6288342600 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1537213900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_02_27_59.pkl
# STAGE 3: Out of 8000, 8 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 7 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 3 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 2 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 8 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 3 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11396149400 reaction time with carry over.
# STAGE 3: 9759635900 reaction time with carry over decimal.
# STAGE 3: 11161489200 reaction time for train.
# STAGE 3: 2775251000 reaction time for test.
# STAGE 3: 9131216600 reaction time for train with carry over .
# STAGE 3: 7814915300 reaction time for train with carry over decimal.
# STAGE 3: 2104769700 reaction time for train small.
# STAGE 3: 504708100 reaction time for test small.
# STAGE 3: 1231485800 reaction time for train with carry over and small.
# STAGE 3: 283046000 reaction time for test with carry over and small.
# STAGE 3: 940841400 reaction time for train with carry over decimal and small.
# STAGE 3: 231669700 reaction time for test with carry over decimal and small.
# STAGE 3: 9755835400 reaction time for train small binary.
# STAGE 3: 2386642900 reaction time for test small binary.
# STAGE 3: 7725562800 reaction time for train with carry over and small binary.
# STAGE 3: 1876324700 reaction time for test with carry over and small binary.
# STAGE 3: 6409261500 reaction time for train with carry over decimal and small binary.
# STAGE 3: 1556112500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_06_49_46.pkl
# STAGE 1: Out of 8000, 3833 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 966 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 3166 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 808 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 970 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 231 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 562 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 136 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 2513 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 663 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 424 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 111 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 3315 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 811 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 2648 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 653 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 1995 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 508 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9129541200 reaction time with carry over.
# STAGE 1: 7841522000 reaction time with carry over decimal.
# STAGE 1: 8942168200 reaction time for train.
# STAGE 1: 2216383700 reaction time for test.
# STAGE 1: 7320098800 reaction time for train with carry over .
# STAGE 1: 6271991800 reaction time for train with carry over decimal.
# STAGE 1: 1682841400 reaction time for train small.
# STAGE 1: 391944000 reaction time for test small.
# STAGE 1: 991931600 reaction time for train with carry over and small.
# STAGE 1: 224348400 reaction time for test with carry over and small.
# STAGE 1: 758219600 reaction time for train with carry over decimal and small.
# STAGE 1: 183840400 reaction time for test with carry over decimal and small.
# STAGE 1: 7762746800 reaction time for train small binary.
# STAGE 1: 1888924500 reaction time for test small binary.
# STAGE 1: 6140677400 reaction time for train with carry over and small binary.
# STAGE 1: 1481983200 reaction time for test with carry over and small binary.
# STAGE 1: 5092570400 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1242071000 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_06_49_46.pkl
# STAGE 2: Out of 8000, 443 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 113 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 87 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 16 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 330 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 87 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 44 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 7 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 443 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 113 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 330 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 87 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11478373000 reaction time with carry over.
# STAGE 2: 9818165000 reaction time with carry over decimal.
# STAGE 2: 11276641300 reaction time for train.
# STAGE 2: 2837372100 reaction time for test.
# STAGE 2: 9178305500 reaction time for train with carry over .
# STAGE 2: 7837840800 reaction time for train with carry over decimal.
# STAGE 2: 2265536100 reaction time for train small.
# STAGE 2: 545731700 reaction time for test small.
# STAGE 2: 1344519000 reaction time for train with carry over and small.
# STAGE 2: 304797000 reaction time for test with carry over and small.
# STAGE 2: 1022449300 reaction time for train with carry over decimal and small.
# STAGE 2: 253191200 reaction time for test with carry over decimal and small.
# STAGE 2: 9879732400 reaction time for train small binary.
# STAGE 2: 2436734800 reaction time for test small binary.
# STAGE 2: 7781396600 reaction time for train with carry over and small binary.
# STAGE 2: 1899430200 reaction time for test with carry over and small binary.
# STAGE 2: 6440931900 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1579686900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_06_49_46.pkl
# STAGE 3: Out of 8000, 143 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 31 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 83 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 12 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 43 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 11 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 25 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 6 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 143 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 1718, 31 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 43 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1117, 11 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 11031972100 reaction time with carry over.
# STAGE 3: 9418005700 reaction time with carry over decimal.
# STAGE 3: 10784665000 reaction time for train.
# STAGE 3: 2705589200 reaction time for test.
# STAGE 3: 8814207400 reaction time for train with carry over .
# STAGE 3: 7522781900 reaction time for train with carry over decimal.
# STAGE 3: 2077645200 reaction time for train small.
# STAGE 3: 494808200 reaction time for test small.
# STAGE 3: 1233147500 reaction time for train with carry over and small.
# STAGE 3: 283176000 reaction time for test with carry over and small.
# STAGE 3: 943246200 reaction time for train with carry over decimal and small.
# STAGE 3: 231762900 reaction time for test with carry over decimal and small.
# STAGE 3: 9458958400 reaction time for train small binary.
# STAGE 3: 2332383700 reaction time for test small binary.
# STAGE 3: 7488500800 reaction time for train with carry over and small binary.
# STAGE 3: 1844559200 reaction time for test with carry over and small binary.
# STAGE 3: 6197075300 reaction time for train with carry over decimal and small binary.
# STAGE 3: 1522018300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_02_35.pkl
# STAGE 1: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 1518 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 4506 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 1149 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 1152 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 273 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 520 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 116 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 3999 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 1026 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 454 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 116 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 5225 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 1303 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 3749 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 934 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 3242 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 811 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 9001395800 reaction time with carry over.
# STAGE 1: 7687366000 reaction time with carry over decimal.
# STAGE 1: 8820818700 reaction time for train.
# STAGE 1: 2196787400 reaction time for test.
# STAGE 1: 7213599500 reaction time for train with carry over .
# STAGE 1: 6155807600 reaction time for train with carry over decimal.
# STAGE 1: 1654126100 reaction time for train small.
# STAGE 1: 399518000 reaction time for test small.
# STAGE 1: 971518500 reaction time for train with carry over and small.
# STAGE 1: 227030600 reaction time for test with carry over and small.
# STAGE 1: 730015500 reaction time for train with carry over decimal and small.
# STAGE 1: 181056400 reaction time for test with carry over decimal and small.
# STAGE 1: 7713786500 reaction time for train small binary.
# STAGE 1: 1890174200 reaction time for test small binary.
# STAGE 1: 6106567300 reaction time for train with carry over and small binary.
# STAGE 1: 1481183100 reaction time for test with carry over and small binary.
# STAGE 1: 5048775400 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1224945200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_02_35.pkl
# STAGE 2: Out of 8000, 1091 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 295 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 866 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 235 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 68 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 9 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 27 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 4 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 843 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 229 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 40 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 8 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 863 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 226 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 638 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 166 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 615 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 160 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 11623738800 reaction time with carry over.
# STAGE 2: 9970635100 reaction time with carry over decimal.
# STAGE 2: 11364115500 reaction time for train.
# STAGE 2: 2838381900 reaction time for test.
# STAGE 2: 9308691900 reaction time for train with carry over .
# STAGE 2: 7976634900 reaction time for train with carry over decimal.
# STAGE 2: 2144802200 reaction time for train small.
# STAGE 2: 511950200 reaction time for test small.
# STAGE 2: 1270623200 reaction time for train with carry over and small.
# STAGE 2: 289006300 reaction time for test with carry over and small.
# STAGE 2: 975792100 reaction time for train with carry over decimal and small.
# STAGE 2: 241521200 reaction time for test with carry over decimal and small.
# STAGE 2: 9912902100 reaction time for train small binary.
# STAGE 2: 2448671500 reaction time for test small binary.
# STAGE 2: 7857478500 reaction time for train with carry over and small binary.
# STAGE 2: 1925336500 reaction time for test with carry over and small binary.
# STAGE 2: 6525421500 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1604289800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_11_02_35.pkl
# STAGE 3: Out of 8000, 1372 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 364 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 993 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 260 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 203 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 48 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 89 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 18 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 961 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 244 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 98 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 21 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 1197 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 1718, 303 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 818 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1349, 199 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 786 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1117, 183 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 10916189600 reaction time with carry over.
# STAGE 3: 9357125700 reaction time with carry over decimal.
# STAGE 3: 10699510400 reaction time for train.
# STAGE 3: 2671145400 reaction time for test.
# STAGE 3: 8731224200 reaction time for train with carry over .
# ...
# STAGE 2: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 13509234300 reaction time with carry over.
# STAGE 2: 11565442800 reaction time with carry over decimal.
# STAGE 2: 13236309000 reaction time for train.
# STAGE 2: 3335763000 reaction time for test.
# STAGE 2: 10777442800 reaction time for train with carry over .
# STAGE 2: 9221550100 reaction time for train with carry over decimal.
# STAGE 2: 2550921100 reaction time for train small.
# STAGE 2: 598803500 reaction time for test small.
# STAGE 2: 1497850200 reaction time for train with carry over and small.
# STAGE 2: 343086900 reaction time for test with carry over and small.
# STAGE 2: 1146085600 reaction time for train with carry over decimal and small.
# STAGE 2: 278211300 reaction time for test with carry over decimal and small.
# STAGE 2: 11539780800 reaction time for train small binary.
# STAGE 2: 2866901600 reaction time for test small binary.
# STAGE 2: 9080914600 reaction time for train with carry over and small binary.
# STAGE 2: 2262930100 reaction time for test with carry over and small binary.
# STAGE 2: 7525021900 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1875031300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_11_28_48.pkl
# STAGE 3: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 2000 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 1631 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1536 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 364 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 904 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 207 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 1399 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 687 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 168 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 1718, 1718 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1349, 1349 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1117, 1117 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 13365168500 reaction time with carry over.
# STAGE 3: 11464260300 reaction time with carry over decimal.
# STAGE 3: 13136405800 reaction time for train.
# STAGE 3: 3282980500 reaction time for test.
# STAGE 3: 10689334900 reaction time for train with carry over .
# STAGE 3: 9159472500 reaction time for train with carry over decimal.
# STAGE 3: 2515974700 reaction time for train small.
# STAGE 3: 593724500 reaction time for test small.
# STAGE 3: 1480953800 reaction time for train with carry over and small.
# STAGE 3: 339559200 reaction time for test with carry over and small.
# STAGE 3: 1117606700 reaction time for train with carry over decimal and small.
# STAGE 3: 274212900 reaction time for test with carry over decimal and small.
# STAGE 3: 11473791300 reaction time for train small binary.
# STAGE 3: 2822464800 reaction time for test small binary.
# STAGE 3: 9026720400 reaction time for train with carry over and small binary.
# STAGE 3: 2215317900 reaction time for test with carry over and small binary.
# STAGE 3: 7496858000 reaction time for train with carry over decimal and small binary.
# STAGE 3: 1844272100 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_28_50.pkl
# STAGE 1: Out of 8000, 2267 trained were predicted correctly in the current model.
# STAGE 1: Out of 2000, 589 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 1696 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 443 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1536, 652 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 364, 157 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 904, 275 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 207, 63 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 1490 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 406 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 687, 258 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 168, 71 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 1787 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 1718, 444 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 1216 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1349, 298 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 1010 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1117, 261 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 11021326700 reaction time with carry over.
# STAGE 1: 9470800500 reaction time with carry over decimal.
# STAGE 1: 10864622000 reaction time for train.
# STAGE 1: 2713404600 reaction time for test.
# STAGE 1: 8809603100 reaction time for train with carry over .
# STAGE 1: 7573638500 reaction time for train with carry over decimal.
# STAGE 1: 2110580600 reaction time for train small.
# STAGE 1: 497542400 reaction time for test small.
# STAGE 1: 1248085700 reaction time for train with carry over and small.
# STAGE 1: 279940200 reaction time for test with carry over and small.
# STAGE 1: 964288700 reaction time for train with carry over decimal and small.
# STAGE 1: 233547700 reaction time for test with carry over decimal and small.
# STAGE 1: 9499185400 reaction time for train small binary.
# STAGE 1: 2329714200 reaction time for test small binary.
# STAGE 1: 7444166500 reaction time for train with carry over and small binary.
# STAGE 1: 1828033200 reaction time for test with carry over and small binary.
# STAGE 1: 6208201900 reaction time for train with carry over decimal and small binary.
# STAGE 1: 1513471600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_28_50.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 13984366000 reaction time with carry over.
# STAGE 2: 11947755900 reaction time with carry over decimal.
# STAGE 2: 13751538300 reaction time for train.
# STAGE 2: 3430422900 reaction time for test.
# STAGE 2: 11199397200 reaction time for train with carry over .
# STAGE 2: 9540288100 reaction time for train with carry over decimal.
# STAGE 2: 2699052000 reaction time for train small.
# STAGE 2: 618185500 reaction time for test small.
# STAGE 2: 1604739900 reaction time for train with carry over and small.
# STAGE 2: 347391000 reaction time for test with carry over and small.
# STAGE 2: 1188752600 reaction time for train with carry over decimal and small.
# STAGE 2: 285443000 reaction time for test with carry over decimal and small.
# STAGE 2: 11992842300 reaction time for train small binary.
# STAGE 2: 2942645800 reaction time for test small binary.
# STAGE 2: 9440701200 reaction time for train with carry over and small binary.
# STAGE 2: 2297191700 reaction time for test with carry over and small binary.
# STAGE 2: 7781592100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 1919690700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_3-2024_11_20_11_28_50.pkl
# STAGE 3: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 0 tested were predicted correctly in the current model.
# STAGE 3: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1536, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 364, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 3: Out of 904, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 207, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 687, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 168, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 1718, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 3: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 1349, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 3: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: Out of 1117, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 3: 13648127400 reaction time with carry over.
# STAGE 3: 11611296400 reaction time with carry over decimal.
# STAGE 3: 13360215800 reaction time for train.
# STAGE 3: 3332524900 reaction time for test.
# STAGE 3: 10928273800 reaction time for train with carry over .
# STAGE 3: 9280856800 reaction time for train with carry over decimal.
# STAGE 3: 2546345400 reaction time for train small.
# STAGE 3: 623281800 reaction time for test small.
# STAGE 3: 1496201500 reaction time for train with carry over and small.
# STAGE 3: 358530800 reaction time for test with carry over and small.
# STAGE 3: 1117002500 reaction time for train with carry over decimal and small.
# STAGE 3: 281469000 reaction time for test with carry over decimal and small.
# STAGE 3: 11624096600 reaction time for train small binary.
# STAGE 3: 2858127200 reaction time for test small binary.
# STAGE 3: 9192154600 reaction time for train with carry over and small binary.
# STAGE 3: 2245455900 reaction time for test with carry over and small binary.
# STAGE 3: 7544737600 reaction time for train with carry over decimal and small binary.
# STAGE 3: 1856041900 reaction time for test with carry over decimal and small binary.
# Finished, file AP_0.1_0.1 created
