# %%
import os
import re
import pandas as pd

# %%
validation_performance = 'no'

analyzed_data_folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Analyzed_Data'

if validation_performance == 'yes':
    folder_path = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance'
else:
    folder_path = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests'


count_train = 8000
count_test = 8384
count_carry_over_train = 6524
count_carry_over_test = 7673
count_small_train = 1614
count_small_test = 946
count_small_train_carry = 963
count_small_test_carry = 568
count_carry_over_decimal_train = 5576
count_carry_over_decimal_test = 4384
count_small_train_carry_decimal = 724
count_small_test_carry_decimal = 412

count_small_binary_train = 6986
count_small_binary_test = 5302
count_small_binary_train_carry = 5510
count_small_binary_test_carry = 4591
count_small_binary_train_carry_decimal = 4562
count_small_binary_test_carry_decimal = 2559

total_count = count_train + count_test
total_count_carry_over = count_carry_over_train + count_carry_over_test
total_count_no_carry_over = total_count - total_count_carry_over
count_no_carry_over_train = count_train - count_carry_over_train
count_no_carry_over_test = count_test - count_carry_over_test
total_count_small = count_small_train + count_small_test
total_count_large = total_count - total_count_small
count_large_train = count_train - count_small_train
count_large_test = count_test - count_small_test
total_count_small_carry = count_small_train_carry + count_small_test_carry
total_count_small_no_carry = total_count_small - total_count_small_carry
count_small_train_no_carry = count_small_train - count_small_train_carry
count_small_test_no_carry = count_small_test - count_small_test_carry
total_count_large_carry = total_count_carry_over - total_count_small_carry
count_large_train_carry = count_carry_over_train - count_small_train_carry
count_large_test_carry = count_carry_over_test - count_small_test_carry
total_count_large_no_carry = total_count_large - total_count_large_carry
count_large_train_no_carry = count_large_train - count_large_train_carry
count_large_test_no_carry = count_large_test - count_large_test_carry

total_count_small_binary = count_small_binary_train + count_small_binary_test
total_count_large_binary = total_count - total_count_small_binary
count_large_binary_train = count_train - count_small_binary_train
count_large_binary_test = count_test - count_small_binary_test
total_count_small_binary_carry = count_small_binary_train_carry + count_small_binary_test_carry
total_count_small_binary_no_carry = total_count_small_binary - total_count_small_binary_carry
count_small_binary_train_no_carry = count_small_binary_train - count_small_binary_train_carry
count_small_binary_test_no_carry = count_small_binary_test - count_small_binary_test_carry
total_count_large_binary_carry = total_count_carry_over - total_count_small_binary_carry
count_large_binary_train_carry = count_carry_over_train - count_small_binary_train_carry
count_large_binary_test_carry = count_carry_over_test - count_small_binary_test_carry
total_count_large_binary_no_carry = total_count_large_binary - total_count_large_binary_carry

count_large_binary_train_no_carry = count_large_binary_train - count_large_binary_train_carry
count_large_binary_test_no_carry = count_large_binary_test - count_large_binary_test_carry

total_count_carry_over_decimal = count_carry_over_decimal_train + count_carry_over_decimal_test
total_count_no_carry_over_decimal = total_count - total_count_carry_over_decimal
count_no_carry_over_decimal_train = count_train - count_carry_over_decimal_train
count_no_carry_over_decimal_test = count_test - count_carry_over_decimal_test
total_count_small_carry_decimal = count_small_train_carry_decimal + count_small_test_carry_decimal
total_count_small_no_carry_decimal = total_count_small - total_count_small_carry_decimal
count_small_train_no_carry_decimal = count_small_train - count_small_train_carry_decimal
count_small_test_no_carry_decimal = count_small_test - count_small_test_carry_decimal
total_count_large_carry_decimal = total_count_carry_over_decimal - total_count_small_carry_decimal
count_large_train_carry_decimal = count_carry_over_decimal_train - count_small_train_carry_decimal
count_large_test_carry_decimal = count_carry_over_decimal_test - count_small_test_carry_decimal
total_count_large_no_carry_decimal = total_count_large - total_count_large_carry_decimal
count_large_train_no_carry_decimal = count_large_train - count_large_train_carry_decimal
count_large_test_no_carry_decimal = count_large_test - count_large_test_carry_decimal

total_count_small_binary_carry_decimal = count_small_binary_train_carry_decimal + count_small_binary_test_carry_decimal
total_count_small_binary_no_carry_decimal = total_count_small_binary - total_count_small_binary_carry_decimal
count_small_binary_train_no_carry_decimal = count_small_binary_train - count_small_binary_train_carry_decimal
count_small_binary_test_no_carry_decimal = count_small_binary_test - count_small_binary_test_carry_decimal
total_count_large_binary_carry_decimal = total_count_carry_over_decimal - total_count_small_binary_carry_decimal
count_large_binary_train_carry_decimal = count_carry_over_decimal_train - count_small_binary_train_carry_decimal
count_large_binary_test_carry_decimal = count_carry_over_decimal_test - count_small_binary_test_carry_decimal
total_count_large_binary_no_carry_decimal = total_count_large_binary - total_count_large_binary_carry_decimal
count_large_binary_train_no_carry_decimal = count_large_binary_train - count_large_binary_train_carry_decimal
count_large_binary_test_no_carry_decimal = count_large_binary_test - count_large_binary_test_carry_decimal


model_regex = r"Loaded trainable_model_stage_\d+-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl"
type_file_regex = r"tests-(\w+)-(AP_0\.1_0\.1|AP_0\.05_0\.05|Generated_model)"
correct_predictions_train_regex = r"STAGE (\d+): Out of 8000, (\d+) trained were predicted correctly in the current model."
correct_predictions_test_regex = r"STAGE (\d+): Out of 8384, (\d+) tested were predicted correctly in the current model."
correct_carry_over_predictions_train_regex = r"STAGE (\d+): Out of 6524, (\d+) trained with carry-over were predicted correctly in the current model."
correct_carry_over_predictions_test_regex = r"STAGE (\d+): Out of 7673, (\d+) tested with carry-over were predicted correctly in the current model."
correct_predictions_small_train_regex = r"STAGE (\d+): Out of 1614, (\d+) trained with small problem size were predicted correctly in the current model."
correct_predictions_small_test_regex = r"STAGE (\d+): Out of 946, (\d+) tested with small problem size were predicted correctly in the current model."
correct_predictions_small_train_carry_regex = r"STAGE (\d+): Out of 963, (\d+) trained with small problem size and with carry-over were predicted correctly in the current model."
correct_predictions_small_test_carry_regex = r"STAGE (\d+): Out of 568, (\d+) tested with small problem size and with carry-over were predicted correctly in the current model."
correct_carry_over_decimal_predictions_train_regex = r"STAGE (\d+): Out of 5576, (\d+) trained with carry-over decimal were predicted correctly in the current model."
correct_carry_over_decimal_predictions_test_regex = r"STAGE (\d+): Out of 4384, (\d+) tested with carry-over decimal were predicted correctly in the current model."
correct_predictions_small_train_carry_decimal_regex = r"STAGE (\d+): Out of 724, (\d+) trained with small problem size and with carry-over decimal were predicted correctly in the current model."
correct_predictions_small_test_carry_decimal_regex = r"STAGE (\d+): Out of 412, (\d+) tested with small problem size and with carry-over decimal were predicted correctly in the current model."

correct_predictions_small_binary_train_regex = r"STAGE (\d+): Out of 6986, (\d+) trained with small binary problem size were predicted correctly in the current model."
correct_predictions_small_binary_test_regex = r"STAGE (\d+): Out of 5302, (\d+) tested with small binary problem size were predicted correctly in the current model."
correct_predictions_small_binary_train_carry_regex = r"STAGE (\d+): Out of 5510, (\d+) trained with small binary problem size and with carry-over were predicted correctly in the current model."
correct_predictions_small_binary_test_carry_regex = r"STAGE (\d+): Out of 4591, (\d+) tested with small binary problem size and with carry-over were predicted correctly in the current model."
correct_predictions_small_binary_train_carry_decimal_regex = r"STAGE (\d+): Out of 4562, (\d+) trained with small binary problem size and with carry-over decimal were predicted correctly in the current model."
correct_predictions_small_binary_test_carry_decimal_regex = r"STAGE (\d+): Out of 2559, (\d+) tested with small binary problem size and with carry-over decimal were predicted correctly in the current model."

reaction_time_carry_regex = r"STAGE (\d+): (\d+) reaction time with carry over\."
reaction_time_carry_decimal_regex = r"STAGE (\d+): (\d+) reaction time with carry over decimal\."
reaction_time_train_regex = r"STAGE (\d+): (\d+) reaction time for train\."
reaction_time_test_regex = r"STAGE (\d+): (\d+) reaction time for test\."
reaction_time_train_carry_regex = r"STAGE (\d+): (\d+) reaction time for train with carry over \."
reaction_time_train_carry_decimal_regex = r"STAGE (\d+): (\d+) reaction time for train with carry over decimal\."
reaction_time_small_train_regex = r"STAGE (\d+): (\d+) reaction time for train small\."
reaction_time_small_test_regex = r"STAGE (\d+): (\d+) reaction time for test small\."
reaction_time_small_train_carry_regex = r"STAGE (\d+): (\d+) reaction time for train with carry over and small\."
reaction_time_small_test_carry_regex = r"STAGE (\d+): (\d+) reaction time for test with carry over and small\."
reaction_time_small_train_carry_decimal_regex = r"STAGE (\d+): (\d+) reaction time for train with carry over decimal and small\."
reaction_time_small_test_carry_decimal_regex = r"STAGE (\d+): (\d+) reaction time for test with carry over decimal and small\."

reaction_time_small_binary_train_regex = r"STAGE (\d+): (\d+) reaction time for train small binary\."
reaction_time_small_binary_test_regex = r"STAGE (\d+): (\d+) reaction time for test small binary\."
reaction_time_small_binary_train_carry_regex = r"STAGE (\d+): (\d+) reaction time for train with carry over and small binary\."
reaction_time_small_binary_test_carry_regex = r"STAGE (\d+): (\d+) reaction time for test with carry over and small binary\."
reaction_time_small_binary_train_carry_decimal_regex = r"STAGE (\d+): (\d+) reaction time for train with carry over decimal and small binary\."
reaction_time_small_binary_test_carry_decimal_regex = r"STAGE (\d+): (\d+) reaction time for test with carry over decimal and small binary\."

data = []

for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        match = re.search(type_file_regex, filename)        
        if match:
            type_training = match.group(1)
            file_name = match.group(2)
            
            stage = None
            with open(os.path.join(folder_path, filename), 'r') as file:
                for line in file:
                    model_match = re.search(model_regex, line)
                    if model_match:
                        current_time = model_match.group(1)
                        continue
                        
                    predictions_train = re.search(correct_predictions_train_regex, line)
                    if predictions_train:
                        stage = int(predictions_train.group(1))
                        correct_predictions_train = int(predictions_train.group(2))
                        continue 
                        
                    predictions_test = re.search(correct_predictions_test_regex, line)
                    if predictions_test:
                        correct_predictions_test = int(predictions_test.group(2))
                        continue  

                    predictions_train = re.search(correct_predictions_train_regex, line)
                    if predictions_train:
                        correct_predictions_train = int(predictions_train.group(2))
                        continue 

                    carry_over_predictions_test = re.search(correct_carry_over_predictions_test_regex, line)
                    if carry_over_predictions_test:
                        correct_carry_over_predictions_test = int(carry_over_predictions_test.group(2))
                        continue 

                    carry_over_predictions_train = re.search(correct_carry_over_predictions_train_regex, line)
                    if carry_over_predictions_train:
                        correct_carry_over_predictions_train = int(carry_over_predictions_train.group(2))
                        continue 

                    predictions_small_train = re.search(correct_predictions_small_train_regex, line)
                    if predictions_small_train:
                        correct_predictions_small_train = int(predictions_small_train.group(2))
                        continue 

                    predictions_small_test = re.search(correct_predictions_small_test_regex, line)
                    if predictions_small_test:
                        correct_predictions_small_test = int(predictions_small_test.group(2))
                        continue 

                    predictions_small_train_carry = re.search(correct_predictions_small_train_carry_regex, line)
                    if predictions_small_train_carry:
                        correct_predictions_small_train_carry = int(predictions_small_train_carry.group(2))
                        continue 

                    predictions_small_test_carry = re.search(correct_predictions_small_test_carry_regex, line)
                    if predictions_small_test_carry:
                        correct_predictions_small_test_carry = int(predictions_small_test_carry.group(2))
                        continue 

                    carry_over_decimal_predictions_test = re.search(correct_carry_over_decimal_predictions_test_regex, line)
                    if carry_over_decimal_predictions_test:
                        correct_carry_over_decimal_predictions_test = int(carry_over_decimal_predictions_test.group(2))
                        continue 

                    carry_over_decimal_predictions_train = re.search(correct_carry_over_decimal_predictions_train_regex, line)
                    if carry_over_decimal_predictions_train:
                        correct_carry_over_decimal_predictions_train = int(carry_over_decimal_predictions_train.group(2))
                        continue 

                    predictions_small_train_carry_decimal = re.search(correct_predictions_small_train_carry_decimal_regex, line)
                    if predictions_small_train_carry_decimal:
                        correct_predictions_small_train_carry_decimal = int(predictions_small_train_carry_decimal.group(2))
                        continue 

                    predictions_small_test_carry_decimal = re.search(correct_predictions_small_test_carry_decimal_regex, line)
                    if predictions_small_test_carry_decimal:
                        correct_predictions_small_test_carry_decimal = int(predictions_small_test_carry_decimal.group(2))
                        continue 

                    predictions_small_binary_train = re.search(correct_predictions_small_binary_train_regex, line)
                    if predictions_small_binary_train:
                        correct_predictions_small_binary_train = int(predictions_small_binary_train.group(2))
                        continue 

                    predictions_small_binary_test = re.search(correct_predictions_small_binary_test_regex, line)
                    if predictions_small_binary_test:
                        correct_predictions_small_binary_test = int(predictions_small_binary_test.group(2))
                        continue 

                    predictions_small_binary_train_carry = re.search(correct_predictions_small_binary_train_carry_regex, line)
                    if predictions_small_binary_train_carry:
                        correct_predictions_small_binary_train_carry = int(predictions_small_binary_train_carry.group(2))
                        continue 

                    predictions_small_binary_test_carry = re.search(correct_predictions_small_binary_test_carry_regex, line)
                    if predictions_small_binary_test_carry:
                        correct_predictions_small_binary_test_carry = int(predictions_small_binary_test_carry.group(2))
                        continue 

                    carry_over_decimal_predictions_test = re.search(correct_carry_over_decimal_predictions_test_regex, line)
                    if carry_over_decimal_predictions_test:
                        correct_carry_over_decimal_predictions_test = int(carry_over_decimal_predictions_test.group(2))
                        continue 

                    carry_over_decimal_predictions_train = re.search(correct_carry_over_decimal_predictions_train_regex, line)
                    if carry_over_decimal_predictions_train:
                        correct_carry_over_decimal_predictions_train = int(carry_over_decimal_predictions_train.group(2))
                        continue 

                    predictions_small_binary_train_carry_decimal = re.search(correct_predictions_small_binary_train_carry_decimal_regex, line)
                    if predictions_small_binary_train_carry_decimal:
                        correct_predictions_small_binary_train_carry_decimal = int(predictions_small_binary_train_carry_decimal.group(2))
                        continue 

                    predictions_small_binary_test_carry_decimal = re.search(correct_predictions_small_binary_test_carry_decimal_regex, line)
                    if predictions_small_binary_test_carry_decimal:
                        correct_predictions_small_binary_test_carry_decimal = int(predictions_small_binary_test_carry_decimal.group(2))
                        continue 

                    reaction_time_carry_ = re.search(reaction_time_carry_regex, line)
                    if reaction_time_carry_:
                        reaction_time_carry = int(reaction_time_carry_.group(2))
                        continue 

                    reaction_time_carry_decimal_ = re.search(reaction_time_carry_decimal_regex, line)
                    if reaction_time_carry_decimal_:
                        reaction_time_carry_decimal = int(reaction_time_carry_decimal_.group(2))
                        continue 
                    
                    reaction_time_train_ = re.search(reaction_time_train_regex, line)
                    if reaction_time_train_:
                        reaction_time_train = int(reaction_time_train_.group(2))
                        continue 
                    
                    reaction_time_test_ = re.search(reaction_time_test_regex, line)
                    if reaction_time_test_:
                        reaction_time_test = int(reaction_time_test_.group(2))
                        continue 
                    
                    reaction_time_train_carry_ = re.search(reaction_time_train_carry_regex, line)
                    if reaction_time_train_carry_:
                        reaction_time_train_carry = int(reaction_time_train_carry_.group(2))
                        continue 

                    reaction_time_train_carry_decimal_ = re.search(reaction_time_train_carry_decimal_regex, line)
                    if reaction_time_train_carry_decimal_:
                        reaction_time_train_carry_decimal = int(reaction_time_train_carry_decimal_.group(2))
                        continue 
                    
                    reaction_time_small_train_ = re.search(reaction_time_small_train_regex, line)
                    if reaction_time_small_train_:
                        reaction_time_small_train = int(reaction_time_small_train_.group(2))
                        continue 
                    
                    reaction_time_small_test_ = re.search(reaction_time_small_test_regex, line)
                    if reaction_time_small_test_:
                        reaction_time_small_test = int(reaction_time_small_test_.group(2))
                        continue 
                    
                    reaction_time_small_train_carry_ = re.search(reaction_time_small_train_carry_regex, line)
                    if reaction_time_small_train_carry_:
                        reaction_time_small_train_carry = int(reaction_time_small_train_carry_.group(2))
                        continue 
                    
                    reaction_time_small_test_carry_ = re.search(reaction_time_small_test_carry_regex, line)
                    if reaction_time_small_test_carry_:
                        reaction_time_small_test_carry = int(reaction_time_small_test_carry_.group(2))
                        continue 
                        
                    reaction_time_small_train_carry_decimal_ = re.search(reaction_time_small_train_carry_decimal_regex, line)
                    if reaction_time_small_train_carry_decimal_:
                        reaction_time_small_train_carry_decimal = int(reaction_time_small_train_carry_decimal_.group(2))
                        continue
                        
                    reaction_time_small_test_carry_decimal_ = re.search(reaction_time_small_test_carry_decimal_regex, line)
                    if reaction_time_small_test_carry_decimal_:
                        reaction_time_small_test_carry_decimal = int(reaction_time_small_test_carry_decimal_.group(2))
                        continue

                    reaction_time_small_binary_train_ = re.search(reaction_time_small_binary_train_regex, line)
                    if reaction_time_small_binary_train_:
                        reaction_time_small_binary_train = int(reaction_time_small_binary_train_.group(2))
                        continue 
                    
                    reaction_time_small_binary_test_ = re.search(reaction_time_small_binary_test_regex, line)
                    if reaction_time_small_binary_test_:
                        reaction_time_small_binary_test = int(reaction_time_small_binary_test_.group(2))
                        continue 
                    
                    reaction_time_small_binary_train_carry_ = re.search(reaction_time_small_binary_train_carry_regex, line)
                    if reaction_time_small_binary_train_carry_:
                        reaction_time_small_binary_train_carry = int(reaction_time_small_binary_train_carry_.group(2))
                        continue 
                    
                    reaction_time_small_binary_test_carry_ = re.search(reaction_time_small_binary_test_carry_regex, line)
                    if reaction_time_small_binary_test_carry_:
                        reaction_time_small_binary_test_carry = int(reaction_time_small_binary_test_carry_.group(2))
                        continue 
                        
                    reaction_time_small_binary_train_carry_decimal_ = re.search(reaction_time_small_binary_train_carry_decimal_regex, line)
                    if reaction_time_small_binary_train_carry_decimal_:
                        reaction_time_small_binary_train_carry_decimal = int(reaction_time_small_binary_train_carry_decimal_.group(2))
                        continue
                        
                    reaction_time_small_binary_test_carry_decimal_ = re.search(reaction_time_small_binary_test_carry_decimal_regex, line)
                    if reaction_time_small_binary_test_carry_decimal_ and stage is not None:
                        reaction_time_small_binary_test_carry_decimal = int(reaction_time_small_binary_test_carry_decimal_.group(2))
                        
                        if validation_performance == 'yes':
                            analyzed_file_path = f"{analyzed_data_folder}/all_Validation_performance_{type_training}_results_{file_name}.csv"
                        else:
                            analyzed_file_path = f"{analyzed_data_folder}/all_{type_training}_results_{file_name}.csv"
                            
                        if os.path.exists(analyzed_file_path):
                            analyzed_df = pd.read_csv(analyzed_file_path, delimiter=';', decimal=',')
                            
                            stage_data = analyzed_df[(analyzed_df['stage'] == stage) & (analyzed_df['model'] == current_time)]
                            total_trainings = len(stage_data)
                        else:
                            total_trainings = 0

                        total_correct_predictions = correct_predictions_train + correct_predictions_test
                        total_correct_carry_over_predictions = correct_carry_over_predictions_train + correct_carry_over_predictions_test
                        total_correct_no_carry_over_predictions = total_correct_predictions - total_correct_carry_over_predictions
                        correct_no_carry_over_predictions_train = correct_predictions_train - correct_carry_over_predictions_train
                        correct_no_carry_over_predictions_test = correct_predictions_test - correct_carry_over_predictions_test
                        
                        total_correct_predictions_small = correct_predictions_small_train + correct_predictions_small_test
                        total_correct_predictions_large = total_correct_predictions - total_correct_predictions_small
                        correct_predictions_large_train = correct_predictions_train - correct_predictions_small_train
                        correct_predictions_large_test = correct_predictions_test - correct_predictions_small_test

                        total_correct_predictions_small_binary = correct_predictions_small_binary_train + correct_predictions_small_binary_test
                        total_correct_predictions_large_binary = total_correct_predictions - total_correct_predictions_small_binary
                        correct_predictions_large_binary_train = correct_predictions_train - correct_predictions_small_binary_train
                        correct_predictions_large_binary_test = correct_predictions_test - correct_predictions_small_binary_test
                        
                        total_correct_predictions_small_carry = correct_predictions_small_train_carry + correct_predictions_small_test_carry
                        total_correct_predictions_small_no_carry = total_correct_predictions_small - total_correct_predictions_small_carry
                        correct_predictions_small_train_no_carry = correct_predictions_small_train - correct_predictions_small_train_carry
                        correct_predictions_small_test_no_carry = correct_predictions_small_test - correct_predictions_small_test_carry
                        total_correct_predictions_large_carry = total_correct_carry_over_predictions - total_correct_predictions_small_carry
                        correct_predictions_large_train_carry = correct_carry_over_predictions_train - correct_predictions_small_train_carry
                        correct_predictions_large_test_carry = correct_carry_over_predictions_test - correct_predictions_small_test_carry
                        total_correct_predictions_large_no_carry = total_correct_predictions_large - total_correct_predictions_large_carry
                        correct_predictions_large_train_no_carry = correct_predictions_large_train - correct_predictions_large_train_carry
                        correct_predictions_large_test_no_carry = correct_predictions_large_test - correct_predictions_large_test_carry

                        total_correct_predictions_small_binary_carry = correct_predictions_small_binary_train_carry + correct_predictions_small_binary_test_carry
                        total_correct_predictions_small_binary_no_carry = total_correct_predictions_small_binary - total_correct_predictions_small_binary_carry
                        correct_predictions_small_binary_train_no_carry = correct_predictions_small_binary_train - correct_predictions_small_binary_train_carry
                        correct_predictions_small_binary_test_no_carry = correct_predictions_small_binary_test - correct_predictions_small_binary_test_carry
                        total_correct_predictions_large_binary_carry = total_correct_carry_over_predictions - total_correct_predictions_small_binary_carry
                        correct_predictions_large_binary_train_carry = correct_carry_over_predictions_train - correct_predictions_small_binary_train_carry
                        correct_predictions_large_binary_test_carry = correct_carry_over_predictions_test - correct_predictions_small_binary_test_carry
                        total_correct_predictions_large_binary_no_carry = total_correct_predictions_large_binary - total_correct_predictions_large_binary_carry
                        correct_predictions_large_binary_train_no_carry = correct_predictions_large_binary_train - correct_predictions_large_binary_train_carry
                        correct_predictions_large_binary_test_no_carry = correct_predictions_large_binary_test - correct_predictions_large_binary_test_carry
                        
                        total_correct_carry_over_decimal_predictions = correct_carry_over_decimal_predictions_train + correct_carry_over_decimal_predictions_test
                        total_correct_no_carry_over_decimal_predictions = total_correct_predictions - total_correct_carry_over_decimal_predictions
                        correct_no_carry_over_decimal_predictions_train = correct_predictions_train - correct_carry_over_decimal_predictions_train
                        correct_no_carry_over_decimal_predictions_test = correct_predictions_test - correct_carry_over_decimal_predictions_test
                        total_correct_predictions_small_carry_decimal = correct_predictions_small_train_carry_decimal + correct_predictions_small_test_carry_decimal
                        total_correct_predictions_small_no_carry_decimal = total_correct_predictions_small - total_correct_predictions_small_carry_decimal
                        correct_predictions_small_train_no_carry_decimal = correct_predictions_small_train - correct_predictions_small_train_carry_decimal
                        correct_predictions_small_test_no_carry_decimal = correct_predictions_small_test - correct_predictions_small_test_carry_decimal
                        total_correct_predictions_large_carry_decimal = total_correct_carry_over_decimal_predictions - total_correct_predictions_small_carry_decimal
                        correct_predictions_large_train_carry_decimal = correct_carry_over_decimal_predictions_train - correct_predictions_small_train_carry_decimal
                        correct_predictions_large_test_carry_decimal = correct_carry_over_decimal_predictions_test - correct_predictions_small_test_carry_decimal
                        total_correct_predictions_large_no_carry_decimal = total_correct_predictions_large - total_correct_predictions_large_carry_decimal
                        correct_predictions_large_train_no_carry_decimal = correct_predictions_large_train - correct_predictions_large_train_carry_decimal
                        correct_predictions_large_test_no_carry_decimal = correct_predictions_large_test - correct_predictions_large_test_carry_decimal

                        total_correct_predictions_small_binary_carry_decimal = correct_predictions_small_binary_train_carry_decimal + correct_predictions_small_binary_test_carry_decimal
                        total_correct_predictions_small_binary_no_carry_decimal = total_correct_predictions_small_binary - total_correct_predictions_small_binary_carry_decimal
                        correct_predictions_small_binary_train_no_carry_decimal = correct_predictions_small_binary_train - correct_predictions_small_binary_train_carry_decimal
                        correct_predictions_small_binary_test_no_carry_decimal = correct_predictions_small_binary_test - correct_predictions_small_binary_test_carry_decimal
                        total_correct_predictions_large_binary_carry_decimal = total_correct_carry_over_decimal_predictions - total_correct_predictions_small_binary_carry_decimal
                        correct_predictions_large_binary_train_carry_decimal = correct_carry_over_decimal_predictions_train - correct_predictions_small_binary_train_carry_decimal
                        correct_predictions_large_binary_test_carry_decimal = correct_carry_over_decimal_predictions_test - correct_predictions_small_binary_test_carry_decimal
                        total_correct_predictions_large_binary_no_carry_decimal = total_correct_predictions_large_binary - total_correct_predictions_large_binary_carry_decimal
                        correct_predictions_large_binary_train_no_carry_decimal = correct_predictions_large_binary_train - correct_predictions_large_binary_train_carry_decimal
                        correct_predictions_large_binary_test_no_carry_decimal = correct_predictions_large_binary_test - correct_predictions_large_binary_test_carry_decimal

                        total_reaction_time = reaction_time_train + reaction_time_test
                        reaction_time_test_carry = reaction_time_carry - reaction_time_train_carry
                        reaction_time_no_carry = total_reaction_time - reaction_time_carry
                        reaction_time_train_no_carry = reaction_time_train - reaction_time_train_carry
                        reaction_time_test_no_carry = reaction_time_test - reaction_time_test_carry
                        reaction_time_small = reaction_time_small_train + reaction_time_small_test
                        reaction_time_large = total_reaction_time - reaction_time_small
                        reaction_time_large_train = reaction_time_train - reaction_time_small_train
                        reaction_time_large_test = reaction_time_test - reaction_time_small_test
                        reaction_time_small_carry = reaction_time_small_train_carry + reaction_time_small_test_carry
                        reaction_time_small_no_carry = reaction_time_small - reaction_time_small_carry
                        reaction_time_small_train_no_carry = reaction_time_small_train - reaction_time_small_train_carry
                        reaction_time_small_test_no_carry = reaction_time_small_test - reaction_time_small_test_carry
                        reaction_time_large_carry = reaction_time_carry - reaction_time_small_carry
                        reaction_time_large_train_carry = reaction_time_train_carry - reaction_time_small_train_carry
                        reaction_time_large_test_carry = reaction_time_test_carry - reaction_time_small_test_carry
                        reaction_time_large_no_carry = reaction_time_large - reaction_time_large_carry
                        reaction_time_large_train_no_carry = reaction_time_large_train - reaction_time_large_train_carry
                        reaction_time_large_test_no_carry = reaction_time_large_test - reaction_time_large_test_carry

                        reaction_time_small_binary = reaction_time_small_binary_train + reaction_time_small_binary_test
                        reaction_time_large_binary = total_reaction_time - reaction_time_small_binary
                        reaction_time_large_binary_train = reaction_time_train - reaction_time_small_binary_train
                        reaction_time_large_binary_test = reaction_time_test - reaction_time_small_binary_test
                        reaction_time_small_binary_carry = reaction_time_small_binary_train_carry + reaction_time_small_binary_test_carry
                        reaction_time_small_binary_no_carry = reaction_time_small_binary - reaction_time_small_binary_carry
                        reaction_time_small_binary_train_no_carry = reaction_time_small_binary_train - reaction_time_small_binary_train_carry
                        reaction_time_small_binary_test_no_carry = reaction_time_small_binary_test - reaction_time_small_binary_test_carry
                        reaction_time_large_binary_carry = reaction_time_carry - reaction_time_small_binary_carry
                        reaction_time_large_binary_train_carry = reaction_time_train_carry - reaction_time_small_binary_train_carry
                        reaction_time_large_binary_test_carry = reaction_time_test_carry - reaction_time_small_binary_test_carry
                        reaction_time_large_binary_no_carry = reaction_time_large_binary - reaction_time_large_binary_carry
                        reaction_time_large_binary_train_no_carry = reaction_time_large_binary_train - reaction_time_large_binary_train_carry
                        reaction_time_large_binary_test_no_carry = reaction_time_large_binary_test - reaction_time_large_binary_test_carry
                        
                        reaction_time_test_carry_decimal = reaction_time_carry_decimal - reaction_time_train_carry_decimal
                        reaction_time_no_carry_decimal = total_reaction_time - reaction_time_carry_decimal
                        reaction_time_train_no_carry_decimal = reaction_time_train - reaction_time_train_carry_decimal
                        reaction_time_test_no_carry_decimal = reaction_time_test - reaction_time_test_carry_decimal
                        reaction_time_small_carry_decimal = reaction_time_small_train_carry_decimal + reaction_time_small_test_carry_decimal
                        reaction_time_small_no_carry_decimal = reaction_time_small - reaction_time_small_carry_decimal
                        reaction_time_small_train_no_carry_decimal = reaction_time_small_train - reaction_time_small_train_carry_decimal
                        reaction_time_small_test_no_carry_decimal = reaction_time_small_test - reaction_time_small_test_carry_decimal
                        reaction_time_large_carry_decimal = reaction_time_carry_decimal - reaction_time_small_carry_decimal
                        reaction_time_large_train_carry_decimal = reaction_time_train_carry_decimal - reaction_time_small_train_carry_decimal
                        reaction_time_large_test_carry_decimal = reaction_time_test_carry_decimal - reaction_time_small_test_carry_decimal
                        reaction_time_large_no_carry_decimal = reaction_time_large - reaction_time_large_carry_decimal
                        reaction_time_large_train_no_carry_decimal = reaction_time_large_train - reaction_time_large_train_carry_decimal
                        reaction_time_large_test_no_carry_decimal = reaction_time_large_test - reaction_time_large_test_carry_decimal

                        reaction_time_small_binary_carry_decimal = reaction_time_small_binary_train_carry_decimal + reaction_time_small_binary_test_carry_decimal
                        reaction_time_small_binary_no_carry_decimal = reaction_time_small_binary - reaction_time_small_binary_carry_decimal
                        reaction_time_small_binary_train_no_carry_decimal = reaction_time_small_binary_train - reaction_time_small_binary_train_carry_decimal
                        reaction_time_small_binary_test_no_carry_decimal = reaction_time_small_binary_test - reaction_time_small_binary_test_carry_decimal
                        reaction_time_large_binary_carry_decimal = reaction_time_carry_decimal - reaction_time_small_binary_carry_decimal
                        reaction_time_large_binary_train_carry_decimal = reaction_time_train_carry_decimal - reaction_time_small_binary_train_carry_decimal
                        reaction_time_large_binary_test_carry_decimal = reaction_time_test_carry_decimal - reaction_time_small_binary_test_carry_decimal
                        reaction_time_large_binary_no_carry_decimal = reaction_time_large_binary - reaction_time_large_binary_carry_decimal
                        reaction_time_large_binary_train_no_carry_decimal = reaction_time_large_binary_train - reaction_time_large_binary_train_carry_decimal
                        reaction_time_large_binary_test_no_carry_decimal = reaction_time_large_binary_test - reaction_time_large_binary_test_carry_decimal

                        mod_total_reaction_time = total_reaction_time / total_count
                        mod_reaction_time_train = reaction_time_train / count_train
                        mod_reaction_time_test = reaction_time_test / count_test
                        mod_reaction_time_carry = reaction_time_carry / total_count_carry_over
                        mod_reaction_time_train_carry = reaction_time_train_carry / count_carry_over_train
                        mod_reaction_time_test_carry = reaction_time_test_carry / count_carry_over_test
                        mod_reaction_time_no_carry = reaction_time_no_carry / total_count_no_carry_over
                        mod_reaction_time_train_no_carry = reaction_time_train_no_carry / count_no_carry_over_train
                        mod_reaction_time_test_no_carry = reaction_time_test_no_carry / count_no_carry_over_test
                        mod_reaction_time_small = reaction_time_small / total_count_small
                        mod_reaction_time_small_train = reaction_time_small_train / count_small_train
                        mod_reaction_time_small_test = reaction_time_small_test / count_small_test
                        mod_reaction_time_large = reaction_time_large / total_count_large
                        mod_reaction_time_large_train = reaction_time_large_train / count_large_train
                        mod_reaction_time_large_test = reaction_time_large_test / count_large_test
                        mod_reaction_time_small_carry = reaction_time_small_carry / total_count_small_carry
                        mod_reaction_time_small_train_carry = reaction_time_small_train_carry / count_small_train_carry
                        mod_reaction_time_small_test_carry = reaction_time_small_test_carry / count_small_test_carry
                        mod_reaction_time_small_no_carry = reaction_time_small_no_carry / total_count_small_no_carry
                        mod_reaction_time_small_train_no_carry = reaction_time_small_train_no_carry / count_small_train_no_carry
                        mod_reaction_time_small_test_no_carry = reaction_time_small_test_no_carry / count_small_test_no_carry
                        mod_reaction_time_large_carry = reaction_time_large_carry / total_count_large_carry
                        mod_reaction_time_large_train_carry = reaction_time_large_train_carry / count_large_train_carry
                        mod_reaction_time_large_test_carry = reaction_time_large_test_carry / count_large_test_carry
                        mod_reaction_time_large_no_carry = reaction_time_large_no_carry / total_count_large_no_carry
                        mod_reaction_time_large_train_no_carry = reaction_time_large_train_no_carry / count_large_train_no_carry
                        mod_reaction_time_large_test_no_carry = reaction_time_large_test_no_carry / count_large_test_no_carry

                        mod_reaction_time_small_binary = reaction_time_small_binary / total_count_small_binary
                        mod_reaction_time_small_binary_train = reaction_time_small_binary_train / count_small_binary_train
                        mod_reaction_time_small_binary_test = reaction_time_small_binary_test / count_small_binary_test
                        mod_reaction_time_large_binary = reaction_time_large_binary / total_count_large_binary
                        mod_reaction_time_large_binary_train = reaction_time_large_binary_train / count_large_binary_train
                        mod_reaction_time_large_binary_test = reaction_time_large_binary_test / count_large_binary_test
                        mod_reaction_time_small_binary_carry = reaction_time_small_binary_carry / total_count_small_binary_carry
                        mod_reaction_time_small_binary_train_carry = reaction_time_small_binary_train_carry / count_small_binary_train_carry
                        mod_reaction_time_small_binary_test_carry = reaction_time_small_binary_test_carry / count_small_binary_test_carry
                        mod_reaction_time_small_binary_no_carry = reaction_time_small_binary_no_carry / total_count_small_binary_no_carry
                        mod_reaction_time_small_binary_train_no_carry = reaction_time_small_binary_train_no_carry / count_small_binary_train_no_carry
                        mod_reaction_time_small_binary_test_no_carry = reaction_time_small_binary_test_no_carry / count_small_binary_test_no_carry
                        mod_reaction_time_large_binary_carry = reaction_time_large_binary_carry / total_count_large_binary_carry
                        mod_reaction_time_large_binary_train_carry = reaction_time_large_binary_train_carry / count_large_binary_train_carry
                        mod_reaction_time_large_binary_test_carry = reaction_time_large_binary_test_carry / count_large_binary_test_carry
                        if total_count_large_binary_no_carry != 0:
                            mod_reaction_time_large_binary_no_carry = reaction_time_large_binary_no_carry / total_count_large_binary_no_carry
                        else:
                            mod_reaction_time_large_binary_no_carry = 0
                        if count_large_binary_train_no_carry != 0:
                            mod_reaction_time_large_binary_train_no_carry = reaction_time_large_binary_train_no_carry / count_large_binary_train_no_carry
                        else:
                            mod_reaction_time_large_binary_train_no_carry = 0
                        if count_large_binary_test_no_carry != 0:
                            mod_reaction_time_large_binary_test_no_carry = reaction_time_large_binary_test_no_carry / count_large_binary_test_no_carry
                        else:
                            mod_reaction_time_large_binary_test_no_carry = 0
                            
                        mod_reaction_time_carry_decimal = reaction_time_carry_decimal / total_count_carry_over_decimal
                        mod_reaction_time_train_carry_decimal = reaction_time_train_carry_decimal / count_carry_over_decimal_train
                        mod_reaction_time_test_carry_decimal = reaction_time_test_carry_decimal / count_carry_over_decimal_test
                        mod_reaction_time_no_carry_decimal = reaction_time_no_carry_decimal / total_count_no_carry_over_decimal
                        mod_reaction_time_train_no_carry_decimal = reaction_time_train_no_carry_decimal / count_no_carry_over_decimal_train
                        mod_reaction_time_test_no_carry_decimal = reaction_time_test_no_carry_decimal / count_no_carry_over_decimal_test
                        mod_reaction_time_small_carry_decimal = reaction_time_small_carry_decimal / total_count_small_carry_decimal
                        mod_reaction_time_small_train_carry_decimal = reaction_time_small_train_carry_decimal / count_small_train_carry_decimal
                        mod_reaction_time_small_test_carry_decimal = reaction_time_small_test_carry_decimal / count_small_test_carry_decimal
                        mod_reaction_time_small_no_carry_decimal = reaction_time_small_no_carry_decimal / total_count_small_no_carry_decimal
                        mod_reaction_time_small_train_no_carry_decimal = reaction_time_small_train_no_carry_decimal / count_small_train_no_carry_decimal
                        mod_reaction_time_small_test_no_carry_decimal = reaction_time_small_test_no_carry_decimal / count_small_test_no_carry_decimal
                        mod_reaction_time_large_carry_decimal = reaction_time_large_carry_decimal / total_count_large_carry_decimal
                        mod_reaction_time_large_train_carry_decimal = reaction_time_large_train_carry_decimal / count_large_train_carry_decimal
                        mod_reaction_time_large_test_carry_decimal = reaction_time_large_test_carry_decimal / count_large_test_carry_decimal
                        if total_count_large_no_carry_decimal != 0:
                            mod_reaction_time_large_no_carry_decimal = reaction_time_large_no_carry_decimal / total_count_large_no_carry_decimal
                        else:
                            mod_reaction_time_large_no_carry_decimal = 0
                        if count_large_train_no_carry_decimal != 0:
                            mod_reaction_time_large_train_no_carry_decimal = reaction_time_large_train_no_carry_decimal / count_large_train_no_carry_decimal
                        else:
                            mod_reaction_time_large_train_no_carry_decimal = 0
                        if count_large_test_no_carry_decimal != 0:
                            mod_reaction_time_large_test_no_carry_decimal = reaction_time_large_test_no_carry_decimal / count_large_test_no_carry_decimal
                        else:
                            mod_reaction_time_large_test_no_carry_decimal = 0

                        mod_reaction_time_small_binary_carry_decimal = reaction_time_small_binary_carry_decimal / total_count_small_binary_carry_decimal
                        mod_reaction_time_small_binary_train_carry_decimal = reaction_time_small_binary_train_carry_decimal / count_small_binary_train_carry_decimal
                        mod_reaction_time_small_binary_test_carry_decimal = reaction_time_small_binary_test_carry_decimal / count_small_binary_test_carry_decimal
                        mod_reaction_time_small_binary_no_carry_decimal = reaction_time_small_binary_no_carry_decimal / total_count_small_binary_no_carry_decimal
                        mod_reaction_time_small_binary_train_no_carry_decimal = reaction_time_small_binary_train_no_carry_decimal / count_small_binary_train_no_carry_decimal
                        mod_reaction_time_small_binary_test_no_carry_decimal = reaction_time_small_binary_test_no_carry_decimal / count_small_binary_test_no_carry_decimal
                        mod_reaction_time_large_binary_carry_decimal = reaction_time_large_binary_carry_decimal / total_count_large_binary_carry_decimal
                        mod_reaction_time_large_binary_train_carry_decimal = reaction_time_large_binary_train_carry_decimal / count_large_binary_train_carry_decimal
                        mod_reaction_time_large_binary_test_carry_decimal = reaction_time_large_binary_test_carry_decimal / count_large_binary_test_carry_decimal
                        if total_count_large_binary_no_carry_decimal != 0:
                            mod_reaction_time_large_binary_no_carry_decimal = reaction_time_large_binary_no_carry_decimal / total_count_large_binary_no_carry_decimal
                        else:
                            mod_reaction_time_large_binary_no_carry_decimal = 0
                        if count_large_binary_train_no_carry_decimal != 0:
                            mod_reaction_time_large_binary_train_no_carry_decimal = reaction_time_large_binary_train_no_carry_decimal / count_large_binary_train_no_carry_decimal
                        else:
                            mod_reaction_time_large_binary_train_no_carry_decimal = 0
                        if count_large_binary_test_no_carry_decimal != 0:
                            mod_reaction_time_large_binary_test_no_carry_decimal = reaction_time_large_binary_test_no_carry_decimal / count_large_binary_test_no_carry_decimal
                        else:
                            mod_reaction_time_large_binary_test_no_carry_decimal = 0

                        
                        data.append([current_time, type_training, file_name, stage, total_trainings,
                                     total_count, total_correct_predictions,
                                     count_train, correct_predictions_train,
                                     count_test, correct_predictions_test,
                                     total_count_carry_over, total_correct_carry_over_predictions,
                                     count_carry_over_train, correct_carry_over_predictions_train,
                                     count_carry_over_test, correct_carry_over_predictions_test,
                                     total_count_no_carry_over, total_correct_no_carry_over_predictions,
                                     count_no_carry_over_train, correct_no_carry_over_predictions_train,
                                     count_no_carry_over_test, correct_no_carry_over_predictions_test,
                                     total_count_small, total_correct_predictions_small,
                                     count_small_train, correct_predictions_small_train,
                                     count_small_test, correct_predictions_small_test,
                                     total_count_large, total_correct_predictions_large,
                                     count_large_train, correct_predictions_large_train,
                                     count_large_test, correct_predictions_large_test,
                                     total_count_small_carry, total_correct_predictions_small_carry,
                                     count_small_train_carry, correct_predictions_small_train_carry,
                                     count_small_test_carry, correct_predictions_small_test_carry,
                                     total_count_small_no_carry, total_correct_predictions_small_no_carry,
                                     count_small_train_no_carry, correct_predictions_small_train_no_carry,
                                     count_small_test_no_carry, correct_predictions_small_test_no_carry,
                                     total_count_large_carry, total_correct_predictions_large_carry,
                                     count_large_train_carry, correct_predictions_large_train_carry,
                                     count_large_test_carry, correct_predictions_large_test_carry,
                                     total_count_large_no_carry, total_correct_predictions_large_no_carry,
                                     count_large_train_no_carry, correct_predictions_large_train_no_carry,
                                     count_large_test_no_carry, correct_predictions_large_test_no_carry,
                                     total_count_small_binary, total_correct_predictions_small_binary,
                                     count_small_binary_train, correct_predictions_small_binary_train,
                                     count_small_binary_test, correct_predictions_small_binary_test,
                                     total_count_large_binary, total_correct_predictions_large_binary,
                                     count_large_binary_train, correct_predictions_large_binary_train,
                                     count_large_binary_test, correct_predictions_large_binary_test,
                                     total_count_small_binary_carry, total_correct_predictions_small_binary_carry,
                                     count_small_binary_train_carry, correct_predictions_small_binary_train_carry,
                                     count_small_binary_test_carry, correct_predictions_small_binary_test_carry,
                                     total_count_small_binary_no_carry, total_correct_predictions_small_binary_no_carry,
                                     count_small_binary_train_no_carry, correct_predictions_small_binary_train_no_carry,
                                     count_small_binary_test_no_carry, correct_predictions_small_binary_test_no_carry,
                                     total_count_large_binary_carry, total_correct_predictions_large_binary_carry,
                                     count_large_binary_train_carry, correct_predictions_large_binary_train_carry,
                                     count_large_binary_test_carry, correct_predictions_large_binary_test_carry,
                                     total_count_large_binary_no_carry, total_correct_predictions_large_binary_no_carry,
                                     count_large_binary_train_no_carry, correct_predictions_large_binary_train_no_carry,
                                     count_large_binary_test_no_carry, correct_predictions_large_binary_test_no_carry,
                                     total_count_carry_over_decimal, total_correct_carry_over_decimal_predictions,
                                     count_carry_over_decimal_train, correct_carry_over_decimal_predictions_train,
                                     count_carry_over_decimal_test, correct_carry_over_decimal_predictions_test,
                                     total_count_no_carry_over_decimal, total_correct_no_carry_over_decimal_predictions,
                                     count_no_carry_over_decimal_train, correct_no_carry_over_decimal_predictions_train,
                                     count_no_carry_over_decimal_test, correct_no_carry_over_decimal_predictions_test,
                                     total_count_small_carry_decimal, total_correct_predictions_small_carry_decimal,
                                     count_small_train_carry_decimal, correct_predictions_small_train_carry_decimal,
                                     count_small_test_carry_decimal, correct_predictions_small_test_carry_decimal,
                                     total_count_small_no_carry_decimal, total_correct_predictions_small_no_carry_decimal,
                                     count_small_train_no_carry_decimal, correct_predictions_small_train_no_carry_decimal,
                                     count_small_test_no_carry_decimal, correct_predictions_small_test_no_carry_decimal,
                                     total_count_large_carry_decimal, total_correct_predictions_large_carry_decimal,
                                     count_large_train_carry_decimal, correct_predictions_large_train_carry_decimal,
                                     count_large_test_carry_decimal, correct_predictions_large_test_carry_decimal,
                                     total_count_large_no_carry_decimal, total_correct_predictions_large_no_carry_decimal,
                                     count_large_train_no_carry_decimal, correct_predictions_large_train_no_carry_decimal,
                                     count_large_test_no_carry_decimal, correct_predictions_large_test_no_carry_decimal,
                                     total_count_small_binary_carry_decimal, total_correct_predictions_small_binary_carry_decimal,
                                     count_small_binary_train_carry_decimal, correct_predictions_small_binary_train_carry_decimal,
                                     count_small_binary_test_carry_decimal, correct_predictions_small_binary_test_carry_decimal,
                                     total_count_small_binary_no_carry_decimal, total_correct_predictions_small_binary_no_carry_decimal,
                                     count_small_binary_train_no_carry_decimal, correct_predictions_small_binary_train_no_carry_decimal,
                                     count_small_binary_test_no_carry_decimal, correct_predictions_small_binary_test_no_carry_decimal,
                                     total_count_large_binary_carry_decimal, total_correct_predictions_large_binary_carry_decimal,
                                     count_large_binary_train_carry_decimal, correct_predictions_large_binary_train_carry_decimal,
                                     count_large_binary_test_carry_decimal, correct_predictions_large_binary_test_carry_decimal,
                                     total_count_large_binary_no_carry_decimal, total_correct_predictions_large_binary_no_carry_decimal,
                                     count_large_binary_train_no_carry_decimal, correct_predictions_large_binary_train_no_carry_decimal,
                                     count_large_binary_test_no_carry_decimal, correct_predictions_large_binary_test_no_carry_decimal
                                     , mod_total_reaction_time
                                     , mod_reaction_time_train
                                     , mod_reaction_time_test
                                     , mod_reaction_time_carry
                                     , mod_reaction_time_train_carry
                                     , mod_reaction_time_test_carry
                                     , mod_reaction_time_no_carry
                                     , mod_reaction_time_train_no_carry
                                     , mod_reaction_time_test_no_carry
                                     , mod_reaction_time_small
                                     , mod_reaction_time_small_train
                                     , mod_reaction_time_small_test
                                     , mod_reaction_time_large
                                     , mod_reaction_time_large_train
                                     , mod_reaction_time_large_test
                                     , mod_reaction_time_small_carry
                                     , mod_reaction_time_small_train_carry
                                     , mod_reaction_time_small_test_carry
                                     , mod_reaction_time_small_no_carry
                                     , mod_reaction_time_small_train_no_carry
                                     , mod_reaction_time_small_test_no_carry
                                     , mod_reaction_time_large_carry
                                     , mod_reaction_time_large_train_carry
                                     , mod_reaction_time_large_test_carry
                                     , mod_reaction_time_large_no_carry
                                     , mod_reaction_time_large_train_no_carry
                                     , mod_reaction_time_large_test_no_carry
                                     , mod_reaction_time_small_binary
                                     , mod_reaction_time_small_binary_train
                                     , mod_reaction_time_small_binary_test
                                     , mod_reaction_time_large_binary
                                     , mod_reaction_time_large_binary_train
                                     , mod_reaction_time_large_binary_test
                                     , mod_reaction_time_small_binary_carry
                                     , mod_reaction_time_small_binary_train_carry
                                     , mod_reaction_time_small_binary_test_carry
                                     , mod_reaction_time_small_binary_no_carry
                                     , mod_reaction_time_small_binary_train_no_carry
                                     , mod_reaction_time_small_binary_test_no_carry
                                     , mod_reaction_time_large_binary_carry
                                     , mod_reaction_time_large_binary_train_carry
                                     , mod_reaction_time_large_binary_test_carry
                                     , mod_reaction_time_large_binary_no_carry
                                     , mod_reaction_time_large_binary_train_no_carry
                                     , mod_reaction_time_large_binary_test_no_carry
                                     , mod_reaction_time_carry_decimal
                                     , mod_reaction_time_train_carry_decimal
                                     , mod_reaction_time_test_carry_decimal
                                     , mod_reaction_time_no_carry_decimal
                                     , mod_reaction_time_train_no_carry_decimal 
                                     , mod_reaction_time_test_no_carry_decimal 
                                     , mod_reaction_time_small_carry_decimal
                                     , mod_reaction_time_small_train_carry_decimal
                                     , mod_reaction_time_small_test_carry_decimal
                                     , mod_reaction_time_small_no_carry_decimal
                                     , mod_reaction_time_small_train_no_carry_decimal
                                     , mod_reaction_time_small_test_no_carry_decimal
                                     , mod_reaction_time_large_carry_decimal
                                     , mod_reaction_time_large_train_carry_decimal
                                     , mod_reaction_time_large_test_carry_decimal
                                     , mod_reaction_time_large_no_carry_decimal
                                     , mod_reaction_time_large_train_no_carry_decimal
                                     , mod_reaction_time_large_test_no_carry_decimal
                                     , mod_reaction_time_small_binary_carry_decimal
                                     , mod_reaction_time_small_binary_train_carry_decimal
                                     , mod_reaction_time_small_binary_test_carry_decimal
                                     , mod_reaction_time_small_binary_no_carry_decimal
                                     , mod_reaction_time_small_binary_train_no_carry_decimal
                                     , mod_reaction_time_small_binary_test_no_carry_decimal
                                     , mod_reaction_time_large_binary_carry_decimal
                                     , mod_reaction_time_large_binary_train_carry_decimal
                                     , mod_reaction_time_large_binary_test_carry_decimal
                                     , mod_reaction_time_large_binary_no_carry_decimal
                                     , mod_reaction_time_large_binary_train_no_carry_decimal
                                     , mod_reaction_time_large_binary_test_no_carry_decimal
                                     #, total_reaction_time
                                     #, reaction_time_train
                                     #, reaction_time_test
                                     #, reaction_time_carry
                                     #, reaction_time_train_carry
                                     #, reaction_time_test_carry
                                     #, reaction_time_no_carry
                                     #, reaction_time_train_no_carry
                                     #, reaction_time_test_no_carry
                                     #, reaction_time_small
                                     #, reaction_time_small_train
                                     #, reaction_time_small_test
                                     #, reaction_time_large
                                     #, reaction_time_large_train
                                     #, reaction_time_large_test
                                     #, reaction_time_small_carry
                                     #, reaction_time_small_train_carry
                                     #, reaction_time_small_test_carry
                                     #, reaction_time_small_no_carry
                                     #, reaction_time_small_train_no_carry
                                     #, reaction_time_small_test_no_carry
                                     #, reaction_time_large_carry
                                     #, reaction_time_large_train_carry
                                     #, reaction_time_large_test_carry
                                     #, reaction_time_large_no_carry
                                     #, reaction_time_large_train_no_carry
                                     #, reaction_time_large_test_no_carry
                                     #, reaction_time_carry_decimal
                                     #, reaction_time_train_carry_decimal
                                     #, reaction_time_test_carry_decimal
                                     #, reaction_time_no_carry_decimal
                                     #, reaction_time_train_no_carry_decimal 
                                     #, reaction_time_test_no_carry_decimal 
                                     #, reaction_time_small_carry_decimal
                                     #, reaction_time_small_train_carry_decimal
                                     #, reaction_time_small_test_carry_decimal
                                     #, reaction_time_small_no_carry_decimal
                                     #, reaction_time_small_train_no_carry_decimal
                                     #, reaction_time_small_test_no_carry_decimal
                                     #, reaction_time_large_carry_decimal
                                     #, reaction_time_large_train_carry_decimal
                                     #, reaction_time_large_test_carry_decimal
                                     #, reaction_time_large_no_carry_decimal
                                     #, reaction_time_large_train_no_carry_decimal
                                     #, reaction_time_large_test_no_carry_decimal
                                     ]) 
                        
                        # Resetear las variables para la siguiente etapa
                        stage = None

df = pd.DataFrame(data, columns=[
    'current_time', 'type_training', 'file_name', 'stage', 'total_trainings',
    'total_count', 'total_correct_predictions',
    'count_train', 'correct_predictions_train',
    'count_test', 'correct_predictions_test',
    'total_count_carry_over', 'total_correct_carry_over_predictions',
    'count_carry_over_train', 'correct_carry_over_predictions_train',
    'count_carry_over_test', 'correct_carry_over_predictions_test',
    'total_count_no_carry_over', 'total_correct_no_carry_over_predictions',
    'count_no_carry_over_train', 'correct_no_carry_over_predictions_train',
    'count_no_carry_over_test', 'correct_no_carry_over_predictions_test',
    'total_count_small', 'total_correct_predictions_small',
    'count_small_train', 'correct_predictions_small_train',
    'count_small_test', 'correct_predictions_small_test',
    'total_count_large', 'total_correct_predictions_large',
    'count_large_train', 'correct_predictions_large_train',
    'count_large_test', 'correct_predictions_large_test',
    'total_count_small_carry', 'total_correct_predictions_small_carry',
    'count_small_train_carry', 'correct_predictions_small_train_carry',
    'count_small_test_carry', 'correct_predictions_small_test_carry',
    'total_count_small_no_carry', 'total_correct_predictions_small_no_carry',
    'count_small_train_no_carry', 'correct_predictions_small_train_no_carry',
    'count_small_test_no_carry', 'correct_predictions_small_test_no_carry',
    'total_count_large_carry', 'total_correct_predictions_large_carry',
    'count_large_train_carry', 'correct_predictions_large_train_carry',
    'count_large_test_carry', 'correct_predictions_large_test_carry',
    'total_count_large_no_carry', 'total_correct_predictions_large_no_carry',
    'count_large_train_no_carry', 'correct_predictions_large_train_no_carry',
    'count_large_test_no_carry', 'correct_predictions_large_test_no_carry',
    'total_count_small_binary', 'total_correct_predictions_small_binary',
    'count_small_binary_train', 'correct_predictions_small_binary_train',
    'count_small_binary_test', 'correct_predictions_small_binary_test',
    'total_count_large_binary', 'total_correct_predictions_large_binary',
    'count_large_binary_train', 'correct_predictions_large_binary_train',
    'count_large_binary_test', 'correct_predictions_large_binary_test',
    'total_count_small_binary_carry', 'total_correct_predictions_small_binary_carry',
    'count_small_binary_train_carry', 'correct_predictions_small_binary_train_carry',
    'count_small_binary_test_carry', 'correct_predictions_small_binary_test_carry',
    'total_count_small_binary_no_carry', 'total_correct_predictions_small_binary_no_carry',
    'count_small_binary_train_no_carry', 'correct_predictions_small_binary_train_no_carry',
    'count_small_binary_test_no_carry', 'correct_predictions_small_binary_test_no_carry',
    'total_count_large_binary_carry', 'total_correct_predictions_large_binary_carry',
    'count_large_binary_train_carry', 'correct_predictions_large_binary_train_carry',
    'count_large_binary_test_carry', 'correct_predictions_large_binary_test_carry',
    'total_count_large_binary_no_carry', 'total_correct_predictions_large_binary_no_carry',
    'count_large_binary_train_no_carry', 'correct_predictions_large_binary_train_no_carry',
    'count_large_binary_test_no_carry', 'correct_predictions_large_binary_test_no_carry',
    'total_count_carry_over_decimal', 'total_correct_carry_over_decimal_predictions',
    'count_carry_over_decimal_train', 'correct_carry_over_decimal_predictions_train',
    'count_carry_over_decimal_test', 'correct_carry_over_decimal_predictions_test',
    'total_count_no_carry_over_decimal', 'total_correct_no_carry_over_decimal_predictions',
    'count_no_carry_over_decimal_train', 'correct_no_carry_over_decimal_predictions_train',
    'count_no_carry_over_decimal_test', 'correct_no_carry_over_decimal_predictions_test',
    'total_count_small_carry_decimal', 'total_correct_predictions_small_carry_decimal',
    'total_count_small_no_carry_decimal', 'total_correct_predictions_small_no_carry_decimal',
    'count_small_train_carry_decimal', 'correct_predictions_small_train_carry_decimal',
    'count_small_test_carry_decimal', 'correct_predictions_small_test_carry_decimal',
    'count_small_train_no_carry_decimal', 'correct_predictions_small_train_no_carry_decimal',
    'count_small_test_no_carry_decimal', 'correct_predictions_small_test_no_carry_decimal',
    'total_count_large_carry_decimal', 'total_correct_predictions_large_carry_decimal',
    'count_large_train_carry_decimal', 'correct_predictions_large_train_carry_decimal',
    'count_large_test_carry_decimal', 'correct_predictions_large_test_carry_decimal',
    'total_count_large_no_carry_decimal', 'total_correct_predictions_large_no_carry_decimal',
    'count_large_train_no_carry_decimal', 'correct_predictions_large_train_no_carry_decimal',
    'count_large_test_no_carry_decimal', 'correct_predictions_large_test_no_carry_decimal',
    'total_count_small_binary_carry_decimal', 'total_correct_predictions_small_binary_carry_decimal',
    'total_count_small_binary_no_carry_decimal', 'total_correct_predictions_small_binary_no_carry_decimal',
    'count_small_binary_train_carry_decimal', 'correct_predictions_small_binary_train_carry_decimal',
    'count_small_binary_test_carry_decimal', 'correct_predictions_small_binary_test_carry_decimal',
    'count_small_binary_train_no_carry_decimal', 'correct_predictions_small_binary_train_no_carry_decimal',
    'count_small_binary_test_no_carry_decimal', 'correct_predictions_small_binary_test_no_carry_decimal',
    'total_count_large_binary_carry_decimal', 'total_correct_predictions_large_binary_carry_decimal',
    'count_large_binary_train_carry_decimal', 'correct_predictions_large_binary_train_carry_decimal',
    'count_large_binary_test_carry_decimal', 'correct_predictions_large_binary_test_carry_decimal',
    'total_count_large_binary_no_carry_decimal', 'total_correct_predictions_large_binary_no_carry_decimal',
    'count_large_binary_train_no_carry_decimal', 'correct_predictions_large_binary_train_no_carry_decimal',
    'count_large_binary_test_no_carry_decimal', 'correct_predictions_large_binary_test_no_carry_decimal'
    , 'total_reaction_time'
    , 'reaction_time_train'
    , 'reaction_time_test'
    , 'reaction_time_carry'
    , 'reaction_time_train_carry'
    , 'reaction_time_test_carry'
    , 'reaction_time_no_carry'
    , 'reaction_time_train_no_carry'
    , 'reaction_time_test_no_carry'
    , 'reaction_time_small'
    , 'reaction_time_small_train'
    , 'reaction_time_small_test'
    , 'reaction_time_large'
    , 'reaction_time_large_train'
    , 'reaction_time_large_test'
    , 'reaction_time_small_carry'
    , 'reaction_time_small_train_carry'
    , 'reaction_time_small_test_carry'
    , 'reaction_time_small_no_carry'
    , 'reaction_time_small_train_no_carry'
    , 'reaction_time_small_test_no_carry'
    , 'reaction_time_large_carry'
    , 'reaction_time_large_train_carry'
    , 'reaction_time_large_test_carry'
    , 'reaction_time_large_no_carry'
    , 'reaction_time_large_train_no_carry'
    , 'reaction_time_large_test_no_carry'
    , 'reaction_time_small_binary'
    , 'reaction_time_small_binary_train'
    , 'reaction_time_small_binary_test'
    , 'reaction_time_large_binary'
    , 'reaction_time_large_binary_train'
    , 'reaction_time_large_binary_test'
    , 'reaction_time_small_binary_carry'
    , 'reaction_time_small_binary_train_carry'
    , 'reaction_time_small_binary_test_carry'
    , 'reaction_time_small_binary_no_carry'
    , 'reaction_time_small_binary_train_no_carry'
    , 'reaction_time_small_binary_test_no_carry'
    , 'reaction_time_large_binary_carry'
    , 'reaction_time_large_binary_train_carry'
    , 'reaction_time_large_binary_test_carry'
    , 'reaction_time_large_binary_no_carry'
    , 'reaction_time_large_binary_train_no_carry'
    , 'reaction_time_large_binary_test_no_carry'
    , 'reaction_time_carry_decimal'
    , 'reaction_time_train_carry_decimal'
    , 'reaction_time_test_carry_decimal'
    , 'reaction_time_no_carry_decimal'
    , 'reaction_time_train_no_carry_decimal'
    , 'reaction_time_test_no_carry_decimal'
    , 'reaction_time_small_carry_decimal'
    , 'reaction_time_small_train_carry_decimal'
    , 'reaction_time_small_test_carry_decimal'
    , 'reaction_time_small_no_carry_decimal'
    , 'reaction_time_small_train_no_carry_decimal'
    , 'reaction_time_small_test_no_carry_decimal'
    , 'reaction_time_large_carry_decimal'
    , 'reaction_time_large_train_carry_decimal'
    , 'reaction_time_large_test_carry_decimal'
    , 'reaction_time_large_no_carry_decimal'
    , 'reaction_time_large_train_no_carry_decimal'
    , 'reaction_time_large_test_no_carry_decimal'
    , 'reaction_time_small_binary_carry_decimal'
    , 'reaction_time_small_binary_train_carry_decimal'
    , 'reaction_time_small_binary_test_carry_decimal'
    , 'reaction_time_small_binary_no_carry_decimal'
    , 'reaction_time_small_binary_train_no_carry_decimal'
    , 'reaction_time_small_binary_test_no_carry_decimal'
    , 'reaction_time_large_binary_carry_decimal'
    , 'reaction_time_large_binary_train_carry_decimal'
    , 'reaction_time_large_binary_test_carry_decimal'
    , 'reaction_time_large_binary_no_carry_decimal'
    , 'reaction_time_large_binary_train_no_carry_decimal'
    , 'reaction_time_large_binary_test_no_carry_decimal'
])

if validation_performance == 'yes':
    output_path = r'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/tests_Validation_performance_results.xlsx'
else:
    output_path = r'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/tests_results_addition.xlsx'

df.to_excel(output_path, index=False)
print("File 'tests_results_addition.xlsx' created.")
# Out:
# File 'tests_results_addition.xlsx' created.
