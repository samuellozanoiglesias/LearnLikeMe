# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_carry_over_dataset = eval(file.read())
    
# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)

    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None


def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None


# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z

def neural_network_2(params, x1, x2):
    T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2_perfect)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3_perfect) + jnp.dot(z2, v2_perfect)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4_perfect) + jnp.dot(z3, v3_perfect)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5_perfect) + jnp.dot(z4, v4_perfect)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6_perfect) + jnp.dot(z5, v5_perfect)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7_perfect) + jnp.dot(z6, v6_perfect)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8_perfect) + jnp.dot(z7, v7_perfect)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y
    
def neural_network_3(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_3(params, x1, x2, y):
    pred = neural_network_3(params, x1, x2)
    return jnp.mean((pred - y)**2)

# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss
    
@jax.jit
def update_params_3(params, x1, x2, y, lr):
    gradients = grad(loss_3)(params, x1, x2, y)
    step_loss = loss_3(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss
        
    elif stage == 3:
        params, step_loss = update_params_3(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count, carry_over_size, correct_carry_over_predictions_tested_count = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {carry_over_size}, {correct_carry_over_predictions_tested_count} tested with carry-over were predicted correctly in the current model.")      

    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)

    correct_predictions_count = 0
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 3:
        binary_pred = neural_network_3(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
def perfect_model():
    # R vectors of dimension (14,1)
    R2_perfect = np.zeros((14))
    R3_perfect = np.zeros((14))
    R4_perfect = np.zeros((14))
    R5_perfect = np.zeros((14))
    R6_perfect = np.zeros((14))
    R7_perfect = np.zeros((14))
    R8_perfect = np.zeros((14))
    
    for i in range(2):
        R2_perfect[7*i + 6] = 1
        R3_perfect[7*i + 5] = 1
        R4_perfect[7*i + 4] = 1
        R5_perfect[7*i + 3] = 1
        R6_perfect[7*i + 2] = 1
        R7_perfect[7*i + 1] = 1
        R8_perfect[7*i + 0] = 1
    
    # Scalar parameters v
    v2_perfect = 1/2
    v3_perfect = 1/2
    v4_perfect = 1/2
    v5_perfect = 1/2
    v6_perfect = 1/2
    v7_perfect = 1/2
    
    # Matrix T of dimension (28,7)
    T_perfect = np.zeros((14,8))
    for i in range(7):
        for j in range(2):
            T_perfect[7*j + i, i + 1] = 1
    
    # Parameter v
    v_perfect = 1/2
    
    original_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    trainable_model = [R2_perfect, R3_perfect, R4_perfect, R5_perfect, R6_perfect, R7_perfect, R8_perfect,
            v2_perfect, v3_perfect, v4_perfect, v5_perfect, v6_perfect, v7_perfect, 
            T_perfect, v_perfect] 
    return trainable_model, original_model

def generate_model_random(mean=0.5, std=1):
    R2 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the second bit
    R3 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R4 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R5 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R6 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R7 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    R8 = initialize_random_weights(mean, std, (14))  # 28 neurons that correctly calculate the carry for the third bit
    v2 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v3 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v4 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v5 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v6 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    v7 = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry for the third bit
    T = initialize_random_weights(mean, std, (14, 8))  # 196 neurons that allow performing the sum
    v = initialize_random_weights(mean, std)  # 1 neuron that calculates the contribution of the carry vector for all bits
    original_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    trainable_model = [R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v]
    return trainable_model, original_model
    
def generate_model_AP(epsilon_non_zeros = 0.01, epsilon_zeros = 0.01):   
    R2_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R3_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R4_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R5_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R6_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R7_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)
    R8_almost_perfect = np.zeros((14)) + epsilon_zeros * np.random.randint(-10, 10)

    for i in range(2):
        R2_almost_perfect[7*i + 6] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R3_almost_perfect[7*i + 5] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R4_almost_perfect[7*i + 4] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R5_almost_perfect[7*i + 3] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R6_almost_perfect[7*i + 2] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R7_almost_perfect[7*i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
        R8_almost_perfect[7*i + 0] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v2_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v3_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v4_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v5_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v6_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    v7_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)

    T_almost_perfect = np.zeros((14,8)) + epsilon_zeros * np.random.randint(-10, 10)
    
    for i in range(7):
        for j in range(2):
            T_almost_perfect[7*j + i, i + 1] = 1 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    v_almost_perfect = 1/2 + epsilon_non_zeros * np.random.randint(-10, 10)
    
    original_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    trainable_model = [R2_almost_perfect, R3_almost_perfect, R4_almost_perfect, R5_almost_perfect, R6_almost_perfect, R7_almost_perfect, R8_almost_perfect,
                      v2_almost_perfect, v3_almost_perfect, v4_almost_perfect, v5_almost_perfect, v6_almost_perfect, v7_almost_perfect,
                      T_almost_perfect, v_almost_perfect]
    return trainable_model, original_model

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stages/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
model = 'trainable_model_stage'
training_type = 'AP_0.05_0.05'

folder = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
folder_path = f'{folder}/Parameters/{training_type}'
date_pattern = r'trainable_model_stage_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

for filename in files:
    match = re.search(date_pattern, filename)
    if match:
        current_time = match.group(1)
    else:
        print('Error')
        break
    
    file_path = f"{folder_path}/{model}_{current_time}.pkl"
    with open(file_path, 'rb') as file:
        trainable_model = pickle.load(file)

    print(f'Loaded {model}_{current_time}.pkl')
    
    training_stages = 3
    trainings_needed = np.zeros(training_stages)    
    visualizer = 10
    lr_changer = 250
    stage_changer = 2500*3
    N = 500

    for stage in range(3,4):
        if stage == 3:
            trainable_model_stage_3 = [trainable_model[0], 
                                       trainable_model[1], 
                                       trainable_model[2], 
                                       trainable_model[3], 
                                       trainable_model[4], 
                                       trainable_model[5], 
                                       trainable_model[6], 
                                       trainable_model[7], 
                                       trainable_model[8], 
                                       trainable_model[9], 
                                       trainable_model[10],
                                       trainable_model[11],
                                       trainable_model[12],
                                       trainable_model[13],
                                       trainable_model[14]]
        
        save_dir = f"{folder}/Trained_models/No_stages/{training_type}/Stage_{stage}" 
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Stage_{stage}_results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
    
        try:
            test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
            final_loss = 1
            lr = 0.001
            level = -2
            response = "yes"
            while final_loss != 0:
                prev_model = globals()[f"{model}_{stage}"]
                globals()[f"{model}_{stage}"], final_loss = train_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage, level=level, lr=lr, epochs=N)
                trainings_needed[stage-1] += 1
                if math.isnan(final_loss):
                    globals()[f"{model}_{stage}"] = prev_model
                    print('Loss is NaN.')
                    break                
                if trainings_needed[stage-1] % visualizer == 0:
                    if response.lower() == "yes":
                        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params=globals()[f"{model}_{stage}"], stage=stage)
                        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
                        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
                    elif response.lower() == "no":
                        print(f"STAGE {stage}: Objective completed, all are predicted correctly in the current model.")
                    print(f"STAGE {stage}: Loss is {final_loss}.")
                #if trainings_needed[stage-1] % lr_changer == 0:
                #    new_lr = input(f"Change of learning rate? (Current one is {lr}, press enter if not): ")
                #    if new_lr != "":
                #        lr = float(new_lr)
                if trainings_needed[stage-1] % stage_changer == 0:
                    response_pre = 'yes'
                    if response_pre.lower() == "yes":
                        break
                if correct_predictions_trained_count == train_size:
                    response = "yes"
                    while response.lower() not in ["yes", "no"]:
                        response = input("Objective completed, skip to next stage? (yes/no): ")
                        if response.lower() not in ["yes", "no"]:
                            print('Incorrect answer')        
                    if response.lower() == "yes":
                        print('Objective completed')
                        break
                    elif response.lower() == "no":
                        train_size = correct_predictions_trained_count + 1
    
            print(f'Stage {stage} completed in {trainings_needed[stage-1]} trainings.')
            save_response = 'yes'
            if save_response.lower() == 'yes':
                save_path = os.path.join(save_dir, f"trainable_model_stage_{stage}-{current_time}.pkl")
                with open(save_path, 'wb') as f:
                    pickle.dump(globals()[f"{model}_{stage}"], f)
                print(f"Model trainable_model_stage_{stage} saved at {save_path}")

        finally:
            sys.stdout = tee.console
            tee.close()
        print(f"Results of Stage {stage} saved in {results_file}")
# Out:
# Loaded trainable_model_stage_2024_11_20_11_29_20.pkl
# Loss is NaN.
# Stage 3 completed in 1.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/No_stages/AP_0.05_0.05/Stage_3\trainable_model_stage_3-2024_11_20_11_29_20.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/No_stages/AP_0.05_0.05/Stage_3\Stage_3_results_2024_11_20_11_29_20.txt
# Loaded trainable_model_stage_2024_11_20_11_29_22.pkl
# STAGE 3: Out of 8000, 1932 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 510 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.1426369994878769.
# STAGE 3: Out of 8000, 2647 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 660 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.12397978454828262.
# STAGE 3: Out of 8000, 3262 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 810 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.10575487464666367.
# STAGE 3: Out of 8000, 3631 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 888 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09937003254890442.
# STAGE 3: Out of 8000, 4042 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 986 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09406919032335281.
# STAGE 3: Out of 8000, 4704 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1157 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08881468325853348.
# STAGE 3: Out of 8000, 5182 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1293 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08256477117538452.
# STAGE 3: Out of 8000, 5458 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1354 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07780494540929794.
# STAGE 3: Out of 8000, 5383 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1329 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08040527999401093.
# STAGE 3: Out of 8000, 5280 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1315 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0757252499461174.
# STAGE 3: Out of 8000, 5607 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1386 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07502497732639313.
# STAGE 3: Out of 8000, 5689 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1408 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0748421847820282.
# STAGE 3: Out of 8000, 5719 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1415 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08211398869752884.
# STAGE 3: Out of 8000, 5429 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1368 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08058872818946838.
# STAGE 3: Out of 8000, 5681 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1414 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07139122486114502.
# STAGE 3: Out of 8000, 5749 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1420 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07496320456266403.
# STAGE 3: Out of 8000, 5682 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1408 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0765908882021904.
# STAGE 3: Out of 8000, 5767 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1425 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07114969938993454.
# STAGE 3: Out of 8000, 5538 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1403 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07508422434329987.
# STAGE 3: Out of 8000, 5737 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1402 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07238960266113281.
# STAGE 3: Out of 8000, 5843 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1460 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06992803514003754.
# STAGE 3: Out of 8000, 5821 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1448 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07397142797708511.
# STAGE 3: Out of 8000, 5810 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1446 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07104727625846863.
# STAGE 3: Out of 8000, 5907 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1473 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06695333868265152.
# STAGE 3: Out of 8000, 5807 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1440 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07504068315029144.
# STAGE 3: Out of 8000, 5936 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1472 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06998883932828903.
# STAGE 3: Out of 8000, 5816 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1444 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0708606094121933.
# STAGE 3: Out of 8000, 5949 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1477 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07154175639152527.
# STAGE 3: Out of 8000, 5879 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1468 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06822501868009567.
# STAGE 3: Out of 8000, 5935 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1465 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0738002210855484.
# STAGE 3: Out of 8000, 5968 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1478 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0678272694349289.
# STAGE 3: Out of 8000, 5987 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1468 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07120048254728317.
# STAGE 3: Out of 8000, 5936 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1469 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07148844748735428.
# STAGE 3: Out of 8000, 5975 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1484 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07043270766735077.
# STAGE 3: Out of 8000, 5977 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1477 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0679960548877716.
# STAGE 3: Out of 8000, 6012 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0708092525601387.
# STAGE 3: Out of 8000, 5942 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1472 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06616897881031036.
# STAGE 3: Out of 8000, 5979 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1483 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06168937683105469.
# STAGE 3: Out of 8000, 5911 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1466 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07071668654680252.
# STAGE 3: Out of 8000, 5985 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06811695545911789.
# STAGE 3: Out of 8000, 6019 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06738686561584473.
# STAGE 3: Out of 8000, 6008 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07364819198846817.
# STAGE 3: Out of 8000, 6045 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07279134541749954.
# STAGE 3: Out of 8000, 5989 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1494 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07606653869152069.
# STAGE 3: Out of 8000, 6053 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1494 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07048959285020828.
# STAGE 3: Out of 8000, 6014 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06861671805381775.
# STAGE 3: Out of 8000, 6038 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1487 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06761034578084946.
# STAGE 3: Out of 8000, 6039 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1515 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06888432800769806.
# STAGE 3: Out of 8000, 6073 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1519 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06733634322881699.
# STAGE 3: Out of 8000, 6035 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1507 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06720176339149475.
# STAGE 3: Out of 8000, 6006 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1482 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06870350241661072.
# STAGE 3: Out of 8000, 6034 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1493 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06661210209131241.
# STAGE 3: Out of 8000, 6017 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1497 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07126326858997345.
# STAGE 3: Out of 8000, 6042 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1504 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0686311349272728.
# STAGE 3: Out of 8000, 6032 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1483 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06737089902162552.
# STAGE 3: Out of 8000, 6048 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06834156066179276.
# STAGE 3: Out of 8000, 5873 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1460 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06865498423576355.
# STAGE 3: Out of 8000, 6024 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1500 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06572829931974411.
# STAGE 3: Out of 8000, 6030 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0697367787361145.
# STAGE 3: Out of 8000, 6051 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1496 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0677885115146637.
# STAGE 3: Out of 8000, 6014 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06814146786928177.
# STAGE 3: Out of 8000, 6024 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1494 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06786664575338364.
# STAGE 3: Out of 8000, 5985 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1473 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07095737010240555.
# STAGE 3: Out of 8000, 6036 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1486 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06675752997398376.
# STAGE 3: Out of 8000, 6057 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06601579487323761.
# STAGE 3: Out of 8000, 6039 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1493 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06832851469516754.
# STAGE 3: Out of 8000, 6013 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06884811818599701.
# STAGE 3: Out of 8000, 6014 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1486 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06650714576244354.
# STAGE 3: Out of 8000, 6026 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06983562558889389.
# STAGE 3: Out of 8000, 6042 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06916946172714233.
# STAGE 3: Out of 8000, 6077 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1503 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07044538110494614.
# STAGE 3: Out of 8000, 6068 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1506 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06973635405302048.
# STAGE 3: Out of 8000, 6019 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1484 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0649130791425705.
# STAGE 3: Out of 8000, 6015 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1476 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06537770479917526.
# STAGE 3: Out of 8000, 5956 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1470 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06612017750740051.
# STAGE 3: Out of 8000, 6069 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1496 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06718221306800842.
# STAGE 3: Out of 8000, 5978 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1477 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06979793310165405.
# STAGE 3: Out of 8000, 5992 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1472 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06880790740251541.
# STAGE 3: Out of 8000, 5969 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0680772066116333.
# STAGE 3: Out of 8000, 6014 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0701625645160675.
# STAGE 3: Out of 8000, 6051 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06474646180868149.
# STAGE 3: Out of 8000, 6052 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1493 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0671607032418251.
# STAGE 3: Out of 8000, 6059 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1497 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06763458997011185.
# STAGE 3: Out of 8000, 6030 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06293635070323944.
# STAGE 3: Out of 8000, 6026 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07380099594593048.
# STAGE 3: Out of 8000, 5995 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1476 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06777096539735794.
# STAGE 3: Out of 8000, 6067 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1496 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06483923643827438.
# STAGE 3: Out of 8000, 5876 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1462 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06493646651506424.
# STAGE 3: Out of 8000, 6002 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1477 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06635140627622604.
# STAGE 3: Out of 8000, 6015 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1494 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06376174092292786.
# STAGE 3: Out of 8000, 6003 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1474 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06552664190530777.
# STAGE 3: Out of 8000, 5974 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1471 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06352312862873077.
# STAGE 3: Out of 8000, 6006 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0670468658208847.
# STAGE 3: Out of 8000, 5976 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1479 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06711920350790024.
# STAGE 3: Out of 8000, 6051 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1486 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06533519178628922.
# STAGE 3: Out of 8000, 6014 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06756657361984253.
# STAGE 3: Out of 8000, 6076 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1500 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06627284735441208.
# STAGE 3: Out of 8000, 6011 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06909666955471039.
# STAGE 3: Out of 8000, 6073 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1502 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06384864449501038.
# STAGE 3: Out of 8000, 6023 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1502 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06959298253059387.
# STAGE 3: Out of 8000, 6021 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06795181334018707.
# STAGE 3: Out of 8000, 6026 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1487 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06984928995370865.
# STAGE 3: Out of 8000, 6102 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1505 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0670633465051651.
# STAGE 3: Out of 8000, 5982 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1483 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06576556712388992.
# STAGE 3: Out of 8000, 6033 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1499 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06828219443559647.
# STAGE 3: Out of 8000, 6088 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1506 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06159793585538864.
# STAGE 3: Out of 8000, 6077 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1506 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06507821381092072.
# STAGE 3: Out of 8000, 6041 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06976667046546936.
# STAGE 3: Out of 8000, 6090 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1523 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06434167921543121.
# STAGE 3: Out of 8000, 6049 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1480 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06538862735033035.
# STAGE 3: Out of 8000, 6014 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06522863358259201.
# STAGE 3: Out of 8000, 6024 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1499 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06623979657888412.
# STAGE 3: Out of 8000, 5975 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1480 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06417413055896759.
# STAGE 3: Out of 8000, 6062 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1510 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06509851664304733.
# STAGE 3: Out of 8000, 5962 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1467 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06501693278551102.
# STAGE 3: Out of 8000, 6047 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06700214743614197.
# STAGE 3: Out of 8000, 5993 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1484 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06379501521587372.
# STAGE 3: Out of 8000, 6087 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1504 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06638815999031067.
# STAGE 3: Out of 8000, 6105 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1504 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06870483607053757.
# STAGE 3: Out of 8000, 5961 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1478 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06360691785812378.
# STAGE 3: Out of 8000, 6046 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1487 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06406347453594208.
# STAGE 3: Out of 8000, 5964 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1479 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0697651281952858.
# STAGE 3: Out of 8000, 6097 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1494 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06503546983003616.
# STAGE 3: Out of 8000, 6043 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.061045803129673004.
# STAGE 3: Out of 8000, 5847 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1458 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0664791613817215.
# STAGE 3: Out of 8000, 6023 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06866569072008133.
# STAGE 3: Out of 8000, 6037 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06311535090208054.
# STAGE 3: Out of 8000, 6065 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06635188311338425.
# STAGE 3: Out of 8000, 6106 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1504 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06837225705385208.
# STAGE 3: Out of 8000, 6065 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06496033817529678.
# STAGE 3: Out of 8000, 6022 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1486 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06348149478435516.
# STAGE 3: Out of 8000, 6043 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06128764897584915.
# STAGE 3: Out of 8000, 6034 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1488 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06766435503959656.
# STAGE 3: Out of 8000, 5969 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1469 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06287052482366562.
# STAGE 3: Out of 8000, 6013 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1473 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06269369274377823.
# STAGE 3: Out of 8000, 6035 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1475 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06290922313928604.
# STAGE 3: Out of 8000, 6042 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1484 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06250299513339996.
# STAGE 3: Out of 8000, 6056 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1498 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06248198822140694.
# STAGE 3: Out of 8000, 6101 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1504 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06456290185451508.
# STAGE 3: Out of 8000, 6062 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1498 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06586848944425583.
# STAGE 3: Out of 8000, 6036 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1496 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06881830841302872.
# STAGE 3: Out of 8000, 6069 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1499 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0676586851477623.
# STAGE 3: Out of 8000, 6048 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1472 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06710469722747803.
# STAGE 3: Out of 8000, 6036 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06587148457765579.
# STAGE 3: Out of 8000, 6058 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06684565544128418.
# STAGE 3: Out of 8000, 5987 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1470 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06484944373369217.
# STAGE 3: Out of 8000, 6032 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06608032435178757.
# STAGE 3: Out of 8000, 6037 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1483 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06374181061983109.
# STAGE 3: Out of 8000, 6078 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06211056932806969.
# STAGE 3: Out of 8000, 6007 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1484 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0634499043226242.
# STAGE 3: Out of 8000, 6045 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1500 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06549829244613647.
# STAGE 3: Out of 8000, 6008 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1481 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06244761496782303.
# STAGE 3: Out of 8000, 5995 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1473 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06806351989507675.
# STAGE 3: Out of 8000, 6083 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1500 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06674646586179733.
# STAGE 3: Out of 8000, 6068 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1499 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06741215288639069.
# STAGE 3: Out of 8000, 6078 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1496 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0642283633351326.
# STAGE 3: Out of 8000, 5984 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1474 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06655476242303848.
# STAGE 3: Out of 8000, 6073 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06875953078269958.
# STAGE 3: Out of 8000, 6017 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1478 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06502794474363327.
# STAGE 3: Out of 8000, 5969 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1475 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06305724382400513.
# STAGE 3: Out of 8000, 5943 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1459 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06873763352632523.
# STAGE 3: Out of 8000, 6023 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06368836760520935.
# STAGE 3: Out of 8000, 6075 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06476739048957825.
# STAGE 3: Out of 8000, 6030 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1481 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0655260682106018.
# STAGE 3: Out of 8000, 6014 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1476 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06890607625246048.
# STAGE 3: Out of 8000, 6005 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1478 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0659770593047142.
# STAGE 3: Out of 8000, 6059 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1494 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06681065261363983.
# STAGE 3: Out of 8000, 6080 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1487 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06548143178224564.
# STAGE 3: Out of 8000, 6062 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1481 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06422329694032669.
# STAGE 3: Out of 8000, 6081 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1497 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06611502170562744.
# STAGE 3: Out of 8000, 6038 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06428041309118271.
# STAGE 3: Out of 8000, 6031 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06391561031341553.
# STAGE 3: Out of 8000, 6046 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1484 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06296595185995102.
# STAGE 3: Out of 8000, 6100 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1496 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06339563429355621.
# STAGE 3: Out of 8000, 6034 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1473 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06673450767993927.
# STAGE 3: Out of 8000, 6035 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1483 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06408311426639557.
# STAGE 3: Out of 8000, 6066 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.07022392004728317.
# STAGE 3: Out of 8000, 6036 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1482 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06155281141400337.
# STAGE 3: Out of 8000, 6086 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06359220296144485.
# STAGE 3: Out of 8000, 5940 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1462 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06762762367725372.
# STAGE 3: Out of 8000, 6053 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1493 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06379079818725586.
# STAGE 3: Out of 8000, 6050 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1493 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06474006175994873.
# STAGE 3: Out of 8000, 6064 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1487 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0649818629026413.
# STAGE 3: Out of 8000, 6065 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06672099977731705.
# STAGE 3: Out of 8000, 6066 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1484 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06528180837631226.
# STAGE 3: Out of 8000, 6017 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1486 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06337730586528778.
# STAGE 3: Out of 8000, 6076 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06826108694076538.
# STAGE 3: Out of 8000, 6071 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06455810368061066.
# STAGE 3: Out of 8000, 6081 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06390270590782166.
# STAGE 3: Out of 8000, 6005 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1481 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06719774752855301.
# STAGE 3: Out of 8000, 6043 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1476 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0632447600364685.
# STAGE 3: Out of 8000, 6056 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1482 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0632801279425621.
# STAGE 3: Out of 8000, 6066 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1501 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0647495687007904.
# STAGE 3: Out of 8000, 6076 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1499 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06454043090343475.
# STAGE 3: Out of 8000, 6084 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06546102464199066.
# STAGE 3: Out of 8000, 6003 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1464 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06508056074380875.
# STAGE 3: Out of 8000, 6063 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06470607966184616.
# STAGE 3: Out of 8000, 5968 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1461 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06552544236183167.
# STAGE 3: Out of 8000, 6012 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06285946071147919.
# STAGE 3: Out of 8000, 6041 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06444371491670609.
# STAGE 3: Out of 8000, 6090 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1496 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06952562183141708.
# STAGE 3: Out of 8000, 6050 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06700116395950317.
# STAGE 3: Out of 8000, 5919 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1443 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06751982867717743.
# STAGE 3: Out of 8000, 6039 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06761484593153.
# STAGE 3: Out of 8000, 6074 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06341055780649185.
# STAGE 3: Out of 8000, 6016 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1482 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06210027635097504.
# STAGE 3: Out of 8000, 6087 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1489 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06575607508420944.
# STAGE 3: Out of 8000, 6042 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06581158190965652.
# STAGE 3: Out of 8000, 6044 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06497712433338165.
# STAGE 3: Out of 8000, 6053 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1486 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06744430959224701.
# STAGE 3: Out of 8000, 5999 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1478 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06217547878623009.
# STAGE 3: Out of 8000, 6057 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06808873265981674.
# STAGE 3: Out of 8000, 6088 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06681288033723831.
# STAGE 3: Out of 8000, 6089 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1503 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06560471653938293.
# STAGE 3: Out of 8000, 5836 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1443 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06429748982191086.
# STAGE 3: Out of 8000, 6011 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1477 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06564489752054214.
# STAGE 3: Out of 8000, 6017 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1468 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06487298756837845.
# STAGE 3: Out of 8000, 5933 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1442 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06494495272636414.
# STAGE 3: Out of 8000, 6077 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1485 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0667584165930748.
# STAGE 3: Out of 8000, 6072 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1501 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06377732008695602.
# STAGE 3: Out of 8000, 6041 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1491 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06541892886161804.
# STAGE 3: Out of 8000, 6049 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06378677487373352.
# STAGE 3: Out of 8000, 6030 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1488 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06479617953300476.
# STAGE 3: Out of 8000, 6046 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06089209392666817.
# STAGE 3: Out of 8000, 5933 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1457 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06249362230300903.
# STAGE 3: Out of 8000, 6027 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1500 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.060175664722919464.
# STAGE 3: Out of 8000, 6033 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1494 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06037912517786026.
# STAGE 3: Out of 8000, 6039 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1490 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06470832973718643.
# STAGE 3: Out of 8000, 6074 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1500 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06634722650051117.
# STAGE 3: Out of 8000, 6028 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1495 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06533753126859665.
# STAGE 3: Out of 8000, 6005 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1471 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06586700677871704.
# STAGE 3: Out of 8000, 6048 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1475 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06801534444093704.
# STAGE 3: Out of 8000, 5991 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1472 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06250489503145218.
# STAGE 3: Out of 8000, 6093 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1492 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06450971961021423.
# STAGE 3: Out of 8000, 5976 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1451 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.06526508182287216.
# STAGE 3: Out of 8000, 6036 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1483 tested were predicted correctly in the current model.
# ...
# STAGE 3: Loss is 0.09656112641096115.
# STAGE 3: Out of 8000, 4469 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1133 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09627652168273926.
# STAGE 3: Out of 8000, 4561 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1145 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09237810224294662.
# STAGE 3: Out of 8000, 4316 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1078 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08802582323551178.
# STAGE 3: Out of 8000, 4318 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1100 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08906393498182297.
# STAGE 3: Out of 8000, 4262 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1063 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09328950941562653.
# STAGE 3: Out of 8000, 4549 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1129 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09191521257162094.
# STAGE 3: Out of 8000, 4506 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1139 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09690123796463013.
# STAGE 3: Out of 8000, 4465 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1128 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0898212343454361.
# STAGE 3: Out of 8000, 4577 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1155 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08234391361474991.
# STAGE 3: Out of 8000, 4453 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1111 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09063699841499329.
# STAGE 3: Out of 8000, 4098 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09847191721200943.
# STAGE 3: Out of 8000, 4364 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1100 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09087464213371277.
# STAGE 3: Out of 8000, 4277 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1065 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0928114578127861.
# STAGE 3: Out of 8000, 4605 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1144 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0934111699461937.
# STAGE 3: Out of 8000, 4390 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1108 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08885295689105988.
# STAGE 3: Out of 8000, 4332 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1098 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0937357097864151.
# STAGE 3: Out of 8000, 4265 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1071 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08815599977970123.
# STAGE 3: Out of 8000, 4369 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1104 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0915750116109848.
# STAGE 3: Out of 8000, 4510 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1127 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08369384706020355.
# STAGE 3: Out of 8000, 4522 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1132 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.10096119344234467.
# STAGE 3: Out of 8000, 4129 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1022 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09350793808698654.
# STAGE 3: Out of 8000, 4445 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1135 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09894350916147232.
# STAGE 3: Out of 8000, 4560 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1158 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09018902480602264.
# STAGE 3: Out of 8000, 4571 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1165 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09702718257904053.
# STAGE 3: Out of 8000, 4564 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1167 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0884624496102333.
# STAGE 3: Out of 8000, 4464 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1135 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09817254543304443.
# STAGE 3: Out of 8000, 4547 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1143 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09600334614515305.
# STAGE 3: Out of 8000, 4449 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1127 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09294137358665466.
# STAGE 3: Out of 8000, 4429 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1130 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09776147454977036.
# STAGE 3: Out of 8000, 4247 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1075 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.095863938331604.
# STAGE 3: Out of 8000, 4522 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1145 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.10630907863378525.
# STAGE 3: Out of 8000, 4003 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1028 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09327592700719833.
# STAGE 3: Out of 8000, 4242 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1088 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09056795388460159.
# STAGE 3: Out of 8000, 4320 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1101 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.10485392063856125.
# STAGE 3: Out of 8000, 4586 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1149 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0851118266582489.
# STAGE 3: Out of 8000, 4436 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1134 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09601864218711853.
# STAGE 3: Out of 8000, 4391 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1110 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08294033259153366.
# STAGE 3: Out of 8000, 4508 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1150 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09600609540939331.
# STAGE 3: Out of 8000, 4574 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1144 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09114466607570648.
# STAGE 3: Out of 8000, 4522 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1146 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0952950119972229.
# STAGE 3: Out of 8000, 4440 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1129 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09030319005250931.
# STAGE 3: Out of 8000, 4467 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1153 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09521522372961044.
# STAGE 3: Out of 8000, 4320 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1105 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.089980348944664.
# STAGE 3: Out of 8000, 4382 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1111 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09715979546308517.
# STAGE 3: Out of 8000, 4413 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1113 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09716177731752396.
# STAGE 3: Out of 8000, 4085 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09511226415634155.
# STAGE 3: Out of 8000, 4537 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1140 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0942816361784935.
# STAGE 3: Out of 8000, 4102 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1062 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0906897485256195.
# STAGE 3: Out of 8000, 4486 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1136 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09499861299991608.
# STAGE 3: Out of 8000, 4473 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1123 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09179060161113739.
# STAGE 3: Out of 8000, 4137 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1053 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.10050614178180695.
# STAGE 3: Out of 8000, 4466 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1127 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09706228226423264.
# STAGE 3: Out of 8000, 4578 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1160 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09205475449562073.
# STAGE 3: Out of 8000, 4495 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1152 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0941123440861702.
# STAGE 3: Out of 8000, 4270 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1061 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09626606106758118.
# STAGE 3: Out of 8000, 4068 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1045 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09527840465307236.
# STAGE 3: Out of 8000, 4442 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1134 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.095486581325531.
# STAGE 3: Out of 8000, 4532 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1150 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0915188193321228.
# STAGE 3: Out of 8000, 4559 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1154 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.08998118340969086.
# STAGE 3: Out of 8000, 4509 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1137 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09923163056373596.
# STAGE 3: Out of 8000, 4487 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1144 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09709436446428299.
# STAGE 3: Out of 8000, 4253 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1047 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09375939518213272.
# STAGE 3: Out of 8000, 4071 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1009 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09333033859729767.
# STAGE 3: Out of 8000, 4469 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1113 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09524885565042496.
# STAGE 3: Out of 8000, 4327 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1102 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09386958926916122.
# STAGE 3: Out of 8000, 4393 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1120 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09170792251825333.
# STAGE 3: Out of 8000, 4545 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1158 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09036426991224289.
# STAGE 3: Out of 8000, 4371 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1118 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0903567224740982.
# STAGE 3: Out of 8000, 4502 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1118 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09168653935194016.
# STAGE 3: Out of 8000, 4525 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1148 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09270741790533066.
# STAGE 3: Out of 8000, 3835 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 959 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.0872943103313446.
# STAGE 3: Out of 8000, 4472 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1145 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09539252519607544.
# STAGE 3: Out of 8000, 4384 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1083 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09252314269542694.
# STAGE 3: Out of 8000, 4065 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1003 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09368543326854706.
# STAGE 3: Out of 8000, 4507 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1141 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09386613965034485.
# STAGE 3: Out of 8000, 4483 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1113 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.091764435172081.
# STAGE 3: Out of 8000, 4404 trained were predicted correctly in the current model.
# STAGE 3: Out of 2000, 1103 tested were predicted correctly in the current model.
# STAGE 3: Loss is 0.09118682891130447.
# Stage 3 completed in 7500.0 trainings.
# Model trainable_model_stage_3 saved at D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/No_stages/AP_0.05_0.05/Stage_3\trainable_model_stage_3-2024_11_20_11_29_38.pkl
# Results of Stage 3 saved in D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/No_stages/AP_0.05_0.05/Stage_3\Stage_3_results_2024_11_20_11_29_38.txt
