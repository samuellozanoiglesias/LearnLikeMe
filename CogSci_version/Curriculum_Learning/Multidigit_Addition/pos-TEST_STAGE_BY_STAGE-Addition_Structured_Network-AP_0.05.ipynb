# %%
import pandas as pd
import numpy as np
import math

import jax
import jax.numpy as jnp
from jax import random, grad
from jax.nn import relu, sigmoid
from functools import partial

import matplotlib.pyplot as plt

import re
import time
import pytz
import os
import random
import sys
import pickle
from datetime import datetime

# %%
def initialize_random_weights(mean, std, shape = ()):
    return np.random.normal(loc=mean, scale=std, size=shape)

# We use a sinusoidal function to approximate odd numbers by their immediately preceding even number and preserve differentiability
def lower_even(x):
    return x - 0.5 * (1 - jnp.cos(jnp.pi * x))

# We use a sinusoidal function to approximate 0 for evens and 1 for odds while preserving differentiability
def differentiable_even_or_odd(x):
    return ((2 * x ** 3) / 3) - 3 * x ** 2 + ((10 * x) / 3)

folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'

# Cargar las parejas desde el archivo
with open(f"{folder}/train_couples.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/real_test_dataset.txt", 'r') as file:
    real_test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_small_problem_size_binary.txt", 'r') as file:
    combinations_small_problem_size_binary = eval(file.read())

with open(f"{folder}/combinations_with_carry_over_decimal.txt", 'r') as file:
    combinations_with_carry_over_decimal = eval(file.read())

with open(f"{folder}/real_test_dataset_small_problem_size.txt", 'r') as file:
    real_test_dataset_small_problem_size = eval(file.read())

with open(f"{folder}/real_test_dataset_small_problem_size_binary.txt", 'r') as file:
    real_test_dataset_small_problem_size_binary = eval(file.read())

with open(f"{folder}/real_test_dataset_with_carry_over.txt", 'r') as file:
    real_test_dataset_with_carry_over = eval(file.read())

with open(f"{folder}/real_test_dataset_with_carry_over_decimal.txt", 'r') as file:
    real_test_dataset_with_carry_over_decimal = eval(file.read())
    

# Separar parejas con y sin ceros
train_without_zeros = [pair for pair in train_couples if 0 not in pair]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_carry_over_decimal = [pair for pair in train_couples if pair in combinations_with_carry_over_decimal]

# Function to generate dataset with multiplication
def generate_dataset_with_zeros(size):
    # Seleccionar aleatoriamente parejas con ceros
    selected_pairs = random.choices(train_couples, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
    return dataset

def generate_dataset_without_zeros(size):
    # Seleccionar aleatoriamente parejas sin ceros
    selected_pairs = random.choices(train_without_zeros, k=size)
    
    # Separar las columnas de las parejas seleccionadas
    column_1 = [pair[0] for pair in selected_pairs]
    column_2 = [pair[1] for pair in selected_pairs]

    # Crear el DataFrame
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2
    })

    # Crear la tercera columna sumando las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_test_dataset(n_max=100):
    # Create the columns
    column_1 = list(range(n_max)) * n_max  # Numbers from 0 to 9 repeated 10 times
    column_2 = [i for i in range(n_max) for _ in range(n_max)]  # Numbers from 0 to 9 repeated sequentially 10 times

    # Create a DataFrame with the two columns
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Create the third column by multiplying the first two
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def generate_real_test_dataset():
    # Desempaquetar las parejas (a_i, b_i)
    column_1, column_2 = zip(*real_test_dataset)
    #column_1, column_2 = zip(*test_dataset)
    
    # Crear un DataFrame con las dos primeras columnas
    dataset = pd.DataFrame({
        'Column_1': column_1,
        'Column_2': column_2,
    })

    # Crear la tercera columna como la suma de las dos primeras
    dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']

    return dataset

def decimal_to_binary(n, bits):
    if 0 <= n < 2**bits:
        # Convert the number to a binary string and then to an array of integers (0 and 1)
        return np.array(list(format(n, f'0{bits}b'))).astype(np.int8)
    else:
        raise ValueError("Number out of range")

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector, bits):
    # Ensure the vector has the correct number of elements
    if len(binary_vector) != bits:
        raise ValueError(f"The vector must have exactly {bits} elements.")

    # Calculate the decimal number
    decimal = 0
    for i in range(bits):
        decimal += binary_vector[i] * (2 ** (bits - 1 - i))

    return decimal

def transform_to_tridimensional_matrix(dataset, bits_init=7, bits_end=8):
    rows, cols = dataset.shape
    if cols != 3:
        raise ValueError("The dataset must have exactly 3 columns.")

    # Initialize the three matrices
    matrix_column_1 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_2 = np.zeros((rows, bits_init), dtype=np.int8)
    matrix_column_3 = np.zeros((rows, bits_end), dtype=np.int8)

    # Fill the matrices with the binary representation of each column
    for i in range(rows):
        matrix_column_1[i] = decimal_to_binary(dataset.iloc[i, 0], bits_init)
        matrix_column_2[i] = decimal_to_binary(dataset.iloc[i, 1], bits_init)
        matrix_column_3[i] = decimal_to_binary(dataset.iloc[i, 2], bits_end)

    return matrix_column_1, matrix_column_2, matrix_column_3
    
def prepare_dataset(level, size=1, couples_included=[]):       
    if level == -3:
        column_1 = []
        column_2 = []
        pairs = couples_included
        while len(column_1) < size:
            choice = pairs[np.random.choice(len(pairs))]
            column_1.append(choice[0])
            column_2.append(choice[1])
        dataset = pd.DataFrame({'Column_1': column_1,'Column_2': column_2,})
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == -2:
        dataset = generate_dataset_with_zeros(size)
        return dataset
        
    elif level == -1:
        dataset = generate_dataset_without_zeros(size)
        return dataset

    elif level == 0:
        dataset = pd.DataFrame()
        while len(dataset) < size:
            column_1 = np.random.randint(1, 10, size)
            column_2 = np.random.randint(1, 10, size)
            temp_dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
            temp_dataset = temp_dataset[~temp_dataset[['Column_1', 'Column_2']].apply(tuple, axis=1).isin(combinations_with_carry_over)]
            dataset = pd.concat([dataset, temp_dataset])
        dataset = dataset.iloc[:size].reset_index(drop=True)
        dataset['Column_3'] = dataset['Column_1'] * dataset['Column_2']
        return dataset

    elif level == 1:
        pairs = random.choices(train_with_carry_over, k=size)
        column_1 = [pair[0] for pair in pairs]
        column_2 = [pair[1] for pair in pairs]
        dataset = pd.DataFrame({'Column_1': column_1, 'Column_2': column_2})
        dataset['Column_3'] = dataset['Column_1'] + dataset['Column_2']
        return dataset

    else:
        print('Bad index for the training stage.')
        return None

def prepare_outputs(stage, x1, x2, outputs_prev):
    if stage == 1:
        outputs = []
        for vec1, vec2 in zip(x1, x2):
            z2 = lower_even(vec1[6] + vec2[6])
            z3 = lower_even(vec1[5] + vec2[5] + z2 * 1/2)
            z4 = lower_even(vec1[4] + vec2[4] + z3 * 1/2)
            z5 = lower_even(vec1[3] + vec2[3] + z4 * 1/2)
            z6 = lower_even(vec1[2] + vec2[2] + z5 * 1/2)
            z7 = lower_even(vec1[1] + vec2[1] + z6 * 1/2)
            z8 = lower_even(vec1[0] + vec2[0] + z7 * 1/2)
            outputs.append([z8, z7, z6, z5, z4, z3, z2, 0])
        return np.array(outputs)

    elif stage == 2:
        return outputs_prev
        
    elif stage == 3:
        return outputs_prev

    else:
        print('Bad index for the training stage.')
        return None

# Perfect parameters needed for the stages where a part of the NN performs perfectly
# R vectors of dimension (14,1)
R2_perfect = np.zeros((14))
R3_perfect = np.zeros((14))
R4_perfect = np.zeros((14))
R5_perfect = np.zeros((14))
R6_perfect = np.zeros((14))
R7_perfect = np.zeros((14))
R8_perfect = np.zeros((14))

for i in range(2):
    R2_perfect[7*i + 6] = 1
    R3_perfect[7*i + 5] = 1
    R4_perfect[7*i + 4] = 1
    R5_perfect[7*i + 3] = 1
    R6_perfect[7*i + 2] = 1
    R7_perfect[7*i + 1] = 1
    R8_perfect[7*i + 0] = 1

# Scalar parameters v
v2_perfect = 1/2
v3_perfect = 1/2
v4_perfect = 1/2
v5_perfect = 1/2
v6_perfect = 1/2
v7_perfect = 1/2

# Matrix T of dimension (28,7)
T_perfect = np.zeros((14,8))
for i in range(7):
    for j in range(2):
        T_perfect[7*j + i, i + 1] = 1

# Parameter v
v_perfect = 1/2

# Neural network in every stage
def neural_network_1(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7 = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    #y = differentiable_even_or_odd(relu(jnp.dot(vec, T) + jnp.dot(z, v7)))
    return z
    
def neural_network_2(params, x1, x2):
    R2, R3, R4, R5, R6, R7, R8, v2, v3, v4, v5, v6, v7, T, v = params
    x = jnp.concatenate((x1, x2), axis=0)
    z2 = lower_even(jnp.dot(x, R2)) # z2 is a scalar with the first carry over
    z3 = lower_even(jnp.dot(x, R3) + jnp.dot(z2, v2)) # z3 is a scalar with the second carry over
    z4 = lower_even(jnp.dot(x, R4) + jnp.dot(z3, v3)) # z4 is a scalar with the third carry over
    z5 = lower_even(jnp.dot(x, R5) + jnp.dot(z4, v4)) # z5 is a scalar with the fourth carry over
    z6 = lower_even(jnp.dot(x, R6) + jnp.dot(z5, v5)) # z6 is a scalar with the fifth carry over
    z7 = lower_even(jnp.dot(x, R7) + jnp.dot(z6, v6)) # z7 is a scalar with the seventh carry over
    z8 = lower_even(jnp.dot(x, R8) + jnp.dot(z7, v7)) # z7 is a scalar with the seventh carry over
    z = jnp.array([z8, z7, z6, z5, z4, z3, z2, 0])
    y = differentiable_even_or_odd(jnp.dot(x, T) + jnp.dot(z, v))
    return y

# Loss functions in every stage
def loss_1(params, x1, x2, y):
    pred = neural_network_1(params, x1, x2)
    return jnp.mean((pred - y)**2)

def loss_2(params, x1, x2, y):
    pred = neural_network_2(params, x1, x2)
    return jnp.mean((pred - y)**2)
    
# Loss functions in every step
@jax.jit
def update_params_1(params, x1, x2, y, lr):
    gradients = grad(loss_1)(params, x1, x2, y)
    step_loss = loss_1(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

@jax.jit
def update_params_2(params, x1, x2, y, lr):
    gradients = grad(loss_2)(params, x1, x2, y)
    step_loss = loss_2(params, x1, x2, y)
    return [(p - lr * g) for p, g in zip(params, gradients)], step_loss

def decide_training(params, x1, x2, y, lr, stage):
    if stage == 1:
        params, step_loss = update_params_1(params, x1, x2, y, lr)
        return params, step_loss

    elif stage == 2:
        params, step_loss = update_params_2(params, x1, x2, y, lr)
        return params, step_loss

    else:
        print('Bad index for the training stage.')
        return None
        
# Main function to train the network
def train_stages_neural_network(params, stage, level, lr=0.01, epochs=100):
    decimal_dataset = prepare_dataset(level, epochs)
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    final_loss = 0
    # Train the network
    for epoch in range(epochs):
        # Update parameters at each step
        params, step_loss = decide_training(params, inputs_1[epoch], inputs_2[epoch], outputs[epoch], lr, stage)
        final_loss += step_loss

    final_loss = final_loss / epochs
    #print(f"Loss: {final_loss:.6f}")
    return params, final_loss



def decide_test(params, stage, real_test=0, visualize_errors=0):
    if real_test == 1:
        test_count, correct_predictions_test_count, train_count, correct_predictions_train_count, test_carry_over_count, correct_carry_over_predictions_test_count, train_carry_over_count, correct_carry_over_predictions_train_count, small_train_count, correct_predictions_small_train_count, small_test_count, correct_predictions_small_test_count, small_train_carry_count, correct_predictions_small_train_carry_count, small_test_carry_count, correct_predictions_small_test_carry_count, test_carry_over_decimal_count, correct_carry_over_decimal_predictions_test_count, train_carry_over_decimal_count, correct_carry_over_decimal_predictions_train_count, small_train_carry_decimal_count, correct_predictions_small_train_carry_decimal_count, small_test_carry_decimal_count, correct_predictions_small_test_carry_decimal_count, small_binary_train_count, correct_predictions_small_binary_train_count, small_binary_test_count, correct_predictions_small_binary_test_count, small_binary_train_carry_count, correct_predictions_small_binary_train_carry_count, small_binary_test_carry_count, correct_predictions_small_binary_test_carry_count, small_binary_train_carry_decimal_count, correct_predictions_small_binary_train_carry_decimal_count, small_binary_test_carry_decimal_count, correct_predictions_small_binary_test_carry_decimal_count, reaction_time_carry, reaction_time_carry_decimal, reaction_time_train,reaction_time_test, reaction_time_train_carry, reaction_time_train_carry_decimal, reaction_time_small_train, reaction_time_small_test, reaction_time_small_train_carry, reaction_time_small_test_carry, reaction_time_small_train_carry_decimal, reaction_time_small_test_carry_decimal, reaction_time_small_binary_train, reaction_time_small_binary_test, reaction_time_small_binary_train_carry, reaction_time_small_binary_test_carry, reaction_time_small_binary_train_carry_decimal, reaction_time_small_binary_test_carry_decimal = real_test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_count}, {correct_predictions_train_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_count}, {correct_predictions_test_count} tested were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_count}, {correct_carry_over_predictions_train_count} trained with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_count}, {correct_carry_over_predictions_test_count} tested with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_count}, {correct_predictions_small_train_count} trained with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_test_count}, {correct_predictions_small_test_count} tested with small problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_count}, {correct_predictions_small_train_carry_count} trained with small problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_count}, {correct_predictions_small_test_carry_count} tested with small problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {train_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_train_count} trained with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {test_carry_over_decimal_count}, {correct_carry_over_decimal_predictions_test_count} tested with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_train_carry_decimal_count}, {correct_predictions_small_train_carry_decimal_count} trained with small problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_test_carry_decimal_count}, {correct_predictions_small_test_carry_decimal_count} tested with small problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_count}, {correct_predictions_small_binary_train_count} trained with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_test_count}, {correct_predictions_small_binary_test_count} tested with small binary problem size were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_count}, {correct_predictions_small_binary_train_carry_count} trained with small binary problem size and with carry-over were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_count}, {correct_predictions_small_binary_test_carry_count} tested with small binary problem size and with carry-over were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {small_binary_train_carry_decimal_count}, {correct_predictions_small_binary_train_carry_decimal_count} trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.")      
        print(f"STAGE {stage}: Out of {small_binary_test_carry_decimal_count}, {correct_predictions_small_binary_test_carry_decimal_count} tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.")
        print(f"STAGE {stage}: {reaction_time_carry} reaction time with carry over.")
        print(f"STAGE {stage}: {reaction_time_carry_decimal} reaction time with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_train} reaction time for train.")
        print(f"STAGE {stage}: {reaction_time_test} reaction time for test.")
        print(f"STAGE {stage}: {reaction_time_train_carry} reaction time for train with carry over .")
        print(f"STAGE {stage}: {reaction_time_train_carry_decimal} reaction time for train with carry over decimal.")
        print(f"STAGE {stage}: {reaction_time_small_train} reaction time for train small.")
        print(f"STAGE {stage}: {reaction_time_small_test} reaction time for test small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry} reaction time for train with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry} reaction time for test with carry over and small.")
        print(f"STAGE {stage}: {reaction_time_small_train_carry_decimal} reaction time for train with carry over decimal and small.")
        print(f"STAGE {stage}: {reaction_time_small_test_carry_decimal} reaction time for test with carry over decimal and small.") 
        print(f"STAGE {stage}: {reaction_time_small_binary_train} reaction time for train small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test} reaction time for test small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry} reaction time for train with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry} reaction time for test with carry over and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_train_carry_decimal} reaction time for train with carry over decimal and small binary.")
        print(f"STAGE {stage}: {reaction_time_small_binary_test_carry_decimal} reaction time for test with carry over decimal and small binary.") 
            
    else: 
        test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count = test_stages_neural_network(params, stage, visualize_errors=0)
        print(f"STAGE {stage}: Out of {train_size}, {correct_predictions_trained_count} trained were predicted correctly in the current model.")
        print(f"STAGE {stage}: Out of {test_size}, {correct_predictions_tested_count} tested were predicted correctly in the current model.")
        

# Main function to test the network
def test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_test_dataset()
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_tested_count = 0
    correct_predictions_trained_count = 0  # Counter for trained couples
    set_size = inputs_1.shape[0]
    train_size = len(train_couples)
    test_size = set_size - train_size
    
    for i in range(set_size):
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        # Check if the prediction matches the expected output
        if jnp.all(prediction == outputs[i]):  
            if (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1]) in train_couples:
                correct_predictions_trained_count += 1  # Increment for trained couples
            else:
                correct_predictions_tested_count += 1 # Increment for tested couples
        elif visualize_errors == 1:
            print(f'{decimal_dataset.iloc[i, 0]} plus {decimal_dataset.iloc[i, 1]} has failed.')

    return test_size, correct_predictions_tested_count, train_size, correct_predictions_trained_count

def real_test_stages_neural_network(params, stage, visualize_errors=0):
    decimal_dataset = generate_real_test_dataset()    
    inputs_1, inputs_2, outputs_prev = transform_to_tridimensional_matrix(decimal_dataset)
    outputs = prepare_outputs(stage, inputs_1, inputs_2, outputs_prev)
    
    correct_predictions_test_count = 0
    correct_predictions_train_count = 0
    correct_carry_over_predictions_count = 0
    correct_carry_over_predictions_test_count = 0
    correct_carry_over_predictions_train_count = 0
    correct_predictions_small_train_count = 0
    correct_predictions_small_test_count = 0
    correct_predictions_small_train_carry_count = 0
    correct_predictions_small_test_carry_count = 0
    correct_carry_over_decimal_predictions_count = 0
    correct_carry_over_decimal_predictions_test_count = 0
    correct_carry_over_decimal_predictions_train_count = 0
    correct_predictions_small_train_carry_decimal_count = 0
    correct_predictions_small_test_carry_decimal_count = 0
    correct_predictions_small_binary_train_count = 0
    correct_predictions_small_binary_test_count = 0
    correct_predictions_small_binary_train_carry_count = 0
    correct_predictions_small_binary_test_carry_count = 0
    correct_predictions_small_binary_train_carry_decimal_count = 0
    correct_predictions_small_binary_test_carry_decimal_count = 0
    
    set_size = inputs_1.shape[0]
    train_count = len(train_couples)
    test_count = set_size - train_count
    carry_over_count = len(combinations_with_carry_over) 
    carry_over_decimal_count = len(combinations_with_carry_over_decimal) 
    train_carry_over_count = len(train_with_carry_over)
    test_carry_over_count = carry_over_count - train_carry_over_count
    small_count = len(combinations_small_problem_size)
    small_binary_count = len(combinations_small_problem_size_binary)
    train_carry_over_decimal_count = len(train_with_carry_over_decimal)
    test_carry_over_decimal_count = carry_over_decimal_count - train_carry_over_decimal_count

    # Contadores adicionales
    small_train_count = 0
    small_test_count = 0
    small_train_carry_count = 0
    small_test_carry_count = 0
    small_train_carry_decimal_count = 0
    small_test_carry_decimal_count = 0
    small_binary_train_count = 0
    small_binary_test_count = 0
    small_binary_train_carry_count = 0
    small_binary_test_carry_count = 0
    small_binary_train_carry_decimal_count = 0
    small_binary_test_carry_decimal_count = 0
    
    reaction_time_carry = 0
    reaction_time_carry_decimal = 0
    reaction_time_train = 0
    reaction_time_test = 0
    reaction_time_train_carry = 0
    reaction_time_train_carry_decimal = 0
    reaction_time_small_train = 0
    reaction_time_small_test = 0
    reaction_time_small_train_carry = 0
    reaction_time_small_test_carry = 0
    reaction_time_small_train_carry_decimal = 0
    reaction_time_small_test_carry_decimal = 0
    reaction_time_small_binary_train = 0
    reaction_time_small_binary_test = 0
    reaction_time_small_binary_train_carry = 0
    reaction_time_small_binary_test_carry = 0
    reaction_time_small_binary_train_carry_decimal = 0
    reaction_time_small_binary_test_carry_decimal = 0

    for i in range(set_size):
        pair = (decimal_dataset.iloc[i, 0], decimal_dataset.iloc[i, 1])

        start_time = time.perf_counter_ns()
        prediction, binary_pred = predict(params, inputs_1[i], inputs_2[i], stage)
        elapsed_time = time.perf_counter_ns() - start_time

        #is_small = pair in combinations_small_problem_size
        #is_small_binary = pair in combinations_small_problem_size_binary
        #is_train = pair in train_couples
        #is_carry = pair in combinations_with_carry_over
        #is_carry_decimal = pair in combinations_with_carry_over_decimal

        is_small = pair in real_test_dataset_small_problem_size
        is_small_binary = pair in real_test_dataset_small_problem_size_binary
        is_train = pair in train_couples
        is_carry = pair in real_test_dataset_with_carry_over
        is_carry_decimal = pair in real_test_dataset_with_carry_over_decimal

        # Actualizar tiempos de reacción y contadores totales
        if is_small:
            if is_train:
                small_train_count += 1
                reaction_time_small_train += elapsed_time
                if is_carry:
                    small_train_carry_count += 1
                    reaction_time_small_train_carry += elapsed_time
                if is_carry_decimal:
                    small_train_carry_decimal_count += 1
                    reaction_time_small_train_carry_decimal += elapsed_time
            else:
                small_test_count += 1
                reaction_time_small_test += elapsed_time
                if is_carry:
                    small_test_carry_count += 1
                    reaction_time_small_test_carry += elapsed_time
                if is_carry_decimal:
                    small_test_carry_decimal_count += 1
                    reaction_time_small_test_carry_decimal += elapsed_time

        # Actualizar tiempos de reacción y contadores totales
        if is_small_binary:
            if is_train:
                small_binary_train_count += 1
                reaction_time_small_binary_train += elapsed_time
                if is_carry:
                    small_binary_train_carry_count += 1
                    reaction_time_small_binary_train_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_train_carry_decimal_count += 1
                    reaction_time_small_binary_train_carry_decimal += elapsed_time
            else:
                small_binary_test_count += 1
                reaction_time_small_binary_test += elapsed_time
                if is_carry:
                    small_binary_test_carry_count += 1
                    reaction_time_small_binary_test_carry += elapsed_time
                if is_carry_decimal:
                    small_binary_test_carry_decimal_count += 1
                    reaction_time_small_binary_test_carry_decimal += elapsed_time

        if is_carry:
            reaction_time_carry += elapsed_time
        if is_carry_decimal:
            reaction_time_carry_decimal += elapsed_time
        if is_train:
            reaction_time_train += elapsed_time
        else:
            reaction_time_test += elapsed_time
        if is_train and is_carry:
            reaction_time_train_carry += elapsed_time
        if is_train and is_carry_decimal:
            reaction_time_train_carry_decimal += elapsed_time

        # Contar predicciones correctas
        if jnp.all(prediction == outputs[i]):
            if is_small:
                if is_train:
                    correct_predictions_small_train_count += 1
                    if is_carry:
                        correct_predictions_small_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_test_count += 1
                    if is_carry:
                        correct_predictions_small_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_test_carry_decimal_count += 1

            if is_small_binary:
                if is_train:
                    correct_predictions_small_binary_train_count += 1
                    if is_carry:
                        correct_predictions_small_binary_train_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_train_carry_decimal_count += 1
                else:
                    correct_predictions_small_binary_test_count += 1
                    if is_carry:
                        correct_predictions_small_binary_test_carry_count += 1
                    if is_carry_decimal:
                        correct_predictions_small_binary_test_carry_decimal_count += 1

            # Actualizar contadores previos
            if is_carry:
                correct_carry_over_predictions_count += 1 
            if is_carry_decimal:
                correct_carry_over_decimal_predictions_count += 1 
            if is_train:
                correct_predictions_train_count += 1 
            else:
                correct_predictions_test_count += 1
            if is_train and is_carry:
                correct_carry_over_predictions_train_count += 1   
            if is_train and is_carry_decimal:
                correct_carry_over_decimal_predictions_train_count += 1 
                
        elif visualize_errors == 1:
            print(f'{pair[0]} plus {pair[1]} has failed.')

    correct_carry_over_predictions_test_count = correct_carry_over_predictions_count - correct_carry_over_predictions_train_count
    correct_carry_over_decimal_predictions_test_count = correct_carry_over_decimal_predictions_count - correct_carry_over_decimal_predictions_train_count
    
    return (
        test_count,
        correct_predictions_test_count,
        train_count,
        correct_predictions_train_count,
        test_carry_over_count,
        correct_carry_over_predictions_test_count,
        train_carry_over_count,
        correct_carry_over_predictions_train_count,
        small_train_count,
        correct_predictions_small_train_count,
        small_test_count,
        correct_predictions_small_test_count,
        small_train_carry_count,
        correct_predictions_small_train_carry_count,
        small_test_carry_count,
        correct_predictions_small_test_carry_count,
        test_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_test_count,
        train_carry_over_decimal_count,
        correct_carry_over_decimal_predictions_train_count,
        small_train_carry_decimal_count,
        correct_predictions_small_train_carry_decimal_count,
        small_test_carry_decimal_count,
        correct_predictions_small_test_carry_decimal_count,
        small_binary_train_count,
        correct_predictions_small_binary_train_count,
        small_binary_test_count,
        correct_predictions_small_binary_test_count,
        small_binary_train_carry_count,
        correct_predictions_small_binary_train_carry_count,
        small_binary_test_carry_count,
        correct_predictions_small_binary_test_carry_count,
        small_binary_train_carry_decimal_count,
        correct_predictions_small_binary_train_carry_decimal_count,
        small_binary_test_carry_decimal_count,
        correct_predictions_small_binary_test_carry_decimal_count,
        reaction_time_carry,
        reaction_time_carry_decimal,
        reaction_time_train,
        reaction_time_test,
        reaction_time_train_carry,
        reaction_time_train_carry_decimal,
        reaction_time_small_train,
        reaction_time_small_test,
        reaction_time_small_train_carry,
        reaction_time_small_test_carry,
        reaction_time_small_train_carry_decimal,
        reaction_time_small_test_carry_decimal,
        reaction_time_small_binary_train,
        reaction_time_small_binary_test,
        reaction_time_small_binary_train_carry,
        reaction_time_small_binary_test_carry,
        reaction_time_small_binary_train_carry_decimal,
        reaction_time_small_binary_test_carry_decimal
    )

# Predict using the trained neural network
def predict(params, x1, x2, stage):
    if stage == 1:
        binary_pred = neural_network_1(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    elif stage == 2:
        binary_pred = neural_network_2(params, x1, x2)
        rounded_pred = np.round(binary_pred)
        return rounded_pred, binary_pred
        
    else:
        print('Bad index for the training stage.')
        return None

# %%
class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()
        
def load_trainable_model(model, current_time, training_type, stage = 0):
    folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition'
    if stage == 0:
        model_path = f'{folder}/Parameters/{training_type}/{model}_{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'trainable_model'] = pickle.load(f)
        print(f'Model trainable_model_{current_time} loaded successfully.')
        return globals()[f'trainable_model']
        
    else:
        model_path = f'{folder}/Trained_models/Stage_by_stage/{training_type}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
        with open(model_path, 'rb') as f:
            globals()[f'{model}_{stage}'] = pickle.load(f)
        print(f'Model {model}_{stage}_{current_time} loaded successfully.')
        return globals()[f'{model}_{stage}']

# %%
validation_performance = 'no'
easy_examples = 'no'
type_training = 'Stage_by_stage'
file_name = 'AP_0.05_0.05'

if easy_examples == 'yes':
    if validation_performance == 'yes':
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-Easy_examples_{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_2'
    
else:
    if validation_performance == 'yes':    
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/Validation_performance/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_2'
    else:
        output_file = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Tests/tests-{type_training}-{file_name}.txt'
        folder_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_2'

os.makedirs(os.path.dirname(output_file), exist_ok=True)

tee = Tee(output_file, 'w') 
sys.stdout = tee

try:
    visualize_errors = 0
    model = 'trainable_model_stage'
    
    date_pattern = r'trainable_model_stage_2-(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).pkl'
    files = sorted(
        (f for f in os.listdir(folder_path) if f.endswith('.pkl') and not f.startswith('.')),  # Filtrar archivos .pkl y ocultos
        key=lambda x: re.search(date_pattern, x).group(0) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
    
        for stage in range(1, 3):
            if easy_examples == 'yes':
                if validation_performance == 'yes':    
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Easy_examples/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                    
            else:
                if validation_performance == 'yes':   
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/Validation_performance/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'
                else:
                    file_path = f'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition/Trained_models/{type_training}/{file_name}/Stage_{stage}/{model}_{stage}-{current_time}.pkl'

            with open(file_path, 'rb') as file:
                globals()[f"{model}_{stage}"] = pickle.load(file)
    
            print(f'Loaded {model}_{stage}-{current_time}.pkl')

            real_test = 1
            decide_test(params=globals()[f"{model}_{stage}"], stage=stage, real_test=real_test, visualize_errors=visualize_errors)
                
finally:
    sys.stdout = tee.console
    tee.close()
    
print(f'Finished, file {file_name} created')
# Out:
# Loaded trainable_model_stage_1-2024_11_18_18_05_05.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8383 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7672 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4383 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 15753108500 reaction time with carry over.
# STAGE 1: 11038337400 reaction time with carry over decimal.
# STAGE 1: 8883725800 reaction time for train.
# STAGE 1: 9383536700 reaction time for test.
# STAGE 1: 7157103600 reaction time for train with carry over .
# STAGE 1: 6120701600 reaction time for train with carry over decimal.
# STAGE 1: 1875543600 reaction time for train small.
# STAGE 1: 1050808100 reaction time for test small.
# STAGE 1: 1057160700 reaction time for train with carry over and small.
# STAGE 1: 631733200 reaction time for test with carry over and small.
# STAGE 1: 799994100 reaction time for train with carry over decimal and small.
# STAGE 1: 453699600 reaction time for test with carry over decimal and small.
# STAGE 1: 7763283100 reaction time for train small binary.
# STAGE 1: 5883967000 reaction time for test small binary.
# STAGE 1: 6036660900 reaction time for train with carry over and small binary.
# STAGE 1: 5096435200 reaction time for test with carry over and small binary.
# STAGE 1: 5000258900 reaction time for train with carry over decimal and small binary.
# STAGE 1: 2834570400 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_18_18_05_05.pkl
# STAGE 2: Out of 8000, 5662 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 5739 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4700 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 5295 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1111 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 670 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 672 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 428 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3974 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 3132 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 484 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 302 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4937 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 3715 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3975 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 3271 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3249 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1857 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 19976421900 reaction time with carry over.
# STAGE 2: 14087532400 reaction time with carry over decimal.
# STAGE 2: 11268250300 reaction time for train.
# STAGE 2: 11857058700 reaction time for test.
# STAGE 2: 9098459700 reaction time for train with carry over .
# STAGE 2: 7861524000 reaction time for train with carry over decimal.
# STAGE 2: 2280372100 reaction time for train small.
# STAGE 2: 1301534400 reaction time for test small.
# STAGE 2: 1282741400 reaction time for train with carry over and small.
# STAGE 2: 776023400 reaction time for test with carry over and small.
# STAGE 2: 966320100 reaction time for train with carry over decimal and small.
# STAGE 2: 560453000 reaction time for test with carry over decimal and small.
# STAGE 2: 9780966500 reaction time for train small binary.
# STAGE 2: 7304404900 reaction time for test small binary.
# STAGE 2: 7611175900 reaction time for train with carry over and small binary.
# STAGE 2: 6325308400 reaction time for test with carry over and small binary.
# STAGE 2: 6374240200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3516890600 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_13_21_44.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8384 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7673 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16895868500 reaction time with carry over.
# STAGE 1: 11836173400 reaction time with carry over decimal.
# STAGE 1: 9458430200 reaction time for train.
# STAGE 1: 10010822600 reaction time for test.
# STAGE 1: 7721350200 reaction time for train with carry over .
# STAGE 1: 6606485900 reaction time for train with carry over decimal.
# STAGE 1: 1892754400 reaction time for train small.
# STAGE 1: 1110220900 reaction time for test small.
# STAGE 1: 1120603000 reaction time for train with carry over and small.
# STAGE 1: 672155600 reaction time for test with carry over and small.
# STAGE 1: 844285000 reaction time for train with carry over decimal and small.
# STAGE 1: 493355900 reaction time for test with carry over decimal and small.
# STAGE 1: 8275438700 reaction time for train small binary.
# STAGE 1: 6277166600 reaction time for test small binary.
# STAGE 1: 6538358700 reaction time for train with carry over and small binary.
# STAGE 1: 5440862300 reaction time for test with carry over and small binary.
# STAGE 1: 5423494400 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3013171500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_13_21_44.pkl
# STAGE 2: Out of 8000, 5470 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 4075 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4671 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 3537 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 566 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 669 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 416 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 412 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 4103 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 2021 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 311 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 302 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4947 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 3328 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4148 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 2790 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3580 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1667 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20309850100 reaction time with carry over.
# STAGE 2: 14241076700 reaction time with carry over decimal.
# STAGE 2: 11335831300 reaction time for train.
# STAGE 2: 12129940000 reaction time for test.
# STAGE 2: 9212351700 reaction time for train with carry over .
# STAGE 2: 7915370100 reaction time for train with carry over decimal.
# STAGE 2: 2335227400 reaction time for train small.
# STAGE 2: 1379115300 reaction time for test small.
# STAGE 2: 1374537700 reaction time for train with carry over and small.
# STAGE 2: 825532700 reaction time for test with carry over and small.
# STAGE 2: 1043897200 reaction time for train with carry over decimal and small.
# STAGE 2: 593541400 reaction time for test with carry over decimal and small.
# STAGE 2: 9858908300 reaction time for train small binary.
# STAGE 2: 7589104700 reaction time for test small binary.
# STAGE 2: 7735428700 reaction time for train with carry over and small binary.
# STAGE 2: 6556663100 reaction time for test with carry over and small binary.
# STAGE 2: 6438447100 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3657045800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_16_34_42.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8384 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7673 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17231220900 reaction time with carry over.
# STAGE 1: 12009333500 reaction time with carry over decimal.
# STAGE 1: 9787181800 reaction time for train.
# STAGE 1: 10173862300 reaction time for test.
# STAGE 1: 7945027000 reaction time for train with carry over .
# STAGE 1: 6738632200 reaction time for train with carry over decimal.
# STAGE 1: 2001161200 reaction time for train small.
# STAGE 1: 1165444300 reaction time for test small.
# STAGE 1: 1170650700 reaction time for train with carry over and small.
# STAGE 1: 687111700 reaction time for test with carry over and small.
# STAGE 1: 865265500 reaction time for train with carry over decimal and small.
# STAGE 1: 492606400 reaction time for test with carry over decimal and small.
# STAGE 1: 8563917100 reaction time for train small binary.
# STAGE 1: 6444408800 reaction time for test small binary.
# STAGE 1: 6721762300 reaction time for train with carry over and small binary.
# STAGE 1: 5556740400 reaction time for test with carry over and small binary.
# STAGE 1: 5515367500 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3071697100 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_16_34_42.pkl
# STAGE 2: Out of 8000, 1 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 0 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 0 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 0 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 0 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 0 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 0 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 0 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 0 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 0 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 0 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 1 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 0 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 0 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 0 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 0 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 0 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 19965127100 reaction time with carry over.
# STAGE 2: 13972189700 reaction time with carry over decimal.
# STAGE 2: 11237116700 reaction time for train.
# STAGE 2: 11770687500 reaction time for test.
# STAGE 2: 9190801000 reaction time for train with carry over .
# STAGE 2: 7836943100 reaction time for train with carry over decimal.
# STAGE 2: 2272036700 reaction time for train small.
# STAGE 2: 1331128800 reaction time for test small.
# STAGE 2: 1356625100 reaction time for train with carry over and small.
# STAGE 2: 797162700 reaction time for test with carry over and small.
# STAGE 2: 1023093800 reaction time for train with carry over decimal and small.
# STAGE 2: 575131600 reaction time for test with carry over decimal and small.
# STAGE 2: 9801462500 reaction time for train small binary.
# STAGE 2: 7427086500 reaction time for test small binary.
# STAGE 2: 7755146800 reaction time for train with carry over and small binary.
# STAGE 2: 6430725100 reaction time for test with carry over and small binary.
# STAGE 2: 6401288900 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3550859500 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_17_43_33.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8378 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7667 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 945 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 567 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5301 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4590 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17280573800 reaction time with carry over.
# STAGE 1: 12079216500 reaction time with carry over decimal.
# STAGE 1: 9622417000 reaction time for train.
# STAGE 1: 10307706100 reaction time for test.
# STAGE 1: 7822067300 reaction time for train with carry over .
# STAGE 1: 6720980500 reaction time for train with carry over decimal.
# STAGE 1: 1964046800 reaction time for train small.
# STAGE 1: 1161004500 reaction time for test small.
# STAGE 1: 1152781900 reaction time for train with carry over and small.
# STAGE 1: 702154400 reaction time for test with carry over and small.
# STAGE 1: 870903800 reaction time for train with carry over decimal and small.
# STAGE 1: 505909400 reaction time for test with carry over decimal and small.
# STAGE 1: 8382184900 reaction time for train small binary.
# STAGE 1: 6472402400 reaction time for test small binary.
# STAGE 1: 6581835200 reaction time for train with carry over and small binary.
# STAGE 1: 5623202800 reaction time for test with carry over and small binary.
# STAGE 1: 5480748400 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3084932900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_17_43_33.pkl
# STAGE 2: Out of 8000, 3881 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 2371 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 3531 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 2061 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 462 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 491 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 439 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 338 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 2720 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1107 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 256 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 230 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3552 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 1925 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 3202 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 1615 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2391 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 900 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20358976300 reaction time with carry over.
# STAGE 2: 14269291100 reaction time with carry over decimal.
# STAGE 2: 11474315200 reaction time for train.
# STAGE 2: 12042836400 reaction time for test.
# STAGE 2: 9342643600 reaction time for train with carry over .
# STAGE 2: 7987974000 reaction time for train with carry over decimal.
# STAGE 2: 2318915400 reaction time for train small.
# STAGE 2: 1365023300 reaction time for test small.
# STAGE 2: 1368154800 reaction time for train with carry over and small.
# STAGE 2: 815500400 reaction time for test with carry over and small.
# STAGE 2: 1028434200 reaction time for train with carry over decimal and small.
# STAGE 2: 591916700 reaction time for test with carry over decimal and small.
# STAGE 2: 9976134200 reaction time for train small binary.
# STAGE 2: 7633671600 reaction time for test small binary.
# STAGE 2: 7844462600 reaction time for train with carry over and small binary.
# STAGE 2: 6607167900 reaction time for test with carry over and small binary.
# STAGE 2: 6489793000 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3678926900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_20_42_21.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8384 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7673 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16956286500 reaction time with carry over.
# STAGE 1: 11906967600 reaction time with carry over decimal.
# STAGE 1: 9518664900 reaction time for train.
# STAGE 1: 10053260800 reaction time for test.
# STAGE 1: 7741351700 reaction time for train with carry over .
# STAGE 1: 6617160400 reaction time for train with carry over decimal.
# STAGE 1: 1899923500 reaction time for train small.
# STAGE 1: 1098650800 reaction time for test small.
# STAGE 1: 1126789600 reaction time for train with carry over and small.
# STAGE 1: 652586500 reaction time for test with carry over and small.
# STAGE 1: 832857900 reaction time for train with carry over decimal and small.
# STAGE 1: 470389500 reaction time for test with carry over decimal and small.
# STAGE 1: 8319004800 reaction time for train small binary.
# STAGE 1: 6256556300 reaction time for test small binary.
# STAGE 1: 6541691600 reaction time for train with carry over and small binary.
# STAGE 1: 5418230300 reaction time for test with carry over and small binary.
# STAGE 1: 5417500300 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3033040200 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_20_42_21.pkl
# STAGE 2: Out of 8000, 7174 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 7346 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 5837 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 6704 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1386 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 843 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 812 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 505 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 5066 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 3865 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 631 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 374 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 6246 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 4722 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4909 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 4080 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 4138 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 2313 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 21086800000 reaction time with carry over.
# STAGE 2: 14774564500 reaction time with carry over decimal.
# STAGE 2: 12035333900 reaction time for train.
# STAGE 2: 12450404200 reaction time for test.
# STAGE 2: 9741759900 reaction time for train with carry over .
# STAGE 2: 8285307000 reaction time for train with carry over decimal.
# STAGE 2: 2488386300 reaction time for train small.
# STAGE 2: 1467781900 reaction time for test small.
# STAGE 2: 1456790000 reaction time for train with carry over and small.
# STAGE 2: 878507000 reaction time for test with carry over and small.
# STAGE 2: 1078604100 reaction time for train with carry over decimal and small.
# STAGE 2: 630059100 reaction time for test with carry over decimal and small.
# STAGE 2: 10566783400 reaction time for train small binary.
# STAGE 2: 7977811200 reaction time for test small binary.
# STAGE 2: 8273209400 reaction time for train with carry over and small binary.
# STAGE 2: 6872447100 reaction time for test with carry over and small binary.
# STAGE 2: 6816756500 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3830159300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_19_20_48_56.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8383 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7672 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4383 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16919516300 reaction time with carry over.
# STAGE 1: 11876702400 reaction time with carry over decimal.
# STAGE 1: 9511259400 reaction time for train.
# STAGE 1: 10047978600 reaction time for test.
# STAGE 1: 7721435000 reaction time for train with carry over .
# STAGE 1: 6621662900 reaction time for train with carry over decimal.
# STAGE 1: 1938550600 reaction time for train small.
# STAGE 1: 1126316000 reaction time for test small.
# STAGE 1: 1132968000 reaction time for train with carry over and small.
# STAGE 1: 671002700 reaction time for test with carry over and small.
# STAGE 1: 853215400 reaction time for train with carry over decimal and small.
# STAGE 1: 480387500 reaction time for test with carry over decimal and small.
# STAGE 1: 8324121800 reaction time for train small binary.
# STAGE 1: 6322956200 reaction time for test small binary.
# STAGE 1: 6534297400 reaction time for train with carry over and small binary.
# STAGE 1: 5473058900 reaction time for test with carry over and small binary.
# STAGE 1: 5434525300 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3057968700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_19_20_48_56.pkl
# STAGE 2: Out of 8000, 2969 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 1604 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 2936 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 1592 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 361 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 181 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 349 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 176 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 1993 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 839 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 197 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 111 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 2466 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 1134 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 2433 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 1122 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 1490 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 573 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20268129600 reaction time with carry over.
# STAGE 2: 14208789500 reaction time with carry over decimal.
# STAGE 2: 11368743100 reaction time for train.
# STAGE 2: 12034642700 reaction time for test.
# STAGE 2: 9256406500 reaction time for train with carry over .
# STAGE 2: 7905926800 reaction time for train with carry over decimal.
# STAGE 2: 2271700800 reaction time for train small.
# STAGE 2: 1334127600 reaction time for test small.
# STAGE 2: 1333658700 reaction time for train with carry over and small.
# STAGE 2: 797728000 reaction time for test with carry over and small.
# STAGE 2: 1001818400 reaction time for train with carry over decimal and small.
# STAGE 2: 581834000 reaction time for test with carry over decimal and small.
# STAGE 2: 9885587900 reaction time for train small binary.
# STAGE 2: 7559557000 reaction time for test small binary.
# STAGE 2: 7773251300 reaction time for train with carry over and small binary.
# STAGE 2: 6536637400 reaction time for test with carry over and small binary.
# STAGE 2: 6422771600 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3655825700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_01_16_24.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8365 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7654 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4379 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5301 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4590 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17099927800 reaction time with carry over.
# STAGE 1: 12060019200 reaction time with carry over decimal.
# STAGE 1: 9666239700 reaction time for train.
# STAGE 1: 10099157900 reaction time for test.
# STAGE 1: 7874025200 reaction time for train with carry over .
# STAGE 1: 6744671900 reaction time for train with carry over decimal.
# STAGE 1: 1993627300 reaction time for train small.
# STAGE 1: 1212297600 reaction time for test small.
# STAGE 1: 1184139800 reaction time for train with carry over and small.
# STAGE 1: 737356600 reaction time for test with carry over and small.
# STAGE 1: 887247800 reaction time for train with carry over decimal and small.
# STAGE 1: 548194500 reaction time for test with carry over decimal and small.
# STAGE 1: 8428760700 reaction time for train small binary.
# STAGE 1: 6415675000 reaction time for test small binary.
# STAGE 1: 6636546200 reaction time for train with carry over and small binary.
# STAGE 1: 5542419700 reaction time for test with carry over and small binary.
# STAGE 1: 5507192900 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3115398300 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_01_16_24.pkl
# STAGE 2: Out of 8000, 5010 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 3587 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 4427 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 3110 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 359 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 625 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 292 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 401 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3861 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1808 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 219 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 286 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4645 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 3134 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4062 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 2657 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3496 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1583 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20128919900 reaction time with carry over.
# STAGE 2: 14174400700 reaction time with carry over decimal.
# STAGE 2: 11399612500 reaction time for train.
# STAGE 2: 11898600300 reaction time for test.
# STAGE 2: 9262433800 reaction time for train with carry over .
# STAGE 2: 7933448700 reaction time for train with carry over decimal.
# STAGE 2: 2275741500 reaction time for train small.
# STAGE 2: 1317580200 reaction time for test small.
# STAGE 2: 1337881300 reaction time for train with carry over and small.
# STAGE 2: 782664600 reaction time for test with carry over and small.
# STAGE 2: 1014457300 reaction time for train with carry over decimal and small.
# STAGE 2: 579735600 reaction time for test with carry over decimal and small.
# STAGE 2: 9966153800 reaction time for train small binary.
# STAGE 2: 7523088400 reaction time for test small binary.
# STAGE 2: 7828975100 reaction time for train with carry over and small binary.
# STAGE 2: 6490974200 reaction time for test with carry over and small binary.
# STAGE 2: 6499990000 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3659624800 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_05_46_23.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8384 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7673 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# ...
# STAGE 2: Out of 946, 601 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 245 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 406 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3979 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 2143 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 161 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 282 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 4503 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 3633 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 4004 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 3203 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 3439 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1797 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20081863500 reaction time with carry over.
# STAGE 2: 14034664500 reaction time with carry over decimal.
# STAGE 2: 11283563700 reaction time for train.
# STAGE 2: 11912949400 reaction time for test.
# STAGE 2: 9179963500 reaction time for train with carry over .
# STAGE 2: 7836915400 reaction time for train with carry over decimal.
# STAGE 2: 2305696100 reaction time for train small.
# STAGE 2: 1340022500 reaction time for test small.
# STAGE 2: 1343200900 reaction time for train with carry over and small.
# STAGE 2: 798616900 reaction time for test with carry over and small.
# STAGE 2: 1024265300 reaction time for train with carry over decimal and small.
# STAGE 2: 568313200 reaction time for test with carry over decimal and small.
# STAGE 2: 9854677700 reaction time for train small binary.
# STAGE 2: 7593713600 reaction time for test small binary.
# STAGE 2: 7751077500 reaction time for train with carry over and small binary.
# STAGE 2: 6582664200 reaction time for test with carry over and small binary.
# STAGE 2: 6408029400 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3646066700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_29_36.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8382 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7671 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4382 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 17042620300 reaction time with carry over.
# STAGE 1: 11997603400 reaction time with carry over decimal.
# STAGE 1: 9608482000 reaction time for train.
# STAGE 1: 10090024300 reaction time for test.
# STAGE 1: 7814664600 reaction time for train with carry over .
# STAGE 1: 6707800300 reaction time for train with carry over decimal.
# STAGE 1: 1961895100 reaction time for train small.
# STAGE 1: 1147271900 reaction time for test small.
# STAGE 1: 1170250400 reaction time for train with carry over and small.
# STAGE 1: 686820300 reaction time for test with carry over and small.
# STAGE 1: 891121300 reaction time for train with carry over decimal and small.
# STAGE 1: 502589000 reaction time for test with carry over decimal and small.
# STAGE 1: 8410973100 reaction time for train small binary.
# STAGE 1: 6340054800 reaction time for test small binary.
# STAGE 1: 6617155700 reaction time for train with carry over and small binary.
# STAGE 1: 5477986200 reaction time for test with carry over and small binary.
# STAGE 1: 5510291400 reaction time for train with carry over decimal and small binary.
# STAGE 1: 3073065100 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_29_36.pkl
# STAGE 2: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 8382 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 7671 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 20011645000 reaction time with carry over.
# STAGE 2: 13945235500 reaction time with carry over decimal.
# STAGE 2: 11254408400 reaction time for train.
# STAGE 2: 11891463200 reaction time for test.
# STAGE 2: 9141778900 reaction time for train with carry over .
# STAGE 2: 7800310500 reaction time for train with carry over decimal.
# STAGE 2: 2319559000 reaction time for train small.
# STAGE 2: 1378542600 reaction time for test small.
# STAGE 2: 1370955900 reaction time for train with carry over and small.
# STAGE 2: 821050500 reaction time for test with carry over and small.
# STAGE 2: 1024500300 reaction time for train with carry over decimal and small.
# STAGE 2: 594215100 reaction time for test with carry over decimal and small.
# STAGE 2: 9830342200 reaction time for train small binary.
# STAGE 2: 7507795100 reaction time for test small binary.
# STAGE 2: 7717712700 reaction time for train with carry over and small binary.
# STAGE 2: 6486198000 reaction time for test with carry over and small binary.
# STAGE 2: 6376244300 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3576854700 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_1-2024_11_20_11_29_38.pkl
# STAGE 1: Out of 8000, 8000 trained were predicted correctly in the current model.
# STAGE 1: Out of 8384, 8384 tested were predicted correctly in the current model.
# STAGE 1: Out of 6524, 6524 trained with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1631, 7673 tested with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 1614, 1614 trained with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 946, 946 tested with small problem size were predicted correctly in the current model.
# STAGE 1: Out of 963, 963 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 568, 568 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 5576, 5576 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 1399, 4384 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 724, 724 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 412, 412 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 6986, 6986 trained with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5302, 5302 tested with small binary problem size were predicted correctly in the current model.
# STAGE 1: Out of 5510, 5510 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4591, 4591 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 1: Out of 4562, 4562 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: Out of 2559, 2559 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 1: 16447483200 reaction time with carry over.
# STAGE 1: 11515939900 reaction time with carry over decimal.
# STAGE 1: 9464790700 reaction time for train.
# STAGE 1: 9644553800 reaction time for test.
# STAGE 1: 7653637700 reaction time for train with carry over .
# STAGE 1: 6495763600 reaction time for train with carry over decimal.
# STAGE 1: 1986750800 reaction time for train small.
# STAGE 1: 1130228300 reaction time for test small.
# STAGE 1: 1136272700 reaction time for train with carry over and small.
# STAGE 1: 671886200 reaction time for test with carry over and small.
# STAGE 1: 838748700 reaction time for train with carry over decimal and small.
# STAGE 1: 489845800 reaction time for test with carry over decimal and small.
# STAGE 1: 8258406700 reaction time for train small binary.
# STAGE 1: 6170487300 reaction time for test small binary.
# STAGE 1: 6447253700 reaction time for train with carry over and small binary.
# STAGE 1: 5319779000 reaction time for test with carry over and small binary.
# STAGE 1: 5289379600 reaction time for train with carry over decimal and small binary.
# STAGE 1: 2960021900 reaction time for test with carry over decimal and small binary.
# Loaded trainable_model_stage_2-2024_11_20_11_29_38.pkl
# STAGE 2: Out of 8000, 4436 trained were predicted correctly in the current model.
# STAGE 2: Out of 8384, 2767 tested were predicted correctly in the current model.
# STAGE 2: Out of 6524, 3583 trained with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1631, 2311 tested with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 1614, 805 trained with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 946, 547 tested with small problem size were predicted correctly in the current model.
# STAGE 2: Out of 963, 442 trained with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 568, 296 tested with small problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 5576, 3178 trained with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 1399, 1402 tested with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 724, 353 trained with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 412, 219 tested with small problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 6986, 3851 trained with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5302, 2187 tested with small binary problem size were predicted correctly in the current model.
# STAGE 2: Out of 5510, 2998 trained with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4591, 1731 tested with small binary problem size and with carry-over were predicted correctly in the current model.
# STAGE 2: Out of 4562, 2593 trained with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: Out of 2559, 1063 tested with small binary problem size and with carry-over decimal were predicted correctly in the current model.
# STAGE 2: 18595909400 reaction time with carry over.
# STAGE 2: 13041867100 reaction time with carry over decimal.
# STAGE 2: 10472228900 reaction time for train.
# STAGE 2: 10978441600 reaction time for test.
# STAGE 2: 8549372000 reaction time for train with carry over .
# STAGE 2: 7301407000 reaction time for train with carry over decimal.
# STAGE 2: 2074224100 reaction time for train small.
# STAGE 2: 1233017600 reaction time for test small.
# STAGE 2: 1232082700 reaction time for train with carry over and small.
# STAGE 2: 730674300 reaction time for test with carry over and small.
# STAGE 2: 926244700 reaction time for train with carry over decimal and small.
# STAGE 2: 531332300 reaction time for test with carry over decimal and small.
# STAGE 2: 9168594100 reaction time for train small binary.
# STAGE 2: 6921951700 reaction time for test small binary.
# STAGE 2: 7245737200 reaction time for train with carry over and small binary.
# STAGE 2: 5990047500 reaction time for test with carry over and small binary.
# STAGE 2: 5997772200 reaction time for train with carry over decimal and small binary.
# STAGE 2: 3354777900 reaction time for test with carry over decimal and small binary.
# Finished, file AP_0.05_0.05 created
