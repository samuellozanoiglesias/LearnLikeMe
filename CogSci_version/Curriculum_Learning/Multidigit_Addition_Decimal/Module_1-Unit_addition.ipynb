# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.utils import shuffle

# %%
# Generar datos para el módulo de unidades
def generate_unit_data():
    x_data = []
    y_data = []
    for a in range(10):  # Primer número
        for b in range(10):  # Segundo número
            x_data.append([a, b])  # Entrada
            y_data.append((a + b) % 10)  # Unidades de la suma
    return np.array(x_data), np.array(y_data)

# Generar datos
x, y = generate_unit_data()

# Convertir etiquetas a one-hot
y_one_hot = to_categorical(y, num_classes=10)

# Dividir en conjuntos de entrenamiento y validación (80% entrenamiento)
train_size = int(len(x) * 0.8)  # 80% de datos para entrenamiento
#x_train, y_train = x[:train_size], y_one_hot[:train_size]
x_train, y_train = x, y_one_hot
x_val, y_val = x, y_one_hot   

## Asegurar formas consistentes para las entradas
x_train = np.expand_dims(x_train, axis=1)  # Agrega una dimensión para 'timesteps'
x_val = np.expand_dims(x_val, axis=1)      # Haz lo mismo con los datos de validación

# Construir el modelo
model = Sequential([
    LSTM(16, input_shape=(1, 2), return_sequences=True),
    LSTM(32, return_sequences=False),
    Dense(10, activation='softmax')  # Salida para 10 clases
])

# Callback personalizado para detener cuando todas las combinaciones sean correctas
class StopWhenPerfectCallback(EarlyStopping):
    def __init__(self, val_data, **kwargs):
        super().__init__(**kwargs)
        self.val_data = val_data  # Pasamos explícitamente los datos de validación
    
    def on_epoch_end(self, epoch, logs=None):
        # Evaluar el rendimiento sobre todo el conjunto de validación
        val_predictions = self.model.predict(self.val_data[0])
        val_pred_labels = np.argmax(val_predictions, axis=1)
        val_true_labels = np.argmax(self.val_data[1], axis=1)
        
        # Verificar si todas las combinaciones son correctas
        correct_predictions = np.sum(val_pred_labels == val_true_labels)
        total_predictions = len(val_true_labels)
        
        print(f'Evaluación de validación: {correct_predictions}/{total_predictions} correctas')

        # Si todas las combinaciones son correctas, detener el entrenamiento
        if correct_predictions == total_predictions:
            print("¡Todas las combinaciones han sido aprendidas correctamente! Deteniendo entrenamiento.")
            self.model.stop_training = True

# Compilar el modelo
model.compile(optimizer=Adam(learning_rate=0.005), loss='categorical_crossentropy', metrics=['accuracy'])

# Crear una instancia del callback con los datos de validación
stop_callback = StopWhenPerfectCallback(val_data=(x_val, y_val), patience=500)

# Entrenar el modelo con el callback personalizado
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=500,
    batch_size=1,
    callbacks=[stop_callback]
)

# Evaluación final
loss, accuracy = model.evaluate(x_val, y_val)
print(f"Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

# Predicciones
predictions = model.predict(x_val)
predicted_numbers = np.argmax(predictions, axis=1)
real_numbers = np.argmax(y_val, axis=1)  # Etiquetas reales

print("Predicciones (probabilidades):", predictions[:5])
print("Predicciones (números):", predicted_numbers[:5])
print("Etiquetas reales:", real_numbers[:5])

# Mostrar las predicciones de validación y sus etiquetas
print("\nEvaluación de validación final:")
correct_predictions = np.sum(predicted_numbers == real_numbers)
total_predictions = len(real_numbers)
print(f'Predicciones correctas: {correct_predictions}/{total_predictions}')

# Guardar el modelo
model.save('unit_addition_module.keras')
# Out:
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step ep - accuracy: 0.0654 - loss: 2.3
# Evaluación de validación: 10/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0651 - loss: 2.3199 - val_accuracy: 0.1000 - val_loss: 2.3011
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.1078 - loss: 2.306
# Evaluación de validación: 11/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1029 - loss: 2.3069 - val_accuracy: 0.1100 - val_loss: 2.2977
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.0724 - loss: 2.307
# Evaluación de validación: 11/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0720 - loss: 2.3072 - val_accuracy: 0.1100 - val_loss: 2.2944
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.1085 - loss: 2.298
# Evaluación de validación: 15/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1076 - loss: 2.2988 - val_accuracy: 0.1500 - val_loss: 2.2795
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.1191 - loss: 2.280
# Evaluación de validación: 12/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1155 - loss: 2.2834 - val_accuracy: 0.1200 - val_loss: 2.2850
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.1082 - loss: 2.303
# Evaluación de validación: 14/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1079 - loss: 2.3019 - val_accuracy: 0.1400 - val_loss: 2.2384
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.0920 - loss: 2.261
# Evaluación de validación: 16/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.0922 - loss: 2.2613 - val_accuracy: 0.1600 - val_loss: 2.2138
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.1056 - loss: 2.253
# Evaluación de validación: 16/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1062 - loss: 2.2530 - val_accuracy: 0.1600 - val_loss: 2.1749
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.1857 - loss: 2.229
# Evaluación de validación: 15/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1852 - loss: 2.2289 - val_accuracy: 0.1500 - val_loss: 2.1308
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.2472 - loss: 2.057
# Evaluación de validación: 23/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2273 - loss: 2.0770 - val_accuracy: 0.2300 - val_loss: 2.1175
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.1476 - loss: 2.114
# Evaluación de validación: 16/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1473 - loss: 2.1153 - val_accuracy: 0.1600 - val_loss: 2.0630
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.1847 - loss: 2.124
# Evaluación de validación: 15/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1856 - loss: 2.1212 - val_accuracy: 0.1500 - val_loss: 2.0037
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.1324 - loss: 2.021
# Evaluación de validación: 34/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.1344 - loss: 2.0229 - val_accuracy: 0.3400 - val_loss: 1.9379
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.4188 - loss: 1.865
# Evaluación de validación: 28/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4102 - loss: 1.8689 - val_accuracy: 0.2800 - val_loss: 1.7779
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.2765 - loss: 1.798
# Evaluación de validación: 38/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2724 - loss: 1.8005 - val_accuracy: 0.3800 - val_loss: 1.6850
# Epoch 16/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.2441 - loss: 1.766
# Evaluación de validación: 46/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.2468 - loss: 1.7655 - val_accuracy: 0.4600 - val_loss: 1.5784
# Epoch 17/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.5232 - loss: 1.476
# Evaluación de validación: 37/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5088 - loss: 1.4945 - val_accuracy: 0.3700 - val_loss: 1.5483
# Epoch 18/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.4466 - loss: 1.547
# Evaluación de validación: 51/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4452 - loss: 1.5456 - val_accuracy: 0.5100 - val_loss: 1.3669
# Epoch 19/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.5100 - loss: 1.433
# Evaluación de validación: 49/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5091 - loss: 1.4338 - val_accuracy: 0.4900 - val_loss: 1.3298
# Epoch 20/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.5169 - loss: 1.436
# Evaluación de validación: 46/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5151 - loss: 1.4307 - val_accuracy: 0.4600 - val_loss: 1.2866
# Epoch 21/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.4714 - loss: 1.367
# Evaluación de validación: 69/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4772 - loss: 1.3640 - val_accuracy: 0.6900 - val_loss: 1.1544
# Epoch 22/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.6022 - loss: 1.150
# Evaluación de validación: 65/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6115 - loss: 1.1527 - val_accuracy: 0.6500 - val_loss: 1.0749
# Epoch 23/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/steptep - accuracy: 0.5537 - loss: 1.166
# Evaluación de validación: 80/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5597 - loss: 1.1620 - val_accuracy: 0.8000 - val_loss: 1.0352
# Epoch 24/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.6822 - loss: 1.034
# Evaluación de validación: 69/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6753 - loss: 1.0395 - val_accuracy: 0.6900 - val_loss: 1.0553
# Epoch 25/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.6897 - loss: 0.999
# Evaluación de validación: 64/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6874 - loss: 1.0041 - val_accuracy: 0.6400 - val_loss: 0.9821
# Epoch 26/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.6556 - loss: 0.986
# Evaluación de validación: 71/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6644 - loss: 0.9803 - val_accuracy: 0.7100 - val_loss: 0.9190
# Epoch 27/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.7003 - loss: 0.919
# Evaluación de validación: 86/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6947 - loss: 0.9199 - val_accuracy: 0.8600 - val_loss: 0.8140
# Epoch 28/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.7742 - loss: 0.939
# Evaluación de validación: 83/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7733 - loss: 0.9307 - val_accuracy: 0.8300 - val_loss: 0.7732
# Epoch 29/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.7589 - loss: 0.948
# Evaluación de validación: 89/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7587 - loss: 0.9422 - val_accuracy: 0.8900 - val_loss: 0.7156
# Epoch 30/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.7826 - loss: 0.821
# Evaluación de validación: 81/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7810 - loss: 0.8185 - val_accuracy: 0.8100 - val_loss: 0.7116
# Epoch 31/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.8252 - loss: 0.731
# Evaluación de validación: 82/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8221 - loss: 0.7302 - val_accuracy: 0.8200 - val_loss: 0.6725
# Epoch 32/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8725 - loss: 0.696
# Evaluación de validación: 88/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8705 - loss: 0.6974 - val_accuracy: 0.8800 - val_loss: 0.6593
# Epoch 33/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.6508 - loss: 0.790
# Evaluación de validación: 88/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6614 - loss: 0.7831 - val_accuracy: 0.8800 - val_loss: 0.6194
# Epoch 34/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step tep - accuracy: 0.9174 - loss: 0.553
# Evaluación de validación: 91/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9133 - loss: 0.5573 - val_accuracy: 0.9100 - val_loss: 0.5889
# Epoch 35/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9372 - loss: 0.566
# Evaluación de validación: 95/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9309 - loss: 0.5706 - val_accuracy: 0.9500 - val_loss: 0.5327
# Epoch 36/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8644 - loss: 0.609
# Evaluación de validación: 82/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8673 - loss: 0.6022 - val_accuracy: 0.8200 - val_loss: 0.5525
# Epoch 37/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.7894 - loss: 0.582
# Evaluación de validación: 89/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7684 - loss: 0.5975 - val_accuracy: 0.8900 - val_loss: 0.5291
# Epoch 38/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8510 - loss: 0.560
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8514 - loss: 0.5605 - val_accuracy: 0.9700 - val_loss: 0.4846
# Epoch 39/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8904 - loss: 0.471
# Evaluación de validación: 87/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8890 - loss: 0.4729 - val_accuracy: 0.8700 - val_loss: 0.5262
# Epoch 40/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8244 - loss: 0.618
# Evaluación de validación: 83/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8270 - loss: 0.6158 - val_accuracy: 0.8300 - val_loss: 0.5730
# Epoch 41/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8582 - loss: 0.521
# Evaluación de validación: 76/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8458 - loss: 0.5394 - val_accuracy: 0.7600 - val_loss: 0.6300
# Epoch 42/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8008 - loss: 0.604
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8029 - loss: 0.6038 - val_accuracy: 0.9700 - val_loss: 0.4456
# Epoch 43/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8994 - loss: 0.463
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9017 - loss: 0.4596 - val_accuracy: 0.9900 - val_loss: 0.4165
# Epoch 44/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step tep - accuracy: 0.9027 - loss: 0.475
# Evaluación de validación: 89/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9032 - loss: 0.4748 - val_accuracy: 0.8900 - val_loss: 0.3959
# Epoch 45/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/steptep - accuracy: 0.8698 - loss: 0.418
# Evaluación de validación: 93/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8752 - loss: 0.4164 - val_accuracy: 0.9300 - val_loss: 0.3976
# Epoch 46/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.8917 - loss: 0.410
# Evaluación de validación: 90/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8917 - loss: 0.4105 - val_accuracy: 0.9000 - val_loss: 0.3704
# Epoch 47/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.9332 - loss: 0.413
# Evaluación de validación: 95/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9336 - loss: 0.4116 - val_accuracy: 0.9500 - val_loss: 0.3463
# Epoch 48/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9668 - loss: 0.375
# Evaluación de validación: 95/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9664 - loss: 0.3739 - val_accuracy: 0.9500 - val_loss: 0.3007
# Epoch 49/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9631 - loss: 0.339
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9625 - loss: 0.3390 - val_accuracy: 0.9700 - val_loss: 0.3009
# Epoch 50/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9723 - loss: 0.337
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9722 - loss: 0.3376 - val_accuracy: 0.9900 - val_loss: 0.3103
# Epoch 51/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8426 - loss: 0.573
# Evaluación de validación: 76/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8288 - loss: 0.6027 - val_accuracy: 0.7600 - val_loss: 0.6745
# Epoch 52/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9027 - loss: 0.523
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9010 - loss: 0.5108 - val_accuracy: 0.9900 - val_loss: 0.3171
# Epoch 53/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9804 - loss: 0.269
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9787 - loss: 0.2714 - val_accuracy: 0.9700 - val_loss: 0.2568
# Epoch 54/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9788 - loss: 0.244
# Evaluación de validación: 87/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9774 - loss: 0.2500 - val_accuracy: 0.8700 - val_loss: 0.3343
# Epoch 55/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8945 - loss: 0.304
# Evaluación de validación: 98/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8988 - loss: 0.3017 - val_accuracy: 0.9800 - val_loss: 0.2794
# Epoch 56/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9102 - loss: 0.307
# Evaluación de validación: 92/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9112 - loss: 0.3062 - val_accuracy: 0.9200 - val_loss: 0.2800
# Epoch 57/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8833 - loss: 0.352
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8842 - loss: 0.3496 - val_accuracy: 0.9900 - val_loss: 0.2479
# Epoch 58/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9744 - loss: 0.249
# Evaluación de validación: 98/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9747 - loss: 0.2493 - val_accuracy: 0.9800 - val_loss: 0.2174
# Epoch 59/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9721 - loss: 0.199
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9717 - loss: 0.2022 - val_accuracy: 0.9900 - val_loss: 0.2045
# Epoch 60/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9946 - loss: 0.209
# Evaluación de validación: 98/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9927 - loss: 0.2140 - val_accuracy: 0.9800 - val_loss: 0.2538
# Epoch 61/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9863 - loss: 0.269
# Evaluación de validación: 90/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9848 - loss: 0.2675 - val_accuracy: 0.9000 - val_loss: 0.3558
# Epoch 62/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/steptep - accuracy: 0.9679 - loss: 0.236
# Evaluación de validación: 96/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9656 - loss: 0.2382 - val_accuracy: 0.9600 - val_loss: 0.1984
# Epoch 63/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9552 - loss: 0.247
# Evaluación de validación: 89/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9521 - loss: 0.2493 - val_accuracy: 0.8900 - val_loss: 0.3242
# Epoch 64/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9327 - loss: 0.318
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9362 - loss: 0.3065 - val_accuracy: 0.9700 - val_loss: 0.1827
# Epoch 65/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9328 - loss: 0.249
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9377 - loss: 0.2431 - val_accuracy: 0.9700 - val_loss: 0.1773
# Epoch 66/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9306 - loss: 0.252
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9336 - loss: 0.2502 - val_accuracy: 0.9900 - val_loss: 0.1779
# Epoch 67/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9956 - loss: 0.146
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9940 - loss: 0.1516 - val_accuracy: 0.9900 - val_loss: 0.1894
# Epoch 68/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9828 - loss: 0.163
# Evaluación de validación: 95/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9827 - loss: 0.1642 - val_accuracy: 0.9500 - val_loss: 0.1751
# Epoch 69/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9351 - loss: 0.220
# Evaluación de validación: 92/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9374 - loss: 0.2176 - val_accuracy: 0.9200 - val_loss: 0.2728
# Epoch 70/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9769 - loss: 0.226
# Evaluación de validación: 96/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9771 - loss: 0.2210 - val_accuracy: 0.9600 - val_loss: 0.1657
# Epoch 71/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9758 - loss: 0.206
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9751 - loss: 0.2028 - val_accuracy: 0.9900 - val_loss: 0.1465
# Epoch 72/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9887 - loss: 0.178
# Evaluación de validación: 98/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9874 - loss: 0.1766 - val_accuracy: 0.9800 - val_loss: 0.1539
# Epoch 73/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9890 - loss: 0.136
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9890 - loss: 0.1370 - val_accuracy: 0.9700 - val_loss: 0.1505
# Epoch 74/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9826 - loss: 0.155
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9831 - loss: 0.1547 - val_accuracy: 0.9900 - val_loss: 0.1353
# Epoch 75/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.9993 - loss: 0.136
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9972 - loss: 0.1364 - val_accuracy: 0.9900 - val_loss: 0.1330
# Epoch 76/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9930 - loss: 0.142
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9913 - loss: 0.1429 - val_accuracy: 0.9900 - val_loss: 0.1273
# Epoch 77/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9905 - loss: 0.106
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9904 - loss: 0.1092 - val_accuracy: 0.9900 - val_loss: 0.1171
# Epoch 78/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9961 - loss: 0.128
# Evaluación de validación: 72/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9930 - loss: 0.1306 - val_accuracy: 0.7200 - val_loss: 0.4173
# Epoch 79/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/steptep - accuracy: 0.6567 - loss: 1.080
# Evaluación de validación: 64/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6432 - loss: 1.1526 - val_accuracy: 0.6400 - val_loss: 1.5288
# Epoch 80/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.7437 - loss: 0.989
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7555 - loss: 0.9421 - val_accuracy: 0.9900 - val_loss: 0.1852
# Epoch 81/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9619 - loss: 0.218
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9644 - loss: 0.2106 - val_accuracy: 0.9700 - val_loss: 0.1387
# Epoch 82/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9962 - loss: 0.127
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9948 - loss: 0.1275 - val_accuracy: 0.9900 - val_loss: 0.1191
# Epoch 83/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 1.0000 - loss: 0.109
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9995 - loss: 0.1108 - val_accuracy: 0.9900 - val_loss: 0.1214
# Epoch 84/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/steptep - accuracy: 0.9841 - loss: 0.131
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9834 - loss: 0.1311 - val_accuracy: 0.9900 - val_loss: 0.1116
# Epoch 85/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9914 - loss: 0.111
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9911 - loss: 0.1125 - val_accuracy: 0.9900 - val_loss: 0.1095
# Epoch 86/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9951 - loss: 0.124
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9944 - loss: 0.1240 - val_accuracy: 0.9900 - val_loss: 0.1133
# Epoch 87/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9886 - loss: 0.153
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9887 - loss: 0.1482 - val_accuracy: 0.9900 - val_loss: 0.1067
# Epoch 88/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9807 - loss: 0.107
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9814 - loss: 0.1081 - val_accuracy: 0.9900 - val_loss: 0.1230
# Epoch 89/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9908 - loss: 0.123
# Evaluación de validación: 96/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9905 - loss: 0.1252 - val_accuracy: 0.9600 - val_loss: 0.1242
# Epoch 90/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9904 - loss: 0.115
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9904 - loss: 0.1155 - val_accuracy: 0.9900 - val_loss: 0.0977
# Epoch 91/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9761 - loss: 0.094
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9766 - loss: 0.0947 - val_accuracy: 0.9900 - val_loss: 0.0955
# Epoch 92/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9969 - loss: 0.118
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9962 - loss: 0.1172 - val_accuracy: 0.9900 - val_loss: 0.0935
# Epoch 93/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9964 - loss: 0.092
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9955 - loss: 0.0941 - val_accuracy: 0.9900 - val_loss: 0.0930
# Epoch 94/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9899 - loss: 0.115
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9899 - loss: 0.1142 - val_accuracy: 0.9900 - val_loss: 0.1012
# Epoch 95/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9909 - loss: 0.099
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9894 - loss: 0.0999 - val_accuracy: 0.9900 - val_loss: 0.1409
# Epoch 96/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9738 - loss: 0.107
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9722 - loss: 0.1126 - val_accuracy: 0.9700 - val_loss: 0.1600
# Epoch 97/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9175 - loss: 0.208
# Evaluación de validación: 81/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9090 - loss: 0.2200 - val_accuracy: 0.8100 - val_loss: 0.5642
# Epoch 98/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.6631 - loss: 0.964
# Evaluación de validación: 79/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6722 - loss: 0.9416 - val_accuracy: 0.7900 - val_loss: 0.5480
# Epoch 99/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.7684 - loss: 0.804
# Evaluación de validación: 96/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7790 - loss: 0.7715 - val_accuracy: 0.9600 - val_loss: 0.2026
# Epoch 100/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9247 - loss: 0.173
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9296 - loss: 0.1694 - val_accuracy: 0.9900 - val_loss: 0.0974
# Epoch 101/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9896 - loss: 0.096
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9896 - loss: 0.0963 - val_accuracy: 0.9900 - val_loss: 0.0878
# Epoch 102/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9522 - loss: 0.115
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9544 - loss: 0.1137 - val_accuracy: 0.9900 - val_loss: 0.0866
# Epoch 103/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 1.0000 - loss: 0.071
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9992 - loss: 0.0726 - val_accuracy: 0.9900 - val_loss: 0.0842
# Epoch 104/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9768 - loss: 0.089
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9775 - loss: 0.0891 - val_accuracy: 0.9900 - val_loss: 0.0803
# Epoch 105/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9867 - loss: 0.123
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9871 - loss: 0.1194 - val_accuracy: 0.9900 - val_loss: 0.0863
# Epoch 106/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 1.0000 - loss: 0.075
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9995 - loss: 0.0758 - val_accuracy: 0.9900 - val_loss: 0.0770
# Epoch 107/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9787 - loss: 0.104
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9793 - loss: 0.1032 - val_accuracy: 0.9900 - val_loss: 0.0750
# Epoch 108/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 1.0000 - loss: 0.070
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9998 - loss: 0.0708 - val_accuracy: 0.9900 - val_loss: 0.0737
# Epoch 109/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9766 - loss: 0.071
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9775 - loss: 0.0716 - val_accuracy: 0.9900 - val_loss: 0.0721
# Epoch 110/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9789 - loss: 0.068
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9793 - loss: 0.0693 - val_accuracy: 0.9900 - val_loss: 0.0852
# Epoch 111/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.9979 - loss: 0.090
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0904 - val_accuracy: 0.9900 - val_loss: 0.0701
# Epoch 112/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.9984 - loss: 0.070
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9981 - loss: 0.0708 - val_accuracy: 0.9900 - val_loss: 0.0726
# Epoch 113/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9952 - loss: 0.047
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9950 - loss: 0.0487 - val_accuracy: 0.9900 - val_loss: 0.0762
# Epoch 114/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9760 - loss: 0.102
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9762 - loss: 0.1014 - val_accuracy: 0.9900 - val_loss: 0.0702
# Epoch 115/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9860 - loss: 0.079
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9855 - loss: 0.0797 - val_accuracy: 0.9900 - val_loss: 0.1361
# Epoch 116/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.9963 - loss: 0.094
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9957 - loss: 0.0939 - val_accuracy: 0.9900 - val_loss: 0.0675
# Epoch 117/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9883 - loss: 0.049
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9884 - loss: 0.0518 - val_accuracy: 0.9900 - val_loss: 0.0623
# Epoch 118/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9926 - loss: 0.062
# Evaluación de validación: 96/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9915 - loss: 0.0636 - val_accuracy: 0.9600 - val_loss: 0.1632
# Epoch 119/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9539 - loss: 0.093
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9568 - loss: 0.0905 - val_accuracy: 0.9900 - val_loss: 0.0598
# Epoch 120/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 1.0000 - loss: 0.084
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9995 - loss: 0.0832 - val_accuracy: 0.9900 - val_loss: 0.0632
# Epoch 121/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9860 - loss: 0.074
# Evaluación de validación: 97/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9863 - loss: 0.0742 - val_accuracy: 0.9700 - val_loss: 0.0866
# Epoch 122/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.8217 - loss: 0.351
# Evaluación de validación: 63/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8165 - loss: 0.3787 - val_accuracy: 0.6300 - val_loss: 1.0062
# Epoch 123/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.6184 - loss: 1.195
# Evaluación de validación: 75/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6286 - loss: 1.1759 - val_accuracy: 0.7500 - val_loss: 0.5137
# Epoch 124/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.8184 - loss: 0.500
# Evaluación de validación: 91/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8190 - loss: 0.5042 - val_accuracy: 0.9100 - val_loss: 0.2525
# Epoch 125/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9113 - loss: 0.164
# Evaluación de validación: 95/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9155 - loss: 0.1610 - val_accuracy: 0.9500 - val_loss: 0.1805
# Epoch 126/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/steptep - accuracy: 0.9110 - loss: 0.263
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9128 - loss: 0.2632 - val_accuracy: 0.9900 - val_loss: 0.0654
# Epoch 127/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9856 - loss: 0.059
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9859 - loss: 0.0596 - val_accuracy: 0.9900 - val_loss: 0.0631
# Epoch 128/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9981 - loss: 0.042
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9975 - loss: 0.0442 - val_accuracy: 0.9900 - val_loss: 0.0631
# Epoch 129/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9995 - loss: 0.059
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9982 - loss: 0.0606 - val_accuracy: 0.9900 - val_loss: 0.0610
# Epoch 130/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9951 - loss: 0.060
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9944 - loss: 0.0614 - val_accuracy: 0.9900 - val_loss: 0.0586
# Epoch 131/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 1.0000 - loss: 0.072
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9998 - loss: 0.0705 - val_accuracy: 0.9900 - val_loss: 0.0583
# Epoch 132/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9853 - loss: 0.074
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9855 - loss: 0.0734 - val_accuracy: 0.9900 - val_loss: 0.0560
# Epoch 133/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9969 - loss: 0.026
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9962 - loss: 0.0295 - val_accuracy: 0.9900 - val_loss: 0.0562
# Epoch 134/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9824 - loss: 0.059
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9831 - loss: 0.0588 - val_accuracy: 0.9900 - val_loss: 0.0554
# Epoch 135/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9978 - loss: 0.064
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9977 - loss: 0.0642 - val_accuracy: 0.9900 - val_loss: 0.0578
# Epoch 136/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9890 - loss: 0.044
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9890 - loss: 0.0469 - val_accuracy: 0.9900 - val_loss: 0.0534
# Epoch 137/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step tep - accuracy: 0.9996 - loss: 0.045
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9985 - loss: 0.0467 - val_accuracy: 0.9900 - val_loss: 0.0519
# Epoch 138/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/steptep - accuracy: 0.9983 - loss: 0.060
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9973 - loss: 0.0607 - val_accuracy: 0.9900 - val_loss: 0.0559
# Epoch 139/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9662 - loss: 0.062
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9692 - loss: 0.0620 - val_accuracy: 0.9900 - val_loss: 0.0517
# Epoch 140/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9913 - loss: 0.100
# Evaluación de validación: 99/100 correctas
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9911 - loss: 0.0968 - val_accuracy: 0.9900 - val_loss: 0.0516
# Epoch 141/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/steptep - accuracy: 0.9893 - loss: 0.033
# Evaluación de validación: 100/100 correctas
# ¡Todas las combinaciones han sido aprendidas correctamente! Deteniendo entrenamiento.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9893 - loss: 0.0351 - val_accuracy: 1.0000 - val_loss: 0.0501
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 1.0000 - loss: 0.0294
# Loss: 0.0501, Accuracy: 1.0000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Predicciones (probabilidades): [[9.99926329e-01 5.24696588e-05 5.33676525e-09 1.88867268e-08
#   4.50301840e-08 6.09519502e-09 4.05532186e-09 3.30211392e-09
#   3.17285291e-08 2.11284951e-05]
#  [1.45583545e-04 9.99738991e-01 9.98362084e-05 1.10421325e-07
#   9.27110402e-11 1.51240506e-10 1.17841381e-08 5.14255930e-07
#   1.33045642e-05 1.62395463e-06]
#  [1.69141312e-09 2.49987235e-04 9.97164905e-01 2.58514332e-03
#   1.81345894e-09 1.85553965e-13 9.25846531e-13 2.50890841e-09
#   3.62047956e-08 1.06450834e-10]
#  [3.65917852e-11 1.55250487e-12 8.57834038e-06 9.98135567e-01
#   1.85551401e-03 3.20357429e-07 2.56877054e-11 1.86601203e-11
#   1.39742704e-10 4.97162578e-09]
#  [8.87664864e-15 5.38075165e-17 2.39160254e-11 1.66973157e-04
#   9.98024106e-01 1.80892006e-03 5.70884717e-09 4.25386506e-12
#   4.28458149e-15 2.35472102e-12]]
# Predicciones (números): [0 1 2 3 4]
# Etiquetas reales: [0 1 2 3 4]
#
# Evaluación de validación final:
# Predicciones correctas: 100/100
