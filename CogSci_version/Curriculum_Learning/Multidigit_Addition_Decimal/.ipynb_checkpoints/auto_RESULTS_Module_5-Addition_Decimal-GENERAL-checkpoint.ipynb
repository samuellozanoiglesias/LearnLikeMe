# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Verificar si hay GPUs disponibles
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    print("TensorFlow está utilizando la GPU")
else:
    print("TensorFlow no está utilizando la GPU")
# Out:
# TensorFlow no está utilizando la GPU

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}not_sorted_balanced_train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}stimuli.txt", "r") as file:
    test_couples = eval(file.read())

with open(f"{folder}test_dataset.txt", "r") as file:
    test_dataset = eval(file.read())

def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Función para leer los datos desde un archivo .txt y generar el dataset de entrenamiento
def generate_train_dataset():
    x_data = []
    y_data = []
    
    for a, b in train_couples:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Función para generar los datos
def generate_final_data():
    x_data = []
    y_data = []
    for a_dec in range(10):
        for a_unit in range(10):
            for b_dec in range(10):
                for b_unit in range(10):
                    x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada
                    sum_units = (a_unit + b_unit) % 10
                    carry_units = 1 if (a_unit + b_unit) >= 10 else 0
                    sum_dec = (a_dec + b_dec + carry_units) % 10
                    carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
                    y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    return jnp.array(x_data), jnp.array(y_data)

# %%
# Función de pérdida
def loss_fn(params, x, y):
    y_pred_1, y_pred_2, y_pred_3 = model(params, x)
    return jnp.mean((y_pred_1 - y[:, 0]) ** 2) + jnp.mean((y_pred_2 - y[:, 1]) ** 2) + jnp.mean((y_pred_3 - y[:, 2]) ** 2)
    
# Función para actualizar los parámetros
def update_params(params, x, y, lr):
    # Asegúrate de usar JAX para los gradientes y operaciones
    gradients = grad(loss_fn)(params, x, y)
    new_params = jax.tree_util.tree_map(lambda p, g: p - lr * g, params, gradients)
    return new_params

# Función para entrenar el modelo
def train_model(params, x_train, y_train, lr=0.01, epochs=100, stop=1, batch_size=0):
    final_loss = 0
    total_examples = x_train.shape[0]

    if batch_size == 0:
        batch_size = total_examples
    
    # Convertir x_train y y_train a arrays de JAX (si aún no lo son)
    x_train = jnp.array(x_train)
    y_train = jnp.array(y_train)

    batches_per_epoch = int(total_examples/batch_size)
    
    # Entrenar el modelo
    for epoch in range(epochs):  # Número de épocas
        if epoch == 0:
            pred_count, pred_count_test, step_loss = correct_predictions_and_loss(params)  # Contamos las predicciones correctas
            print(f"Epoch {epoch}, Loss: {step_loss}, Correct predictions: {pred_count}, Correct predictions test: {pred_count_test}")
            
        for batch in range(batches_per_epoch):         
            x_batch = x_train[(batch*batch_size):((batch+1)*batch_size)]
            y_batch = y_train[(batch*batch_size):((batch+1)*batch_size)]
            params = update_params(params, x_batch, y_batch, lr)
    
        # Mostrar estadísticas cada 10 épocas
        if epoch % 5 == 0 and epoch != 0:
            pred_count, pred_count_test, step_loss = correct_predictions_and_loss(params)  # Contamos las predicciones correctas
            print(f"Epoch {epoch}, Loss: {step_loss}, Correct predictions: {pred_count}, Correct predictions test: {pred_count_test}")
            if stop == 1 and pred_count_test == 192:
                break

            if stop == 0 and pred_count == 10000:
                break

            if step_loss >= 1000000:
                break
        
    return params, step_loss

def correct_predictions_and_loss(params):
    x_test, y_test = generate_test_dataset()
    pred_count = 0
    pred_count_test = 0
    total_examples = x_test.shape[0]
    pred_hundreds, pred_tens, pred_units = model(params, x_test)   
    loss = jnp.mean((pred_hundreds - y_test[:, 0]) ** 2) + jnp.mean((pred_tens - y_test[:, 1]) ** 2) + jnp.mean((pred_units - y_test[:, 2]) ** 2)
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        # Obtener los valores a y b de x_test
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        # Comparar las predicciones con las etiquetas y contar los aciertos
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            if (a, b) in test_couples:
                pred_count_test += 1

    return pred_count, pred_count_test, loss

def correct_predictions(params):
    x_test, y_test = generate_test_dataset()
    pred_count = 0
    pred_count_test = 0
    total_examples = x_test.shape[0]
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        # Obtener los valores a y b de x_test
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        # Comparar las predicciones con las etiquetas y contar los aciertos
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            if (a, b) in test_couples:
                pred_count_test += 1

    return pred_count, pred_count_test

# %%
# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3

# %%
# Función para leer parámetros de un archivo JSON
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

# Guardar el modelo entrenado
def save_trained_model(params, filename, model_dir):
    os.makedirs(model_dir, exist_ok=True)
    file_path = os.path.join(model_dir, filename)
    serializable_params = {key: value.tolist() for key, value in params.items()}
    
    with open(file_path, 'w') as f:
        json.dump(serializable_params, f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_train, y_train = generate_train_dataset()

param_type = 'RP'

epsilons = [0.1, 0.5, 1]

for epsilon in epsilons:

    save_dir = f"{folder}Results_models/{param_type}_{epsilon}"
    save_model_dir = f"{folder}Trained_models/{param_type}_{epsilon}"
    save_model_dir_2 = f"{folder}Super_trained_models/{param_type}_{epsilon}"
    folder_path = f'{folder}Parameters/{param_type}_{epsilon}'
    date_pattern = r'trainable_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
    files = sorted(
        (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
        key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
    )
    
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/trainable_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trainable_model = json.load(file)
    
        trainable_model_jnp = {key: jnp.array(value) for key, value in trainable_model.items()}
        print(f'Loaded trainable_model_{current_time}.json')
        
        os.makedirs(save_dir, exist_ok=True) 
        results_file = os.path.join(save_dir, f"Results_{current_time}.txt") 
        tee = Tee(results_file, 'w') 
        sys.stdout = tee
        
        try: 
            new_params, average_loss = train_model(trainable_model_jnp, x_train, y_train, lr=0.01, epochs=100)
            pred_count, pred_count_test = correct_predictions(new_params)

            trained_model_filename = f"trained_model_{current_time}.json"
            save_trained_model(new_params, trained_model_filename, save_model_dir)
            print(f'Saved trained_model_{current_time}.json')
    
            if pred_count != 10001:
                new_params_2, average_loss_2 = train_model(new_params, x_train, y_train, lr=0.01, epochs=500, stop=0)
                trained_model_filename_2 = f"super_trained_model_{current_time}.json"
                save_trained_model(new_params_2, trained_model_filename_2, save_model_dir_2)
                print(f'Saved super_trained_model_{current_time}.json')
    
        finally:
            sys.stdout = tee.console
            tee.close()
# Out:
# Loaded trainable_model_2025_01_07_12_12_23.json
# Epoch 0, Loss: 63.4734001159668, Correct predictions: 1, Correct predictions test: 0
# Epoch 5, Loss: 3.184699296951294, Correct predictions: 693, Correct predictions test: 20
# Epoch 10, Loss: 2.195679187774658, Correct predictions: 1185, Correct predictions test: 46
# Epoch 15, Loss: 1.8990426063537598, Correct predictions: 2008, Correct predictions test: 70
# Epoch 20, Loss: 1.7634706497192383, Correct predictions: 2514, Correct predictions test: 86
# Epoch 25, Loss: 1.6663827896118164, Correct predictions: 3200, Correct predictions test: 112
# Epoch 30, Loss: 1.5804024934768677, Correct predictions: 3411, Correct predictions test: 126
# Epoch 35, Loss: 1.4997849464416504, Correct predictions: 3601, Correct predictions test: 138
# Epoch 40, Loss: 1.4234331846237183, Correct predictions: 3796, Correct predictions test: 154
# Epoch 45, Loss: 1.351118803024292, Correct predictions: 3936, Correct predictions test: 160
# Epoch 50, Loss: 1.2827086448669434, Correct predictions: 4058, Correct predictions test: 164
# Epoch 55, Loss: 1.2180452346801758, Correct predictions: 4185, Correct predictions test: 166
# Epoch 60, Loss: 1.1569465398788452, Correct predictions: 4387, Correct predictions test: 170
# Epoch 65, Loss: 1.0992217063903809, Correct predictions: 4459, Correct predictions test: 172
# Epoch 70, Loss: 1.0446808338165283, Correct predictions: 4609, Correct predictions test: 180
# Epoch 75, Loss: 0.993139386177063, Correct predictions: 4770, Correct predictions test: 188
# Epoch 80, Loss: 0.9444225430488586, Correct predictions: 4860, Correct predictions test: 188
# Epoch 85, Loss: 0.8983645439147949, Correct predictions: 4950, Correct predictions test: 190
# Epoch 90, Loss: 0.8548093438148499, Correct predictions: 5050, Correct predictions test: 192
# Saved trained_model_2025_01_07_12_12_23.json
# Epoch 0, Loss: 0.8548093438148499, Correct predictions: 5050, Correct predictions test: 192
# Epoch 5, Loss: 0.8056406378746033, Correct predictions: 5050, Correct predictions test: 192
# Epoch 10, Loss: 0.7670873999595642, Correct predictions: 5050, Correct predictions test: 192
# Epoch 15, Loss: 0.7305980324745178, Correct predictions: 5050, Correct predictions test: 192
# Epoch 20, Loss: 0.6960524916648865, Correct predictions: 5050, Correct predictions test: 192
# Epoch 25, Loss: 0.6633383631706238, Correct predictions: 5050, Correct predictions test: 192
# Epoch 30, Loss: 0.6323497891426086, Correct predictions: 5050, Correct predictions test: 192
# Epoch 35, Loss: 0.6029874682426453, Correct predictions: 5050, Correct predictions test: 192
# Epoch 40, Loss: 0.5751583576202393, Correct predictions: 5050, Correct predictions test: 192
# Epoch 45, Loss: 0.5487749576568604, Correct predictions: 5050, Correct predictions test: 192
# Epoch 50, Loss: 0.5237548351287842, Correct predictions: 5050, Correct predictions test: 192
# Epoch 55, Loss: 0.5000208616256714, Correct predictions: 5050, Correct predictions test: 192
# Epoch 60, Loss: 0.47750046849250793, Correct predictions: 5050, Correct predictions test: 192
# Epoch 65, Loss: 0.4561254680156708, Correct predictions: 5050, Correct predictions test: 192
# Epoch 70, Loss: 0.43583157658576965, Correct predictions: 5050, Correct predictions test: 192
# Epoch 75, Loss: 0.4165586829185486, Correct predictions: 5050, Correct predictions test: 192
# Epoch 80, Loss: 0.3982499837875366, Correct predictions: 5050, Correct predictions test: 192
# Epoch 85, Loss: 0.38085228204727173, Correct predictions: 5050, Correct predictions test: 192
# Epoch 90, Loss: 0.3643152117729187, Correct predictions: 5050, Correct predictions test: 192
# Epoch 95, Loss: 0.34859180450439453, Correct predictions: 5050, Correct predictions test: 192
# Epoch 100, Loss: 0.3336375653743744, Correct predictions: 5050, Correct predictions test: 192
# Epoch 105, Loss: 0.3194107711315155, Correct predictions: 5050, Correct predictions test: 192
# Epoch 110, Loss: 0.3058719038963318, Correct predictions: 5050, Correct predictions test: 192
# Epoch 115, Loss: 0.29298415780067444, Correct predictions: 5050, Correct predictions test: 192
# Epoch 120, Loss: 0.2807125449180603, Correct predictions: 5050, Correct predictions test: 192
# Epoch 125, Loss: 0.26902422308921814, Correct predictions: 5050, Correct predictions test: 192
# Epoch 130, Loss: 0.2578880786895752, Correct predictions: 5050, Correct predictions test: 192
# Epoch 135, Loss: 0.2472752034664154, Correct predictions: 5050, Correct predictions test: 192
# Epoch 140, Loss: 0.23715786635875702, Correct predictions: 5050, Correct predictions test: 192
# Epoch 145, Loss: 0.2275102734565735, Correct predictions: 5050, Correct predictions test: 192
# Epoch 150, Loss: 0.2183079570531845, Correct predictions: 5150, Correct predictions test: 192
# Epoch 155, Loss: 0.20952780544757843, Correct predictions: 5500, Correct predictions test: 192
# Epoch 160, Loss: 0.201148122549057, Correct predictions: 5500, Correct predictions test: 192
# Epoch 165, Loss: 0.19314835965633392, Correct predictions: 5960, Correct predictions test: 192
# Epoch 170, Loss: 0.1855090856552124, Correct predictions: 5980, Correct predictions test: 192
# Epoch 175, Loss: 0.17821213603019714, Correct predictions: 6310, Correct predictions test: 192
# Epoch 180, Loss: 0.1712401807308197, Correct predictions: 6577, Correct predictions test: 192
# Epoch 185, Loss: 0.16457687318325043, Correct predictions: 6790, Correct predictions test: 192
# Epoch 190, Loss: 0.1582067608833313, Correct predictions: 7109, Correct predictions test: 192
# Epoch 195, Loss: 0.15211544930934906, Correct predictions: 7384, Correct predictions test: 192
# Epoch 200, Loss: 0.14628903567790985, Correct predictions: 7729, Correct predictions test: 192
# Epoch 205, Loss: 0.14071455597877502, Correct predictions: 8032, Correct predictions test: 192
# Epoch 210, Loss: 0.13537967205047607, Correct predictions: 8460, Correct predictions test: 192
# Epoch 215, Loss: 0.130272775888443, Correct predictions: 8791, Correct predictions test: 192
# Epoch 220, Loss: 0.1253829002380371, Correct predictions: 9127, Correct predictions test: 192
# Epoch 225, Loss: 0.12069953978061676, Correct predictions: 9610, Correct predictions test: 192
# Epoch 230, Loss: 0.1162128672003746, Correct predictions: 9793, Correct predictions test: 192
# Epoch 235, Loss: 0.11191354691982269, Correct predictions: 9874, Correct predictions test: 192
# Epoch 240, Loss: 0.1077926829457283, Correct predictions: 9925, Correct predictions test: 192
# Epoch 245, Loss: 0.1038418784737587, Correct predictions: 9960, Correct predictions test: 192
# Epoch 250, Loss: 0.10005336254835129, Correct predictions: 9985, Correct predictions test: 192
# Epoch 255, Loss: 0.09641940146684647, Correct predictions: 9994, Correct predictions test: 192
# Epoch 260, Loss: 0.09293298423290253, Correct predictions: 10000, Correct predictions test: 192
# Saved super_trained_model_2025_01_07_12_12_23.json
# Loaded trainable_model_2025_01_07_12_12_25.json
# Epoch 0, Loss: 90.49874877929688, Correct predictions: 1, Correct predictions test: 0
# Epoch 5, Loss: 2.4288482666015625, Correct predictions: 1601, Correct predictions test: 60
# Epoch 10, Loss: 1.0289909839630127, Correct predictions: 2831, Correct predictions test: 90
# Epoch 15, Loss: 0.6541659832000732, Correct predictions: 3604, Correct predictions test: 142
# Epoch 20, Loss: 0.5353575944900513, Correct predictions: 4733, Correct predictions test: 170
# Epoch 25, Loss: 0.48374027013778687, Correct predictions: 4986, Correct predictions test: 174
# Epoch 30, Loss: 0.45161208510398865, Correct predictions: 5027, Correct predictions test: 188
# Epoch 35, Loss: 0.4262809753417969, Correct predictions: 5055, Correct predictions test: 192
# Saved trained_model_2025_01_07_12_12_25.json
# Epoch 0, Loss: 0.4262809753417969, Correct predictions: 5055, Correct predictions test: 192
# Epoch 5, Loss: 0.3998640775680542, Correct predictions: 5075, Correct predictions test: 192
# Epoch 10, Loss: 0.3798387050628662, Correct predictions: 5205, Correct predictions test: 192
# Epoch 15, Loss: 0.3611598014831543, Correct predictions: 5266, Correct predictions test: 192
# Epoch 20, Loss: 0.343623548746109, Correct predictions: 5504, Correct predictions test: 192
# Epoch 25, Loss: 0.3271072506904602, Correct predictions: 5608, Correct predictions test: 192
# Epoch 30, Loss: 0.31152525544166565, Correct predictions: 5824, Correct predictions test: 192
# Epoch 35, Loss: 0.29680946469306946, Correct predictions: 6372, Correct predictions test: 192
# Epoch 40, Loss: 0.28290265798568726, Correct predictions: 6695, Correct predictions test: 192
# Epoch 45, Loss: 0.26975294947624207, Correct predictions: 7165, Correct predictions test: 192
# Epoch 50, Loss: 0.25731390714645386, Correct predictions: 7816, Correct predictions test: 192
# Epoch 55, Loss: 0.24554234743118286, Correct predictions: 8140, Correct predictions test: 192
# Epoch 60, Loss: 0.2343982458114624, Correct predictions: 8550, Correct predictions test: 192
# Epoch 65, Loss: 0.22384385764598846, Correct predictions: 8643, Correct predictions test: 192
# Epoch 70, Loss: 0.213844895362854, Correct predictions: 8806, Correct predictions test: 192
# Epoch 75, Loss: 0.20436763763427734, Correct predictions: 8891, Correct predictions test: 192
# Epoch 80, Loss: 0.19538208842277527, Correct predictions: 9022, Correct predictions test: 192
# Epoch 85, Loss: 0.18685954809188843, Correct predictions: 9175, Correct predictions test: 192
# Epoch 90, Loss: 0.1787729114294052, Correct predictions: 9229, Correct predictions test: 192
# Epoch 95, Loss: 0.17109671235084534, Correct predictions: 9348, Correct predictions test: 192
# Epoch 100, Loss: 0.16380766034126282, Correct predictions: 9460, Correct predictions test: 192
# Epoch 105, Loss: 0.1568836122751236, Correct predictions: 9533, Correct predictions test: 192
# Epoch 110, Loss: 0.15030363202095032, Correct predictions: 9608, Correct predictions test: 192
# Epoch 115, Loss: 0.1440480351448059, Correct predictions: 9685, Correct predictions test: 192
# Epoch 120, Loss: 0.1380988210439682, Correct predictions: 9757, Correct predictions test: 192
# Epoch 125, Loss: 0.13243867456912994, Correct predictions: 9816, Correct predictions test: 192
# Epoch 130, Loss: 0.127051442861557, Correct predictions: 9861, Correct predictions test: 192
# Epoch 135, Loss: 0.12192203104496002, Correct predictions: 9902, Correct predictions test: 192
# Epoch 140, Loss: 0.11703621596097946, Correct predictions: 9929, Correct predictions test: 192
# Epoch 145, Loss: 0.11238070577383041, Correct predictions: 9952, Correct predictions test: 192
# Epoch 150, Loss: 0.10794281959533691, Correct predictions: 9969, Correct predictions test: 192
# Epoch 155, Loss: 0.10371072590351105, Correct predictions: 9981, Correct predictions test: 192
# Epoch 160, Loss: 0.09967357665300369, Correct predictions: 9988, Correct predictions test: 192
# Epoch 165, Loss: 0.09582077711820602, Correct predictions: 9995, Correct predictions test: 192
# Epoch 170, Loss: 0.09214258193969727, Correct predictions: 9997, Correct predictions test: 192
# Epoch 175, Loss: 0.08862975984811783, Correct predictions: 9999, Correct predictions test: 192
# Epoch 180, Loss: 0.08527372032403946, Correct predictions: 10000, Correct predictions test: 192
# Saved super_trained_model_2025_01_07_12_12_25.json
# Loaded trainable_model_2025_01_07_12_12_27.json
# Epoch 0, Loss: 91.141845703125, Correct predictions: 90, Correct predictions test: 0
# Epoch 5, Loss: 1.5841537714004517, Correct predictions: 1916, Correct predictions test: 40
# Epoch 10, Loss: 1.0550991296768188, Correct predictions: 3584, Correct predictions test: 102
# Epoch 15, Loss: 0.8973639607429504, Correct predictions: 4349, Correct predictions test: 138
# Epoch 20, Loss: 0.8290349245071411, Correct predictions: 4458, Correct predictions test: 140
# Epoch 25, Loss: 0.7833602428436279, Correct predictions: 4488, Correct predictions test: 140
# Epoch 30, Loss: 0.744556188583374, Correct predictions: 4488, Correct predictions test: 140
# Epoch 35, Loss: 0.7088600397109985, Correct predictions: 4525, Correct predictions test: 140
# Epoch 40, Loss: 0.675322413444519, Correct predictions: 4600, Correct predictions test: 140
# Epoch 45, Loss: 0.6436481475830078, Correct predictions: 4640, Correct predictions test: 144
# Epoch 50, Loss: 0.6136915683746338, Correct predictions: 4717, Correct predictions test: 144
# Epoch 55, Loss: 0.5853450894355774, Correct predictions: 4776, Correct predictions test: 148
# Epoch 60, Loss: 0.5585124492645264, Correct predictions: 4841, Correct predictions test: 148
# Epoch 65, Loss: 0.5331041216850281, Correct predictions: 4880, Correct predictions test: 156
# Epoch 70, Loss: 0.5090363025665283, Correct predictions: 4921, Correct predictions test: 158
# Epoch 75, Loss: 0.48622989654541016, Correct predictions: 4962, Correct predictions test: 164
# Epoch 80, Loss: 0.4646115303039551, Correct predictions: 4993, Correct predictions test: 172
# Epoch 85, Loss: 0.4441113770008087, Correct predictions: 5006, Correct predictions test: 174
# Epoch 90, Loss: 0.42466503381729126, Correct predictions: 5023, Correct predictions test: 182
# Epoch 95, Loss: 0.40621131658554077, Correct predictions: 5034, Correct predictions test: 186
# Saved trained_model_2025_01_07_12_12_27.json
# Epoch 0, Loss: 0.39212459325790405, Correct predictions: 5212, Correct predictions test: 188
# Epoch 5, Loss: 0.3720569312572479, Correct predictions: 5348, Correct predictions test: 190
# Epoch 10, Loss: 0.3562525808811188, Correct predictions: 5525, Correct predictions test: 192
# Epoch 15, Loss: 0.3412327766418457, Correct predictions: 5722, Correct predictions test: 192
# Epoch 20, Loss: 0.32695329189300537, Correct predictions: 5859, Correct predictions test: 192
# Epoch 25, Loss: 0.3133726716041565, Correct predictions: 6110, Correct predictions test: 192
# Epoch 30, Loss: 0.3004518151283264, Correct predictions: 6322, Correct predictions test: 192
# Epoch 35, Loss: 0.28815415501594543, Correct predictions: 6675, Correct predictions test: 192
# Epoch 40, Loss: 0.2764453887939453, Correct predictions: 6914, Correct predictions test: 192
# Epoch 45, Loss: 0.265293151140213, Correct predictions: 7304, Correct predictions test: 192
# Epoch 50, Loss: 0.2546669542789459, Correct predictions: 7730, Correct predictions test: 192
# Epoch 55, Loss: 0.24453827738761902, Correct predictions: 8191, Correct predictions test: 192
# Epoch 60, Loss: 0.2348804473876953, Correct predictions: 8754, Correct predictions test: 192
# Epoch 65, Loss: 0.22566813230514526, Correct predictions: 9268, Correct predictions test: 192
# Epoch 70, Loss: 0.21687743067741394, Correct predictions: 9607, Correct predictions test: 192
# Epoch 75, Loss: 0.20848624408245087, Correct predictions: 9682, Correct predictions test: 192
# Epoch 80, Loss: 0.20047344267368317, Correct predictions: 9736, Correct predictions test: 192
# Epoch 85, Loss: 0.192819282412529, Correct predictions: 9826, Correct predictions test: 192
# Epoch 90, Loss: 0.18550512194633484, Correct predictions: 9865, Correct predictions test: 192
# Epoch 95, Loss: 0.17851340770721436, Correct predictions: 9925, Correct predictions test: 192
# Epoch 100, Loss: 0.17182761430740356, Correct predictions: 9956, Correct predictions test: 192
# Epoch 105, Loss: 0.1654321700334549, Correct predictions: 9979, Correct predictions test: 192
# Epoch 110, Loss: 0.15931230783462524, Correct predictions: 9988, Correct predictions test: 192
# Epoch 115, Loss: 0.1534542441368103, Correct predictions: 9997, Correct predictions test: 192
# Epoch 120, Loss: 0.14784498512744904, Correct predictions: 9999, Correct predictions test: 192
# Epoch 125, Loss: 0.14247208833694458, Correct predictions: 10000, Correct predictions test: 192
# Saved super_trained_model_2025_01_07_12_12_27.json
# Loaded trainable_model_2025_01_07_12_12_29.json
# Epoch 0, Loss: 62.57429885864258, Correct predictions: 28, Correct predictions test: 0
# Epoch 5, Loss: 1.855635643005371, Correct predictions: 1728, Correct predictions test: 8
# Epoch 10, Loss: 0.8310161828994751, Correct predictions: 3641, Correct predictions test: 36
# Epoch 15, Loss: 0.5623247623443604, Correct predictions: 5110, Correct predictions test: 94
# Epoch 20, Loss: 0.4748409390449524, Correct predictions: 5623, Correct predictions test: 106
# Epoch 25, Loss: 0.4318419396877289, Correct predictions: 6351, Correct predictions test: 136
# Epoch 30, Loss: 0.40080246329307556, Correct predictions: 6699, Correct predictions test: 142
# Epoch 35, Loss: 0.37395042181015015, Correct predictions: 6897, Correct predictions test: 144
# Epoch 40, Loss: 0.34937840700149536, Correct predictions: 7078, Correct predictions test: 144
# Epoch 45, Loss: 0.3265625238418579, Correct predictions: 7132, Correct predictions test: 144
# Epoch 50, Loss: 0.30530408024787903, Correct predictions: 7266, Correct predictions test: 144
# Epoch 55, Loss: 0.28548234701156616, Correct predictions: 7390, Correct predictions test: 144
# Epoch 60, Loss: 0.2669980525970459, Correct predictions: 7477, Correct predictions test: 148
# Epoch 65, Loss: 0.24976031482219696, Correct predictions: 7660, Correct predictions test: 152
# Epoch 70, Loss: 0.23368464410305023, Correct predictions: 7706, Correct predictions test: 164
# Epoch 75, Loss: 0.2186918705701828, Correct predictions: 7930, Correct predictions test: 172
# Epoch 80, Loss: 0.2047080397605896, Correct predictions: 7981, Correct predictions test: 188
# Epoch 85, Loss: 0.1916641891002655, Correct predictions: 8200, Correct predictions test: 192
# Saved trained_model_2025_01_07_12_12_29.json
# Epoch 0, Loss: 0.1916641891002655, Correct predictions: 8200, Correct predictions test: 192
# Epoch 5, Loss: 0.17716211080551147, Correct predictions: 8470, Correct predictions test: 192
# Epoch 10, Loss: 0.16596603393554688, Correct predictions: 8470, Correct predictions test: 192
# Epoch 15, Loss: 0.15551918745040894, Correct predictions: 8785, Correct predictions test: 192
# Epoch 20, Loss: 0.1457703709602356, Correct predictions: 9009, Correct predictions test: 192
# Epoch 25, Loss: 0.13667184114456177, Correct predictions: 9145, Correct predictions test: 192
# Epoch 30, Loss: 0.1281791627407074, Correct predictions: 9550, Correct predictions test: 192
# Epoch 35, Loss: 0.12025098502635956, Correct predictions: 10000, Correct predictions test: 192
# Saved super_trained_model_2025_01_07_12_12_29.json
# Loaded trainable_model_2025_01_07_12_12_31.json
# Epoch 0, Loss: 16.19673728942871, Correct predictions: 5, Correct predictions test: 0
# Epoch 5, Loss: 2.305328845977783, Correct predictions: 1298, Correct predictions test: 28
# Epoch 10, Loss: 1.8880763053894043, Correct predictions: 2615, Correct predictions test: 90
# Epoch 15, Loss: 1.716639757156372, Correct predictions: 2950, Correct predictions test: 98
# Epoch 20, Loss: 1.608803629875183, Correct predictions: 3054, Correct predictions test: 100
# Epoch 25, Loss: 1.5204108953475952, Correct predictions: 3285, Correct predictions test: 108
# Epoch 30, Loss: 1.4404553174972534, Correct predictions: 3497, Correct predictions test: 114
# Epoch 35, Loss: 1.365970253944397, Correct predictions: 3702, Correct predictions test: 134
# Epoch 40, Loss: 1.2959818840026855, Correct predictions: 3850, Correct predictions test: 144
# Epoch 45, Loss: 1.2300361394882202, Correct predictions: 4143, Correct predictions test: 158
# Epoch 50, Loss: 1.1678322553634644, Correct predictions: 4210, Correct predictions test: 164
# Epoch 55, Loss: 1.1091232299804688, Correct predictions: 4520, Correct predictions test: 176
# Epoch 60, Loss: 1.0536916255950928, Correct predictions: 4529, Correct predictions test: 176
# Epoch 65, Loss: 1.0013370513916016, Correct predictions: 4770, Correct predictions test: 188
# Epoch 70, Loss: 0.9518745541572571, Correct predictions: 4770, Correct predictions test: 188
# Epoch 75, Loss: 0.9051311612129211, Correct predictions: 4950, Correct predictions test: 190
# Epoch 80, Loss: 0.8609453439712524, Correct predictions: 4950, Correct predictions test: 190
# Epoch 85, Loss: 0.8191658854484558, Correct predictions: 5050, Correct predictions test: 192
# Saved trained_model_2025_01_07_12_12_31.json
# Epoch 0, Loss: 0.8191658854484558, Correct predictions: 5050, Correct predictions test: 192
# Epoch 5, Loss: 0.7720077037811279, Correct predictions: 5050, Correct predictions test: 192
# Epoch 10, Loss: 0.7350354194641113, Correct predictions: 5050, Correct predictions test: 192
# Epoch 15, Loss: 0.7000459432601929, Correct predictions: 5050, Correct predictions test: 192
# Epoch 20, Loss: 0.6669237613677979, Correct predictions: 5050, Correct predictions test: 192
# Epoch 25, Loss: 0.6355603933334351, Correct predictions: 5050, Correct predictions test: 192
# Epoch 30, Loss: 0.6058541536331177, Correct predictions: 5050, Correct predictions test: 192
# Epoch 35, Loss: 0.577709436416626, Correct predictions: 5050, Correct predictions test: 192
# Epoch 40, Loss: 0.5510367155075073, Correct predictions: 5050, Correct predictions test: 192
# Epoch 45, Loss: 0.5257517099380493, Correct predictions: 5050, Correct predictions test: 192
# Epoch 50, Loss: 0.5017752647399902, Correct predictions: 5050, Correct predictions test: 192
# Epoch 55, Loss: 0.47903314232826233, Correct predictions: 5050, Correct predictions test: 192
# Epoch 60, Loss: 0.45745542645454407, Correct predictions: 5050, Correct predictions test: 192
# Epoch 65, Loss: 0.4369765818119049, Correct predictions: 5060, Correct predictions test: 192
# Epoch 70, Loss: 0.4175350069999695, Correct predictions: 5060, Correct predictions test: 192
# Epoch 75, Loss: 0.39907270669937134, Correct predictions: 5080, Correct predictions test: 192
# Epoch 80, Loss: 0.381535142660141, Correct predictions: 5080, Correct predictions test: 192
# Epoch 85, Loss: 0.36487114429473877, Correct predictions: 5119, Correct predictions test: 192
# Epoch 90, Loss: 0.349032461643219, Correct predictions: 5177, Correct predictions test: 192
# Epoch 95, Loss: 0.3339739143848419, Correct predictions: 5227, Correct predictions test: 192
# Epoch 100, Loss: 0.31965261697769165, Correct predictions: 5322, Correct predictions test: 192
# Epoch 105, Loss: 0.3060286343097687, Correct predictions: 5444, Correct predictions test: 192
# Epoch 110, Loss: 0.29306402802467346, Correct predictions: 5737, Correct predictions test: 192
# Epoch 115, Loss: 0.2807234227657318, Correct predictions: 5839, Correct predictions test: 192
# Epoch 120, Loss: 0.26897311210632324, Correct predictions: 6046, Correct predictions test: 192
# Epoch 125, Loss: 0.2577817738056183, Correct predictions: 6171, Correct predictions test: 192
# Epoch 130, Loss: 0.2471194565296173, Correct predictions: 6376, Correct predictions test: 192
# Epoch 135, Loss: 0.23695828020572662, Correct predictions: 6479, Correct predictions test: 192
# Epoch 140, Loss: 0.2272719442844391, Correct predictions: 6643, Correct predictions test: 192
# Epoch 145, Loss: 0.21803542971611023, Correct predictions: 6726, Correct predictions test: 192
# Epoch 150, Loss: 0.20922532677650452, Correct predictions: 6965, Correct predictions test: 192
# Epoch 155, Loss: 0.20081953704357147, Correct predictions: 7091, Correct predictions test: 192
# Epoch 160, Loss: 0.1927971988916397, Correct predictions: 7348, Correct predictions test: 192
# Epoch 165, Loss: 0.1851385533809662, Correct predictions: 7577, Correct predictions test: 192
# Epoch 170, Loss: 0.17782515287399292, Correct predictions: 7844, Correct predictions test: 192
# Epoch 175, Loss: 0.17083939909934998, Correct predictions: 8164, Correct predictions test: 192
# Epoch 180, Loss: 0.164164736866951, Correct predictions: 8487, Correct predictions test: 192
# Epoch 185, Loss: 0.15778551995754242, Correct predictions: 8782, Correct predictions test: 192
# Epoch 190, Loss: 0.15168701112270355, Correct predictions: 9028, Correct predictions test: 192
# Epoch 195, Loss: 0.14585527777671814, Correct predictions: 9505, Correct predictions test: 192
# Epoch 200, Loss: 0.14027701318264008, Correct predictions: 10000, Correct predictions test: 192
# Saved super_trained_model_2025_01_07_12_12_31.json
# Loaded trainable_model_2025_01_07_12_13_25.json
# Epoch 0, Loss: 416.19476318359375, Correct predictions: 1, Correct predictions test: 0
# Epoch 5, Loss: 80.3563003540039, Correct predictions: 5, Correct predictions test: 0
# Epoch 10, Loss: 42.15214538574219, Correct predictions: 5, Correct predictions test: 0
# Epoch 15, Loss: 31.48419952392578, Correct predictions: 9, Correct predictions test: 0
# Epoch 20, Loss: 27.53194808959961, Correct predictions: 22, Correct predictions test: 0
# Epoch 25, Loss: 25.29627227783203, Correct predictions: 32, Correct predictions test: 0
# Epoch 30, Loss: 23.565168380737305, Correct predictions: 48, Correct predictions test: 0
# Epoch 35, Loss: 22.037431716918945, Correct predictions: 54, Correct predictions test: 0
# Epoch 40, Loss: 20.633007049560547, Correct predictions: 77, Correct predictions test: 0
# Epoch 45, Loss: 19.326581954956055, Correct predictions: 85, Correct predictions test: 2
# Epoch 50, Loss: 18.10701560974121, Correct predictions: 85, Correct predictions test: 2
# Epoch 55, Loss: 16.96719741821289, Correct predictions: 115, Correct predictions test: 6
# Epoch 60, Loss: 15.901422500610352, Correct predictions: 115, Correct predictions test: 6
# Epoch 65, Loss: 14.904654502868652, Correct predictions: 115, Correct predictions test: 6
# Epoch 70, Loss: 13.972285270690918, Correct predictions: 119, Correct predictions test: 6
# Epoch 75, Loss: 13.100055694580078, Correct predictions: 155, Correct predictions test: 8
# Epoch 80, Loss: 12.284005165100098, Correct predictions: 155, Correct predictions test: 8
# Epoch 85, Loss: 11.520437240600586, Correct predictions: 163, Correct predictions test: 8
# Epoch 90, Loss: 10.805910110473633, Correct predictions: 178, Correct predictions test: 8
# Epoch 95, Loss: 10.137207984924316, Correct predictions: 194, Correct predictions test: 14
# Saved trained_model_2025_01_07_12_13_25.json
# Epoch 0, Loss: 9.633218765258789, Correct predictions: 206, Correct predictions test: 14
# Epoch 5, Loss: 8.925477027893066, Correct predictions: 224, Correct predictions test: 16
# Epoch 10, Loss: 8.377029418945312, Correct predictions: 247, Correct predictions test: 20
# Epoch 15, Loss: 7.863549709320068, Correct predictions: 263, Correct predictions test: 20
# Epoch 20, Loss: 7.382753849029541, Correct predictions: 303, Correct predictions test: 22
# Epoch 25, Loss: 6.932514190673828, Correct predictions: 321, Correct predictions test: 24
# Epoch 30, Loss: 6.510840892791748, Correct predictions: 361, Correct predictions test: 36
# Epoch 35, Loss: 6.115878105163574, Correct predictions: 427, Correct predictions test: 42
# Epoch 40, Loss: 5.7458882331848145, Correct predictions: 465, Correct predictions test: 42
# Epoch 45, Loss: 5.399252891540527, Correct predictions: 537, Correct predictions test: 42
# Epoch 50, Loss: 5.074459075927734, Correct predictions: 576, Correct predictions test: 46
# Epoch 55, Loss: 4.7700934410095215, Correct predictions: 705, Correct predictions test: 46
# Epoch 60, Loss: 4.484833717346191, Correct predictions: 784, Correct predictions test: 48
# Epoch 65, Loss: 4.217446327209473, Correct predictions: 922, Correct predictions test: 58
# Epoch 70, Loss: 3.9667794704437256, Correct predictions: 1084, Correct predictions test: 66
# Epoch 75, Loss: 3.7317566871643066, Correct predictions: 1090, Correct predictions test: 66
# Epoch 80, Loss: 3.5113697052001953, Correct predictions: 1380, Correct predictions test: 80
# Epoch 85, Loss: 3.3046798706054688, Correct predictions: 1575, Correct predictions test: 82
# Epoch 90, Loss: 3.110807418823242, Correct predictions: 1735, Correct predictions test: 82
# Epoch 95, Loss: 2.928931713104248, Correct predictions: 1943, Correct predictions test: 90
# Epoch 100, Loss: 2.7582850456237793, Correct predictions: 2128, Correct predictions test: 92
# Epoch 105, Loss: 2.5981507301330566, Correct predictions: 2356, Correct predictions test: 94
# Epoch 110, Loss: 2.447856903076172, Correct predictions: 2571, Correct predictions test: 94
# Epoch 115, Loss: 2.3067779541015625, Correct predictions: 2832, Correct predictions test: 98
# Epoch 120, Loss: 2.174327850341797, Correct predictions: 3059, Correct predictions test: 100
# Epoch 125, Loss: 2.049957752227783, Correct predictions: 3309, Correct predictions test: 102
# Epoch 130, Loss: 1.9331562519073486, Correct predictions: 3562, Correct predictions test: 110
# Epoch 135, Loss: 1.8234442472457886, Correct predictions: 3732, Correct predictions test: 118
# Epoch 140, Loss: 1.7203733921051025, Correct predictions: 4014, Correct predictions test: 124
# Epoch 145, Loss: 1.6235252618789673, Correct predictions: 4252, Correct predictions test: 140
# Epoch 150, Loss: 1.5325080156326294, Correct predictions: 4401, Correct predictions test: 156
# Epoch 155, Loss: 1.4469552040100098, Correct predictions: 4616, Correct predictions test: 172
# Epoch 160, Loss: 1.3665237426757812, Correct predictions: 4800, Correct predictions test: 186
# Epoch 165, Loss: 1.290893316268921, Correct predictions: 4938, Correct predictions test: 188
# Epoch 170, Loss: 1.2197637557983398, Correct predictions: 5043, Correct predictions test: 190
# Epoch 175, Loss: 1.1528542041778564, Correct predictions: 5152, Correct predictions test: 192
# Epoch 180, Loss: 1.0899021625518799, Correct predictions: 5195, Correct predictions test: 192
# Epoch 185, Loss: 1.030661940574646, Correct predictions: 5235, Correct predictions test: 192
# Epoch 190, Loss: 0.9749033451080322, Correct predictions: 5235, Correct predictions test: 192
# Epoch 195, Loss: 0.9224106073379517, Correct predictions: 5255, Correct predictions test: 192
# Epoch 200, Loss: 0.8729826807975769, Correct predictions: 5365, Correct predictions test: 192
# Epoch 205, Loss: 0.8264304399490356, Correct predictions: 5365, Correct predictions test: 192
# Epoch 210, Loss: 0.7825775146484375, Correct predictions: 5365, Correct predictions test: 192
# Epoch 215, Loss: 0.7412579655647278, Correct predictions: 5540, Correct predictions test: 192
# Epoch 220, Loss: 0.702317476272583, Correct predictions: 5540, Correct predictions test: 192
# Epoch 225, Loss: 0.6656103134155273, Correct predictions: 5732, Correct predictions test: 192
# Epoch 230, Loss: 0.6310009956359863, Correct predictions: 5764, Correct predictions test: 192
# Epoch 235, Loss: 0.5983619689941406, Correct predictions: 5955, Correct predictions test: 192
# Epoch 240, Loss: 0.5675740242004395, Correct predictions: 6029, Correct predictions test: 192
# Epoch 245, Loss: 0.5385252237319946, Correct predictions: 6258, Correct predictions test: 192
# Epoch 250, Loss: 0.5111110210418701, Correct predictions: 6431, Correct predictions test: 192
# Epoch 255, Loss: 0.4852331280708313, Correct predictions: 6562, Correct predictions test: 192
# Epoch 260, Loss: 0.4607992172241211, Correct predictions: 6697, Correct predictions test: 192
# Epoch 265, Loss: 0.4377235174179077, Correct predictions: 6820, Correct predictions test: 192
# Epoch 270, Loss: 0.4159248471260071, Correct predictions: 6985, Correct predictions test: 192
# Epoch 275, Loss: 0.3953273594379425, Correct predictions: 7039, Correct predictions test: 192
# Epoch 280, Loss: 0.3758600950241089, Correct predictions: 7174, Correct predictions test: 192
# Epoch 285, Loss: 0.3574562668800354, Correct predictions: 7273, Correct predictions test: 192
# Epoch 290, Loss: 0.3400532007217407, Correct predictions: 7319, Correct predictions test: 192
# Epoch 295, Loss: 0.3235922157764435, Correct predictions: 7394, Correct predictions test: 192
# Epoch 300, Loss: 0.3080184757709503, Correct predictions: 7477, Correct predictions test: 192
# Epoch 305, Loss: 0.2932799458503723, Correct predictions: 7513, Correct predictions test: 192
# Epoch 310, Loss: 0.27932822704315186, Correct predictions: 7588, Correct predictions test: 192
# Epoch 315, Loss: 0.26611772179603577, Correct predictions: 7691, Correct predictions test: 192
# Epoch 320, Loss: 0.25360578298568726, Correct predictions: 7850, Correct predictions test: 192
# Epoch 325, Loss: 0.2417522668838501, Correct predictions: 8030, Correct predictions test: 192
# Epoch 330, Loss: 0.23051920533180237, Correct predictions: 8256, Correct predictions test: 192
# Epoch 335, Loss: 0.21987144649028778, Correct predictions: 8562, Correct predictions test: 192
# Epoch 340, Loss: 0.20977559685707092, Correct predictions: 8905, Correct predictions test: 192
# Epoch 345, Loss: 0.20020052790641785, Correct predictions: 9309, Correct predictions test: 192
# Epoch 350, Loss: 0.19111666083335876, Correct predictions: 9757, Correct predictions test: 192
# Epoch 355, Loss: 0.18249639868736267, Correct predictions: 10000, Correct predictions test: 192
# Saved super_trained_model_2025_01_07_12_13_25.json
# Loaded trainable_model_2025_01_07_12_13_27.json
# Epoch 0, Loss: 1223.8040771484375, Correct predictions: 1, Correct predictions test: 0
# Epoch 5, Loss: 50.60004425048828, Correct predictions: 5, Correct predictions test: 0
# Epoch 10, Loss: 31.52203369140625, Correct predictions: 5, Correct predictions test: 0
# Epoch 15, Loss: 25.95523452758789, Correct predictions: 9, Correct predictions test: 0
# Epoch 20, Loss: 23.583946228027344, Correct predictions: 18, Correct predictions test: 0
# Epoch 25, Loss: 21.99765396118164, Correct predictions: 22, Correct predictions test: 0
# Epoch 30, Loss: 20.642671585083008, Correct predictions: 40, Correct predictions test: 0
# Epoch 35, Loss: 19.394973754882812, Correct predictions: 53, Correct predictions test: 0
# Epoch 40, Loss: 18.22686004638672, Correct predictions: 53, Correct predictions test: 0
# Epoch 45, Loss: 17.130754470825195, Correct predictions: 53, Correct predictions test: 0
# Epoch 50, Loss: 16.102630615234375, Correct predictions: 53, Correct predictions test: 0
# Epoch 55, Loss: 15.138805389404297, Correct predictions: 53, Correct predictions test: 0
# Epoch 60, Loss: 14.235559463500977, Correct predictions: 53, Correct predictions test: 0
# Epoch 65, Loss: 13.389185905456543, Correct predictions: 65, Correct predictions test: 0
# Epoch 70, Loss: 12.596104621887207, Correct predictions: 81, Correct predictions test: 0
# Epoch 75, Loss: 11.85290813446045, Correct predictions: 105, Correct predictions test: 0
# Epoch 80, Loss: 11.156373977661133, Correct predictions: 105, Correct predictions test: 0
# Epoch 85, Loss: 10.503484725952148, Correct predictions: 105, Correct predictions test: 0
# Epoch 90, Loss: 9.891412734985352, Correct predictions: 105, Correct predictions test: 0
# Epoch 95, Loss: 9.317511558532715, Correct predictions: 121, Correct predictions test: 0
# Saved trained_model_2025_01_07_12_13_27.json
# Epoch 0, Loss: 8.884207725524902, Correct predictions: 136, Correct predictions test: 0
# Epoch 5, Loss: 8.274499893188477, Correct predictions: 136, Correct predictions test: 0
# Epoch 10, Loss: 7.800921440124512, Correct predictions: 148, Correct predictions test: 2
# Epoch 15, Loss: 7.356561660766602, Correct predictions: 198, Correct predictions test: 2
# Epoch 20, Loss: 6.939540386199951, Correct predictions: 225, Correct predictions test: 2
# Epoch 25, Loss: 6.548097610473633, Correct predictions: 225, Correct predictions test: 2
# Epoch 30, Loss: 6.180593490600586, Correct predictions: 243, Correct predictions test: 4
# Epoch 35, Loss: 5.835492134094238, Correct predictions: 268, Correct predictions test: 4
# Epoch 40, Loss: 5.5113630294799805, Correct predictions: 268, Correct predictions test: 4
# Epoch 45, Loss: 5.206864356994629, Correct predictions: 306, Correct predictions test: 4
# Epoch 50, Loss: 4.920746803283691, Correct predictions: 396, Correct predictions test: 4
# Epoch 55, Loss: 4.651840686798096, Correct predictions: 396, Correct predictions test: 4
# Epoch 60, Loss: 4.399052619934082, Correct predictions: 426, Correct predictions test: 4
# Epoch 65, Loss: 4.161363124847412, Correct predictions: 455, Correct predictions test: 8
# Epoch 70, Loss: 3.937817096710205, Correct predictions: 491, Correct predictions test: 8
# Epoch 75, Loss: 3.727522373199463, Correct predictions: 624, Correct predictions test: 8
# Epoch 80, Loss: 3.5296454429626465, Correct predictions: 682, Correct predictions test: 14
# Epoch 85, Loss: 3.3434059619903564, Correct predictions: 717, Correct predictions test: 14
# Epoch 90, Loss: 3.1680748462677, Correct predictions: 741, Correct predictions test: 18
# Epoch 95, Loss: 3.002971649169922, Correct predictions: 903, Correct predictions test: 20
# Epoch 100, Loss: 2.8474578857421875, Correct predictions: 1032, Correct predictions test: 20
# Epoch 105, Loss: 2.700937271118164, Correct predictions: 1097, Correct predictions test: 28
# Epoch 110, Loss: 2.562852382659912, Correct predictions: 1407, Correct predictions test: 40
# Epoch 115, Loss: 2.432681083679199, Correct predictions: 1779, Correct predictions test: 50
# Epoch 120, Loss: 2.3099353313446045, Correct predictions: 1943, Correct predictions test: 58
# Epoch 125, Loss: 2.1941590309143066, Correct predictions: 2043, Correct predictions test: 58
# Epoch 130, Loss: 2.0849242210388184, Correct predictions: 2610, Correct predictions test: 84
# Epoch 135, Loss: 1.9818315505981445, Correct predictions: 2880, Correct predictions test: 90
# Epoch 140, Loss: 1.8845058679580688, Correct predictions: 3007, Correct predictions test: 94
# Epoch 145, Loss: 1.792597770690918, Correct predictions: 3299, Correct predictions test: 108
# Epoch 150, Loss: 1.7057788372039795, Correct predictions: 3613, Correct predictions test: 116
# Epoch 155, Loss: 1.6237412691116333, Correct predictions: 3765, Correct predictions test: 118
# Epoch 160, Loss: 1.546197772026062, Correct predictions: 4017, Correct predictions test: 130
# Epoch 165, Loss: 1.4728789329528809, Correct predictions: 4315, Correct predictions test: 138
# Epoch 170, Loss: 1.4035320281982422, Correct predictions: 4369, Correct predictions test: 144
# Epoch 175, Loss: 1.3379216194152832, Correct predictions: 4460, Correct predictions test: 144
# Epoch 180, Loss: 1.2758255004882812, Correct predictions: 4570, Correct predictions test: 144
# Epoch 185, Loss: 1.2170358896255493, Correct predictions: 4600, Correct predictions test: 144
# Epoch 190, Loss: 1.16135835647583, Correct predictions: 4696, Correct predictions test: 144
# Epoch 195, Loss: 1.1086108684539795, Correct predictions: 4768, Correct predictions test: 144
# Epoch 200, Loss: 1.058621883392334, Correct predictions: 4831, Correct predictions test: 148
# Epoch 205, Loss: 1.0112310647964478, Correct predictions: 4885, Correct predictions test: 150
# Epoch 210, Loss: 0.9662882685661316, Correct predictions: 4930, Correct predictions test: 152
# Epoch 215, Loss: 0.923652172088623, Correct predictions: 4975, Correct predictions test: 166
# Epoch 220, Loss: 0.8831908702850342, Correct predictions: 5012, Correct predictions test: 172
# Epoch 225, Loss: 0.8447797298431396, Correct predictions: 5035, Correct predictions test: 182
# Epoch 230, Loss: 0.8083022832870483, Correct predictions: 5047, Correct predictions test: 190
# Epoch 235, Loss: 0.7736493349075317, Correct predictions: 5050, Correct predictions test: 192
# Epoch 240, Loss: 0.7407179474830627, Correct predictions: 5050, Correct predictions test: 192
# Epoch 245, Loss: 0.7094113230705261, Correct predictions: 5050, Correct predictions test: 192
# Epoch 250, Loss: 0.6796393394470215, Correct predictions: 5050, Correct predictions test: 192
# Epoch 255, Loss: 0.6513168811798096, Correct predictions: 5050, Correct predictions test: 192
# Epoch 260, Loss: 0.6243636608123779, Correct predictions: 5050, Correct predictions test: 192
# Epoch 265, Loss: 0.5987048149108887, Correct predictions: 5050, Correct predictions test: 192
# Epoch 270, Loss: 0.5742695331573486, Correct predictions: 5050, Correct predictions test: 192
# Epoch 275, Loss: 0.5509910583496094, Correct predictions: 5050, Correct predictions test: 192
# Epoch 280, Loss: 0.5288072824478149, Correct predictions: 5050, Correct predictions test: 192
# Epoch 285, Loss: 0.5076592564582825, Correct predictions: 5050, Correct predictions test: 192
# Epoch 290, Loss: 0.4874914586544037, Correct predictions: 5050, Correct predictions test: 192
# Epoch 295, Loss: 0.46825259923934937, Correct predictions: 5050, Correct predictions test: 192
# Epoch 300, Loss: 0.44989264011383057, Correct predictions: 5050, Correct predictions test: 192
# Epoch 305, Loss: 0.43236613273620605, Correct predictions: 5050, Correct predictions test: 192
# Epoch 310, Loss: 0.41562962532043457, Correct predictions: 5050, Correct predictions test: 192
# Epoch 315, Loss: 0.39964163303375244, Correct predictions: 5050, Correct predictions test: 192
# Epoch 320, Loss: 0.38436397910118103, Correct predictions: 5050, Correct predictions test: 192
# Epoch 325, Loss: 0.36976030468940735, Correct predictions: 5050, Correct predictions test: 192
# Epoch 330, Loss: 0.35579630732536316, Correct predictions: 5050, Correct predictions test: 192
# Epoch 335, Loss: 0.34243959188461304, Correct predictions: 5050, Correct predictions test: 192
# Epoch 340, Loss: 0.3296595811843872, Correct predictions: 5050, Correct predictions test: 192
# Epoch 345, Loss: 0.3174275755882263, Correct predictions: 5050, Correct predictions test: 192
# Epoch 350, Loss: 0.30571645498275757, Correct predictions: 5050, Correct predictions test: 192
# Epoch 355, Loss: 0.2945003807544708, Correct predictions: 5050, Correct predictions test: 192
# Epoch 360, Loss: 0.283755362033844, Correct predictions: 5050, Correct predictions test: 192
# Epoch 365, Loss: 0.2734582722187042, Correct predictions: 5060, Correct predictions test: 192
# Epoch 370, Loss: 0.26358771324157715, Correct predictions: 5069, Correct predictions test: 192
# Epoch 375, Loss: 0.25412309169769287, Correct predictions: 5097, Correct predictions test: 192
# Epoch 380, Loss: 0.24504512548446655, Correct predictions: 5122, Correct predictions test: 192
# Epoch 385, Loss: 0.23633550107479095, Correct predictions: 5144, Correct predictions test: 192
# Epoch 390, Loss: 0.227976992726326, Correct predictions: 5220, Correct predictions test: 192
# Epoch 395, Loss: 0.2199532836675644, Correct predictions: 5260, Correct predictions test: 192
# Epoch 400, Loss: 0.21224863827228546, Correct predictions: 5334, Correct predictions test: 192
# Epoch 405, Loss: 0.2048485279083252, Correct predictions: 5398, Correct predictions test: 192
# Epoch 410, Loss: 0.19773906469345093, Correct predictions: 5502, Correct predictions test: 192
# Epoch 415, Loss: 0.19090697169303894, Correct predictions: 5591, Correct predictions test: 192
# Epoch 420, Loss: 0.1843397319316864, Correct predictions: 5717, Correct predictions test: 192
# Epoch 425, Loss: 0.17802563309669495, Correct predictions: 5835, Correct predictions test: 192
# Epoch 430, Loss: 0.17195342481136322, Correct predictions: 6005, Correct predictions test: 192
# Epoch 435, Loss: 0.16611233353614807, Correct predictions: 6240, Correct predictions test: 192
# Epoch 440, Loss: 0.16049227118492126, Correct predictions: 6360, Correct predictions test: 192
# Epoch 445, Loss: 0.1550837606191635, Correct predictions: 6618, Correct predictions test: 192
# Epoch 450, Loss: 0.1498774141073227, Correct predictions: 6917, Correct predictions test: 192
# Epoch 455, Loss: 0.1448647379875183, Correct predictions: 7226, Correct predictions test: 192
# Epoch 460, Loss: 0.14003735780715942, Correct predictions: 7583, Correct predictions test: 192
# Epoch 465, Loss: 0.1353876143693924, Correct predictions: 7743, Correct predictions test: 192
# Epoch 470, Loss: 0.13090795278549194, Correct predictions: 8031, Correct predictions test: 192
# Epoch 475, Loss: 0.1265912652015686, Correct predictions: 8325, Correct predictions test: 192
# Epoch 480, Loss: 0.12243074178695679, Correct predictions: 8561, Correct predictions test: 192
# Epoch 485, Loss: 0.11842012405395508, Correct predictions: 8756, Correct predictions test: 192
# Epoch 490, Loss: 0.1145530492067337, Correct predictions: 8828, Correct predictions test: 192
# Epoch 495, Loss: 0.11082375794649124, Correct predictions: 8986, Correct predictions test: 192
# Saved super_trained_model_2025_01_07_12_13_27.json
# Loaded trainable_model_2025_01_07_12_13_29.json
# Epoch 0, Loss: 1360.478271484375, Correct predictions: 1, Correct predictions test: 0
# Epoch 5, Loss: 48.87952423095703, Correct predictions: 14, Correct predictions test: 0
# Epoch 10, Loss: 16.600048065185547, Correct predictions: 55, Correct predictions test: 0
# Epoch 15, Loss: 9.191999435424805, Correct predictions: 52, Correct predictions test: 0
# Epoch 20, Loss: 7.440629005432129, Correct predictions: 101, Correct predictions test: 0
# Epoch 25, Loss: 6.913938999176025, Correct predictions: 150, Correct predictions test: 2
# Epoch 30, Loss: 6.6257405281066895, Correct predictions: 188, Correct predictions test: 2
# Epoch 35, Loss: 6.374292373657227, Correct predictions: 235, Correct predictions test: 6
# Epoch 40, Loss: 6.127203941345215, Correct predictions: 300, Correct predictions test: 6
# Epoch 45, Loss: 5.884005546569824, Correct predictions: 351, Correct predictions test: 6
# Epoch 50, Loss: 5.6477885246276855, Correct predictions: 389, Correct predictions test: 10
# Epoch 55, Loss: 5.42056131362915, Correct predictions: 440, Correct predictions test: 10
# Epoch 60, Loss: 5.203161239624023, Correct predictions: 470, Correct predictions test: 10
# Epoch 65, Loss: 4.995720863342285, Correct predictions: 505, Correct predictions test: 10
# Epoch 70, Loss: 4.798015594482422, Correct predictions: 590, Correct predictions test: 10
# Epoch 75, Loss: 4.609661102294922, Correct predictions: 658, Correct predictions test: 10
# Epoch 80, Loss: 4.430206298828125, Correct predictions: 700, Correct predictions test: 10
# Epoch 85, Loss: 4.259189605712891, Correct predictions: 730, Correct predictions test: 10
# Epoch 90, Loss: 4.096155166625977, Correct predictions: 808, Correct predictions test: 10
# Epoch 95, Loss: 3.9406685829162598, Correct predictions: 856, Correct predictions test: 10
# Saved trained_model_2025_01_07_12_13_29.json
# Epoch 0, Loss: 3.8214335441589355, Correct predictions: 984, Correct predictions test: 10
# Epoch 5, Loss: 3.6507043838500977, Correct predictions: 1033, Correct predictions test: 10
# Epoch 10, Loss: 3.515470504760742, Correct predictions: 1110, Correct predictions test: 10
# Epoch 15, Loss: 3.386268377304077, Correct predictions: 1305, Correct predictions test: 22
# Epoch 20, Loss: 3.262773036956787, Correct predictions: 1461, Correct predictions test: 28
# Epoch 25, Loss: 3.1446824073791504, Correct predictions: 1517, Correct predictions test: 28
# Epoch 30, Loss: 3.031708240509033, Correct predictions: 1605, Correct predictions test: 30
# Epoch 35, Loss: 2.923584461212158, Correct predictions: 1725, Correct predictions test: 36
# Epoch 40, Loss: 2.8200559616088867, Correct predictions: 1877, Correct predictions test: 46
# Epoch 45, Loss: 2.720888137817383, Correct predictions: 1985, Correct predictions test: 46
# Epoch 50, Loss: 2.625856876373291, Correct predictions: 2102, Correct predictions test: 50
# Epoch 55, Loss: 2.5347533226013184, Correct predictions: 2345, Correct predictions test: 54
# Epoch 60, Loss: 2.4473788738250732, Correct predictions: 2441, Correct predictions test: 56
# Epoch 65, Loss: 2.363548755645752, Correct predictions: 2702, Correct predictions test: 62
# Epoch 70, Loss: 2.2830872535705566, Correct predictions: 2980, Correct predictions test: 70
# Epoch 75, Loss: 2.2058305740356445, Correct predictions: 3028, Correct predictions test: 80
# Epoch 80, Loss: 2.131622791290283, Correct predictions: 3028, Correct predictions test: 80
# Epoch 85, Loss: 2.0603182315826416, Correct predictions: 3028, Correct predictions test: 80
# Epoch 90, Loss: 1.9917783737182617, Correct predictions: 3028, Correct predictions test: 80
# Epoch 95, Loss: 1.9258723258972168, Correct predictions: 3057, Correct predictions test: 80
# Epoch 100, Loss: 1.8624789714813232, Correct predictions: 3129, Correct predictions test: 80
# Epoch 105, Loss: 1.8014813661575317, Correct predictions: 3201, Correct predictions test: 84
# Epoch 110, Loss: 1.7427691221237183, Correct predictions: 3201, Correct predictions test: 84
# Epoch 115, Loss: 1.686239242553711, Correct predictions: 3201, Correct predictions test: 84
# Epoch 120, Loss: 1.6317942142486572, Correct predictions: 3230, Correct predictions test: 98
# Epoch 125, Loss: 1.5793406963348389, Correct predictions: 3230, Correct predictions test: 98
# ...
# Epoch 240, Loss: 5.923672676086426, Correct predictions: 2525, Correct predictions test: 56
# Epoch 245, Loss: 5.754101753234863, Correct predictions: 2525, Correct predictions test: 56
# Epoch 250, Loss: 5.589609146118164, Correct predictions: 2525, Correct predictions test: 56
# Epoch 255, Loss: 5.430019855499268, Correct predictions: 2525, Correct predictions test: 56
# Epoch 260, Loss: 5.275167465209961, Correct predictions: 2545, Correct predictions test: 56
# Epoch 265, Loss: 5.1248931884765625, Correct predictions: 2655, Correct predictions test: 56
# Epoch 270, Loss: 4.979045867919922, Correct predictions: 2655, Correct predictions test: 56
# Epoch 275, Loss: 4.837479114532471, Correct predictions: 2655, Correct predictions test: 56
# Epoch 280, Loss: 4.700055122375488, Correct predictions: 2655, Correct predictions test: 56
# Epoch 285, Loss: 4.566636085510254, Correct predictions: 2655, Correct predictions test: 56
# Epoch 290, Loss: 4.437097549438477, Correct predictions: 2655, Correct predictions test: 56
# Epoch 295, Loss: 4.311315059661865, Correct predictions: 2655, Correct predictions test: 56
# Epoch 300, Loss: 4.189168930053711, Correct predictions: 2655, Correct predictions test: 56
# Epoch 305, Loss: 4.070547580718994, Correct predictions: 2835, Correct predictions test: 68
# Epoch 310, Loss: 3.9553375244140625, Correct predictions: 2835, Correct predictions test: 68
# Epoch 315, Loss: 3.843437671661377, Correct predictions: 2835, Correct predictions test: 68
# Epoch 320, Loss: 3.734741687774658, Correct predictions: 2835, Correct predictions test: 68
# Epoch 325, Loss: 3.6291561126708984, Correct predictions: 2835, Correct predictions test: 68
# Epoch 330, Loss: 3.5265839099884033, Correct predictions: 2835, Correct predictions test: 68
# Epoch 335, Loss: 3.4269347190856934, Correct predictions: 2835, Correct predictions test: 68
# Epoch 340, Loss: 3.3301212787628174, Correct predictions: 2865, Correct predictions test: 68
# Epoch 345, Loss: 3.236057758331299, Correct predictions: 2891, Correct predictions test: 68
# Epoch 350, Loss: 3.1446633338928223, Correct predictions: 2972, Correct predictions test: 68
# Epoch 355, Loss: 3.0558598041534424, Correct predictions: 2980, Correct predictions test: 70
# Epoch 360, Loss: 2.969569683074951, Correct predictions: 3028, Correct predictions test: 80
# Epoch 365, Loss: 2.8857192993164062, Correct predictions: 3028, Correct predictions test: 80
# Epoch 370, Loss: 2.804236650466919, Correct predictions: 3028, Correct predictions test: 80
# Epoch 375, Loss: 2.7250547409057617, Correct predictions: 3028, Correct predictions test: 80
# Epoch 380, Loss: 2.6481053829193115, Correct predictions: 3057, Correct predictions test: 80
# Epoch 385, Loss: 2.5733249187469482, Correct predictions: 3129, Correct predictions test: 80
# Epoch 390, Loss: 2.500649929046631, Correct predictions: 3201, Correct predictions test: 84
# Epoch 395, Loss: 2.430020332336426, Correct predictions: 3201, Correct predictions test: 84
# Epoch 400, Loss: 2.361377716064453, Correct predictions: 3201, Correct predictions test: 84
# Epoch 405, Loss: 2.2946648597717285, Correct predictions: 3230, Correct predictions test: 98
# Epoch 410, Loss: 2.229827642440796, Correct predictions: 3230, Correct predictions test: 98
# Epoch 415, Loss: 2.166811227798462, Correct predictions: 3240, Correct predictions test: 98
# Epoch 420, Loss: 2.105564594268799, Correct predictions: 3367, Correct predictions test: 104
# Epoch 425, Loss: 2.0460383892059326, Correct predictions: 3430, Correct predictions test: 110
# Epoch 430, Loss: 1.988183617591858, Correct predictions: 3430, Correct predictions test: 110
# Epoch 435, Loss: 1.9319522380828857, Correct predictions: 3430, Correct predictions test: 110
# Epoch 440, Loss: 1.8772993087768555, Correct predictions: 3430, Correct predictions test: 110
# Epoch 445, Loss: 1.8241798877716064, Correct predictions: 3494, Correct predictions test: 112
# Epoch 450, Loss: 1.7725512981414795, Correct predictions: 3560, Correct predictions test: 112
# Epoch 455, Loss: 1.7223715782165527, Correct predictions: 3616, Correct predictions test: 114
# Epoch 460, Loss: 1.6735997200012207, Correct predictions: 3670, Correct predictions test: 116
# Epoch 465, Loss: 1.6261968612670898, Correct predictions: 3670, Correct predictions test: 116
# Epoch 470, Loss: 1.5801242589950562, Correct predictions: 3670, Correct predictions test: 116
# Epoch 475, Loss: 1.5353448390960693, Correct predictions: 3715, Correct predictions test: 116
# Epoch 480, Loss: 1.4918224811553955, Correct predictions: 3812, Correct predictions test: 118
# Epoch 485, Loss: 1.4495218992233276, Correct predictions: 3860, Correct predictions test: 124
# Epoch 490, Loss: 1.4084093570709229, Correct predictions: 3914, Correct predictions test: 124
# Epoch 495, Loss: 1.3684512376785278, Correct predictions: 3934, Correct predictions test: 124
# Saved super_trained_model_2025_01_07_12_13_41.json
# Loaded trainable_model_2025_01_07_12_13_43.json
# Epoch 0, Loss: 308.1059875488281, Correct predictions: 1, Correct predictions test: 0
# Epoch 5, Loss: 103.58487701416016, Correct predictions: 5, Correct predictions test: 0
# Epoch 10, Loss: 91.79086303710938, Correct predictions: 7, Correct predictions test: 0
# Epoch 15, Loss: 85.62213134765625, Correct predictions: 9, Correct predictions test: 0
# Epoch 20, Loss: 80.93089294433594, Correct predictions: 9, Correct predictions test: 0
# Epoch 25, Loss: 76.74809265136719, Correct predictions: 9, Correct predictions test: 0
# Epoch 30, Loss: 72.84678649902344, Correct predictions: 9, Correct predictions test: 0
# Epoch 35, Loss: 69.16973114013672, Correct predictions: 15, Correct predictions test: 0
# Epoch 40, Loss: 65.69702911376953, Correct predictions: 15, Correct predictions test: 0
# Epoch 45, Loss: 62.41640853881836, Correct predictions: 15, Correct predictions test: 0
# Epoch 50, Loss: 59.31709289550781, Correct predictions: 15, Correct predictions test: 0
# Epoch 55, Loss: 56.38880157470703, Correct predictions: 15, Correct predictions test: 0
# Epoch 60, Loss: 53.621620178222656, Correct predictions: 15, Correct predictions test: 0
# Epoch 65, Loss: 51.00611877441406, Correct predictions: 15, Correct predictions test: 0
# Epoch 70, Loss: 48.533382415771484, Correct predictions: 15, Correct predictions test: 0
# Epoch 75, Loss: 46.19499969482422, Correct predictions: 21, Correct predictions test: 0
# Epoch 80, Loss: 43.983062744140625, Correct predictions: 21, Correct predictions test: 0
# Epoch 85, Loss: 41.890167236328125, Correct predictions: 21, Correct predictions test: 0
# Epoch 90, Loss: 39.909324645996094, Correct predictions: 25, Correct predictions test: 0
# Epoch 95, Loss: 38.03401184082031, Correct predictions: 31, Correct predictions test: 0
# Saved trained_model_2025_01_07_12_13_43.json
# Epoch 0, Loss: 36.6056022644043, Correct predictions: 31, Correct predictions test: 0
# Epoch 5, Loss: 34.57578659057617, Correct predictions: 39, Correct predictions test: 0
# Epoch 10, Loss: 32.98171615600586, Correct predictions: 39, Correct predictions test: 0
# Epoch 15, Loss: 31.470792770385742, Correct predictions: 39, Correct predictions test: 0
# Epoch 20, Loss: 30.038257598876953, Correct predictions: 39, Correct predictions test: 0
# Epoch 25, Loss: 28.679637908935547, Correct predictions: 39, Correct predictions test: 0
# Epoch 30, Loss: 27.390727996826172, Correct predictions: 53, Correct predictions test: 0
# Epoch 35, Loss: 26.167591094970703, Correct predictions: 63, Correct predictions test: 0
# Epoch 40, Loss: 25.006507873535156, Correct predictions: 67, Correct predictions test: 0
# Epoch 45, Loss: 23.904001235961914, Correct predictions: 67, Correct predictions test: 0
# Epoch 50, Loss: 22.856792449951172, Correct predictions: 79, Correct predictions test: 0
# Epoch 55, Loss: 21.8618106842041, Correct predictions: 79, Correct predictions test: 0
# Epoch 60, Loss: 20.916154861450195, Correct predictions: 100, Correct predictions test: 0
# Epoch 65, Loss: 20.017107009887695, Correct predictions: 120, Correct predictions test: 0
# Epoch 70, Loss: 19.162109375, Correct predictions: 138, Correct predictions test: 0
# Epoch 75, Loss: 18.348751068115234, Correct predictions: 138, Correct predictions test: 0
# Epoch 80, Loss: 17.57477378845215, Correct predictions: 150, Correct predictions test: 0
# Epoch 85, Loss: 16.838035583496094, Correct predictions: 157, Correct predictions test: 0
# Epoch 90, Loss: 16.136537551879883, Correct predictions: 187, Correct predictions test: 0
# Epoch 95, Loss: 15.468385696411133, Correct predictions: 208, Correct predictions test: 0
# Epoch 100, Loss: 14.831802368164062, Correct predictions: 228, Correct predictions test: 0
# Epoch 105, Loss: 14.225111961364746, Correct predictions: 260, Correct predictions test: 0
# Epoch 110, Loss: 13.646732330322266, Correct predictions: 376, Correct predictions test: 4
# Epoch 115, Loss: 13.095181465148926, Correct predictions: 481, Correct predictions test: 4
# Epoch 120, Loss: 12.569053649902344, Correct predictions: 513, Correct predictions test: 4
# Epoch 125, Loss: 12.067025184631348, Correct predictions: 527, Correct predictions test: 4
# Epoch 130, Loss: 11.587852478027344, Correct predictions: 646, Correct predictions test: 10
# Epoch 135, Loss: 11.130355834960938, Correct predictions: 789, Correct predictions test: 10
# Epoch 140, Loss: 10.693429946899414, Correct predictions: 929, Correct predictions test: 12
# Epoch 145, Loss: 10.276023864746094, Correct predictions: 994, Correct predictions test: 12
# Epoch 150, Loss: 9.877153396606445, Correct predictions: 1127, Correct predictions test: 14
# Epoch 155, Loss: 9.49588394165039, Correct predictions: 1177, Correct predictions test: 14
# Epoch 160, Loss: 9.131336212158203, Correct predictions: 1231, Correct predictions test: 14
# Epoch 165, Loss: 8.78267765045166, Correct predictions: 1231, Correct predictions test: 14
# Epoch 170, Loss: 8.449119567871094, Correct predictions: 1393, Correct predictions test: 18
# Epoch 175, Loss: 8.129919052124023, Correct predictions: 1501, Correct predictions test: 18
# Epoch 180, Loss: 7.82437801361084, Correct predictions: 1543, Correct predictions test: 20
# Epoch 185, Loss: 7.531828880310059, Correct predictions: 1555, Correct predictions test: 22
# Epoch 190, Loss: 7.251643180847168, Correct predictions: 1561, Correct predictions test: 22
# Epoch 195, Loss: 6.983227729797363, Correct predictions: 1694, Correct predictions test: 28
# Epoch 200, Loss: 6.726021766662598, Correct predictions: 1813, Correct predictions test: 40
# Epoch 205, Loss: 6.479489326477051, Correct predictions: 1918, Correct predictions test: 40
# Epoch 210, Loss: 6.243130683898926, Correct predictions: 2005, Correct predictions test: 40
# Epoch 215, Loss: 6.016464710235596, Correct predictions: 2040, Correct predictions test: 40
# Epoch 220, Loss: 5.799040794372559, Correct predictions: 2148, Correct predictions test: 44
# Epoch 225, Loss: 5.59043025970459, Correct predictions: 2220, Correct predictions test: 46
# Epoch 230, Loss: 5.3902268409729, Correct predictions: 2305, Correct predictions test: 48
# Epoch 235, Loss: 5.198045253753662, Correct predictions: 2375, Correct predictions test: 50
# Epoch 240, Loss: 5.01352071762085, Correct predictions: 2375, Correct predictions test: 50
# Epoch 245, Loss: 4.836306095123291, Correct predictions: 2513, Correct predictions test: 50
# Epoch 250, Loss: 4.666073322296143, Correct predictions: 2616, Correct predictions test: 52
# Epoch 255, Loss: 4.502509117126465, Correct predictions: 2697, Correct predictions test: 52
# Epoch 260, Loss: 4.345317840576172, Correct predictions: 2849, Correct predictions test: 54
# Epoch 265, Loss: 4.194217681884766, Correct predictions: 2849, Correct predictions test: 54
# Epoch 270, Loss: 4.048941135406494, Correct predictions: 2972, Correct predictions test: 60
# Epoch 275, Loss: 3.9092345237731934, Correct predictions: 3126, Correct predictions test: 62
# Epoch 280, Loss: 3.774855613708496, Correct predictions: 3270, Correct predictions test: 66
# Epoch 285, Loss: 3.6455750465393066, Correct predictions: 3331, Correct predictions test: 72
# Epoch 290, Loss: 3.521174430847168, Correct predictions: 3460, Correct predictions test: 82
# Epoch 295, Loss: 3.401444911956787, Correct predictions: 3468, Correct predictions test: 84
# Epoch 300, Loss: 3.286189079284668, Correct predictions: 3614, Correct predictions test: 88
# Epoch 305, Loss: 3.175220012664795, Correct predictions: 3614, Correct predictions test: 88
# Epoch 310, Loss: 3.0683555603027344, Correct predictions: 3701, Correct predictions test: 92
# Epoch 315, Loss: 2.9654273986816406, Correct predictions: 3776, Correct predictions test: 98
# Epoch 320, Loss: 2.8662710189819336, Correct predictions: 3826, Correct predictions test: 98
# Epoch 325, Loss: 2.7707321643829346, Correct predictions: 3886, Correct predictions test: 104
# Epoch 330, Loss: 2.6786627769470215, Correct predictions: 3886, Correct predictions test: 104
# Epoch 335, Loss: 2.58992075920105, Correct predictions: 3971, Correct predictions test: 104
# Epoch 340, Loss: 2.5043728351593018, Correct predictions: 4012, Correct predictions test: 106
# Epoch 345, Loss: 2.4218897819519043, Correct predictions: 4084, Correct predictions test: 112
# Epoch 350, Loss: 2.3423495292663574, Correct predictions: 4102, Correct predictions test: 112
# Epoch 355, Loss: 2.265634536743164, Correct predictions: 4102, Correct predictions test: 112
# Epoch 360, Loss: 2.191633939743042, Correct predictions: 4157, Correct predictions test: 124
# Epoch 365, Loss: 2.1202399730682373, Correct predictions: 4197, Correct predictions test: 126
# Epoch 370, Loss: 2.051351547241211, Correct predictions: 4221, Correct predictions test: 130
# Epoch 375, Loss: 1.9848710298538208, Correct predictions: 4267, Correct predictions test: 134
# Epoch 380, Loss: 1.9207046031951904, Correct predictions: 4303, Correct predictions test: 134
# Epoch 385, Loss: 1.8587639331817627, Correct predictions: 4340, Correct predictions test: 134
# Epoch 390, Loss: 1.7989633083343506, Correct predictions: 4375, Correct predictions test: 134
# Epoch 395, Loss: 1.7412209510803223, Correct predictions: 4375, Correct predictions test: 134
# Epoch 400, Loss: 1.6854593753814697, Correct predictions: 4421, Correct predictions test: 142
# Epoch 405, Loss: 1.6316032409667969, Correct predictions: 4453, Correct predictions test: 144
# Epoch 410, Loss: 1.579581379890442, Correct predictions: 4453, Correct predictions test: 144
# Epoch 415, Loss: 1.529325246810913, Correct predictions: 4531, Correct predictions test: 146
# Epoch 420, Loss: 1.480769157409668, Correct predictions: 4531, Correct predictions test: 146
# Epoch 425, Loss: 1.4338502883911133, Correct predictions: 4591, Correct predictions test: 148
# Epoch 430, Loss: 1.3885080814361572, Correct predictions: 4591, Correct predictions test: 148
# Epoch 435, Loss: 1.3446849584579468, Correct predictions: 4605, Correct predictions test: 148
# Epoch 440, Loss: 1.3023253679275513, Correct predictions: 4654, Correct predictions test: 148
# Epoch 445, Loss: 1.2613762617111206, Correct predictions: 4654, Correct predictions test: 148
# Epoch 450, Loss: 1.2217864990234375, Correct predictions: 4714, Correct predictions test: 152
# Epoch 455, Loss: 1.183506965637207, Correct predictions: 4714, Correct predictions test: 152
# Epoch 460, Loss: 1.1464906930923462, Correct predictions: 4762, Correct predictions test: 154
# Epoch 465, Loss: 1.1106929779052734, Correct predictions: 4762, Correct predictions test: 154
# Epoch 470, Loss: 1.0760695934295654, Correct predictions: 4810, Correct predictions test: 160
# Epoch 475, Loss: 1.042580485343933, Correct predictions: 4810, Correct predictions test: 160
# Epoch 480, Loss: 1.0101840496063232, Correct predictions: 4852, Correct predictions test: 162
# Epoch 485, Loss: 0.9788426160812378, Correct predictions: 4852, Correct predictions test: 162
# Epoch 490, Loss: 0.9485195875167847, Correct predictions: 4888, Correct predictions test: 170
# Epoch 495, Loss: 0.91917884349823, Correct predictions: 4896, Correct predictions test: 170
# Saved super_trained_model_2025_01_07_12_13_43.json
