# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 9
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_51_02.json
# Out of 10000, 320 predictions correct.
# Out of 9808, 308 train predictions correct.
# Out of 6975, 3 carry-over predictions correct.
# Out of 6879, 3 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 202 large predictions correct.
# Out of 8013, 190 large train predictions correct.
# Out of 6246, 3 carry-over large predictions correct.
# Out of 6198, 3 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_04.json
# Out of 10000, 265 predictions correct.
# Out of 9808, 255 train predictions correct.
# Out of 6975, 11 carry-over predictions correct.
# Out of 6879, 11 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 147 large predictions correct.
# Out of 8013, 137 large train predictions correct.
# Out of 6246, 11 carry-over large predictions correct.
# Out of 6198, 11 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_06.json
# Out of 10000, 678 predictions correct.
# Out of 9808, 662 train predictions correct.
# Out of 6975, 31 carry-over predictions correct.
# Out of 6879, 31 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 392 large predictions correct.
# Out of 8013, 376 large train predictions correct.
# Out of 6246, 31 carry-over large predictions correct.
# Out of 6198, 31 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_08.json
# Out of 10000, 804 predictions correct.
# Out of 9808, 790 train predictions correct.
# Out of 6975, 345 carry-over predictions correct.
# Out of 6879, 345 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 616 large predictions correct.
# Out of 8013, 602 large train predictions correct.
# Out of 6246, 345 carry-over large predictions correct.
# Out of 6198, 345 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_10.json
# Out of 10000, 242 predictions correct.
# Out of 9808, 232 train predictions correct.
# Out of 6975, 0 carry-over predictions correct.
# Out of 6879, 0 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 136 large predictions correct.
# Out of 8013, 126 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_12.json
# Out of 10000, 796 predictions correct.
# Out of 9808, 782 train predictions correct.
# Out of 6975, 300 carry-over predictions correct.
# Out of 6879, 300 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 571 large predictions correct.
# Out of 8013, 557 large train predictions correct.
# Out of 6246, 300 carry-over large predictions correct.
# Out of 6198, 300 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_14.json
# Out of 10000, 303 predictions correct.
# Out of 9808, 293 train predictions correct.
# Out of 6975, 61 carry-over predictions correct.
# Out of 6879, 61 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 197 large predictions correct.
# Out of 8013, 187 large train predictions correct.
# Out of 6246, 61 carry-over large predictions correct.
# Out of 6198, 61 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_16.json
# Out of 10000, 834 predictions correct.
# Out of 9808, 820 train predictions correct.
# Out of 6975, 429 carry-over predictions correct.
# Out of 6879, 429 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 700 large predictions correct.
# Out of 8013, 686 large train predictions correct.
# Out of 6246, 429 carry-over large predictions correct.
# Out of 6198, 429 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_18.json
# Out of 10000, 717 predictions correct.
# Out of 9808, 703 train predictions correct.
# Out of 6975, 258 carry-over predictions correct.
# Out of 6879, 258 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 529 large predictions correct.
# Out of 8013, 515 large train predictions correct.
# Out of 6246, 258 carry-over large predictions correct.
# Out of 6198, 258 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_20.json
# Out of 10000, 868 predictions correct.
# Out of 9808, 854 train predictions correct.
# Out of 6975, 409 carry-over predictions correct.
# Out of 6879, 409 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 680 large predictions correct.
# Out of 8013, 666 large train predictions correct.
# Out of 6246, 409 carry-over large predictions correct.
# Out of 6198, 409 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_22.json
# Out of 10000, 421 predictions correct.
# Out of 9808, 411 train predictions correct.
# Out of 6975, 188 carry-over predictions correct.
# Out of 6879, 188 carry-over train predictions correct.
# Out of 820, 25 small predictions correct.
# Out of 724, 25 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 324 large predictions correct.
# Out of 8013, 314 large train predictions correct.
# Out of 6246, 188 carry-over large predictions correct.
# Out of 6198, 188 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_24.json
# Out of 10000, 529 predictions correct.
# Out of 9808, 513 train predictions correct.
# Out of 6975, 3 carry-over predictions correct.
# Out of 6879, 3 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 364 large predictions correct.
# Out of 8013, 348 large train predictions correct.
# Out of 6246, 3 carry-over large predictions correct.
# Out of 6198, 3 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_26.json
# Out of 10000, 401 predictions correct.
# Out of 9808, 391 train predictions correct.
# Out of 6975, 159 carry-over predictions correct.
# Out of 6879, 159 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 295 large predictions correct.
# Out of 8013, 285 large train predictions correct.
# Out of 6246, 159 carry-over large predictions correct.
# Out of 6198, 159 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_28.json
# Out of 10000, 325 predictions correct.
# Out of 9808, 313 train predictions correct.
# Out of 6975, 11 carry-over predictions correct.
# Out of 6879, 11 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 219 large predictions correct.
# Out of 8013, 207 large train predictions correct.
# Out of 6246, 11 carry-over large predictions correct.
# Out of 6198, 11 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_30.json
# Out of 10000, 349 predictions correct.
# Out of 9808, 339 train predictions correct.
# Out of 6975, 95 carry-over predictions correct.
# Out of 6879, 95 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 231 large predictions correct.
# Out of 8013, 221 large train predictions correct.
# Out of 6246, 95 carry-over large predictions correct.
# Out of 6198, 95 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_32.json
# Out of 10000, 342 predictions correct.
# Out of 9808, 330 train predictions correct.
# Out of 6975, 0 carry-over predictions correct.
# Out of 6879, 0 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 208 large predictions correct.
# Out of 8013, 196 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_34.json
# Out of 10000, 760 predictions correct.
# Out of 9808, 746 train predictions correct.
# Out of 6975, 371 carry-over predictions correct.
# Out of 6879, 371 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 642 large predictions correct.
# Out of 8013, 628 large train predictions correct.
# Out of 6246, 371 carry-over large predictions correct.
# Out of 6198, 371 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_36.json
# Out of 10000, 817 predictions correct.
# Out of 9808, 803 train predictions correct.
# Out of 6975, 360 carry-over predictions correct.
# Out of 6879, 360 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 658 large predictions correct.
# Out of 8013, 644 large train predictions correct.
# Out of 6246, 360 carry-over large predictions correct.
# Out of 6198, 360 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_38.json
# Out of 10000, 242 predictions correct.
# Out of 9808, 232 train predictions correct.
# Out of 6975, 0 carry-over predictions correct.
# Out of 6879, 0 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 136 large predictions correct.
# Out of 8013, 126 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_40.json
# Out of 10000, 772 predictions correct.
# Out of 9808, 758 train predictions correct.
# Out of 6975, 340 carry-over predictions correct.
# Out of 6879, 340 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 638 large predictions correct.
# Out of 8013, 624 large train predictions correct.
# Out of 6246, 340 carry-over large predictions correct.
# Out of 6198, 340 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_42.json
# Out of 10000, 880 predictions correct.
# Out of 9808, 866 train predictions correct.
# Out of 6975, 423 carry-over predictions correct.
# Out of 6879, 423 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 721 large predictions correct.
# Out of 8013, 707 large train predictions correct.
# Out of 6246, 423 carry-over large predictions correct.
# Out of 6198, 423 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_44.json
# Out of 10000, 1218 predictions correct.
# Out of 9808, 1202 train predictions correct.
# Out of 6975, 606 carry-over predictions correct.
# Out of 6879, 606 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 967 large predictions correct.
# Out of 8013, 951 large train predictions correct.
# Out of 6246, 606 carry-over large predictions correct.
# Out of 6198, 606 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_46.json
# Out of 10000, 792 predictions correct.
# Out of 9808, 778 train predictions correct.
# Out of 6975, 360 carry-over predictions correct.
# Out of 6879, 360 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 658 large predictions correct.
# Out of 8013, 644 large train predictions correct.
# Out of 6246, 360 carry-over large predictions correct.
# Out of 6198, 360 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_48.json
# Out of 10000, 1342 predictions correct.
# Out of 9808, 1326 train predictions correct.
# Out of 6975, 681 carry-over predictions correct.
# Out of 6879, 681 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1091 large predictions correct.
# Out of 8013, 1075 large train predictions correct.
# Out of 6246, 681 carry-over large predictions correct.
# Out of 6198, 681 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_50.json
# Out of 10000, 465 predictions correct.
# Out of 9808, 455 train predictions correct.
# Out of 6975, 232 carry-over predictions correct.
# Out of 6879, 232 carry-over train predictions correct.
# Out of 820, 25 small predictions correct.
# Out of 724, 25 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 368 large predictions correct.
# Out of 8013, 358 large train predictions correct.
# Out of 6246, 232 carry-over large predictions correct.
# Out of 6198, 232 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_52.json
# Out of 10000, 732 predictions correct.
# Out of 9808, 720 train predictions correct.
# Out of 6975, 345 carry-over predictions correct.
# Out of 6879, 345 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 544 large predictions correct.
# Out of 8013, 532 large train predictions correct.
# Out of 6246, 345 carry-over large predictions correct.
# Out of 6198, 345 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_54.json
# Out of 10000, 401 predictions correct.
# Out of 9808, 391 train predictions correct.
# Out of 6975, 159 carry-over predictions correct.
# Out of 6879, 159 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 295 large predictions correct.
# Out of 8013, 285 large train predictions correct.
# Out of 6246, 159 carry-over large predictions correct.
# Out of 6198, 159 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_56.json
# Out of 10000, 417 predictions correct.
# Out of 9808, 405 train predictions correct.
# Out of 6975, 75 carry-over predictions correct.
# Out of 6879, 75 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 283 large predictions correct.
# Out of 8013, 271 large train predictions correct.
# Out of 6246, 75 carry-over large predictions correct.
# Out of 6198, 75 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_51_58.json
# Out of 10000, 494 predictions correct.
# Out of 9808, 484 train predictions correct.
# Out of 6975, 240 carry-over predictions correct.
# Out of 6879, 240 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 376 large predictions correct.
# Out of 8013, 366 large train predictions correct.
# Out of 6246, 240 carry-over large predictions correct.
# Out of 6198, 240 carry-over large train predictions correct.
