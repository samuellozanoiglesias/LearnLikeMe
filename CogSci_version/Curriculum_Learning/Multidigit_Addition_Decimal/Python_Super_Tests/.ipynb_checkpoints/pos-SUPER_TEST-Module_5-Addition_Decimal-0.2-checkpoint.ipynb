# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 0.2
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Tests/"
folder_path = f'{folder}Trained_models/AP_{epsilon}'
date_pattern = r'trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded trained_model_2024_12_20_01_24_59.json
# Out of 10000, 653 predictions correct.
# Out of 9808, 615 train predictions correct.
# Out of 6975, 568 carry-over predictions correct.
# Out of 6879, 536 carry-over train predictions correct.
# Out of 820, 298 small predictions correct.
# Out of 724, 260 small train predictions correct.
# Out of 270, 213 carry-over small predictions correct.
# Out of 222, 181 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_01.json
# Out of 10000, 573 predictions correct.
# Out of 9808, 549 train predictions correct.
# Out of 6975, 508 carry-over predictions correct.
# Out of 6879, 488 carry-over train predictions correct.
# Out of 820, 243 small predictions correct.
# Out of 724, 219 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_03.json
# Out of 10000, 522 predictions correct.
# Out of 9808, 500 train predictions correct.
# Out of 6975, 474 carry-over predictions correct.
# Out of 6879, 454 carry-over train predictions correct.
# Out of 820, 226 small predictions correct.
# Out of 724, 204 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_05.json
# Out of 10000, 687 predictions correct.
# Out of 9808, 645 train predictions correct.
# Out of 6975, 590 carry-over predictions correct.
# Out of 6879, 556 carry-over train predictions correct.
# Out of 820, 332 small predictions correct.
# Out of 724, 290 small train predictions correct.
# Out of 270, 235 carry-over small predictions correct.
# Out of 222, 201 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_07.json
# Out of 10000, 614 predictions correct.
# Out of 9808, 588 train predictions correct.
# Out of 6975, 549 carry-over predictions correct.
# Out of 6879, 527 carry-over train predictions correct.
# Out of 820, 259 small predictions correct.
# Out of 724, 233 small train predictions correct.
# Out of 270, 194 carry-over small predictions correct.
# Out of 222, 172 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_09.json
# Out of 10000, 452 predictions correct.
# Out of 9808, 438 train predictions correct.
# Out of 6975, 418 carry-over predictions correct.
# Out of 6879, 404 carry-over train predictions correct.
# Out of 820, 199 small predictions correct.
# Out of 724, 185 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_11.json
# Out of 10000, 509 predictions correct.
# Out of 9808, 493 train predictions correct.
# Out of 6975, 461 carry-over predictions correct.
# Out of 6879, 447 carry-over train predictions correct.
# Out of 820, 213 small predictions correct.
# Out of 724, 197 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_13.json
# Out of 10000, 847 predictions correct.
# Out of 9808, 805 train predictions correct.
# Out of 6975, 727 carry-over predictions correct.
# Out of 6879, 693 carry-over train predictions correct.
# Out of 820, 355 small predictions correct.
# Out of 724, 313 small train predictions correct.
# Out of 270, 235 carry-over small predictions correct.
# Out of 222, 201 carry-over small train predictions correct.
# Out of 8109, 48 large predictions correct.
# Out of 8013, 48 large train predictions correct.
# Out of 6246, 48 carry-over large predictions correct.
# Out of 6198, 48 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_15.json
# Out of 10000, 452 predictions correct.
# Out of 9808, 438 train predictions correct.
# Out of 6975, 418 carry-over predictions correct.
# Out of 6879, 404 carry-over train predictions correct.
# Out of 820, 199 small predictions correct.
# Out of 724, 185 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_17.json
# Out of 10000, 614 predictions correct.
# Out of 9808, 588 train predictions correct.
# Out of 6975, 549 carry-over predictions correct.
# Out of 6879, 527 carry-over train predictions correct.
# Out of 820, 259 small predictions correct.
# Out of 724, 233 small train predictions correct.
# Out of 270, 194 carry-over small predictions correct.
# Out of 222, 172 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_19.json
# Out of 10000, 565 predictions correct.
# Out of 9808, 541 train predictions correct.
# Out of 6975, 508 carry-over predictions correct.
# Out of 6879, 488 carry-over train predictions correct.
# Out of 820, 235 small predictions correct.
# Out of 724, 211 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_21.json
# Out of 10000, 764 predictions correct.
# Out of 9808, 722 train predictions correct.
# Out of 6975, 664 carry-over predictions correct.
# Out of 6879, 630 carry-over train predictions correct.
# Out of 820, 335 small predictions correct.
# Out of 724, 293 small train predictions correct.
# Out of 270, 235 carry-over small predictions correct.
# Out of 222, 201 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_23.json
# Out of 10000, 556 predictions correct.
# Out of 9808, 534 train predictions correct.
# Out of 6975, 508 carry-over predictions correct.
# Out of 6879, 488 carry-over train predictions correct.
# Out of 820, 226 small predictions correct.
# Out of 724, 204 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_25.json
# Out of 10000, 1584 predictions correct.
# Out of 9808, 1562 train predictions correct.
# Out of 6975, 1536 carry-over predictions correct.
# Out of 6879, 1516 carry-over train predictions correct.
# Out of 820, 226 small predictions correct.
# Out of 724, 204 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 1062 large predictions correct.
# Out of 8013, 1062 large train predictions correct.
# Out of 6246, 1062 carry-over large predictions correct.
# Out of 6198, 1062 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_27.json
# Out of 10000, 914 predictions correct.
# Out of 9808, 888 train predictions correct.
# Out of 6975, 849 carry-over predictions correct.
# Out of 6879, 827 carry-over train predictions correct.
# Out of 820, 259 small predictions correct.
# Out of 724, 233 small train predictions correct.
# Out of 270, 194 carry-over small predictions correct.
# Out of 222, 172 carry-over small train predictions correct.
# Out of 8109, 300 large predictions correct.
# Out of 8013, 300 large train predictions correct.
# Out of 6246, 300 carry-over large predictions correct.
# Out of 6198, 300 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_29.json
# Out of 10000, 452 predictions correct.
# Out of 9808, 438 train predictions correct.
# Out of 6975, 418 carry-over predictions correct.
# Out of 6879, 404 carry-over train predictions correct.
# Out of 820, 199 small predictions correct.
# Out of 724, 185 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_31.json
# Out of 10000, 1452 predictions correct.
# Out of 9808, 1354 train predictions correct.
# Out of 6975, 1155 carry-over predictions correct.
# Out of 6879, 1095 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 481 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 426 large predictions correct.
# Out of 8013, 414 large train predictions correct.
# Out of 6246, 426 carry-over large predictions correct.
# Out of 6198, 414 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_33.json
# Out of 10000, 1395 predictions correct.
# Out of 9808, 1371 train predictions correct.
# Out of 6975, 1338 carry-over predictions correct.
# Out of 6879, 1318 carry-over train predictions correct.
# Out of 820, 249 small predictions correct.
# Out of 724, 225 small train predictions correct.
# Out of 270, 192 carry-over small predictions correct.
# Out of 222, 172 carry-over small train predictions correct.
# Out of 8109, 850 large predictions correct.
# Out of 8013, 850 large train predictions correct.
# Out of 6246, 850 carry-over large predictions correct.
# Out of 6198, 850 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_35.json
# Out of 10000, 653 predictions correct.
# Out of 9808, 615 train predictions correct.
# Out of 6975, 568 carry-over predictions correct.
# Out of 6879, 536 carry-over train predictions correct.
# Out of 820, 298 small predictions correct.
# Out of 724, 260 small train predictions correct.
# Out of 270, 213 carry-over small predictions correct.
# Out of 222, 181 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_37.json
# Out of 10000, 486 predictions correct.
# Out of 9808, 464 train predictions correct.
# Out of 6975, 438 carry-over predictions correct.
# Out of 6879, 418 carry-over train predictions correct.
# Out of 820, 225 small predictions correct.
# Out of 724, 203 small train predictions correct.
# Out of 270, 177 carry-over small predictions correct.
# Out of 222, 157 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_39.json
# Out of 10000, 521 predictions correct.
# Out of 9808, 499 train predictions correct.
# Out of 6975, 473 carry-over predictions correct.
# Out of 6879, 453 carry-over train predictions correct.
# Out of 820, 225 small predictions correct.
# Out of 724, 203 small train predictions correct.
# Out of 270, 177 carry-over small predictions correct.
# Out of 222, 157 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_41.json
# Out of 10000, 5047 predictions correct.
# Out of 9808, 4855 train predictions correct.
# Out of 6975, 2022 carry-over predictions correct.
# Out of 6879, 1926 carry-over train predictions correct.
# Out of 820, 817 small predictions correct.
# Out of 724, 721 small train predictions correct.
# Out of 270, 267 carry-over small predictions correct.
# Out of 222, 219 carry-over small train predictions correct.
# Out of 8109, 3159 large predictions correct.
# Out of 8013, 3063 large train predictions correct.
# Out of 6246, 1296 carry-over large predictions correct.
# Out of 6198, 1248 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_43.json
# Out of 10000, 531 predictions correct.
# Out of 9808, 507 train predictions correct.
# Out of 6975, 474 carry-over predictions correct.
# Out of 6879, 454 carry-over train predictions correct.
# Out of 820, 235 small predictions correct.
# Out of 724, 211 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_45.json
# Out of 10000, 757 predictions correct.
# Out of 9808, 733 train predictions correct.
# Out of 6975, 692 carry-over predictions correct.
# Out of 6879, 672 carry-over train predictions correct.
# Out of 820, 243 small predictions correct.
# Out of 724, 219 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 184 large predictions correct.
# Out of 8013, 184 large train predictions correct.
# Out of 6246, 184 carry-over large predictions correct.
# Out of 6198, 184 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_47.json
# Out of 10000, 522 predictions correct.
# Out of 9808, 500 train predictions correct.
# Out of 6975, 474 carry-over predictions correct.
# Out of 6879, 454 carry-over train predictions correct.
# Out of 820, 226 small predictions correct.
# Out of 724, 204 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_49.json
# Out of 10000, 531 predictions correct.
# Out of 9808, 507 train predictions correct.
# Out of 6975, 474 carry-over predictions correct.
# Out of 6879, 454 carry-over train predictions correct.
# Out of 820, 235 small predictions correct.
# Out of 724, 211 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_51.json
# Out of 10000, 452 predictions correct.
# Out of 9808, 438 train predictions correct.
# Out of 6975, 418 carry-over predictions correct.
# Out of 6879, 404 carry-over train predictions correct.
# Out of 820, 199 small predictions correct.
# Out of 724, 185 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_53.json
# Out of 10000, 460 predictions correct.
# Out of 9808, 444 train predictions correct.
# Out of 6975, 418 carry-over predictions correct.
# Out of 6879, 404 carry-over train predictions correct.
# Out of 820, 207 small predictions correct.
# Out of 724, 191 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_55.json
# Out of 10000, 535 predictions correct.
# Out of 9808, 511 train predictions correct.
# Out of 6975, 478 carry-over predictions correct.
# Out of 6879, 458 carry-over train predictions correct.
# Out of 820, 235 small predictions correct.
# Out of 724, 211 small train predictions correct.
# Out of 270, 178 carry-over small predictions correct.
# Out of 222, 158 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
# Loaded trained_model_2024_12_20_01_25_57.json
# Out of 10000, 628 predictions correct.
# Out of 9808, 590 train predictions correct.
# Out of 6975, 543 carry-over predictions correct.
# Out of 6879, 511 carry-over train predictions correct.
# Out of 820, 298 small predictions correct.
# Out of 724, 260 small train predictions correct.
# Out of 270, 213 carry-over small predictions correct.
# Out of 222, 181 carry-over small train predictions correct.
# Out of 8109, 0 large predictions correct.
# Out of 8013, 0 large train predictions correct.
# Out of 6246, 0 carry-over large predictions correct.
# Out of 6198, 0 carry-over large train predictions correct.
