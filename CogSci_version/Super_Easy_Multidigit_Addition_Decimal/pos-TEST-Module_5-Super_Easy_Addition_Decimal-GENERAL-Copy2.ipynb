# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Super_Easy_Multidigit_Addition_Decimal/'
folder_specific = f'{folder}v1-Equal_Frequencies/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model(f'{folder}Modules/unit_addition_module.keras')
unit_carry_model = load_model(f'{folder}Modules/unit_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        y_data.append([sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    carry_unit_val = {}
    unit_val = {}

    for i, j in [(0, 2), (1, 3)]:
        units_inputs = jnp.array(x[:, [i, j]])
        units_input = units_inputs[:, None, :]
    
        unit_output = jnp.array(unit_addition_model(units_input))
        unit_carry_output = jnp.array(unit_carry_model(units_input))
    
        unit_val[f'{i}_{j}'] = jnp.argmax(unit_output, axis=-1)
        carry_unit_val[f'{i}_{j}'] = jnp.argmax(unit_carry_output, axis=-1)
    
    salida_1 = sum(
        params[f'v_0_1_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_1_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i, j in [(0, 2), (1, 3)]
    )
    
    salida_2 = sum(
        params[f'v_0_2_{i}_{j}'] * carry_unit_val[f'{i}_{j}'] +
        params[f'v_1_2_{i}_{j}'] * unit_val[f'{i}_{j}']
        for i, j in [(0, 2), (1, 3)]
    )

    return salida_1, salida_2

# %%
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
epsilons = [0.1, 0.2, 0.3, 0.5, 0.7,
            1, 1.5,
            2, 2.5,
            3, 
            5, 7.5,
            10
           ]

# %%
x_test, y_test = generate_test_dataset()
param_type = 'AP'

for epsilon in epsilons:
    print(f'Iniciado {epsilon}.')
    
    save_dir = f"{folder_specific}Tests/"
    folder_path = f'{folder_specific}Trained_models/{param_type}_{epsilon}'
    date_pattern = r'trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
    files = sorted(
        (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
        key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
    )
    
    os.makedirs(save_dir, exist_ok=True) 
    results_file = os.path.join(save_dir, f"Tests_{param_type}_{epsilon}.txt") 
    tee = Tee(results_file, 'w') 
    sys.stdout = tee
    
    try:
        for filename in files:
            match = re.search(date_pattern, filename)
            if match:
                current_time = match.group(1)
            else:
                print('Error')
                break
            
            file_path = f"{folder_path}/trained_model_{current_time}.json"
            with open(file_path, 'rb') as file:
                trained_model = json.load(file)
        
            trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
            print(f'Loaded trained_model_{current_time}.json')
    
            predictions(trained_model_jnp, x_test, y_test)
        
    finally:
        sys.stdout = tee.console
        tee.close()

    print(f'Finalizado {epsilon}.')
# Out:
# Iniciado 0.1.
# Loaded trained_model_2025_01_21_01_12_17.json
# Out of 5050, 5050 predictions correct.
# Out of 4858, 4858 train predictions correct.
# Out of 2025, 2025 carry-over predictions correct.
# Out of 1929, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_19.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_21.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_23.json
# Out of 5050, 5045 predictions correct.
# Out of 4858, 4855 train predictions correct.
# Out of 2025, 2020 carry-over predictions correct.
# Out of 1929, 1926 carry-over train predictions correct.
# Out of 820, 815 small predictions correct.
# Out of 724, 721 small train predictions correct.
# Out of 270, 265 carry-over small predictions correct.
# Out of 222, 219 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_25.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_27.json
# Out of 5050, 4735 predictions correct.
# Out of 4858, 4587 train predictions correct.
# Out of 2025, 1710 carry-over predictions correct.
# Out of 1929, 1658 carry-over train predictions correct.
# Out of 820, 601 small predictions correct.
# Out of 724, 549 small train predictions correct.
# Out of 270, 51 carry-over small predictions correct.
# Out of 222, 47 carry-over small train predictions correct.
# Out of 3159, 3153 large predictions correct.
# Out of 3063, 3057 large train predictions correct.
# Out of 1296, 1290 carry-over large predictions correct.
# Out of 1248, 1242 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_29.json
# Out of 5050, 4898 predictions correct.
# Out of 4858, 4742 train predictions correct.
# Out of 2025, 1873 carry-over predictions correct.
# Out of 1929, 1813 carry-over train predictions correct.
# Out of 820, 697 small predictions correct.
# Out of 724, 637 small train predictions correct.
# Out of 270, 147 carry-over small predictions correct.
# Out of 222, 135 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_31.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_33.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_35.json
# Out of 5050, 4815 predictions correct.
# Out of 4858, 4667 train predictions correct.
# Out of 2025, 1790 carry-over predictions correct.
# Out of 1929, 1738 carry-over train predictions correct.
# Out of 820, 640 small predictions correct.
# Out of 724, 588 small train predictions correct.
# Out of 270, 90 carry-over small predictions correct.
# Out of 222, 86 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.1.
# Iniciado 0.2.
# Loaded trained_model_2025_01_21_01_12_37.json
# Out of 5050, 4251 predictions correct.
# Out of 4858, 4115 train predictions correct.
# Out of 2025, 1295 carry-over predictions correct.
# Out of 1929, 1255 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2950 large predictions correct.
# Out of 3063, 2862 large train predictions correct.
# Out of 1296, 1156 carry-over large predictions correct.
# Out of 1248, 1116 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_39.json
# Out of 5050, 3320 predictions correct.
# Out of 4858, 3210 train predictions correct.
# Out of 2025, 626 carry-over predictions correct.
# Out of 1929, 606 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2165 large predictions correct.
# Out of 3063, 2103 large train predictions correct.
# Out of 1296, 626 carry-over large predictions correct.
# Out of 1248, 606 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_41.json
# Out of 5050, 2781 predictions correct.
# Out of 4858, 2679 train predictions correct.
# Out of 2025, 406 carry-over predictions correct.
# Out of 1929, 388 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1626 large predictions correct.
# Out of 3063, 1572 large train predictions correct.
# Out of 1296, 406 carry-over large predictions correct.
# Out of 1248, 388 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_43.json
# Out of 5050, 3079 predictions correct.
# Out of 4858, 2971 train predictions correct.
# Out of 2025, 570 carry-over predictions correct.
# Out of 1929, 550 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1924 large predictions correct.
# Out of 3063, 1864 large train predictions correct.
# Out of 1296, 570 carry-over large predictions correct.
# Out of 1248, 550 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_45.json
# Out of 5050, 3833 predictions correct.
# Out of 4858, 3703 train predictions correct.
# Out of 2025, 1020 carry-over predictions correct.
# Out of 1929, 984 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2617 large predictions correct.
# Out of 3063, 2535 large train predictions correct.
# Out of 1296, 966 carry-over large predictions correct.
# Out of 1248, 930 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_47.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_49.json
# Out of 5050, 2586 predictions correct.
# Out of 4858, 2496 train predictions correct.
# Out of 2025, 288 carry-over predictions correct.
# Out of 1929, 278 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1447 large predictions correct.
# Out of 3063, 1403 large train predictions correct.
# Out of 1296, 288 carry-over large predictions correct.
# Out of 1248, 278 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_51.json
# Out of 5050, 3487 predictions correct.
# Out of 4858, 3367 train predictions correct.
# Out of 2025, 674 carry-over predictions correct.
# Out of 1929, 648 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2325 large predictions correct.
# Out of 3063, 2253 large train predictions correct.
# Out of 1296, 674 carry-over large predictions correct.
# Out of 1248, 648 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_53.json
# Out of 5050, 2523 predictions correct.
# Out of 4858, 2437 train predictions correct.
# Out of 2025, 288 carry-over predictions correct.
# Out of 1929, 278 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1384 large predictions correct.
# Out of 3063, 1344 large train predictions correct.
# Out of 1296, 288 carry-over large predictions correct.
# Out of 1248, 278 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_55.json
# Out of 5050, 3783 predictions correct.
# Out of 4858, 3657 train predictions correct.
# Out of 2025, 970 carry-over predictions correct.
# Out of 1929, 938 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2567 large predictions correct.
# Out of 3063, 2489 large train predictions correct.
# Out of 1296, 916 carry-over large predictions correct.
# Out of 1248, 884 carry-over large train predictions correct.
# Finalizado 0.2.
# Iniciado 0.3.
# Loaded trained_model_2025_01_21_01_12_57.json
# Out of 5050, 1797 predictions correct.
# Out of 4858, 1751 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 485 small predictions correct.
# Out of 724, 459 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 748 large predictions correct.
# Out of 3063, 728 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_12_59.json
# Out of 5050, 1734 predictions correct.
# Out of 4858, 1684 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 503 small predictions correct.
# Out of 724, 473 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 667 large predictions correct.
# Out of 3063, 647 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_01.json
# Out of 5050, 2173 predictions correct.
# Out of 4858, 2091 train predictions correct.
# Out of 2025, 288 carry-over predictions correct.
# Out of 1929, 278 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1046 large predictions correct.
# Out of 3063, 1010 large train predictions correct.
# Out of 1296, 288 carry-over large predictions correct.
# Out of 1248, 278 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_03.json
# Out of 5050, 1734 predictions correct.
# Out of 4858, 1684 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 503 small predictions correct.
# Out of 724, 473 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 667 large predictions correct.
# Out of 3063, 647 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_05.json
# Out of 5050, 3251 predictions correct.
# Out of 4858, 3137 train predictions correct.
# Out of 2025, 710 carry-over predictions correct.
# Out of 1929, 684 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2096 large predictions correct.
# Out of 3063, 2030 large train predictions correct.
# Out of 1296, 710 carry-over large predictions correct.
# Out of 1248, 684 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_07.json
# Out of 5050, 3627 predictions correct.
# Out of 4858, 3507 train predictions correct.
# Out of 2025, 764 carry-over predictions correct.
# Out of 1929, 738 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2411 large predictions correct.
# Out of 3063, 2339 large train predictions correct.
# Out of 1296, 710 carry-over large predictions correct.
# Out of 1248, 684 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_09.json
# Out of 5050, 1675 predictions correct.
# Out of 4858, 1629 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 478 small predictions correct.
# Out of 724, 452 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 667 large predictions correct.
# Out of 3063, 647 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_11.json
# Out of 5050, 1479 predictions correct.
# Out of 4858, 1435 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 478 small predictions correct.
# Out of 724, 452 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 471 large predictions correct.
# Out of 3063, 453 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_13.json
# Out of 5050, 2551 predictions correct.
# Out of 4858, 2457 train predictions correct.
# Out of 2025, 406 carry-over predictions correct.
# Out of 1929, 388 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1412 large predictions correct.
# Out of 3063, 1364 large train predictions correct.
# Out of 1296, 406 carry-over large predictions correct.
# Out of 1248, 388 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_15.json
# Out of 5050, 1700 predictions correct.
# Out of 4858, 1650 train predictions correct.
# Out of 2025, 81 carry-over predictions correct.
# Out of 1929, 81 carry-over train predictions correct.
# Out of 820, 503 small predictions correct.
# Out of 724, 473 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 667 large predictions correct.
# Out of 3063, 647 large train predictions correct.
# Out of 1296, 81 carry-over large predictions correct.
# Out of 1248, 81 carry-over large train predictions correct.
# Finalizado 0.3.
# Iniciado 0.5.
# Loaded trained_model_2025_01_21_01_13_17.json
# Out of 5050, 976 predictions correct.
# Out of 4858, 956 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 414 small predictions correct.
# Out of 724, 400 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_19.json
# Out of 5050, 1168 predictions correct.
# Out of 4858, 1138 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 414 small predictions correct.
# Out of 724, 400 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 269 large predictions correct.
# Out of 3063, 253 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_21.json
# Out of 5050, 4045 predictions correct.
# Out of 4858, 3911 train predictions correct.
# Out of 2025, 1107 carry-over predictions correct.
# Out of 1929, 1069 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2784 large predictions correct.
# Out of 3063, 2698 large train predictions correct.
# Out of 1296, 1008 carry-over large predictions correct.
# Out of 1248, 970 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_23.json
# Out of 5050, 1010 predictions correct.
# Out of 4858, 986 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 368 small predictions correct.
# Out of 724, 358 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 213 large predictions correct.
# Out of 3063, 199 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_25.json
# Out of 5050, 3125 predictions correct.
# Out of 4858, 3017 train predictions correct.
# Out of 2025, 570 carry-over predictions correct.
# Out of 1929, 550 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1970 large predictions correct.
# Out of 3063, 1910 large train predictions correct.
# Out of 1296, 570 carry-over large predictions correct.
# Out of 1248, 550 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_27.json
# Out of 5050, 875 predictions correct.
# Out of 4858, 859 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 313 small predictions correct.
# Out of 724, 303 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_29.json
# Out of 5050, 1348 predictions correct.
# Out of 4858, 1316 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 428 small predictions correct.
# Out of 724, 414 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 390 large predictions correct.
# Out of 3063, 372 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_31.json
# Out of 5050, 1176 predictions correct.
# Out of 4858, 1146 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 422 small predictions correct.
# Out of 724, 408 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 269 large predictions correct.
# Out of 3063, 253 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_33.json
# Out of 5050, 1552 predictions correct.
# Out of 4858, 1506 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 478 small predictions correct.
# Out of 724, 452 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 544 large predictions correct.
# Out of 3063, 524 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_35.json
# Out of 5050, 5047 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2022 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 817 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 267 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Finalizado 0.5.
# Iniciado 0.7.
# Loaded trained_model_2025_01_21_01_13_37.json
# Out of 5050, 839 predictions correct.
# Out of 4858, 829 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 277 small predictions correct.
# Out of 724, 273 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_39.json
# Out of 5050, 976 predictions correct.
# Out of 4858, 956 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 414 small predictions correct.
# Out of 724, 400 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_41.json
# Out of 5050, 785 predictions correct.
# Out of 4858, 771 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 353 small predictions correct.
# Out of 724, 343 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_43.json
# Out of 5050, 930 predictions correct.
# Out of 4858, 914 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 368 small predictions correct.
# Out of 724, 358 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_45.json
# Out of 5050, 699 predictions correct.
# Out of 4858, 691 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 267 small predictions correct.
# Out of 724, 263 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_47.json
# Out of 5050, 5049 predictions correct.
# Out of 4858, 4857 train predictions correct.
# Out of 2025, 2024 carry-over predictions correct.
# Out of 1929, 1928 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 3159, 3159 large predictions correct.
# Out of 3063, 3063 large train predictions correct.
# Out of 1296, 1296 carry-over large predictions correct.
# Out of 1248, 1248 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_49.json
# Out of 5050, 699 predictions correct.
# Out of 4858, 691 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 267 small predictions correct.
# Out of 724, 263 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_51.json
# Out of 5050, 1176 predictions correct.
# Out of 4858, 1146 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 422 small predictions correct.
# Out of 724, 408 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 269 large predictions correct.
# Out of 3063, 253 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_53.json
# Out of 5050, 785 predictions correct.
# Out of 4858, 771 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 353 small predictions correct.
# Out of 724, 343 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_55.json
# Out of 5050, 721 predictions correct.
# Out of 4858, 711 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 289 small predictions correct.
# Out of 724, 283 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 0.7.
# Iniciado 1.
# Loaded trained_model_2025_01_21_01_13_57.json
# Out of 5050, 538 predictions correct.
# Out of 4858, 532 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 184 small predictions correct.
# Out of 724, 182 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_13_59.json
# Out of 5050, 3900 predictions correct.
# Out of 4858, 3772 train predictions correct.
# Out of 2025, 1002 carry-over predictions correct.
# Out of 1929, 968 carry-over train predictions correct.
# Out of 820, 550 small predictions correct.
# Out of 724, 502 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 2684 large predictions correct.
# Out of 3063, 2604 large train predictions correct.
# Out of 1296, 948 carry-over large predictions correct.
# Out of 1248, 914 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_01.json
# Out of 5050, 930 predictions correct.
# Out of 4858, 914 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 368 small predictions correct.
# Out of 724, 358 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_03.json
# Out of 5050, 1071 predictions correct.
# Out of 4858, 1045 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 373 small predictions correct.
# Out of 724, 363 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 269 large predictions correct.
# Out of 3063, 253 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_05.json
# Out of 5050, 465 predictions correct.
# Out of 4858, 463 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 181 small predictions correct.
# Out of 724, 179 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_07.json
# Out of 5050, 468 predictions correct.
# Out of 4858, 466 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 184 small predictions correct.
# Out of 724, 182 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_09.json
# Out of 5050, 468 predictions correct.
# Out of 4858, 466 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 184 small predictions correct.
# Out of 724, 182 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_11.json
# Out of 5050, 345 predictions correct.
# Out of 4858, 343 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 150 small predictions correct.
# Out of 724, 148 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_13.json
# Out of 5050, 745 predictions correct.
# Out of 4858, 731 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 313 small predictions correct.
# Out of 724, 303 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_15.json
# Out of 5050, 663 predictions correct.
# Out of 4858, 655 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 231 small predictions correct.
# Out of 724, 227 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 1.
# Iniciado 1.5.
# Loaded trained_model_2025_01_21_01_14_17.json
# Out of 5050, 245 predictions correct.
# Out of 4858, 245 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 100 small predictions correct.
# Out of 724, 100 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_19.json
# Out of 5050, 345 predictions correct.
# Out of 4858, 343 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 150 small predictions correct.
# Out of 724, 148 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_21.json
# Out of 5050, 485 predictions correct.
# Out of 4858, 479 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 181 small predictions correct.
# Out of 724, 179 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_23.json
# Out of 5050, 745 predictions correct.
# Out of 4858, 731 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 313 small predictions correct.
# Out of 724, 303 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_25.json
# Out of 5050, 345 predictions correct.
# Out of 4858, 343 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 150 small predictions correct.
# Out of 724, 148 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_27.json
# Out of 5050, 354 predictions correct.
# Out of 4858, 354 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 120 small predictions correct.
# Out of 724, 120 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_29.json
# Out of 5050, 424 predictions correct.
# Out of 4858, 420 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 120 small predictions correct.
# Out of 724, 120 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_31.json
# Out of 5050, 354 predictions correct.
# Out of 4858, 354 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 120 small predictions correct.
# Out of 724, 120 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_33.json
# Out of 5050, 705 predictions correct.
# Out of 4858, 697 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 273 small predictions correct.
# Out of 724, 269 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_35.json
# Out of 5050, 810 predictions correct.
# Out of 4858, 800 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 273 small predictions correct.
# Out of 724, 269 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 133 large predictions correct.
# Out of 3063, 127 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 1.5.
# Iniciado 2.
# Loaded trained_model_2025_01_21_01_14_37.json
# Out of 5050, 237 predictions correct.
# Out of 4858, 237 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 92 small predictions correct.
# Out of 724, 92 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_39.json
# Out of 5050, 235 predictions correct.
# Out of 4858, 235 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 90 small predictions correct.
# Out of 724, 90 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_41.json
# Out of 5050, 345 predictions correct.
# Out of 4858, 343 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 150 small predictions correct.
# Out of 724, 148 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_43.json
# Out of 5050, 468 predictions correct.
# Out of 4858, 466 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 184 small predictions correct.
# Out of 724, 182 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_14_45.json
# Out of 5050, 345 predictions correct.
# Out of 4858, 343 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 150 small predictions correct.
# ...
# Out of 3159, 70 large predictions correct.
# Out of 3063, 66 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_47.json
# Out of 5050, 155 predictions correct.
# Out of 4858, 155 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_49.json
# Out of 5050, 82 predictions correct.
# Out of 4858, 82 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 22 small predictions correct.
# Out of 724, 22 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_51.json
# Out of 5050, 195 predictions correct.
# Out of 4858, 195 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_53.json
# Out of 5050, 131 predictions correct.
# Out of 4858, 131 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 31 small predictions correct.
# Out of 724, 31 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_55.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 5.
# Iniciado 7.5.
# Loaded trained_model_2025_01_21_01_15_57.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_15_59.json
# Out of 5050, 186 predictions correct.
# Out of 4858, 186 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 86 small predictions correct.
# Out of 724, 86 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_01.json
# Out of 5050, 132 predictions correct.
# Out of 4858, 132 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 43 small predictions correct.
# Out of 724, 43 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_03.json
# Out of 5050, 67 predictions correct.
# Out of 4858, 67 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 7 small predictions correct.
# Out of 724, 7 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_05.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_07.json
# Out of 5050, 2164 predictions correct.
# Out of 4858, 2084 train predictions correct.
# Out of 2025, 288 carry-over predictions correct.
# Out of 1929, 278 carry-over train predictions correct.
# Out of 820, 531 small predictions correct.
# Out of 724, 487 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 1046 large predictions correct.
# Out of 3063, 1010 large train predictions correct.
# Out of 1296, 288 carry-over large predictions correct.
# Out of 1248, 278 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_09.json
# Out of 5050, 231 predictions correct.
# Out of 4858, 231 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 86 small predictions correct.
# Out of 724, 86 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_11.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_13.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_15.json
# Out of 5050, 251 predictions correct.
# Out of 4858, 251 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 7.5.
# Iniciado 10.
# Loaded trained_model_2025_01_21_01_16_17.json
# Out of 5050, 7 predictions correct.
# Out of 4858, 7 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 7 small predictions correct.
# Out of 724, 7 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_19.json
# Out of 5050, 7 predictions correct.
# Out of 4858, 7 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 7 small predictions correct.
# Out of 724, 7 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_21.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_23.json
# Out of 5050, 65 predictions correct.
# Out of 4858, 65 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 25 small predictions correct.
# Out of 724, 25 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_25.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_27.json
# Out of 5050, 67 predictions correct.
# Out of 4858, 67 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 7 small predictions correct.
# Out of 724, 7 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_29.json
# Out of 5050, 65 predictions correct.
# Out of 4858, 65 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 25 small predictions correct.
# Out of 724, 25 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_31.json
# Out of 5050, 67 predictions correct.
# Out of 4858, 67 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 7 small predictions correct.
# Out of 724, 7 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_33.json
# Out of 5050, 95 predictions correct.
# Out of 4858, 95 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 50 small predictions correct.
# Out of 724, 50 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Loaded trained_model_2025_01_21_01_16_35.json
# Out of 5050, 61 predictions correct.
# Out of 4858, 61 train predictions correct.
# Out of 2025, 0 carry-over predictions correct.
# Out of 1929, 0 carry-over train predictions correct.
# Out of 820, 1 small predictions correct.
# Out of 724, 1 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 3159, 0 large predictions correct.
# Out of 3063, 0 large train predictions correct.
# Out of 1296, 0 carry-over large predictions correct.
# Out of 1248, 0 carry-over large train predictions correct.
# Finalizado 10.
