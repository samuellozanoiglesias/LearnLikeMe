# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 1.7
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_36_00.json
# Out of 10000, 2529 predictions correct.
# Out of 9808, 2503 train predictions correct.
# Out of 6975, 1304 carry-over predictions correct.
# Out of 6879, 1300 carry-over train predictions correct.
# Out of 820, 140 small predictions correct.
# Out of 724, 140 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2029 large predictions correct.
# Out of 8013, 2003 large train predictions correct.
# Out of 6246, 1304 carry-over large predictions correct.
# Out of 6198, 1300 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_02.json
# Out of 10000, 7673 predictions correct.
# Out of 9808, 7541 train predictions correct.
# Out of 6975, 4762 carry-over predictions correct.
# Out of 6879, 4722 carry-over train predictions correct.
# Out of 820, 558 small predictions correct.
# Out of 724, 514 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6261 large predictions correct.
# Out of 8013, 6173 large train predictions correct.
# Out of 6246, 4493 carry-over large predictions correct.
# Out of 6198, 4453 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_04.json
# Out of 10000, 2842 predictions correct.
# Out of 9808, 2814 train predictions correct.
# Out of 6975, 1526 carry-over predictions correct.
# Out of 6879, 1522 carry-over train predictions correct.
# Out of 820, 189 small predictions correct.
# Out of 724, 187 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2293 large predictions correct.
# Out of 8013, 2267 large train predictions correct.
# Out of 6246, 1526 carry-over large predictions correct.
# Out of 6198, 1522 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_06.json
# Out of 10000, 2952 predictions correct.
# Out of 9808, 2918 train predictions correct.
# Out of 6975, 1580 carry-over predictions correct.
# Out of 6879, 1576 carry-over train predictions correct.
# Out of 820, 189 small predictions correct.
# Out of 724, 187 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2403 large predictions correct.
# Out of 8013, 2371 large train predictions correct.
# Out of 6246, 1580 carry-over large predictions correct.
# Out of 6198, 1576 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_08.json
# Out of 10000, 9336 predictions correct.
# Out of 9808, 9178 train predictions correct.
# Out of 6975, 6311 carry-over predictions correct.
# Out of 6879, 6249 carry-over train predictions correct.
# Out of 820, 705 small predictions correct.
# Out of 724, 643 small train predictions correct.
# Out of 270, 155 carry-over small predictions correct.
# Out of 222, 141 carry-over small train predictions correct.
# Out of 8109, 7599 large predictions correct.
# Out of 8013, 7503 large train predictions correct.
# Out of 6246, 5736 carry-over large predictions correct.
# Out of 6198, 5688 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_10.json
# Out of 10000, 2667 predictions correct.
# Out of 9808, 2641 train predictions correct.
# Out of 6975, 1414 carry-over predictions correct.
# Out of 6879, 1410 carry-over train predictions correct.
# Out of 820, 168 small predictions correct.
# Out of 724, 168 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2139 large predictions correct.
# Out of 8013, 2113 large train predictions correct.
# Out of 6246, 1414 carry-over large predictions correct.
# Out of 6198, 1410 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_12.json
# Out of 10000, 8280 predictions correct.
# Out of 9808, 8140 train predictions correct.
# Out of 6975, 5275 carry-over predictions correct.
# Out of 6879, 5229 carry-over train predictions correct.
# Out of 820, 609 small predictions correct.
# Out of 724, 559 small train predictions correct.
# Out of 270, 69 carry-over small predictions correct.
# Out of 222, 65 carry-over small train predictions correct.
# Out of 8109, 6734 large predictions correct.
# Out of 8013, 6644 large train predictions correct.
# Out of 6246, 4881 carry-over large predictions correct.
# Out of 6198, 4839 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_14.json
# Out of 10000, 2804 predictions correct.
# Out of 9808, 2778 train predictions correct.
# Out of 6975, 1506 carry-over predictions correct.
# Out of 6879, 1502 carry-over train predictions correct.
# Out of 820, 171 small predictions correct.
# Out of 724, 171 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2273 large predictions correct.
# Out of 8013, 2247 large train predictions correct.
# Out of 6246, 1506 carry-over large predictions correct.
# Out of 6198, 1502 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_16.json
# Out of 10000, 2647 predictions correct.
# Out of 9808, 2621 train predictions correct.
# Out of 6975, 1394 carry-over predictions correct.
# Out of 6879, 1390 carry-over train predictions correct.
# Out of 820, 168 small predictions correct.
# Out of 724, 168 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2119 large predictions correct.
# Out of 8013, 2093 large train predictions correct.
# Out of 6246, 1394 carry-over large predictions correct.
# Out of 6198, 1390 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_18.json
# Out of 10000, 3684 predictions correct.
# Out of 9808, 3642 train predictions correct.
# Out of 6975, 1917 carry-over predictions correct.
# Out of 6879, 1907 carry-over train predictions correct.
# Out of 820, 243 small predictions correct.
# Out of 724, 241 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2937 large predictions correct.
# Out of 8013, 2897 large train predictions correct.
# Out of 6246, 1917 carry-over large predictions correct.
# Out of 6198, 1907 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_20.json
# Out of 10000, 8360 predictions correct.
# Out of 9808, 8210 train predictions correct.
# Out of 6975, 5345 carry-over predictions correct.
# Out of 6879, 5291 carry-over train predictions correct.
# Out of 820, 665 small predictions correct.
# Out of 724, 605 small train predictions correct.
# Out of 270, 115 carry-over small predictions correct.
# Out of 222, 103 carry-over small train predictions correct.
# Out of 8109, 6734 large predictions correct.
# Out of 8013, 6644 large train predictions correct.
# Out of 6246, 4881 carry-over large predictions correct.
# Out of 6198, 4839 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_22.json
# Out of 10000, 3564 predictions correct.
# Out of 9808, 3522 train predictions correct.
# Out of 6975, 1864 carry-over predictions correct.
# Out of 6879, 1854 carry-over train predictions correct.
# Out of 820, 211 small predictions correct.
# Out of 724, 209 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2849 large predictions correct.
# Out of 8013, 2809 large train predictions correct.
# Out of 6246, 1864 carry-over large predictions correct.
# Out of 6198, 1854 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_24.json
# Out of 10000, 2801 predictions correct.
# Out of 9808, 2775 train predictions correct.
# Out of 6975, 1506 carry-over predictions correct.
# Out of 6879, 1502 carry-over train predictions correct.
# Out of 820, 168 small predictions correct.
# Out of 724, 168 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2273 large predictions correct.
# Out of 8013, 2247 large train predictions correct.
# Out of 6246, 1506 carry-over large predictions correct.
# Out of 6198, 1502 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_26.json
# Out of 10000, 5081 predictions correct.
# Out of 9808, 5011 train predictions correct.
# Out of 6975, 2821 carry-over predictions correct.
# Out of 6879, 2801 carry-over train predictions correct.
# Out of 820, 345 small predictions correct.
# Out of 724, 335 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4100 large predictions correct.
# Out of 8013, 4040 large train predictions correct.
# Out of 6246, 2767 carry-over large predictions correct.
# Out of 6198, 2747 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_28.json
# Out of 10000, 5335 predictions correct.
# Out of 9808, 5265 train predictions correct.
# Out of 6975, 3050 carry-over predictions correct.
# Out of 6879, 3030 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4329 large predictions correct.
# Out of 8013, 4269 large train predictions correct.
# Out of 6246, 2996 carry-over large predictions correct.
# Out of 6198, 2976 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_30.json
# Out of 10000, 3327 predictions correct.
# Out of 9808, 3291 train predictions correct.
# Out of 6975, 1700 carry-over predictions correct.
# Out of 6879, 1696 carry-over train predictions correct.
# Out of 820, 207 small predictions correct.
# Out of 724, 205 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2685 large predictions correct.
# Out of 8013, 2651 large train predictions correct.
# Out of 6246, 1700 carry-over large predictions correct.
# Out of 6198, 1696 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_32.json
# Out of 10000, 3337 predictions correct.
# Out of 9808, 3301 train predictions correct.
# Out of 6975, 1751 carry-over predictions correct.
# Out of 6879, 1747 carry-over train predictions correct.
# Out of 820, 211 small predictions correct.
# Out of 724, 209 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2646 large predictions correct.
# Out of 8013, 2612 large train predictions correct.
# Out of 6246, 1751 carry-over large predictions correct.
# Out of 6198, 1747 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_34.json
# Out of 10000, 4727 predictions correct.
# Out of 9808, 4663 train predictions correct.
# Out of 6975, 2621 carry-over predictions correct.
# Out of 6879, 2601 carry-over train predictions correct.
# Out of 820, 285 small predictions correct.
# Out of 724, 279 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3860 large predictions correct.
# Out of 8013, 3802 large train predictions correct.
# Out of 6246, 2621 carry-over large predictions correct.
# Out of 6198, 2601 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_36.json
# Out of 10000, 3472 predictions correct.
# Out of 9808, 3436 train predictions correct.
# Out of 6975, 1796 carry-over predictions correct.
# Out of 6879, 1792 carry-over train predictions correct.
# Out of 820, 211 small predictions correct.
# Out of 724, 209 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2781 large predictions correct.
# Out of 8013, 2747 large train predictions correct.
# Out of 6246, 1796 carry-over large predictions correct.
# Out of 6198, 1792 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_38.json
# Out of 10000, 3532 predictions correct.
# Out of 9808, 3490 train predictions correct.
# Out of 6975, 1832 carry-over predictions correct.
# Out of 6879, 1822 carry-over train predictions correct.
# Out of 820, 211 small predictions correct.
# Out of 724, 209 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2817 large predictions correct.
# Out of 8013, 2777 large train predictions correct.
# Out of 6246, 1832 carry-over large predictions correct.
# Out of 6198, 1822 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_40.json
# Out of 10000, 3188 predictions correct.
# Out of 9808, 3152 train predictions correct.
# Out of 6975, 1666 carry-over predictions correct.
# Out of 6879, 1662 carry-over train predictions correct.
# Out of 820, 207 small predictions correct.
# Out of 724, 205 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2561 large predictions correct.
# Out of 8013, 2527 large train predictions correct.
# Out of 6246, 1666 carry-over large predictions correct.
# Out of 6198, 1662 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_42.json
# Out of 10000, 2957 predictions correct.
# Out of 9808, 2923 train predictions correct.
# Out of 6975, 1585 carry-over predictions correct.
# Out of 6879, 1581 carry-over train predictions correct.
# Out of 820, 189 small predictions correct.
# Out of 724, 187 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2408 large predictions correct.
# Out of 8013, 2376 large train predictions correct.
# Out of 6246, 1585 carry-over large predictions correct.
# Out of 6198, 1581 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_44.json
# Out of 10000, 4924 predictions correct.
# Out of 9808, 4858 train predictions correct.
# Out of 6975, 2742 carry-over predictions correct.
# Out of 6879, 2722 carry-over train predictions correct.
# Out of 820, 321 small predictions correct.
# Out of 724, 315 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4021 large predictions correct.
# Out of 8013, 3961 large train predictions correct.
# Out of 6246, 2742 carry-over large predictions correct.
# Out of 6198, 2722 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_46.json
# Out of 10000, 4102 predictions correct.
# Out of 9808, 4052 train predictions correct.
# Out of 6975, 2262 carry-over predictions correct.
# Out of 6879, 2246 carry-over train predictions correct.
# Out of 820, 268 small predictions correct.
# Out of 724, 264 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3330 large predictions correct.
# Out of 8013, 3284 large train predictions correct.
# Out of 6246, 2262 carry-over large predictions correct.
# Out of 6198, 2246 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_48.json
# Out of 10000, 6265 predictions correct.
# Out of 9808, 6175 train predictions correct.
# Out of 6975, 3710 carry-over predictions correct.
# Out of 6879, 3682 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5157 large predictions correct.
# Out of 8013, 5087 large train predictions correct.
# Out of 6246, 3656 carry-over large predictions correct.
# Out of 6198, 3628 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_50.json
# Out of 10000, 5236 predictions correct.
# Out of 9808, 5164 train predictions correct.
# Out of 6975, 2901 carry-over predictions correct.
# Out of 6879, 2881 carry-over train predictions correct.
# Out of 820, 345 small predictions correct.
# Out of 724, 335 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4250 large predictions correct.
# Out of 8013, 4188 large train predictions correct.
# Out of 6246, 2847 carry-over large predictions correct.
# Out of 6198, 2827 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_36_52.json
# Out of 10000, 6142 predictions correct.
# Out of 9808, 6054 train predictions correct.
# Out of 6975, 3632 carry-over predictions correct.
# Out of 6879, 3606 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5034 large predictions correct.
# Out of 8013, 4966 large train predictions correct.
# Out of 6246, 3578 carry-over large predictions correct.
# Out of 6198, 3552 carry-over large train predictions correct.
