# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 0.8
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_30_59.json
# Out of 10000, 6711 predictions correct.
# Out of 9808, 6609 train predictions correct.
# Out of 6975, 4046 carry-over predictions correct.
# Out of 6879, 4016 carry-over train predictions correct.
# Out of 820, 485 small predictions correct.
# Out of 724, 459 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5522 large predictions correct.
# Out of 8013, 5446 large train predictions correct.
# Out of 6246, 3947 carry-over large predictions correct.
# Out of 6198, 3917 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_01.json
# Out of 10000, 7262 predictions correct.
# Out of 9808, 7148 train predictions correct.
# Out of 6975, 4454 carry-over predictions correct.
# Out of 6879, 4418 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5964 large predictions correct.
# Out of 8013, 5882 large train predictions correct.
# Out of 6246, 4279 carry-over large predictions correct.
# Out of 6198, 4243 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_03.json
# Out of 10000, 9764 predictions correct.
# Out of 9808, 9592 train predictions correct.
# Out of 6975, 6739 carry-over predictions correct.
# Out of 6879, 6663 carry-over train predictions correct.
# Out of 820, 761 small predictions correct.
# Out of 724, 685 small train predictions correct.
# Out of 270, 211 carry-over small predictions correct.
# Out of 222, 183 carry-over small train predictions correct.
# Out of 8109, 7949 large predictions correct.
# Out of 8013, 7853 large train predictions correct.
# Out of 6246, 6086 carry-over large predictions correct.
# Out of 6198, 6038 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_05.json
# Out of 10000, 5762 predictions correct.
# Out of 9808, 5684 train predictions correct.
# Out of 6975, 3334 carry-over predictions correct.
# Out of 6879, 3308 carry-over train predictions correct.
# Out of 820, 405 small predictions correct.
# Out of 724, 395 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4704 large predictions correct.
# Out of 8013, 4636 large train predictions correct.
# Out of 6246, 3280 carry-over large predictions correct.
# Out of 6198, 3254 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_07.json
# Out of 10000, 6416 predictions correct.
# Out of 9808, 6322 train predictions correct.
# Out of 6975, 3795 carry-over predictions correct.
# Out of 6879, 3767 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5257 large predictions correct.
# Out of 8013, 5183 large train predictions correct.
# Out of 6246, 3696 carry-over large predictions correct.
# Out of 6198, 3668 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_09.json
# Out of 10000, 5395 predictions correct.
# Out of 9808, 5325 train predictions correct.
# Out of 6975, 3110 carry-over predictions correct.
# Out of 6879, 3090 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4389 large predictions correct.
# Out of 8013, 4329 large train predictions correct.
# Out of 6246, 3056 carry-over large predictions correct.
# Out of 6198, 3036 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_11.json
# Out of 10000, 8323 predictions correct.
# Out of 9808, 8187 train predictions correct.
# Out of 6975, 5337 carry-over predictions correct.
# Out of 6879, 5297 carry-over train predictions correct.
# Out of 820, 577 small predictions correct.
# Out of 724, 529 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6862 large predictions correct.
# Out of 8013, 6774 large train predictions correct.
# Out of 6246, 5038 carry-over large predictions correct.
# Out of 6198, 4998 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_13.json
# Out of 10000, 7605 predictions correct.
# Out of 9808, 7475 train predictions correct.
# Out of 6975, 4694 carry-over predictions correct.
# Out of 6879, 4656 carry-over train predictions correct.
# Out of 820, 531 small predictions correct.
# Out of 724, 487 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6287 large predictions correct.
# Out of 8013, 6201 large train predictions correct.
# Out of 6246, 4519 carry-over large predictions correct.
# Out of 6198, 4481 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_15.json
# Out of 10000, 7434 predictions correct.
# Out of 9808, 7320 train predictions correct.
# Out of 6975, 4610 carry-over predictions correct.
# Out of 6879, 4574 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6136 large predictions correct.
# Out of 8013, 6054 large train predictions correct.
# Out of 6246, 4435 carry-over large predictions correct.
# Out of 6198, 4399 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_17.json
# Out of 10000, 9171 predictions correct.
# Out of 9808, 9019 train predictions correct.
# Out of 6975, 6146 carry-over predictions correct.
# Out of 6879, 6090 carry-over train predictions correct.
# Out of 820, 656 small predictions correct.
# Out of 724, 596 small train predictions correct.
# Out of 270, 106 carry-over small predictions correct.
# Out of 222, 94 carry-over small train predictions correct.
# Out of 8109, 7534 large predictions correct.
# Out of 8013, 7442 large train predictions correct.
# Out of 6246, 5671 carry-over large predictions correct.
# Out of 6198, 5627 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_19.json
# Out of 10000, 9214 predictions correct.
# Out of 9808, 9062 train predictions correct.
# Out of 6975, 6189 carry-over predictions correct.
# Out of 6879, 6133 carry-over train predictions correct.
# Out of 820, 697 small predictions correct.
# Out of 724, 637 small train predictions correct.
# Out of 270, 147 carry-over small predictions correct.
# Out of 222, 135 carry-over small train predictions correct.
# Out of 8109, 7516 large predictions correct.
# Out of 8013, 7424 large train predictions correct.
# Out of 6246, 5653 carry-over large predictions correct.
# Out of 6198, 5609 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_21.json
# Out of 10000, 9228 predictions correct.
# Out of 9808, 9076 train predictions correct.
# Out of 6975, 6203 carry-over predictions correct.
# Out of 6879, 6147 carry-over train predictions correct.
# Out of 820, 665 small predictions correct.
# Out of 724, 605 small train predictions correct.
# Out of 270, 115 carry-over small predictions correct.
# Out of 222, 103 carry-over small train predictions correct.
# Out of 8109, 7562 large predictions correct.
# Out of 8013, 7470 large train predictions correct.
# Out of 6246, 5699 carry-over large predictions correct.
# Out of 6198, 5655 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_23.json
# Out of 10000, 7614 predictions correct.
# Out of 9808, 7486 train predictions correct.
# Out of 6975, 4743 carry-over predictions correct.
# Out of 6879, 4705 carry-over train predictions correct.
# Out of 820, 531 small predictions correct.
# Out of 724, 487 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6296 large predictions correct.
# Out of 8013, 6212 large train predictions correct.
# Out of 6246, 4568 carry-over large predictions correct.
# Out of 6198, 4530 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_25.json
# Out of 10000, 7497 predictions correct.
# Out of 9808, 7381 train predictions correct.
# Out of 6975, 4646 carry-over predictions correct.
# Out of 6879, 4608 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6199 large predictions correct.
# Out of 8013, 6115 large train predictions correct.
# Out of 6246, 4471 carry-over large predictions correct.
# Out of 6198, 4433 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_27.json
# Out of 10000, 6547 predictions correct.
# Out of 9808, 6453 train predictions correct.
# Out of 6975, 3926 carry-over predictions correct.
# Out of 6879, 3898 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5388 large predictions correct.
# Out of 8013, 5314 large train predictions correct.
# Out of 6246, 3827 carry-over large predictions correct.
# Out of 6198, 3799 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_29.json
# Out of 10000, 9620 predictions correct.
# Out of 9808, 9452 train predictions correct.
# Out of 6975, 6595 carry-over predictions correct.
# Out of 6879, 6523 carry-over train predictions correct.
# Out of 820, 739 small predictions correct.
# Out of 724, 667 small train predictions correct.
# Out of 270, 189 carry-over small predictions correct.
# Out of 222, 165 carry-over small train predictions correct.
# Out of 8109, 7839 large predictions correct.
# Out of 8013, 7743 large train predictions correct.
# Out of 6246, 5976 carry-over large predictions correct.
# Out of 6198, 5928 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_31.json
# Out of 10000, 9755 predictions correct.
# Out of 9808, 9569 train predictions correct.
# Out of 6975, 6730 carry-over predictions correct.
# Out of 6879, 6640 carry-over train predictions correct.
# Out of 820, 789 small predictions correct.
# Out of 724, 699 small train predictions correct.
# Out of 270, 239 carry-over small predictions correct.
# Out of 222, 197 carry-over small train predictions correct.
# Out of 8109, 7899 large predictions correct.
# Out of 8013, 7803 large train predictions correct.
# Out of 6246, 6036 carry-over large predictions correct.
# Out of 6198, 5988 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_33.json
# Out of 10000, 7666 predictions correct.
# Out of 9808, 7536 train predictions correct.
# Out of 6975, 4786 carry-over predictions correct.
# Out of 6879, 4748 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6339 large predictions correct.
# Out of 8013, 6255 large train predictions correct.
# Out of 6246, 4611 carry-over large predictions correct.
# Out of 6198, 4573 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_35.json
# Out of 10000, 7641 predictions correct.
# Out of 9808, 7513 train predictions correct.
# Out of 6975, 4770 carry-over predictions correct.
# Out of 6879, 4732 carry-over train predictions correct.
# Out of 820, 531 small predictions correct.
# Out of 724, 487 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6323 large predictions correct.
# Out of 8013, 6239 large train predictions correct.
# Out of 6246, 4595 carry-over large predictions correct.
# Out of 6198, 4557 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_37.json
# Out of 10000, 6687 predictions correct.
# Out of 9808, 6585 train predictions correct.
# Out of 6975, 3998 carry-over predictions correct.
# Out of 6879, 3968 carry-over train predictions correct.
# Out of 820, 485 small predictions correct.
# Out of 724, 459 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5498 large predictions correct.
# Out of 8013, 5422 large train predictions correct.
# Out of 6246, 3899 carry-over large predictions correct.
# Out of 6198, 3869 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_39.json
# Out of 10000, 7230 predictions correct.
# Out of 9808, 7118 train predictions correct.
# Out of 6975, 4422 carry-over predictions correct.
# Out of 6879, 4388 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5932 large predictions correct.
# Out of 8013, 5852 large train predictions correct.
# Out of 6246, 4247 carry-over large predictions correct.
# Out of 6198, 4213 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_41.json
# Out of 10000, 8094 predictions correct.
# Out of 9808, 7960 train predictions correct.
# Out of 6975, 5166 carry-over predictions correct.
# Out of 6879, 5126 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 521 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6673 large predictions correct.
# Out of 8013, 6585 large train predictions correct.
# Out of 6246, 4897 carry-over large predictions correct.
# Out of 6198, 4857 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_43.json
# Out of 10000, 5698 predictions correct.
# Out of 9808, 5626 train predictions correct.
# Out of 6975, 3270 carry-over predictions correct.
# Out of 6879, 3250 carry-over train predictions correct.
# Out of 820, 405 small predictions correct.
# Out of 724, 395 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4640 large predictions correct.
# Out of 8013, 4578 large train predictions correct.
# Out of 6246, 3216 carry-over large predictions correct.
# Out of 6198, 3196 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_45.json
# Out of 10000, 8806 predictions correct.
# Out of 9808, 8664 train predictions correct.
# Out of 6975, 5791 carry-over predictions correct.
# Out of 6879, 5745 carry-over train predictions correct.
# Out of 820, 619 small predictions correct.
# Out of 724, 567 small train predictions correct.
# Out of 270, 69 carry-over small predictions correct.
# Out of 222, 65 carry-over small train predictions correct.
# Out of 8109, 7250 large predictions correct.
# Out of 8013, 7160 large train predictions correct.
# Out of 6246, 5397 carry-over large predictions correct.
# Out of 6198, 5355 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_47.json
# Out of 10000, 9406 predictions correct.
# Out of 9808, 9246 train predictions correct.
# Out of 6975, 6381 carry-over predictions correct.
# Out of 6879, 6317 carry-over train predictions correct.
# Out of 820, 720 small predictions correct.
# Out of 724, 656 small train predictions correct.
# Out of 270, 170 carry-over small predictions correct.
# Out of 222, 154 carry-over small train predictions correct.
# Out of 8109, 7654 large predictions correct.
# Out of 8013, 7558 large train predictions correct.
# Out of 6246, 5791 carry-over large predictions correct.
# Out of 6198, 5743 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_31_49.json
# Out of 10000, 9381 predictions correct.
# Out of 9808, 9223 train predictions correct.
# Out of 6975, 6356 carry-over predictions correct.
# Out of 6879, 6294 carry-over train predictions correct.
# Out of 820, 705 small predictions correct.
# Out of 724, 643 small train predictions correct.
# Out of 270, 155 carry-over small predictions correct.
# Out of 222, 141 carry-over small train predictions correct.
# Out of 8109, 7644 large predictions correct.
# Out of 8013, 7548 large train predictions correct.
# Out of 6246, 5781 carry-over large predictions correct.
# Out of 6198, 5733 carry-over large train predictions correct.
