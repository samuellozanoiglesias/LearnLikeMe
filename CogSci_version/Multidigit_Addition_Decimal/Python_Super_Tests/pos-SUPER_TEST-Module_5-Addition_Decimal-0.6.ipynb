# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 0.6
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_28_59.json
# Out of 10000, 9556 predictions correct.
# Out of 9808, 9390 train predictions correct.
# Out of 6975, 6531 carry-over predictions correct.
# Out of 6879, 6461 carry-over train predictions correct.
# Out of 820, 732 small predictions correct.
# Out of 724, 662 small train predictions correct.
# Out of 270, 182 carry-over small predictions correct.
# Out of 222, 160 carry-over small train predictions correct.
# Out of 8109, 7792 large predictions correct.
# Out of 8013, 7696 large train predictions correct.
# Out of 6246, 5929 carry-over large predictions correct.
# Out of 6198, 5881 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_01.json
# Out of 10000, 7445 predictions correct.
# Out of 9808, 7331 train predictions correct.
# Out of 6975, 4621 carry-over predictions correct.
# Out of 6879, 4585 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6147 large predictions correct.
# Out of 8013, 6065 large train predictions correct.
# Out of 6246, 4446 carry-over large predictions correct.
# Out of 6198, 4410 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_03.json
# Out of 10000, 7151 predictions correct.
# Out of 9808, 7041 train predictions correct.
# Out of 6975, 4350 carry-over predictions correct.
# Out of 6879, 4318 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5896 large predictions correct.
# Out of 8013, 5818 large train predictions correct.
# Out of 6246, 4211 carry-over large predictions correct.
# Out of 6198, 4179 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_05.json
# Out of 10000, 9291 predictions correct.
# Out of 9808, 9139 train predictions correct.
# Out of 6975, 6266 carry-over predictions correct.
# Out of 6879, 6210 carry-over train predictions correct.
# Out of 820, 697 small predictions correct.
# Out of 724, 637 small train predictions correct.
# Out of 270, 147 carry-over small predictions correct.
# Out of 222, 135 carry-over small train predictions correct.
# Out of 8109, 7593 large predictions correct.
# Out of 8013, 7501 large train predictions correct.
# Out of 6246, 5730 carry-over large predictions correct.
# Out of 6198, 5686 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_07.json
# Out of 10000, 7480 predictions correct.
# Out of 9808, 7366 train predictions correct.
# Out of 6975, 4656 carry-over predictions correct.
# Out of 6879, 4620 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6182 large predictions correct.
# Out of 8013, 6100 large train predictions correct.
# Out of 6246, 4481 carry-over large predictions correct.
# Out of 6198, 4445 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_09.json
# Out of 10000, 9095 predictions correct.
# Out of 9808, 8943 train predictions correct.
# Out of 6975, 6070 carry-over predictions correct.
# Out of 6879, 6014 carry-over train predictions correct.
# Out of 820, 665 small predictions correct.
# Out of 724, 605 small train predictions correct.
# Out of 270, 115 carry-over small predictions correct.
# Out of 222, 103 carry-over small train predictions correct.
# Out of 8109, 7449 large predictions correct.
# Out of 8013, 7357 large train predictions correct.
# Out of 6246, 5586 carry-over large predictions correct.
# Out of 6198, 5542 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_11.json
# Out of 10000, 6821 predictions correct.
# Out of 9808, 6715 train predictions correct.
# Out of 6975, 4114 carry-over predictions correct.
# Out of 6879, 4084 carry-over train predictions correct.
# Out of 820, 503 small predictions correct.
# Out of 724, 473 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5614 large predictions correct.
# Out of 8013, 5538 large train predictions correct.
# Out of 6246, 4015 carry-over large predictions correct.
# Out of 6198, 3985 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_13.json
# Out of 10000, 9291 predictions correct.
# Out of 9808, 9139 train predictions correct.
# Out of 6975, 6266 carry-over predictions correct.
# Out of 6879, 6210 carry-over train predictions correct.
# Out of 820, 697 small predictions correct.
# Out of 724, 637 small train predictions correct.
# Out of 270, 147 carry-over small predictions correct.
# Out of 222, 135 carry-over small train predictions correct.
# Out of 8109, 7593 large predictions correct.
# Out of 8013, 7501 large train predictions correct.
# Out of 6246, 5730 carry-over large predictions correct.
# Out of 6198, 5686 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_15.json
# Out of 10000, 8737 predictions correct.
# Out of 9808, 8595 train predictions correct.
# Out of 6975, 5722 carry-over predictions correct.
# Out of 6879, 5676 carry-over train predictions correct.
# Out of 820, 619 small predictions correct.
# Out of 724, 567 small train predictions correct.
# Out of 270, 69 carry-over small predictions correct.
# Out of 222, 65 carry-over small train predictions correct.
# Out of 8109, 7206 large predictions correct.
# Out of 8013, 7116 large train predictions correct.
# Out of 6246, 5353 carry-over large predictions correct.
# Out of 6198, 5311 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_17.json
# Out of 10000, 8520 predictions correct.
# Out of 9808, 8384 train predictions correct.
# Out of 6975, 5534 carry-over predictions correct.
# Out of 6879, 5494 carry-over train predictions correct.
# Out of 820, 577 small predictions correct.
# Out of 724, 529 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 7031 large predictions correct.
# Out of 8013, 6943 large train predictions correct.
# Out of 6246, 5207 carry-over large predictions correct.
# Out of 6198, 5167 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_19.json
# Out of 10000, 7354 predictions correct.
# Out of 9808, 7240 train predictions correct.
# Out of 6975, 4546 carry-over predictions correct.
# Out of 6879, 4510 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6056 large predictions correct.
# Out of 8013, 5974 large train predictions correct.
# Out of 6246, 4371 carry-over large predictions correct.
# Out of 6198, 4335 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_21.json
# Out of 10000, 8717 predictions correct.
# Out of 9808, 8575 train predictions correct.
# Out of 6975, 5722 carry-over predictions correct.
# Out of 6879, 5676 carry-over train predictions correct.
# Out of 820, 619 small predictions correct.
# Out of 724, 567 small train predictions correct.
# Out of 270, 69 carry-over small predictions correct.
# Out of 222, 65 carry-over small train predictions correct.
# Out of 8109, 7186 large predictions correct.
# Out of 8013, 7096 large train predictions correct.
# Out of 6246, 5353 carry-over large predictions correct.
# Out of 6198, 5311 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_23.json
# Out of 10000, 9944 predictions correct.
# Out of 9808, 9756 train predictions correct.
# Out of 6975, 6919 carry-over predictions correct.
# Out of 6879, 6827 carry-over train predictions correct.
# Out of 820, 812 small predictions correct.
# Out of 724, 720 small train predictions correct.
# Out of 270, 262 carry-over small predictions correct.
# Out of 222, 218 carry-over small train predictions correct.
# Out of 8109, 8061 large predictions correct.
# Out of 8013, 7965 large train predictions correct.
# Out of 6246, 6198 carry-over large predictions correct.
# Out of 6198, 6150 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_25.json
# Out of 10000, 8264 predictions correct.
# Out of 9808, 8128 train predictions correct.
# Out of 6975, 5278 carry-over predictions correct.
# Out of 6879, 5238 carry-over train predictions correct.
# Out of 820, 577 small predictions correct.
# Out of 724, 529 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6803 large predictions correct.
# Out of 8013, 6715 large train predictions correct.
# Out of 6246, 4979 carry-over large predictions correct.
# Out of 6198, 4939 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_27.json
# Out of 10000, 8726 predictions correct.
# Out of 9808, 8584 train predictions correct.
# Out of 6975, 5731 carry-over predictions correct.
# Out of 6879, 5685 carry-over train predictions correct.
# Out of 820, 619 small predictions correct.
# Out of 724, 567 small train predictions correct.
# Out of 270, 69 carry-over small predictions correct.
# Out of 222, 65 carry-over small train predictions correct.
# Out of 8109, 7195 large predictions correct.
# Out of 8013, 7105 large train predictions correct.
# Out of 6246, 5362 carry-over large predictions correct.
# Out of 6198, 5320 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_29.json
# Out of 10000, 8064 predictions correct.
# Out of 9808, 7930 train predictions correct.
# Out of 6975, 5136 carry-over predictions correct.
# Out of 6879, 5096 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 521 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6643 large predictions correct.
# Out of 8013, 6555 large train predictions correct.
# Out of 6246, 4867 carry-over large predictions correct.
# Out of 6198, 4827 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_31.json
# Out of 10000, 9960 predictions correct.
# Out of 9808, 9770 train predictions correct.
# Out of 6975, 6935 carry-over predictions correct.
# Out of 6879, 6841 carry-over train predictions correct.
# Out of 820, 815 small predictions correct.
# Out of 724, 721 small train predictions correct.
# Out of 270, 265 carry-over small predictions correct.
# Out of 222, 219 carry-over small train predictions correct.
# Out of 8109, 8074 large predictions correct.
# Out of 8013, 7978 large train predictions correct.
# Out of 6246, 6211 carry-over large predictions correct.
# Out of 6198, 6163 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_33.json
# Out of 10000, 8520 predictions correct.
# Out of 9808, 8384 train predictions correct.
# Out of 6975, 5534 carry-over predictions correct.
# Out of 6879, 5494 carry-over train predictions correct.
# Out of 820, 577 small predictions correct.
# Out of 724, 529 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 7031 large predictions correct.
# Out of 8013, 6943 large train predictions correct.
# Out of 6246, 5207 carry-over large predictions correct.
# Out of 6198, 5167 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_35.json
# Out of 10000, 9624 predictions correct.
# Out of 9808, 9456 train predictions correct.
# Out of 6975, 6599 carry-over predictions correct.
# Out of 6879, 6527 carry-over train predictions correct.
# Out of 820, 751 small predictions correct.
# Out of 724, 679 small train predictions correct.
# Out of 270, 201 carry-over small predictions correct.
# Out of 222, 177 carry-over small train predictions correct.
# Out of 8109, 7819 large predictions correct.
# Out of 8013, 7723 large train predictions correct.
# Out of 6246, 5956 carry-over large predictions correct.
# Out of 6198, 5908 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_37.json
# Out of 10000, 9916 predictions correct.
# Out of 9808, 9730 train predictions correct.
# Out of 6975, 6891 carry-over predictions correct.
# Out of 6879, 6801 carry-over train predictions correct.
# Out of 820, 801 small predictions correct.
# Out of 724, 711 small train predictions correct.
# Out of 270, 251 carry-over small predictions correct.
# Out of 222, 209 carry-over small train predictions correct.
# Out of 8109, 8044 large predictions correct.
# Out of 8013, 7948 large train predictions correct.
# Out of 6246, 6181 carry-over large predictions correct.
# Out of 6198, 6133 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_39.json
# Out of 10000, 7480 predictions correct.
# Out of 9808, 7366 train predictions correct.
# Out of 6975, 4656 carry-over predictions correct.
# Out of 6879, 4620 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6182 large predictions correct.
# Out of 8013, 6100 large train predictions correct.
# Out of 6246, 4481 carry-over large predictions correct.
# Out of 6198, 4445 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_41.json
# Out of 10000, 8282 predictions correct.
# Out of 9808, 8146 train predictions correct.
# Out of 6975, 5296 carry-over predictions correct.
# Out of 6879, 5256 carry-over train predictions correct.
# Out of 820, 577 small predictions correct.
# Out of 724, 529 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6821 large predictions correct.
# Out of 8013, 6733 large train predictions correct.
# Out of 6246, 4997 carry-over large predictions correct.
# Out of 6198, 4957 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_43.json
# Out of 10000, 9991 predictions correct.
# Out of 9808, 9799 train predictions correct.
# Out of 6975, 6966 carry-over predictions correct.
# Out of 6879, 6870 carry-over train predictions correct.
# Out of 820, 819 small predictions correct.
# Out of 724, 723 small train predictions correct.
# Out of 270, 269 carry-over small predictions correct.
# Out of 222, 221 carry-over small train predictions correct.
# Out of 8109, 8101 large predictions correct.
# Out of 8013, 8005 large train predictions correct.
# Out of 6246, 6238 carry-over large predictions correct.
# Out of 6198, 6190 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_45.json
# Out of 10000, 9964 predictions correct.
# Out of 9808, 9774 train predictions correct.
# Out of 6975, 6939 carry-over predictions correct.
# Out of 6879, 6845 carry-over train predictions correct.
# Out of 820, 815 small predictions correct.
# Out of 724, 721 small train predictions correct.
# Out of 270, 265 carry-over small predictions correct.
# Out of 222, 219 carry-over small train predictions correct.
# Out of 8109, 8078 large predictions correct.
# Out of 8013, 7982 large train predictions correct.
# Out of 6246, 6215 carry-over large predictions correct.
# Out of 6198, 6167 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_47.json
# Out of 10000, 8408 predictions correct.
# Out of 9808, 8272 train predictions correct.
# Out of 6975, 5422 carry-over predictions correct.
# Out of 6879, 5382 carry-over train predictions correct.
# Out of 820, 577 small predictions correct.
# Out of 724, 529 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6947 large predictions correct.
# Out of 8013, 6859 large train predictions correct.
# Out of 6246, 5123 carry-over large predictions correct.
# Out of 6198, 5083 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_49.json
# Out of 10000, 8947 predictions correct.
# Out of 9808, 8803 train predictions correct.
# Out of 6975, 5932 carry-over predictions correct.
# Out of 6879, 5884 carry-over train predictions correct.
# Out of 820, 640 small predictions correct.
# Out of 724, 588 small train predictions correct.
# Out of 270, 90 carry-over small predictions correct.
# Out of 222, 86 carry-over small train predictions correct.
# Out of 8109, 7346 large predictions correct.
# Out of 8013, 7254 large train predictions correct.
# Out of 6246, 5493 carry-over large predictions correct.
# Out of 6198, 5449 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_29_51.json
# Out of 10000, 7927 predictions correct.
# Out of 9808, 7793 train predictions correct.
# Out of 6975, 5007 carry-over predictions correct.
# Out of 6879, 4967 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6533 large predictions correct.
# Out of 8013, 6445 large train predictions correct.
# Out of 6246, 4765 carry-over large predictions correct.
# Out of 6198, 4725 carry-over large train predictions correct.
