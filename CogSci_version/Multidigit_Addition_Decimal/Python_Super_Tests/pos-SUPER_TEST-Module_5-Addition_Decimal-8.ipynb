# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 8
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_49_01.json
# Out of 10000, 1035 predictions correct.
# Out of 9808, 1019 train predictions correct.
# Out of 6975, 423 carry-over predictions correct.
# Out of 6879, 423 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 784 large predictions correct.
# Out of 8013, 768 large train predictions correct.
# Out of 6246, 423 carry-over large predictions correct.
# Out of 6198, 423 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_03.json
# Out of 10000, 834 predictions correct.
# Out of 9808, 818 train predictions correct.
# Out of 6975, 220 carry-over predictions correct.
# Out of 6879, 220 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 581 large predictions correct.
# Out of 8013, 565 large train predictions correct.
# Out of 6246, 220 carry-over large predictions correct.
# Out of 6198, 220 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_05.json
# Out of 10000, 1438 predictions correct.
# Out of 9808, 1422 train predictions correct.
# Out of 6975, 740 carry-over predictions correct.
# Out of 6879, 740 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1150 large predictions correct.
# Out of 8013, 1134 large train predictions correct.
# Out of 6246, 740 carry-over large predictions correct.
# Out of 6198, 740 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_07.json
# Out of 10000, 430 predictions correct.
# Out of 9808, 420 train predictions correct.
# Out of 6975, 188 carry-over predictions correct.
# Out of 6879, 188 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 324 large predictions correct.
# Out of 8013, 314 large train predictions correct.
# Out of 6246, 188 carry-over large predictions correct.
# Out of 6198, 188 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_09.json
# Out of 10000, 760 predictions correct.
# Out of 9808, 744 train predictions correct.
# Out of 6975, 198 carry-over predictions correct.
# Out of 6879, 198 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 559 large predictions correct.
# Out of 8013, 543 large train predictions correct.
# Out of 6246, 198 carry-over large predictions correct.
# Out of 6198, 198 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_11.json
# Out of 10000, 401 predictions correct.
# Out of 9808, 391 train predictions correct.
# Out of 6975, 159 carry-over predictions correct.
# Out of 6879, 159 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 295 large predictions correct.
# Out of 8013, 285 large train predictions correct.
# Out of 6246, 159 carry-over large predictions correct.
# Out of 6198, 159 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_13.json
# Out of 10000, 3408 predictions correct.
# Out of 9808, 3352 train predictions correct.
# Out of 6975, 1573 carry-over predictions correct.
# Out of 6879, 1557 carry-over train predictions correct.
# Out of 820, 215 small predictions correct.
# Out of 724, 213 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2784 large predictions correct.
# Out of 8013, 2730 large train predictions correct.
# Out of 6246, 1573 carry-over large predictions correct.
# Out of 6198, 1557 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_15.json
# Out of 10000, 470 predictions correct.
# Out of 9808, 456 train predictions correct.
# Out of 6975, 11 carry-over predictions correct.
# Out of 6879, 11 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 282 large predictions correct.
# Out of 8013, 268 large train predictions correct.
# Out of 6246, 11 carry-over large predictions correct.
# Out of 6198, 11 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_17.json
# Out of 10000, 624 predictions correct.
# Out of 9808, 612 train predictions correct.
# Out of 6975, 307 carry-over predictions correct.
# Out of 6879, 307 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 506 large predictions correct.
# Out of 8013, 494 large train predictions correct.
# Out of 6246, 307 carry-over large predictions correct.
# Out of 6198, 307 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_19.json
# Out of 10000, 1581 predictions correct.
# Out of 9808, 1565 train predictions correct.
# Out of 6975, 661 carry-over predictions correct.
# Out of 6879, 661 carry-over train predictions correct.
# Out of 820, 129 small predictions correct.
# Out of 724, 129 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1216 large predictions correct.
# Out of 8013, 1200 large train predictions correct.
# Out of 6246, 661 carry-over large predictions correct.
# Out of 6198, 661 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_22.json
# Out of 10000, 1133 predictions correct.
# Out of 9808, 1117 train predictions correct.
# Out of 6975, 522 carry-over predictions correct.
# Out of 6879, 522 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 883 large predictions correct.
# Out of 8013, 867 large train predictions correct.
# Out of 6246, 522 carry-over large predictions correct.
# Out of 6198, 522 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_24.json
# Out of 10000, 506 predictions correct.
# Out of 9808, 496 train predictions correct.
# Out of 6975, 252 carry-over predictions correct.
# Out of 6879, 252 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 388 large predictions correct.
# Out of 8013, 378 large train predictions correct.
# Out of 6246, 252 carry-over large predictions correct.
# Out of 6198, 252 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_26.json
# Out of 10000, 886 predictions correct.
# Out of 9808, 870 train predictions correct.
# Out of 6975, 360 carry-over predictions correct.
# Out of 6879, 360 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 721 large predictions correct.
# Out of 8013, 705 large train predictions correct.
# Out of 6246, 360 carry-over large predictions correct.
# Out of 6198, 360 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_28.json
# Out of 10000, 448 predictions correct.
# Out of 9808, 436 train predictions correct.
# Out of 6975, 131 carry-over predictions correct.
# Out of 6879, 131 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 330 large predictions correct.
# Out of 8013, 318 large train predictions correct.
# Out of 6246, 131 carry-over large predictions correct.
# Out of 6198, 131 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_30.json
# Out of 10000, 829 predictions correct.
# Out of 9808, 815 train predictions correct.
# Out of 6975, 370 carry-over predictions correct.
# Out of 6879, 370 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 641 large predictions correct.
# Out of 8013, 627 large train predictions correct.
# Out of 6246, 370 carry-over large predictions correct.
# Out of 6198, 370 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_32.json
# Out of 10000, 506 predictions correct.
# Out of 9808, 496 train predictions correct.
# Out of 6975, 252 carry-over predictions correct.
# Out of 6879, 252 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 388 large predictions correct.
# Out of 8013, 378 large train predictions correct.
# Out of 6246, 252 carry-over large predictions correct.
# Out of 6198, 252 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_34.json
# Out of 10000, 466 predictions correct.
# Out of 9808, 454 train predictions correct.
# Out of 6975, 124 carry-over predictions correct.
# Out of 6879, 124 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 332 large predictions correct.
# Out of 8013, 320 large train predictions correct.
# Out of 6246, 124 carry-over large predictions correct.
# Out of 6198, 124 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_36.json
# Out of 10000, 856 predictions correct.
# Out of 9808, 840 train predictions correct.
# Out of 6975, 282 carry-over predictions correct.
# Out of 6879, 282 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 643 large predictions correct.
# Out of 8013, 627 large train predictions correct.
# Out of 6246, 282 carry-over large predictions correct.
# Out of 6198, 282 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_38.json
# Out of 10000, 581 predictions correct.
# Out of 9808, 569 train predictions correct.
# Out of 6975, 255 carry-over predictions correct.
# Out of 6879, 255 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 463 large predictions correct.
# Out of 8013, 451 large train predictions correct.
# Out of 6246, 255 carry-over large predictions correct.
# Out of 6198, 255 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_40.json
# Out of 10000, 678 predictions correct.
# Out of 9808, 666 train predictions correct.
# Out of 6975, 336 carry-over predictions correct.
# Out of 6879, 336 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 544 large predictions correct.
# Out of 8013, 532 large train predictions correct.
# Out of 6246, 336 carry-over large predictions correct.
# Out of 6198, 336 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_42.json
# Out of 10000, 624 predictions correct.
# Out of 9808, 612 train predictions correct.
# Out of 6975, 307 carry-over predictions correct.
# Out of 6879, 307 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 506 large predictions correct.
# Out of 8013, 494 large train predictions correct.
# Out of 6246, 307 carry-over large predictions correct.
# Out of 6198, 307 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_44.json
# Out of 10000, 877 predictions correct.
# Out of 9808, 861 train predictions correct.
# Out of 6975, 351 carry-over predictions correct.
# Out of 6879, 351 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 712 large predictions correct.
# Out of 8013, 696 large train predictions correct.
# Out of 6246, 351 carry-over large predictions correct.
# Out of 6198, 351 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_46.json
# Out of 10000, 562 predictions correct.
# Out of 9808, 552 train predictions correct.
# Out of 6975, 308 carry-over predictions correct.
# Out of 6879, 308 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 444 large predictions correct.
# Out of 8013, 434 large train predictions correct.
# Out of 6246, 308 carry-over large predictions correct.
# Out of 6198, 308 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_48.json
# Out of 10000, 458 predictions correct.
# Out of 9808, 444 train predictions correct.
# Out of 6975, 53 carry-over predictions correct.
# Out of 6879, 53 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 324 large predictions correct.
# Out of 8013, 310 large train predictions correct.
# Out of 6246, 53 carry-over large predictions correct.
# Out of 6198, 53 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_50.json
# Out of 10000, 489 predictions correct.
# Out of 9808, 479 train predictions correct.
# Out of 6975, 235 carry-over predictions correct.
# Out of 6879, 235 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 371 large predictions correct.
# Out of 8013, 361 large train predictions correct.
# Out of 6246, 235 carry-over large predictions correct.
# Out of 6198, 235 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_52.json
# Out of 10000, 585 predictions correct.
# Out of 9808, 569 train predictions correct.
# Out of 6975, 11 carry-over predictions correct.
# Out of 6879, 11 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 372 large predictions correct.
# Out of 8013, 356 large train predictions correct.
# Out of 6246, 11 carry-over large predictions correct.
# Out of 6198, 11 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_54.json
# Out of 10000, 494 predictions correct.
# Out of 9808, 482 train predictions correct.
# Out of 6975, 177 carry-over predictions correct.
# Out of 6879, 177 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 376 large predictions correct.
# Out of 8013, 364 large train predictions correct.
# Out of 6246, 177 carry-over large predictions correct.
# Out of 6198, 177 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_56.json
# Out of 10000, 474 predictions correct.
# Out of 9808, 464 train predictions correct.
# Out of 6975, 232 carry-over predictions correct.
# Out of 6879, 232 carry-over train predictions correct.
# Out of 820, 34 small predictions correct.
# Out of 724, 34 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 368 large predictions correct.
# Out of 8013, 358 large train predictions correct.
# Out of 6246, 232 carry-over large predictions correct.
# Out of 6198, 232 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_49_58.json
# Out of 10000, 1007 predictions correct.
# Out of 9808, 991 train predictions correct.
# Out of 6975, 395 carry-over predictions correct.
# Out of 6879, 395 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 756 large predictions correct.
# Out of 8013, 740 large train predictions correct.
# Out of 6246, 395 carry-over large predictions correct.
# Out of 6198, 395 carry-over large train predictions correct.
