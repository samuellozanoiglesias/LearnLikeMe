# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 0.9
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_31_59.json
# Out of 10000, 6573 predictions correct.
# Out of 9808, 6477 train predictions correct.
# Out of 6975, 3938 carry-over predictions correct.
# Out of 6879, 3908 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5414 large predictions correct.
# Out of 8013, 5338 large train predictions correct.
# Out of 6246, 3839 carry-over large predictions correct.
# Out of 6198, 3809 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_01.json
# Out of 10000, 8408 predictions correct.
# Out of 9808, 8272 train predictions correct.
# Out of 6975, 5422 carry-over predictions correct.
# Out of 6879, 5382 carry-over train predictions correct.
# Out of 820, 577 small predictions correct.
# Out of 724, 529 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6947 large predictions correct.
# Out of 8013, 6859 large train predictions correct.
# Out of 6246, 5123 carry-over large predictions correct.
# Out of 6198, 5083 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_03.json
# Out of 10000, 6198 predictions correct.
# Out of 9808, 6108 train predictions correct.
# Out of 6975, 3650 carry-over predictions correct.
# Out of 6879, 3622 carry-over train predictions correct.
# Out of 820, 448 small predictions correct.
# Out of 724, 428 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5097 large predictions correct.
# Out of 8013, 5027 large train predictions correct.
# Out of 6246, 3596 carry-over large predictions correct.
# Out of 6198, 3568 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_05.json
# Out of 10000, 8850 predictions correct.
# Out of 9808, 8708 train predictions correct.
# Out of 6975, 5835 carry-over predictions correct.
# Out of 6879, 5789 carry-over train predictions correct.
# Out of 820, 640 small predictions correct.
# Out of 724, 588 small train predictions correct.
# Out of 270, 90 carry-over small predictions correct.
# Out of 222, 86 carry-over small train predictions correct.
# Out of 8109, 7249 large predictions correct.
# Out of 8013, 7159 large train predictions correct.
# Out of 6246, 5396 carry-over large predictions correct.
# Out of 6198, 5354 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_07.json
# Out of 10000, 5345 predictions correct.
# Out of 9808, 5275 train predictions correct.
# Out of 6975, 3060 carry-over predictions correct.
# Out of 6879, 3040 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4339 large predictions correct.
# Out of 8013, 4279 large train predictions correct.
# Out of 6246, 3006 carry-over large predictions correct.
# Out of 6198, 2986 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_09.json
# Out of 10000, 5885 predictions correct.
# Out of 9808, 5803 train predictions correct.
# Out of 6975, 3430 carry-over predictions correct.
# Out of 6879, 3404 carry-over train predictions correct.
# Out of 820, 432 small predictions correct.
# Out of 724, 418 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4800 large predictions correct.
# Out of 8013, 4732 large train predictions correct.
# Out of 6246, 3376 carry-over large predictions correct.
# Out of 6198, 3350 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_11.json
# Out of 10000, 5375 predictions correct.
# Out of 9808, 5305 train predictions correct.
# Out of 6975, 3096 carry-over predictions correct.
# Out of 6879, 3076 carry-over train predictions correct.
# Out of 820, 359 small predictions correct.
# Out of 724, 349 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4375 large predictions correct.
# Out of 8013, 4315 large train predictions correct.
# Out of 6246, 3042 carry-over large predictions correct.
# Out of 6198, 3022 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_13.json
# Out of 10000, 8779 predictions correct.
# Out of 9808, 8637 train predictions correct.
# Out of 6975, 5764 carry-over predictions correct.
# Out of 6879, 5718 carry-over train predictions correct.
# Out of 820, 640 small predictions correct.
# Out of 724, 588 small train predictions correct.
# Out of 270, 90 carry-over small predictions correct.
# Out of 222, 86 carry-over small train predictions correct.
# Out of 8109, 7178 large predictions correct.
# Out of 8013, 7088 large train predictions correct.
# Out of 6246, 5325 carry-over large predictions correct.
# Out of 6198, 5283 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_15.json
# Out of 10000, 5110 predictions correct.
# Out of 9808, 5040 train predictions correct.
# Out of 6975, 2904 carry-over predictions correct.
# Out of 6879, 2884 carry-over train predictions correct.
# Out of 820, 345 small predictions correct.
# Out of 724, 335 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4183 large predictions correct.
# Out of 8013, 4123 large train predictions correct.
# Out of 6246, 2904 carry-over large predictions correct.
# Out of 6198, 2884 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_17.json
# Out of 10000, 6421 predictions correct.
# Out of 9808, 6327 train predictions correct.
# Out of 6975, 3800 carry-over predictions correct.
# Out of 6879, 3772 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5262 large predictions correct.
# Out of 8013, 5188 large train predictions correct.
# Out of 6246, 3701 carry-over large predictions correct.
# Out of 6198, 3673 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_19.json
# Out of 10000, 9644 predictions correct.
# Out of 9808, 9476 train predictions correct.
# Out of 6975, 6619 carry-over predictions correct.
# Out of 6879, 6547 carry-over train predictions correct.
# Out of 820, 751 small predictions correct.
# Out of 724, 679 small train predictions correct.
# Out of 270, 201 carry-over small predictions correct.
# Out of 222, 177 carry-over small train predictions correct.
# Out of 8109, 7839 large predictions correct.
# Out of 8013, 7743 large train predictions correct.
# Out of 6246, 5976 carry-over large predictions correct.
# Out of 6198, 5928 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_21.json
# Out of 10000, 6226 predictions correct.
# Out of 9808, 6136 train predictions correct.
# Out of 6975, 3678 carry-over predictions correct.
# Out of 6879, 3650 carry-over train predictions correct.
# Out of 820, 448 small predictions correct.
# Out of 724, 428 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5125 large predictions correct.
# Out of 8013, 5055 large train predictions correct.
# Out of 6246, 3624 carry-over large predictions correct.
# Out of 6198, 3596 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_23.json
# Out of 10000, 5246 predictions correct.
# Out of 9808, 5176 train predictions correct.
# Out of 6975, 2972 carry-over predictions correct.
# Out of 6879, 2952 carry-over train predictions correct.
# Out of 820, 359 small predictions correct.
# Out of 724, 349 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4305 large predictions correct.
# Out of 8013, 4245 large train predictions correct.
# Out of 6246, 2972 carry-over large predictions correct.
# Out of 6198, 2952 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_25.json
# Out of 10000, 8194 predictions correct.
# Out of 9808, 8060 train predictions correct.
# Out of 6975, 5248 carry-over predictions correct.
# Out of 6879, 5208 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 521 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6773 large predictions correct.
# Out of 8013, 6685 large train predictions correct.
# Out of 6246, 4979 carry-over large predictions correct.
# Out of 6198, 4939 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_27.json
# Out of 10000, 7268 predictions correct.
# Out of 9808, 7154 train predictions correct.
# Out of 6975, 4460 carry-over predictions correct.
# Out of 6879, 4424 carry-over train predictions correct.
# Out of 820, 511 small predictions correct.
# Out of 724, 479 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5970 large predictions correct.
# Out of 8013, 5888 large train predictions correct.
# Out of 6246, 4285 carry-over large predictions correct.
# Out of 6198, 4249 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_29.json
# Out of 10000, 5762 predictions correct.
# Out of 9808, 5684 train predictions correct.
# Out of 6975, 3334 carry-over predictions correct.
# Out of 6879, 3308 carry-over train predictions correct.
# Out of 820, 405 small predictions correct.
# Out of 724, 395 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4704 large predictions correct.
# Out of 8013, 4636 large train predictions correct.
# Out of 6246, 3280 carry-over large predictions correct.
# Out of 6198, 3254 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_31.json
# Out of 10000, 5730 predictions correct.
# Out of 9808, 5658 train predictions correct.
# Out of 6975, 3302 carry-over predictions correct.
# Out of 6879, 3282 carry-over train predictions correct.
# Out of 820, 405 small predictions correct.
# Out of 724, 395 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4672 large predictions correct.
# Out of 8013, 4610 large train predictions correct.
# Out of 6246, 3248 carry-over large predictions correct.
# Out of 6198, 3228 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_33.json
# Out of 10000, 9915 predictions correct.
# Out of 9808, 9727 train predictions correct.
# Out of 6975, 6890 carry-over predictions correct.
# Out of 6879, 6798 carry-over train predictions correct.
# Out of 820, 805 small predictions correct.
# Out of 724, 713 small train predictions correct.
# Out of 270, 255 carry-over small predictions correct.
# Out of 222, 211 carry-over small train predictions correct.
# Out of 8109, 8039 large predictions correct.
# Out of 8013, 7943 large train predictions correct.
# Out of 6246, 6176 carry-over large predictions correct.
# Out of 6198, 6128 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_35.json
# Out of 10000, 5522 predictions correct.
# Out of 9808, 5450 train predictions correct.
# Out of 6975, 3155 carry-over predictions correct.
# Out of 6879, 3135 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4504 large predictions correct.
# Out of 8013, 4442 large train predictions correct.
# Out of 6246, 3101 carry-over large predictions correct.
# Out of 6198, 3081 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_37.json
# Out of 10000, 5762 predictions correct.
# Out of 9808, 5684 train predictions correct.
# Out of 6975, 3334 carry-over predictions correct.
# Out of 6879, 3308 carry-over train predictions correct.
# Out of 820, 405 small predictions correct.
# Out of 724, 395 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4704 large predictions correct.
# Out of 8013, 4636 large train predictions correct.
# Out of 6246, 3280 carry-over large predictions correct.
# Out of 6198, 3254 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_39.json
# Out of 10000, 5525 predictions correct.
# Out of 9808, 5453 train predictions correct.
# Out of 6975, 3158 carry-over predictions correct.
# Out of 6879, 3138 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4507 large predictions correct.
# Out of 8013, 4445 large train predictions correct.
# Out of 6246, 3104 carry-over large predictions correct.
# Out of 6198, 3084 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_41.json
# Out of 10000, 7748 predictions correct.
# Out of 9808, 7614 train predictions correct.
# Out of 6975, 4828 carry-over predictions correct.
# Out of 6879, 4788 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6354 large predictions correct.
# Out of 8013, 6266 large train predictions correct.
# Out of 6246, 4586 carry-over large predictions correct.
# Out of 6198, 4546 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_43.json
# Out of 10000, 8079 predictions correct.
# Out of 9808, 7945 train predictions correct.
# Out of 6975, 5159 carry-over predictions correct.
# Out of 6879, 5119 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6685 large predictions correct.
# Out of 8013, 6597 large train predictions correct.
# Out of 6246, 4917 carry-over large predictions correct.
# Out of 6198, 4877 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_45.json
# Out of 10000, 8013 predictions correct.
# Out of 9808, 7879 train predictions correct.
# Out of 6975, 5067 carry-over predictions correct.
# Out of 6879, 5027 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 521 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6592 large predictions correct.
# Out of 8013, 6504 large train predictions correct.
# Out of 6246, 4798 carry-over large predictions correct.
# Out of 6198, 4758 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_47.json
# Out of 10000, 6142 predictions correct.
# Out of 9808, 6052 train predictions correct.
# Out of 6975, 3594 carry-over predictions correct.
# Out of 6879, 3566 carry-over train predictions correct.
# Out of 820, 448 small predictions correct.
# Out of 724, 428 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5041 large predictions correct.
# Out of 8013, 4971 large train predictions correct.
# Out of 6246, 3540 carry-over large predictions correct.
# Out of 6198, 3512 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_49.json
# Out of 10000, 8013 predictions correct.
# Out of 9808, 7879 train predictions correct.
# Out of 6975, 5067 carry-over predictions correct.
# Out of 6879, 5027 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 521 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6592 large predictions correct.
# Out of 8013, 6504 large train predictions correct.
# Out of 6246, 4798 carry-over large predictions correct.
# Out of 6198, 4758 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_32_51.json
# Out of 10000, 9927 predictions correct.
# Out of 9808, 9741 train predictions correct.
# Out of 6975, 6902 carry-over predictions correct.
# Out of 6879, 6812 carry-over train predictions correct.
# Out of 820, 795 small predictions correct.
# Out of 724, 705 small train predictions correct.
# Out of 270, 245 carry-over small predictions correct.
# Out of 222, 203 carry-over small train predictions correct.
# Out of 8109, 8061 large predictions correct.
# Out of 8013, 7965 large train predictions correct.
# Out of 6246, 6198 carry-over large predictions correct.
# Out of 6198, 6150 carry-over large train predictions correct.
