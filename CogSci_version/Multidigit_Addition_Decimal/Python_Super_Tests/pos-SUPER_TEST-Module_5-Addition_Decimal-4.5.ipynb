# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 4.5
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_42_01.json
# Out of 10000, 1723 predictions correct.
# Out of 9808, 1707 train predictions correct.
# Out of 6975, 931 carry-over predictions correct.
# Out of 6879, 931 carry-over train predictions correct.
# Out of 820, 102 small predictions correct.
# Out of 724, 102 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1405 large predictions correct.
# Out of 8013, 1389 large train predictions correct.
# Out of 6246, 931 carry-over large predictions correct.
# Out of 6198, 931 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_03.json
# Out of 10000, 1126 predictions correct.
# Out of 9808, 1110 train predictions correct.
# Out of 6975, 550 carry-over predictions correct.
# Out of 6879, 550 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 911 large predictions correct.
# Out of 8013, 895 large train predictions correct.
# Out of 6246, 550 carry-over large predictions correct.
# Out of 6198, 550 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_05.json
# Out of 10000, 1503 predictions correct.
# Out of 9808, 1487 train predictions correct.
# Out of 6975, 805 carry-over predictions correct.
# Out of 6879, 805 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1215 large predictions correct.
# Out of 8013, 1199 large train predictions correct.
# Out of 6246, 805 carry-over large predictions correct.
# Out of 6198, 805 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_07.json
# Out of 10000, 2156 predictions correct.
# Out of 9808, 2134 train predictions correct.
# Out of 6975, 1058 carry-over predictions correct.
# Out of 6879, 1058 carry-over train predictions correct.
# Out of 820, 137 small predictions correct.
# Out of 724, 137 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1783 large predictions correct.
# Out of 8013, 1761 large train predictions correct.
# Out of 6246, 1058 carry-over large predictions correct.
# Out of 6198, 1058 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_09.json
# Out of 10000, 1034 predictions correct.
# Out of 9808, 1018 train predictions correct.
# Out of 6975, 460 carry-over predictions correct.
# Out of 6879, 460 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 821 large predictions correct.
# Out of 8013, 805 large train predictions correct.
# Out of 6246, 460 carry-over large predictions correct.
# Out of 6198, 460 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_11.json
# Out of 10000, 1124 predictions correct.
# Out of 9808, 1108 train predictions correct.
# Out of 6975, 550 carry-over predictions correct.
# Out of 6879, 550 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 911 large predictions correct.
# Out of 8013, 895 large train predictions correct.
# Out of 6246, 550 carry-over large predictions correct.
# Out of 6198, 550 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_13.json
# Out of 10000, 1007 predictions correct.
# Out of 9808, 991 train predictions correct.
# Out of 6975, 458 carry-over predictions correct.
# Out of 6879, 458 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 819 large predictions correct.
# Out of 8013, 803 large train predictions correct.
# Out of 6246, 458 carry-over large predictions correct.
# Out of 6198, 458 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_15.json
# Out of 10000, 1820 predictions correct.
# Out of 9808, 1800 train predictions correct.
# Out of 6975, 945 carry-over predictions correct.
# Out of 6879, 945 carry-over train predictions correct.
# Out of 820, 125 small predictions correct.
# Out of 724, 125 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1425 large predictions correct.
# Out of 8013, 1405 large train predictions correct.
# Out of 6246, 945 carry-over large predictions correct.
# Out of 6198, 945 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_17.json
# Out of 10000, 3005 predictions correct.
# Out of 9808, 2971 train predictions correct.
# Out of 6975, 1466 carry-over predictions correct.
# Out of 6879, 1462 carry-over train predictions correct.
# Out of 820, 179 small predictions correct.
# Out of 724, 179 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2451 large predictions correct.
# Out of 8013, 2417 large train predictions correct.
# Out of 6246, 1466 carry-over large predictions correct.
# Out of 6198, 1462 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_19.json
# Out of 10000, 1070 predictions correct.
# Out of 9808, 1054 train predictions correct.
# Out of 6975, 496 carry-over predictions correct.
# Out of 6879, 496 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 857 large predictions correct.
# Out of 8013, 841 large train predictions correct.
# Out of 6246, 496 carry-over large predictions correct.
# Out of 6198, 496 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_21.json
# Out of 10000, 919 predictions correct.
# Out of 9808, 905 train predictions correct.
# Out of 6975, 460 carry-over predictions correct.
# Out of 6879, 460 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 731 large predictions correct.
# Out of 8013, 717 large train predictions correct.
# Out of 6246, 460 carry-over large predictions correct.
# Out of 6198, 460 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_23.json
# Out of 10000, 2076 predictions correct.
# Out of 9808, 2058 train predictions correct.
# Out of 6975, 1056 carry-over predictions correct.
# Out of 6879, 1056 carry-over train predictions correct.
# Out of 820, 129 small predictions correct.
# Out of 724, 129 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1711 large predictions correct.
# Out of 8013, 1693 large train predictions correct.
# Out of 6246, 1056 carry-over large predictions correct.
# Out of 6198, 1056 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_25.json
# Out of 10000, 1953 predictions correct.
# Out of 9808, 1933 train predictions correct.
# Out of 6975, 1002 carry-over predictions correct.
# Out of 6879, 1002 carry-over train predictions correct.
# Out of 820, 137 small predictions correct.
# Out of 724, 137 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1546 large predictions correct.
# Out of 8013, 1526 large train predictions correct.
# Out of 6246, 1002 carry-over large predictions correct.
# Out of 6198, 1002 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_27.json
# Out of 10000, 7566 predictions correct.
# Out of 9808, 7432 train predictions correct.
# Out of 6975, 4590 carry-over predictions correct.
# Out of 6879, 4550 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 521 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6145 large predictions correct.
# Out of 8013, 6057 large train predictions correct.
# Out of 6246, 4321 carry-over large predictions correct.
# Out of 6198, 4281 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_29.json
# Out of 10000, 5045 predictions correct.
# Out of 9808, 4959 train predictions correct.
# Out of 6975, 2637 carry-over predictions correct.
# Out of 6879, 2611 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3937 large predictions correct.
# Out of 8013, 3871 large train predictions correct.
# Out of 6246, 2583 carry-over large predictions correct.
# Out of 6198, 2557 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_31.json
# Out of 10000, 1340 predictions correct.
# Out of 9808, 1324 train predictions correct.
# Out of 6975, 691 carry-over predictions correct.
# Out of 6879, 691 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1052 large predictions correct.
# Out of 8013, 1036 large train predictions correct.
# Out of 6246, 691 carry-over large predictions correct.
# Out of 6198, 691 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_33.json
# Out of 10000, 1688 predictions correct.
# Out of 9808, 1672 train predictions correct.
# Out of 6975, 815 carry-over predictions correct.
# Out of 6879, 815 carry-over train predictions correct.
# Out of 820, 102 small predictions correct.
# Out of 724, 102 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1370 large predictions correct.
# Out of 8013, 1354 large train predictions correct.
# Out of 6246, 815 carry-over large predictions correct.
# Out of 6198, 815 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_35.json
# Out of 10000, 2111 predictions correct.
# Out of 9808, 2089 train predictions correct.
# Out of 6975, 1053 carry-over predictions correct.
# Out of 6879, 1049 carry-over train predictions correct.
# Out of 820, 137 small predictions correct.
# Out of 724, 137 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1708 large predictions correct.
# Out of 8013, 1686 large train predictions correct.
# Out of 6246, 1053 carry-over large predictions correct.
# Out of 6198, 1049 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_37.json
# Out of 10000, 1533 predictions correct.
# Out of 9808, 1517 train predictions correct.
# Out of 6975, 805 carry-over predictions correct.
# Out of 6879, 805 carry-over train predictions correct.
# Out of 820, 102 small predictions correct.
# Out of 724, 102 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1215 large predictions correct.
# Out of 8013, 1199 large train predictions correct.
# Out of 6246, 805 carry-over large predictions correct.
# Out of 6198, 805 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_39.json
# Out of 10000, 1477 predictions correct.
# Out of 9808, 1461 train predictions correct.
# Out of 6975, 804 carry-over predictions correct.
# Out of 6879, 804 carry-over train predictions correct.
# Out of 820, 96 small predictions correct.
# Out of 724, 96 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1165 large predictions correct.
# Out of 8013, 1149 large train predictions correct.
# Out of 6246, 804 carry-over large predictions correct.
# Out of 6198, 804 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_41.json
# Out of 10000, 902 predictions correct.
# Out of 9808, 888 train predictions correct.
# Out of 6975, 443 carry-over predictions correct.
# Out of 6879, 443 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 714 large predictions correct.
# Out of 8013, 700 large train predictions correct.
# Out of 6246, 443 carry-over large predictions correct.
# Out of 6198, 443 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_43.json
# Out of 10000, 1186 predictions correct.
# Out of 9808, 1170 train predictions correct.
# Out of 6975, 610 carry-over predictions correct.
# Out of 6879, 610 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 971 large predictions correct.
# Out of 8013, 955 large train predictions correct.
# Out of 6246, 610 carry-over large predictions correct.
# Out of 6198, 610 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_45.json
# Out of 10000, 2838 predictions correct.
# Out of 9808, 2806 train predictions correct.
# Out of 6975, 1484 carry-over predictions correct.
# Out of 6879, 1480 carry-over train predictions correct.
# Out of 820, 171 small predictions correct.
# Out of 724, 171 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2307 large predictions correct.
# Out of 8013, 2275 large train predictions correct.
# Out of 6246, 1484 carry-over large predictions correct.
# Out of 6198, 1480 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_47.json
# Out of 10000, 2789 predictions correct.
# Out of 9808, 2753 train predictions correct.
# Out of 6975, 1327 carry-over predictions correct.
# Out of 6879, 1323 carry-over train predictions correct.
# Out of 820, 207 small predictions correct.
# Out of 724, 205 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2222 large predictions correct.
# Out of 8013, 2188 large train predictions correct.
# Out of 6246, 1327 carry-over large predictions correct.
# Out of 6198, 1323 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_49.json
# Out of 10000, 3846 predictions correct.
# Out of 9808, 3794 train predictions correct.
# Out of 6975, 2045 carry-over predictions correct.
# Out of 6879, 2029 carry-over train predictions correct.
# Out of 820, 211 small predictions correct.
# Out of 724, 209 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3176 large predictions correct.
# Out of 8013, 3126 large train predictions correct.
# Out of 6246, 2045 carry-over large predictions correct.
# Out of 6198, 2029 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_51.json
# Out of 10000, 1363 predictions correct.
# Out of 9808, 1347 train predictions correct.
# Out of 6975, 716 carry-over predictions correct.
# Out of 6879, 716 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1077 large predictions correct.
# Out of 8013, 1061 large train predictions correct.
# Out of 6246, 716 carry-over large predictions correct.
# Out of 6198, 716 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_53.json
# Out of 10000, 2180 predictions correct.
# Out of 9808, 2154 train predictions correct.
# Out of 6975, 1049 carry-over predictions correct.
# Out of 6879, 1045 carry-over train predictions correct.
# Out of 820, 140 small predictions correct.
# Out of 724, 140 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1774 large predictions correct.
# Out of 8013, 1748 large train predictions correct.
# Out of 6246, 1049 carry-over large predictions correct.
# Out of 6198, 1045 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_42_55.json
# Out of 10000, 1034 predictions correct.
# Out of 9808, 1018 train predictions correct.
# Out of 6975, 460 carry-over predictions correct.
# Out of 6879, 460 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 821 large predictions correct.
# Out of 8013, 805 large train predictions correct.
# Out of 6246, 460 carry-over large predictions correct.
# Out of 6198, 460 carry-over large train predictions correct.
