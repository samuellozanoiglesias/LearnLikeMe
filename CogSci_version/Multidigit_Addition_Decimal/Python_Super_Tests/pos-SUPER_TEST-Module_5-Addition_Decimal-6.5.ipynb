# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 6.5
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_46_01.json
# Out of 10000, 1779 predictions correct.
# Out of 9808, 1759 train predictions correct.
# Out of 6975, 828 carry-over predictions correct.
# Out of 6879, 828 carry-over train predictions correct.
# Out of 820, 137 small predictions correct.
# Out of 724, 137 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1372 large predictions correct.
# Out of 8013, 1352 large train predictions correct.
# Out of 6246, 828 carry-over large predictions correct.
# Out of 6198, 828 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_03.json
# Out of 10000, 1559 predictions correct.
# Out of 9808, 1539 train predictions correct.
# Out of 6975, 801 carry-over predictions correct.
# Out of 6879, 801 carry-over train predictions correct.
# Out of 820, 111 small predictions correct.
# Out of 724, 111 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1232 large predictions correct.
# Out of 8013, 1212 large train predictions correct.
# Out of 6246, 801 carry-over large predictions correct.
# Out of 6198, 801 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_05.json
# Out of 10000, 1052 predictions correct.
# Out of 9808, 1036 train predictions correct.
# Out of 6975, 403 carry-over predictions correct.
# Out of 6879, 403 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 764 large predictions correct.
# Out of 8013, 748 large train predictions correct.
# Out of 6246, 403 carry-over large predictions correct.
# Out of 6198, 403 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_07.json
# Out of 10000, 871 predictions correct.
# Out of 9808, 855 train predictions correct.
# Out of 6975, 260 carry-over predictions correct.
# Out of 6879, 260 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 621 large predictions correct.
# Out of 8013, 605 large train predictions correct.
# Out of 6246, 260 carry-over large predictions correct.
# Out of 6198, 260 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_09.json
# Out of 10000, 1043 predictions correct.
# Out of 9808, 1027 train predictions correct.
# Out of 6975, 517 carry-over predictions correct.
# Out of 6879, 517 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 878 large predictions correct.
# Out of 8013, 862 large train predictions correct.
# Out of 6246, 517 carry-over large predictions correct.
# Out of 6198, 517 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_11.json
# Out of 10000, 861 predictions correct.
# Out of 9808, 845 train predictions correct.
# Out of 6975, 360 carry-over predictions correct.
# Out of 6879, 360 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 721 large predictions correct.
# Out of 8013, 705 large train predictions correct.
# Out of 6246, 360 carry-over large predictions correct.
# Out of 6198, 360 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_13.json
# Out of 10000, 874 predictions correct.
# Out of 9808, 858 train predictions correct.
# Out of 6975, 348 carry-over predictions correct.
# Out of 6879, 348 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 709 large predictions correct.
# Out of 8013, 693 large train predictions correct.
# Out of 6246, 348 carry-over large predictions correct.
# Out of 6198, 348 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_15.json
# Out of 10000, 776 predictions correct.
# Out of 9808, 762 train predictions correct.
# Out of 6975, 371 carry-over predictions correct.
# Out of 6879, 371 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 642 large predictions correct.
# Out of 8013, 628 large train predictions correct.
# Out of 6246, 371 carry-over large predictions correct.
# Out of 6198, 371 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_17.json
# Out of 10000, 665 predictions correct.
# Out of 9808, 653 train predictions correct.
# Out of 6975, 339 carry-over predictions correct.
# Out of 6879, 339 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 547 large predictions correct.
# Out of 8013, 535 large train predictions correct.
# Out of 6246, 339 carry-over large predictions correct.
# Out of 6198, 339 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_19.json
# Out of 10000, 1070 predictions correct.
# Out of 9808, 1054 train predictions correct.
# Out of 6975, 494 carry-over predictions correct.
# Out of 6879, 494 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 855 large predictions correct.
# Out of 8013, 839 large train predictions correct.
# Out of 6246, 494 carry-over large predictions correct.
# Out of 6198, 494 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_21.json
# Out of 10000, 776 predictions correct.
# Out of 9808, 762 train predictions correct.
# Out of 6975, 317 carry-over predictions correct.
# Out of 6879, 317 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 588 large predictions correct.
# Out of 8013, 574 large train predictions correct.
# Out of 6246, 317 carry-over large predictions correct.
# Out of 6198, 317 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_23.json
# Out of 10000, 1503 predictions correct.
# Out of 9808, 1487 train predictions correct.
# Out of 6975, 805 carry-over predictions correct.
# Out of 6879, 805 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1215 large predictions correct.
# Out of 8013, 1199 large train predictions correct.
# Out of 6246, 805 carry-over large predictions correct.
# Out of 6198, 805 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_25.json
# Out of 10000, 777 predictions correct.
# Out of 9808, 763 train predictions correct.
# Out of 6975, 388 carry-over predictions correct.
# Out of 6879, 388 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 659 large predictions correct.
# Out of 8013, 645 large train predictions correct.
# Out of 6246, 388 carry-over large predictions correct.
# Out of 6198, 388 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_27.json
# Out of 10000, 566 predictions correct.
# Out of 9808, 552 train predictions correct.
# Out of 6975, 177 carry-over predictions correct.
# Out of 6879, 177 carry-over train predictions correct.
# Out of 820, 46 small predictions correct.
# Out of 724, 46 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 448 large predictions correct.
# Out of 8013, 434 large train predictions correct.
# Out of 6246, 177 carry-over large predictions correct.
# Out of 6198, 177 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_29.json
# Out of 10000, 1220 predictions correct.
# Out of 9808, 1204 train predictions correct.
# Out of 6975, 609 carry-over predictions correct.
# Out of 6879, 609 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 970 large predictions correct.
# Out of 8013, 954 large train predictions correct.
# Out of 6246, 609 carry-over large predictions correct.
# Out of 6198, 609 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_31.json
# Out of 10000, 1097 predictions correct.
# Out of 9808, 1081 train predictions correct.
# Out of 6975, 523 carry-over predictions correct.
# Out of 6879, 523 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 884 large predictions correct.
# Out of 8013, 868 large train predictions correct.
# Out of 6246, 523 carry-over large predictions correct.
# Out of 6198, 523 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_33.json
# Out of 10000, 959 predictions correct.
# Out of 9808, 943 train predictions correct.
# Out of 6975, 395 carry-over predictions correct.
# Out of 6879, 395 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 756 large predictions correct.
# Out of 8013, 740 large train predictions correct.
# Out of 6246, 395 carry-over large predictions correct.
# Out of 6198, 395 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_35.json
# Out of 10000, 1116 predictions correct.
# Out of 9808, 1100 train predictions correct.
# Out of 6975, 504 carry-over predictions correct.
# Out of 6879, 504 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 865 large predictions correct.
# Out of 8013, 849 large train predictions correct.
# Out of 6246, 504 carry-over large predictions correct.
# Out of 6198, 504 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_37.json
# Out of 10000, 1043 predictions correct.
# Out of 9808, 1027 train predictions correct.
# Out of 6975, 517 carry-over predictions correct.
# Out of 6879, 517 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 878 large predictions correct.
# Out of 8013, 862 large train predictions correct.
# Out of 6246, 517 carry-over large predictions correct.
# Out of 6198, 517 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_39.json
# Out of 10000, 1392 predictions correct.
# Out of 9808, 1376 train predictions correct.
# Out of 6975, 694 carry-over predictions correct.
# Out of 6879, 694 carry-over train predictions correct.
# Out of 820, 72 small predictions correct.
# Out of 724, 72 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1104 large predictions correct.
# Out of 8013, 1088 large train predictions correct.
# Out of 6246, 694 carry-over large predictions correct.
# Out of 6198, 694 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_41.json
# Out of 10000, 1150 predictions correct.
# Out of 9808, 1134 train predictions correct.
# Out of 6975, 574 carry-over predictions correct.
# Out of 6879, 574 carry-over train predictions correct.
# Out of 820, 70 small predictions correct.
# Out of 724, 70 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 935 large predictions correct.
# Out of 8013, 919 large train predictions correct.
# Out of 6246, 574 carry-over large predictions correct.
# Out of 6198, 574 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_43.json
# Out of 10000, 654 predictions correct.
# Out of 9808, 640 train predictions correct.
# Out of 6975, 249 carry-over predictions correct.
# Out of 6879, 249 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 520 large predictions correct.
# Out of 8013, 506 large train predictions correct.
# Out of 6246, 249 carry-over large predictions correct.
# Out of 6198, 249 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_45.json
# Out of 10000, 1578 predictions correct.
# Out of 9808, 1558 train predictions correct.
# Out of 6975, 651 carry-over predictions correct.
# Out of 6879, 651 carry-over train predictions correct.
# Out of 820, 137 small predictions correct.
# Out of 724, 137 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1131 large predictions correct.
# Out of 8013, 1111 large train predictions correct.
# Out of 6246, 651 carry-over large predictions correct.
# Out of 6198, 651 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_47.json
# Out of 10000, 921 predictions correct.
# Out of 9808, 905 train predictions correct.
# Out of 6975, 395 carry-over predictions correct.
# Out of 6879, 395 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 756 large predictions correct.
# Out of 8013, 740 large train predictions correct.
# Out of 6246, 395 carry-over large predictions correct.
# Out of 6198, 395 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_49.json
# Out of 10000, 733 predictions correct.
# Out of 9808, 719 train predictions correct.
# Out of 6975, 322 carry-over predictions correct.
# Out of 6879, 322 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 593 large predictions correct.
# Out of 8013, 579 large train predictions correct.
# Out of 6246, 322 carry-over large predictions correct.
# Out of 6198, 322 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_51.json
# Out of 10000, 1215 predictions correct.
# Out of 9808, 1199 train predictions correct.
# Out of 6975, 423 carry-over predictions correct.
# Out of 6879, 423 carry-over train predictions correct.
# Out of 820, 102 small predictions correct.
# Out of 724, 102 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 897 large predictions correct.
# Out of 8013, 881 large train predictions correct.
# Out of 6246, 423 carry-over large predictions correct.
# Out of 6198, 423 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_53.json
# Out of 10000, 888 predictions correct.
# Out of 9808, 872 train predictions correct.
# Out of 6975, 339 carry-over predictions correct.
# Out of 6879, 339 carry-over train predictions correct.
# Out of 820, 68 small predictions correct.
# Out of 724, 68 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 700 large predictions correct.
# Out of 8013, 684 large train predictions correct.
# Out of 6246, 339 carry-over large predictions correct.
# Out of 6198, 339 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_55.json
# Out of 10000, 1995 predictions correct.
# Out of 9808, 1975 train predictions correct.
# Out of 6975, 1065 carry-over predictions correct.
# Out of 6879, 1065 carry-over train predictions correct.
# Out of 820, 140 small predictions correct.
# Out of 724, 140 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 1545 large predictions correct.
# Out of 8013, 1525 large train predictions correct.
# Out of 6246, 1065 carry-over large predictions correct.
# Out of 6198, 1065 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_46_57.json
# Out of 10000, 988 predictions correct.
# Out of 9808, 972 train predictions correct.
# Out of 6975, 493 carry-over predictions correct.
# Out of 6879, 493 carry-over train predictions correct.
# Out of 820, 62 small predictions correct.
# Out of 724, 62 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 854 large predictions correct.
# Out of 8013, 838 large train predictions correct.
# Out of 6246, 493 carry-over large predictions correct.
# Out of 6198, 493 carry-over large train predictions correct.
