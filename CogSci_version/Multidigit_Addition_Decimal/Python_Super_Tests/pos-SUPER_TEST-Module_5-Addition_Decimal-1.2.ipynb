# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 1.2
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
unit_addition_model = load_model('unit_addition_module.keras')
unit_carry_model = load_model('unit_carry_module.keras')
dec_addition_model = load_model('dec_addition_module.keras')
dec_carry_model = load_model('dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Super_Tests/"
folder_path = f'{folder}Super_Trained_models/AP_{epsilon}'
date_pattern = r'super_trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Super_Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/super_trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded super_trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded super_trained_model_2024_12_20_01_34_00.json
# Out of 10000, 7692 predictions correct.
# Out of 9808, 7562 train predictions correct.
# Out of 6975, 4812 carry-over predictions correct.
# Out of 6879, 4774 carry-over train predictions correct.
# Out of 820, 540 small predictions correct.
# Out of 724, 494 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 6365 large predictions correct.
# Out of 8013, 6281 large train predictions correct.
# Out of 6246, 4637 carry-over large predictions correct.
# Out of 6198, 4599 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_02.json
# Out of 10000, 7673 predictions correct.
# Out of 9808, 7541 train predictions correct.
# Out of 6975, 4762 carry-over predictions correct.
# Out of 6879, 4722 carry-over train predictions correct.
# Out of 820, 558 small predictions correct.
# Out of 724, 514 small train predictions correct.
# Out of 270, 27 carry-over small predictions correct.
# Out of 222, 27 carry-over small train predictions correct.
# Out of 8109, 6261 large predictions correct.
# Out of 8013, 6173 large train predictions correct.
# Out of 6246, 4493 carry-over large predictions correct.
# Out of 6198, 4453 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_04.json
# Out of 10000, 6150 predictions correct.
# Out of 9808, 6060 train predictions correct.
# Out of 6975, 3640 carry-over predictions correct.
# Out of 6879, 3612 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5042 large predictions correct.
# Out of 8013, 4972 large train predictions correct.
# Out of 6246, 3586 carry-over large predictions correct.
# Out of 6198, 3558 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_06.json
# Out of 10000, 4972 predictions correct.
# Out of 9808, 4904 train predictions correct.
# Out of 6975, 2806 carry-over predictions correct.
# Out of 6879, 2786 carry-over train predictions correct.
# Out of 820, 345 small predictions correct.
# Out of 724, 335 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4045 large predictions correct.
# Out of 8013, 3987 large train predictions correct.
# Out of 6246, 2806 carry-over large predictions correct.
# Out of 6198, 2786 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_08.json
# Out of 10000, 6223 predictions correct.
# Out of 9808, 6129 train predictions correct.
# Out of 6975, 3615 carry-over predictions correct.
# Out of 6879, 3587 carry-over train predictions correct.
# Out of 820, 448 small predictions correct.
# Out of 724, 428 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5077 large predictions correct.
# Out of 8013, 5003 large train predictions correct.
# Out of 6246, 3516 carry-over large predictions correct.
# Out of 6198, 3488 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_10.json
# Out of 10000, 5541 predictions correct.
# Out of 9808, 5469 train predictions correct.
# Out of 6975, 3174 carry-over predictions correct.
# Out of 6879, 3154 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4523 large predictions correct.
# Out of 8013, 4461 large train predictions correct.
# Out of 6246, 3120 carry-over large predictions correct.
# Out of 6198, 3100 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_12.json
# Out of 10000, 6706 predictions correct.
# Out of 9808, 6608 train predictions correct.
# Out of 6975, 4011 carry-over predictions correct.
# Out of 6879, 3979 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5547 large predictions correct.
# Out of 8013, 5469 large train predictions correct.
# Out of 6246, 3912 carry-over large predictions correct.
# Out of 6198, 3880 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_14.json
# Out of 10000, 3765 predictions correct.
# Out of 9808, 3723 train predictions correct.
# Out of 6975, 1998 carry-over predictions correct.
# Out of 6879, 1988 carry-over train predictions correct.
# Out of 820, 243 small predictions correct.
# Out of 724, 241 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3018 large predictions correct.
# Out of 8013, 2978 large train predictions correct.
# Out of 6246, 1998 carry-over large predictions correct.
# Out of 6198, 1988 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_16.json
# Out of 10000, 5545 predictions correct.
# Out of 9808, 5473 train predictions correct.
# Out of 6975, 3178 carry-over predictions correct.
# Out of 6879, 3158 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4527 large predictions correct.
# Out of 8013, 4465 large train predictions correct.
# Out of 6246, 3124 carry-over large predictions correct.
# Out of 6198, 3104 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_18.json
# Out of 10000, 6529 predictions correct.
# Out of 9808, 6433 train predictions correct.
# Out of 6975, 3894 carry-over predictions correct.
# Out of 6879, 3864 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5370 large predictions correct.
# Out of 8013, 5294 large train predictions correct.
# Out of 6246, 3795 carry-over large predictions correct.
# Out of 6198, 3765 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_20.json
# Out of 10000, 6333 predictions correct.
# Out of 9808, 6243 train predictions correct.
# Out of 6975, 3778 carry-over predictions correct.
# Out of 6879, 3750 carry-over train predictions correct.
# Out of 820, 455 small predictions correct.
# Out of 724, 435 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5225 large predictions correct.
# Out of 8013, 5155 large train predictions correct.
# Out of 6246, 3724 carry-over large predictions correct.
# Out of 6198, 3696 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_22.json
# Out of 10000, 5515 predictions correct.
# Out of 9808, 5443 train predictions correct.
# Out of 6975, 3148 carry-over predictions correct.
# Out of 6879, 3128 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4497 large predictions correct.
# Out of 8013, 4435 large train predictions correct.
# Out of 6246, 3094 carry-over large predictions correct.
# Out of 6198, 3074 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_24.json
# Out of 10000, 3861 predictions correct.
# Out of 9808, 3813 train predictions correct.
# Out of 6975, 2094 carry-over predictions correct.
# Out of 6879, 2078 carry-over train predictions correct.
# Out of 820, 243 small predictions correct.
# Out of 724, 241 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3114 large predictions correct.
# Out of 8013, 3068 large train predictions correct.
# Out of 6246, 2094 carry-over large predictions correct.
# Out of 6198, 2078 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_26.json
# Out of 10000, 5510 predictions correct.
# Out of 9808, 5438 train predictions correct.
# Out of 6975, 3155 carry-over predictions correct.
# Out of 6879, 3135 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4504 large predictions correct.
# Out of 8013, 4442 large train predictions correct.
# Out of 6246, 3101 carry-over large predictions correct.
# Out of 6198, 3081 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_28.json
# Out of 10000, 6595 predictions correct.
# Out of 9808, 6493 train predictions correct.
# Out of 6975, 3930 carry-over predictions correct.
# Out of 6879, 3900 carry-over train predictions correct.
# Out of 820, 485 small predictions correct.
# Out of 724, 459 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5406 large predictions correct.
# Out of 8013, 5330 large train predictions correct.
# Out of 6246, 3831 carry-over large predictions correct.
# Out of 6198, 3801 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_30.json
# Out of 10000, 4206 predictions correct.
# Out of 9808, 4156 train predictions correct.
# Out of 6975, 2366 carry-over predictions correct.
# Out of 6879, 2350 carry-over train predictions correct.
# Out of 820, 268 small predictions correct.
# Out of 724, 264 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3434 large predictions correct.
# Out of 8013, 3388 large train predictions correct.
# Out of 6246, 2366 carry-over large predictions correct.
# Out of 6198, 2350 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_32.json
# Out of 10000, 5562 predictions correct.
# Out of 9808, 5490 train predictions correct.
# Out of 6975, 3174 carry-over predictions correct.
# Out of 6879, 3154 carry-over train predictions correct.
# Out of 820, 365 small predictions correct.
# Out of 724, 355 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4544 large predictions correct.
# Out of 8013, 4482 large train predictions correct.
# Out of 6246, 3120 carry-over large predictions correct.
# Out of 6198, 3100 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_34.json
# Out of 10000, 3649 predictions correct.
# Out of 9808, 3607 train predictions correct.
# Out of 6975, 1917 carry-over predictions correct.
# Out of 6879, 1907 carry-over train predictions correct.
# Out of 820, 243 small predictions correct.
# Out of 724, 241 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 2902 large predictions correct.
# Out of 8013, 2862 large train predictions correct.
# Out of 6246, 1917 carry-over large predictions correct.
# Out of 6198, 1907 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_36.json
# Out of 10000, 5186 predictions correct.
# Out of 9808, 5116 train predictions correct.
# Out of 6975, 2966 carry-over predictions correct.
# Out of 6879, 2946 carry-over train predictions correct.
# Out of 820, 359 small predictions correct.
# Out of 724, 349 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4245 large predictions correct.
# Out of 8013, 4185 large train predictions correct.
# Out of 6246, 2966 carry-over large predictions correct.
# Out of 6198, 2946 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_38.json
# Out of 10000, 4978 predictions correct.
# Out of 9808, 4910 train predictions correct.
# Out of 6975, 2812 carry-over predictions correct.
# Out of 6879, 2792 carry-over train predictions correct.
# Out of 820, 345 small predictions correct.
# Out of 724, 335 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4051 large predictions correct.
# Out of 8013, 3993 large train predictions correct.
# Out of 6246, 2812 carry-over large predictions correct.
# Out of 6198, 2792 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_40.json
# Out of 10000, 4296 predictions correct.
# Out of 9808, 4240 train predictions correct.
# Out of 6975, 2381 carry-over predictions correct.
# Out of 6879, 2365 carry-over train predictions correct.
# Out of 820, 280 small predictions correct.
# Out of 724, 274 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3512 large predictions correct.
# Out of 8013, 3462 large train predictions correct.
# Out of 6246, 2381 carry-over large predictions correct.
# Out of 6198, 2365 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_42.json
# Out of 10000, 3861 predictions correct.
# Out of 9808, 3813 train predictions correct.
# Out of 6975, 2094 carry-over predictions correct.
# Out of 6879, 2078 carry-over train predictions correct.
# Out of 820, 243 small predictions correct.
# Out of 724, 241 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3114 large predictions correct.
# Out of 8013, 3068 large train predictions correct.
# Out of 6246, 2094 carry-over large predictions correct.
# Out of 6198, 2078 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_44.json
# Out of 10000, 5895 predictions correct.
# Out of 9808, 5813 train predictions correct.
# Out of 6975, 3440 carry-over predictions correct.
# Out of 6879, 3414 carry-over train predictions correct.
# Out of 820, 432 small predictions correct.
# Out of 724, 418 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 4810 large predictions correct.
# Out of 8013, 4742 large train predictions correct.
# Out of 6246, 3386 carry-over large predictions correct.
# Out of 6198, 3360 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_46.json
# Out of 10000, 9116 predictions correct.
# Out of 9808, 8964 train predictions correct.
# Out of 6975, 6101 carry-over predictions correct.
# Out of 6879, 6045 carry-over train predictions correct.
# Out of 820, 656 small predictions correct.
# Out of 724, 596 small train predictions correct.
# Out of 270, 106 carry-over small predictions correct.
# Out of 222, 94 carry-over small train predictions correct.
# Out of 8109, 7499 large predictions correct.
# Out of 8013, 7407 large train predictions correct.
# Out of 6246, 5646 carry-over large predictions correct.
# Out of 6198, 5602 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_48.json
# Out of 10000, 9964 predictions correct.
# Out of 9808, 9774 train predictions correct.
# Out of 6975, 6939 carry-over predictions correct.
# Out of 6879, 6845 carry-over train predictions correct.
# Out of 820, 815 small predictions correct.
# Out of 724, 721 small train predictions correct.
# Out of 270, 265 carry-over small predictions correct.
# Out of 222, 219 carry-over small train predictions correct.
# Out of 8109, 8078 large predictions correct.
# Out of 8013, 7982 large train predictions correct.
# Out of 6246, 6215 carry-over large predictions correct.
# Out of 6198, 6167 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_50.json
# Out of 10000, 4541 predictions correct.
# Out of 9808, 4481 train predictions correct.
# Out of 6975, 2463 carry-over predictions correct.
# Out of 6879, 2447 carry-over train predictions correct.
# Out of 820, 285 small predictions correct.
# Out of 724, 279 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3674 large predictions correct.
# Out of 8013, 3620 large train predictions correct.
# Out of 6246, 2463 carry-over large predictions correct.
# Out of 6198, 2447 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_52.json
# Out of 10000, 4774 predictions correct.
# Out of 9808, 4712 train predictions correct.
# Out of 6975, 2660 carry-over predictions correct.
# Out of 6879, 2642 carry-over train predictions correct.
# Out of 820, 321 small predictions correct.
# Out of 724, 315 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 3871 large predictions correct.
# Out of 8013, 3815 large train predictions correct.
# Out of 6246, 2660 carry-over large predictions correct.
# Out of 6198, 2642 carry-over large train predictions correct.
# Loaded super_trained_model_2024_12_20_01_34_54.json
# Out of 10000, 6226 predictions correct.
# Out of 9808, 6136 train predictions correct.
# Out of 6975, 3678 carry-over predictions correct.
# Out of 6879, 3650 carry-over train predictions correct.
# Out of 820, 448 small predictions correct.
# Out of 724, 428 small train predictions correct.
# Out of 270, 0 carry-over small predictions correct.
# Out of 222, 0 carry-over small train predictions correct.
# Out of 8109, 5125 large predictions correct.
# Out of 8013, 5055 large train predictions correct.
# Out of 6246, 3624 carry-over large predictions correct.
# Out of 6198, 3596 carry-over large train predictions correct.
