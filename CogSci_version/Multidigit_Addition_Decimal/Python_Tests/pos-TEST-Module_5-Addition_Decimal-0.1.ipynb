# %%
import numpy as np
import os
import re
import random
import json
import sys
import time
from datetime import datetime
import pandas as pd
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')
from tensorflow.keras.models import Model, load_model, clone_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, Multiply, Add, Lambda, Concatenate, Reshape, Flatten
from tensorflow.keras.initializers import GlorotUniform, RandomUniform, Constant
from tensorflow.keras.callbacks import LambdaCallback
import jax
import jax.numpy as jnp
from jax import grad, jit

# %%
epsilon = 0.1
folder = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Curriculum_Learning/Multidigit_Addition_Decimal/'

# %%
# Cargar los módulos preentrenados (unit_module y carry_module)
folder_models = 'D:/OneDrive - Universidad Complutense de Madrid (UCM)/Doctorado/Programacion/Curriculum_Learning/Multidigit_Addition_Decimal/'

unit_addition_model = load_model(f'{folder_models}unit_addition_module.keras')
unit_carry_model = load_model(f'{folder_models}unit_carry_module.keras')
dec_addition_model = load_model(f'{folder_models}dec_addition_module.keras')
dec_carry_model = load_model(f'{folder_models}dec_carry_module.keras')

unit_addition_model.trainable = False
unit_carry_model.trainable = False
dec_addition_model.trainable = False
dec_carry_model.trainable = False

unit_addition_model.name = 'unit_addition_model'
unit_carry_model.name = 'unit_carry_model'
dec_addition_model.name = 'dec_addition_model'
dec_carry_model.name = 'dec_carry_model'

# %%
# Cargar las parejas desde el archivo
with open(f"{folder}/test_dataset.txt", 'r') as file:
    test_dataset = eval(file.read())  # Convertir el contenido del archivo a una lista de tuplas
    
with open(f"{folder}/train_couples_stimuli.txt", "r") as file:
    train_couples = eval(file.read())

with open(f"{folder}/combinations_with_carry_over.txt", "r") as file:
    combinations_with_carry_over = eval(file.read())  # Leer y convertir el contenido en una lista de tuplas

with open(f"{folder}/combinations_small_problem_size.txt", 'r') as file:
    combinations_small_problem_size = eval(file.read())

with open(f"{folder}/combinations_large_problem_size.txt", 'r') as file:
    combinations_large_problem_size = eval(file.read())

carry_over_small = [pair for pair in combinations_with_carry_over if pair in combinations_small_problem_size]
carry_over_large = [pair for pair in combinations_with_carry_over if pair in combinations_large_problem_size]
train_with_carry_over = [pair for pair in train_couples if pair in combinations_with_carry_over]
train_with_small = [pair for pair in train_couples if pair in combinations_small_problem_size]
train_with_large = [pair for pair in train_couples if pair in combinations_large_problem_size]
train_with_carry_over_small = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_small_problem_size]
train_with_carry_over_large = [pair for pair in train_couples if pair in combinations_with_carry_over if pair in combinations_large_problem_size]

# %%
def generate_test_dataset():
    x_data = []
    y_data = []
    
    for a, b in test_dataset:
        a_dec = a // 10  # Decena del primer número
        a_unit = a % 10  # Unidad del primer número
        b_dec = b // 10  # Decena del segundo número
        b_unit = b % 10  # Unidad del segundo número

        x_data.append([a_dec, a_unit, b_dec, b_unit])  # Entrada

        sum_units = (a_unit + b_unit) % 10
        carry_units = 1 if (a_unit + b_unit) >= 10 else 0
        sum_dec = (a_dec + b_dec + carry_units) % 10
        carry_dec = 1 if (a_dec + b_dec + carry_units) >= 10 else 0
        y_data.append([carry_dec, sum_dec, sum_units])  # Salida
    
    return jnp.array(x_data), jnp.array(y_data)

# Modelo dinámico en JAX
def model(params, x):
    units_input = jnp.array(x[:, [1, 3]])  # Columnas 1 y 3 representando unidades y decenas
    units_input = units_input[:, None, :]  # Añade una dimensión extra para la secuencia (N, 1, 2)
                            
    unit_output = jnp.array(unit_addition_model(units_input))  # Asegúrate de que la entrada sea un batch
    unit_carry_output = jnp.array(unit_carry_model(units_input))  # Salida de acarreo de unidades

    # Tomar el valor máximo de las predicciones (argmax en JAX)
    unit_val = jnp.argmax(unit_output, axis=-1)
    carry_unit_val = jnp.argmax(unit_carry_output, axis=-1)

    decs_input = jnp.array(x[:, [0, 2]])
    decs_input = jnp.concatenate([decs_input, carry_unit_val[:, None]], axis=-1)
    decs_input = decs_input[:, None, :]  # Añadir dimensión para la secuencia (N, 1, 3)
    
    dec_output = jnp.array(dec_addition_model(decs_input))  # Salida para decenas
    dec_carry_output = jnp.array(dec_carry_model(decs_input))  # Salida de acarreo de decenas
    
    dec_val = jnp.argmax(dec_output, axis=-1)
    carry_dec_val = jnp.argmax(dec_carry_output, axis=-1)

    # Calcular las salidas combinadas con los parámetros v
    salida_1 = (params['v0'] * carry_dec_val) + (params['v1'] * dec_val) + (params['v2'] * carry_unit_val) + (params['v3'] * unit_val)
    salida_2 = (params['v4'] * carry_dec_val) + (params['v5'] * dec_val) + (params['v6'] * carry_unit_val) + (params['v7'] * unit_val)
    salida_3 = (params['v8'] * carry_dec_val) + (params['v9'] * dec_val) + (params['v10'] * carry_unit_val) + (params['v11'] * unit_val)

    return salida_1, salida_2, salida_3
    
    
def predictions(params, x_test, y_test):
    pred_count = 0
    pred_count_train = 0
    pred_count_carry_over = 0
    pred_count_carry_over_train = 0
    pred_count_small = 0
    pred_count_small_train = 0
    pred_count_carry_over_small = 0
    pred_count_carry_over_small_train = 0
    pred_count_large = 0
    pred_count_large_train = 0
    pred_count_carry_over_large = 0
    pred_count_carry_over_large_train = 0
    
    total_examples = x_test.shape[0]
    total_train = len(train_couples)
    total_carry_over = len(combinations_with_carry_over)
    total_train_with_carry_over = len(train_with_carry_over)
    total_small = len(combinations_small_problem_size)
    total_train_with_small = len(train_with_small)
    total_carry_over_small = len(carry_over_small)
    total_train_with_carry_over_small = len(train_with_carry_over_small)
    total_large = len(combinations_large_problem_size)
    total_train_with_large = len(train_with_large)
    total_carry_over_large = len(carry_over_large)
    total_train_with_carry_over_large = len(train_with_carry_over_large)
    
    pred_hundreds, pred_tens, pred_units = model(params, x_test)        
    
    for i in range(total_examples):
        normalized_pred = [int(jnp.round(pred_hundreds[i].item())),
                           int(jnp.round(pred_tens[i].item())),
                           int(jnp.round(pred_units[i].item()))]
        
        a = int(str(x_test[i, 0]) + str(x_test[i, 1]))
        b = int(str(x_test[i, 2]) + str(x_test[i, 3]))
        
        if normalized_pred[0] == y_test[i, 0] and normalized_pred[1] == y_test[i, 1] and normalized_pred[2] == y_test[i, 2]:
            pred_count += 1
            
            if (a, b) in train_couples:
                pred_count_train += 1
                
                if (a, b) in combinations_with_carry_over:
                    pred_count_carry_over_train += 1

                    if (a, b) in combinations_small_problem_size:
                        pred_count_carry_over_small_train += 1

                    elif (a, b) in combinations_large_problem_size:
                        pred_count_carry_over_large_train += 1

                if (a, b) in combinations_small_problem_size:
                    pred_count_small_train += 1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_large_train += 1

            if (a, b) in combinations_with_carry_over:
                pred_count_carry_over +=1

                if (a, b) in combinations_small_problem_size:
                    pred_count_carry_over_small +=1

                elif (a, b) in combinations_large_problem_size:
                    pred_count_carry_over_large +=1
                
            if (a, b) in combinations_small_problem_size:
                pred_count_small +=1   

            elif (a, b) in combinations_large_problem_size:
                pred_count_large +=1 

    print(f'Out of {total_examples}, {pred_count} predictions correct.')
    print(f'Out of {total_train}, {pred_count_train} train predictions correct.')
    print(f'Out of {total_carry_over}, {pred_count_carry_over} carry-over predictions correct.')
    print(f'Out of {total_train_with_carry_over}, {pred_count_carry_over_train} carry-over train predictions correct.')
    print(f'Out of {total_small}, {pred_count_small} small predictions correct.')
    print(f'Out of {total_train_with_small}, {pred_count_small_train} small train predictions correct.')
    print(f'Out of {total_carry_over_small}, {pred_count_carry_over_small} carry-over small predictions correct.')
    print(f'Out of {total_train_with_carry_over_small}, {pred_count_carry_over_small_train} carry-over small train predictions correct.')   
    print(f'Out of {total_large}, {pred_count_large} large predictions correct.')
    print(f'Out of {total_train_with_large}, {pred_count_large_train} large train predictions correct.')
    print(f'Out of {total_carry_over_large}, {pred_count_carry_over_large} carry-over large predictions correct.')
    print(f'Out of {total_train_with_carry_over_large}, {pred_count_carry_over_large_train} carry-over large train predictions correct.') 

    return None

# %%
def load_params_from_file(filename):
    with open(filename, 'r') as f:
        return json.load(f)

class Tee(object):
    def __init__(self, file, mode='w'):
        self.file = open(file, mode)
        self.console = sys.stdout  

    def write(self, data):
        self.console.write(data)   
        self.file.write(data)    

    def flush(self):
        self.console.flush()
        self.file.flush()

    def close(self):
        self.file.close()

# %%
x_test, y_test = generate_test_dataset()

save_dir = f"{folder}Tests/"
folder_path = f'{folder}Trained_models/AP_{epsilon}'
date_pattern = r'trained_model_(\d{4}_\d{2}_\d{2}_\d{2}_\d{2}_\d{2}).json'
files = sorted(
    (f for f in os.listdir(folder_path) if not f.startswith('.')),  # Filtrar archivos ocultos
    key=lambda x: re.search(date_pattern, x).group(1) if re.search(date_pattern, x) else ''
)

os.makedirs(save_dir, exist_ok=True) 
results_file = os.path.join(save_dir, f"Tests_AP_{epsilon}.txt") 
tee = Tee(results_file, 'w') 
sys.stdout = tee

try:
    for filename in files:
        match = re.search(date_pattern, filename)
        if match:
            current_time = match.group(1)
        else:
            print('Error')
            break
        
        file_path = f"{folder_path}/trained_model_{current_time}.json"
        with open(file_path, 'rb') as file:
            trained_model = json.load(file)
    
        trained_model_jnp = {key: jnp.array(value) for key, value in trained_model.items()}
        print(f'Loaded trained_model_{current_time}.json')

        predictions(trained_model_jnp, x_test, y_test)
    
finally:
    sys.stdout = tee.console
    tee.close()
# Out:
# Loaded trained_model_2024_12_29_15_40_47.json
# Out of 10000, 1485 predictions correct.
# Out of 9808, 1409 train predictions correct.
# Out of 6975, 1155 carry-over predictions correct.
# Out of 6879, 1127 carry-over train predictions correct.
# Out of 820, 495 small predictions correct.
# Out of 724, 433 small train predictions correct.
# Out of 270, 165 carry-over small predictions correct.
# Out of 222, 151 carry-over small train predictions correct.
# Out of 8109, 531 large predictions correct.
# Out of 8013, 517 large train predictions correct.
# Out of 6246, 531 carry-over large predictions correct.
# Out of 6198, 517 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_40_49.json
# Out of 10000, 4950 predictions correct.
# Out of 9808, 4760 train predictions correct.
# Out of 6975, 2025 carry-over predictions correct.
# Out of 6879, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 3059 large predictions correct.
# Out of 8013, 2965 large train predictions correct.
# Out of 6246, 1296 carry-over large predictions correct.
# Out of 6198, 1248 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_40_51.json
# Out of 10000, 1834 predictions correct.
# Out of 9808, 1786 train predictions correct.
# Out of 6975, 1644 carry-over predictions correct.
# Out of 6879, 1612 carry-over train predictions correct.
# Out of 820, 367 small predictions correct.
# Out of 724, 331 small train predictions correct.
# Out of 270, 177 carry-over small predictions correct.
# Out of 222, 157 carry-over small train predictions correct.
# Out of 8109, 1008 large predictions correct.
# Out of 8013, 996 large train predictions correct.
# Out of 6246, 1008 carry-over large predictions correct.
# Out of 6198, 996 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_40_53.json
# Out of 10000, 2715 predictions correct.
# Out of 9808, 2597 train predictions correct.
# Out of 6975, 2205 carry-over predictions correct.
# Out of 6879, 2135 carry-over train predictions correct.
# Out of 820, 750 small predictions correct.
# Out of 724, 664 small train predictions correct.
# Out of 270, 240 carry-over small predictions correct.
# Out of 222, 202 carry-over small train predictions correct.
# Out of 8109, 1506 large predictions correct.
# Out of 8013, 1474 large train predictions correct.
# Out of 6246, 1506 carry-over large predictions correct.
# Out of 6198, 1474 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_40_55.json
# Out of 10000, 2255 predictions correct.
# Out of 9808, 2167 train predictions correct.
# Out of 6975, 1978 carry-over predictions correct.
# Out of 6879, 1928 carry-over train predictions correct.
# Out of 820, 505 small predictions correct.
# Out of 724, 437 small train predictions correct.
# Out of 270, 228 carry-over small predictions correct.
# Out of 222, 198 carry-over small train predictions correct.
# Out of 8109, 1291 large predictions correct.
# Out of 8013, 1271 large train predictions correct.
# Out of 6246, 1291 carry-over large predictions correct.
# Out of 6198, 1271 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_40_57.json
# Out of 10000, 3589 predictions correct.
# Out of 9808, 3437 train predictions correct.
# Out of 6975, 2025 carry-over predictions correct.
# Out of 6879, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 1698 large predictions correct.
# Out of 8013, 1642 large train predictions correct.
# Out of 6246, 1296 carry-over large predictions correct.
# Out of 6198, 1248 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_40_59.json
# Out of 10000, 3327 predictions correct.
# Out of 9808, 3183 train predictions correct.
# Out of 6975, 2637 carry-over predictions correct.
# Out of 6879, 2541 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 1908 large predictions correct.
# Out of 8013, 1860 large train predictions correct.
# Out of 6246, 1908 carry-over large predictions correct.
# Out of 6198, 1860 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_01.json
# Out of 10000, 1749 predictions correct.
# Out of 9808, 1651 train predictions correct.
# Out of 6975, 1407 carry-over predictions correct.
# Out of 6879, 1357 carry-over train predictions correct.
# Out of 820, 567 small predictions correct.
# Out of 724, 491 small train predictions correct.
# Out of 270, 225 carry-over small predictions correct.
# Out of 222, 197 carry-over small train predictions correct.
# Out of 8109, 723 large predictions correct.
# Out of 8013, 701 large train predictions correct.
# Out of 6246, 723 carry-over large predictions correct.
# Out of 6198, 701 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_03.json
# Out of 10000, 3316 predictions correct.
# Out of 9808, 3172 train predictions correct.
# Out of 6975, 2025 carry-over predictions correct.
# Out of 6879, 1929 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 1485 large predictions correct.
# Out of 8013, 1437 large train predictions correct.
# Out of 6246, 1296 carry-over large predictions correct.
# Out of 6198, 1248 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_05.json
# Out of 10000, 1467 predictions correct.
# Out of 9808, 1397 train predictions correct.
# Out of 6975, 1137 carry-over predictions correct.
# Out of 6879, 1115 carry-over train predictions correct.
# Out of 820, 477 small predictions correct.
# Out of 724, 421 small train predictions correct.
# Out of 270, 147 carry-over small predictions correct.
# Out of 222, 139 carry-over small train predictions correct.
# Out of 8109, 531 large predictions correct.
# Out of 8013, 517 large train predictions correct.
# Out of 6246, 531 carry-over large predictions correct.
# Out of 6198, 517 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_07.json
# Out of 10000, 2827 predictions correct.
# Out of 9808, 2717 train predictions correct.
# Out of 6975, 2514 carry-over predictions correct.
# Out of 6879, 2442 carry-over train predictions correct.
# Out of 820, 559 small predictions correct.
# Out of 724, 477 small train predictions correct.
# Out of 270, 246 carry-over small predictions correct.
# Out of 222, 202 carry-over small train predictions correct.
# Out of 8109, 1809 large predictions correct.
# Out of 8013, 1781 large train predictions correct.
# Out of 6246, 1809 carry-over large predictions correct.
# Out of 6198, 1781 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_09.json
# Out of 10000, 2459 predictions correct.
# Out of 9808, 2319 train predictions correct.
# Out of 6975, 1935 carry-over predictions correct.
# Out of 6879, 1843 carry-over train predictions correct.
# Out of 820, 744 small predictions correct.
# Out of 724, 648 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 1206 large predictions correct.
# Out of 8013, 1162 large train predictions correct.
# Out of 6246, 1206 carry-over large predictions correct.
# Out of 6198, 1162 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_11.json
# Out of 10000, 1526 predictions correct.
# Out of 9808, 1454 train predictions correct.
# Out of 6975, 1253 carry-over predictions correct.
# Out of 6879, 1219 carry-over train predictions correct.
# Out of 820, 464 small predictions correct.
# Out of 724, 406 small train predictions correct.
# Out of 270, 191 carry-over small predictions correct.
# Out of 222, 171 carry-over small train predictions correct.
# Out of 8109, 603 large predictions correct.
# Out of 8013, 589 large train predictions correct.
# Out of 6246, 603 carry-over large predictions correct.
# Out of 6198, 589 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_13.json
# Out of 10000, 4395 predictions correct.
# Out of 9808, 4251 train predictions correct.
# Out of 6975, 3240 carry-over predictions correct.
# Out of 6879, 3144 carry-over train predictions correct.
# Out of 820, 820 small predictions correct.
# Out of 724, 724 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 2511 large predictions correct.
# Out of 8013, 2463 large train predictions correct.
# Out of 6246, 2511 carry-over large predictions correct.
# Out of 6198, 2463 carry-over large train predictions correct.
# Loaded trained_model_2024_12_29_15_41_15.json
# Out of 10000, 2042 predictions correct.
# Out of 9808, 1924 train predictions correct.
# Out of 6975, 1718 carry-over predictions correct.
# Out of 6879, 1634 carry-over train predictions correct.
# Out of 820, 579 small predictions correct.
# Out of 724, 497 small train predictions correct.
# Out of 270, 270 carry-over small predictions correct.
# Out of 222, 222 carry-over small train predictions correct.
# Out of 8109, 989 large predictions correct.
# Out of 8013, 953 large train predictions correct.
# Out of 6246, 989 carry-over large predictions correct.
# Out of 6198, 953 carry-over large train predictions correct.
